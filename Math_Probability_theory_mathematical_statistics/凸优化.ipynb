# %% [markdown]
# https://mp.weixin.qq.com/s/3fGepdiD042rSgYOAbJAXA
#
#
#
# 在机器学习中，要做的核心工作之一就是根据实际问题，定义出一个目标函数，接着找到这个目标函数的最优解。

# %% [markdown]
# 有一类问题叫做凸优化问题，我们可以比较有效的找到全局最优解。这就是今天我们就来介绍的主角——凸优化。话不多说，先来看一下相关的一些定义。
#
# # 凸函数
#
# 若$f(x)$是凸函数，（如$y=x^2$）则函数图像位于凸函数上方的区域构成凸集。
#
# 有：
#
#     凸函数图像的上方区域，一定是凸集。
#     一个函数图像的上方区域是凸集，则该函数就是凸函数。
#     __凸函数的局部最小值就是全局最小值__。

# %% [markdown]
# ## 正式定义：
# （1）若函数$f$的定义域$domf$为凸集，且满足
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# 若f是一元函数，上式表示二阶导大于等于零。
#
# 若f是多元函数，上式表示二阶导Hessian矩阵半正定。
#
# ## 凸函数的举例：
#
# 指数函数：$f(x)=e^{ax}$
#
# 幂函数：$f(x)=x^a, x\in R^+, a\ge 1或a\le0 $
#
# 负对数函数：$f(x)=-ln(x)$
#
# 负熵函数：$f(x)=xln(x)$
#
# 范数函数：$f(\vec x)=\parallel x\parallel$
#
# 最大值函数：$f(\vec x)=max(x_1, x_2, ..., x_n)$
#
# 指数线性函数：$f(\vec x)=log(e^{x_1}+e^{x_2}+...+e^{x_n})$
#
# 最大值函数：

# %%
import sys
sys.path.append('/Users/luoyonggui/PycharmProjects/mayiutils_n1/mayiutils/plot_img_processing')

# %%
from plot_img_ops import plot2D

# %%
import numpy as np

# %%
plot2D(lambda x: np.exp(x), [-1, 10])

# %%
plot2D(lambda x: np.exp(-x), [-1, 10])

# %%
plot2D(lambda x: x**10, [-10, 10])

# %%
plot2D(lambda x: x**(-1), [0, 1])
# Out:
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in reciprocal
#   """Entry point for launching an IPython kernel.

# %%
plot2D(lambda x: x**(0.5), [0, 1])

# %%
plot2D(lambda x: -np.log(x), [0, 1])
# Out:
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plot2D(lambda x: x*np.log(x), [0, 1])
# Out:
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## 仿射集
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ## 凸集
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
# 一般来说，仿射集的要求更高，仿射集必然是凸集，凸集未必是仿射集。

# %% [markdown]
# ## 分割超平面
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ## 支持超平面
# $设集合C，X_0为C边界上的点。若存在a\ne 0，满足对任意x\in C，都有a^Tx\le a^Tx_0成立，则称超平面\{x|a^T=a^Tx_0\}为集合C在点X_0出的支撑超平面。$
#
# 凸集边界上任意一点，均存在支撑超平面。反之，若一个闭的非中空（内部点不为空）集合，在边界上的任意一点存在支撑超平面，则该集合为凸集。
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### Jensen不等式
# Jensen不等式是几乎所有不等式的基础:

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
