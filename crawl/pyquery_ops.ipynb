# %%
t = {
  "value":[
    {
      "id":"f067e512-76fd-4c66-8b37-2a0315364266","type":"transcript","start":"PT0.09S","end":"PT3.393S","eventData":{
        "type":"caption","language":"en","text":"Alright, well we'll get started.\r\nGood morning, Good afternoon,"
      },"hidden":False,"userData":"null"
    },{
      "id":"01909472-59aa-443b-a78f-bff21138567e","type":"transcript","start":"PT3.393S","end":"PT7.797S","eventData":{
        "type":"caption","language":"en","text":" good evening, um everyone. Thank you for joining us on our STINT"
      },"hidden":False,"userData":"null"
    },{
      "id":"3b3d2309-8f61-4673-8898-c6669d451009","type":"transcript","start":"PT7.797S","end":"PT11.467S","eventData":{
        "type":"caption","language":"en","text":" global Town Hall. We will talk about our strategic intent "
      },"hidden":False,"userData":"null"
    },{
      "id":"13b9bb71-6ab3-4f45-be2b-65931e0c262b","type":"transcript","start":"PT11.467S","end":"PT15.504S","eventData":{
        "type":"caption","language":"en","text":" process today and what that means for Sensata. This is the "
      },"hidden":False,"userData":"null"
    },{
      "id":"880a6faf-3710-40eb-a1d0-6933f0a5dde2","type":"transcript","start":"PT15.504S","end":"PT20.275S","eventData":{
        "type":"caption","language":"en","text":"second year in a row that we're\r\ndoing this. So we started last"
      },"hidden":False,"userData":"null"
    },{
      "id":"351e874e-1a7e-490b-9737-b570abcb56e6","type":"transcript","start":"PT20.275S","end":"PT22.844S","eventData":{
        "type":"caption","language":"en","text":" year broadcasting from Attleboro, and obviously because "
      },"hidden":False,"userData":"null"
    },{
      "id":"e248bfd9-6ca4-4b0d-90bf-31eefc48ee50","type":"transcript","start":"PT22.844S","end":"PT26.514S","eventData":{
        "type":"caption","language":"en","text":"of the pandemic, we've had to\r\naccelerate our abilities to"
      },"hidden":False,"userData":"null"
    },{
      "id":"6d8f1822-a7ff-43e2-b0ad-a5eabddf0df7","type":"transcript","start":"PT26.514S","end":"PT29.45S","eventData":{
        "type":"caption","language":"en","text":"communicate globally and it's\r\nreally been really well"
      },"hidden":False,"userData":"null"
    },{
      "id":"a8db42fc-410e-4b80-a58d-87204319605d","type":"transcript","start":"PT29.45S","end":"PT31.285S","eventData":{
        "type":"caption","language":"en","text":"received. So thank you everyone."
      },"hidden":False,"userData":"null"
    },{
      "id":"2a388a26-7f61-411b-ab45-992ed291fe67","type":"transcript","start":"PT31.98S","end":"PT33.078S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"53acdb54-aa84-4f46-84ec-a97d9331adc6","type":"transcript","start":"PT34.74S","end":"PT38.772S","eventData":{
        "type":"caption","language":"en","text":"For those of you that don't\r\nknow me, my name is Alexia"
      },"hidden":False,"userData":"null"
    },{
      "id":"dee99349-0b3c-4762-86b2-8396217a17d5","type":"transcript","start":"PT38.772S","end":"PT41.796S","eventData":{
        "type":"caption","language":"en","text":"Taxiarchos. I head of our communications team, what we"
      },"hidden":False,"userData":"null"
    },{
      "id":"e11e9346-aa4d-470d-bc95-e806e2e87c20","type":"transcript","start":"PT41.796S","end":"PT45.156S","eventData":{
        "type":"caption","language":"en","text":"will be sharing with you\r\ntoday is considered to start"
      },"hidden":False,"userData":"null"
    },{
      "id":"cc22f3d1-9394-404f-b2b5-ef9b4b293efb","type":"transcript","start":"PT45.156S","end":"PT47.508S","eventData":{
        "type":"caption","language":"en","text":"a technology strictly\r\nprivate. Obviously, as our"
      },"hidden":False,"userData":"null"
    },{
      "id":"2850804b-5c27-437d-83c1-77d20b34712b","type":"transcript","start":"PT47.508S","end":"PT50.868S","eventData":{
        "type":"caption","language":"en","text":"employees we show information\r\nwith you that we might not"
      },"hidden":False,"userData":"null"
    },{
      "id":"45ff26d8-1638-4dc5-bf23-a20b79a3a698","type":"transcript","start":"PT50.868S","end":"PT54.564S","eventData":{
        "type":"caption","language":"en","text":"share with broader audiences,\r\nso we really ask for you to"
      },"hidden":False,"userData":"null"
    },{
      "id":"fd336ca0-bce4-4da9-8111-1f01c88383b1","type":"transcript","start":"PT54.564S","end":"PT56.916S","eventData":{
        "type":"caption","language":"en","text":"respect that trust and\r\nunderstand that information"
      },"hidden":False,"userData":"null"
    },{
      "id":"1fb9de3c-e198-4799-a8dd-ade957c0a2d1","type":"transcript","start":"PT56.916S","end":"PT59.94S","eventData":{
        "type":"caption","language":"en","text":"that you will be hearing\r\ntoday, whether it's about"
      },"hidden":False,"userData":"null"
    },{
      "id":"61f21829-36d3-4bfe-befd-aab25a7264cc","type":"transcript","start":"PT59.94S","end":"PT1M2.292S","eventData":{
        "type":"caption","language":"en","text":"revenue or market potential\r\nis proprietary, insensitive"
      },"hidden":False,"userData":"null"
    },{
      "id":"bc9b7959-bbf5-489e-b7fc-82af04d9f4fc","type":"transcript","start":"PT1M2.292S","end":"PT1M3.636S","eventData":{
        "type":"caption","language":"en","text":" to Sensata -\u00a0 next slide. "
      },"hidden":False,"userData":"null"
    },{
      "id":"8c95ddd4-c60e-4637-86be-7e941b5d5871","type":"transcript","start":"PT1M5.09S","end":"PT1M9.566S","eventData":{
        "type":"caption","language":"en","text":"We have about 90 minutes set\r\naside for you today and you'll"
      },"hidden":False,"userData":"null"
    },{
      "id":"35beb910-9465-4fcc-b3bd-ba49f3a6d082","type":"transcript","start":"PT1M9.566S","end":"PT1M13.669S","eventData":{
        "type":"caption","language":"en","text":" hear from a number of speakers across Sensata. I'm Hans Lidforss"
      },"hidden":False,"userData":"null"
    },{
      "id":"6963a739-b8ca-49ee-9c43-21ef2a443f30","type":"transcript","start":"PT1M13.669S","end":"PT1M17.026S","eventData":{
        "type":"caption","language":"en","text":"Our SVP\u00a0 Chief Strategy and Corporate Development Officer"
      },"hidden":False,"userData":"null"
    },{
      "id":"36fff161-10fa-4d88-8ceb-fefa8164306f","type":"transcript","start":"PT1M17.026S","end":"PT1M21.875S","eventData":{
        "type":"caption","language":"en","text":" will give you an overview of what STINT is, how we arrive at "
      },"hidden":False,"userData":"null"
    },{
      "id":"641e5836-5de4-47ad-8739-6c364466e8e5","type":"transcript","start":"PT1M21.875S","end":"PT1M26.351S","eventData":{
        "type":"caption","language":"en","text":" it, and end of you on corporate STINT. Vineet Nargolwala,"
      },"hidden":False,"userData":"null"
    },{
      "id":"e676bd27-07b3-4205-bb40-2dcd034d586d","type":"transcript","start":"PT1M26.351S","end":"PT1M29.335S","eventData":{
        "type":"caption","language":"en","text":"our EVP of Sensing Solutions business. That's our industrial"
      },"hidden":False,"userData":"null"
    },{
      "id":"8a940838-7204-4a64-87c0-2eb8dfaf6037","type":"transcript","start":"PT1M29.335S","end":"PT1M33.811S","eventData":{
        "type":"caption","language":"en","text":" aerospace in HVOR\u00a0 businesses will give you an overview of the "
      },"hidden":False,"userData":"null"
    },{
      "id":"85dcb463-159d-4c81-a01e-bb1c68c9f149","type":"transcript","start":"PT1M33.811S","end":"PT1M34.93S","eventData":{
        "type":"caption","language":"en","text":"incensing solutions business."
      },"hidden":False,"userData":"null"
    },{
      "id":"1be7dd8f-7329-47a3-ad4b-ebd18cf5e2a9","type":"transcript","start":"PT1M34.99S","end":"PT1M38.248S","eventData":{
        "type":"caption","language":"en","text":" Markets Paul Chawla, our EVP or performance sensing and"
      },"hidden":False,"userData":"null"
    },{
      "id":"b3347076-1b53-4561-97c5-ce29c28e1510","type":"transcript","start":"PT1M38.248S","end":"PT1M41.868S","eventData":{
        "type":"caption","language":"en","text":"automotive will give you a view\r\ninto our automotive markets"
      },"hidden":False,"userData":"null"
    },{
      "id":"086a01a1-7b04-4bcd-ab02-cb88c97dd8ed","type":"transcript","start":"PT1M41.868S","end":"PT1M45.126S","eventData":{
        "type":"caption","language":"en","text":" globally and then George Verras, our SVP of Sensata Ventures"
      },"hidden":False,"userData":"null"
    },{
      "id":"d6b933d5-e6b7-40d8-82d8-3ade0feca554","type":"transcript","start":"PT1M45.126S","end":"PT1M49.47S","eventData":{
        "type":"caption","language":"en","text":" will give you a view into some of the really interesting initiatives"
      },"hidden":False,"userData":"null"
    },{
      "id":"c4bf75c8-13f8-45cd-b298-25a4ae891843","type":"transcript","start":"PT1M49.47S","end":"PT1M53.09S","eventData":{
        "type":"caption","language":"en","text":"that we have in Sensata Ventures and how they work"
      },"hidden":False,"userData":"null"
    },{
      "id":"227e64dc-87fd-465a-aaed-80a46a5a544f","type":"transcript","start":"PT1M53.09S","end":"PT1M56.71S","eventData":{
        "type":"caption","language":"en","text":"across the company to drive\r\ngrowth. Next slide please. We"
      },"hidden":False,"userData":"null"
    },{
      "id":"2eab6e8d-b411-4fd2-933e-47685ce81327","type":"transcript","start":"PT1M56.71S","end":"PT2M0.692S","eventData":{
        "type":"caption","language":"en","text":"will be doing Q&A today on\r\nMicrosoft teams live event and"
      },"hidden":False,"userData":"null"
    },{
      "id":"80447a85-9c10-47e5-b46e-3968ef946c60","type":"transcript","start":"PT2M0.692S","end":"PT2M5.036S","eventData":{
        "type":"caption","language":"en","text":"one of the things that I should\r\nhave mentioned at the outset."
      },"hidden":False,"userData":"null"
    },{
      "id":"f8aac0f6-cede-4e37-8390-d4b4d1030b02","type":"transcript","start":"PT2M5.09S","end":"PT2M8.115S","eventData":{
        "type":"caption","language":"en","text":"Is that Microsoft Teams live\r\nevent is a little bit different"
      },"hidden":False,"userData":"null"
    },{
      "id":"302f8169-3b59-4d6f-ae58-46407bbc91f8","type":"transcript","start":"PT2M8.115S","end":"PT2M11.69S","eventData":{
        "type":"caption","language":"en","text":"than just a regular teams event,\r\nso you may be looking for your"
      },"hidden":False,"userData":"null"
    },{
      "id":"7f850faf-875a-428e-ac54-8f44881dc3d3","type":"transcript","start":"PT2M11.69S","end":"PT2M14.44S","eventData":{
        "type":"caption","language":"en","text":"mute button because we've all\r\nbeen during those meetings in"
      },"hidden":False,"userData":"null"
    },{
      "id":"b325570b-6b39-4fa8-a8ad-db34912bae5d","type":"transcript","start":"PT2M14.44S","end":"PT2M18.015S","eventData":{
        "type":"caption","language":"en","text":"the past few months where we've\r\nhad to mute our buttons or we"
      },"hidden":False,"userData":"null"
    },{
      "id":"d5e84106-ea41-4404-9214-a2061fecd6a5","type":"transcript","start":"PT2M18.015S","end":"PT2M21.59S","eventData":{
        "type":"caption","language":"en","text":"want to say something at a live\r\nevent is a little bit different"
      },"hidden":False,"userData":"null"
    },{
      "id":"fad0f1e9-073b-42b5-900a-979a58ad48ea","type":"transcript","start":"PT2M21.59S","end":"PT2M23.79S","eventData":{
        "type":"caption","language":"en","text":"that you're automatically muted\r\nunless your presenter. Otherwise"
      },"hidden":False,"userData":"null"
    },{
      "id":"2cf5ce4b-b4ea-4268-8103-b645128ff554","type":"transcript","start":"PT2M23.79S","end":"PT2M27.365S","eventData":{
        "type":"caption","language":"en","text":"we have thousands of people on\r\nthis call, and it would just be"
      },"hidden":False,"userData":"null"
    },{
      "id":"9950e794-75b3-4f6d-ae4b-82a15fa8355e","type":"transcript","start":"PT2M27.365S","end":"PT2M30.94S","eventData":{
        "type":"caption","language":"en","text":"really unproductive, so this is\r\nthe way that you know we want to"
      },"hidden":False,"userData":"null"
    },{
      "id":"20355ca4-25ee-476b-9185-13a03aff331d","type":"transcript","start":"PT2M30.94S","end":"PT2M35.065S","eventData":{
        "type":"caption","language":"en","text":"hear from you. So please do use\r\na Q and a feature. It's on your"
      },"hidden":False,"userData":"null"
    },{
      "id":"13f9b605-d28f-4b81-988f-0c5436b2e681","type":"transcript","start":"PT2M35.065S","end":"PT2M39.372S","eventData":{
        "type":"caption","language":"en","text":"teams. Or if you click on your\r\nbutt on the hover over it,"
      },"hidden":False,"userData":"null"
    },{
      "id":"49ae8465-3987-4985-b461-28af5b464850","type":"transcript","start":"PT2M39.372S","end":"PT2M43.013S","eventData":{
        "type":"caption","language":"en","text":"there's a little you know,\r\ndialogue box with a question and"
      },"hidden":False,"userData":"null"
    },{
      "id":"4ac55d33-b10a-464e-8026-956c69cf6a6e","type":"transcript","start":"PT2M43.013S","end":"PT2M47.316S","eventData":{
        "type":"caption","language":"en","text":"that's how you can come get your\r\nquestions in. We would ask that"
      },"hidden":False,"userData":"null"
    },{
      "id":"ba8e989c-b8f0-44a0-b3d0-94708a3e3c95","type":"transcript","start":"PT2M47.316S","end":"PT2M50.626S","eventData":{
        "type":"caption","language":"en","text":"you you know really paid\r\nattention to everything that the"
      },"hidden":False,"userData":"null"
    },{
      "id":"f900fa64-e6fa-430c-bfd2-6ba0b5fd5311","type":"transcript","start":"PT2M50.626S","end":"PT2M54.267S","eventData":{
        "type":"caption","language":"en","text":"presenters have collected today\r\nto present to you. There's a lot"
      },"hidden":False,"userData":"null"
    },{
      "id":"ad541b69-b5e1-47b5-8bc3-26840b84f636","type":"transcript","start":"PT2M54.267S","end":"PT2M56.915S","eventData":{
        "type":"caption","language":"en","text":"of information we've distilled\r\nthis into. What's most"
      },"hidden":False,"userData":"null"
    },{
      "id":"166028ed-67e8-4458-8a89-fe488b37fb86","type":"transcript","start":"PT2M56.915S","end":"PT3M0.556S","eventData":{
        "type":"caption","language":"en","text":"important, but obviously as you\r\nknow so many, so many people"
      },"hidden":False,"userData":"null"
    },{
      "id":"4d2f5066-127c-4f35-ae41-9f187e721187","type":"transcript","start":"PT3M0.556S","end":"PT3M4.859S","eventData":{
        "type":"caption","language":"en","text":"across this out of work on this\r\ntent material and we really are"
      },"hidden":False,"userData":"null"
    },{
      "id":"242e25ce-5761-4d5e-a25f-314513b3d3d7","type":"transcript","start":"PT3M4.859S","end":"PT3M7.722S","eventData":{
        "type":"caption","language":"en","text":"appreciative so. Take the time,\r\nlisten really know, get"
      },"hidden":False,"userData":"null"
    },{
      "id":"e938c999-3869-4732-89ed-33947053d226","type":"transcript","start":"PT3M7.722S","end":"PT3M11.034S","eventData":{
        "type":"caption","language":"en","text":"involved. Ask the questions that\r\nyou want and we will take. Take"
      },"hidden":False,"userData":"null"
    },{
      "id":"f68bf22d-4d66-4d0a-aa3b-ecac9255f79b","type":"transcript","start":"PT3M11.034S","end":"PT3M12.414S","eventData":{
        "type":"caption","language":"en","text":"your questions at the end."
      },"hidden":False,"userData":"null"
    },{
      "id":"aa3e3f95-9f1d-4d34-995f-bffc242ea026","type":"transcript","start":"PT3M13.02S","end":"PT3M13.998S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"41c97063-af66-4e23-8a1b-7073f39118f1","type":"transcript","start":"PT3M15.77S","end":"PT3M21.1S","eventData":{
        "type":"caption","language":"en","text":"Alright, so with that I'm after\r\nstage and I'd like to hand it"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4d642f2-eb39-4b61-8293-5f6cbf1e1dbd","type":"transcript","start":"PT3M21.1S","end":"PT3M26.02S","eventData":{
        "type":"caption","language":"en","text":"over to hands to take over Hans.\r\nAlright so thank you, uh"
      },"hidden":False,"userData":"null"
    },{
      "id":"2ebc9296-f279-41d6-a517-98441d835ef7","type":"transcript","start":"PT3M26.02S","end":"PT3M30.12S","eventData":{
        "type":"caption","language":"en","text":"everybody for calling in Um, I\r\nwill next page please."
      },"hidden":False,"userData":"null"
    },{
      "id":"b134fe87-103c-45e7-a222-4c9929af5688","type":"transcript","start":"PT3M32.2S","end":"PT3M36.088S","eventData":{
        "type":"caption","language":"en","text":"I will first go through a few\r\nprocess changes that we have"
      },"hidden":False,"userData":"null"
    },{
      "id":"62125163-0b39-4bcb-ab73-4745e940144b","type":"transcript","start":"PT3M36.088S","end":"PT3M39.328S","eventData":{
        "type":"caption","language":"en","text":"implemented this year to make\r\nthe stent process more efficient"
      },"hidden":False,"userData":"null"
    },{
      "id":"ac2dbedf-57a3-4b0f-8836-156b6ed4c3eb","type":"transcript","start":"PT3M39.328S","end":"PT3M44.264S","eventData":{
        "type":"caption","language":"en","text":"and effective. Uh, so first\r\nchanges that we have more"
      },"hidden":False,"userData":"null"
    },{
      "id":"b2f63799-eb21-4269-ba9e-ff2ddc1ce63c","type":"transcript","start":"PT3M44.264S","end":"PT3M48.394S","eventData":{
        "type":"caption","language":"en","text":"clearly addressed the three\r\nlevels of strategy this year, so"
      },"hidden":False,"userData":"null"
    },{
      "id":"b701d651-462d-4834-a727-21626fd6d9b9","type":"transcript","start":"PT3M48.394S","end":"PT3M51.285S","eventData":{
        "type":"caption","language":"en","text":"corporate strategy, business\r\nunit strategy, and functional"
      },"hidden":False,"userData":"null"
    },{
      "id":"e22e647a-3380-4356-9e88-a2780443ea57","type":"transcript","start":"PT3M51.285S","end":"PT3M55.564S","eventData":{
        "type":"caption","language":"en","text":"strategy. Uh, the corporate\r\nstrategy should really outline"
      },"hidden":False,"userData":"null"
    },{
      "id":"b9a98d3c-7de1-440d-a478-5984060aa21b","type":"transcript","start":"PT3M55.564S","end":"PT3M59.452S","eventData":{
        "type":"caption","language":"en","text":"the overall vision of the\r\ncompany. The overall strategic"
      },"hidden":False,"userData":"null"
    },{
      "id":"20b45800-0ca4-47c2-907d-8d20285d2734","type":"transcript","start":"PT3M59.452S","end":"PT4M3.34S","eventData":{
        "type":"caption","language":"en","text":"direction where we should select\r\nto compete an resource"
      },"hidden":False,"userData":"null"
    },{
      "id":"675dd779-9039-4d38-a006-cdb5122b1bad","type":"transcript","start":"PT4M3.34S","end":"PT4M7.86S","eventData":{
        "type":"caption","language":"en","text":"allocation. Business unit\r\nstrategy then, should a follow"
      },"hidden":False,"userData":"null"
    },{
      "id":"23fc217d-426d-4044-a338-ffb3a952b4a7","type":"transcript","start":"PT4M7.86S","end":"PT4M12.26S","eventData":{
        "type":"caption","language":"en","text":"on to those directions an\r\noutline how to maximize revenue"
      },"hidden":False,"userData":"null"
    },{
      "id":"f4dc5658-78b8-4ce7-b5e8-7ade9a3a61d5","type":"transcript","start":"PT4M12.26S","end":"PT4M16.66S","eventData":{
        "type":"caption","language":"en","text":"and profit within the selected\r\nmarket segments. Outline of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"8bc7b99a-30f8-4dca-bd71-354a120c881c","type":"transcript","start":"PT4M16.66S","end":"PT4M21.796S","eventData":{
        "type":"caption","language":"en","text":"corporate strategy. Um, since\r\nI'd adventure is really a subset"
      },"hidden":False,"userData":"null"
    },{
      "id":"bd93f896-dd4c-44be-9902-a478d63f86d8","type":"transcript","start":"PT4M21.796S","end":"PT4M26.86S","eventData":{
        "type":"caption","language":"en","text":"of the be your business strategy\r\nand they are, as you probably"
      },"hidden":False,"userData":"null"
    },{
      "id":"7ef4ec83-6aad-4d30-9728-f63635924260","type":"transcript","start":"PT4M26.86S","end":"PT4M30.236S","eventData":{
        "type":"caption","language":"en","text":"know, specifically tasked to\r\nexplore new business opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"1c2b609c-7201-4604-9ea5-23363b080813","type":"transcript","start":"PT4M30.236S","end":"PT4M31.502S","eventData":{
        "type":"caption","language":"en","text":"within the Megatrends."
      },"hidden":False,"userData":"null"
    },{
      "id":"9df5df8d-28db-4b7d-87fb-a52343c3bca7","type":"transcript","start":"PT4M32.98S","end":"PT4M36.132S","eventData":{
        "type":"caption","language":"en","text":"Functional strategies, then\r\nuhm, should outline plans to"
      },"hidden":False,"userData":"null"
    },{
      "id":"f7298fc7-73c7-4b77-a83c-ab34695843ec","type":"transcript","start":"PT4M36.132S","end":"PT4M40.466S","eventData":{
        "type":"caption","language":"en","text":"support the BU strategies in\r\nthe most effective way, so we"
      },"hidden":False,"userData":"null"
    },{
      "id":"8e108c93-db60-45b4-ba22-eeac2bcbdc2c","type":"transcript","start":"PT4M40.466S","end":"PT4M44.012S","eventData":{
        "type":"caption","language":"en","text":"have really tried to layout\r\nsort of more distinctive"
      },"hidden":False,"userData":"null"
    },{
      "id":"4ca1b79e-e209-41b7-9bcb-1937b4480515","type":"transcript","start":"PT4M44.012S","end":"PT4M46.77S","eventData":{
        "type":"caption","language":"en","text":"corporate strategy, business\r\nunit strategy and functional"
      },"hidden":False,"userData":"null"
    },{
      "id":"6477efc0-9c71-483b-b1fa-24e48ce19a6e","type":"transcript","start":"PT4M46.77S","end":"PT4M48.74S","eventData":{
        "type":"caption","language":"en","text":"strategy in this year's stink."
      },"hidden":False,"userData":"null"
    },{
      "id":"5c5bf698-00c7-4480-9eb1-717c5d0877ad","type":"transcript","start":"PT4M51.15S","end":"PT4M52.308S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"8c398bf5-1915-4db4-8ff0-a85c9c84b689","type":"transcript","start":"PT4M53.96S","end":"PT4M58.074S","eventData":{
        "type":"caption","language":"en","text":"The second change we have\r\nimplemented this year is we have"
      },"hidden":False,"userData":"null"
    },{
      "id":"1f9ffb09-f3e8-41e7-82b5-ac63de8a7f0a","type":"transcript","start":"PT4M58.074S","end":"PT5M1.814S","eventData":{
        "type":"caption","language":"en","text":"divided distinta process into\r\ntwo parts to further focus on"
      },"hidden":False,"userData":"null"
    },{
      "id":"e484e986-b346-4a94-b752-9a46b86b0687","type":"transcript","start":"PT5M1.814S","end":"PT5M3.31S","eventData":{
        "type":"caption","language":"en","text":"and develop our growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"aeacef47-ee36-4fca-9f08-d5c15baebfaa","type":"transcript","start":"PT5M3.31S","end":"PT5M9.01S","eventData":{
        "type":"caption","language":"en","text":"opportunities. So that part one\r\nthat we have just gone through"
      },"hidden":False,"userData":"null"
    },{
      "id":"4060e9ff-56f4-4ede-b243-b5fa7a0be17a","type":"transcript","start":"PT5M9.01S","end":"PT5M12.642S","eventData":{
        "type":"caption","language":"en","text":"focuses on really identifying\r\nmarket opportunity and growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"84fc05bf-280e-4eb9-bb3a-2df6e3f3e2d6","type":"transcript","start":"PT5M12.642S","end":"PT5M18.472S","eventData":{
        "type":"caption","language":"en","text":"initiatives. Part 2 that we will\r\nkick off in a fall. Focus on um,"
      },"hidden":False,"userData":"null"
    },{
      "id":"025e66a6-8dc5-4e7d-b05b-22d07801d793","type":"transcript","start":"PT5M18.472S","end":"PT5M21.384S","eventData":{
        "type":"caption","language":"en","text":"the current business\r\nentitlements. An hour long range"
      },"hidden":False,"userData":"null"
    },{
      "id":"cd328d00-530a-4752-b92e-348d3700bc27","type":"transcript","start":"PT5M21.384S","end":"PT5M25.752S","eventData":{
        "type":"caption","language":"en","text":"plan and you will hear more\r\nabout those further in the fall."
      },"hidden":False,"userData":"null"
    },{
      "id":"47a9c856-6833-4fe1-8a10-af6a58b5ec0c","type":"transcript","start":"PT5M27.08S","end":"PT5M30.93S","eventData":{
        "type":"caption","language":"en","text":"Near for this year is also\r\ntighter focus between the long"
      },"hidden":False,"userData":"null"
    },{
      "id":"be0a070d-f955-4c26-9249-f1048f8ba94f","type":"transcript","start":"PT5M30.93S","end":"PT5M34.08S","eventData":{
        "type":"caption","language":"en","text":"range planning, an annual plan\r\nwhich previously was quite"
      },"hidden":False,"userData":"null"
    },{
      "id":"d5b05677-4904-4533-9eb4-4db37cce520c","type":"transcript","start":"PT5M34.08S","end":"PT5M37.23S","eventData":{
        "type":"caption","language":"en","text":"separate processes, so you will\r\nsee a tighter coordination"
      },"hidden":False,"userData":"null"
    },{
      "id":"9c733be3-6967-48e9-883d-3c5f3b4feac9","type":"transcript","start":"PT5M37.23S","end":"PT5M38.98S","eventData":{
        "type":"caption","language":"en","text":"between the two this year."
      },"hidden":False,"userData":"null"
    },{
      "id":"1883b0b5-693c-4cf8-a516-94d512ff8a6f","type":"transcript","start":"PT5M40.25S","end":"PT5M44.498S","eventData":{
        "type":"caption","language":"en","text":"And ask me for once we have\r\napproved stints, uh, we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"16c30573-d458-4a73-93ca-b09871d08599","type":"transcript","start":"PT5M44.498S","end":"PT5M47.33S","eventData":{
        "type":"caption","language":"en","text":"develop strategies for cards\r\nwhich tracks how we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"b65e89c9-a092-4f40-9625-4c9b6aa9a1cc","type":"transcript","start":"PT5M47.33S","end":"PT5M50.516S","eventData":{
        "type":"caption","language":"en","text":"delivering on this train\r\nstrategies. And we will monitor"
      },"hidden":False,"userData":"null"
    },{
      "id":"256b4e46-90c1-4f0d-a76d-a868ae6ce0d0","type":"transcript","start":"PT5M50.516S","end":"PT5M55.218S","eventData":{
        "type":"caption","language":"en","text":"those quarterly. Uh, if one of\r\nthe strategic scorecard metric"
      },"hidden":False,"userData":"null"
    },{
      "id":"a3fa18f4-0354-42cb-aa7e-ab2fcac93d72","type":"transcript","start":"PT5M55.218S","end":"PT5M58.928S","eventData":{
        "type":"caption","language":"en","text":"shows that we are off\r\nstrategy, we will review those"
      },"hidden":False,"userData":"null"
    },{
      "id":"c34e4833-cbbf-4792-bf4d-c1723d5f5cbd","type":"transcript","start":"PT5M58.928S","end":"PT6M2.267S","eventData":{
        "type":"caption","language":"en","text":"topics in the so-called\r\nmeanest things as needed. But"
      },"hidden":False,"userData":"null"
    },{
      "id":"6816c5e7-6223-4795-be9d-4bd2c3f80f66","type":"transcript","start":"PT6M2.267S","end":"PT6M5.977S","eventData":{
        "type":"caption","language":"en","text":"typically we review those mean\r\ninstant it once per quarter."
      },"hidden":False,"userData":"null"
    },{
      "id":"642441b9-cf81-40ee-afa2-e3b3f8d5664d","type":"transcript","start":"PT6M8.04S","end":"PT6M9.258S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"e927ccf7-e600-497d-ac6e-2e96b1e32759","type":"transcript","start":"PT6M11.7S","end":"PT6M15.649S","eventData":{
        "type":"caption","language":"en","text":"Turning now to our vision and\r\nstrategy. Uhm, we continue to"
      },"hidden":False,"userData":"null"
    },{
      "id":"c2497214-407b-43fa-8fea-7dd2d723dd98","type":"transcript","start":"PT6M15.649S","end":"PT6M19.239S","eventData":{
        "type":"caption","language":"en","text":"believe that our vision and\r\npurpose are both compelling and"
      },"hidden":False,"userData":"null"
    },{
      "id":"b5597aae-aa52-4ab0-9df5-79246ac64118","type":"transcript","start":"PT6M19.239S","end":"PT6M21.034S","eventData":{
        "type":"caption","language":"en","text":"give good guidance towards our"
      },"hidden":False,"userData":"null"
    },{
      "id":"9dbae2cb-019d-41c8-97b8-9263d98e5f50","type":"transcript","start":"PT6M21.034S","end":"PT6M24.7S","eventData":{
        "type":"caption","language":"en","text":"future direction. Our vision and\r\npurpose, therefore remain"
      },"hidden":False,"userData":"null"
    },{
      "id":"6711eb22-6d3b-4c44-92b5-2ec64a65b18f","type":"transcript","start":"PT6M24.7S","end":"PT6M26.98S","eventData":{
        "type":"caption","language":"en","text":"larger. The same with two minor"
      },"hidden":False,"userData":"null"
    },{
      "id":"a403e81e-8f81-4f25-bee9-3f485d4a085a","type":"transcript","start":"PT6M26.98S","end":"PT6M31.43S","eventData":{
        "type":"caption","language":"en","text":"tweaks. Hey, in our revision\r\nwe have added the words an"
      },"hidden":False,"userData":"null"
    },{
      "id":"73c11982-f520-485b-85b8-c0df0ea42c1c","type":"transcript","start":"PT6M31.43S","end":"PT6M35.486S","eventData":{
        "type":"caption","language":"en","text":"insights in the end. As you\r\ncan see, just signal that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"bb3b434d-e062-4e8c-833c-2b813fc9d421","type":"transcript","start":"PT6M35.486S","end":"PT6M39.204S","eventData":{
        "type":"caption","language":"en","text":"are not only going to be a\r\nworld leader, an early"
      },"hidden":False,"userData":"null"
    },{
      "id":"585e7520-c669-4596-8af4-5f62beee1eeb","type":"transcript","start":"PT6M39.204S","end":"PT6M41.908S","eventData":{
        "type":"caption","language":"en","text":"innovator or mission critical\r\nsensory solutions but also"
      },"hidden":False,"userData":"null"
    },{
      "id":"8a656a4d-3a8b-4d2c-86dd-3541e6c21210","type":"transcript","start":"PT6M41.908S","end":"PT6M44.274S","eventData":{
        "type":"caption","language":"en","text":"leader in providing our\r\ncustomer valuable insights"
      },"hidden":False,"userData":"null"
    },{
      "id":"8747cd6c-bc3c-4045-9b86-ad799e8425f7","type":"transcript","start":"PT6M44.274S","end":"PT6M45.288S","eventData":{
        "type":"caption","language":"en","text":"from those solutions."
      },"hidden":False,"userData":"null"
    },{
      "id":"20858c2d-ca2e-4b39-b336-ff1aa5cfcf8e","type":"transcript","start":"PT6M46.73S","end":"PT6M51.794S","eventData":{
        "type":"caption","language":"en","text":"We have also added the words\r\nan partners to our purpose to"
      },"hidden":False,"userData":"null"
    },{
      "id":"d33bae80-8fe7-4fda-8e95-784b19044bed","type":"transcript","start":"PT6M51.794S","end":"PT6M56.436S","eventData":{
        "type":"caption","language":"en","text":"signal that we should not only\r\nhelp our customers deliver a"
      },"hidden":False,"userData":"null"
    },{
      "id":"27607d74-129d-48f2-b021-9aae901029ac","type":"transcript","start":"PT6M56.436S","end":"PT6M58.968S","eventData":{
        "type":"caption","language":"en","text":"cleaner, more efficient,\r\nelectrified and connected"
      },"hidden":False,"userData":"null"
    },{
      "id":"623c79cc-033b-4715-8d6d-1f2520df9707","type":"transcript","start":"PT6M58.968S","end":"PT7M3.188S","eventData":{
        "type":"caption","language":"en","text":"world, but we should also\r\nextend those to our partners"
      },"hidden":False,"userData":"null"
    },{
      "id":"1eb7a181-88f8-4305-8d7d-0c1a50853d33","type":"transcript","start":"PT7M3.188S","end":"PT7M6.564S","eventData":{
        "type":"caption","language":"en","text":"which will be most will be\r\nincreasingly important."
      },"hidden":False,"userData":"null"
    },{
      "id":"90be124d-0966-4b86-bc39-411feb39c021","type":"transcript","start":"PT7M8.05S","end":"PT7M9.13S","eventData":{
        "type":"caption","language":"en","text":"Next Page P."
      },"hidden":False,"userData":"null"
    },{
      "id":"299cf8f4-fbb4-4183-bfdd-82bffa923106","type":"transcript","start":"PT7M11.47S","end":"PT7M15.573S","eventData":{
        "type":"caption","language":"en","text":"As any good strategy development\r\nprocess, it starts with a good"
      },"hidden":False,"userData":"null"
    },{
      "id":"f7fd2970-e675-4240-83f7-85b9de472b73","type":"transcript","start":"PT7M15.573S","end":"PT7M18.93S","eventData":{
        "type":"caption","language":"en","text":"understanding of the markets,\r\nour competitors in the customers"
      },"hidden":False,"userData":"null"
    },{
      "id":"c912dfbf-3eef-488a-b2d8-a922938fbfc2","type":"transcript","start":"PT7M18.93S","end":"PT7M24.178S","eventData":{
        "type":"caption","language":"en","text":"we serve. And ask you now, um,\r\nthere has been a lot of changes"
      },"hidden":False,"userData":"null"
    },{
      "id":"780d3933-5545-4990-8d6e-3edd5f78c021","type":"transcript","start":"PT7M24.178S","end":"PT7M26.959S","eventData":{
        "type":"caption","language":"en","text":"in our markets lately, and\r\nchange continues. An even"
      },"hidden":False,"userData":"null"
    },{
      "id":"800ea25a-3850-4a84-9ac5-166dc8beff77","type":"transcript","start":"PT7M26.959S","end":"PT7M28.813S","eventData":{
        "type":"caption","language":"en","text":"accelerates in some parts of our"
      },"hidden":False,"userData":"null"
    },{
      "id":"57f0bfe6-4e73-499b-9fa6-01ff09483429","type":"transcript","start":"PT7M28.813S","end":"PT7M32.56S","eventData":{
        "type":"caption","language":"en","text":"business. A few of those changes\r\nare outlined on this slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"f7394887-1a20-455c-b76e-6fc3ecd0be1b","type":"transcript","start":"PT7M34.03S","end":"PT7M37.285S","eventData":{
        "type":"caption","language":"en","text":"Value is shifting from\r\nmechanical components in"
      },"hidden":False,"userData":"null"
    },{
      "id":"b812edae-f4bb-43b4-9add-e7d3f947ad1b","type":"transcript","start":"PT7M37.285S","end":"PT7M38.68S","eventData":{
        "type":"caption","language":"en","text":"intelligent systems and"
      },"hidden":False,"userData":"null"
    },{
      "id":"73c1f0c1-d857-435c-aff7-14ee5273b841","type":"transcript","start":"PT7M38.68S","end":"PT7M42.126S","eventData":{
        "type":"caption","language":"en","text":"software. Disruptors are\r\ntaking advantage of those"
      },"hidden":False,"userData":"null"
    },{
      "id":"8eafc135-522d-4208-a17b-566237c19a16","type":"transcript","start":"PT7M42.126S","end":"PT7M45.555S","eventData":{
        "type":"caption","language":"en","text":"changes and driving many of\r\nthese trends. Tesla being"
      },"hidden":False,"userData":"null"
    },{
      "id":"c2c8ef51-934a-4884-8f66-a97a45ea1c7b","type":"transcript","start":"PT7M45.555S","end":"PT7M47.46S","eventData":{
        "type":"caption","language":"en","text":"yes. One good example loaded."
      },"hidden":False,"userData":"null"
    },{
      "id":"d2baec98-eb69-4063-a955-e7ba69447b87","type":"transcript","start":"PT7M48.77S","end":"PT7M52.955S","eventData":{
        "type":"caption","language":"en","text":"They changed is also more\r\nsignificant and happening faster"
      },"hidden":False,"userData":"null"
    },{
      "id":"8962ad5f-69a5-4968-b002-77a45bc0c9ed","type":"transcript","start":"PT7M52.955S","end":"PT7M54.35S","eventData":{
        "type":"caption","language":"en","text":"than ever before."
      },"hidden":False,"userData":"null"
    },{
      "id":"8bf4056e-adb0-4c58-a48c-7ef058df19d0","type":"transcript","start":"PT7M57.92S","end":"PT8M0.965S","eventData":{
        "type":"caption","language":"en","text":"Uh, which creates both\r\nopportunities and threats."
      },"hidden":False,"userData":"null"
    },{
      "id":"6a72f052-94c8-4898-9ab4-62498074d321","type":"transcript","start":"PT8M1.58S","end":"PT8M4.31S","eventData":{
        "type":"caption","language":"en","text":"I tend to view those changes\r\nas opportunities, but we"
      },"hidden":False,"userData":"null"
    },{
      "id":"c606000e-0d61-4c44-8d5f-acf5f6817d2f","type":"transcript","start":"PT8M4.31S","end":"PT8M7.586S","eventData":{
        "type":"caption","language":"en","text":"should recognize that some of\r\nthem also can be threats if we"
      },"hidden":False,"userData":"null"
    },{
      "id":"748dbf58-a925-46b8-8fd8-76e469982b90","type":"transcript","start":"PT8M7.586S","end":"PT8M8.678S","eventData":{
        "type":"caption","language":"en","text":"don't address them properly."
      },"hidden":False,"userData":"null"
    },{
      "id":"89cb8eda-cda7-412d-aff0-e116f633cfb4","type":"transcript","start":"PT8M10.52S","end":"PT8M14.42S","eventData":{
        "type":"caption","language":"en","text":"One example of what we need to\r\ndo differently is to leverage"
      },"hidden":False,"userData":"null"
    },{
      "id":"3302ec0d-60d3-4e30-8131-15101ba353ae","type":"transcript","start":"PT8M14.42S","end":"PT8M17.345S","eventData":{
        "type":"caption","language":"en","text":"different forms of partnerships\r\nbetter, since going alone is"
      },"hidden":False,"userData":"null"
    },{
      "id":"5bb6df75-7c72-4860-a388-46bd987e11de","type":"transcript","start":"PT8M17.345S","end":"PT8M20.92S","eventData":{
        "type":"caption","language":"en","text":"often too slow and may not need\r\nthe new customer needs."
      },"hidden":False,"userData":"null"
    },{
      "id":"f6c78f5f-ba57-46dd-84dd-fff992b29db8","type":"transcript","start":"PT8M22.09S","end":"PT8M25.28S","eventData":{
        "type":"caption","language":"en","text":"Another example of changes that\r\nare impacting our business or"
      },"hidden":False,"userData":"null"
    },{
      "id":"39ac2dbc-6834-45f7-a612-dee37227300d","type":"transcript","start":"PT8M25.28S","end":"PT8M28.151S","eventData":{
        "type":"caption","language":"en","text":"macro factors like trade\r\ndisputes with China. We will"
      },"hidden":False,"userData":"null"
    },{
      "id":"6a339d4d-4379-498d-8d66-85078095512c","type":"transcript","start":"PT8M28.151S","end":"PT8M31.66S","eventData":{
        "type":"caption","language":"en","text":"need to adapt our business to\r\nthose changes and for example,"
      },"hidden":False,"userData":"null"
    },{
      "id":"9be10369-9188-4417-9d88-5a2d56fc7841","type":"transcript","start":"PT8M31.66S","end":"PT8M35.807S","eventData":{
        "type":"caption","language":"en","text":"we may have to alter the way we\r\nplay and win in China."
      },"hidden":False,"userData":"null"
    },{
      "id":"2bd55c11-6a8b-40b9-b61b-b0d0bc56cf9f","type":"transcript","start":"PT8M37.71S","end":"PT8M40.77S","eventData":{
        "type":"caption","language":"en","text":"We have, of course taken all\r\nthose changes into consideration"
      },"hidden":False,"userData":"null"
    },{
      "id":"5b6bfb22-527e-4fd3-8870-4c8b533c2d2e","type":"transcript","start":"PT8M40.77S","end":"PT8M44.442S","eventData":{
        "type":"caption","language":"en","text":"when we have developed our new\r\nstrategy, in which I will go"
      },"hidden":False,"userData":"null"
    },{
      "id":"978814d4-9210-45c4-9e36-b7cabd58f0f9","type":"transcript","start":"PT8M44.442S","end":"PT8M47.47S","eventData":{
        "type":"caption","language":"en","text":"through here shortly. Next\r\npage, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"a184f976-4508-490f-bd43-37dacfc4dbe2","type":"transcript","start":"PT8M50.17S","end":"PT8M54.768S","eventData":{
        "type":"caption","language":"en","text":"COVID-19 has of course had a\r\nmaterial impact on our business,"
      },"hidden":False,"userData":"null"
    },{
      "id":"e893c9da-ada2-42e1-94ba-7b9a53547644","type":"transcript","start":"PT8M54.768S","end":"PT8M57.694S","eventData":{
        "type":"caption","language":"en","text":"and in short in the short term."
      },"hidden":False,"userData":"null"
    },{
      "id":"e78b199a-64d5-4a74-a497-3ad67b77b93d","type":"transcript","start":"PT8M59.38S","end":"PT9M3.241S","eventData":{
        "type":"caption","language":"en","text":"We know it hasn't been easy for\r\nall of you to navigate these"
      },"hidden":False,"userData":"null"
    },{
      "id":"d8e25ebb-405e-41fe-b14b-18c6585aeacf","type":"transcript","start":"PT9M3.241S","end":"PT9M5.914S","eventData":{
        "type":"caption","language":"en","text":"last few months and we\r\nappreciate all the sacrifices"
      },"hidden":False,"userData":"null"
    },{
      "id":"92e117c6-71d9-49b2-b362-482c0a713ac4","type":"transcript","start":"PT9M5.914S","end":"PT9M8.884S","eventData":{
        "type":"caption","language":"en","text":"that you have made, including\r\ntemporary pay cuts in photos."
      },"hidden":False,"userData":"null"
    },{
      "id":"de928f63-d277-4f9c-a327-b9a1eac3a6c0","type":"transcript","start":"PT9M9.98S","end":"PT9M14.068S","eventData":{
        "type":"caption","language":"en","text":"The good part is that we do see\r\na recovery, but it will likely"
      },"hidden":False,"userData":"null"
    },{
      "id":"4fc318f9-fa5c-416a-bafa-558ff77f3bf8","type":"transcript","start":"PT9M14.068S","end":"PT9M17.864S","eventData":{
        "type":"caption","language":"en","text":"take a year or two before we get\r\nback to pre COVID-19 levels."
      },"hidden":False,"userData":"null"
    },{
      "id":"2ab04d78-ef5c-44ab-92b9-b75a3fdfe86a","type":"transcript","start":"PT9M19.73S","end":"PT9M22.446S","eventData":{
        "type":"caption","language":"en","text":"Other consequences of\r\nCOVID-19 are likely an"
      },"hidden":False,"userData":"null"
    },{
      "id":"51f47dfe-af89-49c9-b125-f38050b1ba07","type":"transcript","start":"PT9M22.446S","end":"PT9M24.774S","eventData":{
        "type":"caption","language":"en","text":"increase regionalization,\r\nand it possible exploration"
      },"hidden":False,"userData":"null"
    },{
      "id":"0cf2d52e-896c-4772-9254-12bffb605a1a","type":"transcript","start":"PT9M24.774S","end":"PT9M27.49S","eventData":{
        "type":"caption","language":"en","text":"of the megatrends\r\nopportunities. So we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"0cb13209-1fd5-47f6-861d-94a9e80be1cc","type":"transcript","start":"PT9M27.49S","end":"PT9M31.37S","eventData":{
        "type":"caption","language":"en","text":"have to monitor and address\r\nthose going forward if and"
      },"hidden":False,"userData":"null"
    },{
      "id":"b4f047e7-d67e-4e5e-bc10-b0abb141797f","type":"transcript","start":"PT9M31.37S","end":"PT9M32.534S","eventData":{
        "type":"caption","language":"en","text":"when they happen."
      },"hidden":False,"userData":"null"
    },{
      "id":"17d997c7-3d9c-4a6a-8637-3d1ea0fc6cce","type":"transcript","start":"PT9M33.77S","end":"PT9M34.88S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"6675bd2b-ebd7-472f-9b8a-0dff5933397a","type":"transcript","start":"PT9M36.5S","end":"PT9M39.767S","eventData":{
        "type":"caption","language":"en","text":"Before we look ahead, I\r\nwould like to spend a few"
      },"hidden":False,"userData":"null"
    },{
      "id":"1a2d6d8d-034b-420f-88e7-83f134bc9ab2","type":"transcript","start":"PT9M39.767S","end":"PT9M42.737S","eventData":{
        "type":"caption","language":"en","text":"minutes to look back and\r\nprovide some context for our"
      },"hidden":False,"userData":"null"
    },{
      "id":"c1674f61-6bcd-4307-bfb9-5beee4df035f","type":"transcript","start":"PT9M42.737S","end":"PT9M43.331S","eventData":{
        "type":"caption","language":"en","text":"revised strategy."
      },"hidden":False,"userData":"null"
    },{
      "id":"e330d9c7-5766-46d5-b0f2-b0be7bc4a6d7","type":"transcript","start":"PT9M44.45S","end":"PT9M49.01S","eventData":{
        "type":"caption","language":"en","text":"Over the last 10 years we have\r\ndelivered on average good top"
      },"hidden":False,"userData":"null"
    },{
      "id":"6f76cf43-d66a-43f4-84d7-7091318328ea","type":"transcript","start":"PT9M49.01S","end":"PT9M53.19S","eventData":{
        "type":"caption","language":"en","text":"line and bottom line group. We\r\nhave launched St Ventures and"
      },"hidden":False,"userData":"null"
    },{
      "id":"38c50751-2aca-4967-8ff7-77f514b78803","type":"transcript","start":"PT9M53.19S","end":"PT9M56.99S","eventData":{
        "type":"caption","language":"en","text":"started to make good progress on\r\nelectrification and Smart and"
      },"hidden":False,"userData":"null"
    },{
      "id":"f173fc1d-8fbd-4955-a1c1-f1695af17539","type":"transcript","start":"PT9M56.99S","end":"PT10M0.03S","eventData":{
        "type":"caption","language":"en","text":"connected and some progress\r\nlately on autonomy especially."
      },"hidden":False,"userData":"null"
    },{
      "id":"aadf70cc-660a-4ba2-bda5-5f0542d9883a","type":"transcript","start":"PT10M0.11S","end":"PT10M2.3S","eventData":{
        "type":"caption","language":"en","text":"Play with the acquisition\r\nof people."
      },"hidden":False,"userData":"null"
    },{
      "id":"69652719-5be3-455a-9c38-e7ac6bca6803","type":"transcript","start":"PT10M4.07S","end":"PT10M7.55S","eventData":{
        "type":"caption","language":"en","text":"We have been and continue to be\r\nresource constraint, not"
      },"hidden":False,"userData":"null"
    },{
      "id":"34b62bb5-f00a-4c82-b70c-dacb67ebca0d","type":"transcript","start":"PT10M7.55S","end":"PT10M10.682S","eventData":{
        "type":"caption","language":"en","text":"opportunity constrained, and\r\nthat's a very good situation to"
      },"hidden":False,"userData":"null"
    },{
      "id":"e265b717-5a94-4ffe-a704-f3db561b74cd","type":"transcript","start":"PT10M10.682S","end":"PT10M13.248S","eventData":{
        "type":"caption","language":"en","text":"be in. Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"c24a41bf-b75e-4fd3-978d-a68dccadc5c3","type":"transcript","start":"PT10M15.48S","end":"PT10M18.472S","eventData":{
        "type":"caption","language":"en","text":"Having said that, on one\r\nimportant metric, total"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a93a816-9d05-4191-bd30-add9b528ae5e","type":"transcript","start":"PT10M18.472S","end":"PT10M22.212S","eventData":{
        "type":"caption","language":"en","text":"shareholder return or TSR, we\r\nhave lagged our competitors over"
      },"hidden":False,"userData":"null"
    },{
      "id":"53be7cf5-37d6-45d6-a9ba-1aa9a1ed8efd","type":"transcript","start":"PT10M22.212S","end":"PT10M26.326S","eventData":{
        "type":"caption","language":"en","text":"last five years. As you can see\r\nin the top shot."
      },"hidden":False,"userData":"null"
    },{
      "id":"ec059712-b766-459e-ab5e-e13efaff338c","type":"transcript","start":"PT10M27.54S","end":"PT10M32.644S","eventData":{
        "type":"caption","language":"en","text":"We have a work **** **\r\nidentifying why we have lag."
      },"hidden":False,"userData":"null"
    },{
      "id":"a0b94b6c-1f89-4c8c-b697-513081dff316","type":"transcript","start":"PT10M34.01S","end":"PT10M37.772S","eventData":{
        "type":"caption","language":"en","text":"Versus competitors and we have\r\nfound that there are three main"
      },"hidden":False,"userData":"null"
    },{
      "id":"94331db9-1cd7-4cf3-b4c5-e5f7048caa15","type":"transcript","start":"PT10M37.772S","end":"PT10M39.482S","eventData":{
        "type":"caption","language":"en","text":"reasons for our lagging TSR."
      },"hidden":False,"userData":"null"
    },{
      "id":"d102fbeb-5c44-4d6f-be47-b9fb27ebf656","type":"transcript","start":"PT10M40.21S","end":"PT10M44.59S","eventData":{
        "type":"caption","language":"en","text":"The most important reason is\r\nthat our growth and you can see"
      },"hidden":False,"userData":"null"
    },{
      "id":"10ccb701-a6cb-4f6b-b02d-da15fa069791","type":"transcript","start":"PT10M44.59S","end":"PT10M48.97S","eventData":{
        "type":"caption","language":"en","text":"that in the lower left hand\r\ncorner of this, short has been"
      },"hidden":False,"userData":"null"
    },{
      "id":"4744b464-11f0-4ca6-9705-7da49caee196","type":"transcript","start":"PT10M48.97S","end":"PT10M52.62S","eventData":{
        "type":"caption","language":"en","text":"lumpy. Uh, both organic and\r\ninorganic growth has been lumpy"
      },"hidden":False,"userData":"null"
    },{
      "id":"85c20c4e-2a0a-4720-832e-e27d535c33a1","type":"transcript","start":"PT10M52.62S","end":"PT10M57.365S","eventData":{
        "type":"caption","language":"en","text":"and on average we have delivered\r\nonly 3% top line growth over the"
      },"hidden":False,"userData":"null"
    },{
      "id":"794ef553-8320-473d-9662-84dcecbee240","type":"transcript","start":"PT10M57.365S","end":"PT10M59.19S","eventData":{
        "type":"caption","language":"en","text":"last five to six years."
      },"hidden":False,"userData":"null"
    },{
      "id":"716e0af3-95fb-4f2f-be17-7e1d8485c546","type":"transcript","start":"PT11M0.33S","end":"PT11M4.807S","eventData":{
        "type":"caption","language":"en","text":"The second reason is that\r\nalthough we have worked **** **"
      },"hidden":False,"userData":"null"
    },{
      "id":"b81cdbeb-ee5d-4969-bb3d-714a6bfaab4c","type":"transcript","start":"PT11M4.807S","end":"PT11M8.063S","eventData":{
        "type":"caption","language":"en","text":"developing the megatrend\r\nopportunities, they have not yet"
      },"hidden":False,"userData":"null"
    },{
      "id":"cffc535d-f036-487d-9701-c0353c554304","type":"transcript","start":"PT11M8.063S","end":"PT11M10.912S","eventData":{
        "type":"caption","language":"en","text":"delivered meaningful\r\ncontribution to our growth. We"
      },"hidden":False,"userData":"null"
    },{
      "id":"a15858fc-df5f-45ef-a418-570bb53e9f79","type":"transcript","start":"PT11M10.912S","end":"PT11M16.61S","eventData":{
        "type":"caption","language":"en","text":"hope we hope they will, but so\r\nfar we are investing a lot of"
      },"hidden":False,"userData":"null"
    },{
      "id":"901026b7-5351-4411-8d68-ce6f4fbf61ac","type":"transcript","start":"PT11M16.61S","end":"PT11M21.494S","eventData":{
        "type":"caption","language":"en","text":"money in these opportunities and\r\nyet they have still to deliver a"
      },"hidden":False,"userData":"null"
    },{
      "id":"988dc90d-f451-48f9-be49-340de3bb3338","type":"transcript","start":"PT11M21.494S","end":"PT11M24.343S","eventData":{
        "type":"caption","language":"en","text":"meaningful contribution to our\r\ngrowth going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"c78a7cc0-b0ad-48ce-ae59-6b93efe0eec6","type":"transcript","start":"PT11M26.7S","end":"PT11M31.744S","eventData":{
        "type":"caption","language":"en","text":"And 30 uh, there is also some\r\ndrag as we have discussed in"
      },"hidden":False,"userData":"null"
    },{
      "id":"08bb9e34-4371-427e-9446-ba684edeb4e2","type":"transcript","start":"PT11M31.744S","end":"PT11M34.848S","eventData":{
        "type":"caption","language":"en","text":"the past, for our order\r\nexposure, given the"
      },"hidden":False,"userData":"null"
    },{
      "id":"55fd1bda-c667-4cdb-b5c5-8f94a9ae813c","type":"transcript","start":"PT11M34.848S","end":"PT11M36.788S","eventData":{
        "type":"caption","language":"en","text":"cyclicality of that business\r\nsegment."
      },"hidden":False,"userData":"null"
    },{
      "id":"f4e16197-2d47-4e21-9757-e99de45a0161","type":"transcript","start":"PT11M38.97S","end":"PT11M43.15S","eventData":{
        "type":"caption","language":"en","text":"So when you Add all the Bob\r\ntogether, we have recognized"
      },"hidden":False,"userData":"null"
    },{
      "id":"967ce57d-e944-4e04-9bc5-b00472ea7571","type":"transcript","start":"PT11M43.15S","end":"PT11M46.19S","eventData":{
        "type":"caption","language":"en","text":"an address. Uh, these and\r\nother factors. Whenever"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a3ee519-6c2e-49b3-b2df-dddcef986635","type":"transcript","start":"PT11M46.19S","end":"PT11M49.99S","eventData":{
        "type":"caption","language":"en","text":"develop our new strategy and\r\nthe main tweaked or strategy"
      },"hidden":False,"userData":"null"
    },{
      "id":"bdc925fe-411e-4607-8eef-cf375975c48f","type":"transcript","start":"PT11M49.99S","end":"PT11M53.41S","eventData":{
        "type":"caption","language":"en","text":"largely come down to two\r\nwords, accelerate and focus,"
      },"hidden":False,"userData":"null"
    },{
      "id":"b2b0c13f-5f55-43db-9fd6-7b6670270f12","type":"transcript","start":"PT11M53.41S","end":"PT11M57.97S","eventData":{
        "type":"caption","language":"en","text":"which I will now cover on the\r\nnext page. Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"6cc36588-0bff-48ce-8b9b-45cdf66edd8d","type":"transcript","start":"PT11M59.78S","end":"PT12M4.279S","eventData":{
        "type":"caption","language":"en","text":"Sorry, new strategy builds on\r\nthe previous concept of five and"
      },"hidden":False,"userData":"null"
    },{
      "id":"e524cefd-fa34-4ae5-9b34-223c23901546","type":"transcript","start":"PT12M4.279S","end":"PT12M8.778S","eventData":{
        "type":"caption","language":"en","text":"five, which I hope you're all\r\nfamiliar with, but adds the"
      },"hidden":False,"userData":"null"
    },{
      "id":"c670a05e-a3fe-4f26-b7c7-4aea5a3b88bd","type":"transcript","start":"PT12M8.778S","end":"PT12M12.05S","eventData":{
        "type":"caption","language":"en","text":"concepts of accelerating focus,\r\nwhich is particularly important"
      },"hidden":False,"userData":"null"
    },{
      "id":"1d07ef3b-f0c6-439d-aef2-8740942980b8","type":"transcript","start":"PT12M12.05S","end":"PT12M15.322S","eventData":{
        "type":"caption","language":"en","text":"since again, we're resource\r\nconstraints and not opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"9a3d5339-4d0a-48b5-9fcc-9700411f75e3","type":"transcript","start":"PT12M15.322S","end":"PT12M19.917S","eventData":{
        "type":"caption","language":"en","text":"constrained. So let me go\r\nthrough a on a high level what"
      },"hidden":False,"userData":"null"
    },{
      "id":"594ca34e-4d85-4014-b416-87496d068950","type":"transcript","start":"PT12M19.917S","end":"PT12M23.342S","eventData":{
        "type":"caption","language":"en","text":"these concepts mean. And my\r\ncolleagues will expand on"
      },"hidden":False,"userData":"null"
    },{
      "id":"b5de4a0d-b5cb-40b1-be51-4ae58c1e5d1e","type":"transcript","start":"PT12M23.342S","end":"PT12M25.421S","eventData":{
        "type":"caption","language":"en","text":"these concepts to other in\r\ntheir sections."
      },"hidden":False,"userData":"null"
    },{
      "id":"9b5cea6b-8e11-4309-9bc4-e7944d201ab1","type":"transcript","start":"PT12M27.35S","end":"PT12M31.355S","eventData":{
        "type":"caption","language":"en","text":"To capture to better capture the\r\ngrowth opportunities going"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a911f35-fd99-406c-9c7c-b6f3ad9e6e44","type":"transcript","start":"PT12M31.355S","end":"PT12M36.25S","eventData":{
        "type":"caption","language":"en","text":"forward, we will, uh, need to\r\nidentify a high growth and"
      },"hidden":False,"userData":"null"
    },{
      "id":"13ff5b40-39d6-4e5a-9f70-dabe45d00b47","type":"transcript","start":"PT12M36.25S","end":"PT12M39.81S","eventData":{
        "type":"caption","language":"en","text":"markets and opportunities and\r\nExcelerate the investment in"
      },"hidden":False,"userData":"null"
    },{
      "id":"da1b7419-d087-4e7f-bfe7-b628678e4efe","type":"transcript","start":"PT12M39.81S","end":"PT12M43.37S","eventData":{
        "type":"caption","language":"en","text":"those and markets where we can\r\ndeliver differentiated"
      },"hidden":False,"userData":"null"
    },{
      "id":"256cca4c-5e38-44a4-a865-ff38c667bcaf","type":"transcript","start":"PT12M43.37S","end":"PT12M47.82S","eventData":{
        "type":"caption","language":"en","text":"marketing. So that's really the\r\naccelerate portion of that week"
      },"hidden":False,"userData":"null"
    },{
      "id":"254dfc9e-284e-4263-a3c7-90936c77b18d","type":"transcript","start":"PT12M47.82S","end":"PT12M49.155S","eventData":{
        "type":"caption","language":"en","text":"to this strategy."
      },"hidden":False,"userData":"null"
    },{
      "id":"9f6e145b-3a60-4197-a89a-ac41f197d248","type":"transcript","start":"PT12M50.13S","end":"PT12M53.379S","eventData":{
        "type":"caption","language":"en","text":"Uh, the other side on this\r\npage, actively managed"
      },"hidden":False,"userData":"null"
    },{
      "id":"07da957b-690e-4bc2-93c5-532af3f67ca8","type":"transcript","start":"PT12M53.379S","end":"PT12M56.267S","eventData":{
        "type":"caption","language":"en","text":"business portfolio is the\r\nbasically the consequences of"
      },"hidden":False,"userData":"null"
    },{
      "id":"a8e83f39-34fd-46f3-bfeb-4a78ad9e849e","type":"transcript","start":"PT12M56.267S","end":"PT13M0.599S","eventData":{
        "type":"caption","language":"en","text":"the acceleration and that is\r\nthat we have to focus in more"
      },"hidden":False,"userData":"null"
    },{
      "id":"891d9c9b-e61f-490f-a78a-df5fc0335c8a","type":"transcript","start":"PT13M0.599S","end":"PT13M4.57S","eventData":{
        "type":"caption","language":"en","text":"actively managed or respond in\r\nsome areas of the portfolio so"
      },"hidden":False,"userData":"null"
    },{
      "id":"20b2e84d-10a6-413f-9249-2c428f006a5c","type":"transcript","start":"PT13M4.57S","end":"PT13M8.18S","eventData":{
        "type":"caption","language":"en","text":"we can free up capital to\r\ninvest in those most"
      },"hidden":False,"userData":"null"
    },{
      "id":"f9c263b6-2fa3-4608-acb0-706ff2da610c","type":"transcript","start":"PT13M8.18S","end":"PT13M11.79S","eventData":{
        "type":"caption","language":"en","text":"attractive opportunities we\r\nhave in front of us. Again, we"
      },"hidden":False,"userData":"null"
    },{
      "id":"c1392bf6-5b36-433b-a32a-bef9e9fd0fd8","type":"transcript","start":"PT13M11.79S","end":"PT13M14.317S","eventData":{
        "type":"caption","language":"en","text":"are resource constraints and\r\nnot opportunity posting."
      },"hidden":False,"userData":"null"
    },{
      "id":"21c2f189-e005-4418-b7f4-0b2df7402214","type":"transcript","start":"PT13M16.23S","end":"PT13M19.541S","eventData":{
        "type":"caption","language":"en","text":"This is gonna, uh, this is\r\nhard to make those these"
      },"hidden":False,"userData":"null"
    },{
      "id":"433312d3-40f8-4375-b9d2-df241b7765cd","type":"transcript","start":"PT13M19.541S","end":"PT13M23.153S","eventData":{
        "type":"caption","language":"en","text":"choices, and frankly we are\r\nnot very good at it because we"
      },"hidden":False,"userData":"null"
    },{
      "id":"33a4994e-3e83-4022-b928-8f195deb6ef8","type":"transcript","start":"PT13M23.153S","end":"PT13M27.066S","eventData":{
        "type":"caption","language":"en","text":"all see the opportunities in\r\nfront of us and we want to do"
      },"hidden":False,"userData":"null"
    },{
      "id":"95a0606a-9af6-4b48-b8f2-16ecab3e3f49","type":"transcript","start":"PT13M27.066S","end":"PT13M30.076S","eventData":{
        "type":"caption","language":"en","text":"them all but often. The\r\nconsequences of that is that"
      },"hidden":False,"userData":"null"
    },{
      "id":"0da10690-6f41-47cc-aad7-160ccfd676f3","type":"transcript","start":"PT13M30.076S","end":"PT13M33.688S","eventData":{
        "type":"caption","language":"en","text":"we don't have enough money or\r\nresources to spend on the most"
      },"hidden":False,"userData":"null"
    },{
      "id":"efb417a1-592c-40b9-90fe-aa305b9bac6e","type":"transcript","start":"PT13M33.688S","end":"PT13M36.698S","eventData":{
        "type":"caption","language":"en","text":"attractive opportunities in\r\nfront of this and that sort of"
      },"hidden":False,"userData":"null"
    },{
      "id":"6f772951-7ff3-4e3f-bb66-62c80dfea4d4","type":"transcript","start":"PT13M36.698S","end":"PT13M40.009S","eventData":{
        "type":"caption","language":"en","text":"the change that we are trying\r\nto implement in this year's"
      },"hidden":False,"userData":"null"
    },{
      "id":"51f29010-76c0-4d5b-a3ff-cfb7d9ad5000","type":"transcript","start":"PT13M40.009S","end":"PT13M40.31S","eventData":{
        "type":"caption","language":"en","text":"team."
      },"hidden":False,"userData":"null"
    },{
      "id":"95b07e27-d42a-443e-a6cd-350735c7a7e5","type":"transcript","start":"PT13M42.03S","end":"PT13M46.198S","eventData":{
        "type":"caption","language":"en","text":"Please note that all\r\nareas of our business"
      },"hidden":False,"userData":"null"
    },{
      "id":"026c7ad0-5f77-493c-87c6-c1805aefcb5c","type":"transcript","start":"PT13M46.198S","end":"PT13M47.761S","eventData":{
        "type":"caption","language":"en","text":"are equally important."
      },"hidden":False,"userData":"null"
    },{
      "id":"839d0531-10f9-4351-938d-b7425e999a9e","type":"transcript","start":"PT13M49S","end":"PT13M53.1S","eventData":{
        "type":"caption","language":"en","text":"It's just that different parts\r\nof our business have a"
      },"hidden":False,"userData":"null"
    },{
      "id":"d22c426d-11a0-42bf-a848-e5922903c218","type":"transcript","start":"PT13M53.1S","end":"PT13M56.38S","eventData":{
        "type":"caption","language":"en","text":"different role in our\r\nportfolio. Some will generate"
      },"hidden":False,"userData":"null"
    },{
      "id":"a5e37728-a9c6-482a-8ab7-d503559a0e6a","type":"transcript","start":"PT13M56.38S","end":"PT14M0.07S","eventData":{
        "type":"caption","language":"en","text":"cash, another will consume\r\ncash while we're growing at"
      },"hidden":False,"userData":"null"
    },{
      "id":"2452a2c8-915b-481c-8ffc-afb71134eb57","type":"transcript","start":"PT14M0.07S","end":"PT14M1.71S","eventData":{
        "type":"caption","language":"en","text":"these most attractive\r\nopportunities."
      },"hidden":False,"userData":"null"
    },{
      "id":"1bbff715-1d1c-41b3-835b-0c70ae82586e","type":"transcript","start":"PT14M3.23S","end":"PT14M4.358S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"5128b996-3c1a-4eef-b318-232da33d898c","type":"transcript","start":"PT14M6.73S","end":"PT14M10.481S","eventData":{
        "type":"caption","language":"en","text":"So when it comes to the\r\nexcelerate part of our strategy,"
      },"hidden":False,"userData":"null"
    },{
      "id":"601b416c-2a8f-47b2-b705-3b29175c534f","type":"transcript","start":"PT14M10.481S","end":"PT14M13.55S","eventData":{
        "type":"caption","language":"en","text":"the areas where we will\r\naccelerate and increase our"
      },"hidden":False,"userData":"null"
    },{
      "id":"af447ee4-a771-4d20-88ce-cd3652a61e05","type":"transcript","start":"PT14M13.55S","end":"PT14M15.596S","eventData":{
        "type":"caption","language":"en","text":"investment in is largely in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"932b6d3f-143a-40b0-a794-e641756334b5","type":"transcript","start":"PT14M15.596S","end":"PT14M19.62S","eventData":{
        "type":"caption","language":"en","text":"Megatron areas. Uh, especially\r\naround electrification, smarting"
      },"hidden":False,"userData":"null"
    },{
      "id":"61a71a49-b0fc-4e8e-b6ba-bc116850d570","type":"transcript","start":"PT14M19.62S","end":"PT14M24.57S","eventData":{
        "type":"caption","language":"en","text":"connected, industrial iot, and\r\nto a lesser extent, autonomy."
      },"hidden":False,"userData":"null"
    },{
      "id":"7879e6da-7b91-4058-8d45-a75b5123a108","type":"transcript","start":"PT14M26.12S","end":"PT14M30.52S","eventData":{
        "type":"caption","language":"en","text":"We have made good and broad\r\nbased progress in an application"
      },"hidden":False,"userData":"null"
    },{
      "id":"702aa5af-860d-44eb-96f7-b3621bdd82db","type":"transcript","start":"PT14M30.52S","end":"PT14M34.12S","eventData":{
        "type":"caption","language":"en","text":"and will accelerate our\r\ninvestment further in this area."
      },"hidden":False,"userData":"null"
    },{
      "id":"756aaed2-4d45-4e7b-a0e9-0e61c8ce4e28","type":"transcript","start":"PT14M35.32S","end":"PT14M39.731S","eventData":{
        "type":"caption","language":"en","text":"More narrowly focused maybe, but\r\nwe have also made very good"
      },"hidden":False,"userData":"null"
    },{
      "id":"1a5b3459-8f1e-4acc-be82-2ad98f36e5b2","type":"transcript","start":"PT14M39.731S","end":"PT14M42.939S","eventData":{
        "type":"caption","language":"en","text":"progress in our smarting\r\nconnected initiative in HBO."
      },"hidden":False,"userData":"null"
    },{
      "id":"37032376-1fa5-4faf-bcff-b2903ffd15cb","type":"transcript","start":"PT14M43.68S","end":"PT14M47.28S","eventData":{
        "type":"caption","language":"en","text":"Uh, and we are now considering\r\nexpanding, uh, that initiative"
      },"hidden":False,"userData":"null"
    },{
      "id":"0d8c7f29-bdf1-4b30-827b-cf7e800f9b7a","type":"transcript","start":"PT14M47.28S","end":"PT14M49.08S","eventData":{
        "type":"caption","language":"en","text":"into like vehicles as well."
      },"hidden":False,"userData":"null"
    },{
      "id":"37bc4060-25ba-4e04-a9bd-c29abb080e0a","type":"transcript","start":"PT14M50.77S","end":"PT14M54.686S","eventData":{
        "type":"caption","language":"en","text":"Industrial iot is the newest\r\narea of focus, but we think"
      },"hidden":False,"userData":"null"
    },{
      "id":"cdef915b-0100-45cf-b775-369fa118d0dd","type":"transcript","start":"PT14M54.686S","end":"PT14M57.89S","eventData":{
        "type":"caption","language":"en","text":"there is a substantial\r\nopportunity in this area and"
      },"hidden":False,"userData":"null"
    },{
      "id":"20ef8f16-ba75-42fe-8393-34f2181ca2ba","type":"transcript","start":"PT14M57.89S","end":"PT15M0.382S","eventData":{
        "type":"caption","language":"en","text":"it will help with our\r\ndiversification strategy."
      },"hidden":False,"userData":"null"
    },{
      "id":"c941f317-9cce-47cd-8a86-84ef84146ce0","type":"transcript","start":"PT15M2.29S","end":"PT15M5.128S","eventData":{
        "type":"caption","language":"en","text":"We need will expand on our\r\nthoughts in this area later."
      },"hidden":False,"userData":"null"
    },{
      "id":"5a7d419a-f80f-4eaa-a6b1-437cdb77f006","type":"transcript","start":"PT15M7.76S","end":"PT15M11.888S","eventData":{
        "type":"caption","language":"en","text":"Autonomy is the area where we,\r\nuh, have made last progress over"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b5209c2-1e8b-4bab-b514-bd8da3e40329","type":"transcript","start":"PT15M11.888S","end":"PT15M16.36S","eventData":{
        "type":"caption","language":"en","text":"the last few years. But with the\r\nacquisition of Preco we now have"
      },"hidden":False,"userData":"null"
    },{
      "id":"7f0eeb4d-a818-4523-a68b-e40fb22cf30a","type":"transcript","start":"PT15M16.36S","end":"PT15M20.488S","eventData":{
        "type":"caption","language":"en","text":"a platform to build from an\r\ninitially in the Raider in radar"
      },"hidden":False,"userData":"null"
    },{
      "id":"ded08d84-c86b-4354-b74f-d66d1f77c6c0","type":"transcript","start":"PT15M20.488S","end":"PT15M21.52S","eventData":{
        "type":"caption","language":"en","text":"solution for HBO."
      },"hidden":False,"userData":"null"
    },{
      "id":"461e0f41-6d4a-4a13-b92d-984abd0bd789","type":"transcript","start":"PT15M23.15S","end":"PT15M24.149S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"4a7bb25a-b7b3-4828-aa9d-f8eb35f56f18","type":"transcript","start":"PT15M26.11S","end":"PT15M30.114S","eventData":{
        "type":"caption","language":"en","text":"As I mentioned earlier, we want\r\nto accelerate our investment in"
      },"hidden":False,"userData":"null"
    },{
      "id":"3f4c2fce-b50e-4239-b92b-572d037881c8","type":"transcript","start":"PT15M30.114S","end":"PT15M34.482S","eventData":{
        "type":"caption","language":"en","text":"high growth areas and therefore\r\nwe will have to scale back or"
      },"hidden":False,"userData":"null"
    },{
      "id":"a6f59898-adaa-4f2c-896c-05bd02bc73bf","type":"transcript","start":"PT15M34.482S","end":"PT15M37.758S","eventData":{
        "type":"caption","language":"en","text":"investment in other areas. We\r\nwill therefore more explicitly"
      },"hidden":False,"userData":"null"
    },{
      "id":"19ac4f98-9621-47e0-a70d-fc524bc740d6","type":"transcript","start":"PT15M37.758S","end":"PT15M41.034S","eventData":{
        "type":"caption","language":"en","text":"manage our portfolio of assets\r\naccording to religion, vigil"
      },"hidden":False,"userData":"null"
    },{
      "id":"1b0dff82-b10c-4acc-9238-39d848876adf","type":"transcript","start":"PT15M41.034S","end":"PT15M42.49S","eventData":{
        "type":"caption","language":"en","text":"growth and margin potential."
      },"hidden":False,"userData":"null"
    },{
      "id":"643e0886-d94d-4d9f-80a4-c6221fb3492b","type":"transcript","start":"PT15M43.42S","end":"PT15M47.764S","eventData":{
        "type":"caption","language":"en","text":"One tool that we have used in\r\nthe past and will continue"
      },"hidden":False,"userData":"null"
    },{
      "id":"d639cb82-3e8c-4364-a258-f5b2c79cf60c","type":"transcript","start":"PT15M47.764S","end":"PT15M52.108S","eventData":{
        "type":"caption","language":"en","text":"useful in forward is this song\r\nto win framework, which as you"
      },"hidden":False,"userData":"null"
    },{
      "id":"92176afc-2381-4aad-a1d1-015c6874175e","type":"transcript","start":"PT15M52.108S","end":"PT15M55.728S","eventData":{
        "type":"caption","language":"en","text":"may know, how four areas in\r\nincubation stoneware you invest"
      },"hidden":False,"userData":"null"
    },{
      "id":"f1d7877a-4d99-454e-a946-2256080e2563","type":"transcript","start":"PT15M55.728S","end":"PT15M58.262S","eventData":{
        "type":"caption","language":"en","text":"in an incubator business\r\nopportunity. I transformation"
      },"hidden":False,"userData":"null"
    },{
      "id":"999fdc12-5a01-413c-bae8-24541c99a835","type":"transcript","start":"PT15M58.262S","end":"PT16M1.52S","eventData":{
        "type":"caption","language":"en","text":"sound where you invests more\r\nbehind the most attractive"
      },"hidden":False,"userData":"null"
    },{
      "id":"42654929-c877-4323-a16f-58a8a93c9066","type":"transcript","start":"PT16M1.52S","end":"PT16M2.968S","eventData":{
        "type":"caption","language":"en","text":"opportunities to grow them,"
      },"hidden":False,"userData":"null"
    },{
      "id":"6561a2b9-4fa3-4862-b40e-7b2d3bd004f7","type":"transcript","start":"PT16M2.968S","end":"PT16M5.882S","eventData":{
        "type":"caption","language":"en","text":"interviewed businesses.\r\nPerformance owned by the"
      },"hidden":False,"userData":"null"
    },{
      "id":"179c8246-7eb7-43b1-9b6d-df627f52f1c8","type":"transcript","start":"PT16M5.882S","end":"PT16M9.562S","eventData":{
        "type":"caption","language":"en","text":"majority of our business\r\nshould be and is where the"
      },"hidden":False,"userData":"null"
    },{
      "id":"9a7e6175-a384-43c9-8081-012319a3fcea","type":"transcript","start":"PT16M9.562S","end":"PT16M12.506S","eventData":{
        "type":"caption","language":"en","text":"business are generating both\r\ngood growth and good"
      },"hidden":False,"userData":"null"
    },{
      "id":"f173dd73-3460-4350-b59d-11e837166937","type":"transcript","start":"PT16M12.506S","end":"PT16M15.082S","eventData":{
        "type":"caption","language":"en","text":"profitability. And finally the\r\nproductivity sewn where"
      },"hidden":False,"userData":"null"
    },{
      "id":"e3f9b34a-dddd-463b-ab10-597b5c5453e6","type":"transcript","start":"PT16M15.082S","end":"PT16M18.026S","eventData":{
        "type":"caption","language":"en","text":"businesses are not generating\r\nsignificant growth. Maybe but"
      },"hidden":False,"userData":"null"
    },{
      "id":"ee24caef-58e7-40e4-95f2-b1b4b4d7dc21","type":"transcript","start":"PT16M18.026S","end":"PT16M22.074S","eventData":{
        "type":"caption","language":"en","text":"could be quite profitable in\r\nfeed new business ideas in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"dad59ff1-1fc4-4d2b-95d0-bde11109ca53","type":"transcript","start":"PT16M22.074S","end":"PT16M22.442S","eventData":{
        "type":"caption","language":"en","text":"incubator."
      },"hidden":False,"userData":"null"
    },{
      "id":"5637b97f-1a90-4254-ac5c-73745c44e7c9","type":"transcript","start":"PT16M23.66S","end":"PT16M26.88S","eventData":{
        "type":"caption","language":"en","text":"Luckily for us, many of our\r\nbusinesses are in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"19753fc3-6655-4504-9f32-6e2bb76953d7","type":"transcript","start":"PT16M26.88S","end":"PT16M30.1S","eventData":{
        "type":"caption","language":"en","text":"performance zone, but we do\r\nalso have a number of"
      },"hidden":False,"userData":"null"
    },{
      "id":"aa5c6307-0b47-4734-b574-2c8bea840225","type":"transcript","start":"PT16M30.1S","end":"PT16M32.676S","eventData":{
        "type":"caption","language":"en","text":"business segments in the\r\nproductivity sound which we"
      },"hidden":False,"userData":"null"
    },{
      "id":"2a51e9d2-4dd1-4f98-b88e-a5b799f936c9","type":"transcript","start":"PT16M32.676S","end":"PT16M33.964S","eventData":{
        "type":"caption","language":"en","text":"will manage going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"e0eff7eb-43f0-4c79-ac03-7f7bcba9778b","type":"transcript","start":"PT16M34.99S","end":"PT16M38.89S","eventData":{
        "type":"caption","language":"en","text":"As part of the accelerating\r\nfocus strategy, we will be"
      },"hidden":False,"userData":"null"
    },{
      "id":"80cfa35b-0960-45b9-bfab-31d87c43e9aa","type":"transcript","start":"PT16M38.89S","end":"PT16M42.01S","eventData":{
        "type":"caption","language":"en","text":"increasing our investment in\r\nhigh growth areas, which"
      },"hidden":False,"userData":"null"
    },{
      "id":"3873c123-67cd-4c77-be3a-bcd8fbbde2ca","type":"transcript","start":"PT16M42.01S","end":"PT16M45.91S","eventData":{
        "type":"caption","language":"en","text":"largely a will will be in the\r\nuh, incubation and"
      },"hidden":False,"userData":"null"
    },{
      "id":"a4c3bd58-dc71-4118-b3f2-a82de5651580","type":"transcript","start":"PT16M45.91S","end":"PT16M49.03S","eventData":{
        "type":"caption","language":"en","text":"transformation zone and that\r\nwill happen both inside"
      },"hidden":False,"userData":"null"
    },{
      "id":"26f98948-b244-4760-a11f-67d532260c50","type":"transcript","start":"PT16M49.03S","end":"PT16M51.37S","eventData":{
        "type":"caption","language":"en","text":"adventures and in the business\r\nunits."
      },"hidden":False,"userData":"null"
    },{
      "id":"d8563837-098e-4f11-894c-642309c0e123","type":"transcript","start":"PT16M53.28S","end":"PT16M56.558S","eventData":{
        "type":"caption","language":"en","text":"Again, I want to stress that all\r\nbusiness segments are equally"
      },"hidden":False,"userData":"null"
    },{
      "id":"4c6a683e-059c-421c-b7d7-ed6461d9b618","type":"transcript","start":"PT16M56.558S","end":"PT16M59.538S","eventData":{
        "type":"caption","language":"en","text":"important. They just form a\r\ndifferent role in the overall"
      },"hidden":False,"userData":"null"
    },{
      "id":"55495665-38e8-43c7-9234-07bc07519312","type":"transcript","start":"PT16M59.538S","end":"PT17M1.028S","eventData":{
        "type":"caption","language":"en","text":"since our business before you."
      },"hidden":False,"userData":"null"
    },{
      "id":"4fcd9274-1af3-496a-9633-0d9cf07bca3b","type":"transcript","start":"PT17M2.44S","end":"PT17M3.469S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"568c7323-3806-4c90-8dee-97bb1fc4e35d","type":"transcript","start":"PT17M6.33S","end":"PT17M10.081S","eventData":{
        "type":"caption","language":"en","text":"To support the strategy of five\r\nand five accelerator focus, we"
      },"hidden":False,"userData":"null"
    },{
      "id":"a0c2cd83-1dcc-451d-b3dc-7987e8182207","type":"transcript","start":"PT17M10.081S","end":"PT17M13.832S","eventData":{
        "type":"caption","language":"en","text":"have also identified key support\r\nareas that we will focus on."
      },"hidden":False,"userData":"null"
    },{
      "id":"ee25e97a-86d4-40e2-bc5b-ce3ac4662688","type":"transcript","start":"PT17M14.88S","end":"PT17M19.092S","eventData":{
        "type":"caption","language":"en","text":"The first one is A is a poor\r\ncustomers. We will of course"
      },"hidden":False,"userData":"null"
    },{
      "id":"8909ddd2-bdd8-400c-8e4b-1d05e30f0f33","type":"transcript","start":"PT17M19.092S","end":"PT17M22.332S","eventData":{
        "type":"caption","language":"en","text":"continue to serve our existing\r\ncustomers and we will continue"
      },"hidden":False,"userData":"null"
    },{
      "id":"aaa16e33-5d13-463a-974b-14ce0a282726","type":"transcript","start":"PT17M22.332S","end":"PT17M25.248S","eventData":{
        "type":"caption","language":"en","text":"to work on improving commercial\r\nexcellence, for example, through"
      },"hidden":False,"userData":"null"
    },{
      "id":"62723796-8b23-49ba-9842-bcc5156d2f3d","type":"transcript","start":"PT17M25.248S","end":"PT17M28.164S","eventData":{
        "type":"caption","language":"en","text":"the sales and marketing console\r\nthat we need leads."
      },"hidden":False,"userData":"null"
    },{
      "id":"49233514-5ab5-4b79-868f-c0b802d9ff17","type":"transcript","start":"PT17M28.89S","end":"PT17M32.597S","eventData":{
        "type":"caption","language":"en","text":"In addition, we will also have\r\nto develop new capabilities in"
      },"hidden":False,"userData":"null"
    },{
      "id":"76fed81b-ee67-4002-9675-b52ab9696222","type":"transcript","start":"PT17M32.597S","end":"PT17M35.293S","eventData":{
        "type":"caption","language":"en","text":"channels to market. For example,\r\ndevelopment system integration"
      },"hidden":False,"userData":"null"
    },{
      "id":"bdc9bc80-a1eb-4390-842b-21aa71bae9c5","type":"transcript","start":"PT17M35.293S","end":"PT17M38.326S","eventData":{
        "type":"caption","language":"en","text":"channel, since we will start to\r\nserve different customer"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a5a0457-4813-4625-b145-3f08b21f421a","type":"transcript","start":"PT17M38.326S","end":"PT17M40.685S","eventData":{
        "type":"caption","language":"en","text":"segments which will have\r\ndifferent customer needs."
      },"hidden":False,"userData":"null"
    },{
      "id":"76b2be48-f426-40d1-a5ff-4ad0b412a5b7","type":"transcript","start":"PT17M43S","end":"PT17M46.4S","eventData":{
        "type":"caption","language":"en","text":"When it comes to basically\r\noperating systems, we will of"
      },"hidden":False,"userData":"null"
    },{
      "id":"0fcc312a-55ac-4bbc-b571-d1ddf6eac43d","type":"transcript","start":"PT17M46.4S","end":"PT17M50.14S","eventData":{
        "type":"caption","language":"en","text":"course also have to adapt our\r\nour business operating system to"
      },"hidden":False,"userData":"null"
    },{
      "id":"b9f2a5e3-043b-4d83-9792-dc5812e166a6","type":"transcript","start":"PT17M50.14S","end":"PT17M53.54S","eventData":{
        "type":"caption","language":"en","text":"capture this new opportunities\r\nand we will have therefore how"
      },"hidden":False,"userData":"null"
    },{
      "id":"264f0244-562c-48d9-acbe-5d4b10820ab5","type":"transcript","start":"PT17M53.54S","end":"PT17M56.6S","eventData":{
        "type":"caption","language":"en","text":"to adapt how they operate and\r\npartners a company."
      },"hidden":False,"userData":"null"
    },{
      "id":"712ff437-f151-47a8-8b7e-6a4b634d7193","type":"transcript","start":"PT17M57.56S","end":"PT18M0.98S","eventData":{
        "type":"caption","language":"en","text":"This will take different forms\r\nin different parts or business."
      },"hidden":False,"userData":"null"
    },{
      "id":"a6dab8e1-7dc1-49ff-b9f9-2f1acb567dbc","type":"transcript","start":"PT18M0.98S","end":"PT18M4.742S","eventData":{
        "type":"caption","language":"en","text":"For example, in Automotive we\r\nwill likely start to develop new"
      },"hidden":False,"userData":"null"
    },{
      "id":"c74f1094-6ecd-4ffe-97b1-a7fda1de0c84","type":"transcript","start":"PT18M4.742S","end":"PT18M7.82S","eventData":{
        "type":"caption","language":"en","text":"partnerships and maybe even\r\njoint ventures to deliver our"
      },"hidden":False,"userData":"null"
    },{
      "id":"2ce1a186-ed17-485c-97c3-04e8e8708bbd","type":"transcript","start":"PT18M7.82S","end":"PT18M9.188S","eventData":{
        "type":"caption","language":"en","text":"expanded value proposition to"
      },"hidden":False,"userData":"null"
    },{
      "id":"644b8207-3895-4a30-8176-306d5801fcee","type":"transcript","start":"PT18M9.188S","end":"PT18M15.45S","eventData":{
        "type":"caption","language":"en","text":"our customers. We will also work\r\non on two large cross business"
      },"hidden":False,"userData":"null"
    },{
      "id":"a309567f-5397-4bd0-b66c-c5f7e610deb7","type":"transcript","start":"PT18M15.45S","end":"PT18M19.581S","eventData":{
        "type":"caption","language":"en","text":"improvement initiative since our\r\nbusiness systems, led by John"
      },"hidden":False,"userData":"null"
    },{
      "id":"ae367255-c11c-4049-9bf8-74957684e298","type":"transcript","start":"PT18M19.581S","end":"PT18M22.335S","eventData":{
        "type":"caption","language":"en","text":"will address process\r\neffectiveness and efficiency"
      },"hidden":False,"userData":"null"
    },{
      "id":"16ec7bcf-4e82-45bd-8649-056a90fd4a41","type":"transcript","start":"PT18M22.335S","end":"PT18M24.63S","eventData":{
        "type":"caption","language":"en","text":"starting with the sale process."
      },"hidden":False,"userData":"null"
    },{
      "id":"0a268347-c25a-4880-a7c7-9921f169796c","type":"transcript","start":"PT18M25.33S","end":"PT18M28.927S","eventData":{
        "type":"caption","language":"en","text":"And the second large initiatives\r\nis Ron. Since how to management"
      },"hidden":False,"userData":"null"
    },{
      "id":"115c4df3-328b-4969-ad68-a93a6b44e116","type":"transcript","start":"PT18M28.927S","end":"PT18M32.197S","eventData":{
        "type":"caption","language":"en","text":"system, which is led by Paul\r\nBassington? Uh, that will"
      },"hidden":False,"userData":"null"
    },{
      "id":"4933ffeb-194d-4820-a064-65936f505947","type":"transcript","start":"PT18M32.197S","end":"PT18M35.794S","eventData":{
        "type":"caption","language":"en","text":"address, for example, how we\r\nmake decisions and what we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"3875c40f-b949-4892-a043-f81bc3f7ec74","type":"transcript","start":"PT18M35.794S","end":"PT18M37.429S","eventData":{
        "type":"caption","language":"en","text":"measure on a consistent basis."
      },"hidden":False,"userData":"null"
    },{
      "id":"1afd1028-ddf4-4f85-a7a4-a44f383f8b4d","type":"transcript","start":"PT18M39.63S","end":"PT18M42.822S","eventData":{
        "type":"caption","language":"en","text":"When it comes to capital\r\ndeployment, our capital"
      },"hidden":False,"userData":"null"
    },{
      "id":"994680f8-58e2-4bbc-906e-9ba3b6938052","type":"transcript","start":"PT18M42.822S","end":"PT18M46.812S","eventData":{
        "type":"caption","language":"en","text":"deployment policies Will Rock\r\nlargely remain the same, but as"
      },"hidden":False,"userData":"null"
    },{
      "id":"20e8067f-8301-4230-b4a5-074f1f03b8b4","type":"transcript","start":"PT18M46.812S","end":"PT18M50.403S","eventData":{
        "type":"caption","language":"en","text":"I mentioned earlier, we will\r\nallocate capital and resources."
      },"hidden":False,"userData":"null"
    },{
      "id":"60f6098c-a623-4c1b-8e76-38c9a8d7bb61","type":"transcript","start":"PT18M52.1S","end":"PT18M55.428S","eventData":{
        "type":"caption","language":"en","text":"Better to serve the most\r\nattractive growth opportunities."
      },"hidden":False,"userData":"null"
    },{
      "id":"27b51fa2-d078-478c-99b0-f2f7c8a48598","type":"transcript","start":"PT18M57.23S","end":"PT19M0.335S","eventData":{
        "type":"caption","language":"en","text":"Last but definitely not\r\nleast, is of course our"
      },"hidden":False,"userData":"null"
    },{
      "id":"66082948-43fc-4410-a7d0-722e2d9ee5e4","type":"transcript","start":"PT19M0.335S","end":"PT19M3.095S","eventData":{
        "type":"caption","language":"en","text":"people. Our most important\r\nresource. We will continue"
      },"hidden":False,"userData":"null"
    },{
      "id":"1427487b-f733-4258-8983-2799dc89dc6d","type":"transcript","start":"PT19M3.095S","end":"PT19M6.89S","eventData":{
        "type":"caption","language":"en","text":"to involve invest in all of\r\nyou so we together can"
      },"hidden":False,"userData":"null"
    },{
      "id":"4c6bc0da-7bfd-4e00-9e2a-cd79a0ddf1f5","type":"transcript","start":"PT19M6.89S","end":"PT19M9.65S","eventData":{
        "type":"caption","language":"en","text":"capture the many exciting\r\nopportunities we have in"
      },"hidden":False,"userData":"null"
    },{
      "id":"0deafae4-50c4-4ca2-a1de-50c9e36646b4","type":"transcript","start":"PT19M9.65S","end":"PT19M10.685S","eventData":{
        "type":"caption","language":"en","text":"front of us."
      },"hidden":False,"userData":"null"
    },{
      "id":"881531d8-db94-4277-bd26-ab105642ddc2","type":"transcript","start":"PT19M13.3S","end":"PT19M14.428S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"f35ff5f7-4185-4542-9814-9e237203a658","type":"transcript","start":"PT19M16.45S","end":"PT19M20.707S","eventData":{
        "type":"caption","language":"en","text":"So to conclude, our my section,\r\nif we successfully deliver on"
      },"hidden":False,"userData":"null"
    },{
      "id":"5b85e820-29bb-4ae2-8ce8-9716b1c06ed3","type":"transcript","start":"PT19M20.707S","end":"PT19M24.577S","eventData":{
        "type":"caption","language":"en","text":"our five and five, accelerate\r\nand focus strategy and Adolar"
      },"hidden":False,"userData":"null"
    },{
      "id":"fe6c789a-fd86-4dbb-9a24-fdde35e0a848","type":"transcript","start":"PT19M24.577S","end":"PT19M29.608S","eventData":{
        "type":"caption","language":"en","text":"stand plans together, we still\r\nbelieve that we are can be a 5"
      },"hidden":False,"userData":"null"
    },{
      "id":"fd874a59-9792-4b3e-8e57-d25b3cd68adc","type":"transcript","start":"PT19M29.608S","end":"PT19M33.865S","eventData":{
        "type":"caption","language":"en","text":"billion dollar targets in five\r\nyears, with roughly a 5050 split"
      },"hidden":False,"userData":"null"
    },{
      "id":"e2a232db-3299-45ec-a414-415034e889f2","type":"transcript","start":"PT19M33.865S","end":"PT19M37.735S","eventData":{
        "type":"caption","language":"en","text":"between auto and sensing\r\nsolution in five years that you"
      },"hidden":False,"userData":"null"
    },{
      "id":"7b0aedd1-7f5c-44d9-a909-9d8bbc038747","type":"transcript","start":"PT19M37.735S","end":"PT19M40.057S","eventData":{
        "type":"caption","language":"en","text":"can see in the right side."
      },"hidden":False,"userData":"null"
    },{
      "id":"c1c35acf-9d61-4171-984c-9936a67e8d22","type":"transcript","start":"PT19M42.32S","end":"PT19M46.52S","eventData":{
        "type":"caption","language":"en","text":"In summary, uhm, we have a very\r\nexciting opportunity in front of"
      },"hidden":False,"userData":"null"
    },{
      "id":"9cbf7170-4adc-44da-8db2-2a99c3c57b0c","type":"transcript","start":"PT19M46.52S","end":"PT19M50.37S","eventData":{
        "type":"caption","language":"en","text":"us. We believe that we have the\r\nright vision, strategy and"
      },"hidden":False,"userData":"null"
    },{
      "id":"322befa2-5cdf-46e1-873b-b41403c4acac","type":"transcript","start":"PT19M50.37S","end":"PT19M53.87S","eventData":{
        "type":"caption","language":"en","text":"plans. So with all your\r\ntremendous help and support, it"
      },"hidden":False,"userData":"null"
    },{
      "id":"25ed1d35-7f57-401b-a0f9-55bfaa087bac","type":"transcript","start":"PT19M53.87S","end":"PT19M55.62S","eventData":{
        "type":"caption","language":"en","text":"will make it all happen."
      },"hidden":False,"userData":"null"
    },{
      "id":"a6562529-c192-49ab-851b-28309e65fd7c","type":"transcript","start":"PT19M56.38S","end":"PT19M59.356S","eventData":{
        "type":"caption","language":"en","text":"So on behalf of their salty\r\nthank you for delivering on the"
      },"hidden":False,"userData":"null"
    },{
      "id":"843df630-43bd-4341-998b-1fc606552fba","type":"transcript","start":"PT19M59.356S","end":"PT20M1.58S","eventData":{
        "type":"caption","language":"en","text":"short and long. Term goals\r\noffice insider."
      },"hidden":False,"userData":"null"
    },{
      "id":"aa9c9cc3-80a0-48f3-a30a-107a9817a491","type":"transcript","start":"PT20M2.75S","end":"PT20M6.221S","eventData":{
        "type":"caption","language":"en","text":"I will now hand over to. We need\r\nto work cover sensing solutions."
      },"hidden":False,"userData":"null"
    },{
      "id":"efe78fc1-31ed-4381-8a90-66fb503fe1a5","type":"transcript","start":"PT20M8.39S","end":"PT20M10.829S","eventData":{
        "type":"caption","language":"en","text":"Thank you Hans. At high team."
      },"hidden":False,"userData":"null"
    },{
      "id":"a06f2eb1-96e2-4bd5-97f3-94e3819bdfd9","type":"transcript","start":"PT20M11.46S","end":"PT20M15.66S","eventData":{
        "type":"caption","language":"en","text":"Uh, I'm married and I have the\r\nprivilege of leading the sensing"
      },"hidden":False,"userData":"null"
    },{
      "id":"92d73b3a-156f-4096-bc01-513bb33050a8","type":"transcript","start":"PT20M15.66S","end":"PT20M18.81S","eventData":{
        "type":"caption","language":"en","text":"solutions team and really,\r\nreally excited about sharing our"
      },"hidden":False,"userData":"null"
    },{
      "id":"a23d6957-af75-4901-a249-1d2c727d6fb1","type":"transcript","start":"PT20M18.81S","end":"PT20M23.01S","eventData":{
        "type":"caption","language":"en","text":"strategic framework with all of\r\nyou today. So as I think about"
      },"hidden":False,"userData":"null"
    },{
      "id":"d73e140a-462b-4a36-b331-2dad6ee3a784","type":"transcript","start":"PT20M23.01S","end":"PT20M26.86S","eventData":{
        "type":"caption","language":"en","text":"strategy and Hans mentioned it,\r\nstrategy is a set of choices."
      },"hidden":False,"userData":"null"
    },{
      "id":"29476c17-98ba-4f58-aa68-7b032f079d46","type":"transcript","start":"PT20M27.65S","end":"PT20M30.125S","eventData":{
        "type":"caption","language":"en","text":"And force the sensing solutions"
      },"hidden":False,"userData":"null"
    },{
      "id":"7a3384b5-ab88-4dd8-af67-0acbb09461e5","type":"transcript","start":"PT20M30.125S","end":"PT20M34.134S","eventData":{
        "type":"caption","language":"en","text":"businesses. The slate of choices\r\nhas never been greater."
      },"hidden":False,"userData":"null"
    },{
      "id":"b2501ce2-b6d4-44b9-8122-08c9617645dc","type":"transcript","start":"PT20M34.83S","end":"PT20M38.38S","eventData":{
        "type":"caption","language":"en","text":"And the stakes, in terms of\r\nmaking the right choice."
      },"hidden":False,"userData":"null"
    },{
      "id":"8c75e4d9-6b67-4583-804c-f07862db28fd","type":"transcript","start":"PT20M38.96S","end":"PT20M40.54S","eventData":{
        "type":"caption","language":"en","text":"Have never been greater either."
      },"hidden":False,"userData":"null"
    },{
      "id":"542f6946-9601-47e4-922a-bfbe41d902e4","type":"transcript","start":"PT20M41.36S","end":"PT20M44.715S","eventData":{
        "type":"caption","language":"en","text":"And before I jump into the\r\nstrategic framework, I do want"
      },"hidden":False,"userData":"null"
    },{
      "id":"7f6d04d7-bcd2-46d5-a66a-12c7cb43d8d6","type":"transcript","start":"PT20M44.715S","end":"PT20M48.07S","eventData":{
        "type":"caption","language":"en","text":"to thank the entire sensing\r\nsolutions team for the hard work"
      },"hidden":False,"userData":"null"
    },{
      "id":"b93d2597-05ea-4924-849e-a844d68b0c6b","type":"transcript","start":"PT20M48.07S","end":"PT20M51.12S","eventData":{
        "type":"caption","language":"en","text":"in the thought they put into\r\nbringing the right strategies"
      },"hidden":False,"userData":"null"
    },{
      "id":"83a1c194-e9e4-4269-8040-c59684ede985","type":"transcript","start":"PT20M51.12S","end":"PT20M55.39S","eventData":{
        "type":"caption","language":"en","text":"forward in. What is a very, very\r\ndifficult time. So if you can go"
      },"hidden":False,"userData":"null"
    },{
      "id":"3844070f-a9ae-4a66-a6e7-cd413f558ec2","type":"transcript","start":"PT20M55.39S","end":"PT20M56.915S","eventData":{
        "type":"caption","language":"en","text":"to the next page place."
      },"hidden":False,"userData":"null"
    },{
      "id":"543c468d-8299-4372-9157-8bd37b81ee92","type":"transcript","start":"PT20M59.06S","end":"PT21M2.063S","eventData":{
        "type":"caption","language":"en","text":"Let me start by saying that the\r\nend markets we serve."
      },"hidden":False,"userData":"null"
    },{
      "id":"d62e5420-6f4c-4af9-a7e9-f86f1bb4e424","type":"transcript","start":"PT21M2.65S","end":"PT21M6.097S","eventData":{
        "type":"caption","language":"en","text":"Whether it's an industrial,\r\nwhether it's in heavyweight, in"
      },"hidden":False,"userData":"null"
    },{
      "id":"a4edd930-f84b-433a-bc0c-65911362c093","type":"transcript","start":"PT21M6.097S","end":"PT21M9.927S","eventData":{
        "type":"caption","language":"en","text":"an off road, or an aerospace,\r\nremain attractive and markets."
      },"hidden":False,"userData":"null"
    },{
      "id":"28416e22-f459-4183-8d44-c0970d876f77","type":"transcript","start":"PT21M10.78S","end":"PT21M15.37S","eventData":{
        "type":"caption","language":"en","text":"And our businesses continue\r\nto build an extend a"
      },"hidden":False,"userData":"null"
    },{
      "id":"3fbae28e-db1b-47a0-b247-b752204a64a3","type":"transcript","start":"PT21M15.37S","end":"PT21M18.94S","eventData":{
        "type":"caption","language":"en","text":"leadership position within\r\nthose end markets with"
      },"hidden":False,"userData":"null"
    },{
      "id":"e25ec7ee-f396-4e3b-b483-c5c3baa40edd","type":"transcript","start":"PT21M18.94S","end":"PT21M19.96S","eventData":{
        "type":"caption","language":"en","text":"differentiated margins."
      },"hidden":False,"userData":"null"
    },{
      "id":"9ff88e30-28b7-4425-9408-82c7f2b305c8","type":"transcript","start":"PT21M21.28S","end":"PT21M26.012S","eventData":{
        "type":"caption","language":"en","text":"As has mentioned and we all know\r\ntoo, well covered has had a"
      },"hidden":False,"userData":"null"
    },{
      "id":"43f2f770-3589-4118-87e1-6e655921aa2e","type":"transcript","start":"PT21M26.012S","end":"PT21M27.832S","eventData":{
        "type":"caption","language":"en","text":"dramatic impact on the end"
      },"hidden":False,"userData":"null"
    },{
      "id":"3f4cbb32-a642-458a-a104-5ba64463d98f","type":"transcript","start":"PT21M27.832S","end":"PT21M32.847S","eventData":{
        "type":"caption","language":"en","text":"markets. And in the near term,\r\nthat impact has been sharp and"
      },"hidden":False,"userData":"null"
    },{
      "id":"7b1c5417-2747-45f2-824b-1b52252ab335","type":"transcript","start":"PT21M32.847S","end":"PT21M33.858S","eventData":{
        "type":"caption","language":"en","text":"it's been immediate."
      },"hidden":False,"userData":"null"
    },{
      "id":"071ca490-08af-411d-a100-20b0e2f9e26d","type":"transcript","start":"PT21M34.62S","end":"PT21M38.14S","eventData":{
        "type":"caption","language":"en","text":"But we believe that recovery,\r\nwhile it will be slow, will"
      },"hidden":False,"userData":"null"
    },{
      "id":"a69e6a17-7256-494d-b3a8-b808a7b72fbb","type":"transcript","start":"PT21M38.14S","end":"PT21M40.06S","eventData":{
        "type":"caption","language":"en","text":"happen over the next two to"
      },"hidden":False,"userData":"null"
    },{
      "id":"448c5349-cc59-4734-a441-2d0455a52ebb","type":"transcript","start":"PT21M40.06S","end":"PT21M44.673S","eventData":{
        "type":"caption","language":"en","text":"three years. An covert has not\r\nchanged or mission of driving"
      },"hidden":False,"userData":"null"
    },{
      "id":"394c84fd-3c27-4b76-a3b8-c205f2759e16","type":"transcript","start":"PT21M44.673S","end":"PT21M47.172S","eventData":{
        "type":"caption","language":"en","text":"growth in achieving the\r\ndiversification and the"
      },"hidden":False,"userData":"null"
    },{
      "id":"0548bb3f-96dd-4e8e-906b-0f528fd00ddd","type":"transcript","start":"PT21M47.172S","end":"PT21M50.742S","eventData":{
        "type":"caption","language":"en","text":"following five that has just\r\nlaid out for the company."
      },"hidden":False,"userData":"null"
    },{
      "id":"22f4962b-9aae-4644-abad-5f21fbdc7872","type":"transcript","start":"PT21M52.08S","end":"PT21M56.396S","eventData":{
        "type":"caption","language":"en","text":"As I think about the arc over\r\nthe next five and really over"
      },"hidden":False,"userData":"null"
    },{
      "id":"74b3d8fa-b158-4add-b142-8b64c97448c0","type":"transcript","start":"PT21M56.396S","end":"PT22M1.545S","eventData":{
        "type":"caption","language":"en","text":"the next decade. The Mega Trends\r\nof electrification iot an"
      },"hidden":False,"userData":"null"
    },{
      "id":"f3423133-6f5c-4c34-853d-deeceb353a82","type":"transcript","start":"PT22M1.545S","end":"PT22M6.66S","eventData":{
        "type":"caption","language":"en","text":"economy are going to have an\r\noutsize impact. These are major"
      },"hidden":False,"userData":"null"
    },{
      "id":"d8b427b7-02f3-4fe6-a6fc-90f0bfad7fea","type":"transcript","start":"PT22M6.66S","end":"PT22M11.31S","eventData":{
        "type":"caption","language":"en","text":"discontinuities affecting all of\r\nour end markets and are creating"
      },"hidden":False,"userData":"null"
    },{
      "id":"8318a0c4-2e1d-4b4e-974f-9db11fa34dc0","type":"transcript","start":"PT22M11.31S","end":"PT22M15.03S","eventData":{
        "type":"caption","language":"en","text":"opportunities for significant\r\ngrowth, both organically as well"
      },"hidden":False,"userData":"null"
    },{
      "id":"1d0b1ce4-5c95-429e-9258-8e4ce3a30c55","type":"transcript","start":"PT22M15.03S","end":"PT22M16.425S","eventData":{
        "type":"caption","language":"en","text":"as through acquisitions."
      },"hidden":False,"userData":"null"
    },{
      "id":"56dd4968-b58f-493e-b458-15303669474e","type":"transcript","start":"PT22M17.55S","end":"PT22M20.7S","eventData":{
        "type":"caption","language":"en","text":"And we intend to use\r\nboth levels to achieve"
      },"hidden":False,"userData":"null"
    },{
      "id":"6034cbc7-15bf-43cf-849f-3b7f4e2fc4f0","type":"transcript","start":"PT22M20.7S","end":"PT22M21.75S","eventData":{
        "type":"caption","language":"en","text":"our growth objectives."
      },"hidden":False,"userData":"null"
    },{
      "id":"5c05cdb0-46df-414e-aee0-9cad6c7adf76","type":"transcript","start":"PT22M22.89S","end":"PT22M25.018S","eventData":{
        "type":"caption","language":"en","text":"When I think about each of\r\nthe businesses."
      },"hidden":False,"userData":"null"
    },{
      "id":"a5316a59-63cc-4770-b30c-3a846b35ab48","type":"transcript","start":"PT22M26.11S","end":"PT22M29.575S","eventData":{
        "type":"caption","language":"en","text":"Our industrial business is\r\nprobably in the need of"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a5d80dc-1f37-4971-a880-4e3f6c5c9039","type":"transcript","start":"PT22M29.575S","end":"PT22M33.425S","eventData":{
        "type":"caption","language":"en","text":"transformation is most in the\r\nneed for transformation in order"
      },"hidden":False,"userData":"null"
    },{
      "id":"2b4437a5-6cff-4786-ae07-77dc4ae0544c","type":"transcript","start":"PT22M33.425S","end":"PT22M35.35S","eventData":{
        "type":"caption","language":"en","text":"to take advantage of these"
      },"hidden":False,"userData":"null"
    },{
      "id":"4e9d921b-7f18-457d-a6bb-2b910cc88e39","type":"transcript","start":"PT22M35.35S","end":"PT22M39.606S","eventData":{
        "type":"caption","language":"en","text":"megatrends. And when I talk\r\nabout a transformation is really"
      },"hidden":False,"userData":"null"
    },{
      "id":"ac11a48a-5f98-4240-9741-34a2af52f77b","type":"transcript","start":"PT22M39.606S","end":"PT22M44.078S","eventData":{
        "type":"caption","language":"en","text":"across the board. It's in how we\r\ngo to market, what and what"
      },"hidden":False,"userData":"null"
    },{
      "id":"22c51d8e-7ec5-47b0-ba69-9810b4dbf88c","type":"transcript","start":"PT22M44.078S","end":"PT22M46.142S","eventData":{
        "type":"caption","language":"en","text":"markets we focused on focus on."
      },"hidden":False,"userData":"null"
    },{
      "id":"7dbd9cb2-ebe9-4b95-8f68-e41cac43c1d5","type":"transcript","start":"PT22M47.03S","end":"PT22M50.838S","eventData":{
        "type":"caption","language":"en","text":"In terms of a portfolio and the\r\nproduct that we need in order to"
      },"hidden":False,"userData":"null"
    },{
      "id":"5666e5b9-e509-4a9f-91af-9503954069ec","type":"transcript","start":"PT22M50.838S","end":"PT22M52.47S","eventData":{
        "type":"caption","language":"en","text":"be relevant in an iot world."
      },"hidden":False,"userData":"null"
    },{
      "id":"492ae91a-29d3-49d3-94e7-8b41c7b68b99","type":"transcript","start":"PT22M53.23S","end":"PT22M56.44S","eventData":{
        "type":"caption","language":"en","text":"In terms of channels where we\r\nlargely serving OEM channel"
      },"hidden":False,"userData":"null"
    },{
      "id":"bd986473-5b42-4687-a772-0739948c30da","type":"transcript","start":"PT22M56.44S","end":"PT23M0.292S","eventData":{
        "type":"caption","language":"en","text":"today and in order to take\r\nadvantage of iot and to be"
      },"hidden":False,"userData":"null"
    },{
      "id":"70e3dbf8-64dd-494a-b368-3644b0d1ea65","type":"transcript","start":"PT23M0.292S","end":"PT23M3.502S","eventData":{
        "type":"caption","language":"en","text":"meaningfully present in the\r\niot space, we do have to"
      },"hidden":False,"userData":"null"
    },{
      "id":"b99dc70a-00ee-4916-809b-604fde46e5de","type":"transcript","start":"PT23M3.502S","end":"PT23M6.07S","eventData":{
        "type":"caption","language":"en","text":"think about opening up a\r\nsystem integrator channel."
      },"hidden":False,"userData":"null"
    },{
      "id":"7a464da6-72a7-459b-b2fa-2941f6e68632","type":"transcript","start":"PT23M7.25S","end":"PT23M10.13S","eventData":{
        "type":"caption","language":"en","text":"And also in terms of our\r\norganization structure in terms"
      },"hidden":False,"userData":"null"
    },{
      "id":"0f9ddc6c-3910-44d7-8310-43cb7cd37243","type":"transcript","start":"PT23M10.13S","end":"PT23M13.874S","eventData":{
        "type":"caption","language":"en","text":"of talent as the skills required\r\nto serve the iot market as well"
      },"hidden":False,"userData":"null"
    },{
      "id":"61866a77-5f07-478d-b3be-dabeabff935e","type":"transcript","start":"PT23M13.874S","end":"PT23M17.33S","eventData":{
        "type":"caption","language":"en","text":"as the SI channel are going to\r\nbe quite different than this"
      },"hidden":False,"userData":"null"
    },{
      "id":"83c1ea55-1af2-467d-a498-9f4ccbfb98aa","type":"transcript","start":"PT23M17.33S","end":"PT23M19.922S","eventData":{
        "type":"caption","language":"en","text":"skills we've developed and the\r\nmuscles will develop through"
      },"hidden":False,"userData":"null"
    },{
      "id":"82819e6b-08c7-445e-8714-8ed988cb6a08","type":"transcript","start":"PT23M19.922S","end":"PT23M21.074S","eventData":{
        "type":"caption","language":"en","text":"serving the OEM channel."
      },"hidden":False,"userData":"null"
    },{
      "id":"b4c36617-9b10-411a-a347-bfc3fd5ee508","type":"transcript","start":"PT23M22.15S","end":"PT23M25.604S","eventData":{
        "type":"caption","language":"en","text":"When I think about our heavy\r\nmetal and offered business, I"
      },"hidden":False,"userData":"null"
    },{
      "id":"b7c4b5c1-1925-401e-9277-a86f847001a1","type":"transcript","start":"PT23M25.604S","end":"PT23M29.058S","eventData":{
        "type":"caption","language":"en","text":"would say that this is a\r\nbusiness that is really well"
      },"hidden":False,"userData":"null"
    },{
      "id":"21f4998d-b65e-48e9-907a-13d21ca26730","type":"transcript","start":"PT23M29.058S","end":"PT23M30.628S","eventData":{
        "type":"caption","language":"en","text":"positioned to benefit from the"
      },"hidden":False,"userData":"null"
    },{
      "id":"4f116c66-287c-4fc6-8188-765a6d9518f6","type":"transcript","start":"PT23M30.628S","end":"PT23M34.888S","eventData":{
        "type":"caption","language":"en","text":"Megatrends. With the activities\r\nthat are happening within the"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a7f411b-2329-41d4-a8ed-d7b8cb030a87","type":"transcript","start":"PT23M34.888S","end":"PT23M38.698S","eventData":{
        "type":"caption","language":"en","text":"business that are happening\r\nwithin ventures and CEO as well"
      },"hidden":False,"userData":"null"
    },{
      "id":"16b0f870-529d-4f56-a148-eccc893c307f","type":"transcript","start":"PT23M38.698S","end":"PT23M40.222S","eventData":{
        "type":"caption","language":"en","text":"as through our acquisition"
      },"hidden":False,"userData":"null"
    },{
      "id":"3898372b-28e7-46bd-8aa4-37cf406fa74e","type":"transcript","start":"PT23M40.222S","end":"PT23M43.732S","eventData":{
        "type":"caption","language":"en","text":"pipeline. The evidence of\r\nthat, of course, is the recent"
      },"hidden":False,"userData":"null"
    },{
      "id":"782c17ea-7702-4d78-ad95-4fbe5841d62e","type":"transcript","start":"PT23M43.732S","end":"PT23M46.79S","eventData":{
        "type":"caption","language":"en","text":"acquisition of prequel, which\r\nis a great addition to our a"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd2523b9-1063-4ac0-b91b-6685df2854f9","type":"transcript","start":"PT23M46.79S","end":"PT23M49.014S","eventData":{
        "type":"caption","language":"en","text":"tree or business. An overall\r\ntowards insider family."
      },"hidden":False,"userData":"null"
    },{
      "id":"c4f14d14-04ed-4f4d-9733-414b0ff9a51f","type":"transcript","start":"PT23M50.3S","end":"PT23M53.14S","eventData":{
        "type":"caption","language":"en","text":"Find your aerospace\r\nbusiness. It's a small but"
      },"hidden":False,"userData":"null"
    },{
      "id":"79f0d70d-5da3-4c5e-83db-ae0afeb1a40c","type":"transcript","start":"PT23M53.14S","end":"PT23M55.98S","eventData":{
        "type":"caption","language":"en","text":"mighty business. One of our\r\nmost profitable businesses"
      },"hidden":False,"userData":"null"
    },{
      "id":"6ee7cd64-696f-4a5a-b537-0d1b2a741249","type":"transcript","start":"PT23M55.98S","end":"PT23M59.53S","eventData":{
        "type":"caption","language":"en","text":"and in an end market, which\r\nI think has secular,"
      },"hidden":False,"userData":"null"
    },{
      "id":"459d78cb-e12d-494b-9bac-557261b6a62e","type":"transcript","start":"PT23M59.53S","end":"PT24M0.595S","eventData":{
        "type":"caption","language":"en","text":"long-term growth trends."
      },"hidden":False,"userData":"null"
    },{
      "id":"e486d122-ffad-4870-9a22-00ba4a0ee0e3","type":"transcript","start":"PT24M1.68S","end":"PT24M5.44S","eventData":{
        "type":"caption","language":"en","text":"The aerospace business has a\r\ngreat organic path with 10%"
      },"hidden":False,"userData":"null"
    },{
      "id":"b37b7ddd-0dfb-4fe4-b732-1481bf799687","type":"transcript","start":"PT24M5.44S","end":"PT24M9.7S","eventData":{
        "type":"caption","language":"en","text":"growth. But it's clear then\r\nfor us to have a meaningful"
      },"hidden":False,"userData":"null"
    },{
      "id":"5e69a5bf-5f15-4ec1-985c-de68715b751f","type":"transcript","start":"PT24M9.7S","end":"PT24M12.99S","eventData":{
        "type":"caption","language":"en","text":"presence in the aerospace\r\nindustry, we need to scale up"
      },"hidden":False,"userData":"null"
    },{
      "id":"fed1422d-c6da-45b6-a04d-5c4119145f60","type":"transcript","start":"PT24M12.99S","end":"PT24M14.306S","eventData":{
        "type":"caption","language":"en","text":"our business through Eminem."
      },"hidden":False,"userData":"null"
    },{
      "id":"53915684-6814-4c26-8ab4-61abdea4b46c","type":"transcript","start":"PT24M15.52S","end":"PT24M18.963S","eventData":{
        "type":"caption","language":"en","text":"And if we put all of our\r\ninitiatives together, we do"
      },"hidden":False,"userData":"null"
    },{
      "id":"6b845ca7-d7ca-4637-8f5c-0d19d281e25c","type":"transcript","start":"PT24M18.963S","end":"PT24M22.093S","eventData":{
        "type":"caption","language":"en","text":"have an opportunity here to\r\ndouble the size of our"
      },"hidden":False,"userData":"null"
    },{
      "id":"4ba62900-c627-4d9d-8f8f-ba0aedf4d5ce","type":"transcript","start":"PT24M22.093S","end":"PT24M25.223S","eventData":{
        "type":"caption","language":"en","text":"business, and so it's a really\r\nexciting time within sensing"
      },"hidden":False,"userData":"null"
    },{
      "id":"bae062d7-a594-4615-a6a5-23286eafa5e7","type":"transcript","start":"PT24M25.223S","end":"PT24M28.666S","eventData":{
        "type":"caption","language":"en","text":"solutions an our businesses as\r\nwe take on that challenge of"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd1e0df7-496f-46b8-8fc2-283ecd606275","type":"transcript","start":"PT24M28.666S","end":"PT24M31.796S","eventData":{
        "type":"caption","language":"en","text":"doubling the size of our\r\nbusiness over the next five"
      },"hidden":False,"userData":"null"
    },{
      "id":"93841574-ed67-4fdc-b510-05d8ae9cfe6c","type":"transcript","start":"PT24M31.796S","end":"PT24M32.109S","eventData":{
        "type":"caption","language":"en","text":"years."
      },"hidden":False,"userData":"null"
    },{
      "id":"dc5a28dd-ad4c-45b1-8d28-25e7c07e64b7","type":"transcript","start":"PT24M33.14S","end":"PT24M34.01S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"9c1b02b9-fa7a-41e4-a943-c1376cba8e64","type":"transcript","start":"PT24M36.09S","end":"PT24M40.305S","eventData":{
        "type":"caption","language":"en","text":"So so. So let me spend a little\r\nbit of time on on the Mega"
      },"hidden":False,"userData":"null"
    },{
      "id":"a6bdc6c4-3e38-4c29-84e6-a859aad4ed03","type":"transcript","start":"PT24M40.305S","end":"PT24M43.396S","eventData":{
        "type":"caption","language":"en","text":"Trends. And as I said, These are\r\ncreating great discontinuity in"
      },"hidden":False,"userData":"null"
    },{
      "id":"4fe9455c-2bdb-4f43-844c-b499328b7c64","type":"transcript","start":"PT24M43.396S","end":"PT24M44.801S","eventData":{
        "type":"caption","language":"en","text":"the end markets we serve."
      },"hidden":False,"userData":"null"
    },{
      "id":"e8e17682-d0c3-4c00-acba-c1baa235d37a","type":"transcript","start":"PT24M45.49S","end":"PT24M49.474S","eventData":{
        "type":"caption","language":"en","text":"And for us, what that means is\r\nthat the available market ahead"
      },"hidden":False,"userData":"null"
    },{
      "id":"f3c3435b-fae9-4df6-aa26-e2eacdfd6738","type":"transcript","start":"PT24M49.474S","end":"PT24M51.798S","eventData":{
        "type":"caption","language":"en","text":"of us more than doubles over the"
      },"hidden":False,"userData":"null"
    },{
      "id":"42c32f11-d9de-45f5-a104-a0579c7965f8","type":"transcript","start":"PT24M51.798S","end":"PT24M56.428S","eventData":{
        "type":"caption","language":"en","text":"next decade. Now, I'm not going\r\nto read through the numbers"
      },"hidden":False,"userData":"null"
    },{
      "id":"98f1dd61-be28-444c-b51b-42b3c73ce064","type":"transcript","start":"PT24M56.428S","end":"PT24M59.748S","eventData":{
        "type":"caption","language":"en","text":"here. I think it's pretty\r\nobvious that the markets are"
      },"hidden":False,"userData":"null"
    },{
      "id":"9f06558e-62da-4f06-9184-9267162d991f","type":"transcript","start":"PT24M59.748S","end":"PT25M3.068S","eventData":{
        "type":"caption","language":"en","text":"going to be significant and\r\nvery, very meaningful. But if"
      },"hidden":False,"userData":"null"
    },{
      "id":"26b48692-37ce-40f0-82b8-f8be4275cc84","type":"transcript","start":"PT25M3.068S","end":"PT25M6.388S","eventData":{
        "type":"caption","language":"en","text":"you look beyond the numbers,\r\nwhat's really happening in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"7ca4526a-ca4f-4153-a4b7-030a5937181e","type":"transcript","start":"PT25M6.388S","end":"PT25M9.376S","eventData":{
        "type":"caption","language":"en","text":"end markets? We serve our two\r\nmajor trends. It's"
      },"hidden":False,"userData":"null"
    },{
      "id":"316bc7ce-f6c5-4808-8fda-bb25bcb43b86","type":"transcript","start":"PT25M9.376S","end":"PT25M11.51S","eventData":{
        "type":"caption","language":"en","text":"decarbonization. And\r\ndigitization."
      },"hidden":False,"userData":"null"
    },{
      "id":"e30b693a-fac9-4f2f-80a3-8e438cffebed","type":"transcript","start":"PT25M12.7S","end":"PT25M17.716S","eventData":{
        "type":"caption","language":"en","text":"And while you might say that\r\nwe've talked about or, there's"
      },"hidden":False,"userData":"null"
    },{
      "id":"b6277d40-3aa8-4d02-a466-4323c14a70ba","type":"transcript","start":"PT25M17.716S","end":"PT25M21.364S","eventData":{
        "type":"caption","language":"en","text":"been discussion of these two\r\nmegatrends for sometime."
      },"hidden":False,"userData":"null"
    },{
      "id":"c11e52c1-85aa-43fc-aa90-9697c7c11eb8","type":"transcript","start":"PT25M22.24S","end":"PT25M25.488S","eventData":{
        "type":"caption","language":"en","text":"Why is now the right time for us\r\nto go invest in these areas?"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b918279-35cc-49e2-942a-382aba5af7d3","type":"transcript","start":"PT25M26.45S","end":"PT25M32.294S","eventData":{
        "type":"caption","language":"en","text":"I think the reality is the facts\r\nare that the technology required"
      },"hidden":False,"userData":"null"
    },{
      "id":"8f8b461e-4cbb-43ab-8248-cc0b29284c6d","type":"transcript","start":"PT25M32.294S","end":"PT25M35.216S","eventData":{
        "type":"caption","language":"en","text":"to make this a reality now."
      },"hidden":False,"userData":"null"
    },{
      "id":"c47664ad-a925-4689-9607-ec7249a2f843","type":"transcript","start":"PT25M35.79S","end":"PT25M40.003S","eventData":{
        "type":"caption","language":"en","text":"Auto available and now are more\r\ncost effective than ever. So"
      },"hidden":False,"userData":"null"
    },{
      "id":"f11e6516-4e27-4582-ac2b-a02ce34aeb1c","type":"transcript","start":"PT25M40.003S","end":"PT25M41.918S","eventData":{
        "type":"caption","language":"en","text":"when you think about the"
      },"hidden":False,"userData":"null"
    },{
      "id":"047cd941-d33b-444c-bc4b-68758aab7de0","type":"transcript","start":"PT25M41.918S","end":"PT25M45.58S","eventData":{
        "type":"caption","language":"en","text":"availability of. Battery\r\ntechnology and it cost"
      },"hidden":False,"userData":"null"
    },{
      "id":"b7706e0a-2313-4301-9878-4c8235a6dc9a","type":"transcript","start":"PT25M45.58S","end":"PT25M48.408S","eventData":{
        "type":"caption","language":"en","text":"efficiency of battery\r\ntechnology. That's finally here."
      },"hidden":False,"userData":"null"
    },{
      "id":"950f7006-bbe7-49d1-8269-108374cdc448","type":"transcript","start":"PT25M48.408S","end":"PT25M51.236S","eventData":{
        "type":"caption","language":"en","text":"When you think about the cost of"
      },"hidden":False,"userData":"null"
    },{
      "id":"faad42a3-148d-4339-b1ac-fc5f69cc64b5","type":"transcript","start":"PT25M51.236S","end":"PT25M55.632S","eventData":{
        "type":"caption","language":"en","text":"solar. It's down 80% just in the\r\nlast five years. When you think"
      },"hidden":False,"userData":"null"
    },{
      "id":"d8acde2b-db9c-45b6-9af1-89cbb8b32e7d","type":"transcript","start":"PT25M55.632S","end":"PT25M59.09S","eventData":{
        "type":"caption","language":"en","text":"about the cost of wind energy,\r\nit's down 40% in the last five"
      },"hidden":False,"userData":"null"
    },{
      "id":"702c34ee-e11b-4bae-8511-07bf72ee3290","type":"transcript","start":"PT25M59.09S","end":"PT26M3.026S","eventData":{
        "type":"caption","language":"en","text":"years. Then you think about\r\nwhat's enabling iot, the"
      },"hidden":False,"userData":"null"
    },{
      "id":"522bf10f-7857-4bc0-89da-4c26aa88c00f","type":"transcript","start":"PT26M3.026S","end":"PT26M4.142S","eventData":{
        "type":"caption","language":"en","text":"deployment of 5G."
      },"hidden":False,"userData":"null"
    },{
      "id":"9e815be0-848c-4bf2-9f7f-ede22faa03ed","type":"transcript","start":"PT26M4.81S","end":"PT26M9.418S","eventData":{
        "type":"caption","language":"en","text":"The ubiquitous an highly cost\r\neffective cloud computing."
      },"hidden":False,"userData":"null"
    },{
      "id":"1e30eba9-3e9b-48d3-b744-982509a8d4fb","type":"transcript","start":"PT26M10.04S","end":"PT26M13.667S","eventData":{
        "type":"caption","language":"en","text":"The advent of machine learning\r\nand artificial intelligence are"
      },"hidden":False,"userData":"null"
    },{
      "id":"209c4f14-9cc3-4c87-9d75-29755e77fa7c","type":"transcript","start":"PT26M13.667S","end":"PT26M16.891S","eventData":{
        "type":"caption","language":"en","text":"all making the digitalization of\r\nour plants, buildings,"
      },"hidden":False,"userData":"null"
    },{
      "id":"e058202a-2bf5-46e9-ba87-707ce5a43d9a","type":"transcript","start":"PT26M16.891S","end":"PT26M21.324S","eventData":{
        "type":"caption","language":"en","text":"warehouses, supply chain much\r\nmore a reality today than in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"073058df-f0b1-46ac-871b-8c1a990de10e","type":"transcript","start":"PT26M21.324S","end":"PT26M25.757S","eventData":{
        "type":"caption","language":"en","text":"years past, and so we feel\r\nreally bullish about the end"
      },"hidden":False,"userData":"null"
    },{
      "id":"879db719-f41f-4a64-9e7f-74e92bbf5b6d","type":"transcript","start":"PT26M25.757S","end":"PT26M30.19S","eventData":{
        "type":"caption","language":"en","text":"markets we serve and the mega\r\ntrends that are creating the"
      },"hidden":False,"userData":"null"
    },{
      "id":"238bb2d5-2ae9-4acf-a792-96437de3bc8e","type":"transcript","start":"PT26M30.19S","end":"PT26M32.205S","eventData":{
        "type":"caption","language":"en","text":"opportunity for us to drive"
      },"hidden":False,"userData":"null"
    },{
      "id":"ab062f50-4c60-46d8-a7d0-2c847c924185","type":"transcript","start":"PT26M32.205S","end":"PT26M34.33S","eventData":{
        "type":"caption","language":"en","text":"growth. Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"f8769488-b47d-46b0-9e9c-12ad4b534ac9","type":"transcript","start":"PT26M36.47S","end":"PT26M38.79S","eventData":{
        "type":"caption","language":"en","text":"And as I said, our mission\r\nremains unchanged."
      },"hidden":False,"userData":"null"
    },{
      "id":"20c76b32-0b79-4ef0-ab34-77cf11ea209b","type":"transcript","start":"PT26M40.1S","end":"PT26M45.196S","eventData":{
        "type":"caption","language":"en","text":"We are focused on driving growth\r\nand you can see that, uh, if we"
      },"hidden":False,"userData":"null"
    },{
      "id":"0b99a137-3a60-429a-8470-cc123a294ac0","type":"transcript","start":"PT26M45.196S","end":"PT26M47.801S","eventData":{
        "type":"caption","language":"en","text":"are. Successful in our"
      },"hidden":False,"userData":"null"
    },{
      "id":"409136e6-da4c-494d-b249-ebec3c3f58f0","type":"transcript","start":"PT26M47.801S","end":"PT26M52.1S","eventData":{
        "type":"caption","language":"en","text":"strategies. We have a high\r\ndouble digit growth over the"
      },"hidden":False,"userData":"null"
    },{
      "id":"ebf802fd-1077-4cbb-9106-f758ab24e45f","type":"transcript","start":"PT26M52.1S","end":"PT26M56.3S","eventData":{
        "type":"caption","language":"en","text":"next five years and the mega\r\ntrends continue to be a tailwind"
      },"hidden":False,"userData":"null"
    },{
      "id":"8669cb51-dd31-4a63-a398-13cbc593020d","type":"transcript","start":"PT26M56.3S","end":"PT26M58.05S","eventData":{
        "type":"caption","language":"en","text":"for us throughout the decade."
      },"hidden":False,"userData":"null"
    },{
      "id":"8a0405b7-9ec1-4a65-9920-d93a10c8e8f6","type":"transcript","start":"PT26M59.17S","end":"PT27M0.04S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"d09b9e78-b72f-47e8-9474-4972f9053379","type":"transcript","start":"PT27M2.42S","end":"PT27M6.385S","eventData":{
        "type":"caption","language":"en","text":"So as I then connect what Hans\r\ntalked about in terms of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"98e88a9a-4ae5-4f89-8a2f-fc463d97a0e9","type":"transcript","start":"PT27M6.385S","end":"PT27M10.045S","eventData":{
        "type":"caption","language":"en","text":"Five and five and accelerate in\r\nfocus into what is relevant and"
      },"hidden":False,"userData":"null"
    },{
      "id":"83f1811b-30cf-4556-9347-75e2dffdae2c","type":"transcript","start":"PT27M10.045S","end":"PT27M11.875S","eventData":{
        "type":"caption","language":"en","text":"what is really important for us"
      },"hidden":False,"userData":"null"
    },{
      "id":"d4fcd3d5-5991-4f27-981d-067b26b93623","type":"transcript","start":"PT27M11.875S","end":"PT27M15.106S","eventData":{
        "type":"caption","language":"en","text":"within sensing solutions. Let me\r\nstart with the people side"
      },"hidden":False,"userData":"null"
    },{
      "id":"4c9b9a92-1b4d-4601-88a5-e9e4bedf2f04","type":"transcript","start":"PT27M15.106S","end":"PT27M17.369S","eventData":{
        "type":"caption","language":"en","text":"first. It's clear that."
      },"hidden":False,"userData":"null"
    },{
      "id":"fdde723e-b701-48f7-be4d-e0644b4eaa54","type":"transcript","start":"PT27M17.97S","end":"PT27M21.49S","eventData":{
        "type":"caption","language":"en","text":"We need to have the right skill\r\nsets, the right organization"
      },"hidden":False,"userData":"null"
    },{
      "id":"23338f85-c58d-4747-9e80-0e0b2bdce03e","type":"transcript","start":"PT27M21.49S","end":"PT27M26.95S","eventData":{
        "type":"caption","language":"en","text":"structure. The right efficient\r\ncost base an we need to have"
      },"hidden":False,"userData":"null"
    },{
      "id":"e1574240-c4e4-4a0b-98ee-49e612976fe2","type":"transcript","start":"PT27M26.95S","end":"PT27M30.802S","eventData":{
        "type":"caption","language":"en","text":"strong global centers of\r\nbusiness as well as engineering"
      },"hidden":False,"userData":"null"
    },{
      "id":"a8078e07-2a44-44c3-b3c1-f4839196b6d6","type":"transcript","start":"PT27M30.802S","end":"PT27M33.37S","eventData":{
        "type":"caption","language":"en","text":"in order to achieve our growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a517923-fd46-473e-8dd9-029ce5db58d6","type":"transcript","start":"PT27M33.37S","end":"PT27M37.26S","eventData":{
        "type":"caption","language":"en","text":"objectives. And I will tell\r\nyou that this is an error"
      },"hidden":False,"userData":"null"
    },{
      "id":"e5e91689-1407-4b0c-9f1a-808cde4a18d4","type":"transcript","start":"PT27M37.26S","end":"PT27M40.692S","eventData":{
        "type":"caption","language":"en","text":"that my leadership team and I\r\nare spending a ton of time"
      },"hidden":False,"userData":"null"
    },{
      "id":"90c325b2-4e68-4307-80a0-439cfac9f4c9","type":"transcript","start":"PT27M40.692S","end":"PT27M42.694S","eventData":{
        "type":"caption","language":"en","text":"thinking about and putting it\r\ninto action."
      },"hidden":False,"userData":"null"
    },{
      "id":"f302287d-c4d9-4d17-b249-e78f2f955dc2","type":"transcript","start":"PT27M44.01S","end":"PT27M47.22S","eventData":{
        "type":"caption","language":"en","text":"When I think about our\r\ncustomers, really the big change"
      },"hidden":False,"userData":"null"
    },{
      "id":"285c8c63-9751-498d-8d3f-1cb2f1bb66ff","type":"transcript","start":"PT27M47.22S","end":"PT27M51.393S","eventData":{
        "type":"caption","language":"en","text":"that we expect to see over the\r\nnext five years is moving from"
      },"hidden":False,"userData":"null"
    },{
      "id":"10dd5cd0-292e-45e5-bbfa-1e5dcf99a70b","type":"transcript","start":"PT27M51.393S","end":"PT27M55.566S","eventData":{
        "type":"caption","language":"en","text":"an OEM only model to an OEM and\r\nsystem integrated model an that"
      },"hidden":False,"userData":"null"
    },{
      "id":"c939a345-f15b-4564-ac60-eccec9aa7e64","type":"transcript","start":"PT27M55.566S","end":"PT27M59.418S","eventData":{
        "type":"caption","language":"en","text":"is no easy task building and SI\r\nChannel from scratch or even"
      },"hidden":False,"userData":"null"
    },{
      "id":"cc5324f6-d704-416d-ae54-26e7c408bc64","type":"transcript","start":"PT27M59.418S","end":"PT28M3.27S","eventData":{
        "type":"caption","language":"en","text":"acquiring one. Rick will require\r\nus to add new skill sets and"
      },"hidden":False,"userData":"null"
    },{
      "id":"c82690eb-bc7c-4a2b-908b-bf3311693ccd","type":"transcript","start":"PT28M3.27S","end":"PT28M6.159S","eventData":{
        "type":"caption","language":"en","text":"really think about commercial\r\nexcellence in a different way."
      },"hidden":False,"userData":"null"
    },{
      "id":"ebc8db98-b868-4b0e-893b-8815cd442a51","type":"transcript","start":"PT28M7.85S","end":"PT28M10.982S","eventData":{
        "type":"caption","language":"en","text":"When I think about our\r\noperating system, we've talked"
      },"hidden":False,"userData":"null"
    },{
      "id":"c8e0b9e4-cbfd-4251-8904-6ac48bba836e","type":"transcript","start":"PT28M10.982S","end":"PT28M14.81S","eventData":{
        "type":"caption","language":"en","text":"about Taylor supply chain for\r\nsome time now, and I think"
      },"hidden":False,"userData":"null"
    },{
      "id":"1cbd5421-3a18-417d-bbcd-4176a10ae661","type":"transcript","start":"PT28M14.81S","end":"PT28M17.942S","eventData":{
        "type":"caption","language":"en","text":"it's really important that we\r\ndo develop the flexible"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b20fe2f-7fc2-433e-bbfb-5fca309ab438","type":"transcript","start":"PT28M17.942S","end":"PT28M21.422S","eventData":{
        "type":"caption","language":"en","text":"manufacturing capability that\r\nwe need in order to go serve."
      },"hidden":False,"userData":"null"
    },{
      "id":"dabdec9f-a42c-4e5c-bf06-f45ca364fc06","type":"transcript","start":"PT28M21.422S","end":"PT28M25.598S","eventData":{
        "type":"caption","language":"en","text":"Both are OEM customers as well\r\nas the new SI channel that"
      },"hidden":False,"userData":"null"
    },{
      "id":"adcc1e98-a302-44dd-b0be-d06313188582","type":"transcript","start":"PT28M25.598S","end":"PT28M26.642S","eventData":{
        "type":"caption","language":"en","text":"we're talking about."
      },"hidden":False,"userData":"null"
    },{
      "id":"ee410f0b-000f-479b-8758-3a3dbc20f9be","type":"transcript","start":"PT28M28.18S","end":"PT28M31.156S","eventData":{
        "type":"caption","language":"en","text":"It's also really important to\r\nrevitalize the productivity"
      },"hidden":False,"userData":"null"
    },{
      "id":"febd988d-d2a6-4de8-929a-8d64e0c02fe0","type":"transcript","start":"PT28M31.156S","end":"PT28M34.876S","eventData":{
        "type":"caption","language":"en","text":"engine. I think in the years\r\npast, the sensing solutions"
      },"hidden":False,"userData":"null"
    },{
      "id":"e44de855-deb8-4921-99d1-75d4d0285f57","type":"transcript","start":"PT28M34.876S","end":"PT28M38.224S","eventData":{
        "type":"caption","language":"en","text":"business has not gotten his\r\nentitlement from a productivity"
      },"hidden":False,"userData":"null"
    },{
      "id":"175f4293-8c44-4fbf-bd7b-bfc2f0afa16e","type":"transcript","start":"PT28M38.224S","end":"PT28M41.572S","eventData":{
        "type":"caption","language":"en","text":"standpoint. And as we think\r\nabout over indexing towards"
      },"hidden":False,"userData":"null"
    },{
      "id":"0291674a-c794-433a-bd2b-8070bbe9fc26","type":"transcript","start":"PT28M41.572S","end":"PT28M44.548S","eventData":{
        "type":"caption","language":"en","text":"growth, productivity creates the\r\nfunding necessary to drive"
      },"hidden":False,"userData":"null"
    },{
      "id":"2deba1c1-c57e-4415-be16-9bde495f55f8","type":"transcript","start":"PT28M44.548S","end":"PT28M48.64S","eventData":{
        "type":"caption","language":"en","text":"growth and so it's really\r\nimportant that we could do that."
      },"hidden":False,"userData":"null"
    },{
      "id":"3dec08fd-382b-46f4-a582-ee20754ef124","type":"transcript","start":"PT28M50.08S","end":"PT28M54.04S","eventData":{
        "type":"caption","language":"en","text":"From a capital perspective,\r\nemanate is a big level for"
      },"hidden":False,"userData":"null"
    },{
      "id":"3d87c317-3a5c-4bc8-bddc-8df37d8d378c","type":"transcript","start":"PT28M54.04S","end":"PT28M58S","eventData":{
        "type":"caption","language":"en","text":"growth and as we think about\r\nRMA pipeline today, we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"06c7c682-b098-4f57-8ae5-e63df14e2332","type":"transcript","start":"PT28M58S","end":"PT29M2.356S","eventData":{
        "type":"caption","language":"en","text":"tracking almost a billion and\r\na half dollars of revenue in"
      },"hidden":False,"userData":"null"
    },{
      "id":"4771dd8f-8521-499e-9d18-3d9b94c0a8a9","type":"transcript","start":"PT29M2.356S","end":"PT29M5.92S","eventData":{
        "type":"caption","language":"en","text":"our pipeline and we're\r\nquickly working to turn that"
      },"hidden":False,"userData":"null"
    },{
      "id":"e9848fd8-7afb-490d-96e7-eaa2f521e604","type":"transcript","start":"PT29M5.92S","end":"PT29M8.692S","eventData":{
        "type":"caption","language":"en","text":"from a pipeline into\r\nactionable initiatives within"
      },"hidden":False,"userData":"null"
    },{
      "id":"879550c5-4793-4723-b208-742548150fcf","type":"transcript","start":"PT29M8.692S","end":"PT29M9.484S","eventData":{
        "type":"caption","language":"en","text":"that pipeline."
      },"hidden":False,"userData":"null"
    },{
      "id":"cc03b9e1-ded7-4a76-b777-4cd52b82a915","type":"transcript","start":"PT29M11.27S","end":"PT29M12.119S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"f63d217a-7608-48b9-bfa7-b92dd008aa7b","type":"transcript","start":"PT29M14.59S","end":"PT29M19.089S","eventData":{
        "type":"caption","language":"en","text":"So Hans talked about the three\r\nareas for strategic focus, an"
      },"hidden":False,"userData":"null"
    },{
      "id":"187e2ecd-d41b-4c6a-b0b6-944172a861f8","type":"transcript","start":"PT29M19.089S","end":"PT29M23.179S","eventData":{
        "type":"caption","language":"en","text":"I'm really pleased to be talking\r\nabout our industrial iot"
      },"hidden":False,"userData":"null"
    },{
      "id":"4805a864-923b-4df6-bf32-18c3bfa0155c","type":"transcript","start":"PT29M23.179S","end":"PT29M28.55S","eventData":{
        "type":"caption","language":"en","text":"initiative. As we think about a\r\niot within the industrial space"
      },"hidden":False,"userData":"null"
    },{
      "id":"7b370bc4-acd1-4916-b29d-6a7a04bf28cc","type":"transcript","start":"PT29M28.55S","end":"PT29M34.956S","eventData":{
        "type":"caption","language":"en","text":"and an. Let me define the scope\r\na little bit of what that means."
      },"hidden":False,"userData":"null"
    },{
      "id":"eb8bfedf-50b6-43b4-a23f-e2f61415553b","type":"transcript","start":"PT29M34.956S","end":"PT29M37.98S","eventData":{
        "type":"caption","language":"en","text":"It's really the digitalization\r\nof plans of buildings,"
      },"hidden":False,"userData":"null"
    },{
      "id":"72f54619-24ad-4d92-bbe0-9b05a125ffc0","type":"transcript","start":"PT29M37.98S","end":"PT29M41.382S","eventData":{
        "type":"caption","language":"en","text":"warehouses and supply chain to\r\ndeliver more insights and"
      },"hidden":False,"userData":"null"
    },{
      "id":"0e83c8dc-a029-4d4b-95ef-e5cfc927e9f0","type":"transcript","start":"PT29M41.382S","end":"PT29M42.516S","eventData":{
        "type":"caption","language":"en","text":"ultimately more productivity."
      },"hidden":False,"userData":"null"
    },{
      "id":"e703b8f4-bf93-44e4-9530-a06ad0eebd7a","type":"transcript","start":"PT29M43.15S","end":"PT29M47.47S","eventData":{
        "type":"caption","language":"en","text":"And we believe that this is at\r\nleast 6 billion dollar market"
      },"hidden":False,"userData":"null"
    },{
      "id":"aef9e80e-74de-4feb-b175-3642ce00f3f3","type":"transcript","start":"PT29M47.47S","end":"PT29M50.71S","eventData":{
        "type":"caption","language":"en","text":"as we think purely from a\r\nsensing layer standpoint."
      },"hidden":False,"userData":"null"
    },{
      "id":"b7a1316b-da46-4fc9-8de4-bb930c1763a5","type":"transcript","start":"PT29M51.84S","end":"PT29M53.368S","eventData":{
        "type":"caption","language":"en","text":"If you go to the next\r\nslide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"f3650953-4a26-4929-bcbb-592cc59057a8","type":"transcript","start":"PT29M55.72S","end":"PT29M59.164S","eventData":{
        "type":"caption","language":"en","text":"This is a very busy slide and\r\nI'm going to spend a little bit"
      },"hidden":False,"userData":"null"
    },{
      "id":"3c895a5c-77ae-4a6b-b89c-e9468502076c","type":"transcript","start":"PT29M59.164S","end":"PT30M1.08S","eventData":{
        "type":"caption","language":"en","text":"of time just explaining.\r\nYou're seeing here."
      },"hidden":False,"userData":"null"
    },{
      "id":"5ea83605-fc84-4a42-8d09-00d9d5e50c6f","type":"transcript","start":"PT30M2.91S","end":"PT30M5.538S","eventData":{
        "type":"caption","language":"en","text":"As we think about the\r\nindustrial iot value chain."
      },"hidden":False,"userData":"null"
    },{
      "id":"5764daf1-af19-4da1-a86f-51e5f85fad79","type":"transcript","start":"PT30M6.82S","end":"PT30M9.417S","eventData":{
        "type":"caption","language":"en","text":"It's clear that there is a ton"
      },"hidden":False,"userData":"null"
    },{
      "id":"e9dcb43e-d1b3-4d02-a041-652908b96990","type":"transcript","start":"PT30M9.417S","end":"PT30M13.92S","eventData":{
        "type":"caption","language":"en","text":"of. There are a lot of players\r\ntrying to capture the"
      },"hidden":False,"userData":"null"
    },{
      "id":"fe6905ec-c70c-4525-ac92-68a85d2f8367","type":"transcript","start":"PT30M13.92S","end":"PT30M15.48S","eventData":{
        "type":"caption","language":"en","text":"opportunity. Ann"
      },"hidden":False,"userData":"null"
    },{
      "id":"bede4105-230d-4266-9651-f981775a1f4f","type":"transcript","start":"PT30M16.56S","end":"PT30M20.241S","eventData":{
        "type":"caption","language":"en","text":"There are traditional strong\r\nincumbent players. The big names"
      },"hidden":False,"userData":"null"
    },{
      "id":"6d9e4ab2-16c4-4bf6-99a5-d7ab5f4da24c","type":"transcript","start":"PT30M20.241S","end":"PT30M23.922S","eventData":{
        "type":"caption","language":"en","text":"like Rockwell Automation like\r\nSchneider like honey where like"
      },"hidden":False,"userData":"null"
    },{
      "id":"eb7f2b13-8528-4327-b0ae-d0aaccd5733f","type":"transcript","start":"PT30M23.922S","end":"PT30M25.149S","eventData":{
        "type":"caption","language":"en","text":"Emerson and Siemens."
      },"hidden":False,"userData":"null"
    },{
      "id":"0be9801f-4e24-431a-81a2-eeb24c2e8131","type":"transcript","start":"PT30M25.72S","end":"PT30M28.536S","eventData":{
        "type":"caption","language":"en","text":"Who have played an important\r\nrole traditionally within"
      },"hidden":False,"userData":"null"
    },{
      "id":"55a1a9f6-ab8b-4dae-828c-de48ab6a9d46","type":"transcript","start":"PT30M28.536S","end":"PT30M31S","eventData":{
        "type":"caption","language":"en","text":"the plant space or the\r\nbuilding space?"
      },"hidden":False,"userData":"null"
    },{
      "id":"0bb98b1f-72ce-47ed-ad24-83389ddf2df2","type":"transcript","start":"PT30M32.11S","end":"PT30M36.572S","eventData":{
        "type":"caption","language":"en","text":"But as the need for productivity\r\ncontinues to increase and"
      },"hidden":False,"userData":"null"
    },{
      "id":"0af06164-e378-4b60-b598-df727f03a598","type":"transcript","start":"PT30M36.572S","end":"PT30M39.596S","eventData":{
        "type":"caption","language":"en","text":"destruction takes place with\r\ntechnology engine technology as"
      },"hidden":False,"userData":"null"
    },{
      "id":"21d5a9a8-82bf-4b72-9ad3-86b2435f7eb1","type":"transcript","start":"PT30M39.596S","end":"PT30M43.754S","eventData":{
        "type":"caption","language":"en","text":"with change in the value chain,\r\nwe are seeing opportunities that"
      },"hidden":False,"userData":"null"
    },{
      "id":"50ad9d8e-6d20-4312-9c77-c3b82e4d033b","type":"transcript","start":"PT30M43.754S","end":"PT30M47.156S","eventData":{
        "type":"caption","language":"en","text":"are being created for new\r\nentrants to come in."
      },"hidden":False,"userData":"null"
    },{
      "id":"6cf6bd47-1f28-4243-bec8-df410ed34144","type":"transcript","start":"PT30M48.64S","end":"PT30M52.984S","eventData":{
        "type":"caption","language":"en","text":"From the top, we're seeing\r\ndigital integrators like"
      },"hidden":False,"userData":"null"
    },{
      "id":"65066104-72fc-4f61-a16a-d4813e98eced","type":"transcript","start":"PT30M52.984S","end":"PT30M54.07S","eventData":{
        "type":"caption","language":"en","text":"Accenture, Deloitte."
      },"hidden":False,"userData":"null"
    },{
      "id":"2daf6966-117c-469f-b7f6-16bf7f5b4aee","type":"transcript","start":"PT30M55.74S","end":"PT31M1.23S","eventData":{
        "type":"caption","language":"en","text":"Infosys. BTC, to name a few,\r\ncoming in and really trying"
      },"hidden":False,"userData":"null"
    },{
      "id":"e2a57f5d-b421-4f26-92fc-d098ba1a4d8d","type":"transcript","start":"PT31M1.23S","end":"PT31M5.333S","eventData":{
        "type":"caption","language":"en","text":"to provide a digital overlay\r\nonto the plant and onto the"
      },"hidden":False,"userData":"null"
    },{
      "id":"6361f88d-7aa7-41b9-8a73-4c74ed0b5370","type":"transcript","start":"PT31M5.333S","end":"PT31M6.079S","eventData":{
        "type":"caption","language":"en","text":"building framework."
      },"hidden":False,"userData":"null"
    },{
      "id":"d81befd8-975c-4a2f-b617-21e36c478f2c","type":"transcript","start":"PT31M7.98S","end":"PT31M9.93S","eventData":{
        "type":"caption","language":"en","text":"From the bottom, sensors are"
      },"hidden":False,"userData":"null"
    },{
      "id":"e0d14418-28e7-4c36-9185-1aab35379696","type":"transcript","start":"PT31M9.93S","end":"PT31M14.518S","eventData":{
        "type":"caption","language":"en","text":"getting smarter. They're getting\r\nmore sophisticated and are"
      },"hidden":False,"userData":"null"
    },{
      "id":"13482cf7-cf81-4b7f-9114-80d4f151b5f8","type":"transcript","start":"PT31M14.518S","end":"PT31M19.448S","eventData":{
        "type":"caption","language":"en","text":"really becoming PNC agnostic and\r\nallowing a destruction of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"2eea3e2c-0cd1-4d68-b503-098b680e7ef7","type":"transcript","start":"PT31M19.448S","end":"PT31M23.836S","eventData":{
        "type":"caption","language":"en","text":"middle there. And so as we think\r\nabout industrial iot."
      },"hidden":False,"userData":"null"
    },{
      "id":"5675ae62-6971-4d6a-8c8b-a3226501fcff","type":"transcript","start":"PT31M25.01S","end":"PT31M27.061S","eventData":{
        "type":"caption","language":"en","text":"It's clear to us that sensing is"
      },"hidden":False,"userData":"null"
    },{
      "id":"8b8fe86e-6dcc-48b2-93ec-de9da3b0a86a","type":"transcript","start":"PT31M27.061S","end":"PT31M31.96S","eventData":{
        "type":"caption","language":"en","text":"the starting point. An our goal,\r\nour job number one is to make"
      },"hidden":False,"userData":"null"
    },{
      "id":"0bc9f793-aa1e-44b9-a4bb-f287a480bf60","type":"transcript","start":"PT31M31.96S","end":"PT31M35.17S","eventData":{
        "type":"caption","language":"en","text":"sure that we build a strong\r\nposition at the sensing."
      },"hidden":False,"userData":"null"
    },{
      "id":"607aa675-3468-46cd-87fd-a1f5a4863349","type":"transcript","start":"PT31M36.19S","end":"PT31M39.589S","eventData":{
        "type":"caption","language":"en","text":"This is an underserved area that\r\nwe believe, and we are"
      },"hidden":False,"userData":"null"
    },{
      "id":"ae280676-178a-4816-96e7-2da29a392922","type":"transcript","start":"PT31M39.589S","end":"PT31M40.825S","eventData":{
        "type":"caption","language":"en","text":"continuing to validate that"
      },"hidden":False,"userData":"null"
    },{
      "id":"e212d0cc-5ac6-465c-8c18-24408bc49be6","type":"transcript","start":"PT31M40.825S","end":"PT31M45.05S","eventData":{
        "type":"caption","language":"en","text":"hypothesis. And as we build a\r\nposition there, we will look for"
      },"hidden":False,"userData":"null"
    },{
      "id":"14af18e4-1382-4d4e-be51-8104ef26cf59","type":"transcript","start":"PT31M45.05S","end":"PT31M46.5S","eventData":{
        "type":"caption","language":"en","text":"opportunities to go up the"
      },"hidden":False,"userData":"null"
    },{
      "id":"025264cf-68e7-4655-acf4-a0dd7ee140d0","type":"transcript","start":"PT31M46.5S","end":"PT31M52.14S","eventData":{
        "type":"caption","language":"en","text":"stack. But it's not clear to us\r\nthat we that there is an"
      },"hidden":False,"userData":"null"
    },{
      "id":"41ca34ce-dc98-4110-9e79-9907ac7d8832","type":"transcript","start":"PT31M52.14S","end":"PT31M55.84S","eventData":{
        "type":"caption","language":"en","text":"opportunity broadly further up\r\nthe stack to serve this space."
      },"hidden":False,"userData":"null"
    },{
      "id":"ba6432db-2751-4b31-a817-2a3be4b8a39b","type":"transcript","start":"PT31M56.63S","end":"PT32M0.964S","eventData":{
        "type":"caption","language":"en","text":"We have some great data points,\r\nwhether it's a material handling"
      },"hidden":False,"userData":"null"
    },{
      "id":"c8af8b07-0884-4678-b20b-ed5933145b23","type":"transcript","start":"PT32M0.964S","end":"PT32M4.904S","eventData":{
        "type":"caption","language":"en","text":"business or it's our newly\r\nacquired C3 business where there"
      },"hidden":False,"userData":"null"
    },{
      "id":"f14a27ae-c3b6-4c36-aeb3-1048e088a5ed","type":"transcript","start":"PT32M4.904S","end":"PT32M9.632S","eventData":{
        "type":"caption","language":"en","text":"are opportunities to go further\r\nup the stack and do more than"
      },"hidden":False,"userData":"null"
    },{
      "id":"e8788f57-7344-4831-a5ce-283eae86e38f","type":"transcript","start":"PT32M9.632S","end":"PT32M13.178S","eventData":{
        "type":"caption","language":"en","text":"provide a sensing solution by\r\nproviding a controller by"
      },"hidden":False,"userData":"null"
    },{
      "id":"87db1fb5-e1cd-4ffb-83bb-978bd1289cdd","type":"transcript","start":"PT32M13.178S","end":"PT32M16.33S","eventData":{
        "type":"caption","language":"en","text":"providing a web wireless\r\nconnection by providing web"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd39a938-b21b-4388-af5a-4f3395e6a704","type":"transcript","start":"PT32M16.33S","end":"PT32M19.876S","eventData":{
        "type":"caption","language":"en","text":"connectivity and data insights\r\nto help plants and buildings"
      },"hidden":False,"userData":"null"
    },{
      "id":"a47a3c69-97f9-41e4-b6ac-d03548e31094","type":"transcript","start":"PT32M19.876S","end":"PT32M23.816S","eventData":{
        "type":"caption","language":"en","text":"become more efficient and become\r\nmore effective, and we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"1bd8ada7-660f-4772-b842-45f4ffb9a00e","type":"transcript","start":"PT32M23.816S","end":"PT32M26.574S","eventData":{
        "type":"caption","language":"en","text":"continue to look for\r\nopportunities like that."
      },"hidden":False,"userData":"null"
    },{
      "id":"2f7e7693-e180-4ca8-9f6a-aa41922817f0","type":"transcript","start":"PT32M26.75S","end":"PT32M29.77S","eventData":{
        "type":"caption","language":"en","text":"As we scanned the industrial\r\niot landscape, however, just at"
      },"hidden":False,"userData":"null"
    },{
      "id":"bbab9fb6-fd34-4531-bb54-cdb89b967c66","type":"transcript","start":"PT32M29.77S","end":"PT32M32.79S","eventData":{
        "type":"caption","language":"en","text":"the sensing, let alone there,\r\nis a tremendous amount of"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4aee9a6-1957-4b57-a084-67bc858d5e65","type":"transcript","start":"PT32M32.79S","end":"PT32M35.81S","eventData":{
        "type":"caption","language":"en","text":"opportunity for us to innovate\r\nand to build a leadership"
      },"hidden":False,"userData":"null"
    },{
      "id":"c02449f0-00d9-4c6b-838b-0abf23d61e75","type":"transcript","start":"PT32M35.81S","end":"PT32M36.112S","eventData":{
        "type":"caption","language":"en","text":"position."
      },"hidden":False,"userData":"null"
    },{
      "id":"550409d1-8917-478a-9875-55bcbd4d1eee","type":"transcript","start":"PT32M37.99S","end":"PT32M38.869S","eventData":{
        "type":"caption","language":"en","text":"Makes like please."
      },"hidden":False,"userData":"null"
    },{
      "id":"6f1927ac-310a-4986-aae9-f8419bf26bc3","type":"transcript","start":"PT32M40.25S","end":"PT32M44.045S","eventData":{
        "type":"caption","language":"en","text":"And so as we think about a\r\nsensor portfolio, the industrial"
      },"hidden":False,"userData":"null"
    },{
      "id":"213920a3-c072-4013-a23e-e6f4c6bd39ad","type":"transcript","start":"PT32M44.045S","end":"PT32M48.875S","eventData":{
        "type":"caption","language":"en","text":"team is done a really nice job\r\nin laying out what does it mean"
      },"hidden":False,"userData":"null"
    },{
      "id":"41db3835-25bc-4db4-a3a5-4602b12320eb","type":"transcript","start":"PT32M48.875S","end":"PT32M51.98S","eventData":{
        "type":"caption","language":"en","text":"to compete and to differentiate\r\nin the iot space."
      },"hidden":False,"userData":"null"
    },{
      "id":"6c50ce46-0be7-40d3-bcb5-cd0633dfbfa4","type":"transcript","start":"PT32M52.59S","end":"PT32M58.26S","eventData":{
        "type":"caption","language":"en","text":"As you go from left to right at\r\nthe bottom here on the X axis,"
      },"hidden":False,"userData":"null"
    },{
      "id":"dc493bec-5c63-46a8-9f25-17c7165037f3","type":"transcript","start":"PT32M58.26S","end":"PT33M2.418S","eventData":{
        "type":"caption","language":"en","text":"you will see what it means in\r\nterms of industrial sensors"
      },"hidden":False,"userData":"null"
    },{
      "id":"5109e497-52f2-4058-ad6a-44b51ca6b535","type":"transcript","start":"PT33M2.418S","end":"PT33M3.93S","eventData":{
        "type":"caption","language":"en","text":"becoming smarter and more"
      },"hidden":False,"userData":"null"
    },{
      "id":"c4427c7c-0568-46e2-9e2e-0f22f3a09ee3","type":"transcript","start":"PT33M3.93S","end":"PT33M6.66S","eventData":{
        "type":"caption","language":"en","text":"connected. And on the Y axis."
      },"hidden":False,"userData":"null"
    },{
      "id":"42fdec28-01b2-42e1-9c14-4d7c0d9a1134","type":"transcript","start":"PT33M7.31S","end":"PT33M12.146S","eventData":{
        "type":"caption","language":"en","text":"We are the team is defined what\r\nis table stakes to compete"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd74ceac-5fb1-44ed-841f-68962b1ab3ab","type":"transcript","start":"PT33M12.146S","end":"PT33M15.37S","eventData":{
        "type":"caption","language":"en","text":"versus what helps us become\r\ndifferentiated in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"3b549b8f-a220-44ee-af1a-8684545ec338","type":"transcript","start":"PT33M15.37S","end":"PT33M21.01S","eventData":{
        "type":"caption","language":"en","text":"marketplace. So suffice to say\r\nthat the ability to be flexible"
      },"hidden":False,"userData":"null"
    },{
      "id":"5f6de12f-03b0-48ef-a08f-080c96a30d2d","type":"transcript","start":"PT33M21.01S","end":"PT33M25.024S","eventData":{
        "type":"caption","language":"en","text":"from a manufacturing standpoint,\r\nthe ability to provide analog"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a50e657-df15-4c7d-84e2-260b423c8f72","type":"transcript","start":"PT33M25.024S","end":"PT33M29.484S","eventData":{
        "type":"caption","language":"en","text":"and Digital Outputs and the\r\nability to provide a low-cost."
      },"hidden":False,"userData":"null"
    },{
      "id":"35b1c93a-de8f-4696-82be-1980df3968e9","type":"transcript","start":"PT33M30.13S","end":"PT33M33.442S","eventData":{
        "type":"caption","language":"en","text":"And very efficient wireless\r\ninterface are quickly becoming"
      },"hidden":False,"userData":"null"
    },{
      "id":"223e22e3-dbed-4abc-aa6f-ea0f79df3987","type":"transcript","start":"PT33M33.442S","end":"PT33M37.582S","eventData":{
        "type":"caption","language":"en","text":"table stakes in the industry.\r\nHowever, we have an opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"179461fe-d299-4d12-926e-8e9a91f24fbc","type":"transcript","start":"PT33M37.582S","end":"PT33M41.308S","eventData":{
        "type":"caption","language":"en","text":"to innovate by becoming smarter\r\nin the sensing offerings,"
      },"hidden":False,"userData":"null"
    },{
      "id":"40f313b6-358c-494e-9e3c-2a753758c0bb","type":"transcript","start":"PT33M41.308S","end":"PT33M44.62S","eventData":{
        "type":"caption","language":"en","text":"whether it's bringing in\r\nmultiple sense sensory inputs,"
      },"hidden":False,"userData":"null"
    },{
      "id":"97e18591-af77-4ccd-b7ff-80cb951323c9","type":"transcript","start":"PT33M44.62S","end":"PT33M48.346S","eventData":{
        "type":"caption","language":"en","text":"whether it's doing more\r\nanalytics on the edge, whether"
      },"hidden":False,"userData":"null"
    },{
      "id":"15beec9a-de32-4412-81e0-80c147a0c151","type":"transcript","start":"PT33M48.346S","end":"PT33M52.486S","eventData":{
        "type":"caption","language":"en","text":"it's doing more diagnosis to\r\nallow the systems in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"da790720-90d2-452b-bd7c-9b377b4a8b64","type":"transcript","start":"PT33M52.486S","end":"PT33M56.626S","eventData":{
        "type":"caption","language":"en","text":"solutions to become smarter and\r\nmore effective, those are the"
      },"hidden":False,"userData":"null"
    },{
      "id":"c5d586d6-a48c-4246-8e27-d8f6cde34d7b","type":"transcript","start":"PT33M56.626S","end":"PT34M0.766S","eventData":{
        "type":"caption","language":"en","text":"opportunities in front of us,\r\nand so we're really excited"
      },"hidden":False,"userData":"null"
    },{
      "id":"37b1ccce-c2e5-4947-8f3d-4ffdd24ad468","type":"transcript","start":"PT34M0.766S","end":"PT34M2.422S","eventData":{
        "type":"caption","language":"en","text":"about building this portfolio"
      },"hidden":False,"userData":"null"
    },{
      "id":"ce004a60-ebb5-4620-af73-1d60fefe3a59","type":"transcript","start":"PT34M2.422S","end":"PT34M7.284S","eventData":{
        "type":"caption","language":"en","text":"out. And not one team or laser\r\nfocus. Now on looking at both"
      },"hidden":False,"userData":"null"
    },{
      "id":"11bb0820-2909-4bbf-b576-c5aa998a7671","type":"transcript","start":"PT34M7.284S","end":"PT34M11.448S","eventData":{
        "type":"caption","language":"en","text":"organic as well as Emily options\r\nto help build up this portfolio."
      },"hidden":False,"userData":"null"
    },{
      "id":"5805a4fe-6e9f-4b2f-a53e-7d1055982017","type":"transcript","start":"PT34M13.48S","end":"PT34M14.29S","eventData":{
        "type":"caption","language":"en","text":"Next slide, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"a3686c58-e1fe-4057-ae56-ac66cbb84e14","type":"transcript","start":"PT34M16.24S","end":"PT34M20.06S","eventData":{
        "type":"caption","language":"en","text":"The final piece here that\r\nI'll talk about is this"
      },"hidden":False,"userData":"null"
    },{
      "id":"ba09226b-79f5-47bd-8bbc-bcb3475450bc","type":"transcript","start":"PT34M20.06S","end":"PT34M23.116S","eventData":{
        "type":"caption","language":"en","text":"notion of opening up a\r\nsystem integrator channel."
      },"hidden":False,"userData":"null"
    },{
      "id":"1f723cbd-ede3-4478-9ae0-1ced87266b35","type":"transcript","start":"PT34M24.22S","end":"PT34M27.3S","eventData":{
        "type":"caption","language":"en","text":"As the team's done, the work in\r\nunderstanding the opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"14962593-4975-445f-a8ce-ff7c281eb49d","type":"transcript","start":"PT34M27.3S","end":"PT34M29.456S","eventData":{
        "type":"caption","language":"en","text":"that lies in front of us in"
      },"hidden":False,"userData":"null"
    },{
      "id":"81e47a87-761a-43a5-a52f-ffc35b16c0b6","type":"transcript","start":"PT34M29.456S","end":"PT34M34.244S","eventData":{
        "type":"caption","language":"en","text":"industrial iot. One of our key\r\nrevelations has been that almost"
      },"hidden":False,"userData":"null"
    },{
      "id":"03c4fb4a-8927-4c3c-a8e6-099597cf4e50","type":"transcript","start":"PT34M34.244S","end":"PT34M38.104S","eventData":{
        "type":"caption","language":"en","text":"60% of the market actually goes\r\nthrough a system integrator."
      },"hidden":False,"userData":"null"
    },{
      "id":"db763353-7701-4865-9736-d07f7d7d6ac2","type":"transcript","start":"PT34M39S","end":"PT34M40.56S","eventData":{
        "type":"caption","language":"en","text":"And the reason is simply this."
      },"hidden":False,"userData":"null"
    },{
      "id":"04808615-1185-48e1-abfc-00922a6e3505","type":"transcript","start":"PT34M41.41S","end":"PT34M43.84S","eventData":{
        "type":"caption","language":"en","text":"Volume equipment providers"
      },"hidden":False,"userData":"null"
    },{
      "id":"8282b6c5-6558-4999-afe0-c8ac5c17c20e","type":"transcript","start":"PT34M43.84S","end":"PT34M49.934S","eventData":{
        "type":"caption","language":"en","text":"cannot solve. A very discrete\r\nproblem that a building or a"
      },"hidden":False,"userData":"null"
    },{
      "id":"659da2ee-87d5-4da5-a801-7b3b76fd25b5","type":"transcript","start":"PT34M49.934S","end":"PT34M53.262S","eventData":{
        "type":"caption","language":"en","text":"plant has that requires\r\nconnecting multiple pieces of"
      },"hidden":False,"userData":"null"
    },{
      "id":"5b85d2ac-30b5-4071-8a1d-290dea9de74e","type":"transcript","start":"PT34M53.262S","end":"PT34M57.006S","eventData":{
        "type":"caption","language":"en","text":"equipment together. Disparate\r\nsystems and bringing all of that"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a4b17fb-54f9-4381-baae-2f6f53b1069d","type":"transcript","start":"PT34M57.006S","end":"PT35M1.166S","eventData":{
        "type":"caption","language":"en","text":"together into one seamless\r\nsolution and the role of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"adff7f95-1d62-42e3-a988-7ef18528a4a9","type":"transcript","start":"PT35M1.166S","end":"PT35M4.91S","eventData":{
        "type":"caption","language":"en","text":"system integrator becomes really\r\ncritical in working closely with"
      },"hidden":False,"userData":"null"
    },{
      "id":"df5139b9-f478-4b62-91ea-224d125272ec","type":"transcript","start":"PT35M4.91S","end":"PT35M8.654S","eventData":{
        "type":"caption","language":"en","text":"the end customer. Understanding\r\nthe problem statement and then"
      },"hidden":False,"userData":"null"
    },{
      "id":"61f64d56-12af-4c56-9823-022a63452908","type":"transcript","start":"PT35M8.654S","end":"PT35M11.15S","eventData":{
        "type":"caption","language":"en","text":"designing, installing,\r\ncommissioning and maintaining a"
      },"hidden":False,"userData":"null"
    },{
      "id":"8a26415a-38df-4d0e-b09d-c13a65251ffe","type":"transcript","start":"PT35M11.15S","end":"PT35M15.726S","eventData":{
        "type":"caption","language":"en","text":"solution that solves the problem\r\nand continues to evolve as a"
      },"hidden":False,"userData":"null"
    },{
      "id":"4c4292a5-a1c5-4d27-a6b1-ca78e8611cf2","type":"transcript","start":"PT35M15.726S","end":"PT35M17.02S","eventData":{
        "type":"caption","language":"en","text":"customer needs. Cool."
      },"hidden":False,"userData":"null"
    },{
      "id":"a58b7a9b-62b9-4aca-8eb1-e708d8c78cf1","type":"transcript","start":"PT35M17.62S","end":"PT35M21.741S","eventData":{
        "type":"caption","language":"en","text":"And so we believe that the role\r\nof the SI is absolutely critical"
      },"hidden":False,"userData":"null"
    },{
      "id":"c3ada1a3-c2f5-4ae9-8a34-b289751ebfec","type":"transcript","start":"PT35M21.741S","end":"PT35M27.427S","eventData":{
        "type":"caption","language":"en","text":"in. Designing and delivering and\r\nderiving value from an iot"
      },"hidden":False,"userData":"null"
    },{
      "id":"f96aeeb5-583f-4796-b334-d8b0b290943f","type":"transcript","start":"PT35M27.427S","end":"PT35M31.66S","eventData":{
        "type":"caption","language":"en","text":"solution. And as we think about\r\nserving that that SI Channel."
      },"hidden":False,"userData":"null"
    },{
      "id":"58472e92-aff9-4465-8cf6-f2b7e465dfb3","type":"transcript","start":"PT35M32.34S","end":"PT35M36.905S","eventData":{
        "type":"caption","language":"en","text":"Uh, the there is no one size\r\nfits all system integrators."
      },"hidden":False,"userData":"null"
    },{
      "id":"10412eca-f21b-46ed-9a44-30ee840e3d40","type":"transcript","start":"PT35M38.26S","end":"PT35M42.34S","eventData":{
        "type":"caption","language":"en","text":"But the big tier one Tier 2\r\nsystem integrators like some of"
      },"hidden":False,"userData":"null"
    },{
      "id":"1dbc2b01-56b1-4c96-9913-5e61896fee09","type":"transcript","start":"PT35M42.34S","end":"PT35M45.4S","eventData":{
        "type":"caption","language":"en","text":"the names mentioned here. We\r\nhave the digital system"
      },"hidden":False,"userData":"null"
    },{
      "id":"adc6729c-1358-404c-858f-c72e61cca1e4","type":"transcript","start":"PT35M45.4S","end":"PT35M48.46S","eventData":{
        "type":"caption","language":"en","text":"integrators that we need to\r\nbuild relationships with and"
      },"hidden":False,"userData":"null"
    },{
      "id":"57099fff-67cc-4367-a899-fc38fd90b3e7","type":"transcript","start":"PT35M48.46S","end":"PT35M52.54S","eventData":{
        "type":"caption","language":"en","text":"then there is a whole world or\r\nsmall to medium size enterprises"
      },"hidden":False,"userData":"null"
    },{
      "id":"7cfce8ec-d913-4203-a771-cad9e6499a70","type":"transcript","start":"PT35M52.54S","end":"PT35M56.96S","eventData":{
        "type":"caption","language":"en","text":"that really formed the bulk of\r\nthe SI base and so will be"
      },"hidden":False,"userData":"null"
    },{
      "id":"27826c36-1373-44dd-95d1-4d607795679c","type":"transcript","start":"PT35M56.96S","end":"PT35M59.68S","eventData":{
        "type":"caption","language":"en","text":"looking for different strategies\r\nincluding going director. Some"
      },"hidden":False,"userData":"null"
    },{
      "id":"805c6aa6-867c-46bf-b965-613ddba93df0","type":"transcript","start":"PT35M59.68S","end":"PT36M2.4S","eventData":{
        "type":"caption","language":"en","text":"of these system integrators\r\nversus serving others through"
      },"hidden":False,"userData":"null"
    },{
      "id":"b9c87b3b-3072-4824-a1ae-1561680f81c6","type":"transcript","start":"PT36M2.4S","end":"PT36M6.14S","eventData":{
        "type":"caption","language":"en","text":"distribution. So a very very\r\nexciting time ahead of us across"
      },"hidden":False,"userData":"null"
    },{
      "id":"77c6d7ce-99cd-4985-bc1d-cd95ea5484dc","type":"transcript","start":"PT36M6.14S","end":"PT36M9.2S","eventData":{
        "type":"caption","language":"en","text":"the sensing solutions business\r\nis a lot of innovation."
      },"hidden":False,"userData":"null"
    },{
      "id":"f3e2855f-fd84-4c4c-bfbe-56d64ba1e065","type":"transcript","start":"PT36M9.31S","end":"PT36M13.692S","eventData":{
        "type":"caption","language":"en","text":"A lot of new new that we will\r\nbe working on and I look"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4c37dfb-6e5e-41e3-b129-8e4cb71fef70","type":"transcript","start":"PT36M13.692S","end":"PT36M16.509S","eventData":{
        "type":"caption","language":"en","text":"forward to working on these\r\ngrowth strategies along with"
      },"hidden":False,"userData":"null"
    },{
      "id":"fd43e3bd-9eb7-4d30-b4dc-4e18acb4d3ed","type":"transcript","start":"PT36M16.509S","end":"PT36M19.952S","eventData":{
        "type":"caption","language":"en","text":"my team and on sharing updates\r\nwith the broader. Since our"
      },"hidden":False,"userData":"null"
    },{
      "id":"9e9ade83-6a07-466f-9bae-b502a4132557","type":"transcript","start":"PT36M19.952S","end":"PT36M23.395S","eventData":{
        "type":"caption","language":"en","text":"community as we make progress.\r\nThank you and I'm going to"
      },"hidden":False,"userData":"null"
    },{
      "id":"1232c4e8-240e-4c74-bfb9-3e1f352a6b63","type":"transcript","start":"PT36M23.395S","end":"PT36M24.96S","eventData":{
        "type":"caption","language":"en","text":"turn it over to Paul."
      },"hidden":False,"userData":"null"
    },{
      "id":"3ab1bdd1-519f-4d6a-9acb-94b2185de433","type":"transcript","start":"PT36M28.14S","end":"PT36M31.89S","eventData":{
        "type":"caption","language":"en","text":"Thank you, we need a good\r\nmorning. Good afternoon, good"
      },"hidden":False,"userData":"null"
    },{
      "id":"0bce1653-284f-4bb2-ba2a-a758616cd768","type":"transcript","start":"PT36M31.89S","end":"PT36M36.39S","eventData":{
        "type":"caption","language":"en","text":"evening teams. This is Paul. I\r\napologize, I'm not on video but"
      },"hidden":False,"userData":"null"
    },{
      "id":"46f0bca5-cf84-412d-abc5-b17ecb9f2146","type":"transcript","start":"PT36M36.39S","end":"PT36M41.64S","eventData":{
        "type":"caption","language":"en","text":"I I'm in an area where my Wi-Fi\r\nreception is not brilliant. So I"
      },"hidden":False,"userData":"null"
    },{
      "id":"23554efa-1989-4a57-8929-067c9bcb3143","type":"transcript","start":"PT36M41.64S","end":"PT36M46.14S","eventData":{
        "type":"caption","language":"en","text":"want to take you through the\r\njourney. We started with GPT in"
      },"hidden":False,"userData":"null"
    },{
      "id":"df095a9d-1d98-4f78-af8f-255c20983e19","type":"transcript","start":"PT36M46.14S","end":"PT36M50.265S","eventData":{
        "type":"caption","language":"en","text":"GSM, but even more so the\r\njourney we are embarking in"
      },"hidden":False,"userData":"null"
    },{
      "id":"6bd77ff2-d299-48a8-9596-7cab243cada9","type":"transcript","start":"PT36M50.265S","end":"PT36M52.14S","eventData":{
        "type":"caption","language":"en","text":"supporting company\r\ndiversification strategies all"
      },"hidden":False,"userData":"null"
    },{
      "id":"353addab-e8fa-488f-8c5f-da5648b5e7f6","type":"transcript","start":"PT36M52.14S","end":"PT36M55.515S","eventData":{
        "type":"caption","language":"en","text":"but also out of diversification\r\nstrategies. Going forward and"
      },"hidden":False,"userData":"null"
    },{
      "id":"5ab68181-fb82-4c69-b3b0-ae59d725cdd5","type":"transcript","start":"PT36M55.515S","end":"PT37M0.39S","eventData":{
        "type":"caption","language":"en","text":"they said as I would like to\r\nthank as well very much the."
      },"hidden":False,"userData":"null"
    },{
      "id":"a36420b1-55e5-4a3c-a8de-6167f636032e","type":"transcript","start":"PT37M0.53S","end":"PT37M3.295S","eventData":{
        "type":"caption","language":"en","text":"Automotive teams who these\r\nunprecedented times where"
      },"hidden":False,"userData":"null"
    },{
      "id":"040e5ad4-d42d-42f8-a7c0-b7eb2d12b616","type":"transcript","start":"PT37M3.295S","end":"PT37M7.64S","eventData":{
        "type":"caption","language":"en","text":"short-term and crisis management\r\nwas the agenda of the day, has"
      },"hidden":False,"userData":"null"
    },{
      "id":"35a0d754-5bc0-4694-aeef-203ac4202981","type":"transcript","start":"PT37M7.64S","end":"PT37M10.8S","eventData":{
        "type":"caption","language":"en","text":"been doing some very creative\r\nthinking in helping."
      },"hidden":False,"userData":"null"
    },{
      "id":"300537ea-2338-442a-ad3d-90beb631530d","type":"transcript","start":"PT37M12.3S","end":"PT37M16.638S","eventData":{
        "type":"caption","language":"en","text":"This this, this thought process\r\nor diversification going beyond"
      },"hidden":False,"userData":"null"
    },{
      "id":"eafb8b2a-7ced-4d4e-a64e-9d22fdfc61f7","type":"transcript","start":"PT37M16.638S","end":"PT37M21.458S","eventData":{
        "type":"caption","language":"en","text":"some of our traditional sensing\r\nsolutions and looking at moving"
      },"hidden":False,"userData":"null"
    },{
      "id":"bf0a4f26-d585-4306-a2bf-9afe3d36b202","type":"transcript","start":"PT37M21.458S","end":"PT37M25.314S","eventData":{
        "type":"caption","language":"en","text":"into neighboring environments or\r\nmore insight. Smarter sensors"
      },"hidden":False,"userData":"null"
    },{
      "id":"f46f2f85-908b-48e2-9459-6d5c6e2364fd","type":"transcript","start":"PT37M25.314S","end":"PT37M27.242S","eventData":{
        "type":"caption","language":"en","text":"and software and systems."
      },"hidden":False,"userData":"null"
    },{
      "id":"62841bba-c587-4746-a44a-7a32ce622129","type":"transcript","start":"PT37M27.86S","end":"PT37M29.08S","eventData":{
        "type":"caption","language":"en","text":"On the next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"5bb8c351-8f0b-4cf2-8604-3bdba0a33034","type":"transcript","start":"PT37M33.89S","end":"PT37M38.855S","eventData":{
        "type":"caption","language":"en","text":"I have a little time lag on the\r\nclick that so we've been on a"
      },"hidden":False,"userData":"null"
    },{
      "id":"e0284a52-dd7d-4101-ae32-85c9789ea865","type":"transcript","start":"PT37M38.855S","end":"PT37M42.827S","eventData":{
        "type":"caption","language":"en","text":"journey as we split GPT in GSM.\r\nIn trying to enhance our"
      },"hidden":False,"userData":"null"
    },{
      "id":"15c10953-d179-4df0-a3c3-04947bc6b129","type":"transcript","start":"PT37M42.827S","end":"PT37M46.799S","eventData":{
        "type":"caption","language":"en","text":"traditional call GSM growth back\r\nto the levels of where GPT has"
      },"hidden":False,"userData":"null"
    },{
      "id":"63b17388-11af-497e-b33a-37199a723324","type":"transcript","start":"PT37M46.799S","end":"PT37M51.433S","eventData":{
        "type":"caption","language":"en","text":"been in the last five years and\r\na lot of those things are now"
      },"hidden":False,"userData":"null"
    },{
      "id":"11c96c43-0ca1-44cb-91e3-f8c610c93aa8","type":"transcript","start":"PT37M51.433S","end":"PT37M55.405S","eventData":{
        "type":"caption","language":"en","text":"back on track and we're having a\r\ngreat track record on with"
      },"hidden":False,"userData":"null"
    },{
      "id":"a6b3c52d-b22e-4f22-a9e1-6412c7d45506","type":"transcript","start":"PT37M55.405S","end":"PT37M56.398S","eventData":{
        "type":"caption","language":"en","text":"electrification, especially this"
      },"hidden":False,"userData":"null"
    },{
      "id":"1b04cba1-234d-4160-91c4-81d8223d6a87","type":"transcript","start":"PT37M56.398S","end":"PT37M59.44S","eventData":{
        "type":"caption","language":"en","text":"year. But the."
      },"hidden":False,"userData":"null"
    },{
      "id":"de2928fa-0396-449a-aa7f-45610ca95435","type":"transcript","start":"PT37M59.49S","end":"PT38M3.08S","eventData":{
        "type":"caption","language":"en","text":"The focus of our strategic\r\nintent with the leadership team"
      },"hidden":False,"userData":"null"
    },{
      "id":"3e74a771-4b75-4454-b6b4-430dd825ab50","type":"transcript","start":"PT38M3.08S","end":"PT38M7.388S","eventData":{
        "type":"caption","language":"en","text":"was looking beyond and trying to\r\nfind new Sam's where to expand"
      },"hidden":False,"userData":"null"
    },{
      "id":"a7f01abf-0b76-48a1-977c-8b8970d657f6","type":"transcript","start":"PT38M7.388S","end":"PT38M11.337S","eventData":{
        "type":"caption","language":"en","text":"the altar in order for it to\r\nstay relevant. Obviously Covid"
      },"hidden":False,"userData":"null"
    },{
      "id":"84cee032-ebe6-406d-9be0-ea5a16f684c9","type":"transcript","start":"PT38M11.337S","end":"PT38M14.927S","eventData":{
        "type":"caption","language":"en","text":"has left very dramatic impact\r\nlike in all other industries,"
      },"hidden":False,"userData":"null"
    },{
      "id":"9e0ff3fb-f60b-4dec-b69f-7bf717dcfe5d","type":"transcript","start":"PT38M14.927S","end":"PT38M18.876S","eventData":{
        "type":"caption","language":"en","text":"but potentially out industry is\r\nbeing hit a little harder, but"
      },"hidden":False,"userData":"null"
    },{
      "id":"2d692b54-ea39-404f-ad82-98d1e922d4c4","type":"transcript","start":"PT38M18.876S","end":"PT38M22.825S","eventData":{
        "type":"caption","language":"en","text":"we are seeing as the OEMs and\r\nour customers and governments"
      },"hidden":False,"userData":"null"
    },{
      "id":"6bc9f5fe-01ac-4271-b13f-e0aa621c5786","type":"transcript","start":"PT38M22.825S","end":"PT38M26.056S","eventData":{
        "type":"caption","language":"en","text":"comeback stimulus and incentives\r\nthat are going to accelerate."
      },"hidden":False,"userData":"null"
    },{
      "id":"01167926-716d-46ff-a2fa-bad3cedfa661","type":"transcript","start":"PT38M26.056S","end":"PT38M29.646S","eventData":{
        "type":"caption","language":"en","text":"Probably the biggest mega trend\r\nof all that is electrification"
      },"hidden":False,"userData":"null"
    },{
      "id":"34fa9be9-2204-4347-aab6-2053aa025045","type":"transcript","start":"PT38M29.646S","end":"PT38M33.862S","eventData":{
        "type":"caption","language":"en","text":"and. For those of you might\r\nbe reading yesterday, you"
      },"hidden":False,"userData":"null"
    },{
      "id":"89f33849-1310-416f-a9e1-9812ec23255d","type":"transcript","start":"PT38M33.862S","end":"PT38M36.788S","eventData":{
        "type":"caption","language":"en","text":"probably saw that\r\nannouncement in Europe where"
      },"hidden":False,"userData":"null"
    },{
      "id":"3b916baf-4470-42e1-8c05-91637ac1c38f","type":"transcript","start":"PT38M36.788S","end":"PT38M41.804S","eventData":{
        "type":"caption","language":"en","text":"1 trillion is going to be\r\ninvested by 2050 to drive 0"
      },"hidden":False,"userData":"null"
    },{
      "id":"800e0e72-5856-4512-beee-b3fce97bdb58","type":"transcript","start":"PT38M41.804S","end":"PT38M45.148S","eventData":{
        "type":"caption","language":"en","text":"carbon emission across all\r\nindustries and not just"
      },"hidden":False,"userData":"null"
    },{
      "id":"02546c44-433b-4109-b6f2-adaa16cda367","type":"transcript","start":"PT38M45.148S","end":"PT38M47.656S","eventData":{
        "type":"caption","language":"en","text":"Automotive. We are seeing\r\nincreased penetration,"
      },"hidden":False,"userData":"null"
    },{
      "id":"f8b32c9c-0622-470e-b7fe-0ea5a12b273e","type":"transcript","start":"PT38M47.656S","end":"PT38M51.418S","eventData":{
        "type":"caption","language":"en","text":"Indiana in connectivity and a\r\nlittle slowdown on the"
      },"hidden":False,"userData":"null"
    },{
      "id":"c693590d-1a78-434e-b159-6d7076a576c5","type":"transcript","start":"PT38M51.418S","end":"PT38M53.09S","eventData":{
        "type":"caption","language":"en","text":"autonomous and write sharing."
      },"hidden":False,"userData":"null"
    },{
      "id":"4cce2fb6-8be9-4e45-b87d-88a446219ec2","type":"transcript","start":"PT38M54.84S","end":"PT39M1.066S","eventData":{
        "type":"caption","language":"en","text":"Driving forces GPT is on a good\r\njourney. Doing still conserving"
      },"hidden":False,"userData":"null"
    },{
      "id":"b0e5573d-8e2f-4a8b-8f3f-c725198973bd","type":"transcript","start":"PT39M1.066S","end":"PT39M2.764S","eventData":{
        "type":"caption","language":"en","text":"share winning selectively."
      },"hidden":False,"userData":"null"
    },{
      "id":"7bc895be-4e1a-48b3-8a6e-fca64b11a85f","type":"transcript","start":"PT39M4.32S","end":"PT39M9.572S","eventData":{
        "type":"caption","language":"en","text":"Try to enhance our margins and\r\nwill be doing more of the same."
      },"hidden":False,"userData":"null"
    },{
      "id":"40e45bbb-66ab-4c26-a736-3ea6eb087154","type":"transcript","start":"PT39M9.572S","end":"PT39M14.016S","eventData":{
        "type":"caption","language":"en","text":"Going forward. GSM has had a\r\ngood star a tremendous year"
      },"hidden":False,"userData":"null"
    },{
      "id":"a668b361-e00f-4d3f-8517-472e4b732d0f","type":"transcript","start":"PT39M14.016S","end":"PT39M17.248S","eventData":{
        "type":"caption","language":"en","text":"after now on winning,\r\nelectrification and needs to"
      },"hidden":False,"userData":"null"
    },{
      "id":"ae217fc9-d040-4305-959b-667a82778fd3","type":"transcript","start":"PT39M17.248S","end":"PT39M20.884S","eventData":{
        "type":"caption","language":"en","text":"keep doubling down and the\r\nopportunities that have been"
      },"hidden":False,"userData":"null"
    },{
      "id":"3d0cef8d-970b-4d70-b208-30a21056c422","type":"transcript","start":"PT39M20.884S","end":"PT39M24.52S","eventData":{
        "type":"caption","language":"en","text":"bubbling up in the stint.\r\nDiscussions have been around"
      },"hidden":False,"userData":"null"
    },{
      "id":"94758df7-2392-42e3-909c-587a0a649d26","type":"transcript","start":"PT39M24.52S","end":"PT39M27.348S","eventData":{
        "type":"caption","language":"en","text":"connected, outdoors, passenger\r\ncars, connected tires connected."
      },"hidden":False,"userData":"null"
    },{
      "id":"ac7dfb6e-0fb5-4a72-ba9e-2a01888e63f6","type":"transcript","start":"PT39M29.23S","end":"PT39M30.43S","eventData":{
        "type":"caption","language":"en","text":"LCD fleets."
      },"hidden":False,"userData":"null"
    },{
      "id":"869de464-f2f1-4470-964b-4a1cec93bafe","type":"transcript","start":"PT39M31.47S","end":"PT39M36.486S","eventData":{
        "type":"caption","language":"en","text":"On the electrification side, we\r\nhave to keep going and enhancing"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6943a42-7735-4cd8-82fc-e4d9a9533903","type":"transcript","start":"PT39M36.486S","end":"PT39M39.678S","eventData":{
        "type":"caption","language":"en","text":"our portfolio with smarter\r\ncontactors, faster contactors"
      },"hidden":False,"userData":"null"
    },{
      "id":"ea501c28-29cb-4ce5-acf8-56f4b4d318e2","type":"transcript","start":"PT39M39.678S","end":"PT39M44.238S","eventData":{
        "type":"caption","language":"en","text":"with like power of users,\r\nsmarter E position sensors, and"
      },"hidden":False,"userData":"null"
    },{
      "id":"38ea3258-d7f3-4557-9412-36f7118853bd","type":"transcript","start":"PT39M44.238S","end":"PT39M47.886S","eventData":{
        "type":"caption","language":"en","text":"maybe expanding our same with\r\nexpanded integrate expanded"
      },"hidden":False,"userData":"null"
    },{
      "id":"62bd7e32-f211-4d4d-ae2b-0719d4a6fb44","type":"transcript","start":"PT39M47.886S","end":"PT39M52.446S","eventData":{
        "type":"caption","language":"en","text":"valves to on the thermal\r\nmanagement site. This is where"
      },"hidden":False,"userData":"null"
    },{
      "id":"14d57060-69d5-4f3d-844e-192454ca167c","type":"transcript","start":"PT39M52.446S","end":"PT39M57.462S","eventData":{
        "type":"caption","language":"en","text":"our sensor is applied on\r\nactuator valve and the idea of"
      },"hidden":False,"userData":"null"
    },{
      "id":"d8cff285-009a-4357-8734-f803aa736722","type":"transcript","start":"PT39M57.462S","end":"PT39M59.286S","eventData":{
        "type":"caption","language":"en","text":"combining these two together"
      },"hidden":False,"userData":"null"
    },{
      "id":"538c98ff-4e14-42ff-b108-54872ced9db6","type":"transcript","start":"PT39M59.286S","end":"PT40M2.78S","eventData":{
        "type":"caption","language":"en","text":"could increased. $80.00 per\r\ncassettes going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"1e7b5438-c5ce-4447-a42a-9b7604ee5ce7","type":"transcript","start":"PT40M3.97S","end":"PT40M6.658S","eventData":{
        "type":"caption","language":"en","text":"On the connectivity side,\r\ndigitalization is obviously"
      },"hidden":False,"userData":"null"
    },{
      "id":"d9428db7-033d-49ff-b827-c4ae14f65ef3","type":"transcript","start":"PT40M6.658S","end":"PT40M10.882S","eventData":{
        "type":"caption","language":"en","text":"the big theme at all our\r\ncustomers. It is driving you"
      },"hidden":False,"userData":"null"
    },{
      "id":"ad696c3e-2038-4b88-a79b-09ff1e2e4337","type":"transcript","start":"PT40M10.882S","end":"PT40M14.722S","eventData":{
        "type":"caption","language":"en","text":"profit pools. Cars are\r\nbecoming more and more a body"
      },"hidden":False,"userData":"null"
    },{
      "id":"2e33e01f-019c-413f-a899-f10a06e3cdd9","type":"transcript","start":"PT40M14.722S","end":"PT40M19.33S","eventData":{
        "type":"caption","language":"en","text":"in white, put on a battery and\r\na mega computer. So there's"
      },"hidden":False,"userData":"null"
    },{
      "id":"76f853eb-a59d-4e20-b278-bb48412a154b","type":"transcript","start":"PT40M19.33S","end":"PT40M20.866S","eventData":{
        "type":"caption","language":"en","text":"lots of applications and."
      },"hidden":False,"userData":"null"
    },{
      "id":"a09ff874-9b3f-4b0e-b845-e07e05fc478a","type":"transcript","start":"PT40M22.36S","end":"PT40M26.329S","eventData":{
        "type":"caption","language":"en","text":"Insights that that could\r\ndrive value for our customers"
      },"hidden":False,"userData":"null"
    },{
      "id":"653aa0c9-e5d8-42a5-a288-d0df4002dc41","type":"transcript","start":"PT40M26.329S","end":"PT40M31.18S","eventData":{
        "type":"caption","language":"en","text":"and for us going forward. So\r\nfocusing on a passenger car"
      },"hidden":False,"userData":"null"
    },{
      "id":"f1efd273-90f0-45ec-b24c-13c72e1990fd","type":"transcript","start":"PT40M31.18S","end":"PT40M34.708S","eventData":{
        "type":"caption","language":"en","text":"connected passenger car when\r\nI connected. Tell CBS"
      },"hidden":False,"userData":"null"
    },{
      "id":"d27f42a5-a5cb-4972-96dc-59041433a59c","type":"transcript","start":"PT40M34.708S","end":"PT40M38.236S","eventData":{
        "type":"caption","language":"en","text":"corrected tires could drive\r\nprofitable revenue models for"
      },"hidden":False,"userData":"null"
    },{
      "id":"f1f6f262-78ac-4ed2-b844-00904eb46a04","type":"transcript","start":"PT40M38.236S","end":"PT40M42.646S","eventData":{
        "type":"caption","language":"en","text":"us going forward. We will\r\nhave to pursue some more"
      },"hidden":False,"userData":"null"
    },{
      "id":"90cb30f1-7f4a-465e-b05c-3d540c220e0f","type":"transcript","start":"PT40M42.646S","end":"PT40M45.292S","eventData":{
        "type":"caption","language":"en","text":"portfolio management's hand\r\nsaid we will."
      },"hidden":False,"userData":"null"
    },{
      "id":"20fec638-f3a6-4821-9769-0556e7b5add6","type":"transcript","start":"PT40M46.93S","end":"PT40M51.586S","eventData":{
        "type":"caption","language":"en","text":"Also be looking at new ways of\r\nworking the word partnership or"
      },"hidden":False,"userData":"null"
    },{
      "id":"32ac6304-122c-4d00-9095-1f4ed88c0335","type":"transcript","start":"PT40M51.586S","end":"PT40M55.854S","eventData":{
        "type":"caption","language":"en","text":"we have our DNA is being very\r\nstrong on executing ourselves"
      },"hidden":False,"userData":"null"
    },{
      "id":"f74ff6b2-3ff4-457e-af9d-993549dd258e","type":"transcript","start":"PT40M55.854S","end":"PT40M59.346S","eventData":{
        "type":"caption","language":"en","text":"with vertical integration. But\r\nin this new arena, horizontal"
      },"hidden":False,"userData":"null"
    },{
      "id":"366cd993-6c70-43d5-801f-f1283f9a038b","type":"transcript","start":"PT40M59.346S","end":"PT41M2.838S","eventData":{
        "type":"caption","language":"en","text":"collaboration is going to be a\r\nbuzzword with partnerships,"
      },"hidden":False,"userData":"null"
    },{
      "id":"04c243cb-427a-4a2d-a34e-363c1ad426e3","type":"transcript","start":"PT41M2.838S","end":"PT41M6.33S","eventData":{
        "type":"caption","language":"en","text":"joint development agreements,\r\nmaybe jayvees. In some cases we"
      },"hidden":False,"userData":"null"
    },{
      "id":"fcbaae21-3e85-4a5e-bc27-e59631192965","type":"transcript","start":"PT41M6.33S","end":"PT41M10.598S","eventData":{
        "type":"caption","language":"en","text":"will be sharing the pain of\r\ninvestments, but also some of"
      },"hidden":False,"userData":"null"
    },{
      "id":"d80378f4-db96-4bde-8153-38aadd6d7249","type":"transcript","start":"PT41M10.598S","end":"PT41M12.15S","eventData":{
        "type":"caption","language":"en","text":"the gains potentially going"
      },"hidden":False,"userData":"null"
    },{
      "id":"a317f976-b160-45f6-b243-a82f0d943254","type":"transcript","start":"PT41M12.15S","end":"PT41M17.5S","eventData":{
        "type":"caption","language":"en","text":"forward. Within this landscape\r\nout or could grow up to 12% by"
      },"hidden":False,"userData":"null"
    },{
      "id":"3fcc7dd2-a679-4acf-8111-5e7268249e51","type":"transcript","start":"PT41M17.5S","end":"PT41M21.57S","eventData":{
        "type":"caption","language":"en","text":"2025 and 6% going forward\r\npending the choices that we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"b0744ada-3f21-494d-9087-660fcaea5f00","type":"transcript","start":"PT41M21.57S","end":"PT41M23.79S","eventData":{
        "type":"caption","language":"en","text":"make in line with the corporate"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd5bd630-f514-43d1-bbd2-966d12c81034","type":"transcript","start":"PT41M23.79S","end":"PT41M26.118S","eventData":{
        "type":"caption","language":"en","text":"strategies. The next\r\npage please."
      },"hidden":False,"userData":"null"
    },{
      "id":"4592a316-886a-443e-bd98-5aea2e973012","type":"transcript","start":"PT41M29.2S","end":"PT41M34.722S","eventData":{
        "type":"caption","language":"en","text":"As you can see, the uh, our\r\ntraditional Sam's are slowing"
      },"hidden":False,"userData":"null"
    },{
      "id":"2deab032-b756-4d0e-af8d-02bd13751b2b","type":"transcript","start":"PT41M34.722S","end":"PT41M41.75S","eventData":{
        "type":"caption","language":"en","text":"down by 2030. This is no news\r\non GPT, but the GSM ones as"
      },"hidden":False,"userData":"null"
    },{
      "id":"684a3684-a301-4925-aa34-d0e7b3e62adf","type":"transcript","start":"PT41M41.75S","end":"PT41M44.26S","eventData":{
        "type":"caption","language":"en","text":"well are achieving that too."
      },"hidden":False,"userData":"null"
    },{
      "id":"ce70e1eb-6178-44bd-a99f-cc369c7280ea","type":"transcript","start":"PT41M44.88S","end":"PT41M50.1S","eventData":{
        "type":"caption","language":"en","text":"Um, so a lot of focus is being\r\nput to try and look at new"
      },"hidden":False,"userData":"null"
    },{
      "id":"26f5b72e-42c9-40c3-b8d8-a3cabdf2438c","type":"transcript","start":"PT41M50.1S","end":"PT41M53.58S","eventData":{
        "type":"caption","language":"en","text":"science that are actually now\r\ntripling. We're getting to 23"
      },"hidden":False,"userData":"null"
    },{
      "id":"2cb7a73b-4053-4bd0-b850-591fb9c76770","type":"transcript","start":"PT41M53.58S","end":"PT41M56.712S","eventData":{
        "type":"caption","language":"en","text":"billion portfolio of areas we\r\ncould be playing in."
      },"hidden":False,"userData":"null"
    },{
      "id":"f828d213-aa1d-4975-bfeb-96d72ae106a5","type":"transcript","start":"PT41M57.31S","end":"PT42M1.22S","eventData":{
        "type":"caption","language":"en","text":"Uh, GSM obviously being the big\r\ndriver aftermarket needs a"
      },"hidden":False,"userData":"null"
    },{
      "id":"52a9c749-db3d-4c08-b4f4-a400284f1c60","type":"transcript","start":"PT42M1.22S","end":"PT42M5.13S","eventData":{
        "type":"caption","language":"en","text":"booster beyond what we do in\r\nTPMS, and there's opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"392853f4-5e50-45af-bed3-11c3f020f1e6","type":"transcript","start":"PT42M5.13S","end":"PT42M10.213S","eventData":{
        "type":"caption","language":"en","text":"there, and so is the total. If\r\nwe also added at Ada's or"
      },"hidden":False,"userData":"null"
    },{
      "id":"46290322-49db-41e7-8a66-80594838127d","type":"transcript","start":"PT42M10.213S","end":"PT42M13.732S","eventData":{
        "type":"caption","language":"en","text":"potential playing radar in\r\nautonomy for outlook, there's a"
      },"hidden":False,"userData":"null"
    },{
      "id":"c75d62b0-5b1e-489d-ab02-5d44a1e841e6","type":"transcript","start":"PT42M13.732S","end":"PT42M16.86S","eventData":{
        "type":"caption","language":"en","text":"healthy portfolio from which to\r\nchoose going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"dd288d83-9269-49d2-8caf-15fa759e6544","type":"transcript","start":"PT42M18.35S","end":"PT42M19.289S","eventData":{
        "type":"caption","language":"en","text":"Next page, please."
      },"hidden":False,"userData":"null"
    },{
      "id":"a27f214e-781b-40f6-a84c-d97a04d9f411","type":"transcript","start":"PT42M24.49S","end":"PT42M28.96S","eventData":{
        "type":"caption","language":"en","text":"And when we look at the\r\npotential revenue choices and"
      },"hidden":False,"userData":"null"
    },{
      "id":"7885e040-050e-4e45-a083-4392db4779f8","type":"transcript","start":"PT42M28.96S","end":"PT42M33.877S","eventData":{
        "type":"caption","language":"en","text":"portfolios, we can play in as we\r\nstart in 2020, unfortunately"
      },"hidden":False,"userData":"null"
    },{
      "id":"2af84f06-2c1f-4ed9-aa7f-7d4a9d623a7e","type":"transcript","start":"PT42M33.877S","end":"PT42M38.347S","eventData":{
        "type":"caption","language":"en","text":"gone backwards where 1.5 billion\r\ndollar business due to Covid."
      },"hidden":False,"userData":"null"
    },{
      "id":"6602c1df-6062-4b50-9861-a032f7413720","type":"transcript","start":"PT42M38.347S","end":"PT42M43.711S","eventData":{
        "type":"caption","language":"en","text":"But we have a path forward to\r\nget back to sustainable growth."
      },"hidden":False,"userData":"null"
    },{
      "id":"bdf6f5dc-80b1-4736-bedd-e6a4e59a273c","type":"transcript","start":"PT42M44.35S","end":"PT42M49.407S","eventData":{
        "type":"caption","language":"en","text":"Oh, and as you see in these uh\r\ncoloured buckets we are moving"
      },"hidden":False,"userData":"null"
    },{
      "id":"84c19546-09bb-4c5d-95dc-11df646b875c","type":"transcript","start":"PT42M49.407S","end":"PT42M53.686S","eventData":{
        "type":"caption","language":"en","text":"away from a little bit. Some of\r\nour traditional outdoor legacy"
      },"hidden":False,"userData":"null"
    },{
      "id":"0de60edb-7c61-4d76-9a69-2ddaec334317","type":"transcript","start":"PT42M53.686S","end":"PT42M55.242S","eventData":{
        "type":"caption","language":"en","text":"that's very driven around"
      },"hidden":False,"userData":"null"
    },{
      "id":"46d3a469-a593-4477-a276-d1a8d0a9c914","type":"transcript","start":"PT42M55.242S","end":"PT42M58.4S","eventData":{
        "type":"caption","language":"en","text":"powertrain and. Um engine\r\napplications exhaust"
      },"hidden":False,"userData":"null"
    },{
      "id":"c0ce88ca-4069-473a-9861-e7d69f0200a3","type":"transcript","start":"PT42M58.4S","end":"PT43M2S","eventData":{
        "type":"caption","language":"en","text":"applications now? Not so much\r\nbecause we're getting out of"
      },"hidden":False,"userData":"null"
    },{
      "id":"c736142b-6930-4c63-9089-f3d8974744a7","type":"transcript","start":"PT43M2S","end":"PT43M6.32S","eventData":{
        "type":"caption","language":"en","text":"them, but more because we are\r\ngrowing in other areas and as"
      },"hidden":False,"userData":"null"
    },{
      "id":"05738839-247a-4dbe-8c83-0df24cafedcf","type":"transcript","start":"PT43M6.32S","end":"PT43M11S","eventData":{
        "type":"caption","language":"en","text":"you see, the we're trying to\r\ngrow in areas where you have out"
      },"hidden":False,"userData":"null"
    },{
      "id":"5cdbbe86-2d33-4a6d-8b3b-0f821cc2c73e","type":"transcript","start":"PT43M11S","end":"PT43M14.6S","eventData":{
        "type":"caption","language":"en","text":"girls like that's driven by\r\nelectrification that gets up to"
      },"hidden":False,"userData":"null"
    },{
      "id":"6ec4dc31-67e9-46db-ac64-9775ffce0e3c","type":"transcript","start":"PT43M14.6S","end":"PT43M18.2S","eventData":{
        "type":"caption","language":"en","text":"24% potential of the portfolio\r\nby 2030. And then counter"
      },"hidden":False,"userData":"null"
    },{
      "id":"2bae84db-d72b-4550-b052-f8734ca32839","type":"transcript","start":"PT43M18.2S","end":"PT43M22.16S","eventData":{
        "type":"caption","language":"en","text":"cyclical business models that\r\nare in the aftermarket or in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"4233ac72-a41d-404e-b50b-8aa8f5966fcf","type":"transcript","start":"PT43M22.16S","end":"PT43M26.12S","eventData":{
        "type":"caption","language":"en","text":"connected world where we could\r\nactually even be playing in sass"
      },"hidden":False,"userData":"null"
    },{
      "id":"59c9dc66-75bd-407d-bb9c-597dd77fbab0","type":"transcript","start":"PT43M26.12S","end":"PT43M27.2S","eventData":{
        "type":"caption","language":"en","text":"models going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"d0531ac2-6ead-46d3-bb91-ef6048cb8e3d","type":"transcript","start":"PT43M29.1S","end":"PT43M29.85S","eventData":{
        "type":"caption","language":"en","text":"Next page."
      },"hidden":False,"userData":"null"
    },{
      "id":"3904ebe3-b58e-4fa9-9291-232398734c95","type":"transcript","start":"PT43M30.98S","end":"PT43M35.743S","eventData":{
        "type":"caption","language":"en","text":"And in line with the same\r\nslides, you've seen a corporate"
      },"hidden":False,"userData":"null"
    },{
      "id":"42c8782e-4446-4719-8a8e-0430e6e63976","type":"transcript","start":"PT43M35.743S","end":"PT43M41.372S","eventData":{
        "type":"caption","language":"en","text":"an in sensing solutions. We have\r\nto focus and markets we can try"
      },"hidden":False,"userData":"null"
    },{
      "id":"167a0343-cf0b-45f5-8278-e6ebeffbff37","type":"transcript","start":"PT43M41.372S","end":"PT43M44.403S","eventData":{
        "type":"caption","language":"en","text":"and grow in clearly\r\nelectrification and connected"
      },"hidden":False,"userData":"null"
    },{
      "id":"90acae11-746d-4570-9bc6-eeaf844e9194","type":"transcript","start":"PT43M44.403S","end":"PT43M46.135S","eventData":{
        "type":"caption","language":"en","text":"connected passenger cars in"
      },"hidden":False,"userData":"null"
    },{
      "id":"ccc19d87-4b1f-4c60-8f0c-f79e21fdf77a","type":"transcript","start":"PT43M46.135S","end":"PT43M51.404S","eventData":{
        "type":"caption","language":"en","text":"fleets. It is by Manageing\r\nactively our portfolio and"
      },"hidden":False,"userData":"null"
    },{
      "id":"a8eac60e-82f2-4484-90c6-a230ce58409f","type":"transcript","start":"PT43M51.404S","end":"PT43M55.388S","eventData":{
        "type":"caption","language":"en","text":"resources, making choices and\r\nfocusing and operating mode"
      },"hidden":False,"userData":"null"
    },{
      "id":"4230a711-e691-4fdc-bb17-bd8a4d3738c3","type":"transcript","start":"PT43M55.388S","end":"PT43M58.874S","eventData":{
        "type":"caption","language":"en","text":"could be with partnership,\r\nenhanced partnerships, maybe"
      },"hidden":False,"userData":"null"
    },{
      "id":"13e8709c-66e3-4da5-b274-dafe78de508f","type":"transcript","start":"PT43M58.874S","end":"PT44M4.352S","eventData":{
        "type":"caption","language":"en","text":"some jobs to be seen by building\r\nor continuously building a"
      },"hidden":False,"userData":"null"
    },{
      "id":"95400077-c113-4f0a-a416-4cba8105fe76","type":"transcript","start":"PT44M4.352S","end":"PT44M6.842S","eventData":{
        "type":"caption","language":"en","text":"diverse talent pool and and."
      },"hidden":False,"userData":"null"
    },{
      "id":"6d43c8e3-2567-4f11-bb0d-48e81798b31e","type":"transcript","start":"PT44M8.39S","end":"PT44M9.725S","eventData":{
        "type":"caption","language":"en","text":"Probably around the"
      },"hidden":False,"userData":"null"
    },{
      "id":"b3b58f21-f054-44e2-8ae0-badfeb03aa21","type":"transcript","start":"PT44M9.725S","end":"PT44M13.274S","eventData":{
        "type":"caption","language":"en","text":"organization. Um, allocating\r\ncapital, whether it's a"
      },"hidden":False,"userData":"null"
    },{
      "id":"f90e7b3d-094c-44b5-b26f-3642958ed8a1","type":"transcript","start":"PT44M13.274S","end":"PT44M16.506S","eventData":{
        "type":"caption","language":"en","text":"investment on equipment or\r\nManet appropriately in these"
      },"hidden":False,"userData":"null"
    },{
      "id":"ef0d1aad-0c4b-4acd-a29d-cedd427fd76f","type":"transcript","start":"PT44M16.506S","end":"PT44M18.93S","eventData":{
        "type":"caption","language":"en","text":"focus areas and obviously\r\ndriving commercial"
      },"hidden":False,"userData":"null"
    },{
      "id":"31d8b12f-9a68-4734-8da3-903d86c8cc8f","type":"transcript","start":"PT44M18.93S","end":"PT44M22.566S","eventData":{
        "type":"caption","language":"en","text":"excellence with all our\r\ncustomers. But we will also"
      },"hidden":False,"userData":"null"
    },{
      "id":"a681a28d-2190-42c6-a203-22c75bbaa3b6","type":"transcript","start":"PT44M22.566S","end":"PT44M27.414S","eventData":{
        "type":"caption","language":"en","text":"be watching out. I'll share\r\na slide at the end where our"
      },"hidden":False,"userData":"null"
    },{
      "id":"39d6d994-a49a-4566-a2de-e56b64c01ed9","type":"transcript","start":"PT44M27.414S","end":"PT44M30.242S","eventData":{
        "type":"caption","language":"en","text":"customer portfolio is\r\nchanging some of our"
      },"hidden":False,"userData":"null"
    },{
      "id":"2314bc90-d766-48d9-aa1c-bc186fa0525a","type":"transcript","start":"PT44M30.242S","end":"PT44M33.474S","eventData":{
        "type":"caption","language":"en","text":"traditional customers might\r\nnot be the ones we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"ebe25826-5acd-4c94-b0fc-d63bc7f3fb8d","type":"transcript","start":"PT44M33.474S","end":"PT44M36.706S","eventData":{
        "type":"caption","language":"en","text":"dealing with in the future,\r\nso creating new"
      },"hidden":False,"userData":"null"
    },{
      "id":"0a09e437-03cd-4424-a6e8-fc2ff90ada36","type":"transcript","start":"PT44M36.706S","end":"PT44M39.534S","eventData":{
        "type":"caption","language":"en","text":"relationships is really\r\ngoing to be key."
      },"hidden":False,"userData":"null"
    },{
      "id":"d310dc54-cbf8-426e-b15a-b0fd02e57e9d","type":"transcript","start":"PT44M41.57S","end":"PT44M42.47S","eventData":{
        "type":"caption","language":"en","text":"Next page."
      },"hidden":False,"userData":"null"
    },{
      "id":"8b270e81-ea84-49a1-93bc-8169e95b564d","type":"transcript","start":"PT44M43.95S","end":"PT44M50.102S","eventData":{
        "type":"caption","language":"en","text":"And. We took all the initiatives\r\nthat have been coming out of all"
      },"hidden":False,"userData":"null"
    },{
      "id":"1e48b3e6-1edc-4c81-b43f-fe80a276691d","type":"transcript","start":"PT44M50.102S","end":"PT44M53.621S","eventData":{
        "type":"caption","language":"en","text":"the different marketing and\r\nfront end teams and even"
      },"hidden":False,"userData":"null"
    },{
      "id":"452e9db0-cf62-4cf2-996a-ff01f8138fef","type":"transcript","start":"PT44M53.621S","end":"PT44M57.531S","eventData":{
        "type":"caption","language":"en","text":"ventures and try to rate them\r\nagainst the corporate strategy."
      },"hidden":False,"userData":"null"
    },{
      "id":"c8cbccf2-12ee-459d-b40f-261aa7118467","type":"transcript","start":"PT44M57.531S","end":"PT45M0.659S","eventData":{
        "type":"caption","language":"en","text":"Care abouts that clearly are\r\ndriving improve shareholder"
      },"hidden":False,"userData":"null"
    },{
      "id":"b58974b5-d371-45ae-b076-c217823a754f","type":"transcript","start":"PT45M0.659S","end":"PT45M4.178S","eventData":{
        "type":"caption","language":"en","text":"return, diversifying in markets\r\nwhere they could be broader"
      },"hidden":False,"userData":"null"
    },{
      "id":"14dfbd56-7d79-4028-9a3c-2dd4a8212fdf","type":"transcript","start":"PT45M4.178S","end":"PT45M7.697S","eventData":{
        "type":"caption","language":"en","text":"sense outta synergies. An\r\nobviously what's the kind of"
      },"hidden":False,"userData":"null"
    },{
      "id":"d16648ea-100c-4ff5-884e-9d50da0463e9","type":"transcript","start":"PT45M7.697S","end":"PT45M12.78S","eventData":{
        "type":"caption","language":"en","text":"effort or investment we have to\r\nput in to get to that revenue."
      },"hidden":False,"userData":"null"
    },{
      "id":"03ab18c5-87e7-4a81-93f3-0c81b2e70a80","type":"transcript","start":"PT45M13.54S","end":"PT45M17.037S","eventData":{
        "type":"caption","language":"en","text":"And you can see that on the top\r\nthree lines that's really around"
      },"hidden":False,"userData":"null"
    },{
      "id":"96f2852d-675e-4a37-aa86-224aa290721b","type":"transcript","start":"PT45M17.037S","end":"PT45M20.534S","eventData":{
        "type":"caption","language":"en","text":"safety. It is. These are all\r\ngood areas for out, or there's a"
      },"hidden":False,"userData":"null"
    },{
      "id":"3c478848-285d-4cd6-8f4a-235b339b2409","type":"transcript","start":"PT45M20.534S","end":"PT45M23.762S","eventData":{
        "type":"caption","language":"en","text":"little less energy in some of\r\nthe other businesses and we will"
      },"hidden":False,"userData":"null"
    },{
      "id":"aed7a973-1c64-4b89-960d-af042fd5da4f","type":"transcript","start":"PT45M23.762S","end":"PT45M26.721S","eventData":{
        "type":"caption","language":"en","text":"carry on doing these with.\r\nFunded in Ari from customers, as"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6f6ee79-8f68-447c-8534-9e9630f30834","type":"transcript","start":"PT45M26.721S","end":"PT45M28.335S","eventData":{
        "type":"caption","language":"en","text":"the team has been successful up"
      },"hidden":False,"userData":"null"
    },{
      "id":"2a873af5-a3cc-4fa2-927a-d10d01977eea","type":"transcript","start":"PT45M28.335S","end":"PT45M33.162S","eventData":{
        "type":"caption","language":"en","text":"to now. But the the winners or\r\npotential winners in this"
      },"hidden":False,"userData":"null"
    },{
      "id":"ac203b39-250e-4ea4-bdf2-c52a60c01dfa","type":"transcript","start":"PT45M33.162S","end":"PT45M36.834S","eventData":{
        "type":"caption","language":"en","text":"selection, other ones in the\r\nyellow boxes where integrated"
      },"hidden":False,"userData":"null"
    },{
      "id":"d5126f6d-fda7-45b4-9d60-89b476f8d8ce","type":"transcript","start":"PT45M36.834S","end":"PT45M40.914S","eventData":{
        "type":"caption","language":"en","text":"expansion valves with P plus the\r\nsensors, is a plane"
      },"hidden":False,"userData":"null"
    },{
      "id":"5e494440-c641-4cf4-92f2-38d94ba0e08f","type":"transcript","start":"PT45M40.914S","end":"PT45M43.77S","eventData":{
        "type":"caption","language":"en","text":"electrification aftermarket\r\ncould help us diversify. Then"
      },"hidden":False,"userData":"null"
    },{
      "id":"d1a7a816-ad60-4a3b-971e-14e2f0a14ef7","type":"transcript","start":"PT45M43.77S","end":"PT45M48.666S","eventData":{
        "type":"caption","language":"en","text":"going beyond what we do in TPMS\r\ncollective tires and TMS with"
      },"hidden":False,"userData":"null"
    },{
      "id":"f7084bb1-f6dc-4fd9-9830-a0b5839c40bf","type":"transcript","start":"PT45M48.666S","end":"PT45M53.154S","eventData":{
        "type":"caption","language":"en","text":"models would be something that\r\nleads one of the big corporate"
      },"hidden":False,"userData":"null"
    },{
      "id":"ea42b758-4ad5-4681-a9f7-4d3569b73887","type":"transcript","start":"PT45M53.154S","end":"PT45M57.642S","eventData":{
        "type":"caption","language":"en","text":"themes and the same for\r\nconnected out of on the LCD"
      },"hidden":False,"userData":"null"
    },{
      "id":"86cdc4e7-b90e-4641-9754-12bef00e4bc6","type":"transcript","start":"PT45M57.642S","end":"PT46M2.13S","eventData":{
        "type":"caption","language":"en","text":"side. We are keeping his option\r\ntickets radar trying to find"
      },"hidden":False,"userData":"null"
    },{
      "id":"a4df50a6-53cf-4431-a520-4e36185a18bf","type":"transcript","start":"PT46M2.13S","end":"PT46M3.354S","eventData":{
        "type":"caption","language":"en","text":"whether we have."
      },"hidden":False,"userData":"null"
    },{
      "id":"be8a1834-05c6-4f1e-afd7-a2e3539071af","type":"transcript","start":"PT46M3.42S","end":"PT46M6.372S","eventData":{
        "type":"caption","language":"en","text":"Uh, and entitlement to play, and\r\nwhether there's Duff"
      },"hidden":False,"userData":"null"
    },{
      "id":"fa647e3f-1855-4117-941c-a21db7ca79c0","type":"transcript","start":"PT46M6.372S","end":"PT46M10.308S","eventData":{
        "type":"caption","language":"en","text":"Differentiation in the outer\r\nworld. Also to be able to do do"
      },"hidden":False,"userData":"null"
    },{
      "id":"569b3b79-24a9-47b8-adfe-fcf0bd30ea9e","type":"transcript","start":"PT46M10.308S","end":"PT46M11.62S","eventData":{
        "type":"caption","language":"en","text":"something in this arena."
      },"hidden":False,"userData":"null"
    },{
      "id":"aa556d3d-0c8c-40b2-9ac9-8632854ea872","type":"transcript","start":"PT46M12.97S","end":"PT46M13.938S","eventData":{
        "type":"caption","language":"en","text":"On the next page."
      },"hidden":False,"userData":"null"
    },{
      "id":"a53e2486-91a4-44d0-82ae-b71f20a14052","type":"transcript","start":"PT46M15.97S","end":"PT46M20.086S","eventData":{
        "type":"caption","language":"en","text":"This visualizes it's a busy\r\nslide. A lot of logos, but it"
      },"hidden":False,"userData":"null"
    },{
      "id":"f573ae2b-2ae5-421d-9d96-df1d31133985","type":"transcript","start":"PT46M20.086S","end":"PT46M24.545S","eventData":{
        "type":"caption","language":"en","text":"does talk to a little bit what's\r\nhappening in our industry and it"
      },"hidden":False,"userData":"null"
    },{
      "id":"5cab40b0-dcfe-4725-87d0-79e78e5d0a9e","type":"transcript","start":"PT46M24.545S","end":"PT46M28.318S","eventData":{
        "type":"caption","language":"en","text":"is intensifying day after day.\r\nWe see customers tying up with"
      },"hidden":False,"userData":"null"
    },{
      "id":"b9490b64-a083-411f-9e47-18b5711384b7","type":"transcript","start":"PT46M28.318S","end":"PT46M31.062S","eventData":{
        "type":"caption","language":"en","text":"each other or on sharing\r\ntechnology and platforms."
      },"hidden":False,"userData":"null"
    },{
      "id":"249e8f9f-6bd3-40fd-af8d-ea18f8ea50f5","type":"transcript","start":"PT46M31.96S","end":"PT46M36.437S","eventData":{
        "type":"caption","language":"en","text":"Uh, we see in the middle box\r\ntechnology players tying up"
      },"hidden":False,"userData":"null"
    },{
      "id":"c8ab8baf-27a1-4bd8-a975-45daf890aec9","type":"transcript","start":"PT46M36.437S","end":"PT46M40.507S","eventData":{
        "type":"caption","language":"en","text":"either with our customers or\r\nbetween themselves and on the"
      },"hidden":False,"userData":"null"
    },{
      "id":"c5768261-a9f5-4dd7-a808-718ffb63c3d7","type":"transcript","start":"PT46M40.507S","end":"PT46M45.391S","eventData":{
        "type":"caption","language":"en","text":"bottom line we see merges and\r\nwe'll probably see more of those"
      },"hidden":False,"userData":"null"
    },{
      "id":"fc19cb3d-7d7d-401f-bf6c-2a8699f6d7df","type":"transcript","start":"PT46M45.391S","end":"PT46M49.054S","eventData":{
        "type":"caption","language":"en","text":"for sharing platform but also\r\ncreating scale and enhance"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b5fa2e9-c261-49c9-9d28-911236d74634","type":"transcript","start":"PT46M49.054S","end":"PT46M53.938S","eventData":{
        "type":"caption","language":"en","text":"profitability. And when you look\r\nat the right side of the box"
      },"hidden":False,"userData":"null"
    },{
      "id":"edf68be0-4dea-4c74-b83f-f340024c36f1","type":"transcript","start":"PT46M53.938S","end":"PT46M58.822S","eventData":{
        "type":"caption","language":"en","text":"since other could be playing in\r\nsome of these similar arenas in"
      },"hidden":False,"userData":"null"
    },{
      "id":"d341f41e-f312-4134-bd33-dfecb755fac7","type":"transcript","start":"PT46M58.822S","end":"PT47M2.078S","eventData":{
        "type":"caption","language":"en","text":"China may be looking at\r\npartnerships with psych."
      },"hidden":False,"userData":"null"
    },{
      "id":"c2cd348c-9957-42b8-844a-20840368e5ff","type":"transcript","start":"PT47M2.17S","end":"PT47M9.286S","eventData":{
        "type":"caption","language":"en","text":"Uh, to that could enhance us\r\nin, um, in GSM edas and"
      },"hidden":False,"userData":"null"
    },{
      "id":"2f97b36a-f2c3-4714-a7a1-6db4ab0d168a","type":"transcript","start":"PT47M9.286S","end":"PT47M14.12S","eventData":{
        "type":"caption","language":"en","text":"TMS applications. On the\r\nsoftware side, in the middle box"
      },"hidden":False,"userData":"null"
    },{
      "id":"a87e4261-7db1-4b79-99fd-83235862d36c","type":"transcript","start":"PT47M14.12S","end":"PT47M17.97S","eventData":{
        "type":"caption","language":"en","text":"and technology we have a JDA\r\nsign with NYRA where we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"2c39f486-75be-476b-b3d2-7e9c34bceaac","type":"transcript","start":"PT47M17.97S","end":"PT47M20.42S","eventData":{
        "type":"caption","language":"en","text":"collaborating on I tread\r\nsoftware development for"
      },"hidden":False,"userData":"null"
    },{
      "id":"7a4897df-c4cb-47a7-a6d8-918c541ebe32","type":"transcript","start":"PT47M20.42S","end":"PT47M23.92S","eventData":{
        "type":"caption","language":"en","text":"treadwear. That, combined with a\r\nsensor, gives a much higher"
      },"hidden":False,"userData":"null"
    },{
      "id":"d3d45b38-8d88-4883-983f-ed2f24294384","type":"transcript","start":"PT47M23.92S","end":"PT47M25.32S","eventData":{
        "type":"caption","language":"en","text":"accuracy in defining treadwear."
      },"hidden":False,"userData":"null"
    },{
      "id":"477c4c9c-70d2-4b31-a0b6-fe75aaf51d53","type":"transcript","start":"PT47M25.91S","end":"PT47M29.32S","eventData":{
        "type":"caption","language":"en","text":"This could lead to use as models\r\nand other applications cross"
      },"hidden":False,"userData":"null"
    },{
      "id":"1df0e9d1-8197-480f-ad66-9d935faacddb","type":"transcript","start":"PT47M29.32S","end":"PT47M33.958S","eventData":{
        "type":"caption","language":"en","text":"industry. And we have our our,\r\nour traditional customers like"
      },"hidden":False,"userData":"null"
    },{
      "id":"2df1fd28-f68b-4c48-8ef7-9262c114c3fd","type":"transcript","start":"PT47M33.958S","end":"PT47M36.772S","eventData":{
        "type":"caption","language":"en","text":"Continental Denzel Ware,\r\nspecially post covid. There's"
      },"hidden":False,"userData":"null"
    },{
      "id":"40b8d977-38cb-43c2-8247-2a962a48c719","type":"transcript","start":"PT47M36.772S","end":"PT47M40.39S","eventData":{
        "type":"caption","language":"en","text":"opportunities for looking at\r\ncombining or taking over some"
      },"hidden":False,"userData":"null"
    },{
      "id":"1f6576c7-30d3-4166-9c97-7d1451ea7f31","type":"transcript","start":"PT47M40.39S","end":"PT47M44.008S","eventData":{
        "type":"caption","language":"en","text":"of their capacity. You know\r\nwin win situation because"
      },"hidden":False,"userData":"null"
    },{
      "id":"a63d6835-ae86-4a1f-b124-a7ce2ba4ad71","type":"transcript","start":"PT47M44.008S","end":"PT47M47.626S","eventData":{
        "type":"caption","language":"en","text":"maybe it's not called for them\r\nanymore going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"c65fe3f9-5c2c-4a35-bb61-dabbf286f842","type":"transcript","start":"PT47M49.26S","end":"PT47M51.81S","eventData":{
        "type":"caption","language":"en","text":"The index page I think\r\nthat was the last one."
      },"hidden":False,"userData":"null"
    },{
      "id":"d05163c8-a495-43ee-88ab-f618a0d46327","type":"transcript","start":"PT47M53.1S","end":"PT47M54.86S","eventData":{
        "type":"caption","language":"en","text":"Yeah, that was the last\r\npage. Thank you."
      },"hidden":False,"userData":"null"
    },{
      "id":"a21083e0-7caf-4de1-ba20-f62fa8d38bdc","type":"transcript","start":"PT47M57.44S","end":"PT47M58.46S","eventData":{
        "type":"caption","language":"en","text":"And with George."
      },"hidden":False,"userData":"null"
    },{
      "id":"8bebe1ca-764b-404d-8c82-049c0797f6a9","type":"transcript","start":"PT48M1.33S","end":"PT48M3.045S","eventData":{
        "type":"caption","language":"en","text":"All right, thanks Paulo, great"
      },"hidden":False,"userData":"null"
    },{
      "id":"4309fe37-2c11-44aa-b493-eec3646ed4d5","type":"transcript","start":"PT48M3.045S","end":"PT48M7.535S","eventData":{
        "type":"caption","language":"en","text":"job. Hi everyone, I'm George\r\nFerris. I lead up R Us inside"
      },"hidden":False,"userData":"null"
    },{
      "id":"2b0f29ba-61fb-466d-9363-6ad7a8f98b52","type":"transcript","start":"PT48M7.535S","end":"PT48M10.685S","eventData":{
        "type":"caption","language":"en","text":"Adventures team and uh, I'm\r\nreally excited to have the"
      },"hidden":False,"userData":"null"
    },{
      "id":"bf77441e-ba31-41e6-a9c0-2326215fddcd","type":"transcript","start":"PT48M10.685S","end":"PT48M14.15S","eventData":{
        "type":"caption","language":"en","text":"opportunity today to talk to the\r\nbroader team about all the"
      },"hidden":False,"userData":"null"
    },{
      "id":"06b6cf84-d201-4aac-b28b-e032c5f1efc7","type":"transcript","start":"PT48M14.15S","end":"PT48M16.985S","eventData":{
        "type":"caption","language":"en","text":"exciting things that are\r\nhappening in ventures and across"
      },"hidden":False,"userData":"null"
    },{
      "id":"5b6d8165-7cf2-461a-b0e0-477c383d78cd","type":"transcript","start":"PT48M16.985S","end":"PT48M19.505S","eventData":{
        "type":"caption","language":"en","text":"the company in our\r\nelectrification and Smart and"
      },"hidden":False,"userData":"null"
    },{
      "id":"279c7eef-d038-4b45-a931-0d2ac1d47209","type":"transcript","start":"PT48M19.505S","end":"PT48M22.42S","eventData":{
        "type":"caption","language":"en","text":"connected initiatives. So we\r\ncan go to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"93b61941-dc6b-4f26-9d35-2961cbc75fa5","type":"transcript","start":"PT48M23.81S","end":"PT48M27.792S","eventData":{
        "type":"caption","language":"en","text":"First, let's talk about some\r\nside adventures, so I get the"
      },"hidden":False,"userData":"null"
    },{
      "id":"966bd3d1-b6cd-43d4-9b1e-2157772aec46","type":"transcript","start":"PT48M27.792S","end":"PT48M31.774S","eventData":{
        "type":"caption","language":"en","text":"question a lot. What is ventures\r\nSimply put inside adventures is"
      },"hidden":False,"userData":"null"
    },{
      "id":"093fcc17-5df7-406b-901a-c4ab637bf465","type":"transcript","start":"PT48M31.774S","end":"PT48M33.584S","eventData":{
        "type":"caption","language":"en","text":"an incubation engine for the"
      },"hidden":False,"userData":"null"
    },{
      "id":"ef4f242b-350a-41de-bb0d-7a312aaebcd0","type":"transcript","start":"PT48M33.584S","end":"PT48M39.641S","eventData":{
        "type":"caption","language":"en","text":"company. And our goal is to take\r\nmany ideas and really narrow"
      },"hidden":False,"userData":"null"
    },{
      "id":"caec03a2-2aac-4818-a25d-d3a22dd89e50","type":"transcript","start":"PT48M39.641S","end":"PT48M44.602S","eventData":{
        "type":"caption","language":"en","text":"them down and then scale them\r\ninto a few successful new"
      },"hidden":False,"userData":"null"
    },{
      "id":"e6537200-1391-4d46-b1c0-4f5e8f1d077a","type":"transcript","start":"PT48M44.602S","end":"PT48M47.759S","eventData":{
        "type":"caption","language":"en","text":"businesses within syncada that\r\ndelivered differentiated value."
      },"hidden":False,"userData":"null"
    },{
      "id":"19e6fd69-7975-435e-bfc9-07e0fb16e90f","type":"transcript","start":"PT48M48.33S","end":"PT48M53.19S","eventData":{
        "type":"caption","language":"en","text":"And it's important that you\r\nknow, we think about this as a"
      },"hidden":False,"userData":"null"
    },{
      "id":"89f9689a-c9d3-419b-9209-9d58ce68196b","type":"transcript","start":"PT48M53.19S","end":"PT48M56.43S","eventData":{
        "type":"caption","language":"en","text":"transformation process in a\r\npipeline. It's really taking"
      },"hidden":False,"userData":"null"
    },{
      "id":"4e5596c4-f0e9-4667-b5ec-6570efd74346","type":"transcript","start":"PT48M56.43S","end":"PT49M0.48S","eventData":{
        "type":"caption","language":"en","text":"many ideas, scaling a few of\r\nthem, transforming them, and"
      },"hidden":False,"userData":"null"
    },{
      "id":"5e2578cb-30ce-4646-bffa-4d7f83328845","type":"transcript","start":"PT49M0.48S","end":"PT49M4.935S","eventData":{
        "type":"caption","language":"en","text":"turning him into businesses that\r\ncan achieve a scale of 300"
      },"hidden":False,"userData":"null"
    },{
      "id":"a36866de-4eea-4cb1-a897-ad9d617ba367","type":"transcript","start":"PT49M4.935S","end":"PT49M9.39S","eventData":{
        "type":"caption","language":"en","text":"million or greater in revenue\r\nwithin within a few years. And"
      },"hidden":False,"userData":"null"
    },{
      "id":"6a887928-0068-4f57-8271-ff23d2820245","type":"transcript","start":"PT49M9.39S","end":"PT49M13.44S","eventData":{
        "type":"caption","language":"en","text":"we do this by really deeply\r\nunderstanding the markets and"
      },"hidden":False,"userData":"null"
    },{
      "id":"2c1383f4-7b3b-4c2b-91a4-48703d6b2bce","type":"transcript","start":"PT49M13.44S","end":"PT49M17.895S","eventData":{
        "type":"caption","language":"en","text":"the ecosystems that our teams\r\nare working in and focusing on"
      },"hidden":False,"userData":"null"
    },{
      "id":"316b5719-5e11-4c38-8365-abb8ced0aca2","type":"transcript","start":"PT49M17.895S","end":"PT49M19.92S","eventData":{
        "type":"caption","language":"en","text":"driving solutions with with our"
      },"hidden":False,"userData":"null"
    },{
      "id":"30ae3251-e57b-4643-9558-0ba96525389d","type":"transcript","start":"PT49M19.92S","end":"PT49M24.942S","eventData":{
        "type":"caption","language":"en","text":"customers. The key to being\r\nsuccessful is taking a fast"
      },"hidden":False,"userData":"null"
    },{
      "id":"7fcf15f9-e616-4868-a211-09eb26ae282e","type":"transcript","start":"PT49M24.942S","end":"PT49M28.884S","eventData":{
        "type":"caption","language":"en","text":"agile approach to launching\r\nthese new ventures. It's really"
      },"hidden":False,"userData":"null"
    },{
      "id":"2c6abdd1-2581-4c84-ac4c-f051dcfbdd83","type":"transcript","start":"PT49M28.884S","end":"PT49M33.264S","eventData":{
        "type":"caption","language":"en","text":"about having an independent and\r\nempowered team enabling them to"
      },"hidden":False,"userData":"null"
    },{
      "id":"04ec3bd0-6eb2-4b20-868e-6a4fa2d06670","type":"transcript","start":"PT49M33.264S","end":"PT49M36.768S","eventData":{
        "type":"caption","language":"en","text":"drive for results, and then\r\ncontinually learning and"
      },"hidden":False,"userData":"null"
    },{
      "id":"bc477323-e5bb-4784-b79d-e076c20c86fd","type":"transcript","start":"PT49M36.768S","end":"PT49M40.71S","eventData":{
        "type":"caption","language":"en","text":"adapting our approach. That's\r\nour mission in inside Avengers,"
      },"hidden":False,"userData":"null"
    },{
      "id":"85d97f2e-2b4f-4a3f-b21a-7f0ff55bd543","type":"transcript","start":"PT49M40.71S","end":"PT49M44.214S","eventData":{
        "type":"caption","language":"en","text":"so if we go to the next page."
      },"hidden":False,"userData":"null"
    },{
      "id":"ac74514b-c1ba-4f81-b8e2-50d7a0378945","type":"transcript","start":"PT49M45.06S","end":"PT49M48.78S","eventData":{
        "type":"caption","language":"en","text":"You can see here listed the\r\nthree incubation projects that"
      },"hidden":False,"userData":"null"
    },{
      "id":"a19938ac-bb8d-4eb8-b726-f39ef3539e34","type":"transcript","start":"PT49M48.78S","end":"PT49M51.384S","eventData":{
        "type":"caption","language":"en","text":"we currently have, an\r\nelectrification, smart and"
      },"hidden":False,"userData":"null"
    },{
      "id":"16768b11-85d5-41c7-9e12-228088e9a80c","type":"transcript","start":"PT49M51.384S","end":"PT49M54.36S","eventData":{
        "type":"caption","language":"en","text":"connected, and autonomy. We're\r\nworking with battery management"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4e8c70f-de92-4185-bd41-50792e63de24","type":"transcript","start":"PT49M54.36S","end":"PT49M58.08S","eventData":{
        "type":"caption","language":"en","text":"systems under electrification.\r\nOne of the key things that we've"
      },"hidden":False,"userData":"null"
    },{
      "id":"d0eaf8a5-733b-4cc8-83dc-02c2332a6955","type":"transcript","start":"PT49M58.08S","end":"PT50M0.312S","eventData":{
        "type":"caption","language":"en","text":"done there is required to come."
      },"hidden":False,"userData":"null"
    },{
      "id":"dba67bba-4d7e-4950-93c9-e3592f41c0ae","type":"transcript","start":"PT50M0.39S","end":"PT50M5.582S","eventData":{
        "type":"caption","language":"en","text":"We called our made an investment\r\nin a company called Lithium"
      },"hidden":False,"userData":"null"
    },{
      "id":"bfb36504-9338-457a-8eba-6c247b11bc95","type":"transcript","start":"PT50M5.582S","end":"PT50M10.774S","eventData":{
        "type":"caption","language":"en","text":"balance and we will become the\r\nmajority owners in 2021 and"
      },"hidden":False,"userData":"null"
    },{
      "id":"58e625da-ade0-47ef-9346-5d2cf11011ca","type":"transcript","start":"PT50M10.774S","end":"PT50M15.966S","eventData":{
        "type":"caption","language":"en","text":"that's really kicked off our\r\nability to deliver a BMS system"
      },"hidden":False,"userData":"null"
    },{
      "id":"48195652-a82d-47b3-b821-d280d822616d","type":"transcript","start":"PT50M15.966S","end":"PT50M17.854S","eventData":{
        "type":"caption","language":"en","text":"into the Greater electrification"
      },"hidden":False,"userData":"null"
    },{
      "id":"f5515109-f018-4320-9b83-1d9a3d10cde2","type":"transcript","start":"PT50M17.854S","end":"PT50M22.132S","eventData":{
        "type":"caption","language":"en","text":"ecosystem. We have an internal\r\norganic development in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"85faf38d-8cbb-4059-9791-ce78411c5b94","type":"transcript","start":"PT50M22.132S","end":"PT50M25.588S","eventData":{
        "type":"caption","language":"en","text":"wireless hub for smart and\r\nconnected focusing. Initially on"
      },"hidden":False,"userData":"null"
    },{
      "id":"f2db4797-dc5d-4f94-9cff-9ad7e9ccb175","type":"transcript","start":"PT50M25.588S","end":"PT50M30.196S","eventData":{
        "type":"caption","language":"en","text":"heavy vehicle fleets and then in\r\nautonomy. You can see we've made"
      },"hidden":False,"userData":"null"
    },{
      "id":"35fe3b6d-abba-48d4-b9d9-5bfbbf558125","type":"transcript","start":"PT50M30.196S","end":"PT50M34.036S","eventData":{
        "type":"caption","language":"en","text":"a recent acquisition with Rico\r\nand we're continuing to expand"
      },"hidden":False,"userData":"null"
    },{
      "id":"806f6687-e303-480d-be30-53d2c518b29d","type":"transcript","start":"PT50M34.036S","end":"PT50M37.876S","eventData":{
        "type":"caption","language":"en","text":"in radar by looking at bringing\r\ndigital radar digital imaging"
      },"hidden":False,"userData":"null"
    },{
      "id":"24d46dfe-d45d-4a07-8d4c-69d37f61a37f","type":"transcript","start":"PT50M37.876S","end":"PT50M42.1S","eventData":{
        "type":"caption","language":"en","text":"technology into Syncada and then\r\nunderneath each one of the three"
      },"hidden":False,"userData":"null"
    },{
      "id":"abbf4626-410e-4b9a-bdda-67f8926f3359","type":"transcript","start":"PT50M42.1S","end":"PT50M45.94S","eventData":{
        "type":"caption","language":"en","text":"major megatrends you can see\r\nsome of the different pipeline"
      },"hidden":False,"userData":"null"
    },{
      "id":"250a054c-c503-4ee0-88f6-74d2ccb36988","type":"transcript","start":"PT50M45.94S","end":"PT50M50.932S","eventData":{
        "type":"caption","language":"en","text":"activity that we have going on\r\nin order to keep a healthy flow"
      },"hidden":False,"userData":"null"
    },{
      "id":"ab5d54c0-7ca6-4af1-b424-da1645475771","type":"transcript","start":"PT50M50.932S","end":"PT50M54.79S","eventData":{
        "type":"caption","language":"en","text":"of opportunities. Coming into\r\nSyncada and then at the bottom"
      },"hidden":False,"userData":"null"
    },{
      "id":"5472f1dc-4356-4471-87c1-758eef7b5327","type":"transcript","start":"PT50M54.79S","end":"PT50M59.83S","eventData":{
        "type":"caption","language":"en","text":"you can see at the bottom of the\r\npage those are the tenants of"
      },"hidden":False,"userData":"null"
    },{
      "id":"4422897f-9f43-4c60-86f9-b0c7a4d6ff35","type":"transcript","start":"PT50M59.83S","end":"PT51M3.79S","eventData":{
        "type":"caption","language":"en","text":"how we try to strive to work\r\nwith inside adventures about"
      },"hidden":False,"userData":"null"
    },{
      "id":"9963ea17-530e-4e53-b280-022cde5f5fae","type":"transcript","start":"PT51M3.79S","end":"PT51M7.39S","eventData":{
        "type":"caption","language":"en","text":"risk, reach, reward, empower\r\nship speed and agility and then"
      },"hidden":False,"userData":"null"
    },{
      "id":"23814f59-c85f-4aaa-bdbb-949d3c04442b","type":"transcript","start":"PT51M7.39S","end":"PT51M10.99S","eventData":{
        "type":"caption","language":"en","text":"being a learning and adapting\r\norganization. So with that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4bd9eb4-bbd6-4fca-9f55-8b71c11c561b","type":"transcript","start":"PT51M10.99S","end":"PT51M13.15S","eventData":{
        "type":"caption","language":"en","text":"can move to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"995fd7ab-a211-4e7c-a849-4942ccf05155","type":"transcript","start":"PT51M13.75S","end":"PT51M16.63S","eventData":{
        "type":"caption","language":"en","text":"We're going to talk about our"
      },"hidden":False,"userData":"null"
    },{
      "id":"1b9ec60b-b4d6-4283-a7e7-4f014ef0b440","type":"transcript","start":"PT51M16.63S","end":"PT51M20.16S","eventData":{
        "type":"caption","language":"en","text":"electrification initiative. So\r\nthis electrification megatrend"
      },"hidden":False,"userData":"null"
    },{
      "id":"adfaae26-21b5-49ba-989f-28224a8b4e02","type":"transcript","start":"PT51M20.16S","end":"PT51M22.41S","eventData":{
        "type":"caption","language":"en","text":"is critically important to our"
      },"hidden":False,"userData":"null"
    },{
      "id":"a27dae22-6b52-4e4a-b2e1-f85d925723d9","type":"transcript","start":"PT51M22.41S","end":"PT51M27.006S","eventData":{
        "type":"caption","language":"en","text":"company's future. When we think\r\nabout the mega trends affecting"
      },"hidden":False,"userData":"null"
    },{
      "id":"b3cb9c2f-a23a-439e-b270-5fc31198a112","type":"transcript","start":"PT51M27.006S","end":"PT51M30.933S","eventData":{
        "type":"caption","language":"en","text":"our end markets, electrification\r\nis one of the biggest ones. It's"
      },"hidden":False,"userData":"null"
    },{
      "id":"e3644c16-cbbf-48c6-ae6a-5092ccfa40b4","type":"transcript","start":"PT51M30.933S","end":"PT51M35.217S","eventData":{
        "type":"caption","language":"en","text":"affecting all of our markets,\r\nit's reshaping them as we as we"
      },"hidden":False,"userData":"null"
    },{
      "id":"9e7302f0-2c91-4917-bda9-1106a2c3f7a7","type":"transcript","start":"PT51M35.217S","end":"PT51M39.501S","eventData":{
        "type":"caption","language":"en","text":"speak. The good news is that\r\nwith our current product, so we"
      },"hidden":False,"userData":"null"
    },{
      "id":"a9e84dbc-2cc4-4210-bd59-5e0908c3cf30","type":"transcript","start":"PT51M39.501S","end":"PT51M43.785S","eventData":{
        "type":"caption","language":"en","text":"have a very large market. You\r\ncan see there are 26 billion"
      },"hidden":False,"userData":"null"
    },{
      "id":"e8635a65-51c5-4920-b90a-e00d68797fbb","type":"transcript","start":"PT51M43.785S","end":"PT51M48.069S","eventData":{
        "type":"caption","language":"en","text":"dollars that our products and\r\nour teams work in, and it's a"
      },"hidden":False,"userData":"null"
    },{
      "id":"b4b54e32-25f9-4205-af9e-c28b57e3980e","type":"transcript","start":"PT51M48.069S","end":"PT51M52.353S","eventData":{
        "type":"caption","language":"en","text":"really big and exciting space\r\nfor us inside, and one that I"
      },"hidden":False,"userData":"null"
    },{
      "id":"4eb05b78-3dac-4a79-af97-f26c03d6c8bc","type":"transcript","start":"PT51M52.353S","end":"PT51M56.637S","eventData":{
        "type":"caption","language":"en","text":"think we all believe in strongly\r\nand know that we can be"
      },"hidden":False,"userData":"null"
    },{
      "id":"2f759c42-92ca-4f7f-9b6a-5bdd79333fdc","type":"transcript","start":"PT51M56.637S","end":"PT52M1.66S","eventData":{
        "type":"caption","language":"en","text":"successful in. And then when you\r\nlook at the new projects that"
      },"hidden":False,"userData":"null"
    },{
      "id":"9993c91b-ce67-4c65-881c-c54c2ee6c5c8","type":"transcript","start":"PT52M1.66S","end":"PT52M5.08S","eventData":{
        "type":"caption","language":"en","text":"we're launching, we have the\r\npotential to intercept intercept"
      },"hidden":False,"userData":"null"
    },{
      "id":"d00bbb5d-bc39-4c2b-abf4-b556b8b8d78f","type":"transcript","start":"PT52M5.08S","end":"PT52M9.26S","eventData":{
        "type":"caption","language":"en","text":"an additional 20 billion dollar\r\nSam by 2030. So as, as"
      },"hidden":False,"userData":"null"
    },{
      "id":"3e9aa490-51ed-40c8-a2b6-eab5f0f099e3","type":"transcript","start":"PT52M9.26S","end":"PT52M12.3S","eventData":{
        "type":"caption","language":"en","text":"everybody's been saying, You\r\nknow we're not opportunity"
      },"hidden":False,"userData":"null"
    },{
      "id":"f6367267-f18f-4b4a-8d28-8664e42ffde7","type":"transcript","start":"PT52M12.3S","end":"PT52M15.34S","eventData":{
        "type":"caption","language":"en","text":"limited, it's really about\r\nfocusing and trying to"
      },"hidden":False,"userData":"null"
    },{
      "id":"eb12093a-0508-4641-8b3b-2dceb1dd5446","type":"transcript","start":"PT52M15.34S","end":"PT52M19.52S","eventData":{
        "type":"caption","language":"en","text":"understand what should we work\r\non. So our strategy today is"
      },"hidden":False,"userData":"null"
    },{
      "id":"28b91e0b-2213-4732-a656-c89e2a270584","type":"transcript","start":"PT52M19.52S","end":"PT52M23.32S","eventData":{
        "type":"caption","language":"en","text":"investing to be leaders and\r\ncontactors. We want to continue"
      },"hidden":False,"userData":"null"
    },{
      "id":"13761f00-aeac-48e8-b62d-84f77888eb83","type":"transcript","start":"PT52M23.32S","end":"PT52M27.88S","eventData":{
        "type":"caption","language":"en","text":"that leadership. We want to\r\ncontinue to invest in BMS in Hu"
      },"hidden":False,"userData":"null"
    },{
      "id":"09cb5d98-bc1a-4670-9735-ae456efb76b6","type":"transcript","start":"PT52M27.88S","end":"PT52M29.02S","eventData":{
        "type":"caption","language":"en","text":"are an industrial."
      },"hidden":False,"userData":"null"
    },{
      "id":"66057140-5d10-4cd1-9ae3-a8ff0efb5e20","type":"transcript","start":"PT52M29.33S","end":"PT52M33.586S","eventData":{
        "type":"caption","language":"en","text":"And and even going up further in\r\nthe in the system and doing PD"
      },"hidden":False,"userData":"null"
    },{
      "id":"48bf9efb-c8b7-45ed-85c6-766c37f9964f","type":"transcript","start":"PT52M33.586S","end":"PT52M38.146S","eventData":{
        "type":"caption","language":"en","text":"use for HBO are and we want to\r\ncontinue to look at. Do we have"
      },"hidden":False,"userData":"null"
    },{
      "id":"47872c48-0fe3-4ffc-aabd-951887825eff","type":"transcript","start":"PT52M38.146S","end":"PT52M42.098S","eventData":{
        "type":"caption","language":"en","text":"a potential of doing BMX in\r\nauto? Is that a place that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"cdbbc139-c8b8-4741-bfac-4a90ddb3dc3f","type":"transcript","start":"PT52M42.098S","end":"PT52M45.442S","eventData":{
        "type":"caption","language":"en","text":"want to play in? So that's\r\nsomething that we're looking at?"
      },"hidden":False,"userData":"null"
    },{
      "id":"3a05369a-778e-493a-b6a9-886daab8f0f4","type":"transcript","start":"PT52M46.18S","end":"PT52M52.032S","eventData":{
        "type":"caption","language":"en","text":"And then, as you can see there\r\non the third bullet, we want to"
      },"hidden":False,"userData":"null"
    },{
      "id":"9ece1292-8158-4064-9a23-001a40776614","type":"transcript","start":"PT52M52.032S","end":"PT52M54.958S","eventData":{
        "type":"caption","language":"en","text":"continue to partner and\r\norganically develop current"
      },"hidden":False,"userData":"null"
    },{
      "id":"419fae0c-8d72-4b21-adf2-4fb0af9eb1fe","type":"transcript","start":"PT52M54.958S","end":"PT52M58.302S","eventData":{
        "type":"caption","language":"en","text":"sensing solutions. An insulation\r\nmonitoring that could really"
      },"hidden":False,"userData":"null"
    },{
      "id":"54656856-c8df-40f5-ac5d-b89107703ff3","type":"transcript","start":"PT52M58.302S","end":"PT53M2.482S","eventData":{
        "type":"caption","language":"en","text":"help our broader portfolio in\r\nthe HBO are and industrial"
      },"hidden":False,"userData":"null"
    },{
      "id":"ac006b13-eeb5-4ea9-956e-0ce52527e2bf","type":"transcript","start":"PT53M2.482S","end":"PT53M4.16S","eventData":{
        "type":"caption","language":"en","text":"businesses. Um?"
      },"hidden":False,"userData":"null"
    },{
      "id":"09a1c3c7-cf7d-4a2d-a8f6-33a5b09d4ec2","type":"transcript","start":"PT53M5.26S","end":"PT53M9.602S","eventData":{
        "type":"caption","language":"en","text":"At the end of the day, it's all\r\nabout focus as we've talked"
      },"hidden":False,"userData":"null"
    },{
      "id":"380ef19c-9585-4b21-989d-0ac0ed7ecb27","type":"transcript","start":"PT53M9.602S","end":"PT53M12.942S","eventData":{
        "type":"caption","language":"en","text":"about and we really want to\r\nfocus in the electrification"
      },"hidden":False,"userData":"null"
    },{
      "id":"84098949-3a5c-47e5-8a5f-bdcb4a963c3b","type":"transcript","start":"PT53M12.942S","end":"PT53M15.948S","eventData":{
        "type":"caption","language":"en","text":"space, the high value\r\napplications we want to make"
      },"hidden":False,"userData":"null"
    },{
      "id":"3cbc2290-a17d-46d1-8968-96b79bf47d92","type":"transcript","start":"PT53M15.948S","end":"PT53M20.624S","eventData":{
        "type":"caption","language":"en","text":"sure we fill in the gaps that we\r\nhave in our portfolio. But more"
      },"hidden":False,"userData":"null"
    },{
      "id":"bfc06aae-1d4e-4762-b1b7-6243f7b2136a","type":"transcript","start":"PT53M20.624S","end":"PT53M24.966S","eventData":{
        "type":"caption","language":"en","text":"importantly, we really want to\r\nlook at how can we expand and go"
      },"hidden":False,"userData":"null"
    },{
      "id":"e3b755d8-95ca-4005-87c2-f05a7976d20e","type":"transcript","start":"PT53M24.966S","end":"PT53M28.64S","eventData":{
        "type":"caption","language":"en","text":"up that hardware and or software\r\nstack that will really drive"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b89ddb4-0aa7-46dc-b7a8-c68177dc8533","type":"transcript","start":"PT53M28.64S","end":"PT53M31.646S","eventData":{
        "type":"caption","language":"en","text":"differentiation at the subsystem\r\nlevel and then also drive"
      },"hidden":False,"userData":"null"
    },{
      "id":"c1ef4071-685f-4277-9f6f-11f73c3224a0","type":"transcript","start":"PT53M31.646S","end":"PT53M35.654S","eventData":{
        "type":"caption","language":"en","text":"differentiated value for us. And\r\nyou can see below. I won't read"
      },"hidden":False,"userData":"null"
    },{
      "id":"7fcd735a-6653-4648-85ee-179d0ed1bb76","type":"transcript","start":"PT53M35.654S","end":"PT53M37.324S","eventData":{
        "type":"caption","language":"en","text":"through all the different things"
      },"hidden":False,"userData":"null"
    },{
      "id":"bf6f333b-d9e0-4a24-98de-799805d82d41","type":"transcript","start":"PT53M37.324S","end":"PT53M41.55S","eventData":{
        "type":"caption","language":"en","text":"that were. We're working on\r\nand we have the ability to do"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6516643-4a69-4419-aa64-75cd882517ee","type":"transcript","start":"PT53M41.55S","end":"PT53M45.224S","eventData":{
        "type":"caption","language":"en","text":"this organically, but we also\r\nsee a lot of potential for"
      },"hidden":False,"userData":"null"
    },{
      "id":"be85f36f-87bb-4197-bb44-4f6212abc910","type":"transcript","start":"PT53M45.224S","end":"PT53M48.564S","eventData":{
        "type":"caption","language":"en","text":"M&A in this space to really\r\naccelerate what we're doing."
      },"hidden":False,"userData":"null"
    },{
      "id":"d1e756fb-2ae5-4dea-89cc-9ab9078c6702","type":"transcript","start":"PT53M49.75S","end":"PT53M51.294S","eventData":{
        "type":"caption","language":"en","text":"So if we go to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"bbc41653-e611-43ee-b5cf-38c9887e8f2e","type":"transcript","start":"PT53M52.31S","end":"PT53M56.69S","eventData":{
        "type":"caption","language":"en","text":"I really like this slide because\r\nit shows the whole ecosystem of"
      },"hidden":False,"userData":"null"
    },{
      "id":"dafcd7a3-5fae-422c-9f57-e820ff658fb9","type":"transcript","start":"PT53M56.69S","end":"PT53M59.61S","eventData":{
        "type":"caption","language":"en","text":"what's happening around up\r\naround electrification, and you"
      },"hidden":False,"userData":"null"
    },{
      "id":"c42f4a27-c22a-48d8-b6aa-9eb3d9d6d2f5","type":"transcript","start":"PT53M59.61S","end":"PT54M4.355S","eventData":{
        "type":"caption","language":"en","text":"can see that the impact of clean\r\nenergy that shift is a big"
      },"hidden":False,"userData":"null"
    },{
      "id":"95d7da35-33e0-4495-a06b-66460ee5fd8a","type":"transcript","start":"PT54M4.355S","end":"PT54M9.1S","eventData":{
        "type":"caption","language":"en","text":"opportunity for Syncada, and you\r\ncan see over on the on the right"
      },"hidden":False,"userData":"null"
    },{
      "id":"0479c17f-d3fc-4df4-8c33-5a1017cff924","type":"transcript","start":"PT54M9.1S","end":"PT54M14.21S","eventData":{
        "type":"caption","language":"en","text":"side, you know we have a path of\r\nbeing over 1 billion dollars and"
      },"hidden":False,"userData":"null"
    },{
      "id":"17c2041c-d60b-40ba-bbc8-c70bf27bb1b4","type":"transcript","start":"PT54M14.21S","end":"PT54M17.495S","eventData":{
        "type":"caption","language":"en","text":"Justin are electrification\r\nportfolio by 2030, and you can"
      },"hidden":False,"userData":"null"
    },{
      "id":"95f22b22-ca41-471f-8fab-0a14544272c9","type":"transcript","start":"PT54M17.495S","end":"PT54M20.415S","eventData":{
        "type":"caption","language":"en","text":"see that it's driving\r\nopportunities across charging EV"
      },"hidden":False,"userData":"null"
    },{
      "id":"8792cac7-5dc0-433d-9a88-de648a7b4941","type":"transcript","start":"PT54M20.415S","end":"PT54M22.97S","eventData":{
        "type":"caption","language":"en","text":"storage. I mean, you can see the"
      },"hidden":False,"userData":"null"
    },{
      "id":"91ee1278-76cd-42d0-b65b-043d695bf1b0","type":"transcript","start":"PT54M22.97S","end":"PT54M25.808S","eventData":{
        "type":"caption","language":"en","text":"list there. On the page an."
      },"hidden":False,"userData":"null"
    },{
      "id":"1ad6294b-1405-40bc-bd97-dd14a2e3f7ed","type":"transcript","start":"PT54M26.42S","end":"PT54M29.488S","eventData":{
        "type":"caption","language":"en","text":"You know what's really exciting\r\nis if you look at the bottom of"
      },"hidden":False,"userData":"null"
    },{
      "id":"c0de2c56-f956-44bb-91db-f292a3fad848","type":"transcript","start":"PT54M29.488S","end":"PT54M32.32S","eventData":{
        "type":"caption","language":"en","text":"the page there you can see how\r\nbroad a portfolio we already"
      },"hidden":False,"userData":"null"
    },{
      "id":"1e39b709-5794-43c9-87f6-041eb76873de","type":"transcript","start":"PT54M32.32S","end":"PT54M35.152S","eventData":{
        "type":"caption","language":"en","text":"have in this space with all the\r\nproducts that are listed there."
      },"hidden":False,"userData":"null"
    },{
      "id":"2e0fc339-97d7-4607-b9f6-ff8a61f9d016","type":"transcript","start":"PT54M35.8S","end":"PT54M39.715S","eventData":{
        "type":"caption","language":"en","text":"Uhm, but there are absolutely\r\ngreat opportunities for us"
      },"hidden":False,"userData":"null"
    },{
      "id":"c803ea35-7a36-4683-99a3-53099b2b636c","type":"transcript","start":"PT54M39.715S","end":"PT54M44.5S","eventData":{
        "type":"caption","language":"en","text":"moving forward. I want to share\r\none example of something that"
      },"hidden":False,"userData":"null"
    },{
      "id":"7651aa89-6c75-4f91-99a6-8b7f21273a1f","type":"transcript","start":"PT54M44.5S","end":"PT54M48.415S","eventData":{
        "type":"caption","language":"en","text":"we're doing adventures. We're\r\nworking with a company called"
      },"hidden":False,"userData":"null"
    },{
      "id":"c2f37472-d507-4ca4-9996-20606e8e444c","type":"transcript","start":"PT54M48.415S","end":"PT54M51.895S","eventData":{
        "type":"caption","language":"en","text":"peak power that develops\r\nbuilding energy storage systems"
      },"hidden":False,"userData":"null"
    },{
      "id":"9250e32c-bb49-4ca9-bcd3-46aa9544eaad","type":"transcript","start":"PT54M51.895S","end":"PT54M55.81S","eventData":{
        "type":"caption","language":"en","text":"and building management system\r\nsoftware and they deploy sensors"
      },"hidden":False,"userData":"null"
    },{
      "id":"42919955-fb84-498f-8bae-fd19bd2b0408","type":"transcript","start":"PT54M55.81S","end":"PT55M0.595S","eventData":{
        "type":"caption","language":"en","text":"to build that iot system and\r\nenable their solution, and they"
      },"hidden":False,"userData":"null"
    },{
      "id":"7093baa2-c1a5-47b8-9f8d-8f41181b4980","type":"transcript","start":"PT55M0.595S","end":"PT55M4.51S","eventData":{
        "type":"caption","language":"en","text":"improve building efficiency to\r\nsave the buildings money and"
      },"hidden":False,"userData":"null"
    },{
      "id":"56cb332d-e936-4854-bb5c-051a7f676103","type":"transcript","start":"PT55M4.51S","end":"PT55M6.685S","eventData":{
        "type":"caption","language":"en","text":"also store energy off peak."
      },"hidden":False,"userData":"null"
    },{
      "id":"50899df0-5160-4c1c-968b-f6e9cda75c9b","type":"transcript","start":"PT55M7.35S","end":"PT55M11.2S","eventData":{
        "type":"caption","language":"en","text":"To be able to support peak\r\ndemand when that occurs, saving"
      },"hidden":False,"userData":"null"
    },{
      "id":"96c51e50-3c92-410b-b5c0-28480c55ae3b","type":"transcript","start":"PT55M11.2S","end":"PT55M14.7S","eventData":{
        "type":"caption","language":"en","text":"the owners and the of the\r\nbuildings, you know a"
      },"hidden":False,"userData":"null"
    },{
      "id":"8f461dfb-053a-4663-896d-c52326a2432d","type":"transcript","start":"PT55M14.7S","end":"PT55M18.2S","eventData":{
        "type":"caption","language":"en","text":"considerable amount of money.\r\nIt's a great opportunity for us."
      },"hidden":False,"userData":"null"
    },{
      "id":"f66a5271-8681-41d0-8a54-5ce620af110f","type":"transcript","start":"PT55M18.2S","end":"PT55M23.45S","eventData":{
        "type":"caption","language":"en","text":"It fits in well with what we do\r\nwhen we look at both the sensor"
      },"hidden":False,"userData":"null"
    },{
      "id":"2798e44e-2b77-4e55-b92d-c2038233bcf4","type":"transcript","start":"PT55M23.45S","end":"PT55M27.65S","eventData":{
        "type":"caption","language":"en","text":"layer and also what we're trying\r\nto do around VMS and storage"
      },"hidden":False,"userData":"null"
    },{
      "id":"43d31c09-12d8-42e6-a26d-0cf860d6ac0d","type":"transcript","start":"PT55M27.65S","end":"PT55M30.8S","eventData":{
        "type":"caption","language":"en","text":"solutions. Solutions with our\r\nlithium balance products and the"
      },"hidden":False,"userData":"null"
    },{
      "id":"66e56d17-aa72-415d-bc88-8d4f72b98805","type":"transcript","start":"PT55M30.8S","end":"PT55M34.65S","eventData":{
        "type":"caption","language":"en","text":"ability to take those solutions\r\nfrom Europe and enter the North"
      },"hidden":False,"userData":"null"
    },{
      "id":"524df84b-7676-438d-9b9e-32f67dfd4a7b","type":"transcript","start":"PT55M34.65S","end":"PT55M37.8S","eventData":{
        "type":"caption","language":"en","text":"American market to really\r\nexciting opportunity for us and."
      },"hidden":False,"userData":"null"
    },{
      "id":"1895d720-2f29-4a4a-94f0-b05ca23e029b","type":"transcript","start":"PT55M38.34S","end":"PT55M41.662S","eventData":{
        "type":"caption","language":"en","text":"You know one that I know,\r\nnicotine bar are really excited"
      },"hidden":False,"userData":"null"
    },{
      "id":"5ffd6348-f596-4c18-808c-36c4535f676b","type":"transcript","start":"PT55M41.662S","end":"PT55M42.87S","eventData":{
        "type":"caption","language":"en","text":"about the closing on."
      },"hidden":False,"userData":"null"
    },{
      "id":"716f8f65-b156-48c0-9b3a-8b146fb3779a","type":"transcript","start":"PT55M44.01S","end":"PT55M45.578S","eventData":{
        "type":"caption","language":"en","text":"So if we go to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"62d699df-caf9-48bc-aa7e-93ef7da6c0b3","type":"transcript","start":"PT55M46.94S","end":"PT55M51.461S","eventData":{
        "type":"caption","language":"en","text":"Here I'll talk a little bit\r\nabout our smart and connected"
      },"hidden":False,"userData":"null"
    },{
      "id":"cea7585a-adb7-4371-ae27-8ab6c73eebea","type":"transcript","start":"PT55M51.461S","end":"PT55M55.16S","eventData":{
        "type":"caption","language":"en","text":"initiative. We have a really\r\nexciting opportunity on the"
      },"hidden":False,"userData":"null"
    },{
      "id":"dbad6875-6086-459c-986f-9d277a92b64b","type":"transcript","start":"PT55M55.16S","end":"PT55M58.859S","eventData":{
        "type":"caption","language":"en","text":"heavy commercial vehicle fleet\r\nside, and it's happening now."
      },"hidden":False,"userData":"null"
    },{
      "id":"72667e08-64a4-43ba-8021-2c84fd563f85","type":"transcript","start":"PT55M58.859S","end":"PT56M3.38S","eventData":{
        "type":"caption","language":"en","text":"It's a big market 7 billion\r\ndollar market. The across that"
      },"hidden":False,"userData":"null"
    },{
      "id":"30e1a809-5896-4102-ad14-f86aa94440b5","type":"transcript","start":"PT56M3.38S","end":"PT56M7.901S","eventData":{
        "type":"caption","language":"en","text":"whole iot stack and we have some\r\nreally strong engagement with"
      },"hidden":False,"userData":"null"
    },{
      "id":"35d918c6-4ab2-4347-ad9e-d352d548f13c","type":"transcript","start":"PT56M7.901S","end":"PT56M12.833S","eventData":{
        "type":"caption","language":"en","text":"people like Dasque Swift, Pepsi\r\nand FedEx, just to name a few."
      },"hidden":False,"userData":"null"
    },{
      "id":"dfaeb033-1eab-4b19-a5cf-e098e14f97f0","type":"transcript","start":"PT56M12.833S","end":"PT56M17.354S","eventData":{
        "type":"caption","language":"en","text":"Some of those companies you may\r\nknow, some definitely know and."
      },"hidden":False,"userData":"null"
    },{
      "id":"8d0bb4c8-10a3-4d7f-b79d-9bd248d597a3","type":"transcript","start":"PT56M17.77S","end":"PT56M21.706S","eventData":{
        "type":"caption","language":"en","text":"You know we have some really\r\nimportant choices to make on how"
      },"hidden":False,"userData":"null"
    },{
      "id":"2a244e07-5ae6-42d6-a079-67f346f7c704","type":"transcript","start":"PT56M21.706S","end":"PT56M25.314S","eventData":{
        "type":"caption","language":"en","text":"we can expand this. Uh, this.\r\nThis initiative we're doing very"
      },"hidden":False,"userData":"null"
    },{
      "id":"9361818d-7913-4bb0-a5e3-648ad9aea51d","type":"transcript","start":"PT56M25.314S","end":"PT56M28.594S","eventData":{
        "type":"caption","language":"en","text":"well right now, and we're\r\nfocused on the heavy vehicle"
      },"hidden":False,"userData":"null"
    },{
      "id":"99787589-aefb-4af9-8346-23eb3511b2c1","type":"transcript","start":"PT56M28.594S","end":"PT56M30.562S","eventData":{
        "type":"caption","language":"en","text":"fleet. But we really see that."
      },"hidden":False,"userData":"null"
    },{
      "id":"805551a5-e3fa-474e-8ab7-2bb294b72967","type":"transcript","start":"PT56M32.71S","end":"PT56M37.366S","eventData":{
        "type":"caption","language":"en","text":"As our OEMs sales cycle has\r\nslowed down due to Covid and"
      },"hidden":False,"userData":"null"
    },{
      "id":"6e4a6be0-8cf1-4623-b1d1-b26ee968f3d5","type":"transcript","start":"PT56M37.366S","end":"PT56M41.246S","eventData":{
        "type":"caption","language":"en","text":"push out some things like that\r\nwere really reprioritizing fleet"
      },"hidden":False,"userData":"null"
    },{
      "id":"93a1ccce-dc62-4b03-a35f-08befa15774d","type":"transcript","start":"PT56M41.246S","end":"PT56M45.126S","eventData":{
        "type":"caption","language":"en","text":"retrofits and going after those\r\nbig fleets an we're really"
      },"hidden":False,"userData":"null"
    },{
      "id":"d19d1162-50f1-4c9d-9580-8f7ecd31d05b","type":"transcript","start":"PT56M45.126S","end":"PT56M49.782S","eventData":{
        "type":"caption","language":"en","text":"trying to expand the scope of\r\nwhat we're doing to not only"
      },"hidden":False,"userData":"null"
    },{
      "id":"d8f41c57-e99e-4a6d-a456-cc91efe534d9","type":"transcript","start":"PT56M49.782S","end":"PT56M53.274S","eventData":{
        "type":"caption","language":"en","text":"cover the heavy commercial\r\nvehicle fleets, but also to"
      },"hidden":False,"userData":"null"
    },{
      "id":"2a56f4f4-4d22-49a6-8471-e7b1cefb0a61","type":"transcript","start":"PT56M53.274S","end":"PT56M57.542S","eventData":{
        "type":"caption","language":"en","text":"expand down the asset classes to\r\nthe medium duty and light"
      },"hidden":False,"userData":"null"
    },{
      "id":"9694968d-127a-487b-a24e-12dacc4cec8a","type":"transcript","start":"PT56M57.542S","end":"PT57M1.81S","eventData":{
        "type":"caption","language":"en","text":"commercial vehicle fleets. And\r\nby doing that, it opens up a"
      },"hidden":False,"userData":"null"
    },{
      "id":"b5be3c1a-439d-411a-968d-d65a14e0737d","type":"transcript","start":"PT57M1.81S","end":"PT57M6.87S","eventData":{
        "type":"caption","language":"en","text":"significant. Market you can see\r\nthere are 20 billion dollars Sam"
      },"hidden":False,"userData":"null"
    },{
      "id":"9d447ed2-dd5d-402e-bf0e-014ef5d9bb33","type":"transcript","start":"PT57M6.87S","end":"PT57M11.901S","eventData":{
        "type":"caption","language":"en","text":"and again it's it's here and now\r\nand it's very important for us"
      },"hidden":False,"userData":"null"
    },{
      "id":"961d4473-daee-4eb6-bed4-a22c1ed1646f","type":"transcript","start":"PT57M11.901S","end":"PT57M16.158S","eventData":{
        "type":"caption","language":"en","text":"to to move down the asset\r\nclasses and really drive the"
      },"hidden":False,"userData":"null"
    },{
      "id":"9bdfc9de-1b53-400b-9514-56478c5efc9b","type":"transcript","start":"PT57M16.158S","end":"PT57M17.706S","eventData":{
        "type":"caption","language":"en","text":"scale of this venture."
      },"hidden":False,"userData":"null"
    },{
      "id":"af03cc9d-f1a0-4285-9ae1-dd5bbbc49bd8","type":"transcript","start":"PT57M18.78S","end":"PT57M20.91S","eventData":{
        "type":"caption","language":"en","text":"So on the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"4ae6d7fc-de51-4ae1-a9b2-50f36ff3412b","type":"transcript","start":"PT57M22.02S","end":"PT57M27.195S","eventData":{
        "type":"caption","language":"en","text":"You can see here to me this is a\r\ngreat example of what it means"
      },"hidden":False,"userData":"null"
    },{
      "id":"89d73c5c-aecf-40b8-bc5c-6bc82b3ce713","type":"transcript","start":"PT57M27.195S","end":"PT57M30.99S","eventData":{
        "type":"caption","language":"en","text":"to be agile in Avengers\r\nenvironment so you can see here"
      },"hidden":False,"userData":"null"
    },{
      "id":"21bb3815-dd40-41a6-a17e-86ec48fcd5fb","type":"transcript","start":"PT57M30.99S","end":"PT57M34.095S","eventData":{
        "type":"caption","language":"en","text":"the whole ecosystem that's\r\ndeveloped across the tractor and"
      },"hidden":False,"userData":"null"
    },{
      "id":"22b08351-619c-41a0-a4b1-060fd1e06422","type":"transcript","start":"PT57M34.095S","end":"PT57M37.545S","eventData":{
        "type":"caption","language":"en","text":"trailer. When we started this\r\nventure, we were only really"
      },"hidden":False,"userData":"null"
    },{
      "id":"eda3fa39-2d66-4f1a-89f7-85e88f01df61","type":"transcript","start":"PT57M37.545S","end":"PT57M41.34S","eventData":{
        "type":"caption","language":"en","text":"talking about the sensors like\r\nPMS in the vehicle area network"
      },"hidden":False,"userData":"null"
    },{
      "id":"92f26171-8995-4abd-9a2f-aabf29833f88","type":"transcript","start":"PT57M41.34S","end":"PT57M44.79S","eventData":{
        "type":"caption","language":"en","text":"or the van layer and it's listed\r\nthere in blue."
      },"hidden":False,"userData":"null"
    },{
      "id":"e2ba0b6f-ee0d-4b8c-bb70-d43bf28261d0","type":"transcript","start":"PT57M45.78S","end":"PT57M49.663S","eventData":{
        "type":"caption","language":"en","text":"Now, in order to deliver the\r\nfull customer experience in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"f911c629-e8e6-49f7-9983-997a7ecb7c94","type":"transcript","start":"PT57M49.663S","end":"PT57M53.193S","eventData":{
        "type":"caption","language":"en","text":"solution that our customers\r\nneed, we have to develop things"
      },"hidden":False,"userData":"null"
    },{
      "id":"b82533cb-0bfa-45f5-b6fa-24071993693f","type":"transcript","start":"PT57M53.193S","end":"PT57M56.723S","eventData":{
        "type":"caption","language":"en","text":"like mobile apps, telematics\r\nsolutions for the trailers and a"
      },"hidden":False,"userData":"null"
    },{
      "id":"65d3da3c-8335-487d-9ec9-47d54a515905","type":"transcript","start":"PT57M56.723S","end":"PT58M1.312S","eventData":{
        "type":"caption","language":"en","text":"full cloud solution that you can\r\nsee there. Listed on the top of"
      },"hidden":False,"userData":"null"
    },{
      "id":"b9cba319-6f66-4fb3-a4fd-42b02af03b5a","type":"transcript","start":"PT58M1.312S","end":"PT58M4.842S","eventData":{
        "type":"caption","language":"en","text":"the page. So we've really\r\nexpanded across the full iot"
      },"hidden":False,"userData":"null"
    },{
      "id":"18e05c87-58b7-4484-bd4b-606191264cee","type":"transcript","start":"PT58M4.842S","end":"PT58M9.078S","eventData":{
        "type":"caption","language":"en","text":"stack and we've made this change\r\nin scope and made this progress"
      },"hidden":False,"userData":"null"
    },{
      "id":"456e37ca-2adf-4cc6-940a-f2f1d49664ed","type":"transcript","start":"PT58M9.078S","end":"PT58M10.843S","eventData":{
        "type":"caption","language":"en","text":"in just over 12 months."
      },"hidden":False,"userData":"null"
    },{
      "id":"689d7fc1-4404-4e23-83d4-cbc4b5982399","type":"transcript","start":"PT58M11.47S","end":"PT58M15.046S","eventData":{
        "type":"caption","language":"en","text":"So it's really amazing to me\r\nwhen you think about what a"
      },"hidden":False,"userData":"null"
    },{
      "id":"451dee42-85ae-4262-9a84-0cfcf533e154","type":"transcript","start":"PT58M15.046S","end":"PT58M18.324S","eventData":{
        "type":"caption","language":"en","text":"focused and committed team at\r\nSyncada can do, and this is"
      },"hidden":False,"userData":"null"
    },{
      "id":"56e64aa8-aed9-46c4-8407-35e14aed9dc2","type":"transcript","start":"PT58M18.324S","end":"PT58M21.9S","eventData":{
        "type":"caption","language":"en","text":"what the type of things that\r\nwe're going to need to do"
      },"hidden":False,"userData":"null"
    },{
      "id":"827ad643-8c08-4bff-84f6-545a989f1e7d","type":"transcript","start":"PT58M21.9S","end":"PT58M25.178S","eventData":{
        "type":"caption","language":"en","text":"across the entire company and\r\nthat we do do across the"
      },"hidden":False,"userData":"null"
    },{
      "id":"c546f22b-d7b2-459b-8336-cb135a006439","type":"transcript","start":"PT58M25.178S","end":"PT58M26.966S","eventData":{
        "type":"caption","language":"en","text":"company in order to be\r\nsuccessful."
      },"hidden":False,"userData":"null"
    },{
      "id":"e2d37bc4-6879-4a49-a4df-ddc6d06365f7","type":"transcript","start":"PT58M28.18S","end":"PT58M30.14S","eventData":{
        "type":"caption","language":"en","text":"So we go to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"18d7647f-6824-46d7-b326-df0e40a92b26","type":"transcript","start":"PT58M31.35S","end":"PT58M35.057S","eventData":{
        "type":"caption","language":"en","text":"You can see why we're expanding\r\nfrom, uh, the heavy commercial"
      },"hidden":False,"userData":"null"
    },{
      "id":"3aa34d62-9251-4503-8912-b6fb9072ed3a","type":"transcript","start":"PT58M35.057S","end":"PT58M38.09S","eventData":{
        "type":"caption","language":"en","text":"vehicle fleets down into the\r\nmedium and light commercial"
      },"hidden":False,"userData":"null"
    },{
      "id":"c531ca8f-3749-44f4-a191-818e7164e456","type":"transcript","start":"PT58M38.09S","end":"PT58M41.797S","eventData":{
        "type":"caption","language":"en","text":"vehicle fleets. You can really\r\nsee how big the opportunity is"
      },"hidden":False,"userData":"null"
    },{
      "id":"c922b9bd-4923-40b9-95df-28b71b02edbe","type":"transcript","start":"PT58M41.797S","end":"PT58M45.841S","eventData":{
        "type":"caption","language":"en","text":"when you look at the number of\r\nvehicles on the left. The"
      },"hidden":False,"userData":"null"
    },{
      "id":"359cbb65-eb1f-4034-bac9-93e20afe86c7","type":"transcript","start":"PT58M45.841S","end":"PT58M49.548S","eventData":{
        "type":"caption","language":"en","text":"expansion by going into the\r\nMCB&LCV space, and it more than"
      },"hidden":False,"userData":"null"
    },{
      "id":"b40d88c3-9f97-43c2-b1e1-33106fac426c","type":"transcript","start":"PT58M49.548S","end":"PT58M53.592S","eventData":{
        "type":"caption","language":"en","text":"doubles the opportunity that we\r\nhave today. And you can see over"
      },"hidden":False,"userData":"null"
    },{
      "id":"a781c324-e906-4e5d-9268-66eef4a4487e","type":"transcript","start":"PT58M53.592S","end":"PT58M58.31S","eventData":{
        "type":"caption","language":"en","text":"on the right side of the slide\r\nwe want to be the number one"
      },"hidden":False,"userData":"null"
    },{
      "id":"dbfc2a71-2c25-42b9-a5d9-d03c4c3d60e3","type":"transcript","start":"PT58M58.31S","end":"PT59M1.006S","eventData":{
        "type":"caption","language":"en","text":"solution to large fleet\r\ncustomers that operate these"
      },"hidden":False,"userData":"null"
    },{
      "id":"58cdaf50-6110-4756-b3d9-56df9e1540e3","type":"transcript","start":"PT59M1.006S","end":"PT59M3.028S","eventData":{
        "type":"caption","language":"en","text":"fleets that have a very large."
      },"hidden":False,"userData":"null"
    },{
      "id":"75e4041e-4785-4b70-879a-74d8076a2ced","type":"transcript","start":"PT59M3.43S","end":"PT59M7.5S","eventData":{
        "type":"caption","language":"en","text":"Mix vehicle asset classes within\r\ntheir fleets and again really"
      },"hidden":False,"userData":"null"
    },{
      "id":"e022a0e8-b28e-4df0-87e0-78b9faf0b04a","type":"transcript","start":"PT59M7.5S","end":"PT59M11.57S","eventData":{
        "type":"caption","language":"en","text":"you know for really important\r\ncustomers for customers that I"
      },"hidden":False,"userData":"null"
    },{
      "id":"0bdfd147-0b3e-4e39-9d08-0e79b86170d1","type":"transcript","start":"PT59M11.57S","end":"PT59M16.047S","eventData":{
        "type":"caption","language":"en","text":"think everybody on the on the\r\nphone listening in knows those"
      },"hidden":False,"userData":"null"
    },{
      "id":"7dc5d996-e42f-49ea-ab55-6d74f43d64da","type":"transcript","start":"PT59M16.047S","end":"PT59M20.931S","eventData":{
        "type":"caption","language":"en","text":"customers. So with that, why\r\ndon't we go to the next slide?"
      },"hidden":False,"userData":"null"
    },{
      "id":"231679c8-6bff-49ab-94c2-a95c2e8a3051","type":"transcript","start":"PT59M22.61S","end":"PT59M28.58S","eventData":{
        "type":"caption","language":"en","text":"And you can see here as we layer\r\nin what we're doing on HTV, and"
      },"hidden":False,"userData":"null"
    },{
      "id":"4db23aa8-955b-428a-9acc-c8b18b1bae82","type":"transcript","start":"PT59M28.58S","end":"PT59M34.55S","eventData":{
        "type":"caption","language":"en","text":"then as we continue to build out\r\nand work on MTV and LCV, and add"
      },"hidden":False,"userData":"null"
    },{
      "id":"1c8061be-0375-40f4-95b2-f130b091ac1b","type":"transcript","start":"PT59M34.55S","end":"PT59M38.928S","eventData":{
        "type":"caption","language":"en","text":"things like prognostics that are\r\nauto team has been working on"
      },"hidden":False,"userData":"null"
    },{
      "id":"493bc4bc-f82d-4375-a78f-73170a5a88f2","type":"transcript","start":"PT59M38.928S","end":"PT59M42.908S","eventData":{
        "type":"caption","language":"en","text":"their. They're doing some really\r\ngood work around prognostics and"
      },"hidden":False,"userData":"null"
    },{
      "id":"05c87da2-2085-47ab-8a6e-eede14c10f8a","type":"transcript","start":"PT59M42.908S","end":"PT59M48.48S","eventData":{
        "type":"caption","language":"en","text":"driving us to do more on the LCD\r\nside. You can see that together"
      },"hidden":False,"userData":"null"
    },{
      "id":"9f62330d-d9f1-4032-8bcb-b662cba92efb","type":"transcript","start":"PT59M48.48S","end":"PT59M52.858S","eventData":{
        "type":"caption","language":"en","text":"we can have a combined business\r\nthat can achieve greater than"
      },"hidden":False,"userData":"null"
    },{
      "id":"21b198ff-a793-46ef-90b0-d619bf519e19","type":"transcript","start":"PT59M52.858S","end":"PT59M54.848S","eventData":{
        "type":"caption","language":"en","text":"400 million dollars in 2025."
      },"hidden":False,"userData":"null"
    },{
      "id":"b6d3fb16-ec8c-47a5-a3ef-1de47b726fb0","type":"transcript","start":"PT59M55.16S","end":"PT59M59.867S","eventData":{
        "type":"caption","language":"en","text":"And really, excitingly is\r\ndelivering 30% EBIT margins to"
      },"hidden":False,"userData":"null"
    },{
      "id":"f6c7229c-88d4-4a7c-8da1-79ebddfe48fd","type":"transcript","start":"PT59M59.867S","end":"PT1H3.709S","eventData":{
        "type":"caption","language":"en","text":"the? Company, so when you\r\nthink about that and the"
      },"hidden":False,"userData":"null"
    },{
      "id":"1577f9e3-c870-449f-bc65-20808146c99e","type":"transcript","start":"PT1H3.709S","end":"PT1H8.041S","eventData":{
        "type":"caption","language":"en","text":"ability to continue to expand,\r\nnot just HIV but even grow the"
      },"hidden":False,"userData":"null"
    },{
      "id":"8f134911-52cb-47a8-aadf-b5c7597478db","type":"transcript","start":"PT1H8.041S","end":"PT1H12.373S","eventData":{
        "type":"caption","language":"en","text":"MC be an LCD space even\r\nfurther, it really is a truly"
      },"hidden":False,"userData":"null"
    },{
      "id":"76cbe71b-7ff1-447f-bdc0-cac3c26f2bf6","type":"transcript","start":"PT1H12.373S","end":"PT1H16.344S","eventData":{
        "type":"caption","language":"en","text":"amazing opportunity for us at\r\nthe syncada to get into this"
      },"hidden":False,"userData":"null"
    },{
      "id":"0dc15a04-7d0f-4275-9cd2-7369320bf1f3","type":"transcript","start":"PT1H16.344S","end":"PT1H16.705S","eventData":{
        "type":"caption","language":"en","text":"space."
      },"hidden":False,"userData":"null"
    },{
      "id":"6956e3c6-3bd7-4ffd-a405-1ceead6f09e1","type":"transcript","start":"PT1H18.01S","end":"PT1H20.93S","eventData":{
        "type":"caption","language":"en","text":"So with that, when we\r\ngo to the next slide."
      },"hidden":False,"userData":"null"
    },{
      "id":"edb7a007-4107-4cb7-a3d8-cbbb86a06a87","type":"transcript","start":"PT1H22.04S","end":"PT1H26.967S","eventData":{
        "type":"caption","language":"en","text":"And last topic I want to cover\r\nbefore you rap it up is"
      },"hidden":False,"userData":"null"
    },{
      "id":"bb3c8d45-ecb8-4ebe-8531-b75af6777df2","type":"transcript","start":"PT1H26.967S","end":"PT1H31.136S","eventData":{
        "type":"caption","language":"en","text":"autonomy. So over the last\r\ncouple of years as we've talked"
      },"hidden":False,"userData":"null"
    },{
      "id":"80d2a502-edf2-45c1-a95c-f79a08eb216f","type":"transcript","start":"PT1H31.136S","end":"PT1H34.547S","eventData":{
        "type":"caption","language":"en","text":"about, we've seen the promise of\r\nwidespread autonomy adoption"
      },"hidden":False,"userData":"null"
    },{
      "id":"11abebc0-ed23-4d21-b0a8-840ac2d5df13","type":"transcript","start":"PT1H34.547S","end":"PT1H39.095S","eventData":{
        "type":"caption","language":"en","text":"push out. But that said, we have\r\nseen the emergence of high"
      },"hidden":False,"userData":"null"
    },{
      "id":"65cbb6a4-148f-4a89-85f1-cf0e6c43d17f","type":"transcript","start":"PT1H39.095S","end":"PT1H42.885S","eventData":{
        "type":"caption","language":"en","text":"performing L2 systems or L2\r\nplus. Those systems are growing"
      },"hidden":False,"userData":"null"
    },{
      "id":"535ded18-3c99-4674-b2fe-04ad618b6cd3","type":"transcript","start":"PT1H42.885S","end":"PT1H45.917S","eventData":{
        "type":"caption","language":"en","text":"and that does provide\r\nopportunities for syncada things"
      },"hidden":False,"userData":"null"
    },{
      "id":"680d12c3-dc39-4508-8d56-8f8416813cb7","type":"transcript","start":"PT1H45.917S","end":"PT1H51.223S","eventData":{
        "type":"caption","language":"en","text":"like radar IM use and we think\r\nthat radar is a great space as"
      },"hidden":False,"userData":"null"
    },{
      "id":"2e6e4357-76ac-4422-8a4d-58b26460fe55","type":"transcript","start":"PT1H51.223S","end":"PT1H52.739S","eventData":{
        "type":"caption","language":"en","text":"we talked about previously."
      },"hidden":False,"userData":"null"
    },{
      "id":"f97ee546-a3e6-47c2-8630-aacd256cc42a","type":"transcript","start":"PT1H52.94S","end":"PT1H58.166S","eventData":{
        "type":"caption","language":"en","text":"We we see radars critical for\r\neight as systems and also as a"
      },"hidden":False,"userData":"null"
    },{
      "id":"20a0e9ba-5a23-4a63-96ed-9764ec65a789","type":"transcript","start":"PT1H58.166S","end":"PT1H1M2.186S","eventData":{
        "type":"caption","language":"en","text":"future building block for\r\nautonomy. So as as we've talked"
      },"hidden":False,"userData":"null"
    },{
      "id":"7542d6de-8f5e-439b-969f-e369ea0f43bd","type":"transcript","start":"PT1H1M2.186S","end":"PT1H1M6.608S","eventData":{
        "type":"caption","language":"en","text":"about today, and as I hope\r\neveryone has either heard about"
      },"hidden":False,"userData":"null"
    },{
      "id":"9df5a8bc-ff0d-46cf-a385-b6e3b3e07ef6","type":"transcript","start":"PT1H1M6.608S","end":"PT1H1M10.226S","eventData":{
        "type":"caption","language":"en","text":"before red July 1st week\r\nrequired Preco Erator Company"
      },"hidden":False,"userData":"null"
    },{
      "id":"1a92d871-cb57-478f-8cae-a889f0c43350","type":"transcript","start":"PT1H1M10.226S","end":"PT1H1M14.246S","eventData":{
        "type":"caption","language":"en","text":"that's focused on the HBO our\r\nmarket precos about $20,000,000"
      },"hidden":False,"userData":"null"
    },{
      "id":"13f9b716-97cc-41a8-80e5-9a90d2da67c6","type":"transcript","start":"PT1H1M14.246S","end":"PT1H1M18.266S","eventData":{
        "type":"caption","language":"en","text":"in revenue with great products\r\nand more importantly with a"
      },"hidden":False,"userData":"null"
    },{
      "id":"816a1389-f1b4-4d83-bdd1-1954cbd82dc2","type":"transcript","start":"PT1H1M18.266S","end":"PT1H1M22.688S","eventData":{
        "type":"caption","language":"en","text":"great team. And Preco is now the\r\nbeachhead, on which we."
      },"hidden":False,"userData":"null"
    },{
      "id":"9b373e7b-5f52-4ded-9f5e-7654c2b0b333","type":"transcript","start":"PT1H1M22.99S","end":"PT1H1M26.983S","eventData":{
        "type":"caption","language":"en","text":"Plans to build an even larger\r\nand stronger radar business for"
      },"hidden":False,"userData":"null"
    },{
      "id":"a9b38f69-fc7a-4ae0-bbcc-ee42d95cbc54","type":"transcript","start":"PT1H1M26.983S","end":"PT1H1M31.339S","eventData":{
        "type":"caption","language":"en","text":"for syncada. So with that we're\r\nvery happy to have the Preko"
      },"hidden":False,"userData":"null"
    },{
      "id":"ecd1a765-39a9-4e15-9f2d-105a6f31ca3a","type":"transcript","start":"PT1H1M31.339S","end":"PT1H1M36.058S","eventData":{
        "type":"caption","language":"en","text":"team as part of teams and Sada\r\nan really are looking forward to"
      },"hidden":False,"userData":"null"
    },{
      "id":"3893c460-2e5b-45c1-808e-27dc0f808d8f","type":"transcript","start":"PT1H1M36.058S","end":"PT1H1M39.688S","eventData":{
        "type":"caption","language":"en","text":"building our radar business to\r\ngreater than 300 million by"
      },"hidden":False,"userData":"null"
    },{
      "id":"c68311b9-8c94-46c3-a41b-ca6a5ef94b21","type":"transcript","start":"PT1H1M39.688S","end":"PT1H1M45.026S","eventData":{
        "type":"caption","language":"en","text":"2030. So with that, uh, why\r\ndon't we go to the last slide"
      },"hidden":False,"userData":"null"
    },{
      "id":"c447da58-c358-44b5-8fac-5ac05dae2a0b","type":"transcript","start":"PT1H1M45.026S","end":"PT1H1M50.105S","eventData":{
        "type":"caption","language":"en","text":"so? What I want to leave you\r\nwith is is this. I think that"
      },"hidden":False,"userData":"null"
    },{
      "id":"47a3c97f-bf7b-4f8b-83d8-7bddf691275f","type":"transcript","start":"PT1H1M50.105S","end":"PT1H1M53.57S","eventData":{
        "type":"caption","language":"en","text":"the top line says it very well.\r\nSyncada is well positioned,"
      },"hidden":False,"userData":"null"
    },{
      "id":"5fae267f-1312-4a73-8e81-5becfecff411","type":"transcript","start":"PT1H1M53.57S","end":"PT1H1M55.145S","eventData":{
        "type":"caption","language":"en","text":"focused and invested for our"
      },"hidden":False,"userData":"null"
    },{
      "id":"52323e1e-388d-4d01-9da7-a862276a05b3","type":"transcript","start":"PT1H1M55.145S","end":"PT1H2M0.676S","eventData":{
        "type":"caption","language":"en","text":"future. And I can tell you that\r\nas a leadership team, we know"
      },"hidden":False,"userData":"null"
    },{
      "id":"2e6a4e68-9c22-4c96-83c1-8835f45c9985","type":"transcript","start":"PT1H2M0.676S","end":"PT1H2M5.395S","eventData":{
        "type":"caption","language":"en","text":"that we have some some near term\r\nissues that our company and all"
      },"hidden":False,"userData":"null"
    },{
      "id":"0e223215-3295-43af-a1c2-97d56651d6d4","type":"transcript","start":"PT1H2M5.395S","end":"PT1H2M9.025S","eventData":{
        "type":"caption","language":"en","text":"this personally are facing. But\r\nwe are absolutely confident in"
      },"hidden":False,"userData":"null"
    },{
      "id":"c3ad3665-f53d-4945-b799-3e42f2f2ad07","type":"transcript","start":"PT1H2M9.025S","end":"PT1H2M13.381S","eventData":{
        "type":"caption","language":"en","text":"our opportunity and in our\r\nvision of five and five we can"
      },"hidden":False,"userData":"null"
    },{
      "id":"cc8c09f2-23e7-4d01-8dd4-efa53e3a783a","type":"transcript","start":"PT1H2M13.381S","end":"PT1H2M15.559S","eventData":{
        "type":"caption","language":"en","text":"reach 5 billion in revenue by"
      },"hidden":False,"userData":"null"
    },{
      "id":"f0da89c1-24f2-421e-a335-135662910cac","type":"transcript","start":"PT1H2M15.559S","end":"PT1H2M19.879S","eventData":{
        "type":"caption","language":"en","text":"2020 2025. The vision is there.\r\nIt's compelling, I believe in"
      },"hidden":False,"userData":"null"
    },{
      "id":"b830c2bf-c9a0-4799-8606-87cb9e710a30","type":"transcript","start":"PT1H2M19.879S","end":"PT1H2M24.182S","eventData":{
        "type":"caption","language":"en","text":"it, and I really believe that\r\nif we we execute well and focus"
      },"hidden":False,"userData":"null"
    },{
      "id":"5bbdc7b2-2aef-4f81-b125-64c46f28d50b","type":"transcript","start":"PT1H2M24.182S","end":"PT1H2M28.485S","eventData":{
        "type":"caption","language":"en","text":"on what we need to do, there's\r\nno question in my mind that"
      },"hidden":False,"userData":"null"
    },{
      "id":"6e76ef7b-9370-49e4-92ab-e73bd4d9efab","type":"transcript","start":"PT1H2M28.485S","end":"PT1H2M32.126S","eventData":{
        "type":"caption","language":"en","text":"teams inside a Canon will\r\nachieve it. So with that from"
      },"hidden":False,"userData":"null"
    },{
      "id":"c4d9606c-52f3-45af-b377-16fb6ef7eccb","type":"transcript","start":"PT1H2M32.126S","end":"PT1H2M36.098S","eventData":{
        "type":"caption","language":"en","text":"my office here in Attleboro, I\r\nwant to say thank you. Thank"
      },"hidden":False,"userData":"null"
    },{
      "id":"47e546d6-e92b-4d26-a1c6-2b38b643679b","type":"transcript","start":"PT1H2M36.098S","end":"PT1H2M40.401S","eventData":{
        "type":"caption","language":"en","text":"you for all that you've done so\r\nfar and for all that you"
      },"hidden":False,"userData":"null"
    },{
      "id":"ae827ba1-4c1f-4b7d-94aa-733913620251","type":"transcript","start":"PT1H2M40.401S","end":"PT1H2M44.373S","eventData":{
        "type":"caption","language":"en","text":"continue to do everyday. And\r\nwith that I will kick it back"
      },"hidden":False,"userData":"null"
    },{
      "id":"634410a6-240a-4d9a-9d2f-dc8a55528c05","type":"transcript","start":"PT1H2M44.373S","end":"PT1H2M46.359S","eventData":{
        "type":"caption","language":"en","text":"over to Alexia for Q&A session."
      },"hidden":False,"userData":"null"
    },{
      "id":"3a0c91c4-64b0-42b3-b79b-818e92a3e1c6","type":"transcript","start":"PT1H2M51.07S","end":"PT1H2M55.228S","eventData":{
        "type":"caption","language":"en","text":"Alright, thank you everyone and\r\nI really want to thank anzan"
      },"hidden":False,"userData":"null"
    },{
      "id":"ece42183-83df-4a00-93bd-683fbc9e2a4a","type":"transcript","start":"PT1H2M55.228S","end":"PT1H2M59.008S","eventData":{
        "type":"caption","language":"en","text":"beneath Paul and George really\r\nfor first doing this. It's"
      },"hidden":False,"userData":"null"
    },{
      "id":"14424013-4426-45b3-9039-9498b37427b3","type":"transcript","start":"PT1H2M59.008S","end":"PT1H3M2.788S","eventData":{
        "type":"caption","language":"en","text":"really important for our global\r\nteams. Second sticking to the"
      },"hidden":False,"userData":"null"
    },{
      "id":"64d31736-b078-49e6-9be3-c7d363c6df50","type":"transcript","start":"PT1H3M2.788S","end":"PT1H3M7.324S","eventData":{
        "type":"caption","language":"en","text":"time and catching up sometime so\r\nwe have lots of time for"
      },"hidden":False,"userData":"null"
    },{
      "id":"15ff059d-9b67-485e-b50f-d12fd4c08e24","type":"transcript","start":"PT1H3M7.324S","end":"PT1H3M10.726S","eventData":{
        "type":"caption","language":"en","text":"questions and third really for\r\nthe flexibility with navigating"
      },"hidden":False,"userData":"null"
    },{
      "id":"76e55809-32d0-4388-88dd-3de3893e4133","type":"transcript","start":"PT1H3M10.726S","end":"PT1H3M14.506S","eventData":{
        "type":"caption","language":"en","text":"new channels and ways to\r\ncommunicate with our teams. So"
      },"hidden":False,"userData":"null"
    },{
      "id":"ceb5213c-a836-4332-8b81-e3964402aaf1","type":"transcript","start":"PT1H3M14.506S","end":"PT1H3M17.908S","eventData":{
        "type":"caption","language":"en","text":"here's some ground rules we have\r\nabout 25 questions."
      },"hidden":False,"userData":"null"
    },{
      "id":"adec40c0-e825-4d2c-8e2f-5ad331fd4c57","type":"transcript","start":"PT1H3M18.02S","end":"PT1H3M22.167S","eventData":{
        "type":"caption","language":"en","text":"In the queue right now and we\r\nhave a little more than 20"
      },"hidden":False,"userData":"null"
    },{
      "id":"5cc184ef-0ab4-4a90-a61a-caa5ddaca8cc","type":"transcript","start":"PT1H3M22.167S","end":"PT1H3M25.676S","eventData":{
        "type":"caption","language":"en","text":"minutes, we're going to get\r\nthrough as many questions as we"
      },"hidden":False,"userData":"null"
    },{
      "id":"e636770f-3a06-4d47-b861-9d720891c2cf","type":"transcript","start":"PT1H3M25.676S","end":"PT1H3M30.461S","eventData":{
        "type":"caption","language":"en","text":"can, and if I can just ask\r\npeople to. If you go on the on"
      },"hidden":False,"userData":"null"
    },{
      "id":"e296966d-586d-4d42-8af4-c02221225b8a","type":"transcript","start":"PT1H3M30.461S","end":"PT1H3M34.289S","eventData":{
        "type":"caption","language":"en","text":"the live Q&A panel. If you sort\r\nyour questions by most like"
      },"hidden":False,"userData":"null"
    },{
      "id":"106e5b2a-583e-45b6-99e6-7cff0bf8cbff","type":"transcript","start":"PT1H3M34.289S","end":"PT1H3M37.798S","eventData":{
        "type":"caption","language":"en","text":"there's most liked or most\r\nrecent, if you click on most"
      },"hidden":False,"userData":"null"
    },{
      "id":"fb132822-f924-426e-9301-768cf34ebf94","type":"transcript","start":"PT1H3M37.798S","end":"PT1H3M41.307S","eventData":{
        "type":"caption","language":"en","text":"light, that's how we're going to\r\nbe answering the questions and"
      },"hidden":False,"userData":"null"
    },{
      "id":"56934d46-9af8-4285-a81e-053e80f5f4a4","type":"transcript","start":"PT1H3M41.307S","end":"PT1H3M46.092S","eventData":{
        "type":"caption","language":"en","text":"we're going to just work our way\r\ndown, so I will ask my team to"
      },"hidden":False,"userData":"null"
    },{
      "id":"0bcf3cf2-e499-4e7b-b6ce-c543e77f56df","type":"transcript","start":"PT1H3M46.092S","end":"PT1H3M48.325S","eventData":{
        "type":"caption","language":"en","text":"kind of jump in as I direct."
      },"hidden":False,"userData":"null"
    },{
      "id":"6ba16396-928b-42d3-89cd-f92aa2b2c597","type":"transcript","start":"PT1H3M48.38S","end":"PT1H3M51.22S","eventData":{
        "type":"caption","language":"en","text":"Obviously Hans, Albany and\r\nGeorge are available for"
      },"hidden":False,"userData":"null"
    },{
      "id":"313c9bab-d45c-403c-8969-87f8dfbfa8c7","type":"transcript","start":"PT1H3M51.22S","end":"PT1H3M55.835S","eventData":{
        "type":"caption","language":"en","text":"questions. We also have Jeff on\r\nthe line as well to take any"
      },"hidden":False,"userData":"null"
    },{
      "id":"4005488f-3f26-4f59-84b7-010e2aa57863","type":"transcript","start":"PT1H3M55.835S","end":"PT1H3M59.03S","eventData":{
        "type":"caption","language":"en","text":"questions so I really appreciate\r\neveryone's time. Alright, we"
      },"hidden":False,"userData":"null"
    },{
      "id":"5947406c-59c5-422a-9b02-224fad3de895","type":"transcript","start":"PT1H3M59.03S","end":"PT1H4M2.935S","eventData":{
        "type":"caption","language":"en","text":"might have to do lightning\r\nround, so let's just let's start"
      },"hidden":False,"userData":"null"
    },{
      "id":"d975c2be-398d-4c04-9e90-1397facc9a10","type":"transcript","start":"PT1H4M2.935S","end":"PT1H4M6.84S","eventData":{
        "type":"caption","language":"en","text":"first question with the most\r\nnumber of likes is with the"
      },"hidden":False,"userData":"null"
    },{
      "id":"31791aca-799c-4270-9047-07c983ddb94e","type":"transcript","start":"PT1H4M6.84S","end":"PT1H4M8.97S","eventData":{
        "type":"caption","language":"en","text":"latest round of voluntary\r\nseparation packages,"
      },"hidden":False,"userData":"null"
    },{
      "id":"2342f327-e851-4768-a672-80df58296962","type":"transcript","start":"PT1H4M8.97S","end":"PT1H4M12.165S","eventData":{
        "type":"caption","language":"en","text":"incentivizing some of our most\r\nexperienced employees to leave."
      },"hidden":False,"userData":"null"
    },{
      "id":"8cf6e7e7-c7ad-49f2-b3ae-e5b398622e25","type":"transcript","start":"PT1H4M12.165S","end":"PT1H4M16.07S","eventData":{
        "type":"caption","language":"en","text":"The company has the SLT factored\r\nthis loss of valuable experience"
      },"hidden":False,"userData":"null"
    },{
      "id":"a9d81f9c-eb0c-4c89-8a17-4b2a8b151391","type":"transcript","start":"PT1H4M16.07S","end":"PT1H4M18.2S","eventData":{
        "type":"caption","language":"en","text":"into their stint plans for the"
      },"hidden":False,"userData":"null"
    },{
      "id":"0de892c8-1657-49d4-bfba-fc00bb43dfaa","type":"transcript","start":"PT1H4M18.2S","end":"PT1H4M21.403S","eventData":{
        "type":"caption","language":"en","text":"coming year? Maybe I'll ask\r\nJeff to take that one, and"
      },"hidden":False,"userData":"null"
    },{
      "id":"413bc2bf-ba0c-4088-b737-4cf4e1cd4bde","type":"transcript","start":"PT1H4M21.403S","end":"PT1H4M23.536S","eventData":{
        "type":"caption","language":"en","text":"if anyone else wants to add\r\nthat, be great."
      },"hidden":False,"userData":"null"
    },{
      "id":"1ad3b413-9d7d-4fff-b097-c0db5bda4534","type":"transcript","start":"PT1H4M24.84S","end":"PT1H4M28.9S","eventData":{
        "type":"caption","language":"en","text":"Sure, thanks Alexian. Obviously\r\na great question based upon the"
      },"hidden":False,"userData":"null"
    },{
      "id":"857b9b94-836c-4d4d-b617-c60dd2cf04ef","type":"transcript","start":"PT1H4M28.9S","end":"PT1H4M34.178S","eventData":{
        "type":"caption","language":"en","text":"number of likes on that I I\r\nguess I'd start by just making"
      },"hidden":False,"userData":"null"
    },{
      "id":"cd0b5486-a3d1-4790-94f7-dbe1ffba629e","type":"transcript","start":"PT1H4M34.178S","end":"PT1H4M38.644S","eventData":{
        "type":"caption","language":"en","text":"sure that I state clearly that\r\nthe voluntary program is not"
      },"hidden":False,"userData":"null"
    },{
      "id":"142b5d4f-d50e-46ca-9f60-5fd33f50e10d","type":"transcript","start":"PT1H4M38.644S","end":"PT1H4M41.486S","eventData":{
        "type":"caption","language":"en","text":"intended to incentivize\r\nexperience employees to leave,"
      },"hidden":False,"userData":"null"
    },{
      "id":"1730f0df-580a-4867-84f5-c0e250efc531","type":"transcript","start":"PT1H4M41.486S","end":"PT1H4M46.358S","eventData":{
        "type":"caption","language":"en","text":"but it was very much intended to\r\ngive our employees more control"
      },"hidden":False,"userData":"null"
    },{
      "id":"0ece9655-7185-4066-bca7-6d7310c62c9a","type":"transcript","start":"PT1H4M46.358S","end":"PT1H4M47.576S","eventData":{
        "type":"caption","language":"en","text":"of the process."
      },"hidden":False,"userData":"null"
    },{
      "id":"5c11638a-e738-4ce9-bb20-e1fa3226bedb","type":"transcript","start":"PT1H4M48.18S","end":"PT1H4M52.404S","eventData":{
        "type":"caption","language":"en","text":"Um and the reality is, many\r\nemployees may be thinking about"
      },"hidden":False,"userData":"null"
    },{
      "id":"5e2910a7-41bc-49e6-8b92-bea40ede2a0e","type":"transcript","start":"PT1H4M52.404S","end":"PT1H4M55.86S","eventData":{
        "type":"caption","language":"en","text":"change for different reasons.\r\nMight be a change associated"
      },"hidden":False,"userData":"null"
    },{
      "id":"52e36058-f830-4b3a-98e1-902c2b23c5a2","type":"transcript","start":"PT1H4M55.86S","end":"PT1H4M59.7S","eventData":{
        "type":"caption","language":"en","text":"with work location. Might be a\r\nchange associated with just"
      },"hidden":False,"userData":"null"
    },{
      "id":"7707f476-7dc9-436b-ad4e-9c55aadf0170","type":"transcript","start":"PT1H4M59.7S","end":"PT1H5M5.076S","eventData":{
        "type":"caption","language":"en","text":"wanting to take time off. Might\r\nbe a change in Karere and yes it"
      },"hidden":False,"userData":"null"
    },{
      "id":"43c5ca94-7914-4b3e-ae07-4c7ab3fb4fa4","type":"transcript","start":"PT1H5M5.076S","end":"PT1H5M9.3S","eventData":{
        "type":"caption","language":"en","text":"it may be a change associated\r\nwith their impending or desired"
      },"hidden":False,"userData":"null"
    },{
      "id":"54b69234-5fd0-4233-b5d5-4b5494d59d42","type":"transcript","start":"PT1H5M9.3S","end":"PT1H5M13.524S","eventData":{
        "type":"caption","language":"en","text":"retirement. So it adds a huge\r\namount of complexity and it"
      },"hidden":False,"userData":"null"
    },{
      "id":"36fcfbd8-710b-4415-8606-3088f307b046","type":"transcript","start":"PT1H5M13.524S","end":"PT1H5M18.132S","eventData":{
        "type":"caption","language":"en","text":"opens us up to losing control of\r\nthe process, which is not"
      },"hidden":False,"userData":"null"
    },{
      "id":"a9de5942-f771-4863-a95e-7328b673027e","type":"transcript","start":"PT1H5M18.132S","end":"PT1H5M20.82S","eventData":{
        "type":"caption","language":"en","text":"something we would typically\r\nvolunteer to do."
      },"hidden":False,"userData":"null"
    },{
      "id":"2f787bc3-dbef-451c-85d0-5dfc9d78abd3","type":"transcript","start":"PT1H5M21.22S","end":"PT1H5M24.262S","eventData":{
        "type":"caption","language":"en","text":"Uh, but we understand the\r\nimplications associated with it."
      },"hidden":False,"userData":"null"
    },{
      "id":"54161aa9-3932-4599-848d-fd39fc25a8c5","type":"transcript","start":"PT1H5M24.262S","end":"PT1H5M27.98S","eventData":{
        "type":"caption","language":"en","text":"An it without question requires\r\nus to think about people who"
      },"hidden":False,"userData":"null"
    },{
      "id":"06431f30-d600-4020-a94c-231eda3e4de7","type":"transcript","start":"PT1H5M27.98S","end":"PT1H5M31.36S","eventData":{
        "type":"caption","language":"en","text":"have elected to take the\r\nvoluntary program based upon the"
      },"hidden":False,"userData":"null"
    },{
      "id":"7a3910c0-fd56-4f6c-8334-cf88234ce0b6","type":"transcript","start":"PT1H5M31.36S","end":"PT1H5M36.092S","eventData":{
        "type":"caption","language":"en","text":"skills we need and it it needs\r\nto be factored into not only our"
      },"hidden":False,"userData":"null"
    },{
      "id":"528c28f5-1f56-43a1-ac72-b4b70b189bdd","type":"transcript","start":"PT1H5M36.092S","end":"PT1H5M40.148S","eventData":{
        "type":"caption","language":"en","text":"future plans but also our our\r\nplans are on our strategy, but"
      },"hidden":False,"userData":"null"
    },{
      "id":"c04b03b6-279e-44f1-9aa2-5e20dcebaafd","type":"transcript","start":"PT1H5M40.148S","end":"PT1H5M44.542S","eventData":{
        "type":"caption","language":"en","text":"also our plans around are hiring\r\nprogram and so forth, so it's a"
      },"hidden":False,"userData":"null"
    },{
      "id":"b4f842c3-9a4a-4d5c-958f-4d5b08a16514","type":"transcript","start":"PT1H5M44.542S","end":"PT1H5M48.26S","eventData":{
        "type":"caption","language":"en","text":"great question, but I just\r\nwanted to make sure that it's"
      },"hidden":False,"userData":"null"
    },{
      "id":"766cb13c-65c0-4b76-81fe-4401be8bf871","type":"transcript","start":"PT1H5M48.26S","end":"PT1H5M51.64S","eventData":{
        "type":"caption","language":"en","text":"goes without. It's definitely\r\nnotice that will need to hire"
      },"hidden":False,"userData":"null"
    },{
      "id":"37783706-2f6d-44cf-b7f8-4eb467f95903","type":"transcript","start":"PT1H5M51.64S","end":"PT1H5M56.034S","eventData":{
        "type":"caption","language":"en","text":"back certain skills, but we want\r\nto make sure that we give in."
      },"hidden":False,"userData":"null"
    },{
      "id":"d3676fb8-1402-47e9-93ae-ff98f6989ba8","type":"transcript","start":"PT1H5M56.19S","end":"PT1H6M0.128S","eventData":{
        "type":"caption","language":"en","text":"Boys as much control over\r\nthis process as we can, given"
      },"hidden":False,"userData":"null"
    },{
      "id":"287928b6-a354-49c6-b35f-10be09454d15","type":"transcript","start":"PT1H6M0.128S","end":"PT1H6M2.992S","eventData":{
        "type":"caption","language":"en","text":"the unfortunate situation we\r\nare associated with the"
      },"hidden":False,"userData":"null"
    },{
      "id":"ccd97291-04cc-4ac4-8689-d8f02aa5d78f","type":"transcript","start":"PT1H6M2.992S","end":"PT1H6M4.424S","eventData":{
        "type":"caption","language":"en","text":"decline in overall market."
      },"hidden":False,"userData":"null"
    },{
      "id":"aba64e85-156b-4e80-86d3-85e382ff03e7","type":"transcript","start":"PT1H6M6.42S","end":"PT1H6M8.932S","eventData":{
        "type":"caption","language":"en","text":"Yeah I I would just add that you"
      },"hidden":False,"userData":"null"
    },{
      "id":"6e8d522d-c4e4-4526-93d7-bcc4d78f93c6","type":"transcript","start":"PT1H6M8.932S","end":"PT1H6M14.884S","eventData":{
        "type":"caption","language":"en","text":"know. Um, so this week is marks\r\nmy 26 years. It's inside a an I"
      },"hidden":False,"userData":"null"
    },{
      "id":"b599923c-8b89-40f2-97cd-e68feca2b42b","type":"transcript","start":"PT1H6M14.884S","end":"PT1H6M19.216S","eventData":{
        "type":"caption","language":"en","text":"can tell you we've been through\r\nups and downs like this before"
      },"hidden":False,"userData":"null"
    },{
      "id":"740dda30-9625-44b9-a7fe-a16aa02203ae","type":"transcript","start":"PT1H6M19.216S","end":"PT1H6M24.27S","eventData":{
        "type":"caption","language":"en","text":"and it's never easy to lose to\r\nlose people you know and but it"
      },"hidden":False,"userData":"null"
    },{
      "id":"5bfc0a5f-cf16-4826-879f-d1d2febb92e6","type":"transcript","start":"PT1H6M24.27S","end":"PT1H6M27.88S","eventData":{
        "type":"caption","language":"en","text":"is a natural part of any\r\norganization's life. People come"
      },"hidden":False,"userData":"null"
    },{
      "id":"8cb26c53-4f8c-4707-91fe-716213d4829f","type":"transcript","start":"PT1H6M27.88S","end":"PT1H6M31.851S","eventData":{
        "type":"caption","language":"en","text":"in. People go. People have long\r\ncareers, they retire. And it's"
      },"hidden":False,"userData":"null"
    },{
      "id":"8833a2d2-77fc-4cb5-9fb0-b8a56be65334","type":"transcript","start":"PT1H6M31.851S","end":"PT1H6M36.544S","eventData":{
        "type":"caption","language":"en","text":"important that we realize that\r\nthis is part of a cycle and that"
      },"hidden":False,"userData":"null"
    },{
      "id":"4970cfc8-460c-4703-b10a-4eff361b98b3","type":"transcript","start":"PT1H6M36.544S","end":"PT1H6M40.154S","eventData":{
        "type":"caption","language":"en","text":"we do plan for that and manage\r\nfor that but."
      },"hidden":False,"userData":"null"
    },{
      "id":"5c686554-d22a-4095-8cd3-5540dd4f24bf","type":"transcript","start":"PT1H6M40.28S","end":"PT1H6M44.444S","eventData":{
        "type":"caption","language":"en","text":"Most importantly, I'd leave you\r\nwith when we went through a very"
      },"hidden":False,"userData":"null"
    },{
      "id":"aa3a1811-56df-4507-b48b-2440c6bbd526","type":"transcript","start":"PT1H6M44.444S","end":"PT1H6M48.608S","eventData":{
        "type":"caption","language":"en","text":"similar experience back in 08\r\nand 09. You know we had very"
      },"hidden":False,"userData":"null"
    },{
      "id":"7f8f90af-7044-445c-8724-3131114300f0","type":"transcript","start":"PT1H6M48.608S","end":"PT1H6M52.425S","eventData":{
        "type":"caption","language":"en","text":"experienced people leave the\r\ncompany back then as well, and I"
      },"hidden":False,"userData":"null"
    },{
      "id":"4806d8f6-4247-407b-a548-7cd8513ed018","type":"transcript","start":"PT1H6M52.425S","end":"PT1H6M56.936S","eventData":{
        "type":"caption","language":"en","text":"can tell you that the years\r\nafter that we saw some of our"
      },"hidden":False,"userData":"null"
    },{
      "id":"df42e87e-de2f-49e3-a1f3-3e53e4e2f03c","type":"transcript","start":"PT1H6M56.936S","end":"PT1H7M1.1S","eventData":{
        "type":"caption","language":"en","text":"highest growth. We became laser\r\nfocused on what we needed to do."
      },"hidden":False,"userData":"null"
    },{
      "id":"e94eb01f-afdd-4cbd-b57f-4dcbf39a3633","type":"transcript","start":"PT1H7M1.1S","end":"PT1H7M4.917S","eventData":{
        "type":"caption","language":"en","text":"We took advantage of rising\r\nmarkets when they did come back,"
      },"hidden":False,"userData":"null"
    },{
      "id":"7a6c6724-e8c6-4f2b-b3b8-c34c8ca1a8be","type":"transcript","start":"PT1H7M4.917S","end":"PT1H7M9.428S","eventData":{
        "type":"caption","language":"en","text":"but we really had a renewed\r\nsense of purpose of what we had"
      },"hidden":False,"userData":"null"
    },{
      "id":"d76af943-237f-4d5b-a3a4-7449b8468a99","type":"transcript","start":"PT1H7M9.428S","end":"PT1H7M10.816S","eventData":{
        "type":"caption","language":"en","text":"to do. So it's."
      },"hidden":False,"userData":"null"
    },{
      "id":"37be2b79-514f-4b56-b8d9-d3a451d9114d","type":"transcript","start":"PT1H7M10.97S","end":"PT1H7M14.534S","eventData":{
        "type":"caption","language":"en","text":"Again, it's always tough to\r\nlose people into those who are"
      },"hidden":False,"userData":"null"
    },{
      "id":"cd705a25-9bbd-47e6-a6bb-31f0b631d4fd","type":"transcript","start":"PT1H7M14.534S","end":"PT1H7M18.422S","eventData":{
        "type":"caption","language":"en","text":"leaving who we won't be able to\r\nsee necessarily. I say good"
      },"hidden":False,"userData":"null"
    },{
      "id":"6ad1724f-c817-40aa-9af1-2d36c6b1223c","type":"transcript","start":"PT1H7M18.422S","end":"PT1H7M21.662S","eventData":{
        "type":"caption","language":"en","text":"luck in your future endeavors,\r\nbut you know, let's stay"
      },"hidden":False,"userData":"null"
    },{
      "id":"9aba83f1-39cf-4c27-a575-8aad592f4662","type":"transcript","start":"PT1H7M21.662S","end":"PT1H7M25.226S","eventData":{
        "type":"caption","language":"en","text":"focused, and let's make sure\r\nthat we were in the markets."
      },"hidden":False,"userData":"null"
    },{
      "id":"f5c20cc9-c5eb-4d5a-89e2-461f2e7e519b","type":"transcript","start":"PT1H7M25.226S","end":"PT1H7M28.466S","eventData":{
        "type":"caption","language":"en","text":"Come back that we are\r\nsuccessful and like I said"
      },"hidden":False,"userData":"null"
    },{
      "id":"a92a3c2a-7da0-4bd9-a63a-6d6bd83d1d91","type":"transcript","start":"PT1H7M28.466S","end":"PT1H7M33.002S","eventData":{
        "type":"caption","language":"en","text":"before, I know that we can do\r\nthat as a as a company. We've"
      },"hidden":False,"userData":"null"
    },{
      "id":"408940de-b18d-4094-9c2d-b0f27987796d","type":"transcript","start":"PT1H7M33.002S","end":"PT1H7M33.974S","eventData":{
        "type":"caption","language":"en","text":"done it before."
      },"hidden":False,"userData":"null"
    },{
      "id":"409a04df-cb31-4ed2-b87a-3c0472cb2012","type":"transcript","start":"PT1H7M37.07S","end":"PT1H7M41.02S","eventData":{
        "type":"caption","language":"en","text":"Alright, thank you George. Thank\r\nyou Jeff. Next question is"
      },"hidden":False,"userData":"null"
    },{
      "id":"941352bc-4f7f-4f7f-85bd-247c02bb8852","type":"transcript","start":"PT1H7M41.02S","end":"PT1H7M44.575S","eventData":{
        "type":"caption","language":"en","text":"actually a couple of questions\r\non um investment in"
      },"hidden":False,"userData":"null"
    },{
      "id":"b8e346c9-cedf-4b18-ab65-6215a9f119a2","type":"transcript","start":"PT1H7M44.575S","end":"PT1H7M48.13S","eventData":{
        "type":"caption","language":"en","text":"manufacturing in China. So has\r\nCOVID-19 highlighted the over"
      },"hidden":False,"userData":"null"
    },{
      "id":"e589f44e-a244-4493-8462-fa9d057328c1","type":"transcript","start":"PT1H7M48.13S","end":"PT1H7M51.685S","eventData":{
        "type":"caption","language":"en","text":"reliance and possible over\r\ninvestment in China. Now we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"ebf8d785-3b06-44ac-909c-760aec2f8535","type":"transcript","start":"PT1H7M51.685S","end":"PT1H7M55.24S","eventData":{
        "type":"caption","language":"en","text":"planning on reducing our\r\ndependency in China and there's"
      },"hidden":False,"userData":"null"
    },{
      "id":"f0dc6fac-dedc-4c17-9679-b1bf483766df","type":"transcript","start":"PT1H7M55.24S","end":"PT1H7M59.19S","eventData":{
        "type":"caption","language":"en","text":"also a a good question by\r\nFrederick David talking about"
      },"hidden":False,"userData":"null"
    },{
      "id":"c274f6c3-8496-45e6-a3e8-17e63fd9cc60","type":"transcript","start":"PT1H7M59.19S","end":"PT1H8M2.745S","eventData":{
        "type":"caption","language":"en","text":"hot perspective of possibly\r\nreducing dependence in China and"
      },"hidden":False,"userData":"null"
    },{
      "id":"b31a1fbe-e9c0-4fce-bc29-45bdfb8d2eec","type":"transcript","start":"PT1H8M2.745S","end":"PT1H8M5.115S","eventData":{
        "type":"caption","language":"en","text":"extending manufacturing in\r\nAmerica's and Europe."
      },"hidden":False,"userData":"null"
    },{
      "id":"7589114e-381a-40be-8048-d86a4d3a56e7","type":"transcript","start":"PT1H8M6.57S","end":"PT1H8M9.606S","eventData":{
        "type":"caption","language":"en","text":"Just want take that and maybe\r\nHans if you have anything to"
      },"hidden":False,"userData":"null"
    },{
      "id":"cd4ecb2a-fdc7-4257-bee1-dbd2d50d6c43","type":"transcript","start":"PT1H8M9.606S","end":"PT1H8M13.938S","eventData":{
        "type":"caption","language":"en","text":"add. Yeah, that that would be\r\ngreat, so I guess I would"
      },"hidden":False,"userData":"null"
    },{
      "id":"77e3de14-10f2-49cc-bca2-0268d332f165","type":"transcript","start":"PT1H8M13.938S","end":"PT1H8M17.106S","eventData":{
        "type":"caption","language":"en","text":"start with the fact that\r\nChina is such a large market"
      },"hidden":False,"userData":"null"
    },{
      "id":"35f53fb4-9bb8-4528-9cd9-92e5801c42f5","type":"transcript","start":"PT1H8M17.106S","end":"PT1H8M19.41S","eventData":{
        "type":"caption","language":"en","text":"that any global company\r\ncannot ignore the market."
      },"hidden":False,"userData":"null"
    },{
      "id":"73af1bf7-d1a3-4713-ab02-2152f41448f0","type":"transcript","start":"PT1H8M20.44S","end":"PT1H8M23.52S","eventData":{
        "type":"caption","language":"en","text":"So both from a market\r\nopportunity, revenue standpoint,"
      },"hidden":False,"userData":"null"
    },{
      "id":"f0a66ddb-4f0b-49a6-826d-b63935a20eee","type":"transcript","start":"PT1H8M23.52S","end":"PT1H8M27.37S","eventData":{
        "type":"caption","language":"en","text":"talent base and manufacturing\r\nstandpoint, it is a market that"
      },"hidden":False,"userData":"null"
    },{
      "id":"ab01796d-2622-42f5-bc9d-a1c151f4325c","type":"transcript","start":"PT1H8M27.37S","end":"PT1H8M31.605S","eventData":{
        "type":"caption","language":"en","text":"cannot be ignored. We need to\r\nmake sure that we're investing"
      },"hidden":False,"userData":"null"
    },{
      "id":"e0618ace-762d-4215-be73-5060d3fc820e","type":"transcript","start":"PT1H8M31.605S","end":"PT1H8M36.61S","eventData":{
        "type":"caption","language":"en","text":"their, uh, as you all know\r\nthat's been a focus area for us."
      },"hidden":False,"userData":"null"
    },{
      "id":"efb9ae0d-f2b5-408a-9051-64ac51059979","type":"transcript","start":"PT1H8M36.61S","end":"PT1H8M38.15S","eventData":{
        "type":"caption","language":"en","text":"Having said all that."
      },"hidden":False,"userData":"null"
    },{
      "id":"409fa793-be50-4e33-a084-da4e441b784d","type":"transcript","start":"PT1H8M38.89S","end":"PT1H8M43.39S","eventData":{
        "type":"caption","language":"en","text":"Clearly the tension between US\r\nin China makes all of our jobs"
      },"hidden":False,"userData":"null"
    },{
      "id":"21ac4a3f-a031-485c-8194-2046c29891fd","type":"transcript","start":"PT1H8M43.39S","end":"PT1H8M47.89S","eventData":{
        "type":"caption","language":"en","text":"much more difficult in terms of\r\ngetting done. What we need to."
      },"hidden":False,"userData":"null"
    },{
      "id":"296b7f89-d4ee-47e6-b669-1642c047ab76","type":"transcript","start":"PT1H8M48.68S","end":"PT1H8M53.373S","eventData":{
        "type":"caption","language":"en","text":"And we have been aiming for some\r\ntime to develop a region for"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6628fa5-4c71-424a-9c01-841965ef11a0","type":"transcript","start":"PT1H8M53.373S","end":"PT1H8M57.344S","eventData":{
        "type":"caption","language":"en","text":"region strategy. What what that\r\nmeans is that we're lining the"
      },"hidden":False,"userData":"null"
    },{
      "id":"a1d3d130-0693-488a-87fc-817bf1366fba","type":"transcript","start":"PT1H8M57.344S","end":"PT1H9M1.676S","eventData":{
        "type":"caption","language":"en","text":"best we can. The supply chain\r\nwith the customer base in those"
      },"hidden":False,"userData":"null"
    },{
      "id":"6239d708-6b95-445a-8304-f20b680eeaca","type":"transcript","start":"PT1H9M1.676S","end":"PT1H9M4.925S","eventData":{
        "type":"caption","language":"en","text":"regions. And obviously that's\r\ngood for customers. It's also"
      },"hidden":False,"userData":"null"
    },{
      "id":"606ce991-db40-4e79-b0b4-a8d9ec4fbdde","type":"transcript","start":"PT1H9M4.925S","end":"PT1H9M9.257S","eventData":{
        "type":"caption","language":"en","text":"good to reduce overall risk for\r\nus as an organization, but the"
      },"hidden":False,"userData":"null"
    },{
      "id":"25e5a157-833c-4c91-ba21-04c802d52d41","type":"transcript","start":"PT1H9M9.257S","end":"PT1H9M13.95S","eventData":{
        "type":"caption","language":"en","text":"punch line is, it is such a\r\nlarge market that it just can't"
      },"hidden":False,"userData":"null"
    },{
      "id":"d628c48a-9e31-4f72-bb85-67bf268bc350","type":"transcript","start":"PT1H9M13.95S","end":"PT1H9M17.199S","eventData":{
        "type":"caption","language":"en","text":"be ignored and we're constantly\r\nbalancing where our investments"
      },"hidden":False,"userData":"null"
    },{
      "id":"fef08cc8-b977-44bc-8825-c1aa7e0deb0e","type":"transcript","start":"PT1H9M17.199S","end":"PT1H9M19.365S","eventData":{
        "type":"caption","language":"en","text":"are to make sure that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"2216533c-b212-4439-8a26-f916ef1cb6d4","type":"transcript","start":"PT1H9M19.365S","end":"PT1H9M21.364S","eventData":{
        "type":"caption","language":"en","text":"optimize. The outcome\r\nfor us as a company."
      },"hidden":False,"userData":"null"
    },{
      "id":"440f0cae-d351-4837-985b-ff4f8aca0bb5","type":"transcript","start":"PT1H9M23.89S","end":"PT1H9M30.302S","eventData":{
        "type":"caption","language":"en","text":"Maybe I add a few words on that,\r\nso from a growth perspective I"
      },"hidden":False,"userData":"null"
    },{
      "id":"af999114-e417-4e12-9d96-a70d998c9caa","type":"transcript","start":"PT1H9M30.302S","end":"PT1H9M35.34S","eventData":{
        "type":"caption","language":"en","text":"think, uhm, we have started to\r\nlook at China differently over"
      },"hidden":False,"userData":"null"
    },{
      "id":"6c7124ac-cee0-463b-b2c2-fc06b0e01db0","type":"transcript","start":"PT1H9M35.34S","end":"PT1H9M39.004S","eventData":{
        "type":"caption","language":"en","text":"the last few years.\r\nHistorically, China was largely"
      },"hidden":False,"userData":"null"
    },{
      "id":"354bff05-71ba-45a1-a743-882c7a5fabdb","type":"transcript","start":"PT1H9M39.004S","end":"PT1H9M43.126S","eventData":{
        "type":"caption","language":"en","text":"copying ideas and technologies\r\nfrom the so called Western"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd03bdac-5c81-45e9-8d1d-59a36ef1397f","type":"transcript","start":"PT1H9M43.126S","end":"PT1H9M46.79S","eventData":{
        "type":"caption","language":"en","text":"world, whereas now real\r\ninnovation is happening in"
      },"hidden":False,"userData":"null"
    },{
      "id":"771d087b-bf7a-4091-b973-102aaaf2b7bb","type":"transcript","start":"PT1H9M46.79S","end":"PT1H9M53.202S","eventData":{
        "type":"caption","language":"en","text":"China. So I think we need to\r\nlook at China is not just a"
      },"hidden":False,"userData":"null"
    },{
      "id":"748005a3-188e-4ede-b60b-a4ad067e893c","type":"transcript","start":"PT1H9M53.202S","end":"PT1H9M57.799S","eventData":{
        "type":"caption","language":"en","text":"manufacturing center. Uh, but it\r\nalso has an innovation hub. Uhm,"
      },"hidden":False,"userData":"null"
    },{
      "id":"34fdcf38-4109-4623-9e01-32a3191c4000","type":"transcript","start":"PT1H9M57.799S","end":"PT1H9M59.965S","eventData":{
        "type":"caption","language":"en","text":"so we need to devote more"
      },"hidden":False,"userData":"null"
    },{
      "id":"3736034c-2719-4da7-922e-833e147d4ee4","type":"transcript","start":"PT1H9M59.965S","end":"PT1H10M2.714S","eventData":{
        "type":"caption","language":"en","text":"resources. Business development\r\nresources. Emanet resources and"
      },"hidden":False,"userData":"null"
    },{
      "id":"b2425a1f-5301-4d73-bf77-dbe0e3107e59","type":"transcript","start":"PT1H10M2.714S","end":"PT1H10M7.082S","eventData":{
        "type":"caption","language":"en","text":"so on. Uh, in China to really,\r\nuh, you know, capture the"
      },"hidden":False,"userData":"null"
    },{
      "id":"1910d1c1-e3e1-42fd-bbfa-221ebe982d4b","type":"transcript","start":"PT1H10M7.082S","end":"PT1H10M9.994S","eventData":{
        "type":"caption","language":"en","text":"opportunities that is created\r\nthrough this knew very"
      },"hidden":False,"userData":"null"
    },{
      "id":"c7942cea-50e8-4824-9a31-436782f90f04","type":"transcript","start":"PT1H10M9.994S","end":"PT1H10M13.998S","eventData":{
        "type":"caption","language":"en","text":"innovative companies that are\r\npopping up in China and we can"
      },"hidden":False,"userData":"null"
    },{
      "id":"7585bc9c-64b2-437c-be11-9f0375db1b88","type":"transcript","start":"PT1H10M13.998S","end":"PT1H10M16.91S","eventData":{
        "type":"caption","language":"en","text":"therefore take those\r\ntechnologies in those ideas and"
      },"hidden":False,"userData":"null"
    },{
      "id":"897c6163-08d0-4d96-851a-57f411756414","type":"transcript","start":"PT1H10M16.91S","end":"PT1H10M21.642S","eventData":{
        "type":"caption","language":"en","text":"spam them. Sort of back to the\r\nso called Western world. So I"
      },"hidden":False,"userData":"null"
    },{
      "id":"b831d267-9cc4-4e09-8390-abe9076bfdfb","type":"transcript","start":"PT1H10M21.642S","end":"PT1H10M26.374S","eventData":{
        "type":"caption","language":"en","text":"think that's a big change and I\r\nthink we need to accelerate that"
      },"hidden":False,"userData":"null"
    },{
      "id":"a98fb01e-8303-4323-acd1-8e82d6fe82af","type":"transcript","start":"PT1H10M26.374S","end":"PT1H10M31.341S","eventData":{
        "type":"caption","language":"en","text":"that initiative. You know, Hans.\r\nThis is one eight if I can just"
      },"hidden":False,"userData":"null"
    },{
      "id":"7e92dff1-ffe9-4820-a62c-84652c5972b5","type":"transcript","start":"PT1H10M31.341S","end":"PT1H10M35.193S","eventData":{
        "type":"caption","language":"en","text":"add to that, I think we are\r\nalready seeing China lead the"
      },"hidden":False,"userData":"null"
    },{
      "id":"e8300a31-ccf6-4786-b9bc-e2515940f0ef","type":"transcript","start":"PT1H10M35.193S","end":"PT1H10M38.082S","eventData":{
        "type":"caption","language":"en","text":"world as it comes to a\r\nacceleration of electric"
      },"hidden":False,"userData":"null"
    },{
      "id":"5bf92cd2-30f3-4882-b2e5-908275ec63fa","type":"transcript","start":"PT1H10M38.082S","end":"PT1H10M42.255S","eventData":{
        "type":"caption","language":"en","text":"vehicles. We have already seen a\r\nbig part of the bus fleet in"
      },"hidden":False,"userData":"null"
    },{
      "id":"58461a96-fc44-49e7-a7e8-a52c68c28acc","type":"transcript","start":"PT1H10M42.255S","end":"PT1H10M45.465S","eventData":{
        "type":"caption","language":"en","text":"China. Electrify. And now that\r\ntechnology is coming to the"
      },"hidden":False,"userData":"null"
    },{
      "id":"4594b024-9103-4435-abc0-02ca8eb1725d","type":"transcript","start":"PT1H10M45.465S","end":"PT1H10M47.07S","eventData":{
        "type":"caption","language":"en","text":"other parts of the world."
      },"hidden":False,"userData":"null"
    },{
      "id":"7fc7168f-8621-4f6b-a81b-f02a1d8f7304","type":"transcript","start":"PT1H10M47.91S","end":"PT1H10M52.365S","eventData":{
        "type":"caption","language":"en","text":"I today talked about industrial\r\niot and when we think about"
      },"hidden":False,"userData":"null"
    },{
      "id":"8805f6ff-bdd5-42a2-a18c-c0e93e0f85cf","type":"transcript","start":"PT1H10M52.365S","end":"PT1H10M54.39S","eventData":{
        "type":"caption","language":"en","text":"industry 4.0 or iot within"
      },"hidden":False,"userData":"null"
    },{
      "id":"01b13842-4495-409b-a9fd-59e5283b07ed","type":"transcript","start":"PT1H10M54.39S","end":"PT1H10M59.543S","eventData":{
        "type":"caption","language":"en","text":"factories. 8 or 10 pilots are\r\ntoday happening in China, and so"
      },"hidden":False,"userData":"null"
    },{
      "id":"216048c8-1bca-47dc-b42b-30f8d311e6a2","type":"transcript","start":"PT1H10M59.543S","end":"PT1H11M4.485S","eventData":{
        "type":"caption","language":"en","text":"it's very clear to us that in\r\norder for us to be meaningful in"
      },"hidden":False,"userData":"null"
    },{
      "id":"28589b66-5b8b-402d-9ee7-06b90ecb0604","type":"transcript","start":"PT1H11M4.485S","end":"PT1H11M9.074S","eventData":{
        "type":"caption","language":"en","text":"industrial iot, we will have to\r\nbe a major player in the China"
      },"hidden":False,"userData":"null"
    },{
      "id":"780f8dbb-29c9-46dd-a812-050fe259b14b","type":"transcript","start":"PT1H11M9.074S","end":"PT1H11M12.251S","eventData":{
        "type":"caption","language":"en","text":"market. Whether it's with local\r\nmanufacturers or with global"
      },"hidden":False,"userData":"null"
    },{
      "id":"f4b4e887-4eca-49f0-8665-ae599f348de2","type":"transcript","start":"PT1H11M12.251S","end":"PT1H11M15.075S","eventData":{
        "type":"caption","language":"en","text":"manufacturers, global companies\r\nmanufacturing in China, and so"
      },"hidden":False,"userData":"null"
    },{
      "id":"c19b5fea-960c-4208-9cbc-a854e9e23deb","type":"transcript","start":"PT1H11M15.075S","end":"PT1H11M19.311S","eventData":{
        "type":"caption","language":"en","text":"the importance of China as we\r\nlook ahead continues to be more"
      },"hidden":False,"userData":"null"
    },{
      "id":"69ecd668-8dc5-49ea-afc1-07282d09c8f5","type":"transcript","start":"PT1H11M19.311S","end":"PT1H11M20.723S","eventData":{
        "type":"caption","language":"en","text":"and more strategic and."
      },"hidden":False,"userData":"null"
    },{
      "id":"e7865914-bc9d-4b98-8435-8bfd9c32d7fe","type":"transcript","start":"PT1H11M22.02S","end":"PT1H11M25.404S","eventData":{
        "type":"caption","language":"en","text":"It is less about using China\r\nas a manufacturing base as Han"
      },"hidden":False,"userData":"null"
    },{
      "id":"bdca1f90-8f39-405d-b144-df88aa19a72e","type":"transcript","start":"PT1H11M25.404S","end":"PT1H11M28.506S","eventData":{
        "type":"caption","language":"en","text":"said, it's more about making\r\nsure that we are innovating in"
      },"hidden":False,"userData":"null"
    },{
      "id":"62d29d66-b840-41ac-895d-25e48bfc36f5","type":"transcript","start":"PT1H11M28.506S","end":"PT1H11M31.044S","eventData":{
        "type":"caption","language":"en","text":"China to serve the needs of\r\nthe local market."
      },"hidden":False,"userData":"null"
    },{
      "id":"4ece6b9f-da5f-4e29-9d96-fd8598cacc3d","type":"transcript","start":"PT1H11M37.44S","end":"PT1H11M41.88S","eventData":{
        "type":"caption","language":"en","text":"Perfect thank you. All next\r\nquestion comes from an AM and a"
      },"hidden":False,"userData":"null"
    },{
      "id":"01fa101b-cf6c-4f70-aee2-254c176cdee6","type":"transcript","start":"PT1H11M41.88S","end":"PT1H11M45.58S","eventData":{
        "type":"caption","language":"en","text":"strategy. So in the last few\r\nyears we bought several"
      },"hidden":False,"userData":"null"
    },{
      "id":"cf982517-f39c-4d48-9601-268aad0df60e","type":"transcript","start":"PT1H11M45.58S","end":"PT1H11M48.91S","eventData":{
        "type":"caption","language":"en","text":"businesses which have not met\r\nthe true financial, operational"
      },"hidden":False,"userData":"null"
    },{
      "id":"deec8dd9-78dd-4100-85bf-4613b57dbf52","type":"transcript","start":"PT1H11M48.91S","end":"PT1H11M52.98S","eventData":{
        "type":"caption","language":"en","text":"quality. Intent of Syncada. Are\r\nwe putting more intention to the"
      },"hidden":False,"userData":"null"
    },{
      "id":"8128ae3d-7376-45aa-9ff1-9995147ed096","type":"transcript","start":"PT1H11M52.98S","end":"PT1H11M56.68S","eventData":{
        "type":"caption","language":"en","text":"finer details for future\r\npurchases and if yes, what will"
      },"hidden":False,"userData":"null"
    },{
      "id":"a7a2260a-6fa4-425f-8f78-f6a406331db2","type":"transcript","start":"PT1H11M56.68S","end":"PT1H12M0.75S","eventData":{
        "type":"caption","language":"en","text":"be the change and maybe I'll ask\r\ncons to address that."
      },"hidden":False,"userData":"null"
    },{
      "id":"d351ae47-3d12-4d13-a859-d55b03412c5d","type":"transcript","start":"PT1H12M1.62S","end":"PT1H12M7.576S","eventData":{
        "type":"caption","language":"en","text":"Sure. Uh, well, first I, I guess\r\nI I will say that I think we"
      },"hidden":False,"userData":"null"
    },{
      "id":"78e141d5-0135-4d3a-b825-292114405972","type":"transcript","start":"PT1H12M7.576S","end":"PT1H12M10.916S","eventData":{
        "type":"caption","language":"en","text":"have delivered largely on the\r\npremises of the acquisition we"
      },"hidden":False,"userData":"null"
    },{
      "id":"d1232df7-0d0a-42b3-a2b6-8d14c0f24b05","type":"transcript","start":"PT1H12M10.916S","end":"PT1H12M13.254S","eventData":{
        "type":"caption","language":"en","text":"have bought in the past, so I"
      },"hidden":False,"userData":"null"
    },{
      "id":"de390e45-a3f6-4b39-97d4-e309368ef1aa","type":"transcript","start":"PT1H12M13.254S","end":"PT1H12M18.03S","eventData":{
        "type":"caption","language":"en","text":"think. Looking in the River\r\nmirrored, I think we should be"
      },"hidden":False,"userData":"null"
    },{
      "id":"03dbd51f-98d5-4526-bc08-bb3880a01060","type":"transcript","start":"PT1H12M18.03S","end":"PT1H12M21.66S","eventData":{
        "type":"caption","language":"en","text":"reasonably content with what we\r\nhave achieved. There are areas"
      },"hidden":False,"userData":"null"
    },{
      "id":"a5316ca0-2cf7-47fd-971c-b5d58021b3fc","type":"transcript","start":"PT1H12M21.66S","end":"PT1H12M25.653S","eventData":{
        "type":"caption","language":"en","text":"where we didn't achieve our\r\ngoals, but there are also areas"
      },"hidden":False,"userData":"null"
    },{
      "id":"7651b72e-8670-459b-8a18-de1e842724a1","type":"transcript","start":"PT1H12M25.653S","end":"PT1H12M29.646S","eventData":{
        "type":"caption","language":"en","text":"where we have sort of leverage.\r\nSort of. Takes shredder for"
      },"hidden":False,"userData":"null"
    },{
      "id":"b0b3a053-614d-4714-8d10-d582d198fad1","type":"transcript","start":"PT1H12M29.646S","end":"PT1H12M33.276S","eventData":{
        "type":"caption","language":"en","text":"example, although the TPMS\r\nmarket is now maturing, we have"
      },"hidden":False,"userData":"null"
    },{
      "id":"48befaaf-3cb6-43f8-960e-0f0cc5137ce9","type":"transcript","start":"PT1H12M33.276S","end":"PT1H12M36.543S","eventData":{
        "type":"caption","language":"en","text":"really leverage the capabilities\r\nwe bought from Schroeder into"
      },"hidden":False,"userData":"null"
    },{
      "id":"49e952b4-2ab1-4545-a27b-40828c337d63","type":"transcript","start":"PT1H12M36.543S","end":"PT1H12M39.084S","eventData":{
        "type":"caption","language":"en","text":"this morning connected\r\ninitiative right on this"
      },"hidden":False,"userData":"null"
    },{
      "id":"2351a6ed-4fac-4f43-b43e-3dd6140669c4","type":"transcript","start":"PT1H12M39.084S","end":"PT1H12M42.714S","eventData":{
        "type":"caption","language":"en","text":"morning, connected initiative\r\nwould not be where it is today"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a3072f2-4229-49e7-885b-c16aa0aa97ca","type":"transcript","start":"PT1H12M42.714S","end":"PT1H12M46.707S","eventData":{
        "type":"caption","language":"en","text":"unless we have bought shredder\r\nright? So I think we should."
      },"hidden":False,"userData":"null"
    },{
      "id":"175b8421-15b4-4adf-9b18-0d70c81dfdfa","type":"transcript","start":"PT1H12M47.15S","end":"PT1H12M51.24S","eventData":{
        "type":"caption","language":"en","text":"Not be too pessimistic about our\r\nour past acquisition. Uhm,"
      },"hidden":False,"userData":"null"
    },{
      "id":"005f164c-ea4c-4788-944c-b3b98131d36d","type":"transcript","start":"PT1H12M51.24S","end":"PT1H12M55.739S","eventData":{
        "type":"caption","language":"en","text":"Having said that, I think that\r\nchanges that we have talked"
      },"hidden":False,"userData":"null"
    },{
      "id":"39bf80c7-ff7e-427c-a2d7-64c37c95a8d1","type":"transcript","start":"PT1H12M55.739S","end":"PT1H13M0.647S","eventData":{
        "type":"caption","language":"en","text":"about, you know at the Stanton\r\nelsewhere is really that we need"
      },"hidden":False,"userData":"null"
    },{
      "id":"a6b090b1-fe24-4a64-92cb-e21c455b908d","type":"transcript","start":"PT1H13M0.647S","end":"PT1H13M5.555S","eventData":{
        "type":"caption","language":"en","text":"to become more of a so called\r\nCheryl acquire, which means that"
      },"hidden":False,"userData":"null"
    },{
      "id":"13784ec7-4d97-47ab-af3c-35b75b5d50f2","type":"transcript","start":"PT1H13M5.555S","end":"PT1H13M10.463S","eventData":{
        "type":"caption","language":"en","text":"we will focusing on buying sort\r\nof bite size companies and do"
      },"hidden":False,"userData":"null"
    },{
      "id":"4b6c4620-10d1-4166-9f0f-1562762c85eb","type":"transcript","start":"PT1H13M10.463S","end":"PT1H13M16.189S","eventData":{
        "type":"caption","language":"en","text":"them a little bit more often. So\r\nit's part of the sort of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"5ba29305-92eb-4b17-bc63-89a1ba958c3d","type":"transcript","start":"PT1H13M16.189S","end":"PT1H13M17.825S","eventData":{
        "type":"caption","language":"en","text":"business cadence of Syncada."
      },"hidden":False,"userData":"null"
    },{
      "id":"40a5620e-fcda-489a-90c8-6483b01e6541","type":"transcript","start":"PT1H13M18.04S","end":"PT1H13M22.372S","eventData":{
        "type":"caption","language":"en","text":"Is that every year we buy sort\r\nof 234A smaller companies. And,"
      },"hidden":False,"userData":"null"
    },{
      "id":"2ed89514-e47d-422f-b06d-f6bb41dc3856","type":"transcript","start":"PT1H13M22.372S","end":"PT1H13M27.426S","eventData":{
        "type":"caption","language":"en","text":"uh, so that sort of, I think, a\r\nshift that we are trying to"
      },"hidden":False,"userData":"null"
    },{
      "id":"f8790373-25a6-4f9d-ba20-6e234403dc81","type":"transcript","start":"PT1H13M27.426S","end":"PT1H13M31.624S","eventData":{
        "type":"caption","language":"en","text":"implement. An, uh back to the\r\nearlier conversation, we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"72a83f09-8a9c-45f9-8ea6-c633437a0056","type":"transcript","start":"PT1H13M31.624S","end":"PT1H13M35.161S","eventData":{
        "type":"caption","language":"en","text":"trying to focus those\r\ninvestments in these high growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"81e7d40d-4b2c-4e50-bd9b-b5547299eb98","type":"transcript","start":"PT1H13M35.161S","end":"PT1H13M39.877S","eventData":{
        "type":"caption","language":"en","text":"areas as we discussed, a lot has\r\nbeen focusing on the industrial"
      },"hidden":False,"userData":"null"
    },{
      "id":"19f72178-54ed-4e33-b28c-3483aa73da49","type":"transcript","start":"PT1H13M39.877S","end":"PT1H13M44.593S","eventData":{
        "type":"caption","language":"en","text":"business segment as we need\r\npointed out where there is a lot"
      },"hidden":False,"userData":"null"
    },{
      "id":"65a5e7c1-c52b-4ea7-a40f-75e7c0b7782d","type":"transcript","start":"PT1H13M44.593S","end":"PT1H13M48.13S","eventData":{
        "type":"caption","language":"en","text":"of opportunities to buy an\r\nexpand into these areas."
      },"hidden":False,"userData":"null"
    },{
      "id":"fdd5fe50-0350-45ae-bbef-d5ce3e3c1e70","type":"transcript","start":"PT1H13M49.85S","end":"PT1H13M55.35S","eventData":{
        "type":"caption","language":"en","text":"So, so we will continue to, uh,\r\nto be aggressively pursuing"
      },"hidden":False,"userData":"null"
    },{
      "id":"9647a334-ebab-4f06-a539-3abf529d899d","type":"transcript","start":"PT1H13M55.35S","end":"PT1H14M0.85S","eventData":{
        "type":"caption","language":"en","text":"emanet opportunities. We will of\r\ncourse be as diligent as we"
      },"hidden":False,"userData":"null"
    },{
      "id":"6dc15504-89d3-46ce-adde-4d918e150abd","type":"transcript","start":"PT1H14M0.85S","end":"PT1H14M6.85S","eventData":{
        "type":"caption","language":"en","text":"possibly can, and, for example,\r\nin Bonita area, as you may know,"
      },"hidden":False,"userData":"null"
    },{
      "id":"d067dab4-7bca-4e4f-97c4-0e47ca19a08d","type":"transcript","start":"PT1H14M6.85S","end":"PT1H14M11.35S","eventData":{
        "type":"caption","language":"en","text":"we're building up more of a\r\nintegration capability inside"
      },"hidden":False,"userData":"null"
    },{
      "id":"f759ff68-a6ac-4af4-8aaa-de5f61a25e46","type":"transcript","start":"PT1H14M11.35S","end":"PT1H14M14.35S","eventData":{
        "type":"caption","language":"en","text":"sensing solution to be able to."
      },"hidden":False,"userData":"null"
    },{
      "id":"6fc07f38-20c7-4b78-851c-92729d25854d","type":"transcript","start":"PT1H14M15.61S","end":"PT1H14M19.726S","eventData":{
        "type":"caption","language":"en","text":"No, not only develop plans for\r\nthese business, but also when we"
      },"hidden":False,"userData":"null"
    },{
      "id":"0a3a3156-1371-4fca-9943-08a92ab73bc6","type":"transcript","start":"PT1H14M19.726S","end":"PT1H14M23.842S","eventData":{
        "type":"caption","language":"en","text":"have them on board that we can\r\nintegrate and capture the value"
      },"hidden":False,"userData":"null"
    },{
      "id":"d10b9fa0-575f-45d3-b58b-3627c69dad71","type":"transcript","start":"PT1H14M23.842S","end":"PT1H14M25.9S","eventData":{
        "type":"caption","language":"en","text":"creation that they that they can"
      },"hidden":False,"userData":"null"
    },{
      "id":"12afc60b-b359-4693-8cb3-81fec4eeb831","type":"transcript","start":"PT1H14M25.9S","end":"PT1H14M31.778S","eventData":{
        "type":"caption","language":"en","text":"give us. So, so that I guess\r\nis in a high level how we're"
      },"hidden":False,"userData":"null"
    },{
      "id":"d9588282-a230-42f2-9bb8-62b99a8dba23","type":"transcript","start":"PT1H14M31.778S","end":"PT1H14M34.256S","eventData":{
        "type":"caption","language":"en","text":"looking at this emanate\r\nstrategy going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"5b564063-06e8-4e6d-b6c3-16b883405aa9","type":"transcript","start":"PT1H14M38.29S","end":"PT1H14M42.25S","eventData":{
        "type":"caption","language":"en","text":"Thanks sons, Alright next\r\nsession is for a pool so a Poly."
      },"hidden":False,"userData":"null"
    },{
      "id":"245d1e76-99f4-4106-bc73-bc68c97d33b0","type":"transcript","start":"PT1H14M42.25S","end":"PT1H14M45.88S","eventData":{
        "type":"caption","language":"en","text":"Could you elaborate some more on\r\nthe relocation of resources you"
      },"hidden":False,"userData":"null"
    },{
      "id":"35c418a8-906c-42b1-8268-42a44e281d00","type":"transcript","start":"PT1H14M45.88S","end":"PT1H14M49.84S","eventData":{
        "type":"caption","language":"en","text":"announced that are needed? Maybe\r\na bit more on what and when."
      },"hidden":False,"userData":"null"
    },{
      "id":"6652e040-1586-461a-8faa-df28d8b622db","type":"transcript","start":"PT1H14M50.85S","end":"PT1H14M56.716S","eventData":{
        "type":"caption","language":"en","text":"Yeah, sure, so this is not you.\r\nWe've been doing this now for a"
      },"hidden":False,"userData":"null"
    },{
      "id":"4d9f1662-d6f1-4de2-abc8-4d57a55b8874","type":"transcript","start":"PT1H14M56.716S","end":"PT1H15M1.325S","eventData":{
        "type":"caption","language":"en","text":"couple of years. A relegating\r\nresources from GPT to GSM from"
      },"hidden":False,"userData":"null"
    },{
      "id":"7403c79e-801f-472c-b4c0-d0194968265d","type":"transcript","start":"PT1H15M1.325S","end":"PT1H15M5.934S","eventData":{
        "type":"caption","language":"en","text":"some of the chassis teams too\r\nsmart and connected as per"
      },"hidden":False,"userData":"null"
    },{
      "id":"15553e69-8afe-499a-ba7b-ccfdcd40cbe9","type":"transcript","start":"PT1H15M5.934S","end":"PT1H15M10.962S","eventData":{
        "type":"caption","language":"en","text":"needs, and this is a trend that\r\nwill carry on as certain"
      },"hidden":False,"userData":"null"
    },{
      "id":"fdfe2ca9-6b05-44a6-916a-14c29dbe3b14","type":"transcript","start":"PT1H15M10.962S","end":"PT1H15M15.571S","eventData":{
        "type":"caption","language":"en","text":"business or segments will still\r\nkeep our share and maintain what"
      },"hidden":False,"userData":"null"
    },{
      "id":"b2785756-6331-4cdf-9463-2a5d37510574","type":"transcript","start":"PT1H15M15.571S","end":"PT1H15M21.437S","eventData":{
        "type":"caption","language":"en","text":"we have but will not need a lot\r\nof R&D effort. Those teams and."
      },"hidden":False,"userData":"null"
    },{
      "id":"37473ad8-ec72-46b9-92b2-bd99236f5645","type":"transcript","start":"PT1H15M21.52S","end":"PT1H15M26.752S","eventData":{
        "type":"caption","language":"en","text":"Uh, in various campuses will\r\nwill pivot as per need to other"
      },"hidden":False,"userData":"null"
    },{
      "id":"0e2961d5-fb41-4fd9-9ed9-d590f1ed9429","type":"transcript","start":"PT1H15M26.752S","end":"PT1H15M30.676S","eventData":{
        "type":"caption","language":"en","text":"applications within the business\r\nor also across business. There"
      },"hidden":False,"userData":"null"
    },{
      "id":"5c5cab03-5360-4bde-a6f2-dee5f0c81628","type":"transcript","start":"PT1H15M30.676S","end":"PT1H15M35.908S","eventData":{
        "type":"caption","language":"en","text":"quite a few outer players team\r\nteam members who have also moved"
      },"hidden":False,"userData":"null"
    },{
      "id":"2ceaf0ab-35a2-4344-bde6-4d02df0ac19b","type":"transcript","start":"PT1H15M35.908S","end":"PT1H15M41.14S","eventData":{
        "type":"caption","language":"en","text":"to sensing solutions and HBO\r\nare, so this is a trend, will"
      },"hidden":False,"userData":"null"
    },{
      "id":"542a4f6c-6a45-4f41-b61e-8b20a9f19b39","type":"transcript","start":"PT1H15M41.14S","end":"PT1H15M45.936S","eventData":{
        "type":"caption","language":"en","text":"carry on and there's no fix\r\ntiming on it. Obviously the"
      },"hidden":False,"userData":"null"
    },{
      "id":"eb4993b9-4fb1-483b-b5c6-c567671b9850","type":"transcript","start":"PT1H15M45.936S","end":"PT1H15M50.296S","eventData":{
        "type":"caption","language":"en","text":"covid downtown has put some\r\nconstraints on some of our"
      },"hidden":False,"userData":"null"
    },{
      "id":"5e5d3402-cbb7-4d5f-8cf3-791f90d8d446","type":"transcript","start":"PT1H15M50.296S","end":"PT1H15M52.04S","eventData":{
        "type":"caption","language":"en","text":"capability. Do everything we"
      },"hidden":False,"userData":"null"
    },{
      "id":"fb6638a3-a77b-428c-9d16-c7bf5af137c7","type":"transcript","start":"PT1H15M52.04S","end":"PT1H15M56.203S","eventData":{
        "type":"caption","language":"en","text":"want but. Um markets are\r\ncoming back and we have. We"
      },"hidden":False,"userData":"null"
    },{
      "id":"dab572a2-4210-44bc-ad39-0ce6cb100773","type":"transcript","start":"PT1H15M56.203S","end":"PT1H15M59.416S","eventData":{
        "type":"caption","language":"en","text":"have some good growth\r\npotential in front of us."
      },"hidden":False,"userData":"null"
    },{
      "id":"68e77100-9d7a-4632-84a6-e1dc78dff937","type":"transcript","start":"PT1H15M59.416S","end":"PT1H16M2.272S","eventData":{
        "type":"caption","language":"en","text":"Electrification being the\r\nbiggest one in this moment"
      },"hidden":False,"userData":"null"
    },{
      "id":"245a2c2e-698e-4d5c-b075-43229efd2870","type":"transcript","start":"PT1H16M2.272S","end":"PT1H16M6.199S","eventData":{
        "type":"caption","language":"en","text":"where we need more resources,\r\nso will carry on this journey"
      },"hidden":False,"userData":"null"
    },{
      "id":"d036ba7b-929e-45f4-b345-d13eb42586a8","type":"transcript","start":"PT1H16M6.199S","end":"PT1H16M10.126S","eventData":{
        "type":"caption","language":"en","text":"and it is not in one place\r\nspecifically. It really is"
      },"hidden":False,"userData":"null"
    },{
      "id":"6e76b176-6148-4fdd-80d0-ab65487151c7","type":"transcript","start":"PT1H16M10.126S","end":"PT1H16M13.339S","eventData":{
        "type":"caption","language":"en","text":"something we're doing across\r\nall campuses around the world."
      },"hidden":False,"userData":"null"
    },{
      "id":"e00adf6e-36d1-485b-bd10-298c341d429b","type":"transcript","start":"PT1H16M18.55S","end":"PT1H16M22.092S","eventData":{
        "type":"caption","language":"en","text":"Great thanks Paul. Alright, Uh\r\nnext question and I know that"
      },"hidden":False,"userData":"null"
    },{
      "id":"4e672eda-ec82-44bc-ac7b-7a4b450318b6","type":"transcript","start":"PT1H16M22.092S","end":"PT1H16M25.956S","eventData":{
        "type":"caption","language":"en","text":"it's on everyone's mind really\r\nis around our people. And how do"
      },"hidden":False,"userData":"null"
    },{
      "id":"01c98717-dc73-44e1-a8f2-abd4b900eb66","type":"transcript","start":"PT1H16M25.956S","end":"PT1H16M29.176S","eventData":{
        "type":"caption","language":"en","text":"we plan on building a strong\r\nworkforce during these difficult"
      },"hidden":False,"userData":"null"
    },{
      "id":"e46f65ed-6fa2-4139-a449-c6e89c1233db","type":"transcript","start":"PT1H16M29.176S","end":"PT1H16M33.362S","eventData":{
        "type":"caption","language":"en","text":"times? So maybe I'll ask. Um,\r\nmaybe I'll ask Jeff to kind of"
      },"hidden":False,"userData":"null"
    },{
      "id":"dd414eea-de49-49c8-83a6-549a9f8671ec","type":"transcript","start":"PT1H16M33.362S","end":"PT1H16M36.904S","eventData":{
        "type":"caption","language":"en","text":"kick that one-off and anyone\r\nelse who would like to join."
      },"hidden":False,"userData":"null"
    },{
      "id":"ddfec08c-4206-429a-9503-9fdb9a2f79f2","type":"transcript","start":"PT1H16M38.9S","end":"PT1H16M43.388S","eventData":{
        "type":"caption","language":"en","text":"Sure, so it's difficult in a\r\ntime where things are so hard"
      },"hidden":False,"userData":"null"
    },{
      "id":"b939de56-fa51-4ff0-ae23-481ae2867a55","type":"transcript","start":"PT1H16M43.388S","end":"PT1H16M46.754S","eventData":{
        "type":"caption","language":"en","text":"and we have a dislocation\r\nassociated with the overall"
      },"hidden":False,"userData":"null"
    },{
      "id":"e6c3436e-3227-45f5-b6d6-b07dd54f2003","type":"transcript","start":"PT1H16M46.754S","end":"PT1H16M50.494S","eventData":{
        "type":"caption","language":"en","text":"market demand in our cost\r\nstructure to build this, but"
      },"hidden":False,"userData":"null"
    },{
      "id":"ae1c8371-6af6-48cf-9dea-48aa9d5154ba","type":"transcript","start":"PT1H16M50.494S","end":"PT1H16M55.356S","eventData":{
        "type":"caption","language":"en","text":"we're working very hard at it. I\r\nthink it starts with open this"
      },"hidden":False,"userData":"null"
    },{
      "id":"c4390d3a-0624-47bb-8ffb-add6266b20c5","type":"transcript","start":"PT1H16M55.356S","end":"PT1H16M57.974S","eventData":{
        "type":"caption","language":"en","text":"collaboration, high levels of\r\ncommunication, transparency, and"
      },"hidden":False,"userData":"null"
    },{
      "id":"01a68c38-83ec-498d-84f6-a18fdaa90867","type":"transcript","start":"PT1H16M57.974S","end":"PT1H17M2.462S","eventData":{
        "type":"caption","language":"en","text":"so I think that as we've\r\nembarked on this, and as we've"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a6609ad-9ae4-4a3e-83b6-f30e9697e302","type":"transcript","start":"PT1H17M2.462S","end":"PT1H17M6.202S","eventData":{
        "type":"caption","language":"en","text":"tried to increase the level of\r\ncommunication, even though we've"
      },"hidden":False,"userData":"null"
    },{
      "id":"48afb903-258d-4342-909a-aacc710331da","type":"transcript","start":"PT1H17M6.202S","end":"PT1H17M8.446S","eventData":{
        "type":"caption","language":"en","text":"had to make very hard decisions."
      },"hidden":False,"userData":"null"
    },{
      "id":"b7e4d89e-892c-49f1-8f7b-3f8ebabbe932","type":"transcript","start":"PT1H17M8.92S","end":"PT1H17M12.538S","eventData":{
        "type":"caption","language":"en","text":"Regarding our employee based\r\ninvolving folks in that process,"
      },"hidden":False,"userData":"null"
    },{
      "id":"b347a948-5b59-475c-b8be-87a0df6f7bf9","type":"transcript","start":"PT1H17M12.538S","end":"PT1H17M14.95S","eventData":{
        "type":"caption","language":"en","text":"I think goes along way too."
      },"hidden":False,"userData":"null"
    },{
      "id":"1b5dff6f-7742-4842-9179-035324b79d59","type":"transcript","start":"PT1H17M15.54S","end":"PT1H17M18.196S","eventData":{
        "type":"caption","language":"en","text":"Creating that level of\r\nengagement that we're looking"
      },"hidden":False,"userData":"null"
    },{
      "id":"78d2358f-eaed-4df5-b1a1-b34bcd81d1bb","type":"transcript","start":"PT1H17M18.196S","end":"PT1H17M21.516S","eventData":{
        "type":"caption","language":"en","text":"for with our employee base\r\nobviously would much rather be"
      },"hidden":False,"userData":"null"
    },{
      "id":"1f4ad233-82e8-43bd-a936-814a8dde76b4","type":"transcript","start":"PT1H17M21.516S","end":"PT1H17M25.5S","eventData":{
        "type":"caption","language":"en","text":"in a position where the markets\r\nwere serving are growing and we"
      },"hidden":False,"userData":"null"
    },{
      "id":"501c4d8a-9ea1-4648-85b1-c38f7910de32","type":"transcript","start":"PT1H17M25.5S","end":"PT1H17M28.82S","eventData":{
        "type":"caption","language":"en","text":"can continue to hire great\r\ntalent, invest more in our"
      },"hidden":False,"userData":"null"
    },{
      "id":"37f80a7b-991c-4a0a-9520-44e53611b3ca","type":"transcript","start":"PT1H17M28.82S","end":"PT1H17M31.476S","eventData":{
        "type":"caption","language":"en","text":"people as opposed to these\r\nconstrained environments that"
      },"hidden":False,"userData":"null"
    },{
      "id":"62cd6afc-1742-417d-8d1e-6cdfe336a918","type":"transcript","start":"PT1H17M31.476S","end":"PT1H17M35.792S","eventData":{
        "type":"caption","language":"en","text":"were in. But but we're going to\r\ndeal with it the best we"
      },"hidden":False,"userData":"null"
    },{
      "id":"3f615719-7f22-4433-80f8-e986942439c7","type":"transcript","start":"PT1H17M35.792S","end":"PT1H17M39.776S","eventData":{
        "type":"caption","language":"en","text":"possibly can, and being open and\r\ncandid with employees I think is"
      },"hidden":False,"userData":"null"
    },{
      "id":"f6556d8e-0964-44b7-8534-421cd9d65ec8","type":"transcript","start":"PT1H17M39.776S","end":"PT1H17M44.092S","eventData":{
        "type":"caption","language":"en","text":"the best way to do that now.\r\nWe're also making sure that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"c1aa898b-ad1e-410d-83f0-dfa280cab5c8","type":"transcript","start":"PT1H17M44.092S","end":"PT1H17M45.752S","eventData":{
        "type":"caption","language":"en","text":"do continue invest in training."
      },"hidden":False,"userData":"null"
    },{
      "id":"63c2c862-9e12-40e8-96e8-837db6242079","type":"transcript","start":"PT1H17M46.11S","end":"PT1H17M48.954S","eventData":{
        "type":"caption","language":"en","text":"There's been a significant\r\namount of online training that"
      },"hidden":False,"userData":"null"
    },{
      "id":"4b10ea20-f665-4d3b-a4ad-5857d75dd4c6","type":"transcript","start":"PT1H17M48.954S","end":"PT1H17M52.746S","eventData":{
        "type":"caption","language":"en","text":"has been rolled out and a lot\r\nof people in this environment"
      },"hidden":False,"userData":"null"
    },{
      "id":"00321d1c-317d-4e53-acde-30cd9044ddfd","type":"transcript","start":"PT1H17M52.746S","end":"PT1H17M56.222S","eventData":{
        "type":"caption","language":"en","text":"that we're living in have taken\r\nadvantage of that swim. Very"
      },"hidden":False,"userData":"null"
    },{
      "id":"06703c60-7980-4b02-904d-9233ff497280","type":"transcript","start":"PT1H17M56.222S","end":"PT1H17M59.382S","eventData":{
        "type":"caption","language":"en","text":"excited about that fact. We've,\r\nas I mentioned, increase the"
      },"hidden":False,"userData":"null"
    },{
      "id":"2d66f299-6e27-499c-b96b-3d7e1c9c2ab0","type":"transcript","start":"PT1H17M59.382S","end":"PT1H18M2.542S","eventData":{
        "type":"caption","language":"en","text":"level of communication not only\r\nwith our leadership team, but"
      },"hidden":False,"userData":"null"
    },{
      "id":"97af80ee-8d18-4dab-aedd-ffced6578195","type":"transcript","start":"PT1H18M2.542S","end":"PT1H18M5.702S","eventData":{
        "type":"caption","language":"en","text":"more broadly, and I'm very\r\npleased with the progress that"
      },"hidden":False,"userData":"null"
    },{
      "id":"b8c42013-a381-4010-8d8f-4f16ceb98549","type":"transcript","start":"PT1H18M5.702S","end":"PT1H18M9.494S","eventData":{
        "type":"caption","language":"en","text":"we're making on that. And we're\r\ngoing to continue to listen to"
      },"hidden":False,"userData":"null"
    },{
      "id":"4b00761b-f9ab-49d2-a765-6cb23618a350","type":"transcript","start":"PT1H18M9.494S","end":"PT1H18M13.918S","eventData":{
        "type":"caption","language":"en","text":"all of you in terms of what we\r\ncan do better to continue to"
      },"hidden":False,"userData":"null"
    },{
      "id":"f3426a53-8a46-448f-90f3-785fa637cf5a","type":"transcript","start":"PT1H18M13.918S","end":"PT1H18M16.762S","eventData":{
        "type":"caption","language":"en","text":"increase that overall level of\r\nengagement. An investment in"
      },"hidden":False,"userData":"null"
    },{
      "id":"d415e410-fa0a-4479-92bf-6aa0726e468c","type":"transcript","start":"PT1H18M16.762S","end":"PT1H18M17.394S","eventData":{
        "type":"caption","language":"en","text":"the workforce."
      },"hidden":False,"userData":"null"
    },{
      "id":"ae6b77dd-100c-4725-b221-de3a3dd578cc","type":"transcript","start":"PT1H18M21.21S","end":"PT1H18M25.866S","eventData":{
        "type":"caption","language":"en","text":"Great thank you Jeff. Alright we\r\nhave a little bit under 7"
      },"hidden":False,"userData":"null"
    },{
      "id":"f987aa44-2e7c-4da8-abd6-6c36951dfc3c","type":"transcript","start":"PT1H18M25.866S","end":"PT1H18M30.134S","eventData":{
        "type":"caption","language":"en","text":"minutes left so there's a lot of\r\nquestions around iot, Annonce,"
      },"hidden":False,"userData":"null"
    },{
      "id":"94598c9f-0f43-4a77-8040-3a52ca74266f","type":"transcript","start":"PT1H18M30.134S","end":"PT1H18M35.178S","eventData":{
        "type":"caption","language":"en","text":"Asmodel, Vinny. Maybe I can just\r\nask you to kind of UM address"
      },"hidden":False,"userData":"null"
    },{
      "id":"00f1531f-ba73-473a-a904-dc350e737b01","type":"transcript","start":"PT1H18M35.178S","end":"PT1H18M39.834S","eventData":{
        "type":"caption","language":"en","text":"address some of these questions\r\nquickly. I know we have a couple"
      },"hidden":False,"userData":"null"
    },{
      "id":"282c4651-a088-4bb7-a4d8-e2497c11427a","type":"transcript","start":"PT1H18M39.834S","end":"PT1H18M43.326S","eventData":{
        "type":"caption","language":"en","text":"of questions on where industrial\r\niot fits, whether it's"
      },"hidden":False,"userData":"null"
    },{
      "id":"8c51ecfc-9c56-4061-b58d-09d1ac0f6668","type":"transcript","start":"PT1H18M43.326S","end":"PT1H18M47.594S","eventData":{
        "type":"caption","language":"en","text":"industrial in sensing solutions.\r\nWhat are the some of the the"
      },"hidden":False,"userData":"null"
    },{
      "id":"0e948826-59f4-4989-b606-cc5d9e645d7e","type":"transcript","start":"PT1H18M47.594S","end":"PT1H18M50.698S","eventData":{
        "type":"caption","language":"en","text":"investments, the different\r\ninvestments needed both from an"
      },"hidden":False,"userData":"null"
    },{
      "id":"b92dfd17-f902-4c76-b06d-58f388541b0e","type":"transcript","start":"PT1H18M50.698S","end":"PT1H18M53.026S","eventData":{
        "type":"caption","language":"en","text":"infrastructure partnering\r\nthrough Amazon and people?"
      },"hidden":False,"userData":"null"
    },{
      "id":"18e8614a-e93f-4f6b-b894-55b55fcbcb23","type":"transcript","start":"PT1H18M53.17S","end":"PT1H18M57.746S","eventData":{
        "type":"caption","language":"en","text":"A lot, but I'm I know you're up\r\nto the task, so, uh."
      },"hidden":False,"userData":"null"
    },{
      "id":"9feb0583-97e7-4aa3-a1a8-6ea0feff4bb3","type":"transcript","start":"PT1H18M58.9S","end":"PT1H19M1.96S","eventData":{
        "type":"caption","language":"en","text":"I won't answer any of these\r\nquestions, uh, specifically, but"
      },"hidden":False,"userData":"null"
    },{
      "id":"7f96fb15-3ab7-4828-901a-45d889b55ed7","type":"transcript","start":"PT1H19M1.96S","end":"PT1H19M5.326S","eventData":{
        "type":"caption","language":"en","text":"let me provide a little bit of\r\ncontext that hopefully helps."
      },"hidden":False,"userData":"null"
    },{
      "id":"a810770f-b6e2-4f56-bf00-e6a8b313a124","type":"transcript","start":"PT1H19M5.326S","end":"PT1H19M8.692S","eventData":{
        "type":"caption","language":"en","text":"The number of people who ask\r\nthese questions you know, get"
      },"hidden":False,"userData":"null"
    },{
      "id":"bd7b9efb-b084-4a83-98b4-498ee77d0a67","type":"transcript","start":"PT1H19M8.692S","end":"PT1H19M12.67S","eventData":{
        "type":"caption","language":"en","text":"sort of a satisfactory answer.\r\nFirst of all, I did say that our"
      },"hidden":False,"userData":"null"
    },{
      "id":"a72cdc99-f8e1-4446-b06d-b9c678d5253b","type":"transcript","start":"PT1H19M12.67S","end":"PT1H19M16.036S","eventData":{
        "type":"caption","language":"en","text":"starting point is going to be\r\nsensors. However, we are going"
      },"hidden":False,"userData":"null"
    },{
      "id":"738a0a29-b403-4f0a-b764-53add8f92620","type":"transcript","start":"PT1H19M16.036S","end":"PT1H19M19.708S","eventData":{
        "type":"caption","language":"en","text":"to look for opportunities to\r\nplay further up the stack in a"
      },"hidden":False,"userData":"null"
    },{
      "id":"039bb7af-f550-4646-aa77-c6632b0fdda1","type":"transcript","start":"PT1H19M19.708S","end":"PT1H19M23.38S","eventData":{
        "type":"caption","language":"en","text":"much more fulsome way, and to\r\nthe extent that requires us to"
      },"hidden":False,"userData":"null"
    },{
      "id":"af460600-5894-4155-ad09-fc9a4dd0d619","type":"transcript","start":"PT1H19M23.38S","end":"PT1H19M26.746S","eventData":{
        "type":"caption","language":"en","text":"develop software as a service or\r\nequipment is a service type"
      },"hidden":False,"userData":"null"
    },{
      "id":"043ed1b5-df2e-4891-be81-1a08ddf49bc9","type":"transcript","start":"PT1H19M26.746S","end":"PT1H19M29.5S","eventData":{
        "type":"caption","language":"en","text":"models, we will definitely take\r\na look at that."
      },"hidden":False,"userData":"null"
    },{
      "id":"d74bd1f8-30bd-4fe9-b542-c5b4b5dee8d8","type":"transcript","start":"PT1H19M30.52S","end":"PT1H19M34.722S","eventData":{
        "type":"caption","language":"en","text":"Really love the work that\r\nAndrew, 40 and team are doing"
      },"hidden":False,"userData":"null"
    },{
      "id":"55bd5c9e-1521-41a5-9175-93b0c4f162d3","type":"transcript","start":"PT1H19M34.722S","end":"PT1H19M38.16S","eventData":{
        "type":"caption","language":"en","text":"within smart and connected in\r\nfleets around. Really innovating"
      },"hidden":False,"userData":"null"
    },{
      "id":"07536a8d-03eb-408d-9a8b-329ab5c5a24a","type":"transcript","start":"PT1H19M38.16S","end":"PT1H19M42.362S","eventData":{
        "type":"caption","language":"en","text":"and pioneering that person.\r\nSarah and I think we'll be fast"
      },"hidden":False,"userData":"null"
    },{
      "id":"5ec91782-510b-489b-bace-605fb43ba6f6","type":"transcript","start":"PT1H19M42.362S","end":"PT1H19M46.182S","eventData":{
        "type":"caption","language":"en","text":"followers. Their learning from\r\nthem and and building on their"
      },"hidden":False,"userData":"null"
    },{
      "id":"2e31c53d-a320-4063-b3e5-7d4401f126f9","type":"transcript","start":"PT1H19M46.182S","end":"PT1H19M50.384S","eventData":{
        "type":"caption","language":"en","text":"knowledge. And there is also a\r\nnotion of what we use."
      },"hidden":False,"userData":"null"
    },{
      "id":"08e153c3-31e1-4777-b290-01929c3263e1","type":"transcript","start":"PT1H19M51.88S","end":"PT1H19M55.624S","eventData":{
        "type":"caption","language":"en","text":"Our solutions in our own plants.\r\nThe notion of, you know, will we"
      },"hidden":False,"userData":"null"
    },{
      "id":"914cac66-abb8-4ce0-b5d8-2b56bc0a89db","type":"transcript","start":"PT1H19M55.624S","end":"PT1H19M59.368S","eventData":{
        "type":"caption","language":"en","text":"eat their own food? You know,\r\nwhen the dog is redrawn dog food"
      },"hidden":False,"userData":"null"
    },{
      "id":"34c66ff0-221e-4c43-8505-2f29afa5727f","type":"transcript","start":"PT1H19M59.368S","end":"PT1H20M0.52S","eventData":{
        "type":"caption","language":"en","text":"to speak, and, uh?"
      },"hidden":False,"userData":"null"
    },{
      "id":"01ed16f7-4de1-48e8-b445-662d9eb2e79b","type":"transcript","start":"PT1H20M0.94S","end":"PT1H20M5.02S","eventData":{
        "type":"caption","language":"en","text":"The answer to that is yes.\r\nHowever, we need to be very"
      },"hidden":False,"userData":"null"
    },{
      "id":"91f444a1-3b5d-48e9-82ac-c9ddd554f4e4","type":"transcript","start":"PT1H20M5.02S","end":"PT1H20M8.42S","eventData":{
        "type":"caption","language":"en","text":"thoughtful around how we develop\r\nsolutions that that can scale"
      },"hidden":False,"userData":"null"
    },{
      "id":"0975bc89-1e39-4390-ada8-5d9bf7aa1bd8","type":"transcript","start":"PT1H20M8.42S","end":"PT1H20M12.5S","eventData":{
        "type":"caption","language":"en","text":"across flat. So we're very, very\r\nearly right now. My sense is"
      },"hidden":False,"userData":"null"
    },{
      "id":"f0ee1d3f-97f7-454b-9fec-498977a10cef","type":"transcript","start":"PT1H20M12.5S","end":"PT1H20M15.9S","eventData":{
        "type":"caption","language":"en","text":"that will probably use, you\r\nknow, in a limited fashion"
      },"hidden":False,"userData":"null"
    },{
      "id":"b4669db0-6a2d-4a24-98cf-c96c5f7b455a","type":"transcript","start":"PT1H20M15.9S","end":"PT1H20M19.98S","eventData":{
        "type":"caption","language":"en","text":"similar size to test in pilot.\r\nSome of the solutions we think"
      },"hidden":False,"userData":"null"
    },{
      "id":"6afee264-1eb0-4e3d-ad3f-80265bb50e05","type":"transcript","start":"PT1H20M19.98S","end":"PT1H20M24.74S","eventData":{
        "type":"caption","language":"en","text":"that we want to bring to market.\r\nIt may start with taking some of"
      },"hidden":False,"userData":"null"
    },{
      "id":"27c99295-e8be-4de6-b1ad-18c9ef54e4aa","type":"transcript","start":"PT1H20M24.74S","end":"PT1H20M28.48S","eventData":{
        "type":"caption","language":"en","text":"the interesting solutions we\r\nhave at C3 offering that to some"
      },"hidden":False,"userData":"null"
    },{
      "id":"79e76710-067e-400b-9e3f-b02e9eaf7e2b","type":"transcript","start":"PT1H20M28.48S","end":"PT1H20M30.52S","eventData":{
        "type":"caption","language":"en","text":"of our plan leaders and saying,"
      },"hidden":False,"userData":"null"
    },{
      "id":"228b9fde-a418-4d04-80f4-9a51fd90b4eb","type":"transcript","start":"PT1H20M30.52S","end":"PT1H20M33.36S","eventData":{
        "type":"caption","language":"en","text":"hey? Do you see value in\r\ndeploying a solution like this"
      },"hidden":False,"userData":"null"
    },{
      "id":"688e67d6-7859-4275-a638-411fa774b76b","type":"transcript","start":"PT1H20M33.36S","end":"PT1H20M38.175S","eventData":{
        "type":"caption","language":"en","text":"and learning from that? But a\r\nlot more has to be done before"
      },"hidden":False,"userData":"null"
    },{
      "id":"17cf4025-e73e-4011-9656-9ca0cbf3a5e1","type":"transcript","start":"PT1H20M38.175S","end":"PT1H20M41.825S","eventData":{
        "type":"caption","language":"en","text":"we're able to build, bring\r\nsolutions of scale to any"
      },"hidden":False,"userData":"null"
    },{
      "id":"7786995a-a890-41f0-af9f-a28edc01ade3","type":"transcript","start":"PT1H20M41.825S","end":"PT1H20M45.84S","eventData":{
        "type":"caption","language":"en","text":"plans, including our own. OK,\r\nthe question of where will the"
      },"hidden":False,"userData":"null"
    },{
      "id":"bc26246d-22a4-4eb1-ac39-2721e71dac34","type":"transcript","start":"PT1H20M45.84S","end":"PT1H20M49.49S","eventData":{
        "type":"caption","language":"en","text":"industrial will be iot\r\ninitiative set? It is part of"
      },"hidden":False,"userData":"null"
    },{
      "id":"f5b7455e-c5b2-43a4-b1f7-5e72dced014c","type":"transcript","start":"PT1H20M49.49S","end":"PT1H20M53.14S","eventData":{
        "type":"caption","language":"en","text":"our industrial Business Today,\r\nAnne. Frankly, it is part of"
      },"hidden":False,"userData":"null"
    },{
      "id":"3ba16951-61e3-4b32-8bf4-9ddbfde66da0","type":"transcript","start":"PT1H20M53.14S","end":"PT1H20M56.79S","eventData":{
        "type":"caption","language":"en","text":"their transformation as they\r\nlook to become a high growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"095948cf-c8ec-4c82-922b-57174d29a08b","type":"transcript","start":"PT1H20M56.79S","end":"PT1H21M0.075S","eventData":{
        "type":"caption","language":"en","text":"in a sustainable high growth\r\nbusiness within our portfolio."
      },"hidden":False,"userData":"null"
    },{
      "id":"ae81ddf0-e9f0-4553-b7d6-1dceaac351e0","type":"transcript","start":"PT1H21M0.075S","end":"PT1H21M3.725S","eventData":{
        "type":"caption","language":"en","text":"So hopefully I addressed all\r\nthose questions to a certain"
      },"hidden":False,"userData":"null"
    },{
      "id":"f83a72a5-f4b1-4d2b-a282-8de5360f546b","type":"transcript","start":"PT1H21M3.725S","end":"PT1H21M4.09S","eventData":{
        "type":"caption","language":"en","text":"degree."
      },"hidden":False,"userData":"null"
    },{
      "id":"0251f374-4e5c-4320-b74c-57301941ab64","type":"transcript","start":"PT1H21M5.74S","end":"PT1H21M9.529S","eventData":{
        "type":"caption","language":"en","text":"Uh, across across the various\r\nquestions that were answered."
      },"hidden":False,"userData":"null"
    },{
      "id":"a30dbadf-0233-4479-8b71-8cf9195b54a6","type":"transcript","start":"PT1H21M13.27S","end":"PT1H21M16.36S","eventData":{
        "type":"caption","language":"en","text":"Thanks for being really\r\nappreciate it. We have a couple"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6f838c4-1a27-4c5b-a065-292c70cc6fcd","type":"transcript","start":"PT1H21M16.36S","end":"PT1H21M20.377S","eventData":{
        "type":"caption","language":"en","text":"of questions and and I'll ask on\r\nto take those. So what changes"
      },"hidden":False,"userData":"null"
    },{
      "id":"a9a4c35d-4646-4265-a77c-04d2fedf2c85","type":"transcript","start":"PT1H21M20.377S","end":"PT1H21M24.703S","eventData":{
        "type":"caption","language":"en","text":"do we see in our business that\r\nhave led us to change our five"
      },"hidden":False,"userData":"null"
    },{
      "id":"081ef3a7-8384-4c86-88c8-303649ac6bac","type":"transcript","start":"PT1H21M24.703S","end":"PT1H21M28.72S","eventData":{
        "type":"caption","language":"en","text":"year cagar forecast from 9% in\r\n2019 to 14% in 2020? And then"
      },"hidden":False,"userData":"null"
    },{
      "id":"59d02bf5-5fbd-4857-8470-50c64266c2ba","type":"transcript","start":"PT1H21M28.72S","end":"PT1H21M32.737S","eventData":{
        "type":"caption","language":"en","text":"maybe I'll just add on another\r\nquestion that we have so if we"
      },"hidden":False,"userData":"null"
    },{
      "id":"2cc14ee0-3c06-46c8-b099-ce5f442223b5","type":"transcript","start":"PT1H21M32.737S","end":"PT1H21M35.209S","eventData":{
        "type":"caption","language":"en","text":"do get to the Five and five, do"
      },"hidden":False,"userData":"null"
    },{
      "id":"ee126292-331d-44b1-805b-a9e3bd207e58","type":"transcript","start":"PT1H21M35.209S","end":"PT1H21M39.468S","eventData":{
        "type":"caption","language":"en","text":"we have any? What would this\r\nmean for Syncada's stock price?"
      },"hidden":False,"userData":"null"
    },{
      "id":"f329e328-c859-4be5-a78f-ff03d3440836","type":"transcript","start":"PT1H21M42.3S","end":"PT1H21M45.756S","eventData":{
        "type":"caption","language":"en","text":"So, uh, I think that the main\r\ndifference from last year to"
      },"hidden":False,"userData":"null"
    },{
      "id":"3cd1c4a8-94ba-40b0-9bb6-91864c519a72","type":"transcript","start":"PT1H21M45.756S","end":"PT1H21M49.5S","eventData":{
        "type":"caption","language":"en","text":"this year is really covid right?\r\nAnd the impact that code it has"
      },"hidden":False,"userData":"null"
    },{
      "id":"f73b4507-a059-4196-960e-36d931264124","type":"transcript","start":"PT1H21M49.5S","end":"PT1H21M51.228S","eventData":{
        "type":"caption","language":"en","text":"on our business in the near"
      },"hidden":False,"userData":"null"
    },{
      "id":"5feed962-bb3a-4617-9470-fe17dc7a2128","type":"transcript","start":"PT1H21M51.228S","end":"PT1H21M56.752S","eventData":{
        "type":"caption","language":"en","text":"term. Uh, I think many of the,\r\nuh, the strategic plans that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"938c287e-8ea8-46de-bb80-08c2c107a0c7","type":"transcript","start":"PT1H21M56.752S","end":"PT1H22M0.888S","eventData":{
        "type":"caption","language":"en","text":"have all put together reflect\r\nsort of a lower starting points,"
      },"hidden":False,"userData":"null"
    },{
      "id":"6ada174b-ae85-4b96-99a5-c7ade390ea96","type":"transcript","start":"PT1H22M0.888S","end":"PT1H22M5.024S","eventData":{
        "type":"caption","language":"en","text":"but we do see the growth\r\nopportunity is largely that we"
      },"hidden":False,"userData":"null"
    },{
      "id":"7d8e67e4-12ee-4221-9930-3a5fc8fae0b0","type":"transcript","start":"PT1H22M5.024S","end":"PT1H22M10.288S","eventData":{
        "type":"caption","language":"en","text":"saw in the past. In the past\r\nyear or two is still intact. We"
      },"hidden":False,"userData":"null"
    },{
      "id":"63820c0f-6f32-46ac-88cd-7f891b2b9ebb","type":"transcript","start":"PT1H22M10.288S","end":"PT1H22M14.048S","eventData":{
        "type":"caption","language":"en","text":"have then identified additional\r\ngrowth areas like the one that"
      },"hidden":False,"userData":"null"
    },{
      "id":"fdc0db5e-717f-4442-ba34-f7a95483331d","type":"transcript","start":"PT1H22M14.048S","end":"PT1H22M17.808S","eventData":{
        "type":"caption","language":"en","text":"we need just talked about in\r\nindustrial iot, right? And"
      },"hidden":False,"userData":"null"
    },{
      "id":"6a4f3341-15e9-4310-be7c-d5b0a68bdbe9","type":"transcript","start":"PT1H22M17.808S","end":"PT1H22M22.32S","eventData":{
        "type":"caption","language":"en","text":"sharpen our focus in terms of\r\nwhat would that mean for the"
      },"hidden":False,"userData":"null"
    },{
      "id":"10399a50-ee48-4d74-a34c-97f25ed3e8d7","type":"transcript","start":"PT1H22M22.32S","end":"PT1H22M26.588S","eventData":{
        "type":"caption","language":"en","text":"company and. And we believe that\r\nthose growth opportunities that"
      },"hidden":False,"userData":"null"
    },{
      "id":"c318799c-2ed0-4252-9935-83ef3077d740","type":"transcript","start":"PT1H22M26.588S","end":"PT1H22M30.848S","eventData":{
        "type":"caption","language":"en","text":"those new growth opportunities\r\nwill will increase the growth of"
      },"hidden":False,"userData":"null"
    },{
      "id":"1b153dc2-c791-4dad-92f8-ea5f3a44350c","type":"transcript","start":"PT1H22M30.848S","end":"PT1H22M35.96S","eventData":{
        "type":"caption","language":"en","text":"the company. We also now know\r\nmore about sort of the venture"
      },"hidden":False,"userData":"null"
    },{
      "id":"1532e90f-6bae-412e-b3cd-24018387cb02","type":"transcript","start":"PT1H22M35.96S","end":"PT1H22M38.942S","eventData":{
        "type":"caption","language":"en","text":"activities right around\r\nelectrification and Smart and"
      },"hidden":False,"userData":"null"
    },{
      "id":"d854cbab-143f-4bde-9b28-15dd938e2213","type":"transcript","start":"PT1H22M38.942S","end":"PT1H22M43.202S","eventData":{
        "type":"caption","language":"en","text":"connected. And we see those\r\nactually now starting to really"
      },"hidden":False,"userData":"null"
    },{
      "id":"a8f91311-ce8a-4a38-b02e-b0a3785fc3ea","type":"transcript","start":"PT1H22M43.202S","end":"PT1H22M47.888S","eventData":{
        "type":"caption","language":"en","text":"become real businesses and will\r\nhave a material impact on our"
      },"hidden":False,"userData":"null"
    },{
      "id":"faaa6ba5-4907-4c8e-a98b-4a48774182b0","type":"transcript","start":"PT1H22M47.888S","end":"PT1H22M49.592S","eventData":{
        "type":"caption","language":"en","text":"our growth going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"3e6a94df-dec9-4459-8536-0699730f2a57","type":"transcript","start":"PT1H22M50.5S","end":"PT1H22M56.156S","eventData":{
        "type":"caption","language":"en","text":"I would say last, uh, we are\r\ngoing to look at. As I said"
      },"hidden":False,"userData":"null"
    },{
      "id":"e21b7f45-cba9-47b5-a921-d4fa18b2fe26","type":"transcript","start":"PT1H22M56.156S","end":"PT1H23M0.6S","eventData":{
        "type":"caption","language":"en","text":"earlier, being a little bit more\r\naggressive when it comes to"
      },"hidden":False,"userData":"null"
    },{
      "id":"1302e15d-660d-4650-bf97-7fa5ef620f6e","type":"transcript","start":"PT1H23M0.6S","end":"PT1H23M5.044S","eventData":{
        "type":"caption","language":"en","text":"smaller bite size acquisitions.\r\nSo in order to achieve the Five"
      },"hidden":False,"userData":"null"
    },{
      "id":"f8678477-86ce-4ae0-a178-8cee6641dd8b","type":"transcript","start":"PT1H23M5.044S","end":"PT1H23M9.892S","eventData":{
        "type":"caption","language":"en","text":"and five and this higher growth\r\nrate, there is a slightly higher"
      },"hidden":False,"userData":"null"
    },{
      "id":"2bc539ff-69c9-4fac-9090-34f1c3cce9bb","type":"transcript","start":"PT1H23M9.892S","end":"PT1H23M14.336S","eventData":{
        "type":"caption","language":"en","text":"reliance on acquisitions and\r\nwhat that will not just do for"
      },"hidden":False,"userData":"null"
    },{
      "id":"9c108326-2999-4e24-bf08-7c2d0b21fa5f","type":"transcript","start":"PT1H23M14.336S","end":"PT1H23M17.164S","eventData":{
        "type":"caption","language":"en","text":"our revenue, but more\r\nimportantly what new"
      },"hidden":False,"userData":"null"
    },{
      "id":"0a1ff15d-6236-450d-bee6-aaea3fc7f2a2","type":"transcript","start":"PT1H23M17.164S","end":"PT1H23M19.184S","eventData":{
        "type":"caption","language":"en","text":"capabilities we can bring into"
      },"hidden":False,"userData":"null"
    },{
      "id":"2fb9ab23-db54-4de4-b33c-31fc728f60e6","type":"transcript","start":"PT1H23M19.184S","end":"PT1H23M24.34S","eventData":{
        "type":"caption","language":"en","text":"the company. So, so that's why\r\nwe still believe that we can"
      },"hidden":False,"userData":"null"
    },{
      "id":"d11e5afe-8fc7-4951-aaa2-f2e60dc02a38","type":"transcript","start":"PT1H23M24.34S","end":"PT1H23M26.566S","eventData":{
        "type":"caption","language":"en","text":"achieve filed in in five years."
      },"hidden":False,"userData":"null"
    },{
      "id":"942f818c-89a9-492e-8040-b961352e5128","type":"transcript","start":"PT1H23M29.78S","end":"PT1H23M33.773S","eventData":{
        "type":"caption","language":"en","text":"I forgot the last the second\r\nquestion, sorry. Can you remind"
      },"hidden":False,"userData":"null"
    },{
      "id":"75c6e409-4ae0-4442-b3af-f4f9032232d8","type":"transcript","start":"PT1H23M33.773S","end":"PT1H23M37.766S","eventData":{
        "type":"caption","language":"en","text":"me please? Sure it's about the\r\nstock price in 2025 we"
      },"hidden":False,"userData":"null"
    },{
      "id":"d62a988b-f32b-4b69-8554-aff941540ff2","type":"transcript","start":"PT1H23M37.766S","end":"PT1H23M38.855S","eventData":{
        "type":"caption","language":"en","text":"accomplished our targets."
      },"hidden":False,"userData":"null"
    },{
      "id":"e784fc49-7d94-427c-9ac3-b6b5ddd7aacd","type":"transcript","start":"PT1H23M39.94S","end":"PT1H23M42.11S","eventData":{
        "type":"caption","language":"en","text":"I don't want to\r\nspeculate in our."
      },"hidden":False,"userData":"null"
    },{
      "id":"f2351307-7bb6-40d4-adef-784d4ff54faf","type":"transcript","start":"PT1H23M44.92S","end":"PT1H23M49.444S","eventData":{
        "type":"caption","language":"en","text":"But, uh, you know, because the\r\nstock market is is up and down."
      },"hidden":False,"userData":"null"
    },{
      "id":"b1a1c319-9992-41e4-bde5-2b4479386c3b","type":"transcript","start":"PT1H23M49.444S","end":"PT1H23M54.316S","eventData":{
        "type":"caption","language":"en","text":"As you know and and a lot of\r\nthings can change in five years,"
      },"hidden":False,"userData":"null"
    },{
      "id":"ccd2b9b0-63c4-4add-a17a-5ac3d0676adc","type":"transcript","start":"PT1H23M54.316S","end":"PT1H23M57.796S","eventData":{
        "type":"caption","language":"en","text":"right? I think we should,\r\nfocusing on growing our business"
      },"hidden":False,"userData":"null"
    },{
      "id":"4755166e-c449-4145-a7f9-a8e9c3f17fa2","type":"transcript","start":"PT1H23M57.796S","end":"PT1H24M1.972S","eventData":{
        "type":"caption","language":"en","text":"and create a really strong and\r\nand high growth business. And if"
      },"hidden":False,"userData":"null"
    },{
      "id":"e4753bdb-0cc3-42a0-b903-5f95933be466","type":"transcript","start":"PT1H24M1.972S","end":"PT1H24M6.496S","eventData":{
        "type":"caption","language":"en","text":"we do that, the stock price will\r\ntake care of itself. So let's"
      },"hidden":False,"userData":"null"
    },{
      "id":"4eff6d63-581d-45aa-9381-7a8a1b5d5989","type":"transcript","start":"PT1H24M6.496S","end":"PT1H24M10.324S","eventData":{
        "type":"caption","language":"en","text":"focus not on the stock price.\r\nLet focusing on building a"
      },"hidden":False,"userData":"null"
    },{
      "id":"8e3c2d04-7ef0-4c42-8e3f-d9198675d481","type":"transcript","start":"PT1H24M10.324S","end":"PT1H24M11.368S","eventData":{
        "type":"caption","language":"en","text":"really good business."
      },"hidden":False,"userData":"null"
    },{
      "id":"bb5691d0-8d39-495f-bbca-5aa04e333412","type":"transcript","start":"PT1H24M13.42S","end":"PT1H24M17.512S","eventData":{
        "type":"caption","language":"en","text":"Alright, thank you so much Hun.\r\nSo we have one minute left."
      },"hidden":False,"userData":"null"
    },{
      "id":"8756922c-b353-4cc7-a958-5e2a506eddfa","type":"transcript","start":"PT1H24M17.512S","end":"PT1H24M21.604S","eventData":{
        "type":"caption","language":"en","text":"Wanna make sure everyone gets\r\nout on time. Uhm I will take"
      },"hidden":False,"userData":"null"
    },{
      "id":"74711b35-270f-4ac7-9758-b12d9f208702","type":"transcript","start":"PT1H24M21.604S","end":"PT1H24M25.355S","eventData":{
        "type":"caption","language":"en","text":"the last question on people and\r\nyou know what sort of"
      },"hidden":False,"userData":"null"
    },{
      "id":"5a9317b8-c29d-4100-9749-bb1299913f96","type":"transcript","start":"PT1H24M25.355S","end":"PT1H24M28.765S","eventData":{
        "type":"caption","language":"en","text":"investments are are necessary\r\nas we pivot in evolve our"
      },"hidden":False,"userData":"null"
    },{
      "id":"8a5d372d-f695-45b9-bfca-40c4f7134fb6","type":"transcript","start":"PT1H24M28.765S","end":"PT1H24M31.834S","eventData":{
        "type":"caption","language":"en","text":"strategy. Obviously people are\r\nthe significant part of that"
      },"hidden":False,"userData":"null"
    },{
      "id":"9b415407-89bd-480a-88e0-c618cae7b354","type":"transcript","start":"PT1H24M31.834S","end":"PT1H24M36.267S","eventData":{
        "type":"caption","language":"en","text":"strategy and the key pillar. So\r\nwhat will we be doing to invest"
      },"hidden":False,"userData":"null"
    },{
      "id":"f670555b-b0b6-4a14-8b11-13a73ecb9741","type":"transcript","start":"PT1H24M36.267S","end":"PT1H24M39.677S","eventData":{
        "type":"caption","language":"en","text":"in our people as our products\r\nin our solutions evolve?"
      },"hidden":False,"userData":"null"
    },{
      "id":"50890d4e-ef40-44ac-b74d-110b601fe694","type":"transcript","start":"PT1H24M41.89S","end":"PT1H24M45.478S","eventData":{
        "type":"caption","language":"en","text":"Maybe I'll ask cons to start\r\nthat, and an maybe Jeff or"
      },"hidden":False,"userData":"null"
    },{
      "id":"8c40cea9-4c3c-4b00-b41a-46dfe1472287","type":"transcript","start":"PT1H24M45.478S","end":"PT1H24M47.571S","eventData":{
        "type":"caption","language":"en","text":"Vanita pool. It can jump in as"
      },"hidden":False,"userData":"null"
    },{
      "id":"465c8aaa-0aae-41fc-91d9-5a72aec7ef63","type":"transcript","start":"PT1H24M47.571S","end":"PT1H24M52.796S","eventData":{
        "type":"caption","language":"en","text":"well. Sure, yeah. It's as I\r\nmentioned in my in my earlier"
      },"hidden":False,"userData":"null"
    },{
      "id":"f08cde10-8b3b-455a-ae87-5691cc3c483c","type":"transcript","start":"PT1H24M52.796S","end":"PT1H24M56.932S","eventData":{
        "type":"caption","language":"en","text":"talk here, people is really the\r\nthe critical resources we have"
      },"hidden":False,"userData":"null"
    },{
      "id":"f4ba4020-da9f-4903-b1a8-6317110a55c1","type":"transcript","start":"PT1H24M56.932S","end":"PT1H25M1.82S","eventData":{
        "type":"caption","language":"en","text":"of course, and we have to make\r\nsure that we invest in our"
      },"hidden":False,"userData":"null"
    },{
      "id":"35c52883-86c2-402a-8e6a-2e524dd2e9cb","type":"transcript","start":"PT1H25M1.82S","end":"PT1H25M5.956S","eventData":{
        "type":"caption","language":"en","text":"people but also involves sort of\r\nthe capabilities that is needed"
      },"hidden":False,"userData":"null"
    },{
      "id":"376b54e1-0ea8-4907-8054-9660191a5f57","type":"transcript","start":"PT1H25M5.956S","end":"PT1H25M9.716S","eventData":{
        "type":"caption","language":"en","text":"to be successful here. Going\r\nforward with all the changes"
      },"hidden":False,"userData":"null"
    },{
      "id":"264ca5a3-e278-4548-b02f-ea7a67ef5499","type":"transcript","start":"PT1H25M9.716S","end":"PT1H25M13.852S","eventData":{
        "type":"caption","language":"en","text":"that we have laid out in this\r\npresentation and elsewhere with"
      },"hidden":False,"userData":"null"
    },{
      "id":"22ce2df9-7403-4561-9edd-d1ae32da17f2","type":"transcript","start":"PT1H25M13.852S","end":"PT1H25M18.364S","eventData":{
        "type":"caption","language":"en","text":"new customer segments that we\r\nneed to serve. We also need to"
      },"hidden":False,"userData":"null"
    },{
      "id":"db834383-1b63-4800-9879-f7360ae2ec3e","type":"transcript","start":"PT1H25M18.364S","end":"PT1H25M21.372S","eventData":{
        "type":"caption","language":"en","text":"evolve and build new skills,\r\nright? So it's."
      },"hidden":False,"userData":"null"
    },{
      "id":"f2848aa2-5b8c-4988-9a09-0b92fae4fa7d","type":"transcript","start":"PT1H25M22.05S","end":"PT1H25M26.439S","eventData":{
        "type":"caption","language":"en","text":"It's a very, very important um\r\nattribute to our strategy, of"
      },"hidden":False,"userData":"null"
    },{
      "id":"f6d376e1-f898-47f6-9d32-845224b779d9","type":"transcript","start":"PT1H25M26.439S","end":"PT1H25M30.828S","eventData":{
        "type":"caption","language":"en","text":"course, and we will continue to\r\ninvest in our people. We're"
      },"hidden":False,"userData":"null"
    },{
      "id":"7d098ffc-9fd6-49d6-9305-c89388450fe6","type":"transcript","start":"PT1H25M30.828S","end":"PT1H25M34.818S","eventData":{
        "type":"caption","language":"en","text":"trying to make the processes\r\nmore efficient effective so we"
      },"hidden":False,"userData":"null"
    },{
      "id":"f82bfd12-a462-4020-ad80-629113f753e4","type":"transcript","start":"PT1H25M34.818S","end":"PT1H25M38.808S","eventData":{
        "type":"caption","language":"en","text":"can get our work done more\r\nefficiently and effectively. An"
      },"hidden":False,"userData":"null"
    },{
      "id":"6a89c839-ed4b-4c4f-995b-5ffa3364d5c7","type":"transcript","start":"PT1H25M38.808S","end":"PT1H25M43.197S","eventData":{
        "type":"caption","language":"en","text":"we need to build new scales to\r\naddress the both opportunities"
      },"hidden":False,"userData":"null"
    },{
      "id":"d20d4493-931a-437d-97a2-7a2e9e473e4c","type":"transcript","start":"PT1H25M43.197S","end":"PT1H25M47.985S","eventData":{
        "type":"caption","language":"en","text":"and some of the threats that we\r\nhave laid out in the"
      },"hidden":False,"userData":"null"
    },{
      "id":"54b83072-36c1-479e-9a3e-483fe0ea127c","type":"transcript","start":"PT1H25M47.985S","end":"PT1H25M52.773S","eventData":{
        "type":"caption","language":"en","text":"presentation. So more to come.\r\nAnd as Jeff said, it's hard to."
      },"hidden":False,"userData":"null"
    },{
      "id":"6e2f9836-ae99-42c7-9efc-83406b70d355","type":"transcript","start":"PT1H25M53S","end":"PT1H25M56.872S","eventData":{
        "type":"caption","language":"en","text":"Make all those investments in\r\nthe near term because of the"
      },"hidden":False,"userData":"null"
    },{
      "id":"31fcabf6-eba2-449b-b5f3-ba31dda82d19","type":"transcript","start":"PT1H25M56.872S","end":"PT1H26M0.744S","eventData":{
        "type":"caption","language":"en","text":"impact of covert that we're\r\ndoing our very best and we"
      },"hidden":False,"userData":"null"
    },{
      "id":"185aab0c-b2f0-4c79-8d9a-bea176aedcbd","type":"transcript","start":"PT1H26M0.744S","end":"PT1H26M4.264S","eventData":{
        "type":"caption","language":"en","text":"will continue to be very open\r\nand transparent with our"
      },"hidden":False,"userData":"null"
    },{
      "id":"046285de-4a66-4893-aee1-0abf4355fee1","type":"transcript","start":"PT1H26M4.264S","end":"PT1H26M5.32S","eventData":{
        "type":"caption","language":"en","text":"plans going forward."
      },"hidden":False,"userData":"null"
    },{
      "id":"8fe0de28-cd9b-4e67-a7a2-75bc47e651dc","type":"transcript","start":"PT1H26M7.47S","end":"PT1H26M11.106S","eventData":{
        "type":"caption","language":"en","text":"The only thing I would add\r\nthis has been eight is when"
      },"hidden":False,"userData":"null"
    },{
      "id":"3cdd3542-4a1f-4f5a-9def-8d3d48b95aa7","type":"transcript","start":"PT1H26M11.106S","end":"PT1H26M13.53S","eventData":{
        "type":"caption","language":"en","text":"you you heard about the\r\ngrowth plans today."
      },"hidden":False,"userData":"null"
    },{
      "id":"1e27d68e-576c-4287-90dc-a45668e6e0ae","type":"transcript","start":"PT1H26M15.14S","end":"PT1H26M19.872S","eventData":{
        "type":"caption","language":"en","text":"Going from 3 billion or so to 5\r\nbillion is gonna be a"
      },"hidden":False,"userData":"null"
    },{
      "id":"dad9508a-3219-42a5-be29-80b58e977218","type":"transcript","start":"PT1H26M19.872S","end":"PT1H26M23.512S","eventData":{
        "type":"caption","language":"en","text":"tremendous amount of growth,\r\nand growth creates a lot of"
      },"hidden":False,"userData":"null"
    },{
      "id":"d74c9722-8c86-4bda-b676-69fe1a658db9","type":"transcript","start":"PT1H26M23.512S","end":"PT1H26M26.788S","eventData":{
        "type":"caption","language":"en","text":"opportunity, but ultimately we\r\nall own our own couriers,"
      },"hidden":False,"userData":"null"
    },{
      "id":"38286537-cdfc-467d-a907-c2c7c284f02e","type":"transcript","start":"PT1H26M26.788S","end":"PT1H26M30.792S","eventData":{
        "type":"caption","language":"en","text":"right? And so I would encourage\r\neverybody to to understand the"
      },"hidden":False,"userData":"null"
    },{
      "id":"2f780f01-9733-4286-8a6f-8c96870f5690","type":"transcript","start":"PT1H26M30.792S","end":"PT1H26M34.068S","eventData":{
        "type":"caption","language":"en","text":"growth plans, seek out those\r\nnew opportunities that will"
      },"hidden":False,"userData":"null"
    },{
      "id":"3852d071-5921-4c41-8aed-87ac3085adfc","type":"transcript","start":"PT1H26M34.068S","end":"PT1H26M38.436S","eventData":{
        "type":"caption","language":"en","text":"come as a result of that\r\ngrowth, and really ask how can"
      },"hidden":False,"userData":"null"
    },{
      "id":"c6f39980-b548-4c6b-8db8-7de946593f99","type":"transcript","start":"PT1H26M38.436S","end":"PT1H26M42.44S","eventData":{
        "type":"caption","language":"en","text":"you make an impact to help the\r\ncompany achieve those growth"
      },"hidden":False,"userData":"null"
    },{
      "id":"b896de75-e007-43d7-9882-04737643adb2","type":"transcript","start":"PT1H26M42.44S","end":"PT1H26M44.988S","eventData":{
        "type":"caption","language":"en","text":"objectives. So there's a ton of\r\nopportunity."
      },"hidden":False,"userData":"null"
    },{
      "id":"74cd5051-c243-46ab-9dfa-23810cc9883a","type":"transcript","start":"PT1H26M46.07S","end":"PT1H26M49.469S","eventData":{
        "type":"caption","language":"en","text":"In in an earlier answer here,\r\nwe highlighted there's a lot"
      },"hidden":False,"userData":"null"
    },{
      "id":"c738b813-6c3d-4fa2-bc8a-e1a6738d3272","type":"transcript","start":"PT1H26M49.469S","end":"PT1H26M52.25S","eventData":{
        "type":"caption","language":"en","text":"of training being rolled out\r\nand being made available."
      },"hidden":False,"userData":"null"
    },{
      "id":"b496e241-f2da-42da-a0b0-656d76bba4d0","type":"transcript","start":"PT1H26M52.25S","end":"PT1H26M55.031S","eventData":{
        "type":"caption","language":"en","text":"Raise your hand, volunteer\r\nfor the opportunity. Ask how"
      },"hidden":False,"userData":"null"
    },{
      "id":"05f17e31-8022-469b-8f3f-bc46bbb48779","type":"transcript","start":"PT1H26M55.031S","end":"PT1H26M59.048S","eventData":{
        "type":"caption","language":"en","text":"you can help. Ask how you can\r\nhave an impact and get the"
      },"hidden":False,"userData":"null"
    },{
      "id":"b5e0539d-c84d-45b2-a823-f0336e1ed3bd","type":"transcript","start":"PT1H26M59.048S","end":"PT1H27M2.447S","eventData":{
        "type":"caption","language":"en","text":"right training in order to be\r\nready for that role, because"
      },"hidden":False,"userData":"null"
    },{
      "id":"1e165221-f253-4648-a43d-8d7394794a0a","type":"transcript","start":"PT1H27M2.447S","end":"PT1H27M6.155S","eventData":{
        "type":"caption","language":"en","text":"this is going to be a really\r\nexciting journey an we really"
      },"hidden":False,"userData":"null"
    },{
      "id":"882ad8de-0d12-4a43-ac46-4bd696cdb111","type":"transcript","start":"PT1H27M6.155S","end":"PT1H27M9.554S","eventData":{
        "type":"caption","language":"en","text":"need everybody to lean in and\r\nhelp us achieve that growth."
      },"hidden":False,"userData":"null"
    },{
      "id":"663ad0ca-79c9-4db3-8970-cdfabdf478fc","type":"transcript","start":"PT1H27M12.26S","end":"PT1H27M16.017S","eventData":{
        "type":"caption","language":"en","text":"Alright, so I can't think of a\r\nbetter comment to close on. I"
      },"hidden":False,"userData":"null"
    },{
      "id":"4f9f99e1-3717-4b1c-afa9-d4bb93a8c217","type":"transcript","start":"PT1H27M16.017S","end":"PT1H27M19.485S","eventData":{
        "type":"caption","language":"en","text":"want to thank everyone on the\r\npanel. I wanna think Jeff, I"
      },"hidden":False,"userData":"null"
    },{
      "id":"796b523c-9cdf-4c60-ab28-f265d6905cfc","type":"transcript","start":"PT1H27M19.485S","end":"PT1H27M22.664S","eventData":{
        "type":"caption","language":"en","text":"want to thank all of you for\r\nattending. I really encourage"
      },"hidden":False,"userData":"null"
    },{
      "id":"121c51ca-1966-4497-a949-7f3fff9ca962","type":"transcript","start":"PT1H27M22.664S","end":"PT1H27M26.71S","eventData":{
        "type":"caption","language":"en","text":"you to attend our next quarterly\r\ntown Hall on Aug 6th. I know you"
      },"hidden":False,"userData":"null"
    },{
      "id":"536750e0-23ee-4982-b4b7-06b407f7bccf","type":"transcript","start":"PT1H27M26.71S","end":"PT1H27M30.178S","eventData":{
        "type":"caption","language":"en","text":"have a lot of questions and he\r\nsubmitted a ton of questions"
      },"hidden":False,"userData":"null"
    },{
      "id":"254e9ed2-49b2-4481-b1f7-345039944d8f","type":"transcript","start":"PT1H27M30.178S","end":"PT1H27M33.357S","eventData":{
        "type":"caption","language":"en","text":"around. You know people that\r\nhave taken a number of voluntary"
      },"hidden":False,"userData":"null"
    },{
      "id":"a83df1f5-dd28-40f9-8262-e617edda9518","type":"transcript","start":"PT1H27M33.357S","end":"PT1H27M36.536S","eventData":{
        "type":"caption","language":"en","text":"and involuntary actions will\r\ntalk about all that on our next"
      },"hidden":False,"userData":"null"
    },{
      "id":"dec7ed5c-25d3-4dd7-8085-ba121269fc2f","type":"transcript","start":"PT1H27M36.536S","end":"PT1H27M38.848S","eventData":{
        "type":"caption","language":"en","text":"quarterly townhall. Obviously\r\ntoday was really focused on"
      },"hidden":False,"userData":"null"
    },{
      "id":"f7256754-e9ba-4178-8559-909066aa6f2a","type":"transcript","start":"PT1H27M38.848S","end":"PT1H27M41.738S","eventData":{
        "type":"caption","language":"en","text":"stint. Uhm, I want to thank\r\neveryone for participating and"
      },"hidden":False,"userData":"null"
    },{
      "id":"31fc5c4f-4f9e-4eac-9b55-dbb1bdbbef55","type":"transcript","start":"PT1H27M41.738S","end":"PT1H27M43.472S","eventData":{
        "type":"caption","language":"en","text":"thank you for working so hard"
      },"hidden":False,"userData":"null"
    },{
      "id":"cd31625a-f693-42d6-83c6-6543117eb7cd","type":"transcript","start":"PT1H27M43.472S","end":"PT1H27M46.112S","eventData":{
        "type":"caption","language":"en","text":"for Team Syncada. Please\r\ncontinue to stay safe and"
      },"hidden":False,"userData":"null"
    },{
      "id":"819bcabc-e177-47f9-97eb-854d36c5b7b1","type":"transcript","start":"PT1H27M46.112S","end":"PT1H27M48.582S","eventData":{
        "type":"caption","language":"en","text":"serve our customers and be\r\nwell. Have a great day"
      },"hidden":False,"userData":"null"
    },{
      "id":"4133dfb3-14c4-492f-9fc9-b76b4902aefa","type":"transcript","start":"PT1H27M48.582S","end":"PT1H27M48.829S","eventData":{
        "type":"caption","language":"en","text":"everyone."
      },"hidden":False,"userData":"null"
    }
  ]
}

# %%
t.keys()
# Out:
# dict_keys(['value'])

# %%
len(t['value'])
# Out:
# 1386

# %%
t1 = []
for i in t['value']:
    t1.append(i['eventData']['text'])

# %%
print(' '.join(t1))
# Out:
# Alright, well we'll get started.
# Good morning, Good afternoon,  good evening, um everyone. Thank you for joining us on our STINT  global Town Hall. We will talk about our strategic intent   process today and what that means for Sensata. This is the  second year in a row that we're
# doing this. So we started last  year broadcasting from Attleboro, and obviously because  of the pandemic, we've had to
# accelerate our abilities to communicate globally and it's
# really been really well received. So thank you everyone. Next slide, please. For those of you that don't
# know me, my name is Alexia Taxiarchos. I head of our communications team, what we will be sharing with you
# today is considered to start a technology strictly
# private. Obviously, as our employees we show information
# with you that we might not share with broader audiences,
# so we really ask for you to respect that trust and
# understand that information that you will be hearing
# today, whether it's about revenue or market potential
# is proprietary, insensitive  to Sensata -  next slide.  We have about 90 minutes set
# aside for you today and you'll  hear from a number of speakers across Sensata. I'm Hans Lidforss Our SVP  Chief Strategy and Corporate Development Officer  will give you an overview of what STINT is, how we arrive at   it, and end of you on corporate STINT. Vineet Nargolwala, our EVP of Sensing Solutions business. That's our industrial  aerospace in HVOR  businesses will give you an overview of the  incensing solutions business.  Markets Paul Chawla, our EVP or performance sensing and automotive will give you a view
# into our automotive markets  globally and then George Verras, our SVP of Sensata Ventures  will give you a view into some of the really interesting initiatives that we have in Sensata Ventures and how they work across the company to drive
# growth. Next slide please. We will be doing Q&A today on
# Microsoft teams live event and one of the things that I should
# have mentioned at the outset. Is that Microsoft Teams live
# event is a little bit different than just a regular teams event,
# so you may be looking for your mute button because we've all
# been during those meetings in the past few months where we've
# had to mute our buttons or we want to say something at a live
# event is a little bit different that you're automatically muted
# unless your presenter. Otherwise we have thousands of people on
# this call, and it would just be really unproductive, so this is
# the way that you know we want to hear from you. So please do use
# a Q and a feature. It's on your teams. Or if you click on your
# butt on the hover over it, there's a little you know,
# dialogue box with a question and that's how you can come get your
# questions in. We would ask that you you know really paid
# attention to everything that the presenters have collected today
# to present to you. There's a lot of information we've distilled
# this into. What's most important, but obviously as you
# know so many, so many people across this out of work on this
# tent material and we really are appreciative so. Take the time,
# listen really know, get involved. Ask the questions that
# you want and we will take. Take your questions at the end. Next slide, please. Alright, so with that I'm after
# stage and I'd like to hand it over to hands to take over Hans.
# Alright so thank you, uh everybody for calling in Um, I
# will next page please. I will first go through a few
# process changes that we have implemented this year to make
# the stent process more efficient and effective. Uh, so first
# changes that we have more clearly addressed the three
# levels of strategy this year, so corporate strategy, business
# unit strategy, and functional strategy. Uh, the corporate
# strategy should really outline the overall vision of the
# company. The overall strategic direction where we should select
# to compete an resource allocation. Business unit
# strategy then, should a follow on to those directions an
# outline how to maximize revenue and profit within the selected
# market segments. Outline of the corporate strategy. Um, since
# I'd adventure is really a subset of the be your business strategy
# and they are, as you probably know, specifically tasked to
# explore new business opportunity within the Megatrends. Functional strategies, then
# uhm, should outline plans to support the BU strategies in
# the most effective way, so we have really tried to layout
# sort of more distinctive corporate strategy, business
# unit strategy and functional strategy in this year's stink. Next page, please. The second change we have
# implemented this year is we have divided distinta process into
# two parts to further focus on and develop our growth opportunities. So that part one
# that we have just gone through focuses on really identifying
# market opportunity and growth initiatives. Part 2 that we will
# kick off in a fall. Focus on um, the current business
# entitlements. An hour long range plan and you will hear more
# about those further in the fall. Near for this year is also
# tighter focus between the long range planning, an annual plan
# which previously was quite separate processes, so you will
# see a tighter coordination between the two this year. And ask me for once we have
# approved stints, uh, we will develop strategies for cards
# which tracks how we're delivering on this train
# strategies. And we will monitor those quarterly. Uh, if one of
# the strategic scorecard metric shows that we are off
# strategy, we will review those topics in the so-called
# meanest things as needed. But typically we review those mean
# instant it once per quarter. Next page, please. Turning now to our vision and
# strategy. Uhm, we continue to believe that our vision and
# purpose are both compelling and give good guidance towards our future direction. Our vision and
# purpose, therefore remain larger. The same with two minor tweaks. Hey, in our revision
# we have added the words an insights in the end. As you
# can see, just signal that we are not only going to be a
# world leader, an early innovator or mission critical
# sensory solutions but also leader in providing our
# customer valuable insights from those solutions. We have also added the words
# an partners to our purpose to signal that we should not only
# help our customers deliver a cleaner, more efficient,
# electrified and connected world, but we should also
# extend those to our partners which will be most will be
# increasingly important. Next Page P. As any good strategy development
# process, it starts with a good understanding of the markets,
# our competitors in the customers we serve. And ask you now, um,
# there has been a lot of changes in our markets lately, and
# change continues. An even accelerates in some parts of our business. A few of those changes
# are outlined on this slide. Value is shifting from
# mechanical components in intelligent systems and software. Disruptors are
# taking advantage of those changes and driving many of
# these trends. Tesla being yes. One good example loaded. They changed is also more
# significant and happening faster than ever before. Uh, which creates both
# opportunities and threats. I tend to view those changes
# as opportunities, but we should recognize that some of
# them also can be threats if we don't address them properly. One example of what we need to
# do differently is to leverage different forms of partnerships
# better, since going alone is often too slow and may not need
# the new customer needs. Another example of changes that
# are impacting our business or macro factors like trade
# disputes with China. We will need to adapt our business to
# those changes and for example, we may have to alter the way we
# play and win in China. We have, of course taken all
# those changes into consideration when we have developed our new
# strategy, in which I will go through here shortly. Next
# page, please. COVID-19 has of course had a
# material impact on our business, and in short in the short term. We know it hasn't been easy for
# all of you to navigate these last few months and we
# appreciate all the sacrifices that you have made, including
# temporary pay cuts in photos. The good part is that we do see
# a recovery, but it will likely take a year or two before we get
# back to pre COVID-19 levels. Other consequences of
# COVID-19 are likely an increase regionalization,
# and it possible exploration of the megatrends
# opportunities. So we will have to monitor and address
# those going forward if and when they happen. Next page, please. Before we look ahead, I
# would like to spend a few minutes to look back and
# provide some context for our revised strategy. Over the last 10 years we have
# delivered on average good top line and bottom line group. We
# have launched St Ventures and started to make good progress on
# electrification and Smart and connected and some progress
# lately on autonomy especially. Play with the acquisition
# of people. We have been and continue to be
# resource constraint, not opportunity constrained, and
# that's a very good situation to be in. Next page, please. Having said that, on one
# important metric, total shareholder return or TSR, we
# have lagged our competitors over last five years. As you can see
# in the top shot. We have a work **** **
# identifying why we have lag. Versus competitors and we have
# found that there are three main reasons for our lagging TSR. The most important reason is
# that our growth and you can see that in the lower left hand
# corner of this, short has been lumpy. Uh, both organic and
# inorganic growth has been lumpy and on average we have delivered
# only 3% top line growth over the last five to six years. The second reason is that
# although we have worked **** ** developing the megatrend
# opportunities, they have not yet delivered meaningful
# contribution to our growth. We hope we hope they will, but so
# far we are investing a lot of money in these opportunities and
# yet they have still to deliver a meaningful contribution to our
# growth going forward. And 30 uh, there is also some
# drag as we have discussed in the past, for our order
# exposure, given the cyclicality of that business
# segment. So when you Add all the Bob
# together, we have recognized an address. Uh, these and
# other factors. Whenever develop our new strategy and
# the main tweaked or strategy largely come down to two
# words, accelerate and focus, which I will now cover on the
# next page. Next page, please. Sorry, new strategy builds on
# the previous concept of five and five, which I hope you're all
# familiar with, but adds the concepts of accelerating focus,
# which is particularly important since again, we're resource
# constraints and not opportunity constrained. So let me go
# through a on a high level what these concepts mean. And my
# colleagues will expand on these concepts to other in
# their sections. To capture to better capture the
# growth opportunities going forward, we will, uh, need to
# identify a high growth and markets and opportunities and
# Excelerate the investment in those and markets where we can
# deliver differentiated marketing. So that's really the
# accelerate portion of that week to this strategy. Uh, the other side on this
# page, actively managed business portfolio is the
# basically the consequences of the acceleration and that is
# that we have to focus in more actively managed or respond in
# some areas of the portfolio so we can free up capital to
# invest in those most attractive opportunities we
# have in front of us. Again, we are resource constraints and
# not opportunity posting. This is gonna, uh, this is
# hard to make those these choices, and frankly we are
# not very good at it because we all see the opportunities in
# front of us and we want to do them all but often. The
# consequences of that is that we don't have enough money or
# resources to spend on the most attractive opportunities in
# front of this and that sort of the change that we are trying
# to implement in this year's team. Please note that all
# areas of our business are equally important. It's just that different parts
# of our business have a different role in our
# portfolio. Some will generate cash, another will consume
# cash while we're growing at these most attractive
# opportunities. Next page, please. So when it comes to the
# excelerate part of our strategy, the areas where we will
# accelerate and increase our investment in is largely in the Megatron areas. Uh, especially
# around electrification, smarting connected, industrial iot, and
# to a lesser extent, autonomy. We have made good and broad
# based progress in an application and will accelerate our
# investment further in this area. More narrowly focused maybe, but
# we have also made very good progress in our smarting
# connected initiative in HBO. Uh, and we are now considering
# expanding, uh, that initiative into like vehicles as well. Industrial iot is the newest
# area of focus, but we think there is a substantial
# opportunity in this area and it will help with our
# diversification strategy. We need will expand on our
# thoughts in this area later. Autonomy is the area where we,
# uh, have made last progress over the last few years. But with the
# acquisition of Preco we now have a platform to build from an
# initially in the Raider in radar solution for HBO. Next page, please. As I mentioned earlier, we want
# to accelerate our investment in high growth areas and therefore
# we will have to scale back or investment in other areas. We
# will therefore more explicitly manage our portfolio of assets
# according to religion, vigil growth and margin potential. One tool that we have used in
# the past and will continue useful in forward is this song
# to win framework, which as you may know, how four areas in
# incubation stoneware you invest in an incubator business
# opportunity. I transformation sound where you invests more
# behind the most attractive opportunities to grow them, interviewed businesses.
# Performance owned by the majority of our business
# should be and is where the business are generating both
# good growth and good profitability. And finally the
# productivity sewn where businesses are not generating
# significant growth. Maybe but could be quite profitable in
# feed new business ideas in the incubator. Luckily for us, many of our
# businesses are in the performance zone, but we do
# also have a number of business segments in the
# productivity sound which we will manage going forward. As part of the accelerating
# focus strategy, we will be increasing our investment in
# high growth areas, which largely a will will be in the
# uh, incubation and transformation zone and that
# will happen both inside adventures and in the business
# units. Again, I want to stress that all
# business segments are equally important. They just form a
# different role in the overall since our business before you. Next page, please. To support the strategy of five
# and five accelerator focus, we have also identified key support
# areas that we will focus on. The first one is A is a poor
# customers. We will of course continue to serve our existing
# customers and we will continue to work on improving commercial
# excellence, for example, through the sales and marketing console
# that we need leads. In addition, we will also have
# to develop new capabilities in channels to market. For example,
# development system integration channel, since we will start to
# serve different customer segments which will have
# different customer needs. When it comes to basically
# operating systems, we will of course also have to adapt our
# our business operating system to capture this new opportunities
# and we will have therefore how to adapt how they operate and
# partners a company. This will take different forms
# in different parts or business. For example, in Automotive we
# will likely start to develop new partnerships and maybe even
# joint ventures to deliver our expanded value proposition to our customers. We will also work
# on on two large cross business improvement initiative since our
# business systems, led by John will address process
# effectiveness and efficiency starting with the sale process. And the second large initiatives
# is Ron. Since how to management system, which is led by Paul
# Bassington? Uh, that will address, for example, how we
# make decisions and what we will measure on a consistent basis. When it comes to capital
# deployment, our capital deployment policies Will Rock
# largely remain the same, but as I mentioned earlier, we will
# allocate capital and resources. Better to serve the most
# attractive growth opportunities. Last but definitely not
# least, is of course our people. Our most important
# resource. We will continue to involve invest in all of
# you so we together can capture the many exciting
# opportunities we have in front of us. Next page, please. So to conclude, our my section,
# if we successfully deliver on our five and five, accelerate
# and focus strategy and Adolar stand plans together, we still
# believe that we are can be a 5 billion dollar targets in five
# years, with roughly a 5050 split between auto and sensing
# solution in five years that you can see in the right side. In summary, uhm, we have a very
# exciting opportunity in front of us. We believe that we have the
# right vision, strategy and plans. So with all your
# tremendous help and support, it will make it all happen. So on behalf of their salty
# thank you for delivering on the short and long. Term goals
# office insider. I will now hand over to. We need
# to work cover sensing solutions. Thank you Hans. At high team. Uh, I'm married and I have the
# privilege of leading the sensing solutions team and really,
# really excited about sharing our strategic framework with all of
# you today. So as I think about strategy and Hans mentioned it,
# strategy is a set of choices. And force the sensing solutions businesses. The slate of choices
# has never been greater. And the stakes, in terms of
# making the right choice. Have never been greater either. And before I jump into the
# strategic framework, I do want to thank the entire sensing
# solutions team for the hard work in the thought they put into
# bringing the right strategies forward in. What is a very, very
# difficult time. So if you can go to the next page place. Let me start by saying that the
# end markets we serve. Whether it's an industrial,
# whether it's in heavyweight, in an off road, or an aerospace,
# remain attractive and markets. And our businesses continue
# to build an extend a leadership position within
# those end markets with differentiated margins. As has mentioned and we all know
# too, well covered has had a dramatic impact on the end markets. And in the near term,
# that impact has been sharp and it's been immediate. But we believe that recovery,
# while it will be slow, will happen over the next two to three years. An covert has not
# changed or mission of driving growth in achieving the
# diversification and the following five that has just
# laid out for the company. As I think about the arc over
# the next five and really over the next decade. The Mega Trends
# of electrification iot an economy are going to have an
# outsize impact. These are major discontinuities affecting all of
# our end markets and are creating opportunities for significant
# growth, both organically as well as through acquisitions. And we intend to use
# both levels to achieve our growth objectives. When I think about each of
# the businesses. Our industrial business is
# probably in the need of transformation is most in the
# need for transformation in order to take advantage of these megatrends. And when I talk
# about a transformation is really across the board. It's in how we
# go to market, what and what markets we focused on focus on. In terms of a portfolio and the
# product that we need in order to be relevant in an iot world. In terms of channels where we
# largely serving OEM channel today and in order to take
# advantage of iot and to be meaningfully present in the
# iot space, we do have to think about opening up a
# system integrator channel. And also in terms of our
# organization structure in terms of talent as the skills required
# to serve the iot market as well as the SI channel are going to
# be quite different than this skills we've developed and the
# muscles will develop through serving the OEM channel. When I think about our heavy
# metal and offered business, I would say that this is a
# business that is really well positioned to benefit from the Megatrends. With the activities
# that are happening within the business that are happening
# within ventures and CEO as well as through our acquisition pipeline. The evidence of
# that, of course, is the recent acquisition of prequel, which
# is a great addition to our a tree or business. An overall
# towards insider family. Find your aerospace
# business. It's a small but mighty business. One of our
# most profitable businesses and in an end market, which
# I think has secular, long-term growth trends. The aerospace business has a
# great organic path with 10% growth. But it's clear then
# for us to have a meaningful presence in the aerospace
# industry, we need to scale up our business through Eminem. And if we put all of our
# initiatives together, we do have an opportunity here to
# double the size of our business, and so it's a really
# exciting time within sensing solutions an our businesses as
# we take on that challenge of doubling the size of our
# business over the next five years. Next slide, please. So so. So let me spend a little
# bit of time on on the Mega Trends. And as I said, These are
# creating great discontinuity in the end markets we serve. And for us, what that means is
# that the available market ahead of us more than doubles over the next decade. Now, I'm not going
# to read through the numbers here. I think it's pretty
# obvious that the markets are going to be significant and
# very, very meaningful. But if you look beyond the numbers,
# what's really happening in the end markets? We serve our two
# major trends. It's decarbonization. And
# digitization. And while you might say that
# we've talked about or, there's been discussion of these two
# megatrends for sometime. Why is now the right time for us
# to go invest in these areas? I think the reality is the facts
# are that the technology required to make this a reality now. Auto available and now are more
# cost effective than ever. So when you think about the availability of. Battery
# technology and it cost efficiency of battery
# technology. That's finally here. When you think about the cost of solar. It's down 80% just in the
# last five years. When you think about the cost of wind energy,
# it's down 40% in the last five years. Then you think about
# what's enabling iot, the deployment of 5G. The ubiquitous an highly cost
# effective cloud computing. The advent of machine learning
# and artificial intelligence are all making the digitalization of
# our plants, buildings, warehouses, supply chain much
# more a reality today than in the years past, and so we feel
# really bullish about the end markets we serve and the mega
# trends that are creating the opportunity for us to drive growth. Next slide, please. And as I said, our mission
# remains unchanged. We are focused on driving growth
# and you can see that, uh, if we are. Successful in our strategies. We have a high
# double digit growth over the next five years and the mega
# trends continue to be a tailwind for us throughout the decade. Next slide, please. So as I then connect what Hans
# talked about in terms of the Five and five and accelerate in
# focus into what is relevant and what is really important for us within sensing solutions. Let me
# start with the people side first. It's clear that. We need to have the right skill
# sets, the right organization structure. The right efficient
# cost base an we need to have strong global centers of
# business as well as engineering in order to achieve our growth objectives. And I will tell
# you that this is an error that my leadership team and I
# are spending a ton of time thinking about and putting it
# into action. When I think about our
# customers, really the big change that we expect to see over the
# next five years is moving from an OEM only model to an OEM and
# system integrated model an that is no easy task building and SI
# Channel from scratch or even acquiring one. Rick will require
# us to add new skill sets and really think about commercial
# excellence in a different way. When I think about our
# operating system, we've talked about Taylor supply chain for
# some time now, and I think it's really important that we
# do develop the flexible manufacturing capability that
# we need in order to go serve. Both are OEM customers as well
# as the new SI channel that we're talking about. It's also really important to
# revitalize the productivity engine. I think in the years
# past, the sensing solutions business has not gotten his
# entitlement from a productivity standpoint. And as we think
# about over indexing towards growth, productivity creates the
# funding necessary to drive growth and so it's really
# important that we could do that. From a capital perspective,
# emanate is a big level for growth and as we think about
# RMA pipeline today, we're tracking almost a billion and
# a half dollars of revenue in our pipeline and we're
# quickly working to turn that from a pipeline into
# actionable initiatives within that pipeline. Next slide, please. So Hans talked about the three
# areas for strategic focus, an I'm really pleased to be talking
# about our industrial iot initiative. As we think about a
# iot within the industrial space and an. Let me define the scope
# a little bit of what that means. It's really the digitalization
# of plans of buildings, warehouses and supply chain to
# deliver more insights and ultimately more productivity. And we believe that this is at
# least 6 billion dollar market as we think purely from a
# sensing layer standpoint. If you go to the next
# slide, please. This is a very busy slide and
# I'm going to spend a little bit of time just explaining.
# You're seeing here. As we think about the
# industrial iot value chain. It's clear that there is a ton of. There are a lot of players
# trying to capture the opportunity. Ann There are traditional strong
# incumbent players. The big names like Rockwell Automation like
# Schneider like honey where like Emerson and Siemens. Who have played an important
# role traditionally within the plant space or the
# building space? But as the need for productivity
# continues to increase and destruction takes place with
# technology engine technology as with change in the value chain,
# we are seeing opportunities that are being created for new
# entrants to come in. From the top, we're seeing
# digital integrators like Accenture, Deloitte. Infosys. BTC, to name a few,
# coming in and really trying to provide a digital overlay
# onto the plant and onto the building framework. From the bottom, sensors are getting smarter. They're getting
# more sophisticated and are really becoming PNC agnostic and
# allowing a destruction of the middle there. And so as we think
# about industrial iot. It's clear to us that sensing is the starting point. An our goal,
# our job number one is to make sure that we build a strong
# position at the sensing. This is an underserved area that
# we believe, and we are continuing to validate that hypothesis. And as we build a
# position there, we will look for opportunities to go up the stack. But it's not clear to us
# that we that there is an opportunity broadly further up
# the stack to serve this space. We have some great data points,
# whether it's a material handling business or it's our newly
# acquired C3 business where there are opportunities to go further
# up the stack and do more than provide a sensing solution by
# providing a controller by providing a web wireless
# connection by providing web connectivity and data insights
# to help plants and buildings become more efficient and become
# more effective, and we will continue to look for
# opportunities like that. As we scanned the industrial
# iot landscape, however, just at the sensing, let alone there,
# is a tremendous amount of opportunity for us to innovate
# and to build a leadership position. Makes like please. And so as we think about a
# sensor portfolio, the industrial team is done a really nice job
# in laying out what does it mean to compete and to differentiate
# in the iot space. As you go from left to right at
# the bottom here on the X axis, you will see what it means in
# terms of industrial sensors becoming smarter and more connected. And on the Y axis. We are the team is defined what
# is table stakes to compete versus what helps us become
# differentiated in the marketplace. So suffice to say
# that the ability to be flexible from a manufacturing standpoint,
# the ability to provide analog and Digital Outputs and the
# ability to provide a low-cost. And very efficient wireless
# interface are quickly becoming table stakes in the industry.
# However, we have an opportunity to innovate by becoming smarter
# in the sensing offerings, whether it's bringing in
# multiple sense sensory inputs, whether it's doing more
# analytics on the edge, whether it's doing more diagnosis to
# allow the systems in the solutions to become smarter and
# more effective, those are the opportunities in front of us,
# and so we're really excited about building this portfolio out. And not one team or laser
# focus. Now on looking at both organic as well as Emily options
# to help build up this portfolio. Next slide, please. The final piece here that
# I'll talk about is this notion of opening up a
# system integrator channel. As the team's done, the work in
# understanding the opportunity that lies in front of us in industrial iot. One of our key
# revelations has been that almost 60% of the market actually goes
# through a system integrator. And the reason is simply this. Volume equipment providers cannot solve. A very discrete
# problem that a building or a plant has that requires
# connecting multiple pieces of equipment together. Disparate
# systems and bringing all of that together into one seamless
# solution and the role of the system integrator becomes really
# critical in working closely with the end customer. Understanding
# the problem statement and then designing, installing,
# commissioning and maintaining a solution that solves the problem
# and continues to evolve as a customer needs. Cool. And so we believe that the role
# of the SI is absolutely critical in. Designing and delivering and
# deriving value from an iot solution. And as we think about
# serving that that SI Channel. Uh, the there is no one size
# fits all system integrators. But the big tier one Tier 2
# system integrators like some of the names mentioned here. We
# have the digital system integrators that we need to
# build relationships with and then there is a whole world or
# small to medium size enterprises that really formed the bulk of
# the SI base and so will be looking for different strategies
# including going director. Some of these system integrators
# versus serving others through distribution. So a very very
# exciting time ahead of us across the sensing solutions business
# is a lot of innovation. A lot of new new that we will
# be working on and I look forward to working on these
# growth strategies along with my team and on sharing updates
# with the broader. Since our community as we make progress.
# Thank you and I'm going to turn it over to Paul. Thank you, we need a good
# morning. Good afternoon, good evening teams. This is Paul. I
# apologize, I'm not on video but I I'm in an area where my Wi-Fi
# reception is not brilliant. So I want to take you through the
# journey. We started with GPT in GSM, but even more so the
# journey we are embarking in supporting company
# diversification strategies all but also out of diversification
# strategies. Going forward and they said as I would like to
# thank as well very much the. Automotive teams who these
# unprecedented times where short-term and crisis management
# was the agenda of the day, has been doing some very creative
# thinking in helping. This this, this thought process
# or diversification going beyond some of our traditional sensing
# solutions and looking at moving into neighboring environments or
# more insight. Smarter sensors and software and systems. On the next page, please. I have a little time lag on the
# click that so we've been on a journey as we split GPT in GSM.
# In trying to enhance our traditional call GSM growth back
# to the levels of where GPT has been in the last five years and
# a lot of those things are now back on track and we're having a
# great track record on with electrification, especially this year. But the. The focus of our strategic
# intent with the leadership team was looking beyond and trying to
# find new Sam's where to expand the altar in order for it to
# stay relevant. Obviously Covid has left very dramatic impact
# like in all other industries, but potentially out industry is
# being hit a little harder, but we are seeing as the OEMs and
# our customers and governments comeback stimulus and incentives
# that are going to accelerate. Probably the biggest mega trend
# of all that is electrification and. For those of you might
# be reading yesterday, you probably saw that
# announcement in Europe where 1 trillion is going to be
# invested by 2050 to drive 0 carbon emission across all
# industries and not just Automotive. We are seeing
# increased penetration, Indiana in connectivity and a
# little slowdown on the autonomous and write sharing. Driving forces GPT is on a good
# journey. Doing still conserving share winning selectively. Try to enhance our margins and
# will be doing more of the same. Going forward. GSM has had a
# good star a tremendous year after now on winning,
# electrification and needs to keep doubling down and the
# opportunities that have been bubbling up in the stint.
# Discussions have been around connected, outdoors, passenger
# cars, connected tires connected. LCD fleets. On the electrification side, we
# have to keep going and enhancing our portfolio with smarter
# contactors, faster contactors with like power of users,
# smarter E position sensors, and maybe expanding our same with
# expanded integrate expanded valves to on the thermal
# management site. This is where our sensor is applied on
# actuator valve and the idea of combining these two together could increased. $80.00 per
# cassettes going forward. On the connectivity side,
# digitalization is obviously the big theme at all our
# customers. It is driving you profit pools. Cars are
# becoming more and more a body in white, put on a battery and
# a mega computer. So there's lots of applications and. Insights that that could
# drive value for our customers and for us going forward. So
# focusing on a passenger car connected passenger car when
# I connected. Tell CBS corrected tires could drive
# profitable revenue models for us going forward. We will
# have to pursue some more portfolio management's hand
# said we will. Also be looking at new ways of
# working the word partnership or we have our DNA is being very
# strong on executing ourselves with vertical integration. But
# in this new arena, horizontal collaboration is going to be a
# buzzword with partnerships, joint development agreements,
# maybe jayvees. In some cases we will be sharing the pain of
# investments, but also some of the gains potentially going forward. Within this landscape
# out or could grow up to 12% by 2025 and 6% going forward
# pending the choices that we will make in line with the corporate strategies. The next
# page please. As you can see, the uh, our
# traditional Sam's are slowing down by 2030. This is no news
# on GPT, but the GSM ones as well are achieving that too. Um, so a lot of focus is being
# put to try and look at new science that are actually now
# tripling. We're getting to 23 billion portfolio of areas we
# could be playing in. Uh, GSM obviously being the big
# driver aftermarket needs a booster beyond what we do in
# TPMS, and there's opportunity there, and so is the total. If
# we also added at Ada's or potential playing radar in
# autonomy for outlook, there's a healthy portfolio from which to
# choose going forward. Next page, please. And when we look at the
# potential revenue choices and portfolios, we can play in as we
# start in 2020, unfortunately gone backwards where 1.5 billion
# dollar business due to Covid. But we have a path forward to
# get back to sustainable growth. Oh, and as you see in these uh
# coloured buckets we are moving away from a little bit. Some of
# our traditional outdoor legacy that's very driven around powertrain and. Um engine
# applications exhaust applications now? Not so much
# because we're getting out of them, but more because we are
# growing in other areas and as you see, the we're trying to
# grow in areas where you have out girls like that's driven by
# electrification that gets up to 24% potential of the portfolio
# by 2030. And then counter cyclical business models that
# are in the aftermarket or in the connected world where we could
# actually even be playing in sass models going forward. Next page. And in line with the same
# slides, you've seen a corporate an in sensing solutions. We have
# to focus and markets we can try and grow in clearly
# electrification and connected connected passenger cars in fleets. It is by Manageing
# actively our portfolio and resources, making choices and
# focusing and operating mode could be with partnership,
# enhanced partnerships, maybe some jobs to be seen by building
# or continuously building a diverse talent pool and and. Probably around the organization. Um, allocating
# capital, whether it's a investment on equipment or
# Manet appropriately in these focus areas and obviously
# driving commercial excellence with all our
# customers. But we will also be watching out. I'll share
# a slide at the end where our customer portfolio is
# changing some of our traditional customers might
# not be the ones we're dealing with in the future,
# so creating new relationships is really
# going to be key. Next page. And. We took all the initiatives
# that have been coming out of all the different marketing and
# front end teams and even ventures and try to rate them
# against the corporate strategy. Care abouts that clearly are
# driving improve shareholder return, diversifying in markets
# where they could be broader sense outta synergies. An
# obviously what's the kind of effort or investment we have to
# put in to get to that revenue. And you can see that on the top
# three lines that's really around safety. It is. These are all
# good areas for out, or there's a little less energy in some of
# the other businesses and we will carry on doing these with.
# Funded in Ari from customers, as the team has been successful up to now. But the the winners or
# potential winners in this selection, other ones in the
# yellow boxes where integrated expansion valves with P plus the
# sensors, is a plane electrification aftermarket
# could help us diversify. Then going beyond what we do in TPMS
# collective tires and TMS with models would be something that
# leads one of the big corporate themes and the same for
# connected out of on the LCD side. We are keeping his option
# tickets radar trying to find whether we have. Uh, and entitlement to play, and
# whether there's Duff Differentiation in the outer
# world. Also to be able to do do something in this arena. On the next page. This visualizes it's a busy
# slide. A lot of logos, but it does talk to a little bit what's
# happening in our industry and it is intensifying day after day.
# We see customers tying up with each other or on sharing
# technology and platforms. Uh, we see in the middle box
# technology players tying up either with our customers or
# between themselves and on the bottom line we see merges and
# we'll probably see more of those for sharing platform but also
# creating scale and enhance profitability. And when you look
# at the right side of the box since other could be playing in
# some of these similar arenas in China may be looking at
# partnerships with psych. Uh, to that could enhance us
# in, um, in GSM edas and TMS applications. On the
# software side, in the middle box and technology we have a JDA
# sign with NYRA where we're collaborating on I tread
# software development for treadwear. That, combined with a
# sensor, gives a much higher accuracy in defining treadwear. This could lead to use as models
# and other applications cross industry. And we have our our,
# our traditional customers like Continental Denzel Ware,
# specially post covid. There's opportunities for looking at
# combining or taking over some of their capacity. You know
# win win situation because maybe it's not called for them
# anymore going forward. The index page I think
# that was the last one. Yeah, that was the last
# page. Thank you. And with George. All right, thanks Paulo, great job. Hi everyone, I'm George
# Ferris. I lead up R Us inside Adventures team and uh, I'm
# really excited to have the opportunity today to talk to the
# broader team about all the exciting things that are
# happening in ventures and across the company in our
# electrification and Smart and connected initiatives. So we
# can go to the next slide. First, let's talk about some
# side adventures, so I get the question a lot. What is ventures
# Simply put inside adventures is an incubation engine for the company. And our goal is to take
# many ideas and really narrow them down and then scale them
# into a few successful new businesses within syncada that
# delivered differentiated value. And it's important that you
# know, we think about this as a transformation process in a
# pipeline. It's really taking many ideas, scaling a few of
# them, transforming them, and turning him into businesses that
# can achieve a scale of 300 million or greater in revenue
# within within a few years. And we do this by really deeply
# understanding the markets and the ecosystems that our teams
# are working in and focusing on driving solutions with with our customers. The key to being
# successful is taking a fast agile approach to launching
# these new ventures. It's really about having an independent and
# empowered team enabling them to drive for results, and then
# continually learning and adapting our approach. That's
# our mission in inside Avengers, so if we go to the next page. You can see here listed the
# three incubation projects that we currently have, an
# electrification, smart and connected, and autonomy. We're
# working with battery management systems under electrification.
# One of the key things that we've done there is required to come. We called our made an investment
# in a company called Lithium balance and we will become the
# majority owners in 2021 and that's really kicked off our
# ability to deliver a BMS system into the Greater electrification ecosystem. We have an internal
# organic development in the wireless hub for smart and
# connected focusing. Initially on heavy vehicle fleets and then in
# autonomy. You can see we've made a recent acquisition with Rico
# and we're continuing to expand in radar by looking at bringing
# digital radar digital imaging technology into Syncada and then
# underneath each one of the three major megatrends you can see
# some of the different pipeline activity that we have going on
# in order to keep a healthy flow of opportunities. Coming into
# Syncada and then at the bottom you can see at the bottom of the
# page those are the tenants of how we try to strive to work
# with inside adventures about risk, reach, reward, empower
# ship speed and agility and then being a learning and adapting
# organization. So with that we can move to the next slide. We're going to talk about our electrification initiative. So
# this electrification megatrend is critically important to our company's future. When we think
# about the mega trends affecting our end markets, electrification
# is one of the biggest ones. It's affecting all of our markets,
# it's reshaping them as we as we speak. The good news is that
# with our current product, so we have a very large market. You
# can see there are 26 billion dollars that our products and
# our teams work in, and it's a really big and exciting space
# for us inside, and one that I think we all believe in strongly
# and know that we can be successful in. And then when you
# look at the new projects that we're launching, we have the
# potential to intercept intercept an additional 20 billion dollar
# Sam by 2030. So as, as everybody's been saying, You
# know we're not opportunity limited, it's really about
# focusing and trying to understand what should we work
# on. So our strategy today is investing to be leaders and
# contactors. We want to continue that leadership. We want to
# continue to invest in BMS in Hu are an industrial. And and even going up further in
# the in the system and doing PD use for HBO are and we want to
# continue to look at. Do we have a potential of doing BMX in
# auto? Is that a place that we want to play in? So that's
# something that we're looking at? And then, as you can see there
# on the third bullet, we want to continue to partner and
# organically develop current sensing solutions. An insulation
# monitoring that could really help our broader portfolio in
# the HBO are and industrial businesses. Um? At the end of the day, it's all
# about focus as we've talked about and we really want to
# focus in the electrification space, the high value
# applications we want to make sure we fill in the gaps that we
# have in our portfolio. But more importantly, we really want to
# look at how can we expand and go up that hardware and or software
# stack that will really drive differentiation at the subsystem
# level and then also drive differentiated value for us. And
# you can see below. I won't read through all the different things that were. We're working on
# and we have the ability to do this organically, but we also
# see a lot of potential for M&A in this space to really
# accelerate what we're doing. So if we go to the next slide. I really like this slide because
# it shows the whole ecosystem of what's happening around up
# around electrification, and you can see that the impact of clean
# energy that shift is a big opportunity for Syncada, and you
# can see over on the on the right side, you know we have a path of
# being over 1 billion dollars and Justin are electrification
# portfolio by 2030, and you can see that it's driving
# opportunities across charging EV storage. I mean, you can see the list there. On the page an. You know what's really exciting
# is if you look at the bottom of the page there you can see how
# broad a portfolio we already have in this space with all the
# products that are listed there. Uhm, but there are absolutely
# great opportunities for us moving forward. I want to share
# one example of something that we're doing adventures. We're
# working with a company called peak power that develops
# building energy storage systems and building management system
# software and they deploy sensors to build that iot system and
# enable their solution, and they improve building efficiency to
# save the buildings money and also store energy off peak. To be able to support peak
# demand when that occurs, saving the owners and the of the
# buildings, you know a considerable amount of money.
# It's a great opportunity for us. It fits in well with what we do
# when we look at both the sensor layer and also what we're trying
# to do around VMS and storage solutions. Solutions with our
# lithium balance products and the ability to take those solutions
# from Europe and enter the North American market to really
# exciting opportunity for us and. You know one that I know,
# nicotine bar are really excited about the closing on. So if we go to the next slide. Here I'll talk a little bit
# about our smart and connected initiative. We have a really
# exciting opportunity on the heavy commercial vehicle fleet
# side, and it's happening now. It's a big market 7 billion
# dollar market. The across that whole iot stack and we have some
# really strong engagement with people like Dasque Swift, Pepsi
# and FedEx, just to name a few. Some of those companies you may
# know, some definitely know and. You know we have some really
# important choices to make on how we can expand this. Uh, this.
# This initiative we're doing very well right now, and we're
# focused on the heavy vehicle fleet. But we really see that. As our OEMs sales cycle has
# slowed down due to Covid and push out some things like that
# were really reprioritizing fleet retrofits and going after those
# big fleets an we're really trying to expand the scope of
# ...
# means is that we're lining the best we can. The supply chain
# with the customer base in those regions. And obviously that's
# good for customers. It's also good to reduce overall risk for
# us as an organization, but the punch line is, it is such a
# large market that it just can't be ignored and we're constantly
# balancing where our investments are to make sure that we optimize. The outcome
# for us as a company. Maybe I add a few words on that,
# so from a growth perspective I think, uhm, we have started to
# look at China differently over the last few years.
# Historically, China was largely copying ideas and technologies
# from the so called Western world, whereas now real
# innovation is happening in China. So I think we need to
# look at China is not just a manufacturing center. Uh, but it
# also has an innovation hub. Uhm, so we need to devote more resources. Business development
# resources. Emanet resources and so on. Uh, in China to really,
# uh, you know, capture the opportunities that is created
# through this knew very innovative companies that are
# popping up in China and we can therefore take those
# technologies in those ideas and spam them. Sort of back to the
# so called Western world. So I think that's a big change and I
# think we need to accelerate that that initiative. You know, Hans.
# This is one eight if I can just add to that, I think we are
# already seeing China lead the world as it comes to a
# acceleration of electric vehicles. We have already seen a
# big part of the bus fleet in China. Electrify. And now that
# technology is coming to the other parts of the world. I today talked about industrial
# iot and when we think about industry 4.0 or iot within factories. 8 or 10 pilots are
# today happening in China, and so it's very clear to us that in
# order for us to be meaningful in industrial iot, we will have to
# be a major player in the China market. Whether it's with local
# manufacturers or with global manufacturers, global companies
# manufacturing in China, and so the importance of China as we
# look ahead continues to be more and more strategic and. It is less about using China
# as a manufacturing base as Han said, it's more about making
# sure that we are innovating in China to serve the needs of
# the local market. Perfect thank you. All next
# question comes from an AM and a strategy. So in the last few
# years we bought several businesses which have not met
# the true financial, operational quality. Intent of Syncada. Are
# we putting more intention to the finer details for future
# purchases and if yes, what will be the change and maybe I'll ask
# cons to address that. Sure. Uh, well, first I, I guess
# I I will say that I think we have delivered largely on the
# premises of the acquisition we have bought in the past, so I think. Looking in the River
# mirrored, I think we should be reasonably content with what we
# have achieved. There are areas where we didn't achieve our
# goals, but there are also areas where we have sort of leverage.
# Sort of. Takes shredder for example, although the TPMS
# market is now maturing, we have really leverage the capabilities
# we bought from Schroeder into this morning connected
# initiative right on this morning, connected initiative
# would not be where it is today unless we have bought shredder
# right? So I think we should. Not be too pessimistic about our
# our past acquisition. Uhm, Having said that, I think that
# changes that we have talked about, you know at the Stanton
# elsewhere is really that we need to become more of a so called
# Cheryl acquire, which means that we will focusing on buying sort
# of bite size companies and do them a little bit more often. So
# it's part of the sort of the business cadence of Syncada. Is that every year we buy sort
# of 234A smaller companies. And, uh, so that sort of, I think, a
# shift that we are trying to implement. An, uh back to the
# earlier conversation, we're trying to focus those
# investments in these high growth areas as we discussed, a lot has
# been focusing on the industrial business segment as we need
# pointed out where there is a lot of opportunities to buy an
# expand into these areas. So, so we will continue to, uh,
# to be aggressively pursuing emanet opportunities. We will of
# course be as diligent as we possibly can, and, for example,
# in Bonita area, as you may know, we're building up more of a
# integration capability inside sensing solution to be able to. No, not only develop plans for
# these business, but also when we have them on board that we can
# integrate and capture the value creation that they that they can give us. So, so that I guess
# is in a high level how we're looking at this emanate
# strategy going forward. Thanks sons, Alright next
# session is for a pool so a Poly. Could you elaborate some more on
# the relocation of resources you announced that are needed? Maybe
# a bit more on what and when. Yeah, sure, so this is not you.
# We've been doing this now for a couple of years. A relegating
# resources from GPT to GSM from some of the chassis teams too
# smart and connected as per needs, and this is a trend that
# will carry on as certain business or segments will still
# keep our share and maintain what we have but will not need a lot
# of R&D effort. Those teams and. Uh, in various campuses will
# will pivot as per need to other applications within the business
# or also across business. There quite a few outer players team
# team members who have also moved to sensing solutions and HBO
# are, so this is a trend, will carry on and there's no fix
# timing on it. Obviously the covid downtown has put some
# constraints on some of our capability. Do everything we want but. Um markets are
# coming back and we have. We have some good growth
# potential in front of us. Electrification being the
# biggest one in this moment where we need more resources,
# so will carry on this journey and it is not in one place
# specifically. It really is something we're doing across
# all campuses around the world. Great thanks Paul. Alright, Uh
# next question and I know that it's on everyone's mind really
# is around our people. And how do we plan on building a strong
# workforce during these difficult times? So maybe I'll ask. Um,
# maybe I'll ask Jeff to kind of kick that one-off and anyone
# else who would like to join. Sure, so it's difficult in a
# time where things are so hard and we have a dislocation
# associated with the overall market demand in our cost
# structure to build this, but we're working very hard at it. I
# think it starts with open this collaboration, high levels of
# communication, transparency, and so I think that as we've
# embarked on this, and as we've tried to increase the level of
# communication, even though we've had to make very hard decisions. Regarding our employee based
# involving folks in that process, I think goes along way too. Creating that level of
# engagement that we're looking for with our employee base
# obviously would much rather be in a position where the markets
# were serving are growing and we can continue to hire great
# talent, invest more in our people as opposed to these
# constrained environments that were in. But but we're going to
# deal with it the best we possibly can, and being open and
# candid with employees I think is the best way to do that now.
# We're also making sure that we do continue invest in training. There's been a significant
# amount of online training that has been rolled out and a lot
# of people in this environment that we're living in have taken
# advantage of that swim. Very excited about that fact. We've,
# as I mentioned, increase the level of communication not only
# with our leadership team, but more broadly, and I'm very
# pleased with the progress that we're making on that. And we're
# going to continue to listen to all of you in terms of what we
# can do better to continue to increase that overall level of
# engagement. An investment in the workforce. Great thank you Jeff. Alright we
# have a little bit under 7 minutes left so there's a lot of
# questions around iot, Annonce, Asmodel, Vinny. Maybe I can just
# ask you to kind of UM address address some of these questions
# quickly. I know we have a couple of questions on where industrial
# iot fits, whether it's industrial in sensing solutions.
# What are the some of the the investments, the different
# investments needed both from an infrastructure partnering
# through Amazon and people? A lot, but I'm I know you're up
# to the task, so, uh. I won't answer any of these
# questions, uh, specifically, but let me provide a little bit of
# context that hopefully helps. The number of people who ask
# these questions you know, get sort of a satisfactory answer.
# First of all, I did say that our starting point is going to be
# sensors. However, we are going to look for opportunities to
# play further up the stack in a much more fulsome way, and to
# the extent that requires us to develop software as a service or
# equipment is a service type models, we will definitely take
# a look at that. Really love the work that
# Andrew, 40 and team are doing within smart and connected in
# fleets around. Really innovating and pioneering that person.
# Sarah and I think we'll be fast followers. Their learning from
# them and and building on their knowledge. And there is also a
# notion of what we use. Our solutions in our own plants.
# The notion of, you know, will we eat their own food? You know,
# when the dog is redrawn dog food to speak, and, uh? The answer to that is yes.
# However, we need to be very thoughtful around how we develop
# solutions that that can scale across flat. So we're very, very
# early right now. My sense is that will probably use, you
# know, in a limited fashion similar size to test in pilot.
# Some of the solutions we think that we want to bring to market.
# It may start with taking some of the interesting solutions we
# have at C3 offering that to some of our plan leaders and saying, hey? Do you see value in
# deploying a solution like this and learning from that? But a
# lot more has to be done before we're able to build, bring
# solutions of scale to any plans, including our own. OK,
# the question of where will the industrial will be iot
# initiative set? It is part of our industrial Business Today,
# Anne. Frankly, it is part of their transformation as they
# look to become a high growth in a sustainable high growth
# business within our portfolio. So hopefully I addressed all
# those questions to a certain degree. Uh, across across the various
# questions that were answered. Thanks for being really
# appreciate it. We have a couple of questions and and I'll ask on
# to take those. So what changes do we see in our business that
# have led us to change our five year cagar forecast from 9% in
# 2019 to 14% in 2020? And then maybe I'll just add on another
# question that we have so if we do get to the Five and five, do we have any? What would this
# mean for Syncada's stock price? So, uh, I think that the main
# difference from last year to this year is really covid right?
# And the impact that code it has on our business in the near term. Uh, I think many of the,
# uh, the strategic plans that we have all put together reflect
# sort of a lower starting points, but we do see the growth
# opportunity is largely that we saw in the past. In the past
# year or two is still intact. We have then identified additional
# growth areas like the one that we need just talked about in
# industrial iot, right? And sharpen our focus in terms of
# what would that mean for the company and. And we believe that
# those growth opportunities that those new growth opportunities
# will will increase the growth of the company. We also now know
# more about sort of the venture activities right around
# electrification and Smart and connected. And we see those
# actually now starting to really become real businesses and will
# have a material impact on our our growth going forward. I would say last, uh, we are
# going to look at. As I said earlier, being a little bit more
# aggressive when it comes to smaller bite size acquisitions.
# So in order to achieve the Five and five and this higher growth
# rate, there is a slightly higher reliance on acquisitions and
# what that will not just do for our revenue, but more
# importantly what new capabilities we can bring into the company. So, so that's why
# we still believe that we can achieve filed in in five years. I forgot the last the second
# question, sorry. Can you remind me please? Sure it's about the
# stock price in 2025 we accomplished our targets. I don't want to
# speculate in our. But, uh, you know, because the
# stock market is is up and down. As you know and and a lot of
# things can change in five years, right? I think we should,
# focusing on growing our business and create a really strong and
# and high growth business. And if we do that, the stock price will
# take care of itself. So let's focus not on the stock price.
# Let focusing on building a really good business. Alright, thank you so much Hun.
# So we have one minute left. Wanna make sure everyone gets
# out on time. Uhm I will take the last question on people and
# you know what sort of investments are are necessary
# as we pivot in evolve our strategy. Obviously people are
# the significant part of that strategy and the key pillar. So
# what will we be doing to invest in our people as our products
# in our solutions evolve? Maybe I'll ask cons to start
# that, and an maybe Jeff or Vanita pool. It can jump in as well. Sure, yeah. It's as I
# mentioned in my in my earlier talk here, people is really the
# the critical resources we have of course, and we have to make
# sure that we invest in our people but also involves sort of
# the capabilities that is needed to be successful here. Going
# forward with all the changes that we have laid out in this
# presentation and elsewhere with new customer segments that we
# need to serve. We also need to evolve and build new skills,
# right? So it's. It's a very, very important um
# attribute to our strategy, of course, and we will continue to
# invest in our people. We're trying to make the processes
# more efficient effective so we can get our work done more
# efficiently and effectively. An we need to build new scales to
# address the both opportunities and some of the threats that we
# have laid out in the presentation. So more to come.
# And as Jeff said, it's hard to. Make all those investments in
# the near term because of the impact of covert that we're
# doing our very best and we will continue to be very open
# and transparent with our plans going forward. The only thing I would add
# this has been eight is when you you heard about the
# growth plans today. Going from 3 billion or so to 5
# billion is gonna be a tremendous amount of growth,
# and growth creates a lot of opportunity, but ultimately we
# all own our own couriers, right? And so I would encourage
# everybody to to understand the growth plans, seek out those
# new opportunities that will come as a result of that
# growth, and really ask how can you make an impact to help the
# company achieve those growth objectives. So there's a ton of
# opportunity. In in an earlier answer here,
# we highlighted there's a lot of training being rolled out
# and being made available. Raise your hand, volunteer
# for the opportunity. Ask how you can help. Ask how you can
# have an impact and get the right training in order to be
# ready for that role, because this is going to be a really
# exciting journey an we really need everybody to lean in and
# help us achieve that growth. Alright, so I can't think of a
# better comment to close on. I want to thank everyone on the
# panel. I wanna think Jeff, I want to thank all of you for
# attending. I really encourage you to attend our next quarterly
# town Hall on Aug 6th. I know you have a lot of questions and he
# submitted a ton of questions around. You know people that
# have taken a number of voluntary and involuntary actions will
# talk about all that on our next quarterly townhall. Obviously
# today was really focused on stint. Uhm, I want to thank
# everyone for participating and thank you for working so hard for Team Syncada. Please
# continue to stay safe and serve our customers and be
# well. Have a great day everyone.

# %% [markdown]
# # pyquery
# pyquery allows you to make jquery queries on xml documents. The API is as much as possible the similar to jquery. pyquery uses lxml for fast xml and html manipulation.
#
# https://pythonhosted.org/pyquery/
#
# https://pythonhosted.org/pyquery/api.html

# %%
#!pip install -U pyquery
# !pip freeze | grep pyquery
# Out:
# pyquery==1.4.0

# %%
from pyquery import PyQuery as pq

# %% [markdown]
# # pyquery操作html dom tree

# %% [markdown]
# ## 使用pyquery生成html
# 可以生成，但是不太优雅。。。

# %%
html = """
<html ng-controller="JumperController" ng-strict-di="" class="ng-scope" ng-app="jumper" dir="ltr" lang="en">

    
<body dir="ltr" class="theme-for-videopage -mouse -should -not -have -outline">
    <!-- ngIf: loadPage --><div ng-if="loadPage" class="ng-scope" style="">
        <top-nav class="ng-isolate-scope"><topbar class="ng-isolate-scope"><!-- ngIf: $ctrl.shouldShowTopbar --><div class="c-bapi-header topbar topbar-v2 f-authenticated ng-scope" ng-if="$ctrl.shouldShowTopbar"> <header class="stream-office-top-nav" id="stream-office-top-nav"> <div id="O365_NavHeader" class="_48b3a6747e9ecbeb6809a478a379f572.scss o365cs-base o365sx-navbar o365sx-search" role="banner" style="height: 48px; line-height: 48px;"><div id="O365_HeaderLeftRegion" class="_23a17bfeb92ba0b654edfc6cab03ed3a.scss"><div class="_39d41f3de648b4f3498e1a38d97fe686.scss"><button id="O365_MainLink_NavMenu" class="_0299ff19e67bde1ea0ef4995f53311be.scss o365sx-button o365sx-waffle" aria-haspopup="true" aria-expanded="false" type="button" role="button" aria-label="App launcher" title="App launcher"><span class="ms-Icon--WaffleOffice365 ms-icon-font-size-16" style="display: inline-block; font-size: 16px;" role="presentation"></span></button></div></div><div id="CenterRegion" class="_907346bfcf1b63cbf1f8121fb205a803.scss" style="width: calc(100% - 96px);"><div style="width: 100%;"><div style="display: block; position: relative;"><div style="" data-automation-id="visibleContent"><div id="topLevelRegion" class="c1b953e95a09350215e599ea5f933e20.scss"><div id="leftRegion" class="c1b953e95a09350215e599ea5f933e20.scss" style="justify-content: flex-start;"><div id="O365_MainLink_TenantLogo_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"><div class="_2d0fa5f18ae6de3c95eac48b6eb50909.scss o365sx-primary-font"><a id="O365_MainLink_TenantLogo" class="fd3e30cd539c12fb6e85a2c7f74d46bb.scss" title="PROD - sensata.com Azure AD (sso.sensata.com) (Not O365)" aria-label="PROD - sensata.com Azure AD (sso.sensata.com) (Not O365)" href="https://www.office.com/?auth=2&amp;home=1&amp;username=amber-yan%40sensata.com&amp;from=ShellLogo"><img id="O365_MainLink_TenantLogoImg" alt="PROD - sensata.com Azure AD (sso.sensata.com) (Not O365)" title="PROD - sensata.com Azure AD (sso.sensata.com) (Not O365)" src="data:image/png;base64,..."></a></div><div class="b3a3fdb167dc849c79df08c917363fc9.scss o365sx-appName"></div></div><div id="O365_SuiteBranding_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"><div class="_314d83894b3882400fc35fc859c3ff16.scss o365sx-appName"><a href="https://web.microsoftstream.com" role="link" id="O365_AppName" aria-label="Go to Stream"><span class="ab38a845419f0ef0715ce595ac49a106.scss">Stream</span></a></div></div></div><div id="centerRegion" class="c1b953e95a09350215e599ea5f933e20.scss" style="flex: 1 0 auto; justify-content: center;"><div style="display: flex; flex: 1 0 auto;"><div id="O365_SearchBoxContainer_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss" style="flex: 1 0 auto; justify-content: center;"><div style="width: 100%;"></div></div></div></div><div id="HeaderButtonRegion" class="c1b953e95a09350215e599ea5f933e20.scss" style="justify-content: flex-end;"><div id="O365_Feature_Flags_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"></div><div id="O365_MainLink_Day_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"></div><div id="O365_MainLink_Chat_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"></div><div id="O365_MainLink_Bell_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"><div class="ac25fed02f3f4133f1f21a7d9e3ca7f2.scss"><button class="_0299ff19e67bde1ea0ef4995f53311be.scss o365sx-button" id="O365_MainLink_Bell" aria-haspopup="true" aria-label="Notifications" role="button" type="button" title="Notifications" aria-expanded="false"><div class="o365cs-base" aria-hidden="true"><span class="ms-Icon--Ringer" style="display: inline-block; font-size: 16px;" role="presentation"></span></div></button></div></div><div id="O365_MainLink_Settings_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"><div class="ac25fed02f3f4133f1f21a7d9e3ca7f2.scss"><button class="_0299ff19e67bde1ea0ef4995f53311be.scss o365sx-button" id="O365_MainLink_Settings" aria-haspopup="true" aria-label="Settings" role="button" type="button" title="Settings" aria-expanded="false"><div class="o365cs-base" aria-hidden="true"><span class="ms-Icon--Settings" style="display: inline-block; font-size: 16px;" role="presentation"></span></div></button></div></div><div id="O365_MainLink_Help_container" class="dc7ed9a5e04b6acb575f721fa13b8c10.scss"><div class="ac25fed02f3f4133f1f21a7d9e3ca7f2.scss"><button class="_0299ff19e67bde1ea0ef4995f53311be.scss o365sx-button" id="O365_MainLink_Help" aria-haspopup="true" aria-label="Help" role="button" type="button" title="Help" aria-expanded="false"><div class="o365cs-base" aria-hidden="true"><span class="ms-Icon--Help" style="display: inline-block; font-size: 16px;" role="presentation"></span></div></button></div></div></div><div class="dc7ed9a5e04b6acb575f721fa13b8c10.scss abbf934e6755a54ab1e3873ff32905ab.scss"><div></div></div></div></div></div></div></div><div id="O365_HeaderRightRegion" class="f6f6055c0ea8e7d60465984814c03603.scss"><div class="_39d41f3de648b4f3498e1a38d97fe686.scss"><button id="O365_MainLink_Me" class="_0299ff19e67bde1ea0ef4995f53311be.scss _554bec52b64efc8c56ac2eafe5abdee5.scss o365sx-button o365sx-highContrastButton" role="button" aria-haspopup="true" type="button" title="Account manager for Yan, Amber" aria-label="Account manager for Yan, Amber"><div class="_971b1aa64c8487b35e2026e8dc272cef.scss"><div class="c461a030351b633b6e29ec434f4120f7.scss undefined"><span style="display: none;">Yan, Amber</span></div><div class="_0299ff19e67bde1ea0ef4995f53311be.scss f3229ec41b8583dd8dd7687630b709ca.scss"><div id="O365_MainLink_MePhoto" class="_5cd3b7e3330f359c70c3f8080b25a70b.scss"><div><div><div class="_38d7ebc8b9e301ac0fb6c7146c680f3a.scss" style="width: 32px; height: 32px;"><div id="meInitialsButton" style="background-color: rgb(126, 56, 120); font-size: 16px;" class="ebe3b1eb2850b56868257b865001fc57.scss" aria-hidden="true"><span>YA</span></div><div class="b09f993ead477113894c0a380aa56bae.scss"><img style="" src="https://outlook.office.com/owa/service.svc/s/GetPersonaPhoto?email=amber-yan@sensata.com&amp;UA=0&amp;size=HR96x96&amp;sc=1595600012300" alt="YA"></div></div></div></div></div></div></div></button></div><div class="_39d41f3de648b4f3498e1a38d97fe686.scss"><a id="O365_MainLink_Signin" class="_0299ff19e67bde1ea0ef4995f53311be.scss _554bec52b64efc8c56ac2eafe5abdee5.scss o365sx-button o365sx-highContrastButton" role="button" type="button" style="display: none;" aria-label="Sign in"><div class="_971b1aa64c8487b35e2026e8dc272cef.scss"><div class="c461a030351b633b6e29ec434f4120f7.scss undefined"><span style="display: inline;">Sign in</span></div><div class="_0299ff19e67bde1ea0ef4995f53311be.scss f3229ec41b8583dd8dd7687630b709ca.scss"><div id="O365_MainLink_SigninLink" class="_5144c36614176145aadaa132d7d63eeb.scss"><span class="ms-Icon--Contact ms-icon-font-size-18 o365sx-accent-font _29bfbb25c9d5ee5f6f8e79a840f4d4d6.scss" style="display: inline-block; font-size: 18px;" role="presentation"></span></div></div></div></a></div></div><div id="NotificationToastContainer"><div aria-live="polite" role="region" aria-relevant="additions text"></div></div></div><div id="o365cs-flexpane-overlay"></div><div></div></header> <div class="action-bar-container" ng-show="$ctrl.videoEditorInactive" aria-hidden="false"> <div action-list="" class="topbar-container"> <button data-bi-id="topbar-hamburger" class="c-action-trigger c-glyph hamburger topbar-button hide-for-medium" aria-label="Menu" ng-click="$ctrl.mobileMenuClicked($event)" style=""> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_hamburger"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_hamburger" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> <nav role="navigation" class="f-closed mobile-menu ng-hide" ng-attr-aria-hidden="!$ctrl.showMobileMenu" ng-show="$ctrl.showMobileMenu" style=""> <ul class="c-menu"> <li class="c-menu-item"> <a data-bi-id="topbar-home-button-mobile" href="/" class="home-link action-link ng-binding" ng-click="$ctrl.logAndSetFocus($event, '/')"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_home" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_home" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> Home </a> </li> <li data-bi-id="topbar-discover-menu-button-mobile" class="c-menu-item f-sub-menu" ng-keydown="$ctrl.menuKeydown($event, 'discoverMenuExpanded')"> <button class="discover-navigation ms-mobile-sub-menu" id="topbar-discover-navigation-button-mobile" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.discoverMenuExpanded}}" aria-label="Discover menu options" ng-click="$ctrl.expandMenu($event,'discoverMenuExpanded',$ctrl.discoverMenuExpanded)" aria-expanded="false"> <div class="mobile-submenu-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_discover" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_discover" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Discover</span> </div> </button> <!-- ngIf: $ctrl.discoverMenuExpanded --> </li> <li class="c-menu-item f-sub-menu" ng-keydown="$ctrl.menuKeydown($event, 'myContentMenuExpanded')"> <button class="mycontent-navigation ms-mobile-sub-menu" id="topbar-mycontent-navigation-button-mobile" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.myContentMenuExpanded}}" aria-label="My content menu options" ng-click="$ctrl.expandMenu($event, 'myContentMenuExpanded', $ctrl.myContentMenuExpanded)" aria-expanded="false"> <div class="mobile-submenu-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_mycontent" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_mycontent" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">My content</span> </div> </button> <!-- ngIf: $ctrl.myContentMenuExpanded --> </li> <li class="c-menu-item f-sub-menu" ng-keydown="$ctrl.menuKeydown($event, 'createMenuExpanded')"> <button class="create-navigation ms-mobile-sub-menu" id="topbar-create-navigation-button-mobile" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.createMenuExpanded}}" aria-label="Create menu options" ng-click="$ctrl.expandMenu($event,'createMenuExpanded',$ctrl.createMenuExpanded)" aria-expanded="false"> <div class="mobile-submenu-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_create" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_create" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Create</span> </div> </button> <!-- ngIf: $ctrl.createMenuExpanded --> </li> <li class="c-menu-item icon-item hide-for-medium"> <button data-bi-id="topbar-invite-button-mobile" class="action-link ng-binding ms-mobile-sub-menu" aria-label="Invite others" ng-click="$ctrl.inviteClicked($event)"> <div class="mobile-submenu-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_invite_white"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_invite_white" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Invite others</span> </div> </button> </li> <!-- ngIf: $ctrl.isUserFeedbackEnabled() --><li ng-if="$ctrl.isUserFeedbackEnabled()" class="feedback-link c-menu-item icon-item hide-for-medium ng-scope"> <button class="action-link ng-binding ms-mobile-sub-menu mobile-feedback-trigger" aria-label="Send feedback" child-focus-element="smiley-button" ng-click="$ctrl.ocvUifClicked()"> <div class="mobile-submenu-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_feedback"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_feedback" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Send feedback</span> </div> </button> </li><!-- end ngIf: $ctrl.isUserFeedbackEnabled() --> </ul> </nav> <div class="menu-container show-for-medium"> <nav class="desktop-menu" role="navigation"> <ul role="list"> <li class="c-menu-item home-menu-item"> <a data-bi-id="topbar-home-button" href="/" class="home-link ng-binding" ng-class="{'current-menu-name': $ctrl.highlightedTab.home}" ng-click="$ctrl.logAndSetFocus($event, '/')"> <svg-src class="topbar-svg ng-isolate-scope" ng-class="{'current-menu-icon': $ctrl.highlightedTab.home}" svg-name="icon_home" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_home" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> Home </a> </li> <li> <div data-bi-id="topbar-discover-dropdown-menu" class="c-select-menu" ng-keydown="$ctrl.menuKeydown($event, 'discoverMenuExpanded')"> <button class="discover-navigation" id="topbar-discover-navigation-button-desktop" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.discoverMenuExpanded}}" aria-label="Discover menu options" ng-class="{'current-menu-name': $ctrl.highlightedTab.discover}" ng-click="$ctrl.expandMenu($event,'discoverMenuExpanded',$ctrl.discoverMenuExpanded)" aria-expanded="false"> <div class="button-content"> <svg-src class="topbar-svg ng-isolate-scope" ng-class="{'current-menu-icon': $ctrl.highlightedTab.discover}" svg-name="icon_discover" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_discover" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Discover</span> <svg-src class="topbar-svg down-arrow-icon ng-isolate-scope" svg-name="icon_down_arrow" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_down_arrow" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </div> </button> <ul class="c-menu ng-hide" aria-labelledby="topbar-discover-navigation-button-desktop" ng-show="$ctrl.discoverMenuExpanded" role="presentation" aria-hidden="true"> <!-- ngRepeat: option in $ctrl.menuItems.Browse --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.Browse" ng-if="option.enabled"> <a role="link" data-bi-id="topbar-discover-video-link" class="discover-video-link" ng-href="/browse" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="/browse"> Videos </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.Browse --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.Browse" ng-if="option.enabled"> <a role="link" data-bi-id="topbar-discover-channel-link" class="discover-channel-link" ng-href="/browse?view=channel" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="/browse?view=channel"> Channels </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.Browse --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.Browse" ng-if="option.enabled"> <a role="link" data-bi-id="topbar-discover-people-link" class="discover-people-link" ng-href="/browse?view=people" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="/browse?view=people"> People </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.Browse --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.Browse" ng-if="option.enabled"> <a role="link" data-bi-id="topbar-discover-group-link" class="discover-groups-link" ng-href="/browse?view=group" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="/browse?view=group"> Groups </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.Browse --> </ul> </div> </li> <li> <div data-bi-id="topbar-mycontent-dropdown-menu" class="c-select-menu" ng-keydown="$ctrl.menuKeydown($event, 'myContentMenuExpanded')"> <button class="mycontent-navigation" ng-class="{'current-menu-name': $ctrl.highlightedTab.studio}" id="topbar-mycontent-navigation-button-desktop" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.myContentMenuExpanded}}" aria-label="My content menu options" ng-click="$ctrl.expandMenu($event,'myContentMenuExpanded',$ctrl.myContentMenuExpanded)" aria-expanded="false"> <div class="button-content"> <svg-src class="topbar-svg ng-isolate-scope" ng-class="{'current-menu-icon': $ctrl.highlightedTab.studio}" svg-name="icon_mycontent" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_mycontent" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">My content</span> <svg-src class="topbar-svg down-arrow-icon ng-isolate-scope" svg-name="icon_down_arrow" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_down_arrow" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </div> </button> <ul class="c-menu ng-hide" aria-labelledby="topbar-mycontent-navigation-button-desktop" ng-show="$ctrl.myContentMenuExpanded" role="presentation" aria-hidden="true"> <!-- ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-video-link" data-bi-id="topbar-mycontent-videos-link" ng-href="studio/videos" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/videos"> Videos </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-groups-link" data-bi-id="topbar-mycontent-groups-link" ng-href="studio/groups" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/groups"> Groups </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-channel-link" data-bi-id="topbar-mycontent-channels-link" ng-href="studio/channels" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/channels"> Channels </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-meetings-link" data-bi-id="topbar-mycontent-meetings-link" ng-href="studio/meetings" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/meetings"> Meetings </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-watchlist-link" data-bi-id="topbar-mycontent-watchlist-link" ng-href="studio/watchlist" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/watchlist"> Watchlist </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="my-following-channels-link" data-bi-id="topbar-mycontent-following-channels-link" ng-href="studio/followingchannels" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/followingchannels"> Followed channels </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --><!-- ngIf: option.enabled --><li class="c-menu-item ng-scope" ng-repeat="option in $ctrl.menuItems.MyContent" ng-if="option.enabled"> <a class="recycle-bin-link" data-bi-id="topbar-mycontent-recycle-bin-link" ng-href="studio/recyclebin" ng-click="$ctrl.logAndSetFocus($event, option.link.href, true)" href="studio/recyclebin"> Recycle bin </a> </li><!-- end ngIf: option.enabled --><!-- end ngRepeat: option in $ctrl.menuItems.MyContent --> </ul> </div> </li> <li> <div data-bi-id="topbar-create-dropdown-menu" class="c-select-menu" ng-keydown="$ctrl.menuKeydown($event, 'createMenuExpanded')"> <button class="create-navigation" id="create-desktop-navigation" aria-haspopup="true" ng-attr-aria-expanded="{{$ctrl.createMenuExpanded}}" aria-label="Create menu options" ng-click="$ctrl.expandMenu($event,'createMenuExpanded',$ctrl.createMenuExpanded)" aria-expanded="false"> <div class="button-content"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_create" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_create" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="link-label ng-binding">Create</span> <svg-src class="topbar-svg down-arrow-icon ng-isolate-scope" svg-name="icon_down_arrow" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_down_arrow" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </div> </button> <ul class="c-menu ng-hide" aria-labelledby="create-desktop-navigation" ng-show="$ctrl.createMenuExpanded" role="presentation" aria-hidden="true"> <!-- ngIf: $ctrl.isCreateVideoEnabled() --><li class="c-menu-item ng-scope" ng-if="$ctrl.isCreateVideoEnabled()"> <a role="link" id="topbar-create-upload-link" class="upload-link ng-binding" ng-href="/upload" ng-click="$ctrl.logAndSetFocus($event, '/upload')" href="/upload"> Upload video </a> </li><!-- end ngIf: $ctrl.isCreateVideoEnabled() --> <!-- ngIf: $ctrl.isCreateLiveEventEnabled() && $ctrl.CreateLiveEnabled --><li class="c-menu-item ng-scope" ng-if="$ctrl.isCreateLiveEventEnabled() &amp;&amp; $ctrl.CreateLiveEnabled"> <a role="link" data-bi-id="topbar-create-live-link" class="create-live-link ng-binding" ng-href="/create" ng-click="$ctrl.logAndSetFocus($event, '/create')" href="/create"> Live event </a> </li><!-- end ngIf: $ctrl.isCreateLiveEventEnabled() && $ctrl.CreateLiveEnabled --> <!-- ngIf: $ctrl.isCreateGroupEnabled() --><li class="c-menu-item ng-scope" ng-if="$ctrl.isCreateGroupEnabled()"> <a external-link="" role="link" data-bi-id="topbar-create-group-link" class="create-group-link ng-binding" ng-click="$ctrl.createGroupClicked($event)" ng-href="#" href="#"> Group </a> </li><!-- end ngIf: $ctrl.isCreateGroupEnabled() --> <li class="c-menu-item"> <a external-link="" role="link" data-bi-id="topbar-create-channel-link" class="create-channel-link ng-binding" ng-click="$ctrl.createChannelClicked($event)" ng-href="#" href="#"> Channel </a> </li> <!-- ngIf: $ctrl.isRecordVideoEnabled --> <!-- ngIf: $ctrl.isScreenRecorderEnabled --><li class="c-menu-item ng-scope" ng-if="$ctrl.isScreenRecorderEnabled"> <a external-link="" data-bi-id="topbar-create-record-screen-link" role="link" class="screen-capture-link ng-binding" ng-click="$ctrl.recordScreen($event)" ng-href="#" href="#"> Record screen </a> </li><!-- end ngIf: $ctrl.isScreenRecorderEnabled --> </ul> </div> </li> </ul> </nav> </div> <div class="f-search" ng-style="{'width': $ctrl.searchWidth}" style="width: 372px;"> <form data-bi-id="topbar-search-form" role="search" class="c-search topbar-search ng-pristine ng-valid ng-valid-maxlength" ng-submit="$ctrl.submitSearch($event)" aria-label="Topbar search"> <input aria-label="Enter your search" type="search" class="search-input ng-pristine ng-untouched ng-valid ng-empty ng-valid-maxlength" placeholder="Search" ng-model="$ctrl.searchTerm" maxlength="100" autocomplete="off" aria-invalid="false"> <button class="c-glyph topbar-search-button"> <span class="x-screen-reader ng-binding">Search</span> </button> </form> </div> <div class="topbar-right-menu show-for-medium"> <ul role="list"> <li ng-show="$ctrl.totalUploadItemCount" aria-hidden="true" class="ng-hide"> <button class="c-action-trigger action-link topbar-button glyph-upload-progress f-bapi ng-isolate-scope" aria-label="Upload progress" dropdown-overlay-invoke="uploadProgress" disable-animation="true" always-down="true" is-fixed-anchor="false" prefer-left="true" deduct-body-top="true" child-focus-element="bg-upload-item-button" position-under-anchor="true" custom-title="Upload progress"> <!-- ngIf: $ctrl.uploadingCount --> <!-- ngIf: !$ctrl.anyFailed && !$ctrl.uploadingCount --><svg-src class="topbar-svg white-fill green-background upload-complete ng-scope ng-isolate-scope" svg-name="icon_checkmark" ng-if="!$ctrl.anyFailed &amp;&amp; !$ctrl.uploadingCount"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_checkmark" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src><!-- end ngIf: !$ctrl.anyFailed && !$ctrl.uploadingCount --> <!-- ngIf: !$ctrl.uploadingCount && $ctrl.anyFailed -->  </button> </li> <!-- ngIf: $ctrl.isAdminModeToggleVisible() --> <!-- ngIf: $ctrl.isCreateVideoEnabled() --><li ng-if="$ctrl.isCreateVideoEnabled()" class="ng-scope"> <button data-bi-id="topbar-upload-button" class="c-action-trigger action-link topbar-button glyph-upload f-bapi ng-isolate-scope" aria-label="Upload video" ng-click="$ctrl.uploadClicked($event)" custom-title="Upload video" light-style="true"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_upload"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_upload" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </li><!-- end ngIf: $ctrl.isCreateVideoEnabled() --> <li> <button data-bi-id="topbar-invite-button" class="c-action-trigger action-link topbar-button glyph-invite f-bapi ng-isolate-scope" aria-label="Invite others" ng-click="$ctrl.inviteClicked($event)" custom-title="Invite others" light-style="true"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_invite_white"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_invite_white" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </li> <!-- ngIf: $ctrl.isUserFeedbackEnabled() --><li ng-if="$ctrl.isUserFeedbackEnabled()" class="ng-scope"> <button class="c-action-trigger c-glyph glyph-feedback feedback-trigger f-bapi topbar-button ng-isolate-scope" aria-label="Send feedback" child-focus-element="smiley-button" custom-title="Send feedback" light-style="true" ng-click="$ctrl.ocvUifClicked()"> <svg-src class="topbar-svg ng-isolate-scope" svg-name="icon_feedback"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_feedback" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </li><!-- end ngIf: $ctrl.isUserFeedbackEnabled() --> </ul> </div> </div> </div> <!-- ngIf: $ctrl.isNewBannerEnabled && !$ctrl.isReactBannerEnabled --><banner ng-if="$ctrl.isNewBannerEnabled &amp;&amp; !$ctrl.isReactBannerEnabled" ng-show="$ctrl.videoEditorInactive" class="ng-scope ng-isolate-scope" aria-hidden="false"><div class="banner ng-hide" ng-hide="$ctrl.shouldHideBanner" aria-hidden="true"> <div class="banner-content"> <span class="banner-icon"> <!-- ngIf: $ctrl.iconName --> </span> <span class="banner-text-container"> <!-- ngIf: $ctrl.header --> <!-- ngIf: $ctrl.text --> <!-- ngIf: $ctrl.linkUrl && $ctrl.linkLabel --> </span> </div> </div></banner><!-- end ngIf: $ctrl.isNewBannerEnabled && !$ctrl.isReactBannerEnabled --> <!-- ngIf: $ctrl.isReactBannerEnabled --> </div><!-- end ngIf: $ctrl.shouldShowTopbar --> <!-- ngIf: $ctrl.useO365GroupShareableControl --> </topbar> </top-nav>
        <div class="office-scroll-body" role="main">
            <div ng-performance=""><div id="ngPerformanceDisplay"> <style>#ngPerformanceDisplay{display: none;} #perfStats{position: fixed; right: 0; bottom: 15px; z-index: 100000; background-color: rgba(250, 249, 244, 0.97); border: 3px solid #843376; border-right: none; border-radius: 5px 0 0 5px; box-shadow: 0 1px 4px black; padding: 0 15px 15px; font-size: 0.65em;}#perfStats h3{margin-bottom: 0;}#perfStats td:last-child{text-align: right;}</style> <div id="perfStats"> <div id="perfStatsPanel"> <h3>ANGULAR STATS</h3> <table class="table table-condensed"> <tbody> <tr> <td>Total Scopes:</td><td><span id="scopes">491</span></td></tr><tr> <td>Total Watchers:</td><td><span id="watchers">2022</span></td></tr><tr> <td>Dirty Checks:</td><td><span id="dirty-checks">5570</span></td></tr><tr> <td>Digest Cycles:</td><td><span id="digest-cycles">4211</span></td></tr><tr> <td>Digest Cycle (last):</td><td> <span id="digest-ms">5.0</span> ms <br><span id="digest-fps">200</span> FPS </td></tr><tr> <td>Digest Cycle (avg):</td><td> <span id="avg-digest-ms">9.1</span> ms <br><span id="avg-digest-fps">110</span> FPS </td></tr><tr> <td>Digest Cycle (max):</td><td> <span id="max-digest-ms">518.0</span> ms <br><span id="max-digest-fps">2</span> FPS </td></tr></tbody> </table> <h3>PAGELOAD STATS</h3> <table class="table table-condensed"> <tbody> <tr> <td>Head Load:</td><td><span id="head-load">3009.0</span> ms</td></tr><tr> <td>Body Load:</td><td><span id="body-load">0.0</span> ms</td></tr><tr> <td>Footer Load:</td><td><span id="footer-load">0.0</span> ms</td></tr><tr> <td>Vendor Script Load:</td><td><span id="vendor-load">0.0</span> ms</td></tr><tr> <td>App Load:</td><td><span id="app-load">0.0</span> ms</td></tr><tr> <td>Metrics Load:</td><td><span id="metrics-load">0.0</span> ms</td></tr><tr> <td>Time To End-of-Page:</td><td><span id="time-to-eop">0.0</span> ms</td></tr><tr> <td>Time To Angular:</td><td><span id="time-to-ng">11718.0</span> ms</td></tr></tbody> </table> </div></div></div></div>
            <!-- ngViewport:  --><div ng-viewport="" class="ng-scope"><!-- ngIf: Video.videoId --><video-page video-id="Video.videoId" ng-if="Video.videoId" class="ng-scope ng-isolate-scope"><div ng-show="$ctrl.videoEditorInactive" aria-hidden="false" class=""> <!-- ngIf: $ctrl.showMessageBar --> <!-- ngIf: !$ctrl.isLiveGAEnabled && $ctrl.isLiveContent && !$ctrl.isCompleted --> <!-- ngIf: $ctrl.isReadOnlyVideo --> <div class="container video" ng-class="{'admin-elevated-mode':$ctrl.isInAdminMode}"> <div class="main-area"> <section class="player-area" aria-label="Video player section"> <div ng-switch="" on="$ctrl.routingCase"> <div ng-class="!$ctrl.showMetadata?'blank-fill':''" class="" style=""> <!-- ngSwitchWhen: Normal --><div ng-switch-when="Normal" class="ng-scope" style=""> <div class="video-player-container" role="presentation" style="padding-top: 20px;"> <div class="row sub-header"> </div> <div class="row"> <div id="player-wrapper" class="column xsmall-12 medium-8 large-8 small-6 medium-12" ng-class="{'medium-12 large-12': $ctrl.display12Column, 'medium-12': $ctrl.showRightContainer || $ctrl.isCompletedOnLoad}"> <div class="player-content-wrapper169"> <div id="playerContent" class="player-content"> <!-- ngIf: $ctrl.shouldShowEndEventMessage --> <!-- ngIf: $ctrl.video && !$ctrl.shouldShowEndEventMessage --><video-player-view ng-if="$ctrl.video &amp;&amp; !$ctrl.shouldShowEndEventMessage" video="$ctrl.video" video-item="$ctrl.video" video-edit-state-info="$ctrl.videoEditStateInfo" on-viewed="$ctrl.onVideoViewed()" enable-theater-mode="true" toggle-theater-mode="$ctrl.EnableTheaterMode(enable)" is-producer-view="false" on-time-update="$ctrl.onTimeUpdate(currentTime)" on-init="$ctrl.onInit({ seekFunction: seekFunction, getCurrentTime: getCurrentTime, play: play, pause: pause, toggleTheaterMode: toggleTheaterMode })" preload="true" is-in-admin-mode="$ctrl.isInAdminMode" on-video-completed="$ctrl.onVideoCompleted()" is-yammer-available="$ctrl.isYammerAvailable" is-yammer-loaded="$ctrl.isYammerLoaded" yammer-events="$ctrl.yammerEvents" is-completed-on-load="$ctrl.isCompletedOnLoad" on-audience-did-reach-end-of-vodless-playback="$ctrl.onAudienceDidReachEndOfVodlessPlayback()" is-replacing="$ctrl.isReplacing" reload-updated-video="$ctrl.retry()" class="ng-scope ng-isolate-scope"><div class="video-player-view"> <div class="player-content-wrapper"> <div id="playerContent" class="player-content"> <div class="player-inner-content"> <!-- ngIf: $ctrl.isReportIssueOpen --> <!-- ngIf: !$ctrl.isVideoPlayerShown && $ctrl.isContentSourceLiveStream && !$ctrl.isErrorOccured --> <!-- ngIf: $ctrl.isVideoPlayerShown && !$ctrl.showFakePlayButton && !$ctrl.isErrorOccured --><media-player player-options="$ctrl.playerOptions" media-player-id="$ctrl.videoEditStateInfo.mediaPlayerId" ng-if="$ctrl.isVideoPlayerShown &amp;&amp; !$ctrl.showFakePlayButton &amp;&amp; !$ctrl.isErrorOccured" on-viewed="$ctrl.onVideoViewed()" on-deleted-or-replaced="$ctrl.refreshVideoMetadata()" is-live-event-stopped="$ctrl.isLiveEventStopped()" summary-heartbeat="$ctrl.summaryHeartbeat(properties)" playback-summary="$ctrl.playbackSummary(properties)" on-error="$ctrl.onPlayerError(metrics, traceId, isWarning, eventType)" trace-player-logs-and-return-trace-id="$ctrl.tracePlayerLogsAndReturnTraceId(eventName, flushLog, logMediaInternals)" on-player-retry="$ctrl.onPlayerRetry(retryCount, metrics, traceId, isWarning, eventType, enableTelemetry, manualRetry, errorCode, reason)" on-play="$ctrl.onPlayEvent()" on-canplaythrough="$ctrl.onCanplaythrough()" on-init="$ctrl.onInit({ seekFunction: seekFunction, getCurrentTime: getCurrentTime, play: play, pause: pause, toggleTheaterMode: toggleTheaterMode })" on-time-update="$ctrl.onTimeUpdateEvent(currentTime)" preload="$ctrl.preload" enable-theater-mode="$ctrl.enableTheaterMode" enter-theater-mode="$ctrl.toggleTheaterMode({enable: true})" exit-theater-mode="$ctrl.toggleTheaterMode({enable: false})" on-user-active="$ctrl.onUserActive()" player-events-tracker="$ctrl.playerEventsTracker()" on-user-inactive="$ctrl.onUserInactive()" on-pause="$ctrl.onPause()" enable-search="$ctrl.enableSearch" on-search="$ctrl.onSearch()" on-player-ended="$ctrl.changeVideoStateToCompleted()" default-muted="$ctrl.defaultMuted" video-link="$ctrl.videoLink" on-sdn-init-success="$ctrl.onSdnInitSuccess(details)" on-sdn-init-failure="$ctrl.onSdnInitFailure(details)" on-sdn-fatal-error="$ctrl.onSdnFatalError(details)" on-report-issue="$ctrl.onReportIssue()" on-last-amp-error-change="$ctrl.onLastAmpErrorChange(lastAmpError)" playback-session-id="$ctrl.playbackSessionId" is-producer-view="$ctrl.isProducerView" is-live-event-completed="$ctrl.isCompleted" timed-events="$ctrl.video.timedEvents" on-player-caption-detected="$ctrl.onPlayerCaptionDetected()" video-id="$ctrl.video.id" content-version="$ctrl.video.contentVersion" ng-class=" { 'hide-amp-controlbar' : $ctrl.isProducerView &amp;&amp; !$ctrl.hideControlBar } " on-forms-token-post-message="$ctrl.getFormsAuthToken()" on-demand-options="$ctrl.video.liveEvent.liveEventOptions.onDemandOptions" show-end-of-event-overlay="$ctrl.onAudienceDidReachEndOfVodlessPlayback()" reload-updated-video="$ctrl.reloadUpdatedVideo()" class="ng-scope ng-isolate-scope" style=""><div class="media-player-controller" id="Axe3tnzmmaq"> <div poster="" id="vjs_video_3" playsinline="" preload="auto" crossorigin="anonymous" tabindex="-1" class="azuremediaplayer amp-big-play-centered amp-stream-skin vjs_video_3-dimensions amp-size-m vjs-user-inactive" style="width: 100%; height: 100%; font-size: 770px;"><div tabindex="0" class="vjs-controls-enabled vjs-player vjs-workinghover outline-enabled vjs-has-started vjs-paused vjs-ended" aria-label="video player, press space key to play/pause the video"><div><video id="vjs_video_3_AzureHtml5JS_api_5775" class="vjs-tech" oncontextmenu="return false;" tabindex="-1" aria-hidden="true" preload="auto" src="blob:https://web.microsoftstream.com/5bfda6dc-2edd-c74b-85f8-6be9ea16a24d"></video></div><div></div><div class="vjs-fullscreen-outline outline-enabled-control"></div><div class="vjs-poster" tabindex="-1"><span class="vjs-poster-span" tabindex="-1"></span><img src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/2aa98491-bdf5-46e3-bf56-1e8009f66b43/OTQxYTJlNGEtYWNkMy00NjFiLTg5MDgtNjdiYTM3M2E3YTFhLXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3A00%3A00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=fN5f%2BdNeiv8t08ii8UgyddGMmugPjPjn%2BT%2BsPsafS3Q%3D" style="display: inline;" crossorigin="use-credentials" alt="" role="presentation" width="100%" height="auto"></div><div class="vjs-text-track-display" aria-live="off" aria-atomic="true"></div><div class="vjs-loading-spinner" dir="ltr"><span></span></div><button class="vjs-big-play-button " type="button" aria-live="off"><span class="vjs-control-text">Play Video</span></button><div class="vjs-control-bar" dir="ltr" role="region" aria-label="Video controls"><div class="amp-controlbaricons-left"><button class="vjs-play-control vjs-control vjs-button outline-enabled-control vjs-paused" type="button" aria-live="off" style="cursor:pointer" title="Play"><span class="vjs-control-text">Play</span></button><div class="vjs-volume-control" title="volume level" aria-expanded="false"><button class="vjs-mute-control vjs-control vjs-button outline-enabled-control vjs-vol-3" type="button" aria-live="off"><span class="vjs-control-text">Mute</span></button><div class="vjs-menu"><div class="vjs-menu-content"><div tabindex="0" class="vjs-volume-bar vjs-slider-bar vjs-slider vjs-slider-horizontal" role="slider" aria-valuenow="100.00" aria-valuemin="0" aria-valuemax="100" aria-label="volume level" aria-valuetext="100.00%"><div class="vjs-volume-level" style="width: 100%;"><span class="vjs-control-text"></span></div><div class="vjs-volume-handle vjs-control outline-enabled-control" style="left: 100%;"><span class="vjs-control-text" aria-live="polite">100%</span></div></div></div></div></div><div class="vjs-live-control vjs-control vjs-hidden outline-enabled-control" tabindex="0" role="button" aria-live="off" aria-label="LIVE" style="cursor:pointer" title="Go to live"><span class="vjs-control-text"></span><div class="vjs-live-display" aria-live="off"><span class="vjs-control-text">Stream Type</span>LIVE</div></div><div class="vjs-current-time vjs-time-control vjs-control outline-enabled-control"><div class="vjs-current-time-display" aria-live="off"><span class="vjs-control-text">Current Time</span> 1:27:59</div><div class="amp-livetimeindicator">LIVE</div></div><div class="vjs-time-control vjs-time-divider"><div><span>/</span></div></div><div class="vjs-duration vjs-time-control vjs-control outline-enabled-control"><div class="vjs-duration-display" aria-live="off"><span class="vjs-control-text">Duration Time</span> 1:27:59</div></div><div class="vjs-remaining-time vjs-time-control vjs-control outline-enabled-control"><div class="vjs-remaining-time-display" aria-live="off"><span class="vjs-control-text">Remaining Time</span> -0:00</div></div></div><div class="amp-controlbaricons-middle"><div class="vjs-progress-control vjs-control outline-enabled-control" tabindex="-1"><div tabindex="0" class="vjs-progress-holder vjs-slider vjs-slider-horizontal" role="slider" aria-valuenow="99.94" aria-valuemin="0" aria-valuemax="100" aria-label="progress bar" aria-valuetext="01:27:56"><div class="vjs-load-progress " style="width: 100%;"><span class="vjs-control-text" style="left: 99.7929%; width: 0.215559%;"><span>Loaded</span>: 0%</span></div><div class="vjs-mouse-display" style="left: 740px;"><span class="amp-time-tooltip" style="left: -30px;">1:25:53</span><span class="amp-time-tooltip-pointer" style="left: -4px;"></span></div><div class="vjs-play-progress vjs-slider-bar " data-current-time="1:27:59" style="width: 100%;"><span class="vjs-control-text"><span>Progress</span>: 0%</span></div><div class="vjs-slider-handle " style="left: 100%;"><div class="vjs-mouse-display-seek-handle" style="left: 0px;"><span class="amp-time-tooltip">1:27:59</span><span class="amp-time-tooltip-pointer"></span></div><span class="vjs-control-text">Seekbar Handle</span></div></div></div></div><div class="amp-controlbaricons-right"><button class="amp-caption-toggle vjs-control vjs-button outline-enabled-control" type="button" aria-live="off" aria-pressed="true" aria-label="Captions are currently off, Caption toggle"><span class="vjs-control-text">Captions</span></button><div class="amp-more-options-icon vjs-control vjs-button vjs-settings outline-enabled-control" tabindex="0" role="button" aria-live="off" aria-label="Settings" data-return-focus="settingsPanel"><span class="vjs-control-text">Settings</span></div><button class="amp-theater-icon vjs-control vjs-button " type="button" aria-live="off" aria-label="Theater mode"><span class="vjs-control-text">Theater mode</span></button><button class="vjs-fullscreen-control vjs-control vjs-button outline-enabled-control" type="button" aria-live="off" style="cursor:pointer" title="Fullscreen"><span class="vjs-control-text">Fullscreen</span></button></div></div><div class="vjs-moreoptions-dialog vjs-modal-overlay vjs-hidden" tabindex="-1" role="presentation" aria-labelledby="TTsettingsMoreOptionsDialogLabel-vjs_video_3_component_315" aria-describedby="TTMoreOptionsDialogDescription-vjs_video_3_component_315"><div class="vjs-settings-panel" tabindex="-1"><div class="vjs-settings-panel-child outline-enabled-control" tabindex="-1"><div class="vjs-menu vjs-main-menu" role="presentation"><ul class="vjs-menu-content" role="menu"><div class="vjs-menu-button vjs-menu-button-popup vjs-button vjs-menu-item amp-playbackspeed-control-normal outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-expanded="false" aria-haspopup="true" aria-label="Playback Speed" title="Playback Speed"><span class="vjs-control-text"></span><div class="vjs-settings-sub-menu-title">Playback Speed</div><div class="vjs-settings-sub-menu-value"></div></div><div class="vjs-captions-subtitles-button vjs-menu-button vjs-menu-button-popup vjs-button vjs-menu-item outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-expanded="false" aria-haspopup="true"><span class="vjs-control-text"></span><div class="vjs-settings-sub-menu-title">Captions / Subtitles</div><div class="vjs-settings-sub-menu-value">Off</div></div><div class="amp-captions-settings-button vjs-menu-button vjs-menu-button-popup vjs-button vjs-menu-item outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-expanded="false" aria-haspopup="true"><span class="vjs-control-text"></span><div class="vjs-settings-sub-menu-title">Captions / Subtitles settings</div><div class="vjs-settings-sub-menu-value"></div></div><div class="amp-quality-control vjs-menu-button vjs-menu-button-popup vjs-button vjs-menu-item quality-4 outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-expanded="false" aria-haspopup="true"><span class="vjs-control-text"></span><div class="vjs-settings-sub-menu-title">Quality</div><div class="vjs-settings-sub-menu-value">Auto</div></div><div class="amp-caption-toggle vjs-menu-button vjs-menu-button-popup vjs-button vjs-menu-item outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-expanded="false" aria-haspopup="true"><div class="vjs-menu" role="presentation"><ul class="vjs-menu-content" role="menu"></ul></div><span class="vjs-control-text"></span><div class="vjs-settings-sub-menu-title">Report an issue</div><div class="vjs-settings-sub-menu-value"></div></div></ul></div><div class="vjs-settings-sub-menu vjs-hidden" style="margin-right: -152px; opacity: 0;"><div class="vjs-menu" role="presentation"><ul class="vjs-menu-content" role="menu"><li class="vjs-menu-item vjs-back-button outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-label="Back to main menu"><span class="vjs-back-button-text">Playback Speed</span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="2.0x" aria-checked="false">2.0x<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="1.75x" aria-checked="false">1.75x<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="1.5x" aria-checked="false">1.5x<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="1.25x" aria-checked="false">1.25x<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="1.0x" aria-checked="false">1.0x<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="0.5x" aria-checked="false">0.5x<span class="vjs-control-text"> </span></li></ul></div></div><div class="vjs-settings-sub-menu vjs-hidden" style="margin-right: -176px; opacity: 0;"><div class="vjs-menu" role="presentation"><ul class="vjs-menu-content" role="menu"><li class="vjs-menu-item vjs-back-button outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-label="Back to main menu"><span class="vjs-back-button-text">Captions / Subtitles</span></li><li class="vjs-menu-item vjs-selected outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="Off" aria-checked="true">Off<span class="vjs-control-text">, selected</span></li><li class="vjs-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="English [CC]" aria-checked="false">English<span class="vjs-control-text"> </span> CC</li></ul></div></div><div class="vjs-settings-sub-menu vjs-hidden" style="margin-right: -308px; opacity: 0;"><div class="vjs-menu"><ul class="vjs-menu-content" role="menu"><li class="vjs-menu-item dialog-header vjs-back-button outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-label="Back to main menu"><span class="vjs-back-button-text">Captions / Subtitles settings</span></li><li class="amp-caption-settings-menu amp-non-clickable-element" role="presentation" tabindex="-1">
        <div class="amp-caption-setting-container">
            <label class="amp-caption-settings-label" id="captions-text-size-vjs_video_3_component_489">Text size: </label>
            <div class="amp-radio-button-group amp-font-size-group" role="radiogroup" aria-labelledby="captions-text-size-vjs_video_3_component_489">
                <label class="amp-radio-button amp-font-size" role="radio" aria-labelledby="captions-text-size-small-vjs_video_3_component_489">
                    <input type="radio" name="fontSize" value="0.75" class="outline-enabled-control" aria-setsize="3" aria-posinset="1">
                    <span id="captions-text-size-small-vjs_video_3_component_489">Small</span>
                </label>
                <label class="amp-radio-button amp-font-size" role="radio" aria-labelledby="captions-text-size-medium-vjs_video_3_component_489">
                    <input type="radio" name="fontSize" value="1.00" class="outline-enabled-control" aria-setsize="3" aria-posinset="2">
                    <span id="captions-text-size-medium-vjs_video_3_component_489">Medium</span>
                </label>
                <label class="amp-radio-button amp-font-size" role="radio" aria-labelledby="captions-text-size-large-vjs_video_3_component_489">
                    <input type="radio" name="fontSize" value="1.50" class="outline-enabled-control" aria-setsize="3" aria-posinset="3">
                    <span id="captions-text-size-large-vjs_video_3_component_489">Large</span>
                </label>
            </div>

            <label class="amp-caption-settings-label" for="captions-text-color-vjs_video_3_component_489">Text color: 
                <span class="amp-caption-color-selected-text">Standard</span>
            </label>
            <div class="amp-radio-button-group amp-font-color-group" id="caption-text-color-vjs_video_3_component_489" role="radiogroup" aria-label="Text color: ">
                <label class="amp-radio-button amp-font-color" role="radio">
                    <input type="radio" name="fontColor" value="whiteBlack" aria-setsize="4" aria-posinset="1" class="amp-font-color-whiteBlack outline-enabled-control" aria-label="Standard">
                    <span></span>
                </label>
                <label class="amp-radio-button amp-font-color" role="radio">
                    <input type="radio" name="fontColor" value="whiteGray" aria-setsize="4" aria-posinset="2" class="amp-font-color-whiteGray outline-enabled-control" aria-label="Reverse sepia">
                    <span></span>
                </label>
                <label class="amp-radio-button amp-font-color" role="radio">
                    <input type="radio" name="fontColor" value="blackLightGray" aria-setsize="4" aria-posinset="3" class="amp-font-color-blackLightGray outline-enabled-control" aria-label="Sepia">
                    <span></span>
                </label>
                <label class="amp-radio-button amp-font-color" role="radio">
                    <input type="radio" name="fontColor" value="blackWhite" aria-setsize="4" aria-posinset="4" class="amp-font-color-blackWhite outline-enabled-control" aria-label="Reverse standard">
                    <span></span>
                </label>
            </div>

            <div class="amp-background-transparency amp-row-with-button">
                <label class="amp-caption-settings-label" id="captions-background-transparency-label-vjs_video_3_component_489">Background transparency</label>
                <div class="amp-toggle">
                    <button type="button" role="button" aria-pressed="false" class="amp-captions-background-transparency outline-enabled-control" aria-labelledby="captions-background-transparency-label-vjs_video_3_component_489"></button>
                    <span class="toggle-value">Off</span>
                </div>
            </div>
            <div class="amp-caption-settings-reset-container">
                <button type="button" class="amp-caption-settings-reset amp-caption-settings-label outline-enabled-control">Revert to default settings</button>
            </div>
        </div>
        </li></ul></div></div><div class="vjs-settings-sub-menu vjs-hidden" style="margin-right: -146px; opacity: 0;"><div class="vjs-menu" role="presentation"><ul class="vjs-menu-content" role="menu"><li class="vjs-menu-item vjs-back-button outline-enabled-control" tabindex="-1" role="menuitem" aria-live="off" aria-label="Back to main menu"><span class="vjs-back-button-text">Quality</span></li><li class="vjs-menu-item vjs-selected amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="Auto" aria-checked="true">Auto<span class="vjs-control-text">, selected</span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="720p-338Kbps" aria-checked="false">720p-338Kbps<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="540p-205Kbps" aria-checked="false">540p-205Kbps<span class="vjs-control-text"> </span></li><li class="vjs-menu-item amp-menu-item outline-enabled-control" tabindex="-1" role="menuitemcheckbox" aria-live="off" aria-label="360p-105Kbps" aria-checked="false">360p-105Kbps<span class="vjs-control-text"> </span></li></ul></div></div></div></div></div><div class="vjs-error-display vjs-modal-dialog vjs-hidden " tabindex="-1" aria-describedby="vjs_video_3_component_563_description" aria-hidden="true" aria-label="Modal Window" role="dialog"><p class="vjs-modal-dialog-description vjs-offscreen" id="vjs_video_3_component_563_description">This is a modal window.</p><div class="vjs-modal-dialog-content" role="document" tabindex="0"></div></div><div class="vjs-caption-settings vjs-modal-overlay vjs-hidden" tabindex="-1" role="dialog" aria-labelledby="TTsettingsDialogLabel-vjs_video_3_component_568" aria-describedby="TTsettingsDialogDescription-vjs_video_3_component_568">
    <div role="document">
      <div role="heading" aria-level="1" id="TTsettingsDialogLabel-vjs_video_3_component_568" class="vjs-control-text">Captions Settings Dialog</div>
      <div id="TTsettingsDialogDescription-vjs_video_3_component_568" class="vjs-control-text">Beginning of dialog window. Escape will cancel and close the window.</div>
      <div class="vjs-tracksettings">
        <div class="vjs-tracksettings-colors">
          <fieldset class="vjs-fg-color vjs-tracksetting">
            <legend>Text</legend>
            <label class="vjs-label" for="captions-foreground-color-vjs_video_3_component_568">Text color</label>
            <select id="captions-foreground-color-vjs_video_3_component_568">
              <option value="#FFF" selected="">White</option>
              <option value="#000">Black</option>
              <option value="#F00">Red</option>
              <option value="#0F0">Green</option>
              <option value="#00F">Blue</option>
              <option value="#FF0">Yellow</option>
              <option value="#F0F">Magenta</option>
              <option value="#0FF">Cyan</option>
            </select>
            <span class="vjs-text-opacity vjs-opacity">
             <label class="vjs-label" for="captions-foreground-opacity-vjs_video_3_component_568">Text opacity</label>
              <select id="captions-foreground-opacity-vjs_video_3_component_568">
                <option value="1" selected="">Opaque</option>
                <option value="0.5">Semi-Opaque</option>
              </select>
            </span>
          </fieldset>
          <fieldset class="vjs-bg-color vjs-tracksetting">
            <legend>Background</legend>
            <label class="vjs-label" for="captions-background-color-vjs_video_3_component_568">Background Color</label>
            <select id="captions-background-color-vjs_video_3_component_568">
              <option value="#000" selected="">Black</option>
              <option value="#FFF">White</option>
              <option value="#F00">Red</option>
              <option value="#0F0">Green</option>
              <option value="#00F">Blue</option>
              <option value="#FF0">Yellow</option>
              <option value="#F0F">Magenta</option>
              <option value="#0FF">Cyan</option>
            </select>
            <span class="vjs-bg-opacity vjs-opacity">
              <label class="vjs-label" for="captions-background-opacity-vjs_video_3_component_568">Background opacity</label>
              <select id="captions-background-opacity-vjs_video_3_component_568">
                <option value="1" selected="">Opaque</option>
                <option value="0.5">Semi-Transparent</option>
                <option value="0">Transparent</option>
              </select>
            </span>
          </fieldset>
          <fieldset class="window-color vjs-tracksetting">
            <legend>Window</legend>
            <label class="vjs-label" for="captions-window-color-vjs_video_3_component_568">Window Color</label>
            <select id="captions-window-color-vjs_video_3_component_568">
              <option value="#000" selected="">Black</option>
              <option value="#FFF">White</option>
              <option value="#F00">Red</option>
              <option value="#0F0">Green</option>
              <option value="#00F">Blue</option>
              <option value="#FF0">Yellow</option>
              <option value="#F0F">Magenta</option>
              <option value="#0FF">Cyan</option>
            </select>
            <span class="vjs-window-opacity vjs-opacity">
              <label class="vjs-label" for="captions-window-opacity-vjs_video_3_component_568">Transparency</label>
              <select id="captions-window-opacity-vjs_video_3_component_568">
                <option value="0" selected="">Transparent</option>
                <option value="0.5">Semi-Transparent</option>
                <option value="1">Opaque</option>
              </select>
            </span>
          </fieldset>
        </div> <!-- vjs-tracksettings-colors -->
        <div class="vjs-tracksettings-font">
          <div class="vjs-font-percent vjs-tracksetting">
            <label class="vjs-label" for="captions-font-size-vjs_video_3_component_568">Font Size</label>
            <select id="captions-font-size-vjs_video_3_component_568">
              <option value="0.50">50%</option>
              <option value="0.75">75%</option>
              <option value="1.00" selected="">100%</option>
              <option value="1.25">125%</option>
              <option value="1.50">150%</option>
              <option value="1.75">175%</option>
              <option value="2.00">200%</option>
              <option value="3.00">300%</option>
              <option value="4.00">400%</option>
            </select>
          </div>
          <div class="vjs-edge-style vjs-tracksetting">
            <label class="vjs-label" for="captions-edge-style-vjs_video_3_component_568">Text Edge Style</label>
            <select id="captions-edge-style-vjs_video_3_component_568">
              <option value="none" selected="">None</option>
              <option value="raised">Raised</option>
              <option value="depressed">Depressed</option>
              <option value="uniform">Uniform</option>
              <option value="dropshadow">Dropshadow</option>
            </select>
          </div>
          <div class="vjs-font-family vjs-tracksetting">
            <label class="vjs-label" for="captions-font-family-vjs_video_3_component_568">Font Family</label>
            <select id="captions-font-family-vjs_video_3_component_568">
              <option value="proportionalSansSerif" selected="">Proportional Sans-Serif</option>
              <option value="monospaceSansSerif">Monospace Sans-Serif</option>
              <option value="proportionalSerif">Proportional Serif</option>
              <option value="monospaceSerif">Monospace Serif</option>
              <option value="casual">Casual</option>
              <option value="script">Script</option>
              <option value="small-caps">Small Caps</option>
            </select>
          </div>
        </div> <!-- vjs-tracksettings-font -->
        <div class="vjs-tracksettings-controls">
          <button class="vjs-default-button">Defaults</button>
          <button class="vjs-done-button">Done</button>
        </div>
      </div> <!-- vjs-tracksettings -->
    </div> <!--  role="document" --></div><p class="vjs-screen-reader-text" id="player-use-for-screen-reader-alert-only0.050683595946912186" role="alert" aria-atomic="true"></p></div></div> <!-- ngIf: $ctrl.isErrorOccured --> </div> </media-player><!-- end ngIf: $ctrl.isVideoPlayerShown && !$ctrl.showFakePlayButton && !$ctrl.isErrorOccured --> <!-- ngIf: $ctrl.showFakePlayButton --> <!-- ngIf: $ctrl.isErrorOccured --> <!-- ngIf: $ctrl.isProducerView && !$ctrl.hideControlBar --> </div> </div> </div> </div></video-player-view><!-- end ngIf: $ctrl.video && !$ctrl.shouldShowEndEventMessage --> </div> </div> </div> <div id="player-right-container-wrapper" class="column xsmall-12 small-6 medium-4 large-4" ng-show="$ctrl.showRightContainer" role="region" aria-label="Interactive content" aria-hidden="false"> <div class="sub-header"> <tab-navigation class="right-navigation ng-isolate-scope" model="$ctrl.playerRightTabOptions" value="$ctrl.currentRightTab" direction="$ctrl.tabHeaderDirection" show-full-in-small="true"><nav class="tab-navigation c-in-page-navigation" ng-class="{'tab-navigation-v2': $ctrl.isV2StyleEnabled, 'c-in-page-navigation': !$ctrl.isVertical, 'vertical-navigation': $ctrl.isVertical, 'tab-navigation-minimal': $ctrl.minimalStyle}"> <ul class="tab-navigation-list show-for-small" role="tablist" ng-class="{'show-for-medium': !$ctrl.isVertical &amp;&amp; !$ctrl.showFullInSmall, 'show-for-small': $ctrl.showFullInSmall}"> <!-- ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><li class="tab-navigation-item ng-scope transcript-right-tab f-active" role="presentation" ng-repeat="option in $ctrl.model.options" ng-if="!option.hide" ng-class="[option.className, {'f-active': $ctrl.value === option.value}]" style=""> <!-- ngIf: option.svgName --> <button class="c-action-trigger nav-link nav-link-option-1 f-active" role="tab" ng-class="{'f-active': $ctrl.value === option.value, 'item-error': option.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked(option)" ng-disabled="option.disable" aria-posinset="1" aria-setsize="1" aria-selected="true"> <!-- ngIf: option.value === $ctrl.errorTabValue --> Transcript </button> <!-- ngIf: option.afterSvgName --> </li><!-- end ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --> </ul> <!-- ngIf: !$ctrl.isVertical --><ul class="tab-navigation-list ng-scope hide-for-small" ng-if="!$ctrl.isVertical" ng-class="{'hide-for-medium': !$ctrl.showFullInSmall, 'hide-for-small': $ctrl.showFullInSmall}"> <li class="tab-navigation-item"> <button class="c-action-trigger with-drawer nav-link nav-link-option-1 f-active" ng-class="{'f-active': $ctrl.value === $ctrl.activeOption.value, 'item-error': $ctrl.activeOption.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked($ctrl.activeOption)" style=""> <!-- ngIf: $ctrl.activeOption.value === $ctrl.errorTabValue --> Transcript </button> </li> <!-- ngIf: $ctrl.drawerItems --><li class="tab-navigation-item ng-scope" ng-if="$ctrl.drawerItems"> <drawer drawer-items="$ctrl.drawerItems" item="$ctrl.model" left-allign="$ctrl.leftAllign" fixed-elements="$ctrl.fixedElements" tab-navigation-drawer="true" class="ng-isolate-scope" style="display: none;"><div class="drawer" action-list=""> <span ng-show="!$ctrl.transcludeButtonPresent" role="presentation" aria-hidden="false" class=""> <button name="dropdown" role="menu" class="c-action-trigger c-glyph drawer-button drawer-button-stream drawer-button-without-label ng-isolate-scope" aria-label="More actions" custom-title="More actions" aria-expanded="false" ng-click="return;"> <span class="x-screen-reader ng-binding">More actions</span> </button> </span> <span role="presentation" ng-show="$ctrl.transcludeButtonPresent" ng-transclude="transcludebutton" aria-hidden="true" class="ng-hide"> <ng-transclude></ng-transclude> </span> <ul class="drawer-content collapsed" ng-class="{'allign-opp': $ctrl.leftAllign}"> <!-- ngRepeat: item in $ctrl.drawerItems --> </ul> </div></drawer> </li><!-- end ngIf: $ctrl.drawerItems --> <li aria-label="Health" ng-class="$ctrl.svgClassName"> <!-- ngIf: $ctrl.isSvgAfterAvailable --> </li> </ul><!-- end ngIf: !$ctrl.isVertical --> </nav> </tab-navigation> <!-- ngIf: $ctrl.rightTabDrawerItems.length --> </div> <div class="player-right-container-content" id="player-right-container-content" style="height: 391px;"> <div id="yammer-right-tab-page" ng-class="{'live':$ctrl.isLiveNow || $ctrl.isLiveContentCreatedState}" ng-show="$ctrl.isRightTabSet(3)" aria-hidden="true" class="ng-hide"><div id="yammer-container"> <!-- ngIf: $ctrl.yammerHasError --> <!-- ngIf: !$ctrl.yammerHasError --><div id="yammer-embed" ng-if="!$ctrl.yammerHasError" class="ng-scope"> </div><!-- end ngIf: !$ctrl.yammerHasError --> </div></div> <div id="transcript-right-tab-page" ng-class="{'live':$ctrl.isLiveNow || $ctrl.isLiveContentCreatedState}" ng-show="$ctrl.isRightTabSet(1)" aria-hidden="false" class="" style=""><div id="transcript-container" ng-class="{'no-data': $ctrl.isNoTranscriptData || $ctrl.captionProcessing}"> <div id="transcript-content" class="transcript-content" ng-show="$ctrl.isCompletedOnLoad &amp;&amp; $ctrl.showTranscript" aria-hidden="false"> <!-- ngIf: $ctrl.captionProcessing && !$ctrl.captionProcessingPastSLA --> <!-- ngIf: $ctrl.captionProcessing && $ctrl.captionProcessingPastSLA --> <!-- ngIf: $ctrl.captionError --> <!-- ngIf: $ctrl.servicePlans.capabilities.transcriptSearch && $ctrl.captionReady --><search-event ng-if="$ctrl.servicePlans.capabilities.transcriptSearch &amp;&amp; $ctrl.captionReady" video="$ctrl.video" is-admin="$ctrl.isInAdminMode" can-edit="$ctrl.isEditorOrInAdminMode &amp;&amp; $ctrl.isTranscriptEditV3Enabled" on-edit-click="$ctrl.toggleTranscriptEditMode()" is-editable="!$ctrl.showTrimBar &amp;&amp; !ctrl.showReplaceBar" edit-event-button-aria-label="$ctrl.resources.TranscriptEditEnter" view-event-button-aria-label="$ctrl.resources.TranscriptEditExit" event-list-aria-label="$ctrl.resources.TranscriptVirtualListAriaLabel" class="ng-scope ng-isolate-scope"><div class="search-event"> <div class="search-event-wrapper"> <form class="c-search search-event-form ng-pristine ng-valid ng-valid-maxlength"> <input aria-label="Input text and hit enter key to search transcript" type="search" role="search" name="search-field" class="search-event-input search-field ng-pristine ng-untouched ng-valid ng-empty ng-valid-maxlength" ng-model="$ctrl.searchString" autocomplete="off" placeholder="Search transcript" ng-change="$ctrl.onSearchInputChange($ctrl.searchString)" ng-keydown="$ctrl.onSearchInputKeyDown($event)" maxlength="100" aria-invalid="false"> <button class="c-glyph search-magnifier ng-isolate-scope" name="search-button" type="button" aria-label="Search transcript" ng-click="$ctrl.onSearchButtonClick()" custom-title="Search transcript" z-index-override="11" disabled="disabled"></button> <button ng-show="$ctrl.showClearButton()" class="c-glyph clear-button ng-isolate-scope ng-hide" name="clear-button" type="button" ng-click="$ctrl.onClearButtonClick()" aria-label="clear user input" custom-title="Clear search input" z-index-override="11" aria-hidden="true"></button> </form> <button ng-show="$ctrl.canEdit &amp;&amp; $ctrl.onEditClick" class="edit-event-button c-glyph c-action-trigger  ng-hide start-edit-button" aria-label="Edit transcript" ng-click="$ctrl.onEditClicked()" custom-title="Edit transcript" z-index-override="11" aria-hidden="true" style=""> <svg-src svg-name="icon_edit" inline-with-text="true" class="ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_edit" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> <div class="content"> <!-- ngIf: $ctrl.state.isError --> <div class="searching ng-hide" ng-show="$ctrl.state.isSearching" aria-hidden="true"> <div class="searching-inner"> <div class="c-progress f-indeterminate-local f-progress-small" role="progressbar" aria-valuetext="Searching"> <span></span> <span></span> <span></span> <span></span> <span></span> </div> <h6 class="c-heading-6 ng-binding">Searching...</h6> </div> </div> <div class="no-search-result ng-hide" ng-show="$ctrl.state.isNoResults" aria-hidden="true"> <h6 class="c-heading-6 ng-binding" role="note" tabindex="0"> No search results found. </h6> </div> <!-- ngIf: $ctrl.events.length --> <div class="transclude-content" ng-show="$ctrl.state.isCollapsed" aria-hidden="false"> <ng-transclude> <transcript video="$ctrl.video" player-time="$ctrl.playerTime" is-admin="$ctrl.isInAdminMode" on-init="$ctrl.onTranscriptInit(transcriptController)" right-drawer-items="$ctrl.rightTabDrawerItems" bottom-drawer-items="$ctrl.bottomTabDrawerItems" class="ng-scope ng-isolate-scope"><div class="transcript"> <div class="transcript-loading ng-hide" ng-show="$ctrl.isLoadingState" aria-hidden="true" style=""> <loading-panel class="ng-isolate-scope"><div class="loading-panel"> <div class="loading-panel-inner"> <div class="c-progress f-indeterminate-local f-progress-small" role="progressbar" aria-valuetext="Loading"> <span></span> <span></span> <span></span> <span></span> <span></span> </div> <h5 class="c-heading-4 ng-binding">Loading...</h5> </div> </div></loading-panel> </div> <!-- ngIf: $ctrl.isErrorState --> <div ng-show="!$ctrl.isLoadingState &amp;&amp; !$ctrl.isErrorState" class="transcript-inner new" ng-class="{'new': $ctrl.isTranscriptEditV3Enabled}" aria-hidden="false" style=""> <!-- ngIf: $ctrl.transcriptLines.length --><virtual-list class="transcript-list ng-scope ng-isolate-scope" items="$ctrl.transcriptLines" ng-if="$ctrl.transcriptLines.length" is-auto-scrolling="$ctrl.isAutoScrollingState" force-update-to-index="$ctrl.forceUpdateToIndex" force-scroll-to-item="$ctrl.forceScrollToItem" user-interacted="$ctrl.enterUserInteractionMode()" apply-shadow="true" video-id="$ctrl.video.id" scrollable-content-aria-label="$ctrl.resources.TranscriptVirtualListAriaLabel" style=""><!-- ngIf: $ctrl.applyShadow --><div class="virtual-list-shadow-mask ng-scope" ng-if="$ctrl.applyShadow"></div><!-- end ngIf: $ctrl.applyShadow --> <div class="virtual-list"> <!-- ngIf: $ctrl.isVListEnabled --><div class="virtual-list-total-padding ng-scope" ng-style="$ctrl.totalPadding" ng-if="$ctrl.isVListEnabled" style="height: 74583px;"></div><!-- end ngIf: $ctrl.isVListEnabled --> <div class="scrollable-content" role="listbox" aria-label="This is a list of captions." ng-style="$ctrl.scrollTransform" id="" style="position: absolute; transform: translateY(73541px);"> <ng-transclude> 
    <ul class="ng-scope"> <!-- ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5206 seconds from beginning." id="transcript-74cd5051-c243-46ab-9dfa-23810cc9883a" aria-posinset="1367" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5206 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:46 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1366" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> In in an earlier answer here, we highlighted there's a lot </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5209 seconds from beginning." id="transcript-c738b813-6c3d-4fa2-bc8a-e1a6738d3272" aria-posinset="1368" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5209 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:49 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1367" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> of training being rolled out and being made available. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5212 seconds from beginning." id="transcript-b496e241-f2da-42da-a0b0-656d76bba4d0" aria-posinset="1369" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5212 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:52 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1368" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> Raise your hand, volunteer for the opportunity. Ask how </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5215 seconds from beginning." id="transcript-05f17e31-8022-469b-8f3f-bc46bbb48779" aria-posinset="1370" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5215 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:55 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1369" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> you can help. Ask how you can have an impact and get the </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5219 seconds from beginning." id="transcript-b5e0539d-c84d-45b2-a823-f0336e1ed3bd" aria-posinset="1371" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5219 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:59 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1370" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> right training in order to be ready for that role, because </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5222 seconds from beginning." id="transcript-1e165221-f253-4648-a43d-8d7394794a0a" aria-posinset="1372" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5222 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:02 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1371" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> this is going to be a really exciting journey an we really </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5226 seconds from beginning." id="transcript-882ad8de-0d12-4a43-ac46-4bd696cdb111" aria-posinset="1373" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5226 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:06 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1372" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> need everybody to lean in and help us achieve that growth. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5232 seconds from beginning." id="transcript-663ad0ca-79c9-4db3-8970-cdfabdf478fc" aria-posinset="1374" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5232 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:12 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1373" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> Alright, so I can't think of a better comment to close on. I </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5236 seconds from beginning." id="transcript-4f9f99e1-3717-4b1c-afa9-d4bb93a8c217" aria-posinset="1375" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5236 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:16 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1374" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> want to thank everyone on the panel. I wanna think Jeff, I </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5239 seconds from beginning." id="transcript-796b523c-9cdf-4c60-ab28-f265d6905cfc" aria-posinset="1376" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5239 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:19 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1375" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> want to thank all of you for attending. I really encourage </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5242 seconds from beginning." id="transcript-121c51ca-1966-4497-a949-7f3fff9ca962" aria-posinset="1377" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5242 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:22 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1376" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> you to attend our next quarterly town Hall on Aug 6th. I know you </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5246 seconds from beginning." id="transcript-536750e0-23ee-4982-b4b7-06b407f7bccf" aria-posinset="1378" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5246 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:26 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1377" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> have a lot of questions and he submitted a ton of questions </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5250 seconds from beginning." id="transcript-254e9ed2-49b2-4481-b1f7-345039944d8f" aria-posinset="1379" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5250 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:30 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1378" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> around. You know people that have taken a number of voluntary </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5253 seconds from beginning." id="transcript-a83df1f5-dd28-40f9-8262-e617edda9518" aria-posinset="1380" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5253 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:33 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1379" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> and involuntary actions will talk about all that on our next </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5256 seconds from beginning." id="transcript-dec7ed5c-25d3-4dd7-8085-ba121269fc2f" aria-posinset="1381" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5256 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:36 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1380" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> quarterly townhall. Obviously today was really focused on </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5258 seconds from beginning." id="transcript-f7256754-e9ba-4178-8559-909066aa6f2a" aria-posinset="1382" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5258 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:38 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1381" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> stint. Uhm, I want to thank everyone for participating and </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5261 seconds from beginning." id="transcript-31fc5c4f-4f9e-4eac-9b55-dbb1bdbbef55" aria-posinset="1383" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5261 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:41 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1382" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> thank you for working so hard </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5263 seconds from beginning." id="transcript-cd31625a-f693-42d6-83c6-6543117eb7cd" aria-posinset="1384" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5263 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:43 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1383" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> for Team Syncada. Please continue to stay safe and </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5266 seconds from beginning." id="transcript-819bcabc-e177-47f9-97eb-854d36c5b7b1" aria-posinset="1385" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5266 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:46 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1384" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> serve our customers and be well. Have a great day </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5268 seconds from beginning." id="transcript-4133dfb3-14c4-492f-9fc9-b76b4902aefa" aria-posinset="1386" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5268 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:48 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1385" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> everyone. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --> </ul> </ng-transclude> </div> </div></virtual-list><!-- end ngIf: $ctrl.transcriptLines.length --> <!-- ngIf: !$ctrl.isTranscriptEditV3Enabled --> </div> </div> </transcript> </ng-transclude> </div> </div> </div> </search-event><!-- end ngIf: $ctrl.servicePlans.capabilities.transcriptSearch && $ctrl.captionReady --> <!-- ngIf: !$ctrl.servicePlans.capabilities.transcriptSearch && $ctrl.captionReady --> </div> <div class="no-data-message-cont"> <!-- ngIf: $ctrl.isNoTranscriptData --> </div> </div></div> <div id="forms-right-tab-page" ng-class="{'live':$ctrl.isLiveNow || $ctrl.isLiveContentCreatedState}" ng-show="$ctrl.isRightTabSet(5)" aria-hidden="true" class="ng-hide"><div id="forms-container" class="forms-container"> <forms timed-events="$ctrl.timedEvents" show-controls="$ctrl.showFormControls" on-add-form="$ctrl.addForm(formEvent)" on-delete-form="$ctrl.deleteForm(formEvent)" player="$ctrl.player" on-form-clicked="$ctrl.jumpToForm(formEvent)" can-edit="$ctrl.isEditorOrInAdminMode" time-code="$ctrl.playerTime" video-id="$ctrl.videoId" player-session-id="$ctrl.playerSessionId" class="ng-isolate-scope"><div class="forms" dir="ltr"> <!-- ngIf: $ctrl.canEdit --> <!-- ngIf: $ctrl.timedEvents.length !== 0 --> <!-- ngIf: $ctrl.timedEvents.length === 0 && $ctrl.canEdit --> </div></forms> </div></div> </div> </div> </div> </div> </div><!-- end ngSwitchWhen:  --> <!-- ngSwitchWhen: NotFound --> <!-- ngSwitchWhen: Forbidden --> <!-- ngIf: $ctrl.routingCase === 'Uploading' || $ctrl.routingCase === 'NotReady' || $ctrl.routingCase === 'Error' --> </div> </div> </section> <!-- ngIf: $ctrl.video --><section class="other-area ng-scope" ng-if="$ctrl.video" aria-label="section including comments and related videos" style=""> <div class="row"> <div class="column video-detail-container medium-12 large-8" ng-class="{'medium-12 large-12': $ctrl.display12Column, 'medium-12 large-8': $ctrl.showRightContainer || $ctrl.isCompletedOnLoad}" style="margin-top: 0px;"> <div class="bottom-navigation-container"> <tab-navigation class="bottom-navigation ng-isolate-scope" model="$ctrl.playerBottomTabOptions" value="$ctrl.currentBottomTab" direction="$ctrl.tabHeaderDirection" show-full-in-small="true"><nav class="tab-navigation c-in-page-navigation" ng-class="{'tab-navigation-v2': $ctrl.isV2StyleEnabled, 'c-in-page-navigation': !$ctrl.isVertical, 'vertical-navigation': $ctrl.isVertical, 'tab-navigation-minimal': $ctrl.minimalStyle}"> <ul class="tab-navigation-list show-for-small" role="tablist" ng-class="{'show-for-medium': !$ctrl.isVertical &amp;&amp; !$ctrl.showFullInSmall, 'show-for-small': $ctrl.showFullInSmall}"> <!-- ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><li class="tab-navigation-item ng-scope details-bottom-tab f-active" role="presentation" ng-repeat="option in $ctrl.model.options" ng-if="!option.hide" ng-class="[option.className, {'f-active': $ctrl.value === option.value}]" style=""> <!-- ngIf: option.svgName --> <button class="c-action-trigger nav-link nav-link-option-0 f-active" role="tab" ng-class="{'f-active': $ctrl.value === option.value, 'item-error': option.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked(option)" ng-disabled="option.disable" aria-posinset="1" aria-setsize="1" aria-selected="true"> <!-- ngIf: option.value === $ctrl.errorTabValue --> Details </button> <!-- ngIf: option.afterSvgName --> </li><!-- end ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --> </ul> <!-- ngIf: !$ctrl.isVertical --><ul class="tab-navigation-list ng-scope hide-for-small" ng-if="!$ctrl.isVertical" ng-class="{'hide-for-medium': !$ctrl.showFullInSmall, 'hide-for-small': $ctrl.showFullInSmall}"> <li class="tab-navigation-item"> <button class="c-action-trigger with-drawer nav-link nav-link-option-0 f-active" ng-class="{'f-active': $ctrl.value === $ctrl.activeOption.value, 'item-error': $ctrl.activeOption.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked($ctrl.activeOption)"> <!-- ngIf: $ctrl.activeOption.value === $ctrl.errorTabValue --> Details </button> </li> <!-- ngIf: $ctrl.drawerItems --><li class="tab-navigation-item ng-scope" ng-if="$ctrl.drawerItems"> <drawer drawer-items="$ctrl.drawerItems" item="$ctrl.model" left-allign="$ctrl.leftAllign" fixed-elements="$ctrl.fixedElements" tab-navigation-drawer="true" class="ng-isolate-scope"><div class="drawer" action-list=""> <span ng-show="!$ctrl.transcludeButtonPresent" role="presentation" aria-hidden="false" class=""> <button name="dropdown" role="menu" class="c-action-trigger c-glyph drawer-button drawer-button-stream drawer-button-without-label ng-isolate-scope" aria-label="More actions" custom-title="More actions" aria-expanded="false" ng-click="return;"> <span class="x-screen-reader ng-binding">More actions</span> </button> </span> <span role="presentation" ng-show="$ctrl.transcludeButtonPresent" ng-transclude="transcludebutton" aria-hidden="true" class="ng-hide"> <ng-transclude></ng-transclude> </span> <ul class="drawer-content collapsed" ng-class="{'allign-opp': $ctrl.leftAllign}"> <!-- ngRepeat: item in $ctrl.drawerItems --> </ul> </div></drawer> </li><!-- end ngIf: $ctrl.drawerItems --> <li aria-label="Health" ng-class="$ctrl.svgClassName"> <!-- ngIf: $ctrl.isSvgAfterAvailable --> </li> </ul><!-- end ngIf: !$ctrl.isVertical --> </nav> </tab-navigation> <!-- ngIf: $ctrl.bottomTabDrawerItems.length --> </div> <div id="under-player-container" class="xsmall-12 small-12 medium-12 large-12"> <video-metadata ng-show="$ctrl.isBottomTabSet(0) &amp;&amp; $ctrl.showMetadata" video="$ctrl.video" is-in-admin-mode="$ctrl.isInAdminMode" elevated-video-session-properties="$ctrl.elevatedVideoSessionProperties" video-page-session-properties="$ctrl.videoPageSessionProperties" player-options="$ctrl.playerOptions" dialog-interruption-handler="$ctrl.dialogInterruptionHandler" get-player-current-time="$ctrl.getCurrentTime()" drawer-items="$ctrl.drawerItems" view-settings="$ctrl.viewSettings" is-stream-admin="$ctrl.isStreamAdmin" is-live-content="$ctrl.isLiveContent" video-page-session-metrics="$ctrl.videoPageSessionMetrics" is-live-now="$ctrl.isLiveNow" is-completed="$ctrl.isCompleted" is-replacing="$ctrl.isReplacing" is-trimming="$ctrl.isTrimming" class="ng-isolate-scope" aria-hidden="false"><section> <div class="video-meta-container"> <div class="row row-size1"> <!-- ngIf: $ctrl.showErrorMessage --> </div> <div class="row column main-meta row-size0 remove-margin"> <div class="title-container title-with-completed" ng-class="{'title-with-live': $ctrl.isLiveNow, 'title-with-completed': $ctrl.isCompleted, 'title-before-live': $ctrl.isLiveContent &amp;&amp; !$ctrl.isCompleted}"> <span class="live-label-cont"> <!-- ngIf: $ctrl.isLiveNow --> </span> <!-- ngIf: $ctrl.isLiveContent && !$ctrl.isCompleted && !$ctrl.isLiveNow && !$ctrl.isReplacing && !$ctrl.isTrimming --> <!-- ngIf: $ctrl.isLiveContent && $ctrl.isCompleted --> <h1 class="title ng-binding"> 2020 Global STINT Town Hall Meeting </h1> </div> <div class="creator-and-privacy"> <div class="video-create-message"> <video-creator item="$ctrl.video" get-creator-message-template="$ctrl.getCreateMessageTemplate()" class="ng-isolate-scope">﻿<!-- ngIf: ::($ctrl.canDisplayCreator) --><span class="info-message-content ng-binding ng-scope" ng-if="::($ctrl.canDisplayCreator)">Published on 2020/7/22 by  <a class="c-hyperlink info-message-link ng-binding" ng-href="/user/21bed756-c076-4add-9912-d49fcc3543d0" ng-click="$ctrl.cacheCreator()" href="/user/21bed756-c076-4add-9912-d49fcc3543d0">Cermak, Jennifer</a>  </span><!-- end ngIf: ::($ctrl.canDisplayCreator) --></video-creator> </div> <div class="privacy-and-statistics"> <video-privacy class="video-privacy ng-isolate-scope" video-privacy-type="$ctrl.video.privacyMode"><p class="screen-reader-text ng-binding">organization</p> <div class="videoprivacy ng-isolate-scope" aria-hidden="true" custom-title="" light-style="$ctrl.lightCustomTitle"> <svg-src class="icon_privacytag ng-isolate-scope video-privacy-company" aria-label="Privacy" inline-with-text="true" svg-name="icon_privacy_my_org" ng-class="{
            'video-privacy-company' : ($ctrl.videoPrivacyType | isVideoPrivacyCompany),
            'video-privacy-limited' : ($ctrl.videoPrivacyType | isVideoPrivacyLimited)
         }"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_privacy_my_org" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <!-- ngIf: !$ctrl.hideLabel --><span class="c-badge privacytext ng-binding ng-scope" ng-if="!$ctrl.hideLabel"> Company </span><!-- end ngIf: !$ctrl.hideLabel --> </div> </video-privacy> <!-- ngIf: !$ctrl.isLiveNow --><video-statistics ng-if="!$ctrl.isLiveNow" video-statistics-data="$ctrl.video.metrics" show-icons="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="$ctrl.showIcons"> <span role="img" class="view-count metric-inline-flex ng-isolate-scope" custom-title="366 views" light-style="$ctrl.lightCustomTitle" aria-label="366 views"> <span aria-hidden="true" class="ng-binding">366</span> <svg-src svg-name="icon_views_new" class="metric-icon ng-isolate-scope"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_views_new" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </span> <!-- ngIf: !$ctrl.hideLikes --><span role="img" class="like-count metric-inline-flex ng-scope ng-isolate-scope" ng-if="!$ctrl.hideLikes" custom-title="4 likes" light-style="$ctrl.lightCustomTitle" aria-label="4 likes"> <span aria-hidden="true" class="ng-binding">4</span> <svg-src svg-name="icon_likes" class="metric-icon ng-isolate-scope"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_likes" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </span><!-- end ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> </div> </div> <!-- ngIf: $ctrl.video.description --> <!-- ngIf: $ctrl.showSeeMoreSeeLessButton --> </div> <!-- ngIf: !$ctrl.showSeeMoreSeeLessButton --><div class="row column divider ng-scope" ng-if="!$ctrl.showSeeMoreSeeLessButton"> <hr class="c-divider"> </div><!-- end ngIf: !$ctrl.showSeeMoreSeeLessButton --> <div class="row row-size0 action-trigger"> <div class="column xsmall-10 small-7 medium-8 large-8 relativeposition"> <div class="video-action-trigger"> <!-- ngIf: $ctrl.video.userData.permissions.canShareUrl --><button class="c-action-trigger c-glyph action-button video-action-share ng-scope" ng-click="$ctrl.onShareClick()" aria-label="Share" ng-if="$ctrl.video.userData.permissions.canShareUrl"> <span class="action-button-svg-container"><svg-src svg-name="icon_share" inline-with-text="true" class="action-button-svg ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_share" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src></span> <span class="action-button-label ng-binding">Share</span> </button><!-- end ngIf: $ctrl.video.userData.permissions.canShareUrl --> <!-- ngIf: $ctrl.video.userData.isPinned --> <!-- ngIf: !$ctrl.video.userData.isPinned --><button class="c-action-trigger c-glyph action-button video-action-pin ng-scope" ng-click="$ctrl.onPinButtonClick()" ng-disabled="$ctrl.pinButtonDisabled" aria-label="Add to watchlist" ng-if="!$ctrl.video.userData.isPinned"> <span class="action-button-svg-container"><svg-src svg-name="icon-add-to-watchlist" inline-with-text="true" class="action-button-svg video-action-pin ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon-add-to-watchlist" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src></span> <span class="action-button-label ng-binding">Add to watchlist</span> </button><!-- end ngIf: !$ctrl.video.userData.isPinned --> <!-- ngIf: $ctrl.video.userData.isLiked --> <!-- ngIf: !$ctrl.video.userData.isLiked --><button class="c-action-trigger c-glyph action-button video-like ng-scope" ng-click="$ctrl.onLikeClick()" ng-disabled="$ctrl.likeButtonDisabled" aria-label="Like" ng-if="!$ctrl.video.userData.isLiked"> <span class="action-button-svg-container"><svg-src svg-name="icon_likes" inline-with-text="true" class="action-button-svg video-action-like ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_likes" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src></span> <span class="action-button-label ng-binding">Like</span> </button><!-- end ngIf: !$ctrl.video.userData.isLiked --> <drawer class="action-drawer action-drawer-with-label ng-isolate-scope" drawer-items="$ctrl.drawerItems"><div class="drawer" action-list=""> <span ng-show="!$ctrl.transcludeButtonPresent" role="presentation" aria-hidden="false" class=""> <button name="dropdown" role="menu" class="c-action-trigger c-glyph drawer-button drawer-button-stream drawer-button-without-label ng-isolate-scope" aria-label="More actions" custom-title="More actions" aria-expanded="false" ng-click="return;"> <span class="x-screen-reader ng-binding">More actions</span> </button> </span> <span role="presentation" ng-show="$ctrl.transcludeButtonPresent" ng-transclude="transcludebutton" aria-hidden="true" class="ng-hide"> <ng-transclude></ng-transclude> </span> <ul class="drawer-content collapsed" ng-class="{'allign-opp': $ctrl.leftAllign}"> <!-- ngRepeat: item in $ctrl.drawerItems --><li ng-repeat="item in $ctrl.drawerItems" role="presentation" class="ng-scope"> <!-- ngIf: item.isVisible --><button role="menuitem" ng-class="item.iconClassName" class="drawer-item-Linked-group-or-channel c-glyph c-action-trigger drawer-content-item Linked-group-or-channel" aria-label="Linked groups/channels List item 1 of 2" ng-click="$ctrl.onItemClick(item)" ng-if="item.isVisible"> <!-- ngIf: item.svgSrc --><svg-src svg-name="icon_channel_poster" ng-if="item.svgSrc" class="small-icon ng-scope ng-isolate-scope" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_channel_poster" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src><!-- end ngIf: item.svgSrc --> <span class="icon-text ng-binding svg-text" ng-class="item.svgSrc?'svg-text':'glyph-text'">Linked groups/channels</span> </button><!-- end ngIf: item.isVisible --> </li><!-- end ngRepeat: item in $ctrl.drawerItems --><li ng-repeat="item in $ctrl.drawerItems" role="presentation" class="ng-scope"> <!-- ngIf: item.isVisible --><button role="menuitem" ng-class="item.iconClassName" class="drawer-item-add-to-group-channel c-glyph c-action-trigger drawer-content-item add-to-group-channel" aria-label="Add to group/channel List item 2 of 2" ng-click="$ctrl.onItemClick(item)" ng-if="item.isVisible"> <!-- ngIf: item.svgSrc --><svg-src svg-name="icon-add-to-channel" ng-if="item.svgSrc" class="small-icon ng-scope ng-isolate-scope" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon-add-to-channel" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src><!-- end ngIf: item.svgSrc --> <span class="icon-text ng-binding svg-text" ng-class="item.svgSrc?'svg-text':'glyph-text'">Add to group/channel</span> </button><!-- end ngIf: item.isVisible --> </li><!-- end ngRepeat: item in $ctrl.drawerItems --> </ul> </div></drawer> <!-- ngIf: $ctrl.isReactShareDialogEnabled() --> </div> </div> <div class="column xsmall-2 small-5 medium-4 large-4 video-action-trigger view-settings-button"> <!-- ngIf: $ctrl.viewSettings.length --><drawer drawer-items="$ctrl.viewSettings" ng-if="$ctrl.viewSettings.length" class="ng-scope ng-isolate-scope"><div class="drawer" action-list=""> <span ng-show="!$ctrl.transcludeButtonPresent" role="presentation" aria-hidden="true" class="ng-hide"> <button name="dropdown" role="menu" class="c-action-trigger c-glyph drawer-button drawer-button-stream drawer-button-without-label ng-isolate-scope" aria-label="More actions" custom-title="More actions" aria-expanded="false" ng-click="return;"> <span class="x-screen-reader ng-binding">More actions</span> </button> </span> <span role="presentation" ng-show="$ctrl.transcludeButtonPresent" ng-transclude="transcludebutton" aria-hidden="false" class=""><transcludebutton class="ng-scope"> <button class="c-action-trigger drawer-button-stream action-button drawer-button-with-label" aria-label="View settings" aria-expanded="false"> <span class="drawer-icon-container"><svg-src svg-name="icon_settings" inline-with-text="true" class="action-button-svg video-action-unpin ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_settings" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src></span> <span class="drawer-label ng-binding">View settings</span> <span class="drawer-icon-container"><svg-src class="drawer-down-arrow ng-isolate-scope" svg-name="icon_down_arrow" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_down_arrow" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src></span> </button> </transcludebutton></span> <ul class="drawer-content collapsed" ng-class="{'allign-opp': $ctrl.leftAllign}"> <!-- ngRepeat: item in $ctrl.drawerItems --><li ng-repeat="item in $ctrl.drawerItems" role="presentation" class="ng-scope"> <!-- ngIf: item.isVisible --><button role="menuitem" ng-class="item.iconClassName" class="drawer-item-hide-transcript c-glyph c-action-trigger drawer-content-item hide-transcript" aria-label="Hide transcript List item 1 of 2" ng-click="$ctrl.onItemClick(item)" ng-if="item.isVisible"> <!-- ngIf: item.svgSrc --><svg-src svg-name="icon_hide" ng-if="item.svgSrc" class="small-icon ng-scope ng-isolate-scope" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_hide" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src><!-- end ngIf: item.svgSrc --> <span class="icon-text ng-binding svg-text" ng-class="item.svgSrc?'svg-text':'glyph-text'">Hide transcript</span> </button><!-- end ngIf: item.isVisible --> </li><!-- end ngRepeat: item in $ctrl.drawerItems --><li ng-repeat="item in $ctrl.drawerItems" role="presentation" class="ng-scope"> <!-- ngIf: item.isVisible --><button role="menuitem" ng-class="item.iconClassName" class="drawer-item-theater-mode-on c-glyph c-action-trigger drawer-content-item theater-mode-on" aria-label="Theater mode List item 2 of 2" ng-click="$ctrl.onItemClick(item)" ng-if="item.isVisible"> <!-- ngIf: item.svgSrc --><svg-src svg-name="icon_theater_on" ng-if="item.svgSrc" class="small-icon ng-scope ng-isolate-scope" inline-with-text="true"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_theater_on" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src><!-- end ngIf: item.svgSrc --> <span class="icon-text ng-binding svg-text" ng-class="item.svgSrc?'svg-text':'glyph-text'">Theater mode</span> </button><!-- end ngIf: item.isVisible --> </li><!-- end ngRepeat: item in $ctrl.drawerItems --> </ul> </div></drawer><!-- end ngIf: $ctrl.viewSettings.length --> </div> </div> </div> </section></video-metadata> <div id="transcript-bottom-tab" ng-show="$ctrl.isBottomTabSet(1)" aria-hidden="true" class="ng-hide">  </div> <div id="yammer-bottom-tab" ng-show="$ctrl.isBottomTabSet(3)" aria-hidden="true" class="ng-hide">  </div> <div class="video-analytics-container ng-hide" ng-show="$ctrl.isBottomTabSet(4)" aria-hidden="true"> <video-analytics video="$ctrl.video" is-producer="false" is-vod="$ctrl.isVideoVod" class="ng-isolate-scope"><!-- ngIf: !$ctrl.isSmallSize --><div class="video-analytics-container ng-scope" ng-if="!$ctrl.isSmallSize"> <!-- ngIf: !$ctrl.hasData && !$ctrl.isVod --> <!-- ngIf: $ctrl.hasData || $ctrl.isVod --><div class="analytics-data-container ng-scope" ng-if="$ctrl.hasData || $ctrl.isVod"> <!-- ngIf: !$ctrl.isVod --> <div class="view-count-panel"> <div class="view-count-value ng-binding">365</div> <div class="view-count-label ng-binding">Views</div> </div> <div class="like-count-panel"> <div class="like-count-value ng-binding">4</div> <div class="like-count-label"> <svg-src class="likes-icon ng-isolate-scope" svg-name="icon_likes"><span class="svg-container" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_likes" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> <span class="ng-binding">Likes</span> </div> </div> <!-- ngIf: $ctrl.providerUrl --> <!-- ngIf: $ctrl.isDownloadAnalyticsEnabled --> </div><!-- end ngIf: $ctrl.hasData || $ctrl.isVod --> </div><!-- end ngIf: !$ctrl.isSmallSize --> <!-- ngIf: $ctrl.isSmallSize && $ctrl.isLiveNow --></video-analytics> </div> <div id="forms-bottom-tab" ng-show="$ctrl.isBottomTabSet(5)" aria-hidden="true" class="ng-hide">  </div> </div> <div id="faces-container" class="faces-container column xsmall-12 small-12 medium-12 large-12 ng-hide" ng-show="$ctrl.isBottomTabSet(2) &amp;&amp; ($ctrl.showFaces || $ctrl.isLiveContentButFaceDetectionNotReady) &amp;&amp; $ctrl.video.options.faceDetection" aria-hidden="true"> <div id="faces-content" class="faces-content"> <face-chart video="$ctrl.video" player-time="$ctrl.playerTime" is-admin="$ctrl.isInAdminMode" not-ready="$ctrl.isLiveContentButFaceDetectionNotReady" is-live-content="$ctrl.isLiveContent" is-created="$ctrl.isCreated" is-completed="$ctrl.isCompleted" class="ng-isolate-scope"><!-- ngIf: $ctrl.isLoading --> <!-- ngIf: $ctrl.isError --> <!-- ngIf: !$ctrl.isLoading && !$ctrl.isError --><div class="face-chart-container ng-scope" ng-if="!$ctrl.isLoading &amp;&amp; !$ctrl.isError" style=""> <!-- ngIf: ($ctrl.video.userData.permissions.canEdit || $ctrl.isAdmin) && $ctrl.isEditMode --> <!-- ngIf: $ctrl.noFaceShown && !$ctrl.isEditMode --><div ng-if="$ctrl.noFaceShown &amp;&amp; !$ctrl.isEditMode" class="no-face-shown ng-scope"> <div class="no-data-message-cont"> <div class="no-data-message"> <span class="message-icon-cont"> <svg-src svg-name="icon_library" inline-with-text="true" class="message-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_library" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </span> <!-- ngIf: !$ctrl.notReady --><span ng-if="!$ctrl.notReady" class="ng-binding ng-scope">People timelines are not available for this video.</span><!-- end ngIf: !$ctrl.notReady --> <!-- ngIf: $ctrl.vodNotReady || $ctrl.liveVodNotReady --> <!-- ngIf: $ctrl.liveNotReady --> </div> </div> </div><!-- end ngIf: $ctrl.noFaceShown && !$ctrl.isEditMode --> <!-- ngIf: !$ctrl.noFaceShown && !$ctrl.notReady --> <!-- ngIf: $ctrl.showCommandBar() --> </div><!-- end ngIf: !$ctrl.isLoading && !$ctrl.isError --></face-chart> </div> </div> <!-- ngIf: $ctrl.isCompletedOnLoad && !$ctrl.isVODLess --><div id="comments-container" class="comments-container column xsmall-12 small-6 medium-6 large-12 vertical-space ng-scope" ng-if="$ctrl.isCompletedOnLoad &amp;&amp; !$ctrl.isVODLess"> <div id="comments"> <comments video="$ctrl.video" is-in-admin-mode="$ctrl.isInAdminMode" class="ng-isolate-scope"><div class="video-comments c-caption-1"> <div class="comments-loading ng-hide" ng-show="$ctrl.initState.loading" aria-hidden="true" style=""> <loading-panel class="ng-isolate-scope"><div class="loading-panel"> <div class="loading-panel-inner"> <div class="c-progress f-indeterminate-local f-progress-small" role="progressbar" aria-valuetext="Loading"> <span></span> <span></span> <span></span> <span></span> <span></span> </div> <h5 class="c-heading-4 ng-binding">Loading...</h5> </div> </div></loading-panel> </div> <div class="error-banner ng-hide" ng-show="$ctrl.initState.error" aria-hidden="true"> <h6 class="c-heading-6 ng-binding"></h6> </div> <div class="comments-ready" ng-show="$ctrl.initState.ready" aria-hidden="false" style=""> <h2 class="title-heading comments-label c-heading-5 ng-binding"> 0 Comments </h2> <div class="error-banner ng-hide" ng-show="$ctrl.postCommentState.error" aria-hidden="true"> <h6 class="c-heading-6 ng-binding"></h6> </div> <!-- ngIf: $ctrl.video.userData.permissions.canComment --><div class="comment-input-box ng-scope" ng-if="$ctrl.video.userData.permissions.canComment"> <div class="profile-image"> <!-- ngIf: $ctrl.getProfileImage() --><img ng-if="$ctrl.getProfileImage()" ng-src="https://uswe-1-content.api.microsoftstream.com/api/tenants/8fe11266-3a2b-494f-b7ce-92bc201dc2ab/users/79c34bfa-ad42-4aae-a681-1edc26a3b11e/photo?api-version=1.4-private" onerror="this.src=&quot;/bundles/app/generated/user-placeholder.svg&quot;" alt="user profile image" class="ng-scope" src="/bundles/app/generated/user-placeholder.svg"><!-- end ngIf: $ctrl.getProfileImage() --> <!-- ngIf: !$ctrl.getProfileImage() --> </div> <div class="input-area"> <div class="input-arrow"> <div ng-class="$ctrl.commentInputFocused ? 'arrow-outer-focused' : 'arrow-outer'" class="arrow-outer"></div> </div> <div class="c-textarea"> <textarea aria-label="Post a new comment" id="comment-textarea" ng-focus="$ctrl.commentInputFocused = true; $ctrl.focusedBefore = true;" ng-blur="$ctrl.commentInputFocused = false" ng-model="$ctrl.commentInput" class="f-no-resize f-scroll ng-pristine ng-untouched ng-valid ng-empty" name="textarea-default" rows="1" placeholder="Post a new comment" aria-invalid="false"></textarea> </div> </div> <div class="actions ng-hide" ng-show="$ctrl.focusedBefore &amp;&amp; !$ctrl.postCommentState.posting" aria-hidden="true"> <button type="button" class="stream-btn" ng-disabled="$ctrl.postCommentState.posting" ng-click="$ctrl.discardComment()" aria-label="Discard"> <span class="ng-binding">Discard</span> </button> <button type="button" class="stream-btn right-dialog-button ng-binding btn-primary" ng-disabled="!$ctrl.commentInput || $ctrl.postCommentState.posting" ng-click="$ctrl.postComment()" aria-label="Post" disabled="disabled"> <span class="ng-binding">Post</span> </button> </div> <!-- ngIf: $ctrl.postCommentState.posting --> </div><!-- end ngIf: $ctrl.video.userData.permissions.canComment --> <!-- ngIf: !$ctrl.video.userData.permissions.canComment --> <div class="comments-list"> <!-- ngRepeat: c in $ctrl.comments --> </div> <div class="load-more-status"> <div class="error-banner ng-hide" ng-show="$ctrl.loadMoreState.error" aria-hidden="true"> <h6 class="c-heading-6 ng-binding"></h6> </div> <!-- ngIf: $ctrl.reachedEnd --><div class="reach-end ng-scope" role="note" ng-if="$ctrl.reachedEnd" aria-label="No more comments" style=""> </div><!-- end ngIf: $ctrl.reachedEnd --> <!-- ngIf: !$ctrl.reachedEnd --> </div> </div> </div></comments> </div> </div><!-- end ngIf: $ctrl.isCompletedOnLoad && !$ctrl.isVODLess --> <!-- ngIf: $ctrl.showMetadata --><div id="related-videos-container-for-small-screen" class="related-video-container column xsmall-12 small-6 medium-6 large-12 ng-scope" ng-if="$ctrl.showMetadata"> <!-- ngIf: $ctrl.isCompletedOnLoad --><!-- end ngIf: $ctrl.isCompletedOnLoad --> </div><!-- end ngIf: $ctrl.showMetadata --> </div> <div id="related-videos-container-for-big-screen" class="column medium-4 large-4" style="margin-top: 0px;"> <div id="related-videos" ng-if="$ctrl.isCompletedOnLoad" class="ng-scope"> <!-- ngIf: $ctrl.video && !$ctrl.isWatchList --><related-videos video="$ctrl.video" ng-if="$ctrl.video &amp;&amp; !$ctrl.isWatchList" secondary-related-video-clicked="$ctrl.secondaryRelatedVideosClicked()" related-video-clicked="$ctrl.relatedVideosClicked(value)" related-videos-list="$ctrl.getListOfChannelVideos(value)" auto-play-toggle-status="$ctrl.getAutoPlayToggleStatus(status)" class="ng-scope ng-isolate-scope"><div class="related-videos list-style"> <!-- ngIf: $ctrl.relatedVideos.length && $ctrl.hideRelatedVideoDiv() --><div class="primary-related-videos ng-scope" ng-if="$ctrl.relatedVideos.length &amp;&amp; $ctrl.hideRelatedVideoDiv()" style=""> <h2 class="c-heading-5 related-video-label ng-binding">More from trending videos</h2> <!-- ngIf: $ctrl.showAutoPlayToggle() --> <ul class="row"> <!-- ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 0 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/06c63fed-6723-4b8c-90a4-c6a5c3865dde" ng-click="$ctrl.videoClicked()" aria-label=" Video SmarterTogether with Paul Vasington - July 23, 2020 Update, duration is 4 minutes 50 seconds, number of views is 701 " class="video-item-image-link" href="/video/06c63fed-6723-4b8c-90a4-c6a5c3865dde"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/c08c6151-b9d1-4287-bc5d-dd6f0b55519d/MS1mcHg0bm1lN29hejJ2ZGU2cnZlcGxjZGhwZV8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=KwUdNSrcZRAUjJcEKl8ArUe%2fNjtX3P0EBROJ01QmbNQ%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/c08c6151-b9d1-4287-bc5d-dd6f0b55519d/MS1mcHg0bm1lN29hejJ2ZGU2cnZlcGxjZGhwZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=3URQY8uoOcQj4s8YpZXK%2fffzaITTR4%2f1RPCKylMVPpk%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/c08c6151-b9d1-4287-bc5d-dd6f0b55519d/MS1mcHg0bm1lN29hejJ2ZGU2cnZlcGxjZGhwZV8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=TFluZTsxbEcUHlvd%2fAIDNLfs9Nw%2fTrejQqgr5DVIKlo%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/c08c6151-b9d1-4287-bc5d-dd6f0b55519d/MS1mcHg0bm1lN29hejJ2ZGU2cnZlcGxjZGhwZV8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fFLMb12SoIjqab530w7RKnntHzF2jMOC%2fhnCz7zZh0w%3d&quot;}}" alt="SmarterTogether with Paul Vasington - July 23, 2020 Update" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/c08c6151-b9d1-4287-bc5d-dd6f0b55519d/MS1mcHg0bm1lN29hejJ2ZGU2cnZlcGxjZGhwZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=3URQY8uoOcQj4s8YpZXK%2fffzaITTR4%2f1RPCKylMVPpk%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 04:50 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="SmarterTogether with Paul Vasington - July 23, 2020 Update" light-style="true" on-ellipsis-only="true"> SmarterTogether with Paul Vasington - July 23, 2020 Update </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 701 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 1 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/f8d4b791-9efe-4a03-9cff-fd8efbf97c92" ng-click="$ctrl.videoClicked()" aria-label=" Video Sensata COVID-19 Public Service Announcement, duration is 2 minutes 34 seconds, number of views is 871 " class="video-item-image-link" href="/video/f8d4b791-9efe-4a03-9cff-fd8efbf97c92"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8ef52c4b-3499-4cf9-a085-efddc3b4596a/Yzk3MzM0NTktNmQ0OC00NmZiLTg1YmYtOGUzOWFlOTI3NGQ4LXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=001TFfnfst7hTyI2MRQ7oryaBZQ2HlUR6Jykjm6d97c%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8ef52c4b-3499-4cf9-a085-efddc3b4596a/Yzk3MzM0NTktNmQ0OC00NmZiLTg1YmYtOGUzOWFlOTI3NGQ4LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=IoNltM8Ku64RS0tkLapS4B%2fPd0t1YVPJ8Mfr4UtdSHU%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8ef52c4b-3499-4cf9-a085-efddc3b4596a/Yzk3MzM0NTktNmQ0OC00NmZiLTg1YmYtOGUzOWFlOTI3NGQ4LXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=TmBiBC3E%2bzSyyjSWpJPi4MTD37UEC4z6%2bmgnmLDfVj0%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8ef52c4b-3499-4cf9-a085-efddc3b4596a/Yzk3MzM0NTktNmQ0OC00NmZiLTg1YmYtOGUzOWFlOTI3NGQ4LXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=jPYGFmQNXtdLXAJFtQjYS9VEJeX5mrT2LrjiADhJqw0%3d&quot;}}" alt="Sensata COVID-19 Public Service Announcement" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8ef52c4b-3499-4cf9-a085-efddc3b4596a/Yzk3MzM0NTktNmQ0OC00NmZiLTg1YmYtOGUzOWFlOTI3NGQ4LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=IoNltM8Ku64RS0tkLapS4B%2fPd0t1YVPJ8Mfr4UtdSHU%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 02:34 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Sensata COVID-19 Public Service Announcement" light-style="true" on-ellipsis-only="true"> Sensata COVID-19 Public Service Announcement </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 871 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 2 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/90163e75-101b-4223-8fcf-bb4a29e68989" ng-click="$ctrl.videoClicked()" aria-label=" Video Global Sales Recognition Event, duration is 42 minutes 1 second, number of views is 52 " class="video-item-image-link" href="/video/90163e75-101b-4223-8fcf-bb4a29e68989"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/9b730d73-1820-4808-9543-bac24bdf4e97/MS1ndmh4Y2t0bG9kc2picGVoZ3BraXFrNmRtaF8yXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=dko4htzgJIHOhd5VSRvv0rP751niFrrFWD4ysHEbuiU%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/9b730d73-1820-4808-9543-bac24bdf4e97/MS1ndmh4Y2t0bG9kc2picGVoZ3BraXFrNmRtaF8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=cZVA9wv%2bxPmjx6zoQUYXpfFiBDR6Om%2fCZyc2d%2fuAcZs%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/9b730d73-1820-4808-9543-bac24bdf4e97/MS1ndmh4Y2t0bG9kc2picGVoZ3BraXFrNmRtaF8yXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=5fmyuj9FZQROxdW9EPiCIHj5Pb4wvxBf%2f6hxSERD1q8%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/9b730d73-1820-4808-9543-bac24bdf4e97/MS1ndmh4Y2t0bG9kc2picGVoZ3BraXFrNmRtaF8yXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=tby8X7qPqWwVdkcE5d1GnklmYuzoFlzdx8qD4BhfAz4%3d&quot;}}" alt="Global Sales Recognition Event" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/9b730d73-1820-4808-9543-bac24bdf4e97/MS1ndmh4Y2t0bG9kc2picGVoZ3BraXFrNmRtaF8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=cZVA9wv%2bxPmjx6zoQUYXpfFiBDR6Om%2fCZyc2d%2fuAcZs%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 42:01 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Global Sales Recognition Event" light-style="true" on-ellipsis-only="true"> Global Sales Recognition Event </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 52 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 3 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/8cbe9a33-8504-491b-b42b-fd11fb7eeb70" ng-click="$ctrl.videoClicked()" aria-label=" Video ¿Por qué es importante para ti prevenir el COVID-19?, duration is 1 minute 37 seconds, number of views is 61 " class="video-item-image-link" href="/video/8cbe9a33-8504-491b-b42b-fd11fb7eeb70"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/eed2cd84-0161-4821-9d6b-963aab5081fa/MS11Z2dkYjdlMjRnYjVxZHN0c2pyNWZkN29yYl8yXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=jG3xrEDNBLeKSkkbSJtxgjhlZGuOScoIZHFGA7qi83Q%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/eed2cd84-0161-4821-9d6b-963aab5081fa/MS11Z2dkYjdlMjRnYjVxZHN0c2pyNWZkN29yYl8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=nA4q4Tkd2JCBvJbla4B4G65OtpcU%2b%2bvRKTatdDBM6zI%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/eed2cd84-0161-4821-9d6b-963aab5081fa/MS11Z2dkYjdlMjRnYjVxZHN0c2pyNWZkN29yYl8yXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=gDZQKKM%2bB8XvI20W2mmlB6jeKvpixtbaxb4mFdamXLs%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/eed2cd84-0161-4821-9d6b-963aab5081fa/MS11Z2dkYjdlMjRnYjVxZHN0c2pyNWZkN29yYl8yXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fPXDmhFKbBbG10pcFJRV1VY%2bDeMcF7iKkreKuM%2bBuNI%3d&quot;}}" alt="¿Por qué es importante para ti prevenir el COVID-19?" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/eed2cd84-0161-4821-9d6b-963aab5081fa/MS11Z2dkYjdlMjRnYjVxZHN0c2pyNWZkN29yYl8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=nA4q4Tkd2JCBvJbla4B4G65OtpcU%2b%2bvRKTatdDBM6zI%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 01:37 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="¿Por qué es importante para ti prevenir el COVID-19?" light-style="true" on-ellipsis-only="true"> ¿Por qué es importante para ti prevenir el COVID-19? </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 61 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 4 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/a8e74ddd-8241-4aea-b5b3-ac00719bab9b" ng-click="$ctrl.videoClicked()" aria-label=" Video SmarterTogether with Jeff Cote - July 9, 2020 Update, duration is 3 minutes 31 seconds, number of views is 1136 " class="video-item-image-link" href="/video/a8e74ddd-8241-4aea-b5b3-ac00719bab9b"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/455822ac-a5f4-4839-8b9d-89ef7f0ade89/MS02ZW9veHlmdWJneG5xZWRsNXVheWdheGNiZV8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ty6Eu98yjhXkYdjB2wPNwgssCskw5LlwM%2frdCBdpDlA%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/455822ac-a5f4-4839-8b9d-89ef7f0ade89/MS02ZW9veHlmdWJneG5xZWRsNXVheWdheGNiZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=NE%2bk%2bTFGV7%2ftmqAN8zSFBQ8WSwEo5A%2fHhzVvfUWxZVA%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/455822ac-a5f4-4839-8b9d-89ef7f0ade89/MS02ZW9veHlmdWJneG5xZWRsNXVheWdheGNiZV8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=3%2fqwH8frvYkl8thFLiPAHPDIANaL%2f%2bRK035BwdVVJ8E%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/455822ac-a5f4-4839-8b9d-89ef7f0ade89/MS02ZW9veHlmdWJneG5xZWRsNXVheWdheGNiZV8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=In1hYj4ITMwOAG1WVZYphdgok7yJZy7XIFfTZ6dVYCg%3d&quot;}}" alt="SmarterTogether with Jeff Cote - July 9, 2020 Update" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/455822ac-a5f4-4839-8b9d-89ef7f0ade89/MS02ZW9veHlmdWJneG5xZWRsNXVheWdheGNiZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=NE%2bk%2bTFGV7%2ftmqAN8zSFBQ8WSwEo5A%2fHhzVvfUWxZVA%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 03:31 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="SmarterTogether with Jeff Cote - July 9, 2020 Update" light-style="true" on-ellipsis-only="true"> SmarterTogether with Jeff Cote - July 9, 2020 Update </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 1,136 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 5 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/0a80e96e-0075-44c4-8df9-74ce52557e52" ng-click="$ctrl.videoClicked()" aria-label=" Video Global Safety - Returning to the Workplace (E), duration is 19 minutes 48 seconds, number of views is 99 " class="video-item-image-link" href="/video/0a80e96e-0075-44c4-8df9-74ce52557e52"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/0ce5c543-f1a6-4f6c-8b5f-fc4a75d9b6c2/MS1ra2p2dWxtNmt2b3l6N3hjbXBjNDM2MnZsZV8xXzg2eDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=FPnrb8FE09T0to7aCDhcedlH5wiv6bMaXEzNf1lIJls%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/0ce5c543-f1a6-4f6c-8b5f-fc4a75d9b6c2/MS1ra2p2dWxtNmt2b3l6N3hjbXBjNDM2MnZsZV8xXzE3Mng5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=NWihocEQY8yiONHugZL%2bhNYml6J6AEfBZjRG30qmdQY%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/0ce5c543-f1a6-4f6c-8b5f-fc4a75d9b6c2/MS1ra2p2dWxtNmt2b3l6N3hjbXBjNDM2MnZsZV8xXzM0NHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=EEN%2bczM8J2MxT9jUICKhscRtqs6h55rFyUDqk%2fIQs0M%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/0ce5c543-f1a6-4f6c-8b5f-fc4a75d9b6c2/MS1ra2p2dWxtNmt2b3l6N3hjbXBjNDM2MnZsZV8xXzY4OHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=J0r64bJUfX31MIm2OvHPnSqBTivaVWq1z04A7Ax2m70%3d&quot;}}" alt="Global Safety - Returning to the Workplace (E)" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/0ce5c543-f1a6-4f6c-8b5f-fc4a75d9b6c2/MS1ra2p2dWxtNmt2b3l6N3hjbXBjNDM2MnZsZV8xXzE3Mng5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=NWihocEQY8yiONHugZL%2bhNYml6J6AEfBZjRG30qmdQY%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 19:48 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Global Safety - Returning to the Workplace (E)" light-style="true" on-ellipsis-only="true"> Global Safety - Returning to the Workplace (E) </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 99 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 6 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/eadc8a88-d71d-4a40-8331-31c3a875c8de" ng-click="$ctrl.videoClicked()" aria-label=" Video Donación equipo médico, duration is 1 minute 48 seconds, number of views is 149 " class="video-item-image-link" href="/video/eadc8a88-d71d-4a40-8331-31c3a875c8de"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cf970933-54ee-40cb-ab74-32ee3d399139/MS1meXhhaWJwazdka29vZWlpaGttcHNvcXFjZ18xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=QaiXoWsw6KMszY5XUlJJk5NEj1tIUToKd0Z0m5maLDg%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cf970933-54ee-40cb-ab74-32ee3d399139/MS1meXhhaWJwazdka29vZWlpaGttcHNvcXFjZ18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fLYCAevntng8LiXsAQ6EBvOqPVyV12Ug08K%2bNetIvOQ%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cf970933-54ee-40cb-ab74-32ee3d399139/MS1meXhhaWJwazdka29vZWlpaGttcHNvcXFjZ18xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=40QcrQr56de8bWS8RDKP2QJDhGrUKi8KfSnPVyQjUmU%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cf970933-54ee-40cb-ab74-32ee3d399139/MS1meXhhaWJwazdka29vZWlpaGttcHNvcXFjZ18xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=5jHyIf1N8CB54ap%2f52qxOzxHq78rEWNs0%2bsEAUdDJo0%3d&quot;}}" alt="Donación equipo médico" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cf970933-54ee-40cb-ab74-32ee3d399139/MS1meXhhaWJwazdka29vZWlpaGttcHNvcXFjZ18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fLYCAevntng8LiXsAQ6EBvOqPVyV12Ug08K%2bNetIvOQ%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 01:48 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Donación equipo médico" light-style="true" on-ellipsis-only="true"> Donación equipo médico </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 149 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 7 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/f44d2459-2c86-43e5-a6b7-5dcf10b55722" ng-click="$ctrl.videoClicked()" aria-label=" Video SmarterTogether with Hans Lidforss - July 2, 2020 Update, duration is 3 minutes 49 seconds, number of views is 963 " class="video-item-image-link" href="/video/f44d2459-2c86-43e5-a6b7-5dcf10b55722"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/b2e0a692-a0c7-4d75-992c-9b5c61e3f168/MS16dGl6bW90a2RrbXB4d25vM2ZqdzZmdWFnZ18xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=O7eo1mXEU1KYkWZ6%2buY4Pyiy6hkWDTigHWN51NouiTY%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/b2e0a692-a0c7-4d75-992c-9b5c61e3f168/MS16dGl6bW90a2RrbXB4d25vM2ZqdzZmdWFnZ18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bKOhiwNzUs%2btNgmTl1mXruRBmKo70eQEq5TPJg4ZKz8%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/b2e0a692-a0c7-4d75-992c-9b5c61e3f168/MS16dGl6bW90a2RrbXB4d25vM2ZqdzZmdWFnZ18xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=hhYk1HWmqZAW8BWdeA4nVDBdSR575TsYNGQx6rwtE1w%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/b2e0a692-a0c7-4d75-992c-9b5c61e3f168/MS16dGl6bW90a2RrbXB4d25vM2ZqdzZmdWFnZ18xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Ark7swCXm4EiRbbQ0XStORvRsW4qWBMaVB9ampWG9Vo%3d&quot;}}" alt="SmarterTogether with Hans Lidforss - July 2, 2020 Update" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/b2e0a692-a0c7-4d75-992c-9b5c61e3f168/MS16dGl6bW90a2RrbXB4d25vM2ZqdzZmdWFnZ18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bKOhiwNzUs%2btNgmTl1mXruRBmKo70eQEq5TPJg4ZKz8%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 03:49 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="SmarterTogether with Hans Lidforss - July 2, 2020 Update" light-style="true" on-ellipsis-only="true"> SmarterTogether with Hans Lidforss - July 2, 2020 Update </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 963 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 8 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/8f44d3ac-71d2-417b-9ded-7eeab4ddef12" ng-click="$ctrl.videoClicked()" aria-label=" Video ISO 14001 2020 (ags), duration is 9 minutes 40 seconds, number of views is 14 " class="video-item-image-link" href="/video/8f44d3ac-71d2-417b-9ded-7eeab4ddef12"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/a5658b80-2cda-47f1-91f2-2234585af571/MS03Mmh1dWNlaDRld2NkcnpmdjRkNWpqbDdmZV8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=djfltgSS4y3zaeJTNQMlHwAPtKxJx%2b%2bkhDoSrU8HuOg%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/a5658b80-2cda-47f1-91f2-2234585af571/MS03Mmh1dWNlaDRld2NkcnpmdjRkNWpqbDdmZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=k9bJL4ZHBAdV%2bvfgEt9pHOigoNNTyFwgKuHoGhvK9Rw%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/a5658b80-2cda-47f1-91f2-2234585af571/MS03Mmh1dWNlaDRld2NkcnpmdjRkNWpqbDdmZV8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=fRqPtojNxt7Hy0ufYiRKcjDcabTzoqOQfROzUtoqr4U%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/a5658b80-2cda-47f1-91f2-2234585af571/MS03Mmh1dWNlaDRld2NkcnpmdjRkNWpqbDdmZV8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bxoR61IXPkHU8kNd2H9THjLID8%2b2Us4uLTFYmrhF02A%3d&quot;}}" alt="ISO 14001 2020 (ags)" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/a5658b80-2cda-47f1-91f2-2234585af571/MS03Mmh1dWNlaDRld2NkcnpmdjRkNWpqbDdmZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=k9bJL4ZHBAdV%2bvfgEt9pHOigoNNTyFwgKuHoGhvK9Rw%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 09:40 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="ISO 14001 2020 (ags)" light-style="true" on-ellipsis-only="true"> ISO 14001 2020 (ags) </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 14 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 9 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/5c392656-fbc3-4c10-9c14-8a62c0af200d" ng-click="$ctrl.videoClicked()" aria-label=" Video Sensata EVP Video 2018 - English No Captions, duration is 1 minute 19 seconds, number of views is 61 " class="video-item-image-link" href="/video/5c392656-fbc3-4c10-9c14-8a62c0af200d"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/cc7687ff-48c6-44ff-8fc6-aa45a684800f/NGQ3ZjAwZjAtY2NjOS00YjdhLWI1ZDQtNWE4MjY1NmNfMV84MHg0NS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=hwoIdsDHL8xJU1QipVXG165qEVC4vHvu7vE85U1E8ig%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/cc7687ff-48c6-44ff-8fc6-aa45a684800f/NGQ3ZjAwZjAtY2NjOS00YjdhLWI1ZDQtNWE4MjY1NmNfMV8xNjB4OTAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bvNR5Q%2fdzs8phKC39m%2fIpzeHLcMEUFIetjCuLYrgQhI%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/cc7687ff-48c6-44ff-8fc6-aa45a684800f/NGQ3ZjAwZjAtY2NjOS00YjdhLWI1ZDQtNWE4MjY1NmNfMV8zMjB4MTgwLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=OiH25XxkVF8orv229ex%2fbPYTwqHAQVJO4wgPMqgKYZA%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/cc7687ff-48c6-44ff-8fc6-aa45a684800f/NGQ3ZjAwZjAtY2NjOS00YjdhLWI1ZDQtNWE4MjY1NmNfMV82NDB4MzYwLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Peyhj%2b210X3efvuEc%2fUZC5hcBX94YhiDBwn%2bNKqsquY%3d&quot;}}" alt="Sensata EVP Video 2018 - English No Captions" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/cc7687ff-48c6-44ff-8fc6-aa45a684800f/NGQ3ZjAwZjAtY2NjOS00YjdhLWI1ZDQtNWE4MjY1NmNfMV8xNjB4OTAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bvNR5Q%2fdzs8phKC39m%2fIpzeHLcMEUFIetjCuLYrgQhI%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 01:19 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Sensata EVP Video 2018 - English No Captions" light-style="true" on-ellipsis-only="true"> Sensata EVP Video 2018 - English No Captions </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 61 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 10 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/1334f10f-227a-4776-a56b-8c79b4c2f912" ng-click="$ctrl.videoClicked()" aria-label=" Video ESD 2020, duration is 9 minutes 22 seconds, number of views is 4 " class="video-item-image-link" href="/video/1334f10f-227a-4776-a56b-8c79b4c2f912"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b64a0452-fca0-4282-8724-79a2512202e9/MS1ma2l0a3FmaDN6azRubWw2czY0bHMzaWp5ZV8xXzYweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=lttgLQZRrrF6%2bekCbsj2RCzrE7Z1GJDPBaKlUHcHcEs%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b64a0452-fca0-4282-8724-79a2512202e9/MS1ma2l0a3FmaDN6azRubWw2czY0bHMzaWp5ZV8xXzEyMHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=SRmjC4HsvPvKq22bjHu5HHCWTXpfUG6ZANLmc39PY%2fY%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b64a0452-fca0-4282-8724-79a2512202e9/MS1ma2l0a3FmaDN6azRubWw2czY0bHMzaWp5ZV8xXzI0MHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=mNK%2fsMfv9bhuH1eXRfZvwjctQoXOieWT8wwLQe7XFZ4%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b64a0452-fca0-4282-8724-79a2512202e9/MS1ma2l0a3FmaDN6azRubWw2czY0bHMzaWp5ZV8xXzQ4MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=NGWGIc8YpCFEDXP1PIyeNIVfWLyp5hR90sqxLNkPgd4%3d&quot;}}" alt="ESD 2020" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b64a0452-fca0-4282-8724-79a2512202e9/MS1ma2l0a3FmaDN6azRubWw2czY0bHMzaWp5ZV8xXzEyMHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=SRmjC4HsvPvKq22bjHu5HHCWTXpfUG6ZANLmc39PY%2fY%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 09:22 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="ESD 2020" light-style="true" on-ellipsis-only="true"> ESD 2020 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 4 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 11 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/2163c359-4ad9-407c-baea-6dc1455b6d15" ng-click="$ctrl.videoClicked()" aria-label=" Video EU RTC 2020 Session 1, duration is 2 hours 22 minutes 14 seconds, number of views is 7 " class="video-item-image-link" href="/video/2163c359-4ad9-407c-baea-6dc1455b6d15"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8261e38d-eea7-4c64-b9c0-ffad3602d36f/NzYxMDc0YTYtMzI3My00MDA3LTk2NjUtODg5ZWE3ZGY1NGM3LXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=nX1PuTjtbiBywb8yk7KS9l5LlZxy%2fIqvPvJC8nQYMPU%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8261e38d-eea7-4c64-b9c0-ffad3602d36f/NzYxMDc0YTYtMzI3My00MDA3LTk2NjUtODg5ZWE3ZGY1NGM3LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=q05mXzH8rg%2fGAbl8O4%2bwX8DPBw1RFe4oNn%2fcKL50i%2fY%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8261e38d-eea7-4c64-b9c0-ffad3602d36f/NzYxMDc0YTYtMzI3My00MDA3LTk2NjUtODg5ZWE3ZGY1NGM3LXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=A4Sft7FlOdv8sGI8wFBi064gfxYHJfBzkVe%2fh0JVdnU%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8261e38d-eea7-4c64-b9c0-ffad3602d36f/NzYxMDc0YTYtMzI3My00MDA3LTk2NjUtODg5ZWE3ZGY1NGM3LXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=MgWu5%2fCYv2l0RRqQvvz%2b0P4%2f1wGBXKV0DgiVjMlj1xA%3d&quot;}}" alt="EU RTC 2020 Session 1" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/8261e38d-eea7-4c64-b9c0-ffad3602d36f/NzYxMDc0YTYtMzI3My00MDA3LTk2NjUtODg5ZWE3ZGY1NGM3LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=q05mXzH8rg%2fGAbl8O4%2bwX8DPBw1RFe4oNn%2fcKL50i%2fY%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 02:22:14 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="EU RTC 2020 Session 1" light-style="true" on-ellipsis-only="true"> EU RTC 2020 Session 1 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 7 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 12 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/a46d108a-9484-4b6e-b2f8-fe33ff664f3c" ng-click="$ctrl.videoClicked()" aria-label=" Video Laser Weld, duration is 41 minutes 17 seconds, number of views is 12 " class="video-item-image-link" href="/video/a46d108a-9484-4b6e-b2f8-fe33ff664f3c"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/7e480306-4006-4f80-b81b-b64854c261fa/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=UGOGjvM1391oWeGFGx7lzd4yQxWN6wgjCbNV3dXckqA%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/7e480306-4006-4f80-b81b-b64854c261fa/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=axIgq02iMGfJOTF3Yuez%2ftRgq54eBPCTp7JYnDjE%2bUU%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/7e480306-4006-4f80-b81b-b64854c261fa/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=0hhc2jFSGUFh%2fcVun%2f2zeTQZcu9IBFT2nvTjxwaHzZg%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/7e480306-4006-4f80-b81b-b64854c261fa/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=J9Ihy2zACCDPDMgtz3sSzlavkgUiZoPb4Eo6KTJN7cI%3d&quot;}}" alt="Laser Weld" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/7e480306-4006-4f80-b81b-b64854c261fa/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=axIgq02iMGfJOTF3Yuez%2ftRgq54eBPCTp7JYnDjE%2bUU%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 41:17 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Laser Weld" light-style="true" on-ellipsis-only="true"> Laser Weld </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 12 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 13 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/f7ff56e5-e5a0-4966-878a-e46a3adbbcdf" ng-click="$ctrl.videoClicked()" aria-label=" Video 2018 Leadership Summit - Office of the CTO Update, duration is 45 minutes 44 seconds, number of views is 455 " class="video-item-image-link" href="/video/f7ff56e5-e5a0-4966-878a-e46a3adbbcdf"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/a0ed2930-69ca-469b-8f5b-4133e64bdf3b/OTQ3NDMzMDgtMWRhYS00YWQ0LWFiZTYtNjM1ZDAzMGYxZDlmLXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2bHySeHnbKCEC4b1rUqA1E4Z9Q1zH6wu8sTVW%2bR3rhyI%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/a0ed2930-69ca-469b-8f5b-4133e64bdf3b/OTQ3NDMzMDgtMWRhYS00YWQ0LWFiZTYtNjM1ZDAzMGYxZDlmLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=LvjOBfl7%2fv8bVMBHpyEK%2b916JqZcr15F%2bMDDQ3slmt0%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/a0ed2930-69ca-469b-8f5b-4133e64bdf3b/OTQ3NDMzMDgtMWRhYS00YWQ0LWFiZTYtNjM1ZDAzMGYxZDlmLXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=UfwRm9lta5W7xGjP%2fjcS5ny8Wytw0kFXRAcUrRzLP3E%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/a0ed2930-69ca-469b-8f5b-4133e64bdf3b/OTQ3NDMzMDgtMWRhYS00YWQ0LWFiZTYtNjM1ZDAzMGYxZDlmLXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=MrZhvx2daLIECs%2fLk2OwowmTx03KQT58ejKWgKqUtSI%3d&quot;}}" alt="2018 Leadership Summit - Office of the CTO Update" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/a0ed2930-69ca-469b-8f5b-4133e64bdf3b/OTQ3NDMzMDgtMWRhYS00YWQ0LWFiZTYtNjM1ZDAzMGYxZDlmLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=LvjOBfl7%2fv8bVMBHpyEK%2b916JqZcr15F%2bMDDQ3slmt0%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 45:44 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="2018 Leadership Summit - Office of the CTO Update" light-style="true" on-ellipsis-only="true"> 2018 Leadership Summit - Office of the CTO Update </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 455 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 14 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/d0e5a0fd-d8f0-4b10-9185-bb35a079f938" ng-click="$ctrl.videoClicked()" aria-label=" Video Curso ITE, duration is 2 minutes 23 seconds, number of views is 10 " class="video-item-image-link" href="/video/d0e5a0fd-d8f0-4b10-9185-bb35a079f938"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cbe691fc-3a29-435c-8419-6be639e784f4/MS1iaWtjaG13Ymg3NGlxaWFteGZlZGZiNmFuYV8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=9msOpL6osWnT59iLyMde6pXKEdktLQS2FO9RzUkoloI%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cbe691fc-3a29-435c-8419-6be639e784f4/MS1iaWtjaG13Ymg3NGlxaWFteGZlZGZiNmFuYV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=vybcF2LjWbXFdD5VKG9RonheQpyMsJdhHu%2fbRIepK8M%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cbe691fc-3a29-435c-8419-6be639e784f4/MS1iaWtjaG13Ymg3NGlxaWFteGZlZGZiNmFuYV8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=m%2b9y5KN7g%2bOUA9V%2fpsRCS9e5X6vvIs23DZ5t8AJaTJ8%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cbe691fc-3a29-435c-8419-6be639e784f4/MS1iaWtjaG13Ymg3NGlxaWFteGZlZGZiNmFuYV8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=8ejVqwNigetXC257uPlNCKhNZLY3hZUd0w8GPkisFa4%3d&quot;}}" alt="Curso ITE" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/cbe691fc-3a29-435c-8419-6be639e784f4/MS1iaWtjaG13Ymg3NGlxaWFteGZlZGZiNmFuYV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=vybcF2LjWbXFdD5VKG9RonheQpyMsJdhHu%2fbRIepK8M%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 02:23 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Curso ITE" light-style="true" on-ellipsis-only="true"> Curso ITE </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 10 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 15 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/6539dcb1-ef02-45a7-ba8d-c61e1e05d296" ng-click="$ctrl.videoClicked()" aria-label=" Video EU RTC 2020 Session 2, duration is 3 hours 5 minutes 8 seconds, number of views is 2 " class="video-item-image-link" href="/video/6539dcb1-ef02-45a7-ba8d-c61e1e05d296"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/f0e78a4b-88f6-4585-ab70-a79d751ed1da/MS1wenk2bmx3Zzd3ajMybm50NmY3eGlwZWRuZF8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=bImwv6Y%2fS1SaP%2fVFtAiHWTzhKaiaDPNgWY2Bbre%2bOeg%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/f0e78a4b-88f6-4585-ab70-a79d751ed1da/MS1wenk2bmx3Zzd3ajMybm50NmY3eGlwZWRuZF8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Mj0bs8O5ywiMKiZJVeBKTMfP%2b9RLthCi%2b%2bHuqHXQVcQ%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/f0e78a4b-88f6-4585-ab70-a79d751ed1da/MS1wenk2bmx3Zzd3ajMybm50NmY3eGlwZWRuZF8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=6pxRF8jpG22Ng7QCSEXElf4CM8kq5g3FQtTdSEkjaHQ%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/f0e78a4b-88f6-4585-ab70-a79d751ed1da/MS1wenk2bmx3Zzd3ajMybm50NmY3eGlwZWRuZF8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=AGKzYf9qXhmC4nzUcVhmpXdN%2fboILKAK11ooOsSnQ8M%3d&quot;}}" alt="EU RTC 2020 Session 2" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/f0e78a4b-88f6-4585-ab70-a79d751ed1da/MS1wenk2bmx3Zzd3ajMybm50NmY3eGlwZWRuZF8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Mj0bs8O5ywiMKiZJVeBKTMfP%2b9RLthCi%2b%2bHuqHXQVcQ%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 03:05:08 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="EU RTC 2020 Session 2" light-style="true" on-ellipsis-only="true"> EU RTC 2020 Session 2 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 2 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 16 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/877fac3c-2cd9-4b15-9ae9-747b8fde1c01" ng-click="$ctrl.videoClicked()" aria-label=" Video EU RTC 2020 Session 4, duration is 3 hours 2 minutes 2 seconds, number of views is 2 " class="video-item-image-link" href="/video/877fac3c-2cd9-4b15-9ae9-747b8fde1c01"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/3f62880b-3cae-4af9-9d09-86014d581a6d/MS13M3UydnNiamt0bG1vZjZsb3FkZzI0MzdvaF8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=wX8qMeLhjSPuMMZnSFhtYGGWk%2fGfzSd9JV5uI0ELIgY%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/3f62880b-3cae-4af9-9d09-86014d581a6d/MS13M3UydnNiamt0bG1vZjZsb3FkZzI0MzdvaF8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=lmmOw39UXgRhq%2fv4bdwss4KAKQsNsxBCE%2bRqjIZ1CHg%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/3f62880b-3cae-4af9-9d09-86014d581a6d/MS13M3UydnNiamt0bG1vZjZsb3FkZzI0MzdvaF8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=gb42GgmuD0qn0rngbc2FmNc0AQqNLWsHMlRMtT00nDU%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/3f62880b-3cae-4af9-9d09-86014d581a6d/MS13M3UydnNiamt0bG1vZjZsb3FkZzI0MzdvaF8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=AjoFbGkkw%2bdZQZWFseb1dGaA44uB7yWeH0NPrUtgJlI%3d&quot;}}" alt="EU RTC 2020 Session 4" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/3f62880b-3cae-4af9-9d09-86014d581a6d/MS13M3UydnNiamt0bG1vZjZsb3FkZzI0MzdvaF8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=lmmOw39UXgRhq%2fv4bdwss4KAKQsNsxBCE%2bRqjIZ1CHg%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 03:02:02 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="EU RTC 2020 Session 4" light-style="true" on-ellipsis-only="true"> EU RTC 2020 Session 4 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 2 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 17 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/da2a2168-3a35-4b91-b27f-260479c704f5" ng-click="$ctrl.videoClicked()" aria-label=" Video Modulo 1 Entrenamiento en soldadura 2020, duration is 7 minutes 6 seconds, number of views is 3 " class="video-item-image-link" href="/video/da2a2168-3a35-4b91-b27f-260479c704f5"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/bc2c88f6-ba13-4ce7-8e07-79f21e7982ff/MS02NXltaDRlNW9iNTJvbG9vdXlyaGc2Y3VsZl8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ZpmbSc99MHzN2AeOLz2mpo%2b52kSHoR4BOHWq2rqHAiM%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/bc2c88f6-ba13-4ce7-8e07-79f21e7982ff/MS02NXltaDRlNW9iNTJvbG9vdXlyaGc2Y3VsZl8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=KKBCnuKeD9mUd3QiXb0AZ7gbO4d2RDY8JTq9B3oGe0g%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/bc2c88f6-ba13-4ce7-8e07-79f21e7982ff/MS02NXltaDRlNW9iNTJvbG9vdXlyaGc2Y3VsZl8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=UVcnTLoWpd3cWyjK5N%2fEa1rwsfWCUgR5JaON9nV8meM%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/bc2c88f6-ba13-4ce7-8e07-79f21e7982ff/MS02NXltaDRlNW9iNTJvbG9vdXlyaGc2Y3VsZl8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=9oue2LQQe9YNNFdMSk1IFhZRPkZC3mnIDs6%2f8ElVPfs%3d&quot;}}" alt="Modulo 1 Entrenamiento en soldadura 2020" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/bc2c88f6-ba13-4ce7-8e07-79f21e7982ff/MS02NXltaDRlNW9iNTJvbG9vdXlyaGc2Y3VsZl8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=KKBCnuKeD9mUd3QiXb0AZ7gbO4d2RDY8JTq9B3oGe0g%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 07:06 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Modulo 1 Entrenamiento en soldadura 2020" light-style="true" on-ellipsis-only="true"> Modulo 1 Entrenamiento en soldadura 2020 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 3 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 18 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/c822f2e4-4d01-4e60-b379-91682d84fc1e" ng-click="$ctrl.videoClicked()" aria-label=" Video Teams Training -May 15, duration is 59 minutes 54 seconds, number of views is 255 " class="video-item-image-link" href="/video/c822f2e4-4d01-4e60-b379-91682d84fc1e"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/c2e2788b-1f9a-45fa-ad1d-bf494ea42e1d/NjM4OGMwMzItZjQ1Mi00OTA3LTkzYjUtMWQxYTI3NTFjNWE4LXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Day5xO2IIXdY8TBPMAhqtrsUgE6FfUIL4jzg7Km2JtE%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/c2e2788b-1f9a-45fa-ad1d-bf494ea42e1d/NjM4OGMwMzItZjQ1Mi00OTA3LTkzYjUtMWQxYTI3NTFjNWE4LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fqoMDkRqB1KMi5QWrzsHS2RN67flmxzywn5%2b%2bwBJM9E%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/c2e2788b-1f9a-45fa-ad1d-bf494ea42e1d/NjM4OGMwMzItZjQ1Mi00OTA3LTkzYjUtMWQxYTI3NTFjNWE4LXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Hq%2bm1HOVz85swhhgmIJHYZyFtRapDMefkXAHMUaSXg0%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/c2e2788b-1f9a-45fa-ad1d-bf494ea42e1d/NjM4OGMwMzItZjQ1Mi00OTA3LTkzYjUtMWQxYTI3NTFjNWE4LXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=HD0sC%2fo9%2ftzy%2fqF%2bCCLz7lsUy5zou%2fuf6kaCHGhu4TQ%3d&quot;}}" alt="Teams Training -May 15" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/c2e2788b-1f9a-45fa-ad1d-bf494ea42e1d/NjM4OGMwMzItZjQ1Mi00OTA3LTkzYjUtMWQxYTI3NTFjNWE4LXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=%2fqoMDkRqB1KMi5QWrzsHS2RN67flmxzywn5%2b%2bwBJM9E%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 59:54 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Teams Training -May 15" light-style="true" on-ellipsis-only="true"> Teams Training -May 15 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 255 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 19 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/4edcf7ba-9805-4eab-8b0d-7eaf9cf6f023" ng-click="$ctrl.videoClicked()" aria-label=" Video STOP 2020 (Ags), duration is 11 minutes 57 seconds, number of views is 4 " class="video-item-image-link" href="/video/4edcf7ba-9805-4eab-8b0d-7eaf9cf6f023"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b7e48cbb-82b2-43db-b66f-df8c89720243/MS1qcXRtbTJna2Zsa3RlYm9hdzZvM295ZmhpZV8xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=uY69ECd5Rf9tlXa61wr8JmeXE4eJVRFmdhkJJfRqTRI%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b7e48cbb-82b2-43db-b66f-df8c89720243/MS1qcXRtbTJna2Zsa3RlYm9hdzZvM295ZmhpZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=PcdvZVetvjYqaBZ6R8nm2uWtvwn24vdQvBtVKd1o%2bbU%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b7e48cbb-82b2-43db-b66f-df8c89720243/MS1qcXRtbTJna2Zsa3RlYm9hdzZvM295ZmhpZV8xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=La5cXcFNocNM5TwyKwgYU%2fcBBjZLeo6gBS3nadDHUZs%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b7e48cbb-82b2-43db-b66f-df8c89720243/MS1qcXRtbTJna2Zsa3RlYm9hdzZvM295ZmhpZV8xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ocCtwrxMP%2b1oAnwQc3lkPu1Tr4XyfpSb%2fkA4aPgcG%2fY%3d&quot;}}" alt="STOP 2020 (Ags)" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/b7e48cbb-82b2-43db-b66f-df8c89720243/MS1qcXRtbTJna2Zsa3RlYm9hdzZvM295ZmhpZV8xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=PcdvZVetvjYqaBZ6R8nm2uWtvwn24vdQvBtVKd1o%2bbU%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 11:57 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="STOP 2020 (Ags)" light-style="true" on-ellipsis-only="true"> STOP 2020 (Ags) </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 4 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 20 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/79329eff-2a3b-4312-8e6d-a0e3bca9902f" ng-click="$ctrl.videoClicked()" aria-label=" Video Si compartes comida, compartes el virus., duration is 0 minutes 52 seconds, number of views is 55 " class="video-item-image-link" href="/video/79329eff-2a3b-4312-8e6d-a0e3bca9902f"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/70d49280-5b7e-438e-bb1f-0f05150e13e4/MS1sMzRuanpqYTZnYng0cTR4cHh6Z2U2MmlsZF8yXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=pm%2bi1xZzA4BjJN2VPZ%2f02xPkjvIPgjPYXgm9tLl6cCU%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/70d49280-5b7e-438e-bb1f-0f05150e13e4/MS1sMzRuanpqYTZnYng0cTR4cHh6Z2U2MmlsZF8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=4e%2bHhqbxuUha27VWPXr9K55mQL%2b1ufyKF7bOnoBNPDU%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/70d49280-5b7e-438e-bb1f-0f05150e13e4/MS1sMzRuanpqYTZnYng0cTR4cHh6Z2U2MmlsZF8yXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=gHHgHieCuzaxaQ18a0ThCzpBVPTTXMN8WvS%2bip0wPIg%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/70d49280-5b7e-438e-bb1f-0f05150e13e4/MS1sMzRuanpqYTZnYng0cTR4cHh6Z2U2MmlsZF8yXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=WRQAwZDLNPuRTiekIHTeV37AgSA4HdvzygW6DC%2fCeWU%3d&quot;}}" alt="Si compartes comida, compartes el virus." aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/70d49280-5b7e-438e-bb1f-0f05150e13e4/MS1sMzRuanpqYTZnYng0cTR4cHh6Z2U2MmlsZF8yXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=4e%2bHhqbxuUha27VWPXr9K55mQL%2b1ufyKF7bOnoBNPDU%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 00:52 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="Si compartes comida, compartes el virus." light-style="true" on-ellipsis-only="true"> Si compartes comida, compartes el virus. </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 55 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 21 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/b58b4f10-c43c-4664-8b18-1376be4c6b00" ng-click="$ctrl.videoClicked()" aria-label=" Video #InThisTogether Recap, duration is 1 minute 6 seconds, number of views is 194 " class="video-item-image-link" href="/video/b58b4f10-c43c-4664-8b18-1376be4c6b00"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/9a181aa7-4fda-4422-86ca-1b0c08664a71/NDAwZTIyNWEtM2E0Yy00YTA3LWI0YWMtYTM2ZjRkNzc0NWFiLXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=RNCpaHn%2fkji2tXMkwPaIkWkJ0lE5cWQmuj2b1pbAtR8%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/9a181aa7-4fda-4422-86ca-1b0c08664a71/NDAwZTIyNWEtM2E0Yy00YTA3LWI0YWMtYTM2ZjRkNzc0NWFiLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ZS8Dc7ofarSRRSKdAxIfhEbIUvwccn0gtHZfTtY0UVM%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/9a181aa7-4fda-4422-86ca-1b0c08664a71/NDAwZTIyNWEtM2E0Yy00YTA3LWI0YWMtYTM2ZjRkNzc0NWFiLXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=vt%2fnfy0iLgAbKOCWd96smAbDxiGqvRXcusA%2bPobxUus%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/9a181aa7-4fda-4422-86ca-1b0c08664a71/NDAwZTIyNWEtM2E0Yy00YTA3LWI0YWMtYTM2ZjRkNzc0NWFiLXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ruvtKwAOHoxETRuUkTspczv6KITGV2%2fGdODioltWdMQ%3d&quot;}}" alt="#InThisTogether Recap" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/9a181aa7-4fda-4422-86ca-1b0c08664a71/NDAwZTIyNWEtM2E0Yy00YTA3LWI0YWMtYTM2ZjRkNzc0NWFiLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=ZS8Dc7ofarSRRSKdAxIfhEbIUvwccn0gtHZfTtY0UVM%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 01:06 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="#InThisTogether Recap" light-style="true" on-ellipsis-only="true"> #InThisTogether Recap </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 194 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope" ng-class="{'end' : 22 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/a79120f1-58f2-46fa-a259-8f818c9e4f31" ng-click="$ctrl.videoClicked()" aria-label=" Video EU RTC 2020 Session 3, duration is 2 hours 21 minutes 34 seconds, number of views is 1 " class="video-item-image-link" href="/video/a79120f1-58f2-46fa-a259-8f818c9e4f31"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/60f57c7e-8b6f-4924-93e1-41aaa37d4280/NWYxMjlkNGUtN2FhZi00MmUyLTg0ZjUtMWNmYjc3NTZlZjVkLXBvc3Rlcl9leHRyYXNtYWxsLnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=gNVUe6rLvr2H4i8MWaDCmtVNZPCDjVML%2f3LEtktWxZA%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/60f57c7e-8b6f-4924-93e1-41aaa37d4280/NWYxMjlkNGUtN2FhZi00MmUyLTg0ZjUtMWNmYjc3NTZlZjVkLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=PSVCsZ6yLxMmq%2bsahyQuJwMxFClLfnY8SShHjODeWkQ%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/60f57c7e-8b6f-4924-93e1-41aaa37d4280/NWYxMjlkNGUtN2FhZi00MmUyLTg0ZjUtMWNmYjc3NTZlZjVkLXBvc3Rlcl9tZWRpdW0ucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=Hfb9r2b6cmCq%2beGvSPTEV%2bVd7JXspvABSzxSz%2by6ldg%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/60f57c7e-8b6f-4924-93e1-41aaa37d4280/NWYxMjlkNGUtN2FhZi00MmUyLTg0ZjUtMWNmYjc3NTZlZjVkLXBvc3Rlcl9sYXJnZS5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=dOIPQeCWJK9dcGKkGa14p%2fMhHifL9y%2bQZ5FjorgUN7s%3d&quot;}}" alt="EU RTC 2020 Session 3" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/2/60f57c7e-8b6f-4924-93e1-41aaa37d4280/NWYxMjlkNGUtN2FhZi00MmUyLTg0ZjUtMWNmYjc3NTZlZjVkLXBvc3Rlcl9zbWFsbC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=PSVCsZ6yLxMmq%2bsahyQuJwMxFClLfnY8SShHjODeWkQ%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 02:21:34 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="EU RTC 2020 Session 3" light-style="true" on-ellipsis-only="true"> EU RTC 2020 Session 3 </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 1 view </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --><li class="related-list-item column xsmall-12 ng-scope end" ng-class="{'end' : 23 === $ctrl.relatedVideos.length - 1}" ng-repeat="relatedVideoItem in $ctrl.relatedVideos"> <responsive-video-item video-item="relatedVideoItem" query-param="$ctrl.queryStrings" item-clicked="$ctrl.videoItemClicked()" list-style="true" auto-play-status="$ctrl.autoPlayDefault" related-videos="$ctrl.relatedVideos" class="ng-isolate-scope"><div class="responsive-video-item list-style" ng-class="{'list-style' : $ctrl.listStyle}"> <a ng-href="/video/d21795a2-ab2b-44ec-9fc4-3d9f9eeedddf" ng-click="$ctrl.videoClicked()" aria-label=" Video HD -B1 System Demo, duration is 1 hour 10 minutes 48 seconds, number of views is 2 " class="video-item-image-link" href="/video/d21795a2-ab2b-44ec-9fc4-3d9f9eeedddf"> <div class="video-item-thumb"> <div class="video-item-image-link"> <div class="video-item-image-container"> <!-- ngIf: !$ctrl.isImageUrlsEmpty --><img ng-if="!$ctrl.isImageUrlsEmpty" set-img-src="{&quot;extraSmall&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/dc0592fa-1ff3-42ab-ae3c-49ed7d7b6fdc/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzgweDQ1LnBuZw?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=dEL%2fFp5%2b1uTvjYSDcdhxrF5cHs%2bTMzTVhAdL5NbSoh4%3d&quot;},&quot;small&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/dc0592fa-1ff3-42ab-ae3c-49ed7d7b6fdc/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=JTYQ5jEKdfwrbqE8UeDwpN9X%2bI%2bn1NLSrF4QyDXRUZE%3d&quot;},&quot;medium&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/dc0592fa-1ff3-42ab-ae3c-49ed7d7b6fdc/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzMyMHgxODAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=nJagbZxXRQHvUjzS60Kg07iAaEK4IGZB0HRl38lFVvY%3d&quot;},&quot;large&quot;:{&quot;url&quot;:&quot;https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/dc0592fa-1ff3-42ab-ae3c-49ed7d7b6fdc/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzY0MHgzNjAucG5n?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=mc1%2fYti1VputAgIaPDPnYunVr%2bhZLvU3J4rPL%2bsQwpU%3d&quot;}}" alt="HD -B1 System Demo" aria-hidden="true" class="ng-scope" style="display: block;" src="https://uswe-1-content.api.microsoftstream.com/api/thumbnails/1/dc0592fa-1ff3-42ab-ae3c-49ed7d7b6fdc/MS01dXpleG5qdXF5eHFyem1vMnF4eHY3bmdvY18xXzE2MHg5MC5wbmc?validTill=2020-07-26T00%3a00%3a00.0000000Z&amp;aadUserOId=79c34bfa-ad42-4aae-a681-1edc26a3b11e&amp;encoding=base64&amp;api-version=1.4-private&amp;signature=JTYQ5jEKdfwrbqE8UeDwpN9X%2bI%2bn1NLSrF4QyDXRUZE%3d"><!-- end ngIf: !$ctrl.isImageUrlsEmpty --> <!-- ngIf: $ctrl.isImageUrlsEmpty && $ctrl.isLiveVideo --> <!-- ngIf: !$ctrl.isLiveVideo --><div ng-if="!$ctrl.isLiveVideo" class="video-item-thumb-duration ng-binding ng-scope"> 01:10:48 </div><!-- end ngIf: !$ctrl.isLiveVideo --> </div> </div> <!-- ngIf: $ctrl.newVideo && !$ctrl.isLiveNow --> <!-- ngIf: $ctrl.isLiveNow --> <!-- ngIf: $ctrl.videoItem.userData.isViewed && $ctrl.playbackProgressPercentage --> </div> <div class="detail-container"> <h3 class="title-heading"> <div class="video-item-title"> <!-- ngIf: $ctrl.isLiveVideo --> <span class="video-title-text ng-binding ng-isolate-scope" aria-hidden="true" custom-title="HD -B1 System Demo" light-style="true" on-ellipsis-only="true"> HD -B1 System Demo </span> </div> </h3> <div class="video-footer"> <!-- ngIf: $ctrl.isLiveVideo --> <!-- ngIf: $ctrl.isLiveVideo && !$ctrl.isLiveVideoCompleted --> <!-- ngIf: $ctrl.isVideoBeingPlayed --> <!-- ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --><video-statistics ng-if="(!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) &amp;&amp; !$ctrl.isVideoBeingPlayed" video-statistics-data="$ctrl.videoItem.metrics" hide-likes="true" class="ng-scope ng-isolate-scope"><!-- ngIf: !$ctrl.showIcons --><span class="video-statistics ng-scope" ng-if="!$ctrl.showIcons"> <span class="view-count ng-binding"> 2 views </span> <!-- ngIf: !$ctrl.hideLikes --> <!-- ngIf: $ctrl.showComments --> </span><!-- end ngIf: !$ctrl.showIcons --> <!-- ngIf: $ctrl.showIcons --></video-statistics><!-- end ngIf: (!$ctrl.isLiveVideo || $ctrl.isLiveVideoCompleted) && !$ctrl.isVideoBeingPlayed --> </div> </div> </a> </div></responsive-video-item> </li><!-- end ngRepeat: relatedVideoItem in $ctrl.relatedVideos --> </ul> </div><!-- end ngIf: $ctrl.relatedVideos.length && $ctrl.hideRelatedVideoDiv() --> <!-- ngIf: $ctrl.secondaryRelatedVideos.length --> </div></related-videos><!-- end ngIf: $ctrl.video && !$ctrl.isWatchList --> <!-- ngIf: $ctrl.video && $ctrl.isWatchList --> </div></div> </div> </section><!-- end ngIf: $ctrl.video --> </div> </div> </div></video-page><!-- end ngIf: Video.videoId -->
</div>
        </div>
        <footer class="ng-isolate-scope"><div class="row column" ng-show="$ctrl.videoEditorInactive" aria-hidden="false"> <section class="footer-section"> <ul class="c-list f-bare footer-link-list-left"> <li> <a ng-href="/usersettings" aria-label="&quot;Content Language Selector. Currently set to English&quot;" class="language-selector-link ng-binding" href="/usersettings"> <span class="c-glyph glyph-world" aria-hidden="true"></span> English </a> </li> <li> <a external-link="" class="c-hyperlink footer-link company-policy-link ng-binding" ng-href="" target="_blank">  </a> </li> </ul> <ul class="c-list f-bare footer-link-list-right"> <li> <a external-link="" class="c-hyperlink footer-link contact-us-link ng-binding" ng-href="http://go.microsoft.com/fwlink/?LinkID=808783&amp;clcid=0x0009" target="_blank" href="http://go.microsoft.com/fwlink/?LinkID=808783&amp;clcid=0x0009"> Contact us </a> </li> <li> <a external-link="" class="c-hyperlink footer-link privacy-and-cookies-link ng-binding" ng-href="http://go.microsoft.com/fwlink/?LinkID=808237&amp;clcid=0x0009" target="_blank" href="http://go.microsoft.com/fwlink/?LinkID=808237&amp;clcid=0x0009"> Privacy &amp; cookies </a> </li> <li> <a external-link="" class="c-hyperlink footer-link terms-of-use-link ng-binding" ng-href="http://go.microsoft.com/fwlink/?LinkID=808780&amp;clcid=0x0009" target="_blank" href="http://go.microsoft.com/fwlink/?LinkID=808780&amp;clcid=0x0009"> Terms of use </a> </li> <li> <a external-link="" class="c-hyperlink footer-link third-party-notices-link ng-binding" href="https://amsglob0cdnstream13.azureedge.net/1-0-2141-2/bundles/app/generated/thirdpartynotices/notice.txt" download="NOTICE" target="_blank"> Third party notices </a> </li> <li> <a external-link="" class="c-hyperlink footer-link terms-and-conditions-link ng-binding" ng-href="http://go.microsoft.com/fwlink/?LinkID=808240&amp;clcid=0x0009" target="_blank" href="http://go.microsoft.com/fwlink/?LinkID=808240&amp;clcid=0x0009"> Terms &amp; conditions </a> </li> <li dir="ltr" class="copyright ng-binding"> © 2020 Microsoft </li> </ul> </section> </div></footer></div><!-- end ngIf: loadPage -->
    <!-- ngIf: !loadPage -->

<style>.obf-OverallAnchor:focus { background-color: #93003D } .obf-OverallAnchor:hover { background-color: #C30052 } .obf-OverallAnchorActive { background-color: #93003D } .obf-SpinnerCircle { background-color: #93003D } .obf-ChoiceGroup input[type=radio]:checked+label>.obf-ChoiceGroupIcon { border-color: #93003D } .obf-ChoiceGroup input[type=radio]:hover+label>.obf-ChoiceGroupIcon { border-color: #C30052 } .obf-ChoiceGroup input[type=radio]:checked+label>.obf-ChoiceGroupIcon>span { background-color: #93003D } .obf-SubmitButton { background-color: #93003D } .obf-SubmitButton:hover { background-color: #C30052 } .obf-Link { color: #93003D } .obf-Link:hover { color: #C30052 } #obf-TPromptTitle { color: #93003D } #obf-TFormTitle { color: #93003D } </style><dropdown-overlay dropdown-overlay-name="uploadProgress" dropdown-overlay-class="topbarContextMenu uploadProgressContextMenu" parent-element="glyph-upload-progress" next-element="glyph-upload" class="ng-isolate-scope topbarContextMenu uploadProgressContextMenu overlay"><ng-transclude> <bg-upload-progress class="ng-scope ng-isolate-scope"><div class="bg-upload-progress"> <!-- ngRepeat: uploadingItem in $ctrl.uploadingList --> <!-- ngRepeat: otherUploadItem in $ctrl.nonUploadingList --> </div></bg-upload-progress> </ng-transclude></dropdown-overlay><div class="custom-title-body" collapsed="true" style="top: 0px; height: 0px; width: 0px; z-index: 21; left: 0px;">Search transcript</div><iframe src="https://outlook.office.com/owa/SuiteServiceProxy.aspx?suiteServiceUserName=amber-yan%40sensata.com&amp;suiteServiceReturnUrl=https%3A%2F%2Fweb.microsoftstream.com%2Fvideo%2F59035293-9751-4eae-88d6-7a235a553791&amp;returnUrl=https%3A%2F%2Fweb.microsoftstream.com%2Fvideo%2F59035293-9751-4eae-88d6-7a235a553791&amp;apiver=1" id="o365shellowaframe" name="o365shellowaframe" style="display: none;" sandbox="allow-scripts allow-same-origin allow-forms"></iframe><iframe src="https://webshell.suite.office.com/iframe/TokenFactoryIframe?origin=https%3A%2F%2Fweb.microsoftstream.com&amp;shsid=dae9f462-8523-44d7-b4ea-f7ab9dcd8314&amp;apiver=oneshell&amp;cshver=20200719.1" id="o365shellwcssframe" name="o365shellwcssframe" style="display: none;" sandbox="allow-scripts allow-same-origin allow-forms"></iframe><script src="https://r4.res.office365.com/footprint/v3.2/scripts/fp-min.js" type="text/javascript" crossorigin="anonymous"></script></body></html>
"""

# %%
<ul class="ng-scope"> 
<li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5206 seconds from beginning." id="transcript-74cd5051-c243-46ab-9dfa-23810cc9883a" aria-posinset="1367" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5206 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:46 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1366" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> In in an earlier answer here, we highlighted there's a lot </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5209 seconds from beginning." id="transcript-c738b813-6c3d-4fa2-bc8a-e1a6738d3272" aria-posinset="1368" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5209 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:49 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1367" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> of training being rolled out and being made available. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5212 seconds from beginning." id="transcript-b496e241-f2da-42da-a0b0-656d76bba4d0" aria-posinset="1369" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5212 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:52 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1368" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> Raise your hand, volunteer for the opportunity. Ask how </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5215 seconds from beginning." id="transcript-05f17e31-8022-469b-8f3f-bc46bbb48779" aria-posinset="1370" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5215 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:55 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1369" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> you can help. Ask how you can have an impact and get the </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5219 seconds from beginning." id="transcript-b5e0539d-c84d-45b2-a823-f0336e1ed3bd" aria-posinset="1371" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5219 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:26:59 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1370" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> right training in order to be ready for that role, because </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5222 seconds from beginning." id="transcript-1e165221-f253-4648-a43d-8d7394794a0a" aria-posinset="1372" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5222 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:02 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1371" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> this is going to be a really exciting journey an we really </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5226 seconds from beginning." id="transcript-882ad8de-0d12-4a43-ac46-4bd696cdb111" aria-posinset="1373" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5226 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:06 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1372" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> need everybody to lean in and help us achieve that growth. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5232 seconds from beginning." id="transcript-663ad0ca-79c9-4db3-8970-cdfabdf478fc" aria-posinset="1374" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5232 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:12 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1373" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> Alright, so I can't think of a better comment to close on. I </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5236 seconds from beginning." id="transcript-4f9f99e1-3717-4b1c-afa9-d4bb93a8c217" aria-posinset="1375" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5236 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:16 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1374" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> want to thank everyone on the panel. I wanna think Jeff, I </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5239 seconds from beginning." id="transcript-796b523c-9cdf-4c60-ab28-f265d6905cfc" aria-posinset="1376" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5239 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:19 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1375" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> want to thank all of you for attending. I really encourage </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5242 seconds from beginning." id="transcript-121c51ca-1966-4497-a949-7f3fff9ca962" aria-posinset="1377" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5242 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:22 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1376" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> you to attend our next quarterly town Hall on Aug 6th. I know you </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5246 seconds from beginning." id="transcript-536750e0-23ee-4982-b4b7-06b407f7bccf" aria-posinset="1378" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5246 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:26 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1377" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> have a lot of questions and he submitted a ton of questions </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5250 seconds from beginning." id="transcript-254e9ed2-49b2-4481-b1f7-345039944d8f" aria-posinset="1379" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5250 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:30 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1378" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> around. You know people that have taken a number of voluntary </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5253 seconds from beginning." id="transcript-a83df1f5-dd28-40f9-8262-e617edda9518" aria-posinset="1380" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5253 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:33 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1379" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> and involuntary actions will talk about all that on our next </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5256 seconds from beginning." id="transcript-dec7ed5c-25d3-4dd7-8085-ba121269fc2f" aria-posinset="1381" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5256 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:36 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1380" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> quarterly townhall. Obviously today was really focused on </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5258 seconds from beginning." id="transcript-f7256754-e9ba-4178-8559-909066aa6f2a" aria-posinset="1382" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5258 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:38 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1381" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> stint. Uhm, I want to thank everyone for participating and </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5261 seconds from beginning." id="transcript-31fc5c4f-4f9e-4eac-9b55-dbb1bdbbef55" aria-posinset="1383" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5261 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:41 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1382" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> thank you for working so hard </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5263 seconds from beginning." id="transcript-cd31625a-f693-42d6-83c6-6543117eb7cd" aria-posinset="1384" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5263 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:43 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1383" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> for Team Syncada. Please continue to stay safe and </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5266 seconds from beginning." id="transcript-819bcabc-e177-47f9-97eb-854d36c5b7b1" aria-posinset="1385" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5266 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:46 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1384" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> serve our customers and be well. Have a great day </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --><!-- ngIf: line --><li ng-if="line" ng-repeat="line in $vs_renderItems track by line.id" ng-class="$ctrl.shouldHighlight(line) ? 'highlight-line' : 'default-line'" role="listitem" ng-click="$ctrl.onTranscriptClicked(line)" aria-label="Clicking on this transcript will seek video to the time of 5268 seconds from beginning." id="transcript-4133dfb3-14c4-492f-9fc9-b76b4902aefa" aria-posinset="1386" aria-setsize="1386" class="transcript-line c-caption-1 ng-scope default-line" tabindex="0" style=""> <!-- ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --><div class="transcript-line-wrapper ng-scope" ng-if="$ctrl.areTranscriptNewEditButtonsEnabled"> <div class="transcript-timestamp new ng-binding" tabindex="-1" aria-label="Clicking on this transcript will seek video to the time of 5268 seconds from beginning." ng-click="$ctrl.onTranscriptClicked(line)" role="button"> 01:27:48 </div> <div class="transcript-text-container"> <div class="transcript-text new ng-binding" ng-class="{editable: $ctrl.isActiveEdit(line)}" ng-focus="$ctrl.onTranscriptFocused($event, line)" vlist-index="1385" ng-keydown="$ctrl.onTextKeyDown($event)" ng-blur="$ctrl.onTranscriptBlur()" contenteditable="$ctrl.isActiveEdit(line)"> everyone. </div> <div class="transcript-text-action-bar" ng-class="{visible: $ctrl.shouldShowActionBar(line)}" ng-switch="" on="$ctrl.transcriptSavingStatus"> <!-- ngSwitchWhen: 0 --> <!-- ngSwitchWhen: 1 --> <!-- ngSwitchWhen: 2 --> <!-- ngSwitchWhen: 3 --> <!-- ngSwitchDefault:  --><div class="transcript-text-action-buttons ng-scope" ng-switch-default=""> <div class="transcript-text-action-left-buttons"> <button class="stream-btn discard-btn ng-binding" ng-click="$ctrl.discard()"> Discard </button> <button class="stream-btn save-btn ng-binding" type="submit" ng-class="{'btn-primary': $ctrl.isTranscriptModified}" ng-click="$ctrl.save($event, line)"> Save </button> </div> <div class="transcript-text-action-divider"></div> <div class="transcript-text-action-right-buttons"> <button class="stream-btn replay-btn ng-isolate-scope" type="submit" ng-click="$ctrl.replay($event, line)" aria-label="Clicking this button restarts playback from the start of the current transcript segment and sets the focus to the current transcript segment's editable text contents." ng-mouseover="$ctrl.applyActiveStyleToReplayButton()" ng-mouseleave="$ctrl.applyInactiveStyleToReplayButton()" ng-focus="$ctrl.applyActiveStyleToReplayButton()" ng-blur="$ctrl.applyInactiveStyleToReplayButton()" custom-title="Replay this video segment"> <svg-src svg-name="icon_replay" inline-with-text="true" class="replay-icon ng-isolate-scope"><span class="svg-container icon-inline" ng-class="{'icon-inline': $ctrl.inlineWithText}"> <svg class="svg-icon" focusable="false" aria-hidden="true"> <use xlink:href="#icon_replay" ng-attr-xlink:href="{{$ctrl.getSvgPath}}"></use> </svg> </span></svg-src> </button> </div> </div><!-- end ngSwitchWhen:  --> </div> </div> </div><!-- end ngIf: $ctrl.areTranscriptNewEditButtonsEnabled --> <!-- ngIf: !$ctrl.areTranscriptNewEditButtonsEnabled --> </li><!-- end ngIf: line --><!-- end ngRepeat: line in $vs_renderItems track by line.id --> </ul> </ng-transclude> </div> </div></virtual-list><!-- end ngIf: $ctrl.transcriptLines.length --> <!-- ngIf: !$ctrl.isTranscriptEditV3Enabled --> </div> </div> </transcript> </ng-transclude> </div> </div> </div> </search-event><!-- end ngIf: $ctrl.servicePlans.capabilities.transcriptSearch && $ctrl.captionReady --> <!-- ngIf: !$ctrl.servicePlans.capabilities.transcriptSearch && $ctrl.captionReady --> </div> <div class="no-data-message-cont"> <!-- ngIf: $ctrl.isNoTranscriptData --> </div> </div></div> <div id="forms-right-tab-page" ng-class="{'live':$ctrl.isLiveNow || $ctrl.isLiveContentCreatedState}" ng-show="$ctrl.isRightTabSet(5)" aria-hidden="true" class="ng-hide"><div id="forms-container" class="forms-container"> <forms timed-events="$ctrl.timedEvents" show-controls="$ctrl.showFormControls" on-add-form="$ctrl.addForm(formEvent)" on-delete-form="$ctrl.deleteForm(formEvent)" player="$ctrl.player" on-form-clicked="$ctrl.jumpToForm(formEvent)" can-edit="$ctrl.isEditorOrInAdminMode" time-code="$ctrl.playerTime" video-id="$ctrl.videoId" player-session-id="$ctrl.playerSessionId" class="ng-isolate-scope"><div class="forms" dir="ltr"> <!-- ngIf: $ctrl.canEdit --> <!-- ngIf: $ctrl.timedEvents.length !== 0 --> <!-- ngIf: $ctrl.timedEvents.length === 0 && $ctrl.canEdit --> </div></forms> </div></div> </div> </div> </div> </div> </div><!-- end ngSwitchWhen:  --> <!-- ngSwitchWhen: NotFound --> <!-- ngSwitchWhen: Forbidden --> <!-- ngIf: $ctrl.routingCase === 'Uploading' || $ctrl.routingCase === 'NotReady' || $ctrl.routingCase === 'Error' --> </div> </div> </section> <!-- ngIf: $ctrl.video --><section class="other-area ng-scope" ng-if="$ctrl.video" aria-label="section including comments and related videos" style=""> <div class="row"> <div class="column video-detail-container medium-12 large-8" ng-class="{'medium-12 large-12': $ctrl.display12Column, 'medium-12 large-8': $ctrl.showRightContainer || $ctrl.isCompletedOnLoad}" style="margin-top: 0px;"> <div class="bottom-navigation-container"> <tab-navigation class="bottom-navigation ng-isolate-scope" model="$ctrl.playerBottomTabOptions" value="$ctrl.currentBottomTab" direction="$ctrl.tabHeaderDirection" show-full-in-small="true"><nav class="tab-navigation c-in-page-navigation" ng-class="{'tab-navigation-v2': $ctrl.isV2StyleEnabled, 'c-in-page-navigation': !$ctrl.isVertical, 'vertical-navigation': $ctrl.isVertical, 'tab-navigation-minimal': $ctrl.minimalStyle}"> <ul class="tab-navigation-list show-for-small" role="tablist" ng-class="{'show-for-medium': !$ctrl.isVertical &amp;&amp; !$ctrl.showFullInSmall, 'show-for-small': $ctrl.showFullInSmall}"> <!-- ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><li class="tab-navigation-item ng-scope details-bottom-tab f-active" role="presentation" ng-repeat="option in $ctrl.model.options" ng-if="!option.hide" ng-class="[option.className, {'f-active': $ctrl.value === option.value}]" style=""> <!-- ngIf: option.svgName --> <button class="c-action-trigger nav-link nav-link-option-0 f-active" role="tab" ng-class="{'f-active': $ctrl.value === option.value, 'item-error': option.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked(option)" ng-disabled="option.disable" aria-posinset="1" aria-setsize="1" aria-selected="true"> <!-- ngIf: option.value === $ctrl.errorTabValue --> Details </button> <!-- ngIf: option.afterSvgName --> </li><!-- end ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --><!-- ngIf: !option.hide --><!-- end ngRepeat: option in $ctrl.model.options --> </ul> <!-- ngIf: !$ctrl.isVertical --><ul class="tab-navigation-list ng-scope hide-for-small" ng-if="!$ctrl.isVertical" ng-class="{'hide-for-medium': !$ctrl.showFullInSmall, 'hide-for-small': $ctrl.showFullInSmall}"> <li class="tab-navigation-item"> <button class="c-action-trigger with-drawer nav-link nav-link-option-0 f-active" ng-class="{'f-active': $ctrl.value === $ctrl.activeOption.value, 'item-error': $ctrl.activeOption.value === $ctrl.errorTabValue}" ng-click="$ctrl.onTabClicked($ctrl.activeOption)"> <!-- ngIf: $ctrl.activeOption.value === $ctrl.errorTabValue --> Details </button> </li> <!-- ngIf: $ctrl.drawerItems --><li class="tab-navigation-item ng-scope" ng-if="$ctrl.drawerItems"> <drawer drawer-items="$ctrl.drawerItems" item="$ctrl.model" left-allign="$ctrl.leftAllign" fixed-elements="$ctrl.fixedElements" tab-navigation-drawer="true" class="ng-isolate-scope"><div class="drawer" action-list=""> <span ng-show="!$ctrl.transcludeButtonPresent" role="presentation" aria-hidden="false" class=""> <button name="dropdown" role="menu" class="c-action-trigger c-glyph drawer-button drawer-button-stream drawer-button-without-label ng-isolate-scope" aria-label="More actions" custom-title="More actions" aria-expanded="false" ng-click="return;"> <span class="x-screen-reader ng-binding">More actions</span> </button> </span> <span role="presentation" ng-show="$ctrl.transcludeButtonPresent" ng-transclude="transcludebutton" aria-hidden="true" class="ng-hide"> <ng-transclude></ng-transclude> </span> <ul class="drawer-content collapsed" ng-class="{'allign-opp': $ctrl.leftAllign}"> <!-- ngRepeat: item in $ctrl.drawerItems --> </ul> </div></drawer> </li><!-- end ngIf: $ctrl.drawerItems --> <li aria-label="Health" ng-class="$ctrl.svgClassName"> <!-- ngIf: $ctrl.isSvgAfterAvailable --> </li> </ul><!-- end ngIf: !$ctrl.isVertical --> </nav> </tab-navigation> <!-- ngIf: $ctrl.bottomTabDrawerItems.length --> </div> <div id="under-player-container" class="xsmall-12 small-12 medium-12 large-12"> <video-metadata ng-show="$ctrl.isBottomTabSet(0) &amp;&amp; $ctrl.showMetadata" video="$ctrl.video" is-in-admin-mode="$ctrl.isInAdminMode" elevated-video-session-properties="$ctrl.elevatedVideoSessionProperties" video-page-session-properties="$ctrl.videoPageSessionProperties" player-options="$ctrl.playerOptions" dialog-interruption-handler="$ctrl.dialogInterruptionHandler" get-player-current-time="$ctrl.getCurrentTime()" drawer-items="$ctrl.drawerItems" view-settings="$ctrl.viewSettings" is-stream-admin="$ctrl.isStreamAdmin" is-live-content="$ctrl.isLiveContent" video-page-session-metrics="$ctrl.videoPageSessionMetrics" is-live-now="$ctrl.isLiveNow" is-completed="$ctrl.isCompleted" is-replacing="$ctrl.isReplacing" is-trimming="$ctrl.isTrimming" class="ng-isolate-scope" aria-hidden="false"><section> <div class="video-meta-container"> <div class="row row-size1"> <!-- ngIf: $ctrl.showErrorMessage --> </div> <div class="row column main-meta row-size0 remove-margin"> <div class="title-container title-with-completed" ng-class="{'title-with-live': $ctrl.isLiveNow, 'title-with-completed': $ctrl.isCompleted, 'title-before-live': $ctrl.isLiveContent &amp;&amp; !$ctrl.isCompleted}"> <span class="live-label-cont"> <!-- ngIf: $ctrl.isLiveNow --> </span> <!-- ngIf: $ctrl.isLiveContent && !$ctrl.isCompleted && !$ctrl.isLiveNow && !$ctrl.isReplacing && !$ctrl.isTrimming --> <!-- ngIf: $ctrl.isLiveContent && $ctrl.isCompleted --> <h1 class="title ng-binding"> 2020 Global STINT Town Hall Meeting </h1> </div> <div class="creator-and-privacy"> <div class="video-create-message"> <video-creator item="$ctrl.video" get-creator-message-template="$ctrl.getCreateMessageTemplate()" class="ng-isolate-scope">﻿<!-- ngIf: ::($ctrl.canDisplayCreator) --><span class="info-message-content ng-binding ng-scope" ng-if="::($ctrl.canDisplayCreator)">Published on 2020/7/22 by  <a class="c-hyperlink info-message-link ng-binding" ng-href="/user/21bed756-c076-4add-9912-d49fcc3543d0" ng-click="$ctrl.cacheCreator()" href="/user/21bed756-c076-4add-9912-d49fcc3543d0">Cermak, Jennifer</a>  </span><!-- end ngIf: ::($ctrl.canDisplayCreator) --></video-creator> </div> <div class="privacy-and-statistics"> <video-privacy class="video-privacy ng-isolate-scope" video-privacy-type="$ctrl.video.privacyMode"><p class="screen-reader-text ng-binding">organization</p> <div class="videoprivacy ng-isolate-scope" aria-hidden="true" custom-title="" light-style="$ctrl.lightCustomTitle"> <svg-src class="icon_privacytag ng-isolate-scope video-privacy-company" aria-label="Privacy" inline-with-text="true" svg-name="icon_privacy_my_org" ng-class="{

# %%
html = """
<html>  
  <head>
    <meta http-equiv="Content-Type" content="text/html; charset=utf8" />
    <title></title>
  </head>  
  <body>  
  </body>  
</html> 
"""

# %%
d = pq(html)

# %%
print(d.html())
# Out:
#
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf8"/>
#     <title/>
#   </head>
#   <body>
#   </body>

# %%
print(d.outerHtml())
# Out:
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf8">
#     <title></title>
#   </head>
#   <body>
#   </body>
# </html>

# %%
print(d.outer_html())
# Out:
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf8">
#     <title></title>
#   </head>
#   <body>
#   </body>
# </html>

# %% [markdown]
# ## 标签选择器

# %%
d('title').append('Title1')
print(d.outer_html())
# Out:
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf8">
#     <title>Title1</title>
#   </head>
#   <body>
#   </body>
# </html>

# %%
table = pq('<table><thead></thead><tbody></tbody></table>')
table('thead').append('<tr><th>code</th><th>close</th><th>vol</th><th>trade_date</th></tr>')
table('tbody').append('<tr><td>code</td><td>close</td><td>vol</td><td>trade_date</td></tr>')
print(table.outer_html())
# Out:
# <table><thead><tr><th>code</th><th>close</th><th>vol</th><th>trade_date</th></tr></thead><tbody><tr><td>code</td><td>close</td><td>vol</td><td>trade_date</td></tr></tbody></table>

# %%
d('body').append(table)

# %%
print(d.outer_html())
# Out:
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf8">
#     <title>Title1</title>
#   </head>
#   <body>
#   <table><thead><tr><th>code</th><th>close</th><th>vol</th><th>trade_date</th></tr></thead><tbody><tr><td>code</td><td>close</td><td>vol</td><td>trade_date</td></tr></tbody></table></body>
# </html>

# %%
d('#test').html()
# Out:
# '<a href="http://python.org">python</a> !'

# %%
d.show()

# %%
d('#transcript-f067e512-76fd-4c66-8b37-2a0315364266 > div > div:nth-child(2) > div').html()

# %%
html.ng-scope 
body.theme-for-videopage.-mouse.-should.-not.-have.-outline 
div.ng-scope 
div.office-scroll-body 
div.ng-scope 
video-page.ng-scope.ng-isolate-scope 
div div.container.video 
div.main-area 
section.player-area div div div.ng-scope 
div.video-player-container div.row div#player-right-container-wrapper.column.xsmall-12.small-6.medium-4.large-4 div#player-right-container-content.player-right-container-content 
div#transcript-right-tab-page div#transcript-container 
div#transcript-content.transcript-content 
search-event.ng-scope.ng-isolate-scope 
div.search-event div.content 
div.transclude-content ng-transclude 
transcript.ng-scope.ng-isolate-scope div.transcript div.transcript-inner.new 
virtual-list.transcript-list.ng-scope.ng-isolate-scope div.virtual-list 
div.scrollable-content ng-transclude ul.ng-scope 
li#transcript-2f780f01-9733-4286-8a6f-8c96870f5690.transcript-line.c-caption-1.ng-scope.default-line 
div.transcript-line-wrapper.ng-scope

# %%
#transcript-2f780f01-9733-4286-8a6f-8c96870f5690 > div:nth-child(1)

# %%
d('.transcript-line-wrapper').text()
# Out:
# "01:26:46\nIn in an earlier answer here, we highlighted there's a lot\nDiscard Save 01:26:49\nof training being rolled out and being made available.\nDiscard Save 01:26:52\nRaise your hand, volunteer for the opportunity. Ask how\nDiscard Save 01:26:55\nyou can help. Ask how you can have an impact and get the\nDiscard Save 01:26:59\nright training in order to be ready for that role, because\nDiscard Save 01:27:02\nthis is going to be a really exciting journey an we really\nDiscard Save 01:27:06\nneed everybody to lean in and help us achieve that growth.\nDiscard Save 01:27:12\nAlright, so I can't think of a better comment to close on. I\nDiscard Save 01:27:16\nwant to thank everyone on the panel. I wanna think Jeff, I\nDiscard Save 01:27:19\nwant to thank all of you for attending. I really encourage\nDiscard Save 01:27:22\nyou to attend our next quarterly town Hall on Aug 6th. I know you\nDiscard Save 01:27:26\nhave a lot of questions and he submitted a ton of questions\nDiscard Save 01:27:30\naround. You know people that have taken a number of voluntary\nDiscard Save 01:27:33\nand involuntary actions will talk about all that on our next\nDiscard Save 01:27:36\nquarterly townhall. Obviously today was really focused on\nDiscard Save 01:27:38\nstint. Uhm, I want to thank everyone for participating and\nDiscard Save 01:27:41\nthank you for working so hard\nDiscard Save 01:27:43\nfor Team Syncada. Please continue to stay safe and\nDiscard Save 01:27:46\nserve our customers and be well. Have a great day\nDiscard Save 01:27:48\neveryone.\nDiscard Save"

# %%
d('.transcript-line-wrapper').contents()
# Out:
# [' ', <Element div at 0x1060d5228>, ' ', <Element div at 0x1060d5e58>, ' ', ' ', <Element div at 0x1060d5ea8>, ' ', <Element div at 0x1060d5ef8>, ' ', ' ', <Element div at 0x1060d5f48>, ' ', <Element div at 0x1060d5f98>, ' ', ' ', <Element div at 0x1060d4048>, ' ', <Element div at 0x1060d4098>, ' ', ' ', <Element div at 0x1060d40e8>, ' ', <Element div at 0x1060d4138>, ' ', ' ', <Element div at 0x1060d4188>, ' ', <Element div at 0x1060d41d8>, ' ', ' ', <Element div at 0x1060d4228>, ' ', <Element div at 0x1060d4278>, ' ', ' ', <Element div at 0x1060d42c8>, ' ', <Element div at 0x1060d4318>, ' ', ' ', <Element div at 0x1060d4368>, ' ', <Element div at 0x1060d43b8>, ' ', ' ', <Element div at 0x1060d4408>, ' ', <Element div at 0x1060d4458>, ' ', ' ', <Element div at 0x1060d44a8>, ' ', <Element div at 0x1060d44f8>, ' ', ' ', <Element div at 0x1060d4548>, ' ', <Element div at 0x1060d4598>, ' ', ' ', <Element div at 0x1060d45e8>, ' ', <Element div at 0x1060d4638>, ' ', ' ', <Element div at 0x1060d4688>, ' ', <Element div at 0x1060d46d8>, ' ', ' ', <Element div at 0x1060d4728>, ' ', <Element div at 0x1060d4778>, ' ', ' ', <Element div at 0x1060d47c8>, ' ', <Element div at 0x1060d4818>, ' ', ' ', <Element div at 0x1060d4868>, ' ', <Element div at 0x1060d48b8>, ' ', ' ', <Element div at 0x1060d4908>, ' ', <Element div at 0x1060d4958>, ' ', ' ', <Element div at 0x1060d49a8>, ' ', <Element div at 0x1060d49f8>, ' ', ' ', <Element div at 0x1060d4a48>, ' ', <Element div at 0x1060d4a98>, ' ']

# %%
t = d('div#transcript-content.transcript-content div.scrollable-content ng-transclude ul.ng-scope li')

# %%
t.text()
# Out:
# "01:26:46\nIn in an earlier answer here, we highlighted there's a lot\nDiscard Save 01:26:49\nof training being rolled out and being made available.\nDiscard Save 01:26:52\nRaise your hand, volunteer for the opportunity. Ask how\nDiscard Save 01:26:55\nyou can help. Ask how you can have an impact and get the\nDiscard Save 01:26:59\nright training in order to be ready for that role, because\nDiscard Save 01:27:02\nthis is going to be a really exciting journey an we really\nDiscard Save 01:27:06\nneed everybody to lean in and help us achieve that growth.\nDiscard Save 01:27:12\nAlright, so I can't think of a better comment to close on. I\nDiscard Save 01:27:16\nwant to thank everyone on the panel. I wanna think Jeff, I\nDiscard Save 01:27:19\nwant to thank all of you for attending. I really encourage\nDiscard Save 01:27:22\nyou to attend our next quarterly town Hall on Aug 6th. I know you\nDiscard Save 01:27:26\nhave a lot of questions and he submitted a ton of questions\nDiscard Save 01:27:30\naround. You know people that have taken a number of voluntary\nDiscard Save 01:27:33\nand involuntary actions will talk about all that on our next\nDiscard Save 01:27:36\nquarterly townhall. Obviously today was really focused on\nDiscard Save 01:27:38\nstint. Uhm, I want to thank everyone for participating and\nDiscard Save 01:27:41\nthank you for working so hard\nDiscard Save 01:27:43\nfor Team Syncada. Please continue to stay safe and\nDiscard Save 01:27:46\nserve our customers and be well. Have a great day\nDiscard Save 01:27:48\neveryone.\nDiscard Save"

# %%
len(t)
# Out:
# 20

# %%
t[0]
# Out:
# <Element li at 0x1060c4c78>

# %%
t.eq(0)
# Out:
# [<li#transcript-74cd5051-c243-46ab-9dfa-23810cc9883a.transcript-line.c-caption-1.ng-scope.default-line>]

# %%
for i in range(len(t)):
    print(t[0]('div.transcript-line-wrapper.ng-scope div.transcript-text.new.ng-binding').contents())
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-518f0d2df284> in <module>
#       1 for i in range(len(t)):
# ----> 2     print(pq(t[0])('div.transcript-line-wrapper.ng-scope div.transcript-text.new.ng-binding').contents())
#       3     break
#
# ~/anaconda3/lib/python3.7/site-packages/pyquery/pyquery.py in __str__(self)
#     380         """
#     381         encoding = str if PY3k else None
# --> 382         return ''.join([etree.tostring(e, encoding=encoding) for e in self])
#     383
#     384     def __unicode__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pyquery/pyquery.py in <listcomp>(.0)
#     380         """
#     381         encoding = str if PY3k else None
# --> 382         return ''.join([etree.tostring(e, encoding=encoding) for e in self])
#     383
#     384     def __unicode__(self):
#
# src/lxml/etree.pyx in lxml.etree.tostring()
#
# TypeError: Type 'lxml.etree._ElementUnicodeResult' cannot be serialized.

# %%
# Out:
# [" In in an earlier answer here, we highlighted there's a lot ", ' of training being rolled out and being made available. ', ' Raise your hand, volunteer for the opportunity. Ask how ', ' you can help. Ask how you can have an impact and get the ', ' right training in order to be ready for that role, because ', ' this is going to be a really exciting journey an we really ', ' need everybody to lean in and help us achieve that growth. ', " Alright, so I can't think of a better comment to close on. I ", ' want to thank everyone on the panel. I wanna think Jeff, I ', ' want to thank all of you for attending. I really encourage ', ' you to attend our next quarterly town Hall on Aug 6th. I know you ', ' have a lot of questions and he submitted a ton of questions ', ' around. You know people that have taken a number of voluntary ', ' and involuntary actions will talk about all that on our next ', ' quarterly townhall. Obviously today was really focused on ', ' stint. Uhm, I want to thank everyone for participating and ', ' thank you for working so hard ', ' for Team Syncada. Please continue to stay safe and ', ' serve our customers and be well. Have a great day ', ' everyone. ']

# %%
d('ul.ng-scope:nth-child(1)')
# Out:
# [<ul.ng-scope>]
