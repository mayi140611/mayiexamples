# %% [markdown]
# # Statistics and distance based features
# https://www.jianshu.com/p/791ea1d6fdf9

# %% [markdown]
# 例子：这里有一些CTR(点击率)任务的数据
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
