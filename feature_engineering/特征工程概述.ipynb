# %% [markdown]
# 按照pipeline的思路走
#
# 每个pipeline的一个点是stage
#
# stage之间可以是相互独立的(没有先后关系，意味着处理时可以并行)，还有一些是有依赖关系的(必须一个stage跑完才能跑另外一个)

# %% [markdown]
# 并行的stage
#
# 如完全是不同方面的特征，如保单的特征和被保人的特征；

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
