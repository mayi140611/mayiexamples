# %% [markdown]
# https://blog.csdn.net/qq_39232265/article/details/78868487

# %% [markdown]
# notebook 使用 MathJax 将 LaTeX 符号呈现为数学符号。要启动数学模式，请在 LaTeX 符号两侧加上美元符号（例如 $y = mx + b$），以创建内联的数学表达式。对于数学符号块，请使用两个美元符号：
# `y = \frac{a}{b+c}`
#
# $$
# y = \frac{a}{b+c}
# $$

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# \hat y
#
# $$\hat y$$

# %% [markdown]
# ## 微积分常用符号
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# 偏微分符号`\partial`
#
# $$\partial$$

# %% [markdown]
# `\sum_{i=1}^n p_i`
#
# $\sum_{i=1}^n p_i$

# %% [markdown]
# `f′(x)=\lim_{h\to0}\frac{f(x+h)−f(x-h)}{2h}`
#
# $$f′(x)=\lim_{h\to0}\frac{f(x+h)−f(x-h)}{2h}$$

# %% [markdown]
# $$
# \alpha
# \beta
# \theta
# $$

# %% [markdown]
# 使用两个$$包围就会居中

# %% [markdown]
# # 分段函数
#     \begin{cases}...\end{cases}

# %% [markdown]
# 对于成对出现的如括号(), {}等，可以在\left \right，这样排版会变好
#
# 没有\left \right
# $$smooth_{L_{1}}(x)=\begin{cases}0.5x^{2}, |x|\leq 1 \cr |x|-0.5, otherwise\end{cases}$$

# %% [markdown]
# 有\left \right
# $$smooth_{L_{1}}(x)=\begin{cases}0.5x^{2}, &\left |x \right |\leq 1 \cr \left |x \right|-0.5, &otherwise\end{cases}$$

# %% [markdown]
# # 向量&矩阵

# %% [markdown]
# \vec{x}
#
# $$\vec{x}$$
#
# \overline{x}
#
# $$\overline{x}$$
#
# \dot{x}
#
# $$\dot{x}$$
#
# \ddot{x}
#
# $$\ddot{x}$$

# %% [markdown]
# $$\begin{pmatrix} x_1\\x_2\\...\\x_n\end{pmatrix}$$

# %% [markdown]
# $$
# \begin{gathered}
# \begin{matrix} 0 & 1 \\ 1 & 0 \end{matrix}
# \quad
# \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}
# \quad
# \begin{bmatrix} 0 & -1 \\ 1 & 0 \end{bmatrix}
# \quad
# \begin{Bmatrix} 1 & 0 \\ 0 & -1 \end{Bmatrix}
# \quad
# \begin{vmatrix} a & b \\ c & d \end{vmatrix}
# \quad
# \begin{Vmatrix} i & 0 \\ 0 & -i \end{Vmatrix}
# \end{gathered}
# $$

# %% [markdown]
# $$
# \begin{gathered}
# \begin{matrix} 0 & 1 \\ 1 & 0 \end{matrix}
# \quad
# \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}
# \quad
# \begin{bmatrix} 0 & -1 \\ 1 & 0 \end{bmatrix}
# \quad
# \begin{Bmatrix} 1 & 0 \\ 0 & -1 \end{Bmatrix}
# \quad
# \begin{vmatrix} a & b \\ c & d \end{vmatrix}
# \quad
# \begin{Vmatrix} i & 0 \\ 0 & -i \end{Vmatrix}
# \end{gathered}
# $$

# %% [markdown]
# $$A\cdot B\\A\times B$$

# %% [markdown]
# # 空格的输入
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# `$$  a     b  $$`
#
#
# $$  a     b  $$

# %% [markdown]
# 可以看到，空格都被忽略了!
#
# `$$1\ a\ b\ 2$$`
#
# $$1\ a\ b\ 2$$

# %% [markdown]
# ## 输入换行

# %% [markdown]
# `$$1\ a\ b\\2$$`
#
# $$1\ a\ b\\2$$

# %% [markdown]
# # 大写希腊字母
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# $$ \sigma \rho $$

# %% [markdown]
# # 小写希腊字母
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# # 花体

# %% [markdown]
# $\mathcal{F}$
