# %% [markdown]
# # 综合指数

# %% [markdown]
# ## 000985 	中证全指
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000985

# %% [markdown]
# 中证全指由全部A股股票中剔除ST、*ST股票，以及上市时间不足3个月等股票后的剩余股票构成样本股，具有较高的市场代表性。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df = pd.read_excel('data/000985cons.xls')

# %%
df.shape
# Out:
# (3468, 8)

# %% [markdown]
# ## 000016 	上证50
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000016
#
# 上证50指数由沪市A股中规模大、流动性好的最具代表性的50只股票组成，反映上海证券市场最具影响力的一批龙头公司的股票价格表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df_sh50 = pd.read_excel('data/000016closeweight.xls')

# %%
df_sh50.shape
# Out:
# (50, 9)

# %%
df_sh50.sort_values('权重(%)Weight(%)', ascending=False)
# Out:
#        日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 31 2020-02-28              16           上证50                 SSE 50
# 14 2020-02-28              16           上证50                 SSE 50
# 6  2020-02-28              16           上证50                 SSE 50
# 11 2020-02-28              16           上证50                 SSE 50
# 26 2020-02-28              16           上证50                 SSE 50
# 4  2020-02-28              16           上证50                 SSE 50
# 20 2020-02-28              16           上证50                 SSE 50
# 33 2020-02-28              16           上证50                 SSE 50
# 2  2020-02-28              16           上证50                 SSE 50
# 30 2020-02-28              16           上证50                 SSE 50
# 0  2020-02-28              16           上证50                 SSE 50
# 7  2020-02-28              16           上证50                 SSE 50
# 19 2020-02-28              16           上证50                 SSE 50
# ...

# %% [markdown]
# ## 000300 沪深300
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000300
#
# ### 指数简介
# 沪深300指数由上海和深圳证券市场中市值大、流动性好的300只股票组成，综合反映中国A股市场上市股票价格的整体表现。
#
# “沪深300指数®”商标​归属于中证指数有限公司，未经中证指数有限公司事先书面同意，任何人不得以任何形式使用。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %% [markdown]
# ### 成分权重

# %%
import pandas as pd

# %%
df = pd.read_excel('data/000300closeweight.xls')

# %%
df.shape
# Out:
# (300, 9)

# %%
df.sort_values('权重(%)Weight(%)', ascending=False).head(20)
# Out:
#         日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 131 2020-02-28             300          沪深300                CSI 300
# 65  2020-02-28             300          沪深300                CSI 300
# 16  2020-02-28             300          沪深300                CSI 300
# 208 2020-02-28             300          沪深300                CSI 300
# 43  2020-02-28             300          沪深300                CSI 300
# 195 2020-02-28             300          沪深300                CSI 300
# 118 2020-02-28             300          沪深300                CSI 300
# 221 2020-02-28             300          沪深300                CSI 300
# 14  2020-02-28             300          沪深300                CSI 300
# 93  2020-02-28             300          沪深300                CSI 300
# 189 2020-02-28             300          沪深300                CSI 300
# 262 2020-02-28             300          沪深300                CSI 300
# 95  2020-02-28             300          沪深300                CSI 300
# ...

# %% [markdown]
# 相关产品

# %% [markdown]
# ### 510300
# 300ETF
# 华泰柏瑞基金管理有限公司

# %% [markdown]
# ## 000905 	中证500
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000905
#
# 中证500指数由全部A股中剔除沪深300指数成份股及总市值排名前300名的股票后，总市值排名靠前的500只股票组成，
#
# 综合反映中国A股市场中一批中小市值公司的股票价格表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df_500 = pd.read_excel('data/000905closeweight.xls')

# %%
df_500.shape
# Out:
# (500, 9)

# %%
df_500.head()
# Out:
#       日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 0 2020-02-28             905          中证500                CSI 500
# 1 2020-02-28             905          中证500                CSI 500
# 2 2020-02-28             905          中证500                CSI 500
# 3 2020-02-28             905          中证500                CSI 500
# 4 2020-02-28             905          中证500                CSI 500
#
#    成分券代码Constituent Code 成分券名称Constituent Name  \
# 0                 600006                  东风汽车
# 1                 600008                  首创股份
# 2                 600017                   日照港
# 3                 600021                  上海电力
# 4                 600022                  山东钢铁
#
#          成分券英文名称Constituent Name(Eng.) 交易所Exchange  权重(%)Weight(%)
# 0           Dongfeng Automobile Co Ltd         SHH            0.07
# 1               Beijing Capital Co Ltd         SHH            0.17
# 2                   Rizhao Port Co Ltd         SHH            0.11
# ...

# %%
df_500.sort_values('权重(%)Weight(%)', ascending=False).head(20)
# Out:
#         日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 119 2020-02-28             905          中证500                CSI 500
# 393 2020-02-28             905          中证500                CSI 500
# 485 2020-02-28             905          中证500                CSI 500
# 465 2020-02-28             905          中证500                CSI 500
# 398 2020-02-28             905          中证500                CSI 500
# 416 2020-02-28             905          中证500                CSI 500
# 94  2020-02-28             905          中证500                CSI 500
# 360 2020-02-28             905          中证500                CSI 500
# 349 2020-02-28             905          中证500                CSI 500
# 496 2020-02-28             905          中证500                CSI 500
# 413 2020-02-28             905          中证500                CSI 500
# 470 2020-02-28             905          中证500                CSI 500
# 83  2020-02-28             905          中证500                CSI 500
# ...

# %% [markdown]
# # 中证军工
# http://www.csindex.com.cn/zh-CN/indices/index-detail/399967
#
# 中证军工指数由十大军工集团控股的且主营业务与军工行业相关的上市公司以及其他主营业务为军工行业的上市公司作为指数样本，反映军工行业上市公司的整体表现。

# %%
df_jg = pd.read_excel('data/399967cons.xls')

# %%
df_jg.shape
# Out:
# (37, 8)

# %%
df_jg.head()
# Out:
#        日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 0  2020-03-13          399967           中证军工   CSI National Defense
# 1  2020-03-13          399967           中证军工   CSI National Defense
# 2  2020-03-13          399967           中证军工   CSI National Defense
# 3  2020-03-13          399967           中证军工   CSI National Defense
# 4  2020-03-13          399967           中证军工   CSI National Defense
#
#    成分券代码Constituent Code 成分券名称Constituent Name  \
# 0                 600038                  中直股份
# 1                 600118                  中国卫星
# 2                 600184                  光电股份
# 3                 600372                  中航电子
# 4                 600482                  中国动力
#
#                      成分券英文名称Constituent Name(Eng.) 交易所Exchange
# 0                         AVIC Helicopter Co.,Ltd.         SHH
# 1                            China Spacesat Co Ltd         SHH
# 2                     North Electro-Optic Co.,Ltd.         SHH
# ...

# %% [markdown]
# # 信息

# %% [markdown]
# ## 000993 	全指信息 	427
# 全指信息指数从中证全指样本股信息技术行业内选择流动性和市场代表性较好的股票构成指数样本股，以反映沪深两市信息技术行业内公司股票的整体表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df = pd.read_excel('data/000993cons.xls')

# %%
df.shape
# Out:
# (427, 8)

# %%
df['成分券名称Constituent Name'].tolist()
# Out:
# ['同方股份',
#  '上海贝岭',
#  '生益科技',
#  '福日电子',
#  '中昌数据',
#  '航天信息',
#  '大恒科技',
#  '三峡新材',
#  '天通股份',
#  '华微电子',
#  '联创光电',
#  '华胜天成',
#  '金证股份',
#  '士兰微',
#  '湘邮科技',
#  '中国软件',
#  '凯盛科技',
#  '国睿科技',
#  '法拉电子',
#  '恒生电子',
#  '信雅达',
#  '长电科技',
#  '用友网络',
#  '方正科技',
#  '云赛智联',
#  '浙数文化',
#  '号百控股',
#  '飞乐音响',
#  '太极实业',
#  '三安光电',
#  '东软集团',
#  '佳都科技',
#  '海航科技',
#  '浪潮软件',
#  '中国海防',
#  '浙大网新',
#  '宝信软件',
#  '华东电脑',
#  '大晟文化',
#  '环旭电子',
#  '三六零',
#  '大智慧',
#  '人民网',
#  '晶方科技',
#  '中科曙光',
#  '博通集成',
#  '恒银金融',
#  '碳元科技',
#  '海量数据',
#  '汇顶科技',
#  '华正新材',
#  '网达软件',
#  '中贝通信',
#  '景旺电子',
#  '格尔软件',
#  '宏和科技',
#  '电魂网络',
#  '鸿远电子',
#  '永新光学',
#  '超讯通信',
#  '福蓉科技',
#  '依顿电子',
#  '顶点软件',
#  '广东骏亚',
#  '吉比特',
#  '韦尔股份',
#  '思维列控',
#  '淳中科技',
#  '掌阅科技',
#  '中通国脉',
#  '纵横通信',
#  '国联股份',
#  '科森科技',
#  '南威软件',
#  '苏州科达',
#  '火炬电子',
#  '宁波水表',
#  '泰晶科技',
#  '沃格光电',
#  '数据港',
#  '新华网',
#  '春秋电子',
#  '世运电路',
#  '睿能科技',
#  '博敏电子',
#  '兆易创新',
#  '深科技',
#  '深桑达Ａ',
#  '神州数码',
#  '深纺织Ａ',
#  '深天马Ａ',
# ...

# %% [markdown]
# # 金融地产

# %% [markdown]
# ## 399986 	中证银行
# http://www.csindex.com.cn/zh-CN/indices/index-detail/399986
#
# 中证银行指数选取中证全指样本股中的银行行业股票组成，以反映该行业股票的整体表现。

# %%
df = pd.read_excel('data/399986cons.xls')

# %%
df.shape
# Out:
# (32, 8)

# %%
df['成分券名称Constituent Name'].tolist()
# Out:
# ['浦发银行',
#  '华夏银行',
#  '民生银行',
#  '招商银行',
#  '无锡银行',
#  '江苏银行',
#  '杭州银行',
#  '西安银行',
#  '南京银行',
#  '常熟银行',
#  '兴业银行',
#  '北京银行',
#  '上海银行',
#  '农业银行',
#  '交通银行',
#  '工商银行',
#  '长沙银行',
#  '光大银行',
#  '成都银行',
#  '紫金银行',
#  '建设银行',
#  '中国银行',
#  '贵阳银行',
#  '中信银行',
#  '苏农银行',
#  '平安银行',
#  '宁波银行',
#  '江阴银行',
#  '张家港行',
#  '郑州银行',
#  '青岛银行',
#  '青农商行']

# %% [markdown]
# ## 000992 	全指金融
# 全指金融指数从中证全指样本股__金融、地产行业__内选择流动性和市场代表性较好的股票构成指数样本股，
#
# 以反映沪深两市金融地产行业内公司股票的整体表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df = pd.read_excel('data/000922cons.xls')

# %%
df.shape
# Out:
# (100, 8)

# %%
df['成分券名称Constituent Name'].tolist()
# Out:
# ['皖通高速',
#  '民生银行',
#  '上港集团',
#  '宝钢股份',
#  '中原高速',
#  '浙能电力',
#  '中国石化',
#  '招商银行',
#  '保利地产',
#  '宇通客车',
#  '上汽集团',
#  '东睦股份',
#  '建发股份',
#  '香江控股',
#  '雅戈尔',
#  '生益科技',
#  '桂冠电力',
#  '赣粤高速',
#  '南钢股份',
#  '华发股份',
#  '山东高速',
#  '首开股份',
#  '宁沪高速',
#  '金地集团',
#  '海澜之家',
#  '方大特钢',
#  '深高速',
#  '法拉电子',
#  '迪马股份',
#  '海螺水泥',
#  '申能股份',
#  '福耀玻璃',
#  '川投能源',
#  '上海石化',
#  '物产中大',
#  '华域汽车',
#  '华远地产',
#  '马钢股份',
#  '上海机电',
#  '梅花生物',
#  '国投电力',
#  '厦门空港',
#  '长江电力',
#  '恒源煤电',
#  '柳钢股份',
#  '大秦铁路',
#  '南京银行',
#  '中国神华',
#  '中南传媒',
#  '兴业银行',
#  '农业银行',
#  '交通银行',
#  '工商银行',
#  '九牧王',
#  '中国太保',
#  '旗滨集团',
#  '中国建筑',
#  '光大银行',
#  '正泰电器',
#  '建设银行',
#  '中国银行',
#  '中信银行',
#  '养元饮品',
#  '依顿电子',
#  '万科Ａ',
#  '华联控股',
#  '中联重科',
#  '美的集团',
#  '潍柴动力',
#  '金 融 街',
#  '粤高速Ａ',
#  '晨鸣纸业',
#  '佛山照明',
#  '威孚高科',
#  '金科股份',
#  '苏宁环球',
#  '鲁  泰Ａ',
#  '东莞控股',
#  '承德露露',
#  '双汇发展',
#  '招商港口',
#  '新和成',
#  '世荣兆业',
#  '华孚时尚',
#  '孚日股份',
#  '鲁阳节能',
#  '三钢闽光',
#  '荣盛发展',
#  '海利得',
#  '塔牌集团',
#  '九阳股份',
# ...

# %%
df.head()
# Out:
#        日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 0  2020-03-13             922           中证红利           CSI Dividend
# 1  2020-03-13             922           中证红利           CSI Dividend
# 2  2020-03-13             922           中证红利           CSI Dividend
# 3  2020-03-13             922           中证红利           CSI Dividend
# 4  2020-03-13             922           中证红利           CSI Dividend
#
#    成分券代码Constituent Code 成分券名称Constituent Name  \
# 0                 600012                  皖通高速
# 1                 600016                  民生银行
# 2                 600018                  上港集团
# 3                 600019                  宝钢股份
# 4                 600020                  中原高速
#
#                 成分券英文名称Constituent Name(Eng.) 交易所Exchange
# 0                     Anhui Expressway Co Ltd         SHH
# 1             China Minsheng Banking Corp Ltd         SHH
# 2  Shanghai International Port (Group) Co Ltd         SHH
# ...

# %% [markdown]
# ## 399975 	全指证券公司 	44
# http://www.csindex.com.cn/zh-CN/indices/index-detail/399975
#
# 中证全指证券公司指数选取中证全指样本股中的证券公司行业股票组成，以反映该行业股票的整体表现。

# %%
import pandas as pd

# %%
df = pd.read_excel('data/399975cons.xls')

# %%
df.shape
# Out:
# (44, 8)

# %%
df['成分券名称Constituent Name'].tolist()
# Out:
# ['中信证券',
#  '国投资本',
#  '国金证券',
#  '华创阳安',
#  '西南证券',
#  '华鑫股份',
#  '海通证券',
#  '哈投股份',
#  '华安证券',
#  '东方证券',
#  '招商证券',
#  '中信建投',
#  '太平洋',
#  '财通证券',
#  '天风证券',
#  '东兴证券',
#  '国泰君安',
#  '红塔证券',
#  '中原证券',
#  '兴业证券',
#  '东吴证券',
#  '华泰证券',
#  '光大证券',
#  '浙商证券',
#  '中国银河',
#  '方正证券',
#  '南京证券',
#  '申万宏源',
#  '东北证券',
#  '锦龙股份',
#  '国元证券',
#  '国海证券',
#  '广发证券',
#  '长江证券',
#  '越秀金控',
#  '山西证券',
#  '国盛金控',
#  '西部证券',
#  '国信证券',
#  '第一创业',
#  '华西证券',
#  '长城证券',
#  '华林证券',
#  '东方财富']

# %% [markdown]
# # 红利

# %% [markdown]
# ## 000015 	上证红利指数
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000015
#
# 上证红利指数挑选在上证所上市的现金股息率高、分红比较稳定、具有一定规模及流动性的50只股票作为样本，以反映上海证券市场高红利股票的整体状况和走势。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %% [markdown]
# ## 000922 	中证红利
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000922
#
# 中证红利指数以沪深A股中现金股息率高、分红比较稳定、具有一定规模及流动性的100只股票为成分股，采用股息率作为权重分配依据，以反映A股市场高红利股票的整体表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。

# %%
df = pd.read_excel('data/000922cons.xls')

# %%
df.head()
# Out:
#        日期Date  指数代码Index Code 指数名称Index Name 指数英文名称Index Name(Eng.)  \
# 0  2020-03-13             922           中证红利           CSI Dividend
# 1  2020-03-13             922           中证红利           CSI Dividend
# 2  2020-03-13             922           中证红利           CSI Dividend
# 3  2020-03-13             922           中证红利           CSI Dividend
# 4  2020-03-13             922           中证红利           CSI Dividend
#
#    成分券代码Constituent Code 成分券名称Constituent Name  \
# 0                 600012                  皖通高速
# 1                 600016                  民生银行
# 2                 600018                  上港集团
# 3                 600019                  宝钢股份
# 4                 600020                  中原高速
#
#                 成分券英文名称Constituent Name(Eng.) 交易所Exchange
# 0                     Anhui Expressway Co Ltd         SHH
# 1             China Minsheng Banking Corp Ltd         SHH
# 2  Shanghai International Port (Group) Co Ltd         SHH
# ...

# %% [markdown]
# ## 000821 	300红利
# http://www.csindex.com.cn/zh-CN/indices/index-detail/000821
#
# 沪深300红利指数以沪深300指数样本股中股息率最高的50只股票为成分股，采用股息率作为权重分配依据，以反映沪深300指数中高股息率股票的整体表现。
#
# 该指数已纳入截至2018年9月30日的IOSCO金融基准原则鉴证报告范围。
