# %% [markdown]
# http://docs.h5py.org/en/latest/quick.html
#
# https://www.cnblogs.com/weiyinfu/p/10740653.html

# %%
import h5py

# %%
f = h5py.File('tt.h5', 'w')

# %%
f1 = h5py.File('model_weight1.h5', 'r')

# %%
f.copy(f1['model_weights/dense_1'], '/dense_1')

# %%
f.copy(f1['model_weights/input_1'], '/input_1')

# %%
f.copy(f1['model_weights/input_2'], '/input_2')

# %%
f.copy(f1['model_weights/lambda_1'], '/lambda_1')

# %%
f.copy(f1['model_weights/model_2'], '/model_2')

# %%
f.close()

# %%
def printname(name):
    print(name)

# %%
type(f['model_weights'])
# Out:
# h5py._hl.group.Group

# %%
list(f.keys())
# Out:
# ['model_weights']

# %%
f1.visit(printname)
# Out:
# model_weights
# model_weights/dense_1
# model_weights/dense_1/dense_1
# model_weights/dense_1/dense_1/bias:0
# model_weights/dense_1/dense_1/kernel:0
# model_weights/input_1
# model_weights/input_2
# model_weights/lambda_1
# model_weights/model_2
# model_weights/model_2/Embedding-Norm
# model_weights/model_2/Embedding-Norm/beta:0
# model_weights/model_2/Embedding-Norm/gamma:0
# model_weights/model_2/Embedding-Position
# model_weights/model_2/Embedding-Position/embeddings:0
# model_weights/model_2/Embedding-Segment
# model_weights/model_2/Embedding-Segment/embeddings:0
# model_weights/model_2/Embedding-Token
# model_weights/model_2/Embedding-Token/embeddings:0
# model_weights/model_2/Encoder-1-FeedForward
# model_weights/model_2/Encoder-1-FeedForward/Encoder-1-FeedForward_W1:0
# model_weights/model_2/Encoder-1-FeedForward/Encoder-1-FeedForward_W2:0
# model_weights/model_2/Encoder-1-FeedForward/Encoder-1-FeedForward_b1:0
# ...
