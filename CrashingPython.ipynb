# %% [markdown]
# https://wiki.python.org/moin/CrashingPython

# %%
import ctypes
def crash():
        '''\
        crash the Python interpreter...
        '''
        i = ctypes.c_char('a')
        j = ctypes.pointer(i)
        c = 0
        while True:
                j[c] = 'a'
                c += 1
        j

# %%
crash()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c2d2649b4e93> in <module>
# ----> 1 crash()
#
# <ipython-input-4-42b12f328e75> in crash()
#       4         crash the Python interpreter...
#       5         '''
# ----> 6         i = ctypes.c_char('a')
#       7         j = ctypes.pointer(i)
#       8         c = 0
#
# TypeError: one character bytes, bytearray or integer expected

# %% [markdown]
# ## Exhausting Resources
# There are a number of areas where resource exhaustion can crash the interpreter. Here's one fairly easy to demonstrate way to do it though:

# %% [markdown]
# ### setrecursionlimit(n)
#
# Set the maximum depth of the Python interpreter stack to n.  This
# limit prevents infinite recursion from causing an overflow of the C
# stack and crashing Python.  The highest possible limit is platform-
# dependent.
#
# 默认值好像是1000
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import sys
sys.setrecursionlimit(1<<30)

# %%
1<<30  # 移位操作 相当于2**30
# Out:
# 1073741824

# %%
2**30
# Out:
# 1073741824

# %%
1<<0
# Out:
# 1

# %%
1<<1
# Out:
# 2

# %%
1<<4
# Out:
# 16

# %%
sys.getrecursionlimit()
# Out:
# 1073741824

# %%
f = lambda f:f(f)

# %%
f(f)  # 服务直接挂了
