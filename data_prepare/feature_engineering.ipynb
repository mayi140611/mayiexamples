# %% [markdown]
# # Automated Feature Engineering

# %% [markdown]
# https://github.com/WillKoehrsen/automated-feature-engineering

# %% [markdown]
# In this notebook, we will walk through an implementation of using [Featuretools](https://www.featuretools.com/), an open-source Python library for automatically creating features with relational data (where the data is in structured tables). Although there are now many efforts working to enable automated model selection and hyperparameter tuning, there has been a lack of automating work on the feature engineering aspect of the pipeline. This library seeks to close that gap and the general methodology has been proven effective in both [machine learning competitions with the data science machine](https://github.com/HDI-Project/Data-Science-Machine) and [business use cases](https://www.featurelabs.com/blog/predicting-credit-card-fraud/).

# %% [markdown]
# ## Dataset
#
# To show the basic idea of featuretools we will use an example dataset consisting of three tables:
#
# * `clients`: 客户基本信息information about clients at a credit union
# * `loans`: 客户之前的贷款信息previous loans taken out by the clients
# * `payments`: 客户之前的还款信息payments made/missed on the previous loans
#
# The general problem of feature engineering is taking disparate data, often distributed across multiple tables, and combining it into a single table that can be used for training a machine learning model. Featuretools has the ability to do this for us, creating many new candidate features with minimal effort. These features are combined into a single table that can then be passed on to our model.
#
# First, let's load in the data and look at the problem we are working with.

# %%
# !pip install -U featuretools
# Out:
# Collecting featuretools
#   Downloading https://files.pythonhosted.org/packages/52/5f/57c526a0ea506b29a0029f234f09b1fcbf4dbb1e32a1996fe5228d2b2833/featuretools-0.9.1-py3-none-any.whl (221kB)
#      |████████████████████████████████| 225kB 16kB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: distributed>=1.24.2; python_version >= "3" in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (1.26.0)
# Requirement already satisfied, skipping upgrade: cloudpickle>=0.4.0 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (1.2.1)
# Requirement already satisfied, skipping upgrade: future>=0.16.0 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (0.17.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.0; python_version >= "3" in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (0.20.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (1.14.4)
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (0.24.2)
# Requirement already satisfied, skipping upgrade: tqdm>=4.19.2 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (4.31.1)
# Requirement already satisfied, skipping upgrade: dask>=1.1.0; python_version >= "3" in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (1.2.2)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (0.9.0)
# Requirement already satisfied, skipping upgrade: click>=7.0.0 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (7.0)
# Requirement already satisfied, skipping upgrade: pyyaml>=3.12 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (5.1)
# Requirement already satisfied, skipping upgrade: psutil>=5.4.8 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from featuretools) (5.6.1)
# Requirement already satisfied, skipping upgrade: msgpack in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (0.6.1)
# Requirement already satisfied, skipping upgrade: six in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (1.12.0)
# Requirement already satisfied, skipping upgrade: sortedcontainers!=2.0.0,!=2.0.1 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (2.1.0)
# Requirement already satisfied, skipping upgrade: tblib in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (1.3.2)
# Requirement already satisfied, skipping upgrade: tornado>=5 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (6.0.2)
# Requirement already satisfied, skipping upgrade: zict>=0.1.3 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from distributed>=1.24.2; python_version >= "3"->featuretools) (0.1.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.13.3 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.20.0; python_version >= "3"->featuretools) (1.1.0)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->featuretools) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->featuretools) (2.8.0)
# Requirement already satisfied, skipping upgrade: heapdict in /Users/luoyonggui/anaconda3/lib/python3.7/site-packages (from zict>=0.1.3->distributed>=1.24.2; python_version >= "3"->featuretools) (1.0.0)
# Installing collected packages: featuretools
#   Found existing installation: featuretools 0.7.0
#     Uninstalling featuretools-0.7.0:
#       Successfully uninstalled featuretools-0.7.0
# Successfully installed featuretools-0.9.1

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# featuretools for automated feature engineering
import featuretools as ft

# ignore warnings from pandas
# import warnings
# warnings.filterwarnings('ignore')

# %%
# Read in the data
clients = pd.read_csv('data/clients.csv', parse_dates = ['joined'])
loans = pd.read_csv('data/loans.csv', parse_dates = ['loan_start', 'loan_end'])
payments = pd.read_csv('data/payments.csv', parse_dates = ['payment_date'])

# %%
clients.head()
# Out:
#    client_id     joined  income  credit_score
# 0      46109 2002-04-16  172677           527
# 1      49545 2007-11-14  104564           770
# 2      41480 2013-03-11  122607           585
# 3      46180 2001-11-06   43851           562
# 4      25707 2006-10-06  211422           621

# %%
loans.sample(5)
# Out:
#      client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 284      32885      cash        12291       1    10198 2012-03-28 2014-08-14
# 112      39505    credit        10436       0    10509 2007-06-15 2009-03-02
# 205      26326      home        12760       0    11708 2003-12-11 2006-04-13
# 440      26945     other         9329       0    10154 2001-12-17 2004-07-22
# 96       25707     other        11467       1    11499 2011-10-27 2014-01-09
#
#      rate
# 284  1.16
# 112  1.34
# 205  5.43
# 440  5.65
# 96   4.56

# %%
payments.sample(5)
# Out:
#       loan_id  payment_amount payment_date  missed
# 550     11649            1995   2006-05-02       1
# 2750    11728             444   2002-09-20       1
# 2104    10116             937   2001-10-06       1
# 2720    10612             407   2005-01-05       1
# 2057    10732             834   2003-10-24       0

# %% [markdown]
# ## Manual Feature Engineering Examples
#
# Let's show a few examples of features we might make by hand. We will keep this relatively simple to avoid doing too much work!
#
# First we will focus on a single dataframe before combining them together. In the `clients` dataframe, we can take the month of the `joined` column and the natural log of the `income` column.
#
# Later, we see these are known in featuretools as transformation feature primitives because they act on column in a single table.

# %%
# Create a month column
clients['join_month'] = clients['joined'].dt.month

# Create a log of income column
clients['log_income'] = np.log(clients['income'])

clients.head()
# Out:
#    client_id     joined  income  credit_score  join_month  log_income
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611

# %% [markdown]
# To incorporate information about the other tables, we use the `df.groupby` method, followed by a suitable aggregation function, followed by `df.merge`.
#
# For example, let's calculate the average, minimum, and maximum amount of previous loans for each client.
#
# In the terms of featuretools, this would be considered an aggregation feature primitive because we using multiple tables in a one-to-many relationship to calculate aggregation figures (don't worry, this will be explained shortly!).

# %%
# Groupby client id and calculate mean, max, min previous loan size
stats = loans.groupby('client_id')['loan_amount'].agg(['mean', 'max', 'min'])
stats.columns = ['mean_loan_amount', 'max_loan_amount', 'min_loan_amount']
stats.head()
# Out:
#            mean_loan_amount  max_loan_amount  min_loan_amount
# client_id
# 25707           7963.950000            13913             1212
# 26326           7270.062500            13464             1164
# 26695           7824.722222            14865             2389
# 26945           7125.933333            14593              653
# 29841           9813.000000            14837             2778

# %%
# Merge with the clients dataframe
clients.merge(stats, left_on = 'client_id', right_index=True, how = 'left').head(5)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611
#
#    mean_loan_amount  max_loan_amount  min_loan_amount
# 0           8951.60            14049              559
# 1          10289.30            14971             3851
# 2           7894.85            14399              811
# 3           7700.85            14081             1607
# 4           7963.95            13913             1212

# %% [markdown]
# ## Featuretools
# https://www.featuretools.com/

# %% [markdown]
# Now that we know what we are trying to avoid (tedious manual feature engineering), let's figure out how to automate this process. Featuretools operates on an idea known as [Deep Feature Synthesis](https://docs.featuretools.com/api_reference.html#deep-feature-synthesis). You can read the [original paper here](http://www.jmaxkanter.com/static/papers/DSAA_DSM_2015.pdf), and although it's quite readable, it's not necessary to understand the details to do automated feature engineering.
#
#
#  ***The concept of Deep Feature Synthesis is to use basic building blocks known as feature primitives (like the transformations and aggregations done above) that can be stacked on top of each other to form new features. The depth of a "deep feature" is equal to the number of stacked primitives. ***
#
# I threw out some terms there, but don't worry because we'll cover them as we go. Featuretools builds on simple ideas to create a powerful method, and we will build up our understanding in much the same way.
#
# The first part of Featuretools to understand [is an `entity`](https://docs.featuretools.com/loading_data/using_entitysets.html#adding-entities). This is simply a table, or in `pandas`, a `DataFrame`.
#
#
#
# ### EntitySet
# We corral multiple entities into a [single object called an `EntitySet`](https://docs.featuretools.com/loading_data/using_entitysets.html). This is just a large data structure composed of many individual entities and the relationships between them.
#
# Creating a new `EntitySet` is pretty simple:

# %%
es = ft.EntitySet(id = 'clients')

# %% [markdown]
# #### Entities
#
# An entity is simply a table, which is represented in Pandas as a `dataframe`.
#
# ***Each entity must have a uniquely identifying column, known as an index. ***
#
# For the clients dataframe, this is the `client_id` because each id only appears once in the `clients` data. In the `loans` dataframe, `client_id` is not an index because each id might appear more than once. The index for this dataframe is instead `loan_id`.
#
# When we create an `entity` in featuretools, we have to identify which column of the dataframe is the index. If the data does not have a unique index we can tell featuretools to make an index for the entity by passing in `make_index = True` and specifying a name for the index.
#
# If the data also has a uniquely identifying time index, we can pass that in as the `time_index` parameter.
#
# Featuretools will automatically infer the variable types (numeric, categorical, datetime) of the columns in our data, but we can also pass in specific datatypes to override this behavior. As an example, even though the `repaid` column in the `loans` dataframe is represented as an integer, we can tell featuretools that this is a categorical feature since it can only take on two discrete values. This is done using an integer with the variables as keys and the feature types as values.
#
# In the code below we create the three entities and add them to the `EntitySet`.  The syntax is relatively straightforward with a few notes: for the `payments` dataframe we need to make an index, for the `loans` dataframe, we specify that `repaid` is a categorical variable, and for the `payments` dataframe, we specify that `missed` is a categorical feature.

# %%
# Create an entity from the client dataframe
# This dataframe already has an index and a time index
es = es.entity_from_dataframe(entity_id = 'clients', dataframe = clients, 
                              index = 'client_id', time_index = 'joined')

# Create an entity from the loans dataframe
# This dataframe already has an index and a time index
es = es.entity_from_dataframe(entity_id = 'loans', dataframe = loans, 
                              variable_types = {'repaid': ft.variable_types.Categorical},
                              index = 'loan_id', 
                              time_index = 'loan_start')

# Create an entity from the payments dataframe
# This does not yet have a unique index
es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe = payments,
                              variable_types = {'missed': ft.variable_types.Categorical},
                              make_index = True,
                              index = 'payment_id',
                              time_index = 'payment_date')

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
es['loans']
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#     repaid (dtype: categorical)
#   Shape:
#     (Rows: 443, Columns: 8)

# %%
es['payments']
# Out:
# Entity: payments
#   Variables:
#     payment_id (dtype: index)
#     loan_id (dtype: numeric)
#     payment_amount (dtype: numeric)
#     payment_date (dtype: datetime_time_index)
#     missed (dtype: categorical)
#   Shape:
#     (Rows: 3456, Columns: 5)

# %% [markdown]
# #### Relationships
#
# After defining the entities (tables) in an `EntitySet`, we now need to tell featuretools [how they are related with a relationship](https://docs.featuretools.com/loading_data/using_entitysets.html#adding-a-relationship).
#
# The most intuitive way to think of relationships is with the parent to child analogy: a parent-to-child relationship is one-to-many because for each parent, there can be multiple children.
#
# The `client` dataframe is therefore the parent of the `loans` dataframe because while there is only one row for each client in the `client` dataframe, each client may have several previous loans covering multiple rows in the `loans` dataframe. Likewise, the `loans` dataframe is the parent of the `payments` dataframe because each loan will have multiple payments.
#
# These relationships are what allow us to group together datapoints using aggregation primitives and then create new features. As an example, we can group all of the previous loans associated with one client and find the average loan amount. We will discuss the features themselves more in a little bit, but for now let's define the relationships.
#
# To define relationships, we need to specify the parent variable and the child variable. This is the variable that links two entities together. In our example, the `client` and `loans` dataframes are linked together by the `client_id` column. Again, this is a parent to child relationship because for each `client_id` in the parent `client` dataframe, there may be multiple entries of the same `client_id` in the child `loans` dataframe.
#
# We codify relationships in the language of featuretools by specifying the parent variable and then the child variable. After creating a relationship, we add it to the `EntitySet`.

# %%
# Relationship between clients and previous loans
r_client_previous = ft.Relationship(es['clients']['client_id'],
                                    es['loans']['client_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_client_previous)

# %%
# Relationship between previous loans and previous payments
r_payments = ft.Relationship(es['loans']['loan_id'],
                                      es['payments']['loan_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_payments)

es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %% [markdown]
# We now have our entities in an entityset along with the relationships between them. We can now start to making new features from all of the tables using stacks of feature primitives to form deep features. First, let's cover feature primitives.

# %% [markdown]
# ### Feature Primitives
#
# A [feature primitive](https://docs.featuretools.com/automated_feature_engineering/primitives.html) a at a very high-level is an operation applied to data to create a feature. These represent very simple calculations that can be stacked on top of each other to create complex features. Feature primitives fall into two categories:
#
# * __Aggregation__: 聚合。function that groups together child datapoints for each parent and then calculates a statistic such as mean, min, max, or standard deviation. An example is calculating the maximum loan amount for each client. An aggregation works across multiple tables using relationships between tables.
# * __Transformation__: an operation applied to one or more columns in a single table. An example would be extracting the day from dates, or finding the difference between two columns in one table.
#
# Let's take a look at feature primitives in featuretools. We can view the list of primitives:

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#                name         type  \
# 0      percent_true  aggregation
# 1        num_unique  aggregation
# 2  time_since_first  aggregation
# 3               min  aggregation
# 4               all  aggregation
# 5              mean  aggregation
# 6              last  aggregation
# 7             count  aggregation
# 8              skew  aggregation
# 9     n_most_common  aggregation
#
#                                                                        description
# 0                                         Determines the percent of `True` values.
# 1                 Determines the number of distinct values, ignoring `NaN` values.
# 2               Calculates the time elapsed since the first datetime (in seconds).
# 3                            Calculates the smallest value, ignoring `NaN` values.
# 4                                   Calculates if all values are 'True' in a list.
# 5                                       Computes the average for a list of values.
# 6                                             Determines the last value in a list.
# 7                          Determines the total number of values, excluding `NaN`.
# 8  Computes the extent to which a distribution differs from a normal distribution.
# 9                                         Determines the `n` most common elements.

# %%
primitives[primitives['type'] == 'transform']
# Out:
#                                name       type  \
# 20                          cum_min  transform
# 21                        longitude  transform
# 22                 multiply_numeric  transform
# 23                       is_weekend  transform
# 24               less_than_equal_to  transform
# 25            modulo_numeric_scalar  transform
# 26                        cum_count  transform
# 27                       percentile  transform
# 28          subtract_numeric_scalar  transform
# 29                divide_by_feature  transform
# 30                        less_than  transform
# 31                            month  transform
# 32               add_numeric_scalar  transform
# 33                           negate  transform
# 34            greater_than_equal_to  transform
# 35                           minute  transform
# 36                         absolute  transform
# 37                             isin  transform
# 38                 not_equal_scalar  transform
# 39                     greater_than  transform
# 40                             hour  transform
# 41                     equal_scalar  transform
# 42                        num_words  transform
# 43                               or  transform
# 44                          is_null  transform
# 45                          cum_max  transform
# 46                        haversine  transform
# 47          multiply_numeric_scalar  transform
# 48        less_than_equal_to_scalar  transform
# 49                modulo_by_feature  transform
# 50                          weekday  transform
# 51                         cum_mean  transform
# 52                         latitude  transform
# 53  scalar_subtract_numeric_feature  transform
# 54                 less_than_scalar  transform
# 55                   modulo_numeric  transform
# 56                             year  transform
# 57                          cum_sum  transform
# 58                              not  transform
# 59                 subtract_numeric  transform
# 60            divide_numeric_scalar  transform
# 61     greater_than_equal_to_scalar  transform
# 62                             week  transform
# 63                      add_numeric  transform
# 64                             diff  transform
# 65              greater_than_scalar  transform
# 66                           second  transform
# 67                              and  transform
# 68                   num_characters  transform
# 69                        not_equal  transform
# 70                       time_since  transform
# 71                              day  transform
# 72                   divide_numeric  transform
# 73                            equal  transform
# 74              time_since_previous  transform
#
#                                                                     description
# 20                                           Calculates the cumulative minimum.
# 21                  Returns the second tuple value in a list of LatLong tuples.
# 22                                    Element-wise multiplication of two lists.
# 23                                     Determines if a date falls on a weekend.
# 24     Determines if values in one list are less than or equal to another list.
# 25                   Return the modulo of each element in the list by a scalar.
# 26                                             Calculates the cumulative count.
# 27                     Determines the percentile rank for each value in a list.
# 28                             Subtract a scalar from each element in the list.
# 29                                   Divide a scalar by each value in the list.
# 30                 Determines if values in one list are less than another list.
# 31                                    Determines the month value of a datetime.
# 32                                      Add a scalar to each value in the list.
# 33                                                     Negates a numeric value.
# 34  Determines if values in one list are greater than or equal to another list.
# 35                                  Determines the minutes value of a datetime.
# 36                                     Computes the absolute value of a number.
# 37                    Determines whether a value is present in a provided list.
# 38              Determines if values in a list are not equal to a given scalar.
# 39              Determines if values in one list are greater than another list.
# 40                                     Determines the hour value of a datetime.
# 41                  Determines if values in a list are equal to a given scalar.
# 42           Determines the number of words in a string by counting the spaces.
# 43                                        Element-wise logical OR of two lists.
# 44                                               Determines if a value is null.
# 45                                           Calculates the cumulative maximum.
# 46            Calculates the approximate haversine distance between two LatLong
# 47                               Multiply each element in the list by a scalar.
# 48               Determines if values are less than or equal to a given scalar.
# 49                   Return the modulo of a scalar by each element in the list.
# 50                              Determines the day of the week from a datetime.
# 51                                              Calculates the cumulative mean.
# 52                   Returns the first tuple value in a list of LatLong tuples.
# 53                         Subtract each value in the list from a given scalar.
# 54                           Determines if values are less than a given scalar.
# 55                                            Element-wise modulo of two lists.
# 56                                     Determines the year value of a datetime.
# 57                                               Calculates the cumulative sum.
# 58                                                     Negates a boolean value.
# 59                                       Element-wise subtraction of two lists.
# 60                                 Divide each element in the list by a scalar.
# 61            Determines if values are greater than or equal to a given scalar.
# 62                             Determines the week of the year from a datetime.
# 63                                          Element-wise addition of two lists.
# 64                   Compute the difference between the value in a list and the
# 65                        Determines if values are greater than a given scalar.
# 66                                  Determines the seconds value of a datetime.
# 67                                       Element-wise logical AND of two lists.
# 68                             Calculates the number of characters in a string.
# 69              Determines if values in one list are not equal to another list.
# 70                 Calculates time from a value to a specified cutoff datetime.
# 71                             Determines the day of the month from a datetime.
# 72                                          Element-wise division of two lists.
# 73                  Determines if values in one list are equal to another list.
# 74                         Compute the time since the previous entry in a list.

# %%
primitives[primitives['type'] == 'transform'].head(10)
# Out:
#                        name       type  \
# 20                  cum_min  transform
# 21                longitude  transform
# 22         multiply_numeric  transform
# 23               is_weekend  transform
# 24       less_than_equal_to  transform
# 25    modulo_numeric_scalar  transform
# 26                cum_count  transform
# 27               percentile  transform
# 28  subtract_numeric_scalar  transform
# 29        divide_by_feature  transform
#
#                                                                  description
# 20                                        Calculates the cumulative minimum.
# 21               Returns the second tuple value in a list of LatLong tuples.
# 22                                 Element-wise multiplication of two lists.
# 23                                  Determines if a date falls on a weekend.
# 24  Determines if values in one list are less than or equal to another list.
# 25                Return the modulo of each element in the list by a scalar.
# 26                                          Calculates the cumulative count.
# 27                  Determines the percentile rank for each value in a list.
# 28                          Subtract a scalar from each element in the list.
# 29                                Divide a scalar by each value in the list.

# %% [markdown]
# If featuretools does not have enough primitives for us, we can [also make our own.](https://docs.featuretools.com/automated_feature_engineering/primitives.html#defining-custom-primitives)
#
# To get an idea of what a feature primitive actually does, let's try out a few on our data. Using primitives is surprisingly easy using the `ft.dfs` function (which stands for deep feature synthesis). In this function, we specify the entityset to use; the `target_entity`, which is the dataframe we want to make the features for (where the features end up); the `agg_primitives` which are the aggregation feature primitives; and the `trans_primitives` which are the transformation primitives to apply.
#
# In the following example, we are using the `EntitySet` we already created, the target entity is the `clients` dataframe because we want to make new features about each client, and then we specify a few aggregation and transformation primitives.

# %%
# Create new features using specified primitives
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients', 
                                 agg_primitives = ['mean', 'max', 'percent_true', 'last'],
                                 trans_primitives = ['year', 'month', 'subtract_numeric', 'divide_numeric'])

# %%
features.columns.to_list()
# Out:
# ['income',
#  'credit_score',
#  'join_month',
#  'log_income',
#  'MEAN(loans.loan_amount)',
#  'MEAN(loans.rate)',
#  'MAX(loans.loan_amount)',
#  'MAX(loans.rate)',
#  'LAST(loans.loan_id)',
#  'LAST(loans.loan_type)',
#  'LAST(loans.loan_amount)',
#  'LAST(loans.rate)',
#  'LAST(loans.repaid)',
#  'MEAN(payments.payment_amount)',
#  'MAX(payments.payment_amount)',
#  'LAST(payments.payment_id)',
#  'LAST(payments.payment_amount)',
#  'LAST(payments.missed)',
#  'YEAR(joined)',
#  'MONTH(joined)',
#  'income - log_income',
#  'join_month - log_income',
#  'income - join_month',
#  'credit_score - join_month',
#  'credit_score - log_income',
#  'credit_score - income',
#  'join_month / log_income',
#  'join_month / income',
#  'join_month / credit_score',
#  'income / join_month',
#  'credit_score / join_month',
#  'credit_score / log_income',
#  'credit_score / income',
#  'log_income / income',
#  'log_income / credit_score',
#  'income / log_income',
#  'income / credit_score',
#  'log_income / join_month',
#  'MEAN(loans.MEAN(payments.payment_amount))',
#  'MEAN(loans.MAX(payments.payment_amount))',
#  'MEAN(loans.LAST(payments.payment_amount))',
#  'MEAN(loans.loan_amount - rate)',
#  'MEAN(loans.rate / loan_amount)',
#  'MEAN(loans.loan_amount / rate)',
#  'MAX(loans.MEAN(payments.payment_amount))',
#  'MAX(loans.LAST(payments.payment_amount))',
#  'MAX(loans.loan_amount - rate)',
#  'MAX(loans.rate / loan_amount)',
#  'MAX(loans.loan_amount / rate)',
#  'LAST(loans.MEAN(payments.payment_amount))',
#  'LAST(loans.MAX(payments.payment_amount))',
#  'LAST(loans.YEAR(loan_start))',
#  'LAST(loans.YEAR(loan_end))',
#  'LAST(loans.MONTH(loan_start))',
#  'LAST(loans.MONTH(loan_end))',
#  'LAST(loans.loan_amount - rate)',
#  'LAST(loans.rate / loan_amount)',
#  'LAST(loans.loan_amount / rate)',
#  'YEAR(LAST(loans.loan_start))',
#  'YEAR(LAST(loans.loan_end))',
#  'YEAR(LAST(payments.payment_date))',
#  'MONTH(LAST(loans.loan_start))',
#  'MONTH(LAST(loans.loan_end))',
#  'MONTH(LAST(payments.payment_date))',
#  'credit_score - MAX(loans.rate)',
#  'income - LAST(payments.payment_amount)',
#  'join_month - MAX(payments.payment_amount)',
#  'income - MAX(payments.payment_amount)',
#  'MEAN(loans.loan_amount) - MEAN(loans.rate)',
#  'join_month - MEAN(loans.loan_amount)',
#  'join_month - LAST(payments.payment_amount)',
#  'MAX(loans.loan_amount) - MEAN(loans.loan_amount)',
#  'LAST(payments.payment_amount) - MAX(loans.rate)',
#  'log_income - MAX(payments.payment_amount)',
#  'LAST(loans.rate) - MAX(loans.rate)',
#  'join_month - LAST(loans.loan_amount)',
#  'credit_score - MAX(loans.loan_amount)',
#  'LAST(payments.payment_amount) - log_income',
#  'LAST(loans.loan_amount) - LAST(loans.rate)',
#  'log_income - MEAN(loans.loan_amount)',
#  'MAX(loans.rate) - MEAN(payments.payment_amount)',
#  'MAX(loans.loan_amount) - MAX(payments.payment_amount)',
#  'LAST(loans.rate) - MEAN(loans.rate)',
#  'income - MEAN(loans.loan_amount)',
#  'LAST(payments.payment_amount) - MAX(loans.loan_amount)',
#  'join_month - LAST(loans.rate)',
#  'LAST(loans.rate) - LAST(payments.payment_amount)',
#  'LAST(loans.rate) - MAX(payments.payment_amount)',
#  'log_income - MAX(loans.loan_amount)',
#  'MAX(payments.payment_amount) - MEAN(payments.payment_amount)',
#  'income - LAST(loans.loan_amount)',
#  'log_income - MEAN(loans.rate)',
#  'LAST(payments.payment_amount) - MEAN(loans.loan_amount)',
#  'income - MAX(loans.rate)',
#  'log_income - MEAN(payments.payment_amount)',
#  'MAX(payments.payment_amount) - MEAN(loans.rate)',
#  'credit_score - MEAN(loans.loan_amount)',
#  'LAST(loans.loan_amount) - MEAN(loans.loan_amount)',
#  'LAST(loans.loan_amount) - log_income',
#  'LAST(loans.rate) - MEAN(payments.payment_amount)',
#  'LAST(loans.loan_amount) - MAX(payments.payment_amount)',
#  'MAX(loans.rate) - MEAN(loans.rate)',
#  'income - LAST(loans.rate)',
#  'credit_score - MAX(payments.payment_amount)',
#  'LAST(loans.loan_amount) - LAST(payments.payment_amount)',
#  'LAST(payments.payment_amount) - MEAN(payments.payment_amount)',
#  'MAX(loans.loan_amount) - MAX(loans.rate)',
#  'MAX(loans.loan_amount) - MEAN(payments.payment_amount)',
#  'MAX(loans.rate) - MAX(payments.payment_amount)',
#  'LAST(loans.loan_amount) - MEAN(loans.rate)',
#  'LAST(loans.rate) - MAX(loans.loan_amount)',
#  'MAX(loans.rate) - MEAN(loans.loan_amount)',
#  'join_month - MEAN(loans.rate)',
#  'LAST(loans.rate) - log_income',
#  'MEAN(loans.loan_amount) - MEAN(payments.payment_amount)',
#  'credit_score - LAST(loans.rate)',
#  'MEAN(loans.rate) - MEAN(payments.payment_amount)',
#  'credit_score - LAST(payments.payment_amount)',
#  'join_month - MAX(loans.rate)',
#  'income - MEAN(payments.payment_amount)',
#  'join_month - MEAN(payments.payment_amount)',
#  'LAST(loans.loan_amount) - MAX(loans.loan_amount)',
#  'log_income - MAX(loans.rate)',
#  'credit_score - MEAN(loans.rate)',
#  'credit_score - LAST(loans.loan_amount)',
#  'LAST(payments.payment_amount) - MAX(payments.payment_amount)',
#  'MAX(payments.payment_amount) - MEAN(loans.loan_amount)',
#  'join_month - MAX(loans.loan_amount)',
#  'credit_score - MEAN(payments.payment_amount)',
#  'MAX(loans.loan_amount) - MEAN(loans.rate)',
#  'LAST(loans.loan_amount) - MEAN(payments.payment_amount)',
#  'income - MAX(loans.loan_amount)',
#  'income - MEAN(loans.rate)',
#  'LAST(loans.loan_amount) - MAX(loans.rate)',
#  'LAST(loans.rate) - MEAN(loans.loan_amount)',
#  'LAST(payments.payment_amount) - MEAN(loans.rate)',
#  'credit_score / MAX(loans.rate)',
#  'LAST(payments.payment_amount) / LAST(loans.loan_amount)',
#  'MEAN(payments.payment_amount) / credit_score',
#  'log_income / LAST(payments.payment_amount)',
#  'LAST(payments.payment_amount) / MAX(loans.rate)',
#  'MEAN(payments.payment_amount) / join_month - log_income',
#  'credit_score - income / income - join_month',
#  'MEAN(payments.payment_amount) / income - log_income',
#  'join_month / credit_score - income',
#  'log_income / credit_score - log_income',
#  'credit_score - log_income / income - join_month',
#  'MEAN(loans.loan_amount) / LAST(payments.payment_amount)',
#  'MEAN(loans.rate) / MAX(loans.loan_amount)',
#  'credit_score - income / MEAN(loans.loan_amount)',
#  'LAST(payments.payment_amount) / credit_score - join_month',
#  'income - join_month / join_month',
#  'MAX(loans.rate) / join_month',
#  'credit_score - join_month / MEAN(loans.rate)',
#  'LAST(payments.payment_amount) / credit_score',
#  'MEAN(loans.rate) / income - log_income',
#  'MEAN(loans.rate) / income - join_month',
#  'log_income / MEAN(loans.loan_amount)',
#  'join_month / credit_score - join_month',
#  'MEAN(payments.payment_amount) / income',
#  'join_month - log_income / MEAN(loans.rate)',
#  'income - join_month / credit_score - join_month',
#  'LAST(loans.loan_amount) / income',
#  'join_month / LAST(loans.rate)',
#  'LAST(loans.rate) / LAST(payments.payment_amount)',
#  'MAX(loans.loan_amount) / LAST(loans.rate)',
#  'MAX(loans.rate) / MAX(loans.loan_amount)',
#  'MAX(payments.payment_amount) / MEAN(payments.payment_amount)',
#  'MAX(loans.loan_amount) / LAST(loans.loan_amount)',
#  'credit_score - join_month / join_month - log_income',
#  'MEAN(payments.payment_amount) / join_month',
#  'MEAN(payments.payment_amount) / MAX(payments.payment_amount)',
#  'credit_score - join_month / log_income',
#  'income - join_month / credit_score - income',
#  'LAST(loans.loan_amount) / credit_score - income',
#  'LAST(loans.loan_amount) / MEAN(loans.loan_amount)',
#  'log_income / credit_score - income',
#  'MAX(loans.loan_amount) / income - log_income',
#  'LAST(loans.loan_amount) / LAST(payments.payment_amount)',
#  'credit_score - join_month / income',
#  'LAST(payments.payment_amount) / MEAN(payments.payment_amount)',
#  'MEAN(payments.payment_amount) / credit_score - join_month',
#  'credit_score - income / MAX(loans.rate)',
#  'LAST(loans.rate) / MAX(loans.loan_amount)',
#  'MEAN(loans.rate) / credit_score - income',
#  'LAST(payments.payment_amount) / LAST(loans.rate)',
#  'MAX(loans.rate) / MEAN(loans.loan_amount)',
#  'MAX(loans.rate) / credit_score',
#  'MAX(loans.rate) / credit_score - income',
#  'MEAN(loans.rate) / join_month',
#  'MEAN(loans.loan_amount) / credit_score',
#  'MEAN(payments.payment_amount) / MEAN(loans.rate)',
#  'join_month / MEAN(loans.rate)',
#  'credit_score - join_month / join_month',
#  'join_month / income - log_income',
#  'credit_score - join_month / income - log_income',
#  'income - join_month / credit_score - log_income',
#  'credit_score - join_month / credit_score - income',
#  'MAX(payments.payment_amount) / MAX(loans.rate)',
#  'credit_score / credit_score - join_month',
#  'credit_score - income / LAST(loans.rate)',
#  'MAX(loans.loan_amount) / income - join_month',
#  'MEAN(loans.rate) / LAST(payments.payment_amount)',
#  'join_month - log_income / MEAN(loans.loan_amount)',
#  'MAX(loans.rate) / credit_score - join_month',
#  'MAX(loans.loan_amount) / join_month - log_income',
#  'join_month - log_income / income - join_month',
#  'MAX(loans.rate) / income',
#  'MEAN(loans.loan_amount) / credit_score - join_month',
#  'LAST(loans.loan_amount) / MEAN(payments.payment_amount)',
#  'credit_score - join_month / LAST(loans.rate)',
#  'MAX(payments.payment_amount) / log_income',
#  'MAX(payments.payment_amount) / income',
#  'MEAN(loans.loan_amount) / income - join_month',
#  'credit_score - income / credit_score',
#  'credit_score / credit_score - income',
#  'MEAN(payments.payment_amount) / MAX(loans.loan_amount)',
#  'income / LAST(payments.payment_amount)',
#  'join_month / MAX(payments.payment_amount)',
#  'MAX(payments.payment_amount) / MAX(loans.loan_amount)',
#  'join_month / MEAN(loans.loan_amount)',
#  'LAST(loans.loan_amount) / join_month',
#  'income - log_income / credit_score',
#  'LAST(loans.rate) / join_month - log_income',
#  'log_income / MAX(payments.payment_amount)',
#  'credit_score - join_month / LAST(payments.payment_amount)',
#  'income - log_income / MAX(loans.loan_amount)',
#  'credit_score - income / LAST(loans.loan_amount)',
#  'MEAN(loans.loan_amount) / MAX(payments.payment_amount)',
#  'credit_score - log_income / credit_score',
#  'join_month - log_income / LAST(loans.rate)',
#  'credit_score / MAX(loans.loan_amount)',
#  'join_month - log_income / join_month',
#  'income - log_income / log_income',
#  'join_month - log_income / MAX(payments.payment_amount)',
#  'MAX(payments.payment_amount) / credit_score',
#  'LAST(payments.payment_amount) / log_income',
#  'MEAN(loans.rate) / LAST(loans.loan_amount)',
#  'income - log_income / MEAN(loans.loan_amount)',
#  'LAST(loans.loan_amount) / LAST(loans.rate)',
#  'MAX(loans.loan_amount) / MAX(payments.payment_amount)',
#  'MEAN(payments.payment_amount) / credit_score - log_income',
#  'MEAN(loans.rate) / MAX(loans.rate)',
#  'LAST(loans.rate) / credit_score - log_income',
#  'income / income - join_month',
#  'join_month - log_income / credit_score - log_income',
#  'LAST(loans.loan_amount) / income - log_income',
#  'income - join_month / LAST(loans.rate)',
#  'credit_score - income / income - log_income',
#  'LAST(loans.loan_amount) / credit_score - join_month',
#  'credit_score - log_income / MEAN(payments.payment_amount)',
#  'LAST(loans.rate) / MAX(payments.payment_amount)',
#  'MEAN(payments.payment_amount) / credit_score - income',
#  'income / LAST(loans.loan_amount)',
#  'income / MAX(loans.rate)',
#  'credit_score - log_income / LAST(payments.payment_amount)',
#  'MAX(payments.payment_amount) / MEAN(loans.rate)',
#  'MEAN(loans.rate) / LAST(loans.rate)',
#  'LAST(loans.loan_amount) / credit_score',
#  'income - log_income / join_month',
#  'LAST(payments.payment_amount) / join_month',
#  'LAST(loans.rate) / income',
#  'income - log_income / credit_score - income',
#  'credit_score / MAX(payments.payment_amount)',
#  'credit_score - log_income / LAST(loans.rate)',
#  'MAX(loans.rate) / LAST(payments.payment_amount)',
#  'credit_score - log_income / credit_score - income',
#  'MAX(loans.rate) / log_income',
#  'credit_score - income / join_month - log_income',
#  'credit_score - join_month / MEAN(payments.payment_amount)',
#  'MEAN(payments.payment_amount) / income - join_month',
#  'credit_score - income / MEAN(payments.payment_amount)',
#  'MEAN(loans.loan_amount) / MAX(loans.rate)',
#  'MEAN(loans.loan_amount) / join_month - log_income',
#  'LAST(loans.rate) / credit_score - join_month',
#  'MEAN(loans.rate) / MEAN(payments.payment_amount)',
#  'credit_score - income / credit_score - join_month',
#  'join_month / MAX(loans.rate)',
#  'credit_score - log_income / MAX(loans.rate)',
#  'LAST(payments.payment_amount) / credit_score - income',
#  'MAX(loans.rate) / income - log_income',
#  'log_income / income - log_income',
#  'MEAN(loans.loan_amount) / income',
#  'MEAN(loans.loan_amount) / LAST(loans.rate)',
#  'MEAN(loans.loan_amount) / credit_score - log_income',
#  'income / credit_score - log_income',
#  'income - join_month / join_month - log_income',
#  'log_income / LAST(loans.rate)',
#  'log_income / LAST(loans.loan_amount)',
#  'LAST(loans.rate) / MEAN(loans.loan_amount)',
#  'income - join_month / MEAN(payments.payment_amount)',
#  'MEAN(loans.loan_amount) / LAST(loans.loan_amount)',
#  'MEAN(loans.rate) / log_income',
#  'income / MAX(payments.payment_amount)',
#  'MEAN(loans.loan_amount) / MEAN(loans.rate)',
#  'join_month / LAST(payments.payment_amount)',
#  'MAX(loans.loan_amount) / MEAN(loans.loan_amount)',
#  'MAX(loans.loan_amount) / credit_score - log_income',
#  'credit_score / income - log_income',
#  'join_month - log_income / income - log_income',
#  'MEAN(loans.loan_amount) / join_month',
#  'income - log_income / MAX(payments.payment_amount)',
#  'MEAN(loans.rate) / credit_score - log_income',
#  'LAST(loans.rate) / MAX(loans.rate)',
#  'join_month - log_income / credit_score - income',
#  'credit_score - log_income / credit_score - join_month',
#  'income - join_month / LAST(loans.loan_amount)',
#  'MEAN(loans.loan_amount) / log_income',
#  'income - log_income / MEAN(loans.rate)',
#  'join_month - log_income / LAST(payments.payment_amount)',
#  'credit_score - income / LAST(payments.payment_amount)',
#  'credit_score - log_income / join_month',
#  'MEAN(loans.rate) / MEAN(loans.loan_amount)',
#  'income - log_income / LAST(loans.loan_amount)',
#  'credit_score - income / MAX(loans.loan_amount)',
#  'credit_score - income / credit_score - log_income',
#  'MAX(loans.rate) / MEAN(payments.payment_amount)',
#  'LAST(loans.rate) / MEAN(loans.rate)',
#  'MAX(loans.loan_amount) / credit_score - join_month',
#  'MAX(loans.rate) / join_month - log_income',
#  'income - log_income / income',
#  'join_month - log_income / LAST(loans.loan_amount)',
#  'MEAN(payments.payment_amount) / LAST(loans.loan_amount)',
#  'credit_score - join_month / MAX(loans.loan_amount)',
#  'MEAN(loans.rate) / income',
#  'log_income / MEAN(loans.rate)',
#  'income / join_month - log_income',
#  'MAX(payments.payment_amount) / LAST(payments.payment_amount)',
#  'income - log_income / MEAN(payments.payment_amount)',
#  'MAX(payments.payment_amount) / credit_score - log_income',
#  'income - log_income / LAST(loans.rate)',
#  'LAST(loans.rate) / credit_score',
#  'join_month - log_income / credit_score',
#  'credit_score / MEAN(loans.loan_amount)',
#  'income - join_month / MAX(payments.payment_amount)',
#  'LAST(loans.loan_amount) / log_income',
#  'MEAN(loans.rate) / join_month - log_income',
#  'credit_score / credit_score - log_income',
#  'credit_score - log_income / join_month - log_income',
#  'MAX(loans.rate) / MEAN(loans.rate)',
#  'income / LAST(loans.rate)',
#  'LAST(loans.rate) / income - join_month',
#  'join_month - log_income / credit_score - join_month',
#  'income - join_month / MEAN(loans.rate)',
#  'income - join_month / log_income',
#  'credit_score - join_month / credit_score',
#  'MAX(loans.loan_amount) / MAX(loans.rate)',
#  'LAST(loans.loan_amount) / MEAN(loans.rate)',
#  'MAX(loans.rate) / MAX(payments.payment_amount)',
#  'MEAN(loans.loan_amount) / credit_score - income',
#  'LAST(loans.rate) / LAST(loans.loan_amount)',
#  'credit_score - join_month / MAX(loans.rate)',
#  'LAST(loans.loan_amount) / credit_score - log_income',
#  'MAX(loans.loan_amount) / join_month',
#  'log_income / income - join_month',
#  'credit_score - join_month / MAX(payments.payment_amount)',
#  'income / MEAN(payments.payment_amount)',
#  'MAX(payments.payment_amount) / income - log_income',
#  'credit_score / MEAN(loans.rate)',
#  'credit_score - log_income / MEAN(loans.loan_amount)',
#  'join_month / income - join_month',
#  'credit_score - income / log_income',
#  'MEAN(payments.payment_amount) / MEAN(loans.loan_amount)',
#  'LAST(loans.rate) / credit_score - income',
#  'credit_score / LAST(loans.loan_amount)',
#  'credit_score - log_income / log_income',
#  'credit_score - log_income / income - log_income',
#  'LAST(loans.loan_amount) / join_month - log_income',
#  'MEAN(loans.rate) / credit_score - join_month',
#  'LAST(payments.payment_amount) / credit_score - log_income',
#  'join_month / MAX(loans.loan_amount)',
#  'credit_score / MEAN(payments.payment_amount)',
#  'MAX(loans.rate) / LAST(loans.rate)',
#  'income / MEAN(loans.rate)',
#  'LAST(loans.loan_amount) / MAX(loans.rate)',
#  'MAX(loans.rate) / LAST(loans.loan_amount)',
#  'credit_score - log_income / MAX(loans.loan_amount)',
#  'MAX(loans.loan_amount) / LAST(payments.payment_amount)',
#  'MEAN(payments.payment_amount) / MAX(loans.rate)',
#  'credit_score - income / income',
#  'MAX(payments.payment_amount) / LAST(loans.loan_amount)',
#  'MAX(loans.loan_amount) / log_income',
#  'credit_score - log_income / LAST(loans.loan_amount)',
#  'income / credit_score - join_month',
#  'MEAN(loans.rate) / MAX(payments.payment_amount)',
#  'join_month - log_income / log_income',
#  'income / income - log_income',
#  'MAX(payments.payment_amount) / credit_score - join_month',
#  'credit_score - income / MEAN(loans.rate)',
#  'join_month / LAST(loans.loan_amount)',
#  'MAX(payments.payment_amount) / income - join_month',
#  'LAST(payments.payment_amount) / income',
#  'credit_score - log_income / MAX(payments.payment_amount)',
#  'credit_score - income / MAX(payments.payment_amount)',
#  'credit_score - join_month / MEAN(loans.loan_amount)',
#  'income - join_month / income - log_income',
#  'LAST(loans.rate) / join_month',
#  'credit_score - join_month / income - join_month',
#  'MAX(payments.payment_amount) / join_month',
#  'income / MEAN(loans.loan_amount)',
#  'LAST(payments.payment_amount) / MAX(loans.loan_amount)',
#  'join_month / credit_score - log_income',
#  'MAX(loans.loan_amount) / credit_score',
#  'MAX(loans.loan_amount) / credit_score - income',
#  'MEAN(loans.loan_amount) / MAX(loans.loan_amount)',
#  'join_month - log_income / MEAN(payments.payment_amount)',
#  'income - join_month / income',
#  'MEAN(loans.rate) / credit_score',
#  'log_income / MAX(loans.loan_amount)',
#  'LAST(payments.payment_amount) / join_month - log_income',
#  'LAST(payments.payment_amount) / income - log_income',
#  'LAST(payments.payment_amount) / income - join_month',
#  'MEAN(loans.loan_amount) / income - log_income',
#  'LAST(payments.payment_amount) / MEAN(loans.loan_amount)',
#  'MEAN(payments.payment_amount) / LAST(payments.payment_amount)',
#  'log_income / MEAN(payments.payment_amount)',
#  'log_income / credit_score - join_month',
#  'MAX(loans.rate) / income - join_month',
#  'join_month - log_income / income',
#  'MAX(loans.rate) / credit_score - log_income',
#  'income - log_income / MAX(loans.rate)',
#  'credit_score - log_income / MEAN(loans.rate)',
#  'income - log_income / credit_score - join_month',
#  'MAX(loans.loan_amount) / income',
#  'income - join_month / LAST(payments.payment_amount)',
#  'LAST(loans.rate) / MEAN(payments.payment_amount)',
#  'income - join_month / credit_score',
#  'income - join_month / MEAN(loans.loan_amount)',
#  'LAST(loans.loan_amount) / MAX(payments.payment_amount)',
#  'MAX(payments.payment_amount) / credit_score - income',
#  'income / credit_score - income',
#  'MAX(payments.payment_amount) / join_month - log_income',
#  'MEAN(payments.payment_amount) / LAST(loans.rate)',
#  'MAX(loans.loan_amount) / MEAN(payments.payment_amount)',
#  'MAX(payments.payment_amount) / LAST(loans.rate)',
#  'income - log_income / join_month - log_income',
#  'credit_score / join_month - log_income',
#  'credit_score - join_month / LAST(loans.loan_amount)',
#  'LAST(loans.loan_amount) / income - join_month',
#  'LAST(loans.rate) / log_income',
#  'MEAN(loans.loan_amount) / MEAN(payments.payment_amount)',
#  'join_month - log_income / MAX(loans.loan_amount)',
#  'credit_score / LAST(loans.rate)',
#  'join_month - log_income / MAX(loans.rate)',
#  'credit_score / LAST(payments.payment_amount)',
#  'LAST(loans.rate) / income - log_income',
#  'credit_score - income / join_month',
#  'credit_score - join_month / credit_score - log_income',
#  'income - log_income / credit_score - log_income',
#  'LAST(loans.loan_amount) / MAX(loans.loan_amount)',
#  'join_month / MEAN(payments.payment_amount)',
#  'log_income / MAX(loans.rate)',
#  'MEAN(payments.payment_amount) / log_income',
#  'join_month / join_month - log_income',
#  'income - log_income / LAST(payments.payment_amount)',
#  'income - join_month / MAX(loans.loan_amount)',
#  'LAST(payments.payment_amount) / MAX(payments.payment_amount)',
#  'log_income / join_month - log_income',
#  'credit_score / income - join_month',
#  'MAX(payments.payment_amount) / MEAN(loans.loan_amount)',
#  'credit_score - log_income / income',
#  'income - join_month / MAX(loans.rate)',
#  'MAX(loans.loan_amount) / MEAN(loans.rate)',
#  'income / MAX(loans.loan_amount)',
#  'LAST(payments.payment_amount) / MEAN(loans.rate)',
#  'income - log_income / income - join_month']

# %%
features.head()
# Out:
#            income  credit_score  join_month  log_income  \
# client_id
# 25707      211422           621          10   12.261611
# 26326      227920           633           5   12.336750
# 26695      174532           680           8   12.069863
# 26945      214516           806          11   12.276140
# 29841       38354           523           8   10.554614
#
#            MEAN(loans.loan_amount)  MEAN(loans.rate)  MAX(loans.loan_amount)  \
# client_id
# 25707                  7963.950000          3.477000                   13913
# 26326                  7270.062500          2.517500                   13464
# 26695                  7824.722222          2.466111                   14865
# 26945                  7125.933333          2.855333                   14593
# 29841                  9813.000000          3.445000                   14837
#
#            MAX(loans.rate)  LAST(loans.loan_id) LAST(loans.loan_type)  ...  \
# client_id                                                              ...
# 25707                 9.44                10363                  home  ...
# 26326                 6.73                11072                credit  ...
# 26695                 6.51                10985                 other  ...
# 26945                 5.65                11482                  cash  ...
# 29841                 6.76                11188                  home  ...
#
#            LAST(payments.payment_amount) / MAX(payments.payment_amount)  \
# client_id
# 25707                                                          0.089127
# 26326                                                          0.350640
# 26695                                                          0.710778
# 26945                                                          0.576951
# 29841                                                          0.276052
#
#            log_income / join_month - log_income  \
# client_id
# 25707                                 -5.421626
# 26326                                 -1.681501
# 26695                                 -2.965668
# 26945                                 -9.619747
# 29841                                 -4.131588
#
#            credit_score / income - join_month  \
# client_id
# 25707                                0.002937
# 26326                                0.002777
# 26695                                0.003896
# 26945                                0.003757
# 29841                                0.013639
#
#            MAX(payments.payment_amount) / MEAN(loans.loan_amount)  \
# client_id
# 25707                                                    0.339530
# 26326                                                    0.365609
# 26695                                                    0.374710
# 26945                                                    0.388440
# 29841                                                    0.295323
#
#            credit_score - log_income / income  \
# client_id
# 25707                                0.002879
# 26326                                0.002723
# 26695                                0.003827
# 26945                                0.003700
# 29841                                0.013361
#
#            income - join_month / MAX(loans.rate)  \
# client_id
# 25707                               22395.338983
# 26326                               33865.527489
# 26695                               26808.602151
# 26945                               37965.486726
# 29841                                5672.485207
#
#            MAX(loans.loan_amount) / MEAN(loans.rate)  \
# client_id
# 25707                                    4001.438021
# 26326                                    5348.162860
# 26695                                    6027.708943
# 26945                                    5110.786832
# 29841                                    4306.821480
#
#            income / MAX(loans.loan_amount)  \
# client_id
# 25707                            15.196004
# 26326                            16.928105
# 26695                            11.741137
# 26945                            14.699925
# 29841                             2.585024
#
#            LAST(payments.payment_amount) / MEAN(loans.rate)  \
# client_id
# 25707                                             69.312626
# 26326                                            370.208540
# 26695                                            845.055193
# 26945                                            559.304226
# 29841                                            232.220610
#
#            income - log_income / income - join_month
# client_id
# 25707                                       0.999989
# 26326                                       0.999968
# 26695                                       0.999977
# 26945                                       0.999994
# 29841                                       0.999933
#
# [5 rows x 466 columns]

# %% [markdown]
# ### Deep Feature Synthesis
#
# While feature primitives are useful by themselves, the main benefit of using featuretools arises when we stack primitives to get deep features. The depth of a feature is simply the number of primitives required to make a feature. So, a feature that relies on a single aggregation would be a deep feature with a depth of 1, a feature that stacks two primitives would have a depth of 2 and so on. The idea itself is lot simpler than the name "deep feature synthesis" implies. (I think the authors were trying to ride the way of deep neural network hype when they named the method!) To read more about deep feature synthesis, check out [the documentation](https://docs.featuretools.com/automated_feature_engineering/afe.html) or the [original paper by Max Kanter et al](http://www.jmaxkanter.com/static/papers/DSAA_DSM_2015.pdf).
#
# Already in the dataframe we made by specifying the primitives manually we can see the idea of feature depth. For instance, the MEAN(loans.loan_amount) feature has a depth of 1 because it is made by applying a single aggregation primitive. This feature represents the average size of a client's previous loans.

# %%
# Show a feature with a depth of 1
pd.DataFrame(features['MEAN(loans.loan_amount)'].head(10))
# Out:
#            MEAN(loans.loan_amount)
# client_id
# 25707                  7963.950000
# 26326                  7270.062500
# 26695                  7824.722222
# 26945                  7125.933333
# 29841                  9813.000000
# 32726                  6633.263158
# 32885                  9920.400000
# 32961                  7882.235294
# 35089                  6939.200000
# 35214                  7173.555556

# %%
# Show a feature with a depth of 2
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head(10))
# Out:
#            LAST(loans.MEAN(payments.payment_amount))
# client_id
# 25707                                     293.500000
# 26326                                     977.375000
# 26695                                    1769.166667
# 26945                                    1598.666667
# 29841                                    1125.500000
# 32726                                     799.500000
# 32885                                    1729.000000
# 32961                                     282.600000
# 35089                                     110.400000
# 35214                                    1410.250000

# %% [markdown]
# We can create features of arbitrary depth by stacking more primitives.
# __However, when I have used featuretools I've never gone beyond a depth of 2!__
#
# After this point, the features become very convoluted to understand. I'd encourage anyone interested to experiment with increasing the depth (maybe for a real problem) and see if there is value to "going deeper".

# %% [markdown]
# ### Automated Deep Feature Synthesis
#
# In addition to manually specifying aggregation and transformation feature primitives, we can let featuretools automatically generate many new features. We do this by making the same `ft.dfs` function call, but without passing in any primitives. We just set the `max_depth` parameter and featuretools will automatically try many all combinations of feature primitives to the ordered depth.
#
# When running on large datasets, this process can take quite a while, but for our example data, it will be relatively quick. For this call, we only need to specify the `entityset`, the `target_entity` (which will again be `clients`), and the `max_depth`.

# %%
# Perform deep feature synthesis without specifying primitives
features, feature_names = ft.dfs(entityset=es, target_entity='clients', 
                                 max_depth = 2)

# %%
features.head()
# Out:
#            income  credit_score  join_month  log_income  \
# client_id
# 25707      211422           621          10   12.261611
# 26326      227920           633           5   12.336750
# 26695      174532           680           8   12.069863
# 26945      214516           806          11   12.276140
# 29841       38354           523           8   10.554614
#
#            SUM(loans.loan_amount)  SUM(loans.rate)  STD(loans.loan_amount)  \
# client_id
# 25707                      159279            69.54             4149.486062
# 26326                      116321            40.28             4393.666631
# 26695                      140845            44.39             4196.462499
# 26945                      106889            42.83             4543.621769
# 29841                      176634            62.01             4209.224171
#
#            STD(loans.rate)  MAX(loans.loan_amount)  MAX(loans.rate)  ...  \
# client_id                                                            ...
# 25707             2.484186                   13913             9.44  ...
# 26326             2.057142                   13464             6.73  ...
# 26695             1.561659                   14865             6.51  ...
# 26945             1.619717                   14593             5.65  ...
# 29841             2.122904                   14837             6.76  ...
#
#            NUM_UNIQUE(loans.WEEKDAY(loan_end))  \
# client_id
# 25707                                        6
# 26326                                        5
# 26695                                        6
# 26945                                        6
# 29841                                        7
#
#            MODE(loans.MODE(payments.missed))  MODE(loans.DAY(loan_start))  \
# client_id
# 25707                                      0                           27
# 26326                                      0                            6
# 26695                                      0                            3
# 26945                                      0                           16
# 29841                                      1                            1
#
#            MODE(loans.DAY(loan_end))  MODE(loans.YEAR(loan_start))  \
# client_id
# 25707                              1                          2010
# 26326                              6                          2003
# 26695                             14                          2003
# 26945                              1                          2002
# 29841                             15                          2005
#
#            MODE(loans.YEAR(loan_end))  MODE(loans.MONTH(loan_start))  \
# client_id
# 25707                            2007                              1
# 26326                            2005                              4
# 26695                            2005                              9
# 26945                            2004                             12
# 29841                            2007                              3
#
#            MODE(loans.MONTH(loan_end))  MODE(loans.WEEKDAY(loan_start))  \
# client_id
# 25707                                8                                3
# 26326                                7                                5
# 26695                                4                                1
# 26945                                5                                0
# 29841                                2                                5
#
#           MODE(loans.WEEKDAY(loan_end))
# client_id
# 25707                                 0
# 26326                                 2
# 26695                                 1
# 26945                                 1
# 29841                                 1
#
# [5 rows x 94 columns]

# %% [markdown]
# ### Next Steps
#
# While automatic feature engineering solves one problem, it provides us with another problem: too many features! Although it's difficult to say which features will be important to a given machine learning task ahead of time, it's likely that not all of the features made by featuretools add value. In fact, having too many features is a significant issue in machine learning because it makes training a model much harder. The [irrelevant features can drown out the important features](https://pdfs.semanticscholar.org/a83b/ddb34618cc68f1014ca12eef7f537825d104.pdf), leaving a model unable to learn how to map the features to the target.
#
# This problem is known as the ["curse of dimensionality"](https://en.wikipedia.org/wiki/Curse_of_dimensionality#Machine_learning) and is addressed through the process of [feature reduction and selection](http://scikit-learn.org/stable/modules/feature_selection.html), which means [removing low-value features](https://machinelearningmastery.com/feature-selection-machine-learning-python/) from the data. Defining which features are useful is an important problem where a data scientist can still add considerable value to the feature engineering task. Feature reduction will have to be another topic for another day!

# %% [markdown]
# ### Conclusions
#
# In this notebook, we saw how to apply automated feature engineering to an example dataset. This is a powerful method which allows us to overcome the human limits of time and imagination to create many new features from multiple tables of data. Featuretools is built on the idea of deep feature synthesis, which means stacking multiple simple feature primitives - __aggregations and transformations__ - to create new features. Feature engineering allows us to combine information across many tables into a single dataframe that we can then use for machine learning model training. Finally, the next step after creating all of these features is figuring out which ones are important.
#
# Featuretools is currently the only Python option for this process, but with the recent emphasis on automating aspects of the machine learning pipeline, other competitiors will probably enter the sphere. While the exact tools will change, the idea of automatically creating new features out of existing data will grow in importance. Staying up-to-date on methods such as automated feature engineering is crucial in the rapidly changing field of data science. Now go out there and find a problem on which to apply featuretools!
#
# For more information, check out the [documentation for featuretools](https://docs.featuretools.com/index.html). Also, read about how featuretools is [used in the real world by Feature Labs](https://www.featurelabs.com/), the company behind the open-source library.
