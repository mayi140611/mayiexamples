# %% [markdown]
# * 序列化
# – 将python对象转化为json
# 格式的字符串
# * 反序列化
# – 将json格式的字符串转化为
# python对象
# * 推荐使用ujson
#
# ![image.png](attachment:image.png)

# %%
import json

# %%
# !pip install ujson
# Out:
# Collecting ujson
#   Downloading https://files.pythonhosted.org/packages/16/c4/79f3409bc710559015464e5f49b9879430d8f87498ecdc335899732e5377/ujson-1.35.tar.gz (192kB)
#      |████████████████████████████████| 194kB 534kB/s eta 0:00:01
# Building wheels for collected packages: ujson
#   Building wheel for ujson (setup.py) ... done
#   Stored in directory: /Users/luoyonggui/Library/Caches/pip/wheels/28/77/e4/0311145b9c2e2f01470e744855131f9e34d6919687550f87d1
# Successfully built ujson
# Installing collected packages: ujson
# Successfully installed ujson-1.35

# %%
try:
    import ujson as json
    print('ujson')
except:
    import json
# Out:
# ujson

# %%
data = {"spam" : "foo", "parrot" : 42}

# %% [markdown]
# ### 把dict对象编码为json字符串

# %%
in_json = json.dumps(data) # Encode the data
in_json
# Out:
# '{"spam":"foo","parrot":42}'

# %% [markdown]
# ### 把json字符串解码为dict对象

# %%
json.loads(in_json) # Decode into a Python object
# Out:
# {'spam': 'foo', 'parrot': 42}

# %% [markdown]
# ### 把数据写入json文件

# %%
with open('data1.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False)

# %% [markdown]
# {"spam":"foo","parrot":42}

# %% [markdown]
# ### 从json文件中读入json

# %%
with open('data1.json', 'r', encoding='utf-8') as f:
    data1 = json.load(f)
data1
# Out:
# {'spam': 'foo', 'parrot': 42}
