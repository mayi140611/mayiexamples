# %% [markdown]
# # hw01

# %% [markdown]
# ## 1. 部署好学习环境，安装好交易系统，并上传截图。
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. 说一下想在这门课程中学到什么，或者简单介绍自己的投资经验
# 主要想学习一下炒股的常见理论，还用常用的指标如何应用

# %% [markdown]
# # lesson02
# 量比是衡量相对成交量的指标。它是指股市开市后平均每分钟的成交量与过去5个交易日平均每分钟成交量之比。其计算公式为：量比=（现成交总手数 / 现累计开市时间(分) ）/ 过去5日平均每分钟成交量。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 缩量最真实。缩量代表一种共识
# 因为，放量可以通过对倒来制造出来。

# %% [markdown]
# ### 股价低位缩量
# 表示多空双方都不愿意入场

# %% [markdown]
# ## hw02

# %% [markdown]
# ### 1.量价分析中应该深入考虑的是什么？
#
# 我觉得应该多考虑量价关系背后的多空力量的转化。

# %% [markdown]
# ### 2.为什么放量上涨后的缩量回落是健康的？
#
# 股票走势是一种多空博弈。当多头制造一波上涨后，缩量回调代表空头力量较弱，所以是比较健康的。

# %% [markdown]
# ### 3.请自己设置一个止盈与止损的操作策略。
# 当低位震荡时，静静观察；
#
# 当股价上涨突破时，平衡被打破，等待第一波上涨过后，如果股价缩量回调，建仓；
#
# 当股价创新高，量能没有创新高；或者量能创新高，股价没有创新高时，平仓。

# %% [markdown]
# # hw03

# %% [markdown]
# ## 1.描述均线的定义以及均线的作用
#
# 均线的定义： 近n日股票收盘价的平均。
#
# 均线的作用： 可以反映近n日股票收盘价的平均值

# %% [markdown]
# ## 2.将均线指标修改为7,50,125指标并截图
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.描述均线系统的缺点
#
# 最大的缺点是滞后性。常常会造成：股价上涨一段时间以后，均线才能反映；股价下跌一段时间后，均线才能反映。
#
# 如果遇到震荡行情，就会被反复打脸。。。

# %% [markdown]
# # hw05

# %% [markdown]
# ## 1.请描述MACD的使用方法
#
# 第一种方法：当短期均线下穿长期均线（死叉）时卖出，当短期均线上穿长期均线（金叉）时买入
# 第二种方法：看背离，当本次上涨创新高，而红柱子比上次短时，说明发生背离，可以卖出

# %% [markdown]
# ## 2.请找出任意一个MACD的顶背离与底背离，并截图
# ![image.png](attachment:image.png)
