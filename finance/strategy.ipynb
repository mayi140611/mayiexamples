# %% [markdown]
# # 均线策略SMA
# 本质是趋势交易
#
# 当短期均线 上穿 长期均线是买入；相反是卖出
#
# 本质：是让价格的反应变得迟钝，均线周期越长，价格的反应就越迟钝!
#
# 迟钝的好处是平抑了一些扰动，降低交易次数；缺点是：反应迟钝，往往会造成
# 1. 当短期均线刚上穿长期均线时，股票已经上涨了很多（有可能上涨趋势已经结束),
# 1. 当短期均线下穿长期均线时，股价已经下跌很多(损失了很多利润)
#
# 为了避免情况1，短期均线不能太长，这样可以对短期股票走势会灵敏一些，上涨时可以很快的上穿长期均线，下跌时也可以快速下穿
#
# 长期均线不能太短，应该在股票的整个上涨走势中保持平稳缓慢上升，否则交易频率会上升。那么怎么避免卖出时，收益出现大幅回撤呢？
#
# 有什么业务含义做解释或者支持？
#
# 股价有时候会受到意外情况，而剧烈波动，使用短期均线会平抑这种扰动。但是好像找不到其它的解释了呢。。。
#
# 所以，不能使用。。。

# %%
import sys
sys.path.append('/Users/luoyonggui/PycharmProjects/mayifactories/finance/strategy')
from sma import SMA
# %matplotlib inline

# %%
SMA.sma_base('中国石油', count=365, fast_ma=8, slow_ma=60)
# Out:
# returns    0.822696
# strat      1.004672
# dtype: float64
# returns    0.012148
# strat      0.009556
# dtype: float64
# hold_max_drawdown: -0.34092899381273034
# strat_max_drawdown: -0.14080444286393612

# %%
SMA.stock_select('浦发银行')
# Out:
#                  net   slow_ma
# trade_date
# 2019-09-24  1.015558       NaN
# 2019-09-25  1.020744       NaN
# 2019-09-26  1.034573       NaN
# 2019-09-27  1.028523       NaN
# 2019-09-30  1.023337  0.998905
# True

# %%
SMA.sma_base('万华化学')
# Out:
# returns    1.011633
# strat      1.259781
# dtype: float64
# returns    0.027567
# strat      0.020059
# dtype: float64
# hold_max_drawdown: -0.49155782425327466
# strat_max_drawdown: -0.2523808279755062

# %%
SMA.stocks_select(SMA.get_stocks_dict_top_n(800, '20191010'))
# Out:
# 2019-10-16 17:30:52.399535
# 股票池容量：800
# 0, 工商银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.992870       NaN
# 2019-10-11  1.005347       NaN
# 2019-10-14  1.019607       NaN
# 2019-10-15  1.019607       NaN
# 2019-10-16  1.019607  0.985621
# 1, 建设银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.994430       NaN
# 2019-10-11  1.004179       NaN
# 2019-10-14  1.016715       NaN
# 2019-10-15  1.025071       NaN
# 2019-10-16  1.012536  0.990947
# 2, 中国平安
#                  net   slow_ma
# trade_date
# 2019-10-10  1.026553       NaN
# 2019-10-11  1.042792       NaN
# 2019-10-14  1.049172       NaN
# 2019-10-15  1.046272       NaN
# 2019-10-16  1.050680  1.017613
# 3, 贵州茅台
#                  net   slow_ma
# trade_date
# 2019-10-10  1.193181       NaN
# 2019-10-11  1.213429       NaN
# 2019-10-14  1.219007       NaN
# 2019-10-15  1.251032       NaN
# 2019-10-16  1.208677  1.108825
# 4, 农业银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.974860       NaN
# 2019-10-11  0.986033       NaN
# 2019-10-14  0.994413       NaN
# 2019-10-15  1.000000       NaN
# 2019-10-16  1.002793  0.975139
# 5, 中国石油
#                  net   slow_ma
# trade_date
# 2019-10-10  0.931658       NaN
# 2019-10-11  0.943897       NaN
# 2019-10-14  0.942367       NaN
# 2019-10-15  0.934717       NaN
# 2019-10-16  0.931658  0.947982
# 6, 中国银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.975611       NaN
# 2019-10-11  0.986451       NaN
# 2019-10-14  0.994581       NaN
# 2019-10-15  0.997291       NaN
# 2019-10-16  1.000001  0.978546
# 7, 招商银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.994336       NaN
# 2019-10-11  1.027755       NaN
# 2019-10-14  1.043048       NaN
# 2019-10-15  1.037667       NaN
# 2019-10-16  1.042482  1.001284
# 8, 中国人寿
#                  net   slow_ma
# trade_date
# 2019-10-10  0.926980       NaN
# 2019-10-11  0.942911       NaN
# 2019-10-14  0.963156       NaN
# 2019-10-15  0.964152       NaN
# 2019-10-16  0.971122  0.961532
# 9, 中国石化
#                  net   slow_ma
# trade_date
# 2019-10-10  0.965042       NaN
# 2019-10-11  0.980483       NaN
# 2019-10-14  0.980483       NaN
# 2019-10-15  0.972763       NaN
# 2019-10-16  0.974693  0.967037
# 10, 五粮液
#                  net   slow_ma
# trade_date
# 2019-10-10  1.059959       NaN
# 2019-10-11  1.062063       NaN
# 2019-10-14  1.058907       NaN
# 2019-10-15  1.073715       NaN
# 2019-10-16  1.053000  1.044935
# 11, 交通银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.953448       NaN
# 2019-10-11  0.963792       NaN
# 2019-10-14  0.982758       NaN
# 2019-10-15  0.986206       NaN
# 2019-10-16  0.984483  0.961293
# 12, 长江电力
#                  net   slow_ma
# trade_date
# 2019-10-10  1.046518       NaN
# 2019-10-11  1.053977       NaN
# 2019-10-14  1.045945       NaN
# 2019-10-15  1.027011       NaN
# 2019-10-16  1.021847  1.065433
# 13, 中国人保
#                  net   slow_ma
# trade_date
# 2019-10-10  0.953357       NaN
# 2019-10-11  0.961010       NaN
# 2019-10-14  0.988342       NaN
# 2019-10-15  0.973036       NaN
# 2019-10-16  0.988342  0.958266
# 14, 兴业银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.008254       NaN
# 2019-10-11  1.026966       NaN
# 2019-10-14  1.046229       NaN
# 2019-10-15  1.049530       NaN
# 2019-10-16  1.050080  0.998723
# 15, 中国神华
#                  net  slow_ma
# trade_date
# 2019-10-10  0.986368      NaN
# 2019-10-11  0.992136      NaN
# 2019-10-14  0.993185      NaN
# 2019-10-15  0.979550      NaN
# 2019-10-16  0.975355   0.9944
# 16, 恒瑞医药
#                  net   slow_ma
# trade_date
# 2019-10-10  1.256432       NaN
# 2019-10-11  1.262336       NaN
# 2019-10-14  1.264910       NaN
# 2019-10-15  1.290493       NaN
# 2019-10-16  1.301392  1.126284
# 17, 美的集团
#                  net   slow_ma
# trade_date
# 2019-10-10  0.974960       NaN
# 2019-10-11  0.988786       NaN
# 2019-10-14  0.998689       NaN
# 2019-10-15  0.999063       NaN
# 2019-10-16  1.002612  0.981958
# 18, 浦发银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.035499       NaN
# 2019-10-11  1.077924       NaN
# 2019-10-14  1.120347       NaN
# 2019-10-15  1.133334       NaN
# 2019-10-16  1.132469  1.011256
# 19, 格力电器
#                  net   slow_ma
# trade_date
# 2019-10-10  1.083589       NaN
# 2019-10-11  1.099736       NaN
# 2019-10-14  1.102178       NaN
# 2019-10-15  1.105933       NaN
# 2019-10-16  1.108186  1.038186
# 20, 中国太保
#                  net   slow_ma
# trade_date
# 2019-10-10  0.972170       NaN
# 2019-10-11  0.987048       NaN
# 2019-10-14  1.003278       NaN
# 2019-10-15  0.998680       NaN
# 2019-10-16  0.994351  1.013167
# 21, 平安银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.181088       NaN
# 2019-10-11  1.222543       NaN
# 2019-10-14  1.252361       NaN
# 2019-10-15  1.249452       NaN
# 2019-10-16  1.221088  1.072557
# 22, 万科A
#                  net   slow_ma
# trade_date
# 2019-10-10  0.921213       NaN
# 2019-10-11  0.927787       NaN
# 2019-10-14  0.938515       NaN
# 2019-10-15  0.926403       NaN
# 2019-10-16  0.936785  0.934769
# 23, 海天味业
#                  net   slow_ma
# trade_date
# 2019-10-10  1.094156       NaN
# 2019-10-11  1.099747       NaN
# 2019-10-14  1.101844       NaN
# 2019-10-15  1.100846       NaN
# 2019-10-16  1.098349  1.057294
# 24, 工业富联
#                  net   slow_ma
# trade_date
# 2019-10-10  1.156407       NaN
# 2019-10-11  1.170625       NaN
# 2019-10-14  1.200641       NaN
# 2019-10-15  1.177734       NaN
# 2019-10-16  1.166675  1.114605
# 25, 中信银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.034965       NaN
# 2019-10-11  1.048951       NaN
# 2019-10-14  1.071679       NaN
# 2019-10-15  1.066434       NaN
# 2019-10-16  1.061189  1.000965
# 26, 海康威视
#                  net   slow_ma
# trade_date
# 2019-10-10  1.145716       NaN
# 2019-10-11  1.137558       NaN
# 2019-10-14  1.148311       NaN
# 2019-10-15  1.123839       NaN
# 2019-10-16  1.137187  1.151568
# 27, 上汽集团
#                  net   slow_ma
# trade_date
# 2019-10-10  0.997918       NaN
# 2019-10-11  0.998752       NaN
# 2019-10-14  1.017951       NaN
# 2019-10-15  0.998753       NaN
# 2019-10-16  1.007934  1.018903
# 28, 中信证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.970429       NaN
# 2019-10-11  0.994267       NaN
# 2019-10-14  1.000769       NaN
# 2019-10-15  0.983431       NaN
# 2019-10-16  0.977797  0.981571
# 29, 民生银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.018332       NaN
# 2019-10-11  1.028332       NaN
# 2019-10-14  1.044999       NaN
# 2019-10-15  1.043332       NaN
# 2019-10-16  1.038332  0.995943
# 30, 中国建筑
#                  net   slow_ma
# trade_date
# 2019-10-10  0.919461       NaN
# 2019-10-11  0.924494       NaN
# 2019-10-14  0.932883       NaN
# 2019-10-15  0.921138       NaN
# 2019-10-16  0.922815  0.949523
# 31, 迈瑞医疗
#                  net   slow_ma
# trade_date
# 2019-10-10  1.198147       NaN
# 2019-10-11  1.180858       NaN
# 2019-10-14  1.165640       NaN
# 2019-10-15  1.164604       NaN
# 2019-10-16  1.114613  1.120124
# 32, 光大银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.121055       NaN
# 2019-10-11  1.134212       NaN
# 2019-10-14  1.210528       NaN
# 2019-10-15  1.215791       NaN
# 2019-10-16  1.197370  1.027414
# 33, 海螺水泥
#                  net   slow_ma
# trade_date
# 2019-10-10  1.019074       NaN
# 2019-10-11  1.057705       NaN
# 2019-10-14  1.055015       NaN
# 2019-10-15  1.041078       NaN
# 2019-10-16  1.041078  0.994313
# 34, 中国广核
#                  net  slow_ma
# trade_date
# 2019-10-10  1.682732      NaN
# 2019-10-11  1.682732      NaN
# 2019-10-14  1.694780      NaN
# 2019-10-15  1.670684      NaN
# 2019-10-16  1.654620      NaN
# 35, 中国中车
#                  net   slow_ma
# trade_date
# 2019-10-10  0.945530       NaN
# 2019-10-11  0.953291       NaN
# 2019-10-14  0.961051       NaN
# 2019-10-15  0.954584       NaN
# 2019-10-16  0.951998  0.964781
# 36, 温氏股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.966899       NaN
# 2019-10-11  0.960628       NaN
# 2019-10-14  0.943071       NaN
# 2019-10-15  0.940562       NaN
# 2019-10-16  0.929276  0.989489
# 37, 中国联通
#                  net   slow_ma
# trade_date
# 2019-10-10  1.015001       NaN
# 2019-10-11  1.020001       NaN
# 2019-10-14  1.025001       NaN
# 2019-10-15  1.031668       NaN
# 2019-10-16  1.016667  0.994751
# 38, 保利地产
#                  net   slow_ma
# trade_date
# 2019-10-10  1.157543       NaN
# 2019-10-11  1.161981       NaN
# 2019-10-14  1.153845       NaN
# 2019-10-15  1.153845       NaN
# 2019-10-16  1.168638  1.056435
# 39, 中国国旅
#                  net   slow_ma
# trade_date
# 2019-10-10  1.105334       NaN
# 2019-10-11  1.099882       NaN
# 2019-10-14  1.097793       NaN
# 2019-10-15  1.105682       NaN
# 2019-10-16  1.110206  1.061379
# 40, 中信建投
#                  net   slow_ma
# trade_date
# 2019-10-10  1.213852       NaN
# 2019-10-11  1.268752       NaN
# 2019-10-14  1.252131       NaN
# 2019-10-15  1.239540       NaN
# 2019-10-16  1.181114  1.052926
# 41, 顺丰控股
#                  net   slow_ma
# trade_date
# 2019-10-10  1.223548       NaN
# 2019-10-11  1.230683       NaN
# 2019-10-14  1.230088       NaN
# 2019-10-15  1.227710       NaN
# 2019-10-16  1.235737  1.134624
# 42, 牧原股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.200202       NaN
# 2019-10-11  1.204446       NaN
# 2019-10-14  1.216886       NaN
# 2019-10-15  1.226252       NaN
# 2019-10-16  1.205178  1.090004
# 43, 伊利股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.870906       NaN
# 2019-10-11  0.865706       NaN
# 2019-10-14  0.872742       NaN
# 2019-10-15  0.875189       NaN
# 2019-10-16  0.865094  0.899148
# 44, 华泰证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.905165       NaN
# 2019-10-11  0.923123       NaN
# 2019-10-14  0.926035       NaN
# 2019-10-15  0.902254       NaN
# 2019-10-16  0.894974  0.953072
# 45, 海通证券
#                  net   slow_ma
# trade_date
# 2019-10-10  1.047648       NaN
# 2019-10-11  1.081606       NaN
# 2019-10-14  1.095334       NaN
# 2019-10-15  1.089554       NaN
# 2019-10-16  1.085941  1.022127
# 46, 三六零
#                  net   slow_ma
# trade_date
# 2019-10-10  1.177295       NaN
# 2019-10-11  1.232988       NaN
# 2019-10-14  1.229599       NaN
# 2019-10-15  1.163737       NaN
# 2019-10-16  1.146787  1.043956
# 47, 中国交建
#                  net   slow_ma
# trade_date
# 2019-10-10  0.913433       NaN
# 2019-10-11  0.917941       NaN
# 2019-10-14  0.923352       NaN
# 2019-10-15  0.912531       NaN
# 2019-10-16  0.914334  0.944213
# 48, 招商蛇口
#                  net   slow_ma
# trade_date
# 2019-10-10  0.953799       NaN
# 2019-10-11  0.961980       NaN
# 2019-10-14  0.972085       NaN
# 2019-10-15  0.960536       NaN
# 2019-10-16  0.969198  0.965004
# 49, 宁德时代
#                  net   slow_ma
# trade_date
# 2019-10-10  0.975516       NaN
# 2019-10-11  0.983221       NaN
# 2019-10-14  0.974828       NaN
# 2019-10-15  0.976479       NaN
# 2019-10-16  0.958868  1.012699
# 50, 国泰君安
#                  net   slow_ma
# trade_date
# 2019-10-10  0.980667       NaN
# 2019-10-11  0.996918       NaN
# 2019-10-14  1.013169       NaN
# 2019-10-15  1.007565       NaN
# 2019-10-16  1.005883  0.989318
# 51, 上海机场
#                  net   slow_ma
# trade_date
# 2019-10-10  1.018970       NaN
# 2019-10-11  1.016184       NaN
# 2019-10-14  1.003144       NaN
# 2019-10-15  0.991116       NaN
# 2019-10-16  0.990736  1.039084
# 52, 新华保险
#                  net   slow_ma
# trade_date
# 2019-10-10  0.929337       NaN
# 2019-10-11  0.939636       NaN
# 2019-10-14  0.950309       NaN
# 2019-10-15  0.943567       NaN
# 2019-10-16  0.943754  0.960127
# 53, 洋河股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.801936       NaN
# 2019-10-11  0.806263       NaN
# 2019-10-14  0.816252       NaN
# 2019-10-15  0.812949       NaN
# 2019-10-16  0.810432  0.859666
# 54, 宁波银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.203122       NaN
# 2019-10-11  1.229014       NaN
# 2019-10-14  1.223211       NaN
# 2019-10-15  1.210711       NaN
# 2019-10-16  1.204015  1.067834
# 55, 中国中铁
#                  net  slow_ma
# trade_date
# 2019-10-10  0.949867      NaN
# 2019-10-11  0.951440      NaN
# 2019-10-14  0.956158      NaN
# 2019-10-15  0.948295      NaN
# 2019-10-16  0.948295  0.96674
# 56, 立讯精密
#                  net  slow_ma
# trade_date
# 2019-10-10  1.344434      NaN
# 2019-10-11  1.351889      NaN
# 2019-10-14  1.411531      NaN
# 2019-10-15  1.399603      NaN
# 2019-10-16  1.384194  1.20512
# 57, 药明康德
#                  net   slow_ma
# trade_date
# 2019-10-10  1.360526       NaN
# 2019-10-11  1.366695       NaN
# 2019-10-14  1.361606       NaN
# 2019-10-15  1.356980       NaN
# 2019-10-16  1.360527  1.181545
# 58, 中兴通讯
#                  net   slow_ma
# trade_date
# 2019-10-10  0.998175       NaN
# 2019-10-11  0.999086       NaN
# 2019-10-14  1.000909       NaN
# 2019-10-15  0.973274       NaN
# 2019-10-16  0.972060  0.964691
# 59, 万华化学
#                  net   slow_ma
# trade_date
# 2019-10-10  1.067311       NaN
# 2019-10-11  1.080338       NaN
# 2019-10-14  1.088541       NaN
# 2019-10-15  1.060074       NaN
# 2019-10-16  1.063211  1.062329
# 60, 上海银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.080221       NaN
# 2019-10-11  1.083611       NaN
# 2019-10-14  1.102820       NaN
# 2019-10-15  1.127679       NaN
# 2019-10-16  1.108470  1.035967
# 61, 上港集团
#                  net   slow_ma
# trade_date
# 2019-10-10  0.883968       NaN
# 2019-10-11  0.900761       NaN
# 2019-10-14  0.909921       NaN
# 2019-10-15  0.897707       NaN
# 2019-10-16  0.894654  0.946132
# 62, 比亚迪
#                  net   slow_ma
# trade_date
# 2019-10-10  0.897648       NaN
# 2019-10-11  0.887206       NaN
# 2019-10-14  0.894899       NaN
# 2019-10-15  0.879328       NaN
# 2019-10-16  0.870535  0.937369
# 63, 宝钢股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.947201       NaN
# 2019-10-11  0.953602       NaN
# 2019-10-14  0.960001       NaN
# 2019-10-15  0.955201       NaN
# 2019-10-16  0.952001  0.967334
# 64, 京东方A
#                  net   slow_ma
# trade_date
# 2019-10-10  0.952018       NaN
# 2019-10-11  0.949492       NaN
# 2019-10-14  0.959593       NaN
# 2019-10-15  0.944442       NaN
# 2019-10-16  0.939391  0.983753
# 65, 中国铁建
#                  net   slow_ma
# trade_date
# 2019-10-10  1.003324       NaN
# 2019-10-11  1.009563       NaN
# 2019-10-14  1.012682       NaN
# 2019-10-15  1.010603       NaN
# 2019-10-16  1.014762  0.995173
# 66, 广汽集团
#                  net   slow_ma
# trade_date
# 2019-10-10  1.127856       NaN
# 2019-10-11  1.145916       NaN
# 2019-10-14  1.216351       NaN
# 2019-10-15  1.183843       NaN
# 2019-10-16  1.173007  1.042617
# 67, 泸州老窖
#                  net   slow_ma
# trade_date
# 2019-10-10  1.039570       NaN
# 2019-10-11  1.051443       NaN
# 2019-10-14  1.051323       NaN
# 2019-10-15  1.059358       NaN
# 2019-10-16  1.029256  1.027924
# 68, 中国重工
#                  net   slow_ma
# trade_date
# 2019-10-10  0.907888       NaN
# 2019-10-11  0.906243       NaN
# 2019-10-14  0.922690       NaN
# 2019-10-15  0.911177       NaN
# 2019-10-16  0.902954  0.963673
# 69, 三一重工
#                  net   slow_ma
# trade_date
# 2019-10-10  1.095744       NaN
# 2019-10-11  1.120820       NaN
# 2019-10-14  1.122340       NaN
# 2019-10-15  1.140577       NaN
# 2019-10-16  1.129939  1.068515
# 70, 申万宏源
#                  net   slow_ma
# trade_date
# 2019-10-10  0.963925       NaN
# 2019-10-11  0.971941       NaN
# 2019-10-14  0.983965       NaN
# 2019-10-15  0.973945       NaN
# 2019-10-16  0.983965  0.973946
# 71, 中国国航
#                  net  slow_ma
# trade_date
# 2019-10-10  0.891920      NaN
# 2019-10-11  0.914846      NaN
# 2019-10-14  0.925763      NaN
# 2019-10-15  0.917029      NaN
# 2019-10-16  0.913755  0.90826
# 72, 华夏银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.000002       NaN
# 2019-10-11  1.010626       NaN
# 2019-10-14  1.031874       NaN
# 2019-10-15  1.031874       NaN
# 2019-10-16  1.022578  0.987186
# 73, 北京银行
#                  net   slow_ma
# trade_date
# 2019-10-10  0.971579       NaN
# 2019-10-11  0.984012       NaN
# 2019-10-14  1.001775       NaN
# 2019-10-15  1.007103       NaN
# 2019-10-16  0.998223  0.963675
# 74, 爱尔眼科
#                  net   slow_ma
# trade_date
# 2019-10-10  1.208932       NaN
# 2019-10-11  1.201705       NaN
# 2019-10-14  1.202362       NaN
# 2019-10-15  1.222072       NaN
# 2019-10-16  1.247697  1.084152
# 75, 大秦铁路
#                  net  slow_ma
# trade_date
# 2019-10-10  0.969385      NaN
# 2019-10-11  0.973212      NaN
# 2019-10-14  0.979589      NaN
# 2019-10-15  0.978314      NaN
# 2019-10-16  0.984691  0.98397
# 76, 招商证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.996924       NaN
# 2019-10-11  1.017257       NaN
# 2019-10-14  1.031012       NaN
# 2019-10-15  1.022639       NaN
# 2019-10-16  1.024433  0.990305
# 77, 中油资本
#                  net   slow_ma
# trade_date
# 2019-10-10  1.041493       NaN
# 2019-10-11  1.045727       NaN
# 2019-10-14  1.099071       NaN
# 2019-10-15  1.071128       NaN
# 2019-10-16  1.078749  1.032093
# 78, 中国银河
#                  net   slow_ma
# trade_date
# 2019-10-10  0.941531       NaN
# 2019-10-11  0.954429       NaN
# 2019-10-14  0.965608       NaN
# 2019-10-15  0.944111       NaN
# 2019-10-16  0.936372  0.955374
# 79, 山东黄金
#                  net   slow_ma
# trade_date
# 2019-10-10  1.207330       NaN
# 2019-10-11  1.191543       NaN
# 2019-10-14  1.166834       NaN
# 2019-10-15  1.146243       NaN
# 2019-10-16  1.121534  1.194358
# 80, 恒力石化
#                  net   slow_ma
# trade_date
# 2019-10-10  1.285475       NaN
# 2019-10-11  1.300678       NaN
# 2019-10-14  1.359800       NaN
# 2019-10-15  1.378382       NaN
# 2019-10-16  1.413855  1.169314
# 81, 广发证券
#                  net  slow_ma
# trade_date
# 2019-10-10  0.970862      NaN
# 2019-10-11  0.987209      NaN
# 2019-10-14  1.012795      NaN
# 2019-10-15  0.998581      NaN
# 2019-10-16  0.995738  0.96521
# 82, 中公教育
#                  net   slow_ma
# trade_date
# 2019-10-10  1.280823       NaN
# 2019-10-11  1.300611       NaN
# 2019-10-14  1.360733       NaN
# 2019-10-15  1.337901       NaN
# 2019-10-16  1.385085  1.153058
# 83, 东方财富
#                  net   slow_ma
# trade_date
# 2019-10-10  1.076482       NaN
# 2019-10-11  1.094351       NaN
# 2019-10-14  1.106503       NaN
# 2019-10-15  1.110792       NaN
# 2019-10-16  1.100785  1.059481
# 84, 国信证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.904341       NaN
# 2019-10-11  0.917586       NaN
# 2019-10-14  0.930096       NaN
# 2019-10-15  0.919058       NaN
# 2019-10-16  0.920530  0.954527
# 85, 隆基股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.150650       NaN
# 2019-10-11  1.148053       NaN
# 2019-10-14  1.155412       NaN
# 2019-10-15  1.141992       NaN
# 2019-10-16  1.043723  1.135419
# 86, 海尔智家
#                  net   slow_ma
# trade_date
# 2019-10-10  0.936334       NaN
# 2019-10-11  0.938715       NaN
# 2019-10-14  0.941096       NaN
# 2019-10-15  0.930382       NaN
# 2019-10-16  0.930977  0.935046
# 87, 国电南瑞
#                  net   slow_ma
# trade_date
# 2019-10-10  1.204290       NaN
# 2019-10-11  1.201509       NaN
# 2019-10-14  1.251572       NaN
# 2019-10-15  1.210409       NaN
# 2019-10-16  1.212634  1.060605
# 88, 苏宁易购
#                  net   slow_ma
# trade_date
# 2019-10-10  0.966479       NaN
# 2019-10-11  0.962754       NaN
# 2019-10-14  0.975790       NaN
# 2019-10-15  0.982307       NaN
# 2019-10-16  0.972996  0.981487
# 89, 云南白药
#                  net   slow_ma
# trade_date
# 2019-10-10  0.942847       NaN
# 2019-10-11  0.949336       NaN
# 2019-10-14  1.044307       NaN
# 2019-10-15  1.056038       NaN
# 2019-10-16  1.024464  0.959973
# 90, 鹏鼎控股
#                  net   slow_ma
# trade_date
# 2019-10-10  1.267210       NaN
# 2019-10-11  1.274093       NaN
# 2019-10-14  1.341678       NaN
# 2019-10-15  1.354819       NaN
# 2019-10-16  1.339175  1.182071
# 91, 华能国际
#                  net  slow_ma
# trade_date
# 2019-10-10  0.919939      NaN
# 2019-10-11  0.919939      NaN
# 2019-10-14  0.918369      NaN
# 2019-10-15  0.916800      NaN
# 2019-10-16  0.913660  0.99987
# 92, 潍柴动力
#                  net   slow_ma
# trade_date
# 2019-10-10  0.959035       NaN
# 2019-10-11  0.994183       NaN
# 2019-10-14  1.021799       NaN
# 2019-10-15  1.009246       NaN
# 2019-10-16  1.011757  0.974503
# 93, 汇顶科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.341190       NaN
# 2019-10-11  1.361699       NaN
# 2019-10-14  1.350087       NaN
# 2019-10-15  1.312056       NaN
# 2019-10-16  1.316674  1.261693
# 94, 中国通号
#                  net  slow_ma
# trade_date
# 2019-10-10  1.441025      NaN
# 2019-10-11  1.430769      NaN
# 2019-10-14  1.449572      NaN
# 2019-10-15  1.427350      NaN
# 2019-10-16  1.399999      NaN
# 95, 陕西煤业
#                  net   slow_ma
# trade_date
# 2019-10-10  1.006850       NaN
# 2019-10-11  1.012558       NaN
# 2019-10-14  1.018266       NaN
# 2019-10-15  1.005708       NaN
# 2019-10-16  1.007991  1.031412
# 96, 绿地控股
#                  net   slow_ma
# trade_date
# 2019-10-10  0.997231       NaN
# 2019-10-11  1.008296       NaN
# 2019-10-14  1.009680       NaN
# 2019-10-15  1.001381       NaN
# 2019-10-16  1.009680  0.965282
# 97, 韦尔股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.702801       NaN
# 2019-10-11  1.664139       NaN
# 2019-10-14  1.742640       NaN
# 2019-10-15  1.685992       NaN
# 2019-10-16  1.678933  1.447058
# 98, 东方航空
#                  net   slow_ma
# trade_date
# 2019-10-10  0.879337       NaN
# 2019-10-11  0.887601       NaN
# 2019-10-14  0.897519       NaN
# 2019-10-15  0.899172       NaN
# 2019-10-16  0.899172  0.893883
# 99, 永辉超市
#                  net   slow_ma
# trade_date
# 2019-10-10  0.908175       NaN
# 2019-10-11  0.905148       NaN
# 2019-10-14  0.921294       NaN
# 2019-10-15  0.923312       NaN
# 2019-10-16  0.911203  0.950085
# 100, 华夏幸福
#                  net   slow_ma
# trade_date
# 2019-10-10  0.907023       NaN
# 2019-10-11  0.914825       NaN
# 2019-10-14  0.926854       NaN
# 2019-10-15  0.920678       NaN
# 2019-10-16  0.937908  0.907516
# 101, 南方航空
#                  net   slow_ma
# trade_date
# 2019-10-10  0.910340       NaN
# 2019-10-11  0.923728       NaN
# 2019-10-14  0.929082       NaN
# 2019-10-15  0.926405       NaN
# 2019-10-16  0.918372  0.920111
# 102, 中国核电
#                  net   slow_ma
# trade_date
# 2019-10-10  0.980047       NaN
# 2019-10-11  0.985542       NaN
# 2019-10-14  0.985542       NaN
# 2019-10-15  0.981879       NaN
# 2019-10-16  0.976383  0.996593
# 103, 华能水电
#                  net   slow_ma
# trade_date
# 2019-10-10  1.020363       NaN
# 2019-10-11  1.018101       NaN
# 2019-10-14  1.004527       NaN
# 2019-10-15  1.002264       NaN
# 2019-10-16  1.006790  1.032882
# 104, 双汇发展
#                  net   slow_ma
# trade_date
# 2019-10-10  0.929881       NaN
# 2019-10-11  0.927213       NaN
# 2019-10-14  0.953128       NaN
# 2019-10-15  0.963418       NaN
# 2019-10-16  0.960369  0.911682
# 105, 智飞生物
#                  net   slow_ma
# trade_date
# 2019-10-10  1.102522       NaN
# 2019-10-11  1.104732       NaN
# 2019-10-14  1.103406       NaN
# 2019-10-15  1.091475       NaN
# 2019-10-16  1.096335  1.072207
# 106, 用友网络
#                  net   slow_ma
# trade_date
# 2019-10-10  1.175829       NaN
# 2019-10-11  1.155317       NaN
# 2019-10-14  1.171435       NaN
# 2019-10-15  1.115756       NaN
# 2019-10-16  1.130774  1.136125
# 107, 新希望
#                  net   slow_ma
# trade_date
# 2019-10-10  0.943919       NaN
# 2019-10-11  0.932401       NaN
# 2019-10-14  0.932902       NaN
# 2019-10-15  0.936407       NaN
# 2019-10-16  0.920883  0.929095
# 108, 江苏银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.004398       NaN
# 2019-10-11  1.016128       NaN
# 2019-10-14  1.052785       NaN
# 2019-10-15  1.057183       NaN
# 2019-10-16  1.048385  1.000464
# 109, 韵达股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.110161       NaN
# 2019-10-11  1.098449       NaN
# 2019-10-14  1.112061       NaN
# 2019-10-15  1.117442       NaN
# 2019-10-16  1.122190  1.115742
# 110, 洛阳钼业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.932816       NaN
# 2019-10-11  0.935400       NaN
# 2019-10-14  0.943152       NaN
# 2019-10-15  0.930231       NaN
# 2019-10-16  0.919896  0.953229
# 111, 紫金矿业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.932772       NaN
# 2019-10-11  0.935573       NaN
# 2019-10-14  0.932772       NaN
# 2019-10-15  0.924369       NaN
# 2019-10-16  0.918766  0.998739
# 112, 上海电气
#                  net   slow_ma
# trade_date
# 2019-10-10  0.964570       NaN
# 2019-10-11  0.970301       NaN
# 2019-10-14  0.974121       NaN
# 2019-10-15  0.968391       NaN
# 2019-10-16  0.958841  0.981803
# 113, 分众传媒
#                  net   slow_ma
# trade_date
# 2019-10-10  1.010074       NaN
# 2019-10-11  1.012036       NaN
# 2019-10-14  1.068914       NaN
# 2019-10-15  1.041456       NaN
# 2019-10-16  1.084605  1.020558
# 114, 科大讯飞
#                  net   slow_ma
# trade_date
# 2019-10-10  1.011915       NaN
# 2019-10-11  1.008937       NaN
# 2019-10-14  1.010724       NaN
# 2019-10-15  0.986900       NaN
# 2019-10-16  1.042886  0.981196
# 115, 南京银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.075103       NaN
# 2019-10-11  1.113455       NaN
# 2019-10-14  1.127064       NaN
# 2019-10-15  1.130775       NaN
# 2019-10-16  1.130775  1.014369
# 116, 宝丰能源
#                  net   slow_ma
# trade_date
# 2019-10-10  0.886436       NaN
# 2019-10-11  0.886436       NaN
# 2019-10-14  0.890846       NaN
# 2019-10-15  0.882026       NaN
# 2019-10-16  0.880262  0.909613
# 117, 华域汽车
#                  net   slow_ma
# trade_date
# 2019-10-10  1.084708       NaN
# 2019-10-11  1.126302       NaN
# 2019-10-14  1.161352       NaN
# 2019-10-15  1.110412       NaN
# 2019-10-16  1.123031  1.093125
# 118, 东方证券
#                  net  slow_ma
# trade_date
# 2019-10-10  0.986490      NaN
# 2019-10-11  0.996143      NaN
# 2019-10-14  1.006761      NaN
# 2019-10-15  0.988420      NaN
# 2019-10-16  0.996143  0.99643
# 119, 中国电建
#                  net   slow_ma
# trade_date
# 2019-10-10  0.932076       NaN
# 2019-10-11  0.936076       NaN
# 2019-10-14  0.944077       NaN
# 2019-10-15  0.936076       NaN
# 2019-10-16  0.938076  0.958177
# 120, 领益智造
#                  net   slow_ma
# trade_date
# 2019-10-10  1.673674       NaN
# 2019-10-11  1.676905       NaN
# 2019-10-14  1.680137       NaN
# 2019-10-15  1.589668       NaN
# 2019-10-16  1.599362  1.309912
# 121, 长城汽车
#                  net   slow_ma
# trade_date
# 2019-10-10  0.904540       NaN
# 2019-10-11  0.904540       NaN
# 2019-10-14  0.919674       NaN
# 2019-10-15  0.920838       NaN
# 2019-10-16  0.916182  0.947923
# 122, 澜起科技
#                  net  slow_ma
# trade_date
# 2019-10-10  2.520162      NaN
# 2019-10-11  2.477421      NaN
# 2019-10-14  2.543550      NaN
# 2019-10-15  2.484680      NaN
# 2019-10-16  2.420163      NaN
# 123, 荣盛石化
#                  net   slow_ma
# trade_date
# 2019-10-10  0.952791       NaN
# 2019-10-11  0.952791       NaN
# 2019-10-14  0.961375       NaN
# 2019-10-15  0.963092       NaN
# 2019-10-16  0.977685  0.958657
# 124, 山西汾酒
#                  net   slow_ma
# trade_date
# 2019-10-10  1.154895       NaN
# 2019-10-11  1.173380       NaN
# 2019-10-14  1.172207       NaN
# 2019-10-15  1.266101       NaN
# 2019-10-16  1.261406  1.066956
# 125, 青岛啤酒
#                  net   slow_ma
# trade_date
# 2019-10-10  1.098839       NaN
# 2019-10-11  1.082657       NaN
# 2019-10-14  1.056634       NaN
# 2019-10-15  1.043514       NaN
# 2019-10-16  1.045263  1.061555
# 126, 长春高新
#                  net   slow_ma
# trade_date
# 2019-10-10  1.204084       NaN
# 2019-10-11  1.210331       NaN
# 2019-10-14  1.192135       NaN
# 2019-10-15  1.191983       NaN
# 2019-10-16  1.244189  1.070675
# 127, 包钢股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.919251       NaN
# 2019-10-11  0.919251       NaN
# 2019-10-14  0.925462       NaN
# 2019-10-15  0.913040       NaN
# 2019-10-16  0.913040  0.945444
# 128, 复星医药
#                  net   slow_ma
# trade_date
# 2019-10-10  0.944688       NaN
# 2019-10-11  0.938020       NaN
# 2019-10-14  0.945429       NaN
# 2019-10-15  0.935797       NaN
# 2019-10-16  0.928387  0.979092
# 129, 中煤能源
#                  net   slow_ma
# trade_date
# 2019-10-10  1.051281       NaN
# 2019-10-11  1.072649       NaN
# 2019-10-14  1.068375       NaN
# 2019-10-15  1.049145       NaN
# 2019-10-16  1.042734  1.010007
# 130, 紫光股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.139290       NaN
# 2019-10-11  1.136790       NaN
# 2019-10-14  1.147861       NaN
# 2019-10-15  1.102504       NaN
# 2019-10-16  1.098575  1.185896
# 131, 片仔癀
#                  net   slow_ma
# trade_date
# 2019-10-10  1.005681       NaN
# 2019-10-11  1.004750       NaN
# 2019-10-14  1.015925       NaN
# 2019-10-15  1.043491       NaN
# 2019-10-16  1.066307  0.950506
# 132, 新城控股
#                  net   slow_ma
# trade_date
# 2019-10-10  0.975680       NaN
# 2019-10-11  0.989579       NaN
# 2019-10-14  1.012164       NaN
# 2019-10-15  1.020156       NaN
# 2019-10-16  1.051428  0.916616
# 133, 中远海控
#                  net   slow_ma
# trade_date
# 2019-10-10  1.022089       NaN
# 2019-10-11  1.054217       NaN
# 2019-10-14  1.042169       NaN
# 2019-10-15  1.004016       NaN
# 2019-10-16  0.983936  0.957196
# 134, 国投电力
#                  net   slow_ma
# trade_date
# 2019-10-10  1.120759       NaN
# 2019-10-11  1.126978       NaN
# 2019-10-14  1.125734       NaN
# 2019-10-15  1.100856       NaN
# 2019-10-16  1.097124  1.118441
# 135, 恒生电子
#                  net   slow_ma
# trade_date
# 2019-10-10  1.104295       NaN
# 2019-10-11  1.114812       NaN
# 2019-10-14  1.127082       NaN
# 2019-10-15  1.094070       NaN
# 2019-10-16  1.094801  1.071584
# 136, 中国铝业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.931940       NaN
# 2019-10-11  0.937175       NaN
# 2019-10-14  0.945029       NaN
# 2019-10-15  0.931940       NaN
# 2019-10-16  0.921469  0.955585
# 137, 中海油服
#                  net  slow_ma
# trade_date
# 2019-10-10  1.253706      NaN
# 2019-10-11  1.358347      NaN
# 2019-10-14  1.344527      NaN
# 2019-10-15  1.312937      NaN
# 2019-10-16  1.313925  1.13253
# 138, 生益科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.743726       NaN
# 2019-10-11  1.839498       NaN
# 2019-10-14  1.845443       NaN
# 2019-10-15  1.712682       NaN
# 2019-10-16  1.682960  1.526331
# 139, 华侨城A
#                  net   slow_ma
# trade_date
# 2019-10-10  0.971925       NaN
# 2019-10-11  0.971925       NaN
# 2019-10-14  0.983957       NaN
# 2019-10-15  0.973261       NaN
# 2019-10-16  0.981283  0.948284
# 140, 视源股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.213510       NaN
# 2019-10-11  1.222206       NaN
# 2019-10-14  1.229430       NaN
# 2019-10-15  1.204012       NaN
# 2019-10-16  1.252172  1.093265
# 141, 苏泊尔
#                  net   slow_ma
# trade_date
# 2019-10-10  1.036938       NaN
# 2019-10-11  1.049537       NaN
# 2019-10-14  1.078885       NaN
# 2019-10-15  1.097639       NaN
# 2019-10-16  1.115249  1.009609
# 142, 三安光电
#                  net   slow_ma
# trade_date
# 2019-10-10  1.370632       NaN
# 2019-10-11  1.312731       NaN
# 2019-10-14  1.369682       NaN
# 2019-10-15  1.284255       NaN
# 2019-10-16  1.259575  1.154881
# 143, 中国中冶
#                  net   slow_ma
# trade_date
# 2019-10-10  0.937517       NaN
# 2019-10-11  0.940830       NaN
# 2019-10-14  0.950768       NaN
# 2019-10-15  0.947456       NaN
# 2019-10-16  0.947456  0.946843
# 144, 歌尔股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.740847       NaN
# 2019-10-11  1.772638       NaN
# 2019-10-14  1.801539       NaN
# 2019-10-15  1.737956       NaN
# 2019-10-16  1.754334  1.339644
# 145, 金地集团
#                  net   slow_ma
# trade_date
# 2019-10-10  1.047388       NaN
# 2019-10-11  1.049017       NaN
# 2019-10-14  1.066935       NaN
# 2019-10-15  1.056347       NaN
# 2019-10-16  1.067749  0.985795
# 146, 白云山
#                  net   slow_ma
# trade_date
# 2019-10-10  0.865203       NaN
# 2019-10-11  0.868866       NaN
# 2019-10-14  0.878145       NaN
# 2019-10-15  0.875947       NaN
# 2019-10-16  0.871796  0.896208
# 147, 古井贡酒
#                  net   slow_ma
# trade_date
# 2019-10-10  0.948336       NaN
# 2019-10-11  0.946674       NaN
# 2019-10-14  0.941110       NaN
# 2019-10-15  0.945346       NaN
# 2019-10-16  0.917771  0.975064
# 148, 方正证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.974886       NaN
# 2019-10-11  0.986206       NaN
# 2019-10-14  1.004599       NaN
# 2019-10-15  0.987621       NaN
# 2019-10-16  0.983376  0.974498
# 149, 金风科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.091926       NaN
# 2019-10-11  1.079684       NaN
# 2019-10-14  1.081317       NaN
# 2019-10-15  1.042145       NaN
# 2019-10-16  1.034800  1.024592
# 150, 红塔证券
#                  net   slow_ma
# trade_date
# 2019-10-10  1.602062       NaN
# 2019-10-11  1.642269       NaN
# 2019-10-14  1.647424       NaN
# 2019-10-15  1.590723       NaN
# 2019-10-16  1.555671  1.603814
# 151, 陆家嘴
#                  net  slow_ma
# trade_date
# 2019-10-10  0.945614      NaN
# 2019-10-11  0.953092      NaN
# 2019-10-14  0.955811      NaN
# 2019-10-15  0.948333      NaN
# 2019-10-16  0.943574   0.9701
# 152, 同花顺
#                  net   slow_ma
# trade_date
# 2019-10-10  1.101012       NaN
# 2019-10-11  1.153773       NaN
# 2019-10-14  1.151947       NaN
# 2019-10-15  1.077586       NaN
# 2019-10-16  1.065981  1.042734
# 153, 福耀玻璃
#                  net   slow_ma
# trade_date
# 2019-10-10  0.959804       NaN
# 2019-10-11  0.975883       NaN
# 2019-10-14  0.984369       NaN
# 2019-10-15  0.973203       NaN
# 2019-10-16  0.969184  0.982843
# 154, 光大证券
#                  net  slow_ma
# trade_date
# 2019-10-10  1.010586      NaN
# 2019-10-11  1.025422      NaN
# 2019-10-14  1.047239      NaN
# 2019-10-15  1.031531      NaN
# 2019-10-16  1.019313  0.98721
# 155, 浙能电力
#                  net   slow_ma
# trade_date
# 2019-10-10  0.911629       NaN
# 2019-10-11  0.911629       NaN
# 2019-10-14  0.918605       NaN
# 2019-10-15  0.916280       NaN
# 2019-10-16  0.913954  0.948528
# 156, 兖州煤业
#                  net  slow_ma
# trade_date
# 2019-10-10  1.041585      NaN
# 2019-10-11  1.051256      NaN
# 2019-10-14  1.074467      NaN
# 2019-10-15  1.065762      NaN
# 2019-10-16  1.049322  0.99805
# 157, 宁沪高速
#                  net  slow_ma
# trade_date
# 2019-10-10  1.030426      NaN
# 2019-10-11  1.036314      NaN
# 2019-10-14  1.030425      NaN
# 2019-10-15  1.020611      NaN
# 2019-10-16  1.018649  1.00499
# 158, 世纪华通
#                  net   slow_ma
# trade_date
# 2019-10-10  0.804723       NaN
# 2019-10-11  0.821981       NaN
# 2019-10-14  0.827430       NaN
# 2019-10-15  0.815623       NaN
# 2019-10-16  0.789283  0.851075
# 159, 国投资本
#                  net   slow_ma
# trade_date
# 2019-10-10  0.883905       NaN
# 2019-10-11  0.893164       NaN
# 2019-10-14  0.918805       NaN
# 2019-10-15  0.908833       NaN
# 2019-10-16  0.905984  0.934901
# 160, 海大集团
#                  net   slow_ma
# trade_date
# 2019-10-10  1.200727       NaN
# 2019-10-11  1.171530       NaN
# 2019-10-14  1.178829       NaN
# 2019-10-15  1.156567       NaN
# 2019-10-16  1.140508  1.143455
# 161, 上海医药
#                  net  slow_ma
# trade_date
# 2019-10-10  1.054241      NaN
# 2019-10-11  1.061742      NaN
# 2019-10-14  1.074437      NaN
# 2019-10-15  1.073283      NaN
# 2019-10-16  1.084824  1.05554
# 162, 泰格医药
#                  net   slow_ma
# trade_date
# 2019-10-10  1.308162       NaN
# 2019-10-11  1.271350       NaN
# 2019-10-14  1.254462       NaN
# 2019-10-15  1.265658       NaN
# 2019-10-16  1.290895  1.103249
# 163, 康泰生物
#                  net   slow_ma
# trade_date
# 2019-10-10  1.312419       NaN
# 2019-10-11  1.392764       NaN
# 2019-10-14  1.382804       NaN
# 2019-10-15  1.368694       NaN
# 2019-10-16  1.375168  1.154574
# 164, 华兰生物
#                  net   slow_ma
# trade_date
# 2019-10-10  1.164153       NaN
# 2019-10-11  1.165114       NaN
# 2019-10-14  1.166717       NaN
# 2019-10-15  1.163832       NaN
# 2019-10-16  1.199741  1.046755
# 165, 深南电路
#                  net   slow_ma
# trade_date
# 2019-10-10  1.392105       NaN
# 2019-10-11  1.498833       NaN
# 2019-10-14  1.490759       NaN
# 2019-10-15  1.401292       NaN
# 2019-10-16  1.407881  1.239319
# 166, 通威股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.970064       NaN
# 2019-10-11  0.946860       NaN
# 2019-10-14  0.967070       NaN
# 2019-10-15  0.943866       NaN
# 2019-10-16  0.910183  1.044077
# 167, 江西铜业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.968384       NaN
# 2019-10-11  0.974433       NaN
# 2019-10-14  0.981154       NaN
# 2019-10-15  0.967713       NaN
# 2019-10-16  0.959649  0.983844
# 168, 宁波港
#                  net   slow_ma
# trade_date
# 2019-10-10  0.885246       NaN
# 2019-10-11  0.899298       NaN
# 2019-10-14  0.915691       NaN
# 2019-10-15  0.913349       NaN
# 2019-10-16  0.899297  0.928767
# 169, 大唐发电
#                  net   slow_ma
# trade_date
# 2019-10-10  0.922654       NaN
# 2019-10-11  0.922654       NaN
# 2019-10-14  0.932943       NaN
# 2019-10-15  0.929513       NaN
# 2019-10-16  0.932943  0.951366
# 170, 航发动力
#                  net   slow_ma
# trade_date
# 2019-10-10  0.949483       NaN
# 2019-10-11  0.946029       NaN
# 2019-10-14  0.955097       NaN
# 2019-10-15  0.943007       NaN
# 2019-10-16  0.947325  0.990682
# 171, 上海临港
#                  net   slow_ma
# trade_date
# 2019-10-10  0.816012       NaN
# 2019-10-11  0.822291       NaN
# 2019-10-14  0.830454       NaN
# 2019-10-15  0.816012       NaN
# 2019-10-16  0.824175  0.913814
# 172, 青岛港
#                  net   slow_ma
# trade_date
# 2019-10-10  0.881255       NaN
# 2019-10-11  0.882419       NaN
# 2019-10-14  0.891732       NaN
# 2019-10-15  0.884747       NaN
# 2019-10-16  0.876598  0.900271
# 173, 大冶特钢
#                  net   slow_ma
# trade_date
# 2019-10-10  1.358848       NaN
# 2019-10-11  1.423869       NaN
# 2019-10-14  1.400823       NaN
# 2019-10-15  1.412347       NaN
# 2019-10-16  1.363787  1.204787
# 174, 大华股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.129077       NaN
# 2019-10-11  1.104789       NaN
# 2019-10-14  1.115198       NaN
# 2019-10-15  1.090215       NaN
# 2019-10-16  1.096461  1.135439
# 175, 白云机场
#                  net   slow_ma
# trade_date
# 2019-10-10  1.388594       NaN
# 2019-10-11  1.390962       NaN
# 2019-10-14  1.336507       NaN
# 2019-10-15  1.355448       NaN
# 2019-10-16  1.331772  1.148082
# 176, 招商公路
#                  net   slow_ma
# trade_date
# 2019-10-10  0.953772       NaN
# 2019-10-11  0.967154       NaN
# 2019-10-14  0.992701       NaN
# 2019-10-15  1.002434       NaN
# 2019-10-16  1.015816  0.980049
# 177, TCL集团
#                  net   slow_ma
# trade_date
# 2019-10-10  1.035087       NaN
# 2019-10-11  1.032163       NaN
# 2019-10-14  1.046783       NaN
# 2019-10-15  1.023392       NaN
# 2019-10-16  1.023392  1.008479
# 178, 芒果超媒
#                  net  slow_ma
# trade_date
# 2019-10-10  1.179383      NaN
# 2019-10-11  1.162735      NaN
# 2019-10-14  1.152220      NaN
# 2019-10-15  1.148277      NaN
# 2019-10-16  1.126371  1.10082
# 179, 新和成
#                  net   slow_ma
# trade_date
# 2019-10-10  1.069196       NaN
# 2019-10-11  1.058144       NaN
# 2019-10-14  1.061508       NaN
# 2019-10-15  1.010091       NaN
# 2019-10-16  1.019702  1.035246
# 180, 中国卫通
#                  net   slow_ma
# trade_date
# 2019-10-10  0.971478       NaN
# 2019-10-11  0.959253       NaN
# 2019-10-14  1.019563       NaN
# 2019-10-15  0.999188       NaN
# 2019-10-16  0.977998  0.965487
# 181, 中联重科
#                  net   slow_ma
# trade_date
# 2019-10-10  1.030006       NaN
# 2019-10-11  1.035104       NaN
# 2019-10-14  1.033405       NaN
# 2019-10-15  1.024906       NaN
# 2019-10-16  1.023207  0.976682
# 182, 美年健康
#                  net  slow_ma
# trade_date
# 2019-10-10  1.212032      NaN
# 2019-10-11  1.256922      NaN
# 2019-10-14  1.291306      NaN
# 2019-10-15  1.284620      NaN
# 2019-10-16  1.294171  1.14941
# 183, 乐普医疗
#                  net   slow_ma
# trade_date
# 2019-10-10  1.036605       NaN
# 2019-10-11  1.033100       NaN
# 2019-10-14  1.059580       NaN
# 2019-10-15  1.072430       NaN
# 2019-10-16  1.072430  1.008892
# 184, 长城证券
#                  net  slow_ma
# trade_date
# 2019-10-10  0.996070      NaN
# 2019-10-11  1.017053      NaN
# 2019-10-14  1.023610      NaN
# 2019-10-15  0.988200      NaN
# 2019-10-16  0.977052  1.00998
# 185, 正泰电器
#                  net   slow_ma
# trade_date
# 2019-10-10  0.931489       NaN
# 2019-10-11  0.927660       NaN
# 2019-10-14  0.951064       NaN
# 2019-10-15  0.941276       NaN
# 2019-10-16  0.940425  0.970028
# 186, 兆易创新
#                  net   slow_ma
# trade_date
# 2019-10-10  1.439479       NaN
# 2019-10-11  1.387308       NaN
# 2019-10-14  1.442329       NaN
# 2019-10-15  1.360779       NaN
# 2019-10-16  1.348990  1.203209
# 187, 国电电力
#                  net   slow_ma
# trade_date
# 2019-10-10  0.948208       NaN
# 2019-10-11  0.952193       NaN
# 2019-10-14  0.960161       NaN
# 2019-10-15  0.952192       NaN
# 2019-10-16  0.952192  0.983932
# 188, 闻泰科技
#                  net   slow_ma
# trade_date
# 2019-10-10  2.004112       NaN
# 2019-10-11  1.997540       NaN
# 2019-10-14  2.039982       NaN
# 2019-10-15  1.975359       NaN
# 2019-10-16  1.955643  1.486004
# 189, 欧派家居
#                  net   slow_ma
# trade_date
# 2019-10-10  1.022395       NaN
# 2019-10-11  1.030261       NaN
# 2019-10-14  1.070890       NaN
# 2019-10-15  1.044606       NaN
# 2019-10-16  1.093195  1.023491
# 190, 浙江龙盛
#                  net   slow_ma
# trade_date
# 2019-10-10  0.923574       NaN
# 2019-10-11  0.925517       NaN
# 2019-10-14  0.941709       NaN
# 2019-10-15  0.923575       NaN
# 2019-10-16  0.911917  0.945606
# 191, 华东医药
#                  net   slow_ma
# trade_date
# 2019-10-10  0.951967       NaN
# 2019-10-11  0.948717       NaN
# 2019-10-14  0.949800       NaN
# 2019-10-15  0.938966       NaN
# 2019-10-16  0.933549  1.002034
# 192, 蓝思科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.751867       NaN
# 2019-10-11  1.832584       NaN
# 2019-10-14  2.016440       NaN
# 2019-10-15  2.059787       NaN
# 2019-10-16  1.995511  1.377802
# 193, 上海石化
#                  net   slow_ma
# trade_date
# 2019-10-10  0.851021       NaN
# 2019-10-11  0.859184       NaN
# 2019-10-14  0.861225       NaN
# 2019-10-15  0.853061       NaN
# 2019-10-16  0.851021  0.899762
# 194, 天风证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.863136       NaN
# 2019-10-11  0.869130       NaN
# 2019-10-14  0.876123       NaN
# 2019-10-15  0.847152       NaN
# 2019-10-16  0.827172  0.911289
# 195, 深信服
#                  net   slow_ma
# trade_date
# 2019-10-10  1.147646       NaN
# 2019-10-11  1.113113       NaN
# 2019-10-14  1.124176       NaN
# 2019-10-15  1.209578       NaN
# 2019-10-16  1.257757  1.104446
# 196, 杭州银行
#                  net   slow_ma
# trade_date
# 2019-10-10  1.042371       NaN
# 2019-10-11  1.052056       NaN
# 2019-10-14  1.071427       NaN
# 2019-10-15  1.070216       NaN
# 2019-10-16  1.062953  1.004075
# 197, 宝信软件
#                  net   slow_ma
# trade_date
# 2019-10-10  1.331031       NaN
# 2019-10-11  1.298863       NaN
# 2019-10-14  1.287448       NaN
# 2019-10-15  1.261160       NaN
# 2019-10-16  1.261852  1.139699
# 198, 川投能源
#                  net   slow_ma
# trade_date
# 2019-10-10  1.111063       NaN
# 2019-10-11  1.130045       NaN
# 2019-10-14  1.135629       NaN
# 2019-10-15  1.130046       NaN
# 2019-10-16  1.133396  1.071773
# 199, 沪电股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.661203       NaN
# 2019-10-11  1.691347       NaN
# 2019-10-14  1.777848       NaN
# 2019-10-15  1.699212       NaN
# 2019-10-16  1.673000  1.411892
# 200, 华林证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.969878       NaN
# 2019-10-11  0.977710       NaN
# 2019-10-14  0.981325       NaN
# 2019-10-15  0.960240       NaN
# 2019-10-16  0.954819  1.020824
# 201, 中航飞机
#                  net   slow_ma
# trade_date
# 2019-10-10  0.954993       NaN
# 2019-10-11  0.947594       NaN
# 2019-10-14  0.961774       NaN
# 2019-10-15  0.943895       NaN
# 2019-10-16  0.938963  0.991717
# 202, 沃森生物
#                  net  slow_ma
# trade_date
# 2019-10-10  1.042132      NaN
# 2019-10-11  1.072230      NaN
# 2019-10-14  1.109852      NaN
# 2019-10-15  1.109476      NaN
# 2019-10-16  1.120763  1.03769
# 203, 石基信息
#                  net   slow_ma
# trade_date
# 2019-10-10  1.186720       NaN
# 2019-10-11  1.173021       NaN
# 2019-10-14  1.191187       NaN
# 2019-10-15  1.157834       NaN
# 2019-10-16  1.146219  1.082426
# 204, 石化油服
#                  net  slow_ma
# trade_date
# 2019-10-10  0.918031      NaN
# 2019-10-11  0.946720      NaN
# 2019-10-14  0.950818      NaN
# 2019-10-15  0.938523      NaN
# 2019-10-16  0.930326  0.94187
# 205, 中航资本
#                  net   slow_ma
# trade_date
# 2019-10-10  0.882242       NaN
# 2019-10-11  0.887850       NaN
# 2019-10-14  0.917756       NaN
# 2019-10-15  0.904672       NaN
# 2019-10-16  0.902803  0.909718
# 206, 中航沈飞
#                  net   slow_ma
# trade_date
# 2019-10-10  0.998673       NaN
# 2019-10-11  0.992709       NaN
# 2019-10-14  1.018885       NaN
# 2019-10-15  0.988070       NaN
# 2019-10-16  0.991052  1.042202
# 207, 中航光电
#                  net   slow_ma
# trade_date
# 2019-10-10  1.159374       NaN
# 2019-10-11  1.161982       NaN
# 2019-10-14  1.167778       NaN
# 2019-10-15  1.155607       NaN
# 2019-10-16  1.163431  1.147292
# 208, 兴业证券
#                  net   slow_ma
# trade_date
# 2019-10-10  0.941763       NaN
# 2019-10-11  0.953817       NaN
# 2019-10-14  0.976420       NaN
# 2019-10-15  0.959845       NaN
# 2019-10-16  0.952311  0.954663
# 209, 华新水泥
#                  net   slow_ma
# trade_date
# 2019-10-10  0.969786       NaN
# 2019-10-11  0.996102       NaN
# 2019-10-14  0.998051       NaN
# 2019-10-15  0.980020       NaN
# 2019-10-16  0.986355  0.948967
# 210, 今世缘
#                  net   slow_ma
# trade_date
# 2019-10-10  1.169224       NaN
# 2019-10-11  1.169224       NaN
# 2019-10-14  1.162440       NaN
# 2019-10-15  1.181719       NaN
# 2019-10-16  1.152802  1.058396
# 211, 晨光文具
#                  net   slow_ma
# trade_date
# 2019-10-10  1.107390       NaN
# 2019-10-11  1.142113       NaN
# 2019-10-14  1.135416       NaN
# 2019-10-15  1.133928       NaN
# 2019-10-16  1.117063  1.026381
# 212, 上海莱士
#                  net   slow_ma
# trade_date
# 2019-10-10  1.125681       NaN
# ...
# 2019-10-10  1.548956       NaN
# 2019-10-11  1.553008       NaN
# 2019-10-14  1.560436       NaN
# 2019-10-15  1.567863       NaN
# 2019-10-16  1.558411  1.149889
# 732, 西部矿业
#                  net  slow_ma
# trade_date
# 2019-10-10  0.933993      NaN
# 2019-10-11  0.937294      NaN
# 2019-10-14  0.945545      NaN
# 2019-10-15  0.933994      NaN
# 2019-10-16  0.929044  0.95462
# 733, 长盈精密
#                  net   slow_ma
# trade_date
# 2019-10-10  1.287826       NaN
# 2019-10-11  1.270436       NaN
# 2019-10-14  1.295652       NaN
# 2019-10-15  1.215652       NaN
# 2019-10-16  1.217392  1.138392
# 734, 东方国信
#                  net   slow_ma
# trade_date
# 2019-10-10  1.088892       NaN
# 2019-10-11  1.070943       NaN
# 2019-10-14  1.099148       NaN
# 2019-10-15  1.107695       NaN
# 2019-10-16  1.132482  1.060443
# 735, 木林森
#                  net   slow_ma
# trade_date
# 2019-10-10  0.898377       NaN
# 2019-10-11  0.878736       NaN
# 2019-10-14  0.899232       NaN
# 2019-10-15  0.902648       NaN
# 2019-10-16  0.888985  0.927939
# 736, 双鹭药业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.905685       NaN
# 2019-10-11  0.907765       NaN
# 2019-10-14  0.910539       NaN
# 2019-10-15  0.907072       NaN
# 2019-10-16  0.904991  0.936916
# 737, 中化国际
#                  net   slow_ma
# trade_date
# 2019-10-10  0.837564       NaN
# 2019-10-11  0.842640       NaN
# 2019-10-14  0.854485       NaN
# 2019-10-15  0.844332       NaN
# 2019-10-16  0.840948  0.891201
# 738, 东华能源
#                  net   slow_ma
# trade_date
# 2019-10-10  0.934407       NaN
# 2019-10-11  0.952818       NaN
# 2019-10-14  0.972381       NaN
# 2019-10-15  0.982737       NaN
# 2019-10-16  0.970079  0.937054
# 739, ST新梅
#                  net   slow_ma
# trade_date
# 2019-10-10  1.214286       NaN
# 2019-10-11  1.215947       NaN
# 2019-10-14  1.171097       NaN
# 2019-10-15  1.184387       NaN
# 2019-10-16  1.161131  1.281312
# 740, 绿色动力
#                  net   slow_ma
# trade_date
# 2019-10-10  0.865864       NaN
# 2019-10-11  0.853053       NaN
# 2019-10-14  0.868878       NaN
# 2019-10-15  0.881689       NaN
# 2019-10-16  0.906557  0.913075
# 741, 一心堂
#                  net   slow_ma
# trade_date
# 2019-10-10  0.890787       NaN
# 2019-10-11  0.883582       NaN
# 2019-10-14  0.897234       NaN
# 2019-10-15  0.898751       NaN
# 2019-10-16  0.941223  0.927059
# 742, 洽洽食品
#                  net  slow_ma
# trade_date
# 2019-10-10  1.027367      NaN
# 2019-10-11  1.028931      NaN
# 2019-10-14  1.046914      NaN
# 2019-10-15  1.087961      NaN
# 2019-10-16  1.120408  1.00421
# 743, 浙江东方
#                  net   slow_ma
# trade_date
# 2019-10-10  0.901312       NaN
# 2019-10-11  0.918274       NaN
# 2019-10-14  0.946031       NaN
# 2019-10-15  0.935237       NaN
# 2019-10-16  0.926756  0.942484
# 744, 以岭药业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.952296       NaN
# 2019-10-11  0.962703       NaN
# 2019-10-14  0.968774       NaN
# 2019-10-15  0.965305       NaN
# 2019-10-16  0.969641  0.949319
# 745, 宝新能源
#                  net   slow_ma
# trade_date
# 2019-10-10  0.950005       NaN
# 2019-10-11  0.943754       NaN
# 2019-10-14  0.945317       NaN
# 2019-10-15  0.928130       NaN
# 2019-10-16  0.925005  0.937816
# 746, 尔康制药
#                  net   slow_ma
# trade_date
# 2019-10-10  1.191481       NaN
# 2019-10-11  1.211928       NaN
# 2019-10-14  1.217505       NaN
# 2019-10-15  1.237951       NaN
# 2019-10-16  1.303009  1.038967
# 747, 福田汽车
#                  net   slow_ma
# trade_date
# 2019-10-10  0.870129       NaN
# 2019-10-11  0.883116       NaN
# 2019-10-14  0.896103       NaN
# 2019-10-15  0.887445       NaN
# 2019-10-16  0.891774  0.910677
# 748, 酒鬼酒
#                  net   slow_ma
# trade_date
# 2019-10-10  1.444049       NaN
# 2019-10-11  1.394316       NaN
# 2019-10-14  1.386501       NaN
# 2019-10-15  1.374068       NaN
# 2019-10-16  1.331795  1.122914
# 749, 歌华有线
#                  net   slow_ma
# trade_date
# 2019-10-10  0.951713       NaN
# 2019-10-11  0.951713       NaN
# 2019-10-14  0.969822       NaN
# 2019-10-15  0.961773       NaN
# 2019-10-16  0.958755  0.968949
# 750, 德赛西威
#                  net   slow_ma
# trade_date
# 2019-10-10  0.933961       NaN
# 2019-10-11  0.929662       NaN
# 2019-10-14  0.946466       NaN
# 2019-10-15  0.919893       NaN
# 2019-10-16  0.927317  0.966401
# 751, 新洋丰
#                  net   slow_ma
# trade_date
# 2019-10-10  0.929762       NaN
# 2019-10-11  0.879855       NaN
# 2019-10-14  0.888173       NaN
# 2019-10-15  0.862295       NaN
# 2019-10-16  0.844735  1.000834
# 752, 广州酒家
#                  net   slow_ma
# trade_date
# 2019-10-10  1.061865       NaN
# 2019-10-11  1.043207       NaN
# 2019-10-14  1.036333       NaN
# 2019-10-15  1.034042       NaN
# 2019-10-16  1.029459  1.062788
# 753, 一汽轿车
#                  net   slow_ma
# trade_date
# 2019-10-10  0.860043       NaN
# 2019-10-11  0.854702       NaN
# 2019-10-14  0.868590       NaN
# 2019-10-15  0.853633       NaN
# 2019-10-16  0.852565  0.943679
# 754, 五矿稀土
#                  net   slow_ma
# trade_date
# 2019-10-10  0.945392       NaN
# 2019-10-11  0.931917       NaN
# 2019-10-14  0.924825       NaN
# 2019-10-15  0.909222       NaN
# 2019-10-16  0.897875  0.987791
# 755, 瑞达期货
#                  net  slow_ma
# trade_date
# 2019-10-10  5.272881      NaN
# 2019-10-11  5.800706      NaN
# 2019-10-14  6.380597      NaN
# 2019-10-15  6.253132      NaN
# 2019-10-16  6.877908      NaN
# 756, 光弘科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.440372       NaN
# 2019-10-11  1.451076       NaN
# 2019-10-14  1.430688       NaN
# 2019-10-15  1.348119       NaN
# 2019-10-16  1.345061  1.364079
# 757, 易见股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.092277       NaN
# 2019-10-11  1.112051       NaN
# 2019-10-14  1.127117       NaN
# 2019-10-15  1.135592       NaN
# 2019-10-16  1.074387  1.047159
# 758, 新奥股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.027563       NaN
# 2019-10-11  1.025622       NaN
# 2019-10-14  1.089663       NaN
# 2019-10-15  1.082871       NaN
# 2019-10-16  1.089663  0.964524
# 759, 华润双鹤
#                  net   slow_ma
# trade_date
# 2019-10-10  0.944466       NaN
# 2019-10-11  0.941437       NaN
# 2019-10-14  0.961129       NaN
# 2019-10-15  0.958099       NaN
# 2019-10-16  0.967188  0.980654
# 760, 武汉凡谷
#                  net   slow_ma
# trade_date
# 2019-10-10  1.588276       NaN
# 2019-10-11  1.531035       NaN
# 2019-10-14  1.544828       NaN
# 2019-10-15  1.495172       NaN
# 2019-10-16  1.458621  1.340725
# 761, 兆驰股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.979520       NaN
# 2019-10-11  0.982932       NaN
# 2019-10-14  0.986345       NaN
# 2019-10-15  1.010235       NaN
# 2019-10-16  0.989758  0.983503
# 762, 柏楚电子
#                  net  slow_ma
# trade_date
# 2019-10-10  1.893846      NaN
# 2019-10-11  1.878244      NaN
# 2019-10-14  1.921842      NaN
# 2019-10-15  1.887576      NaN
# 2019-10-16  1.818313      NaN
# 763, 光明乳业
#                  net   slow_ma
# trade_date
# 2019-10-10  0.913011       NaN
# 2019-10-11  0.909565       NaN
# 2019-10-14  0.919040       NaN
# 2019-10-15  0.914734       NaN
# 2019-10-16  0.917318  0.936752
# 764, 德邦股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.981750       NaN
# 2019-10-11  0.964231       NaN
# 2019-10-14  0.970801       NaN
# 2019-10-15  0.969341       NaN
# 2019-10-16  1.002918  0.956313
# 765, 天顺风能
#                  net   slow_ma
# trade_date
# 2019-10-10  1.200331       NaN
# 2019-10-11  1.177153       NaN
# 2019-10-14  1.145696       NaN
# 2019-10-15  1.120862       NaN
# 2019-10-16  1.110927  1.062334
# 766, 三棵树
#                  net   slow_ma
# trade_date
# 2019-10-10  1.614899       NaN
# 2019-10-11  1.495329       NaN
# 2019-10-14  1.483652       NaN
# 2019-10-15  1.440915       NaN
# 2019-10-16  1.499066  1.350775
# 767, 东方日升
#                  net   slow_ma
# trade_date
# 2019-10-10  1.326494       NaN
# 2019-10-11  1.273323       NaN
# 2019-10-14  1.280786       NaN
# 2019-10-15  1.250002       NaN
# 2019-10-16  1.228547  1.089241
# 768, 山煤国际
#                  net   slow_ma
# trade_date
# 2019-10-10  1.023808       NaN
# 2019-10-11  1.030158       NaN
# 2019-10-14  1.031745       NaN
# 2019-10-15  1.012697       NaN
# 2019-10-16  1.009522  1.069603
# 769, 风华高科
#                  net   slow_ma
# trade_date
# 2019-10-10  1.354690       NaN
# 2019-10-11  1.472281       NaN
# 2019-10-14  1.457941       NaN
# 2019-10-15  1.312625       NaN
# 2019-10-16  1.299240  1.180548
# 770, 广宇发展
#                  net   slow_ma
# trade_date
# 2019-10-10  1.010388       NaN
# 2019-10-11  1.019291       NaN
# 2019-10-14  1.032644       NaN
# 2019-10-15  1.025225       NaN
# 2019-10-16  1.022258  0.973541
# 771, 通富微电
#                  net   slow_ma
# trade_date
# 2019-10-10  1.346816       NaN
# 2019-10-11  1.329658       NaN
# 2019-10-14  1.384806       NaN
# 2019-10-15  1.397062       NaN
# 2019-10-16  1.350493  1.178616
# 772, 北方导航
#                  net   slow_ma
# trade_date
# 2019-10-10  0.916037       NaN
# 2019-10-11  0.913884       NaN
# 2019-10-14  0.921419       NaN
# 2019-10-15  0.908502       NaN
# 2019-10-16  0.903120  0.961982
# 773, 齐翔腾达
#                  net   slow_ma
# trade_date
# 2019-10-10  0.913992       NaN
# 2019-10-11  0.931964       NaN
# 2019-10-14  0.924262       NaN
# 2019-10-15  0.907573       NaN
# 2019-10-16  0.910141  0.933248
# 774, 东方集团
#                  net   slow_ma
# trade_date
# 2019-10-10  0.923916       NaN
# 2019-10-11  0.926633       NaN
# 2019-10-14  0.937502       NaN
# 2019-10-15  0.929350       NaN
# 2019-10-16  0.923915  0.945564
# 775, 中粮科技
#                  net   slow_ma
# trade_date
# 2019-10-10  0.909456       NaN
# 2019-10-11  0.909456       NaN
# 2019-10-14  0.920108       NaN
# 2019-10-15  0.917445       NaN
# 2019-10-16  0.901466  0.926321
# 776, 阳泉煤业
#                  net  slow_ma
# trade_date
# 2019-10-10  0.935715      NaN
# 2019-10-11  0.941072      NaN
# 2019-10-14  0.950001      NaN
# 2019-10-15  0.946430      NaN
# 2019-10-16  0.930359  0.94634
# 777, 天津港
#                  net   slow_ma
# trade_date
# 2019-10-10  0.990506       NaN
# 2019-10-11  1.000000       NaN
# 2019-10-14  1.012658       NaN
# 2019-10-15  1.014241       NaN
# 2019-10-16  1.006330  0.982384
# 778, 高新兴
#                  net   slow_ma
# trade_date
# 2019-10-10  0.995803       NaN
# 2019-10-11  0.997201       NaN
# 2019-10-14  0.999999       NaN
# 2019-10-15  0.900698       NaN
# 2019-10-16  0.840558  1.000583
# 779, 四川长虹
#                  net  slow_ma
# trade_date
# 2019-10-10  0.907458      NaN
# 2019-10-11  0.914130      NaN
# 2019-10-14  0.924139      NaN
# 2019-10-15  0.910794      NaN
# 2019-10-16  0.900786  0.93087
# 780, 华胜天成
#                  net   slow_ma
# trade_date
# 2019-10-10  1.115238       NaN
# 2019-10-11  1.102542       NaN
# 2019-10-14  1.184573       NaN
# 2019-10-15  1.145511       NaN
# 2019-10-16  1.136721  1.096161
# 781, 冀中能源
#                  net   slow_ma
# trade_date
# 2019-10-10  0.931759       NaN
# 2019-10-11  0.931759       NaN
# 2019-10-14  0.944883       NaN
# 2019-10-15  0.937009       NaN
# 2019-10-16  0.939633  0.943658
# 782, 蓝帆医疗
#                  net   slow_ma
# trade_date
# 2019-10-10  0.960861       NaN
# 2019-10-11  0.961599       NaN
# 2019-10-14  0.980802       NaN
# 2019-10-15  0.951260       NaN
# 2019-10-16  0.954953  0.978707
# 783, 科沃斯
#                  net   slow_ma
# trade_date
# 2019-10-10  0.762881       NaN
# 2019-10-11  0.754351       NaN
# 2019-10-14  0.767657       NaN
# 2019-10-15  0.752986       NaN
# 2019-10-16  0.741045  0.863477
# 784, 恒邦股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.822859       NaN
# 2019-10-11  0.824057       NaN
# 2019-10-14  0.814482       NaN
# 2019-10-15  0.795332       NaN
# 2019-10-16  0.782166  0.934769
# 785, 上峰水泥
#                  net   slow_ma
# trade_date
# 2019-10-10  1.198904       NaN
# 2019-10-11  1.251946       NaN
# 2019-10-14  1.277687       NaN
# 2019-10-15  1.201244       NaN
# 2019-10-16  1.213725  1.022502
# 786, 海联金汇
#                  net   slow_ma
# trade_date
# 2019-10-10  1.429584       NaN
# 2019-10-11  1.477948       NaN
# 2019-10-14  1.507821       NaN
# 2019-10-15  1.357039       NaN
# 2019-10-16  1.312942  1.105925
# 787, 杉杉股份
#                  net   slow_ma
# trade_date
# 2019-10-10  0.984059       NaN
# 2019-10-11  0.977858       NaN
# 2019-10-14  0.976972       NaN
# 2019-10-15  0.961029       NaN
# 2019-10-16  0.935342  0.957501
# 788, 中牧股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.364056       NaN
# 2019-10-11  1.329032       NaN
# 2019-10-14  1.341936       NaN
# 2019-10-15  1.403686       NaN
# 2019-10-16  1.418434  1.327404
# 789, 杭氧股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.066063       NaN
# 2019-10-11  1.063585       NaN
# 2019-10-14  1.089183       NaN
# 2019-10-15  1.091660       NaN
# 2019-10-16  1.069364  1.109952
# 790, 宇信科技
#                  net   slow_ma
# trade_date
# 2019-10-10  1.070870       NaN
# 2019-10-11  1.063300       NaN
# 2019-10-14  1.118358       NaN
# 2019-10-15  1.089453       NaN
# 2019-10-16  1.053666  1.074215
# 791, 创业慧康
#                  net   slow_ma
# trade_date
# 2019-10-10  1.088587       NaN
# 2019-10-11  1.092412       NaN
# 2019-10-14  1.136389       NaN
# 2019-10-15  1.089863       NaN
# 2019-10-16  1.128741  1.016442
# 792, 联化科技
#                  net  slow_ma
# trade_date
# 2019-10-10  1.166954      NaN
# 2019-10-11  1.174779      NaN
# 2019-10-14  1.168693      NaN
# 2019-10-15  1.154779      NaN
# 2019-10-16  1.146084  1.06397
# 793, 瑞康医药
#                  net   slow_ma
# trade_date
# 2019-10-10  1.071617       NaN
# 2019-10-11  1.063805       NaN
# 2019-10-14  1.067711       NaN
# 2019-10-15  1.048179       NaN
# 2019-10-16  1.042971  1.024263
# 794, 派思股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.324240       NaN
# 2019-10-11  1.372292       NaN
# 2019-10-14  1.418612       NaN
# 2019-10-15  1.389174       NaN
# 2019-10-16  1.334628  1.122235
# 795, 方大特钢
#                  net   slow_ma
# trade_date
# 2019-10-10  0.894955       NaN
# 2019-10-11  0.891804       NaN
# 2019-10-14  0.900208       NaN
# 2019-10-15  0.883401       NaN
# 2019-10-16  0.883401  0.907473
# 796, 太极股份
#                  net   slow_ma
# trade_date
# 2019-10-10  1.080349       NaN
# 2019-10-11  1.057547       NaN
# 2019-10-14  1.089396       NaN
# 2019-10-15  1.045604       NaN
# 2019-10-16  1.046327  1.080348
# 797, 华谊兄弟
#                  net   slow_ma
# trade_date
# 2019-10-10  0.922434       NaN
# 2019-10-11  0.911952       NaN
# 2019-10-14  0.918241       NaN
# 2019-10-15  0.905662       NaN
# 2019-10-16  0.890987  0.947521
# 798, 滨江集团
#                  net   slow_ma
# trade_date
# 2019-10-10  0.936017       NaN
# 2019-10-11  0.933647       NaN
# 2019-10-14  0.947864       NaN
# 2019-10-15  0.947864       NaN
# 2019-10-16  0.947864  0.937242
# 799, 中工国际
#                  net   slow_ma
# trade_date
# 2019-10-10  0.867133       NaN
# 2019-10-11  0.870629       NaN
# 2019-10-14  0.888111       NaN
# 2019-10-15  0.882866       NaN
# 2019-10-16  0.899474  0.915136
# 2019-10-16 17:44:24.645666
# 符合条件的stock num: 47
# ['中国人寿',
#  '中国石化',
#  '五粮液',
#  '万科A',
#  '招商蛇口',
#  '中兴通讯',
#  '万华化学',
#  '泸州老窖',
#  '中国国航',
#  '大秦铁路',
#  '东方航空',
#  '韵达股份',
#  '中国中冶',
#  '方正证券',
#  '金风科技',
#  '汇川技术',
#  '美凯龙',
#  '完美世界',
#  '中国外运',
#  '协鑫集成',
#  '东山精密',
#  '中远海发',
#  '东兴证券',
#  '亨通光电',
#  '安迪苏',
#  '郑州银行',
#  '景旺电子',
#  '南京证券',
#  '湖北能源',
#  '中天科技',
#  '老凤祥',
#  '中远海能',
#  '桐昆股份',
#  '山西证券',
#  '广深铁路',
#  '东华软件',
#  '小商品城',
#  '首创股份',
#  '江苏租赁',
#  '云南铜业',
#  '九阳股份',
#  '百联股份',
#  '益生股份',
#  '供销大集',
#  '柳钢股份',
#  '卫星石化',
#  '兆驰股份']

# %%
targets = ['中国人寿',
 '万科A',
 '海康威视',
 '招商蛇口',
 '申万宏源',
 '中国银河',
 '海尔智家',
 '东方航空',
 '南方航空',
 '新希望',
 '韵达股份',
 '荣盛石化',
 '国投电力',
 '中国中冶',
 '福耀玻璃',
 '石化油服',
 '中航资本',
 '上海莱士',
 '美锦能源',
 '巨人网络',
 '财通证券',
 '协鑫集成',
 '中科曙光',
 '深天马A',
 '江苏国信',
 '长飞光纤',
 '网宿科技',
 '中铁工业',
 '山西证券',
 '中南传媒',
 '广深铁路',
 '星宇股份',
 '张裕A',
 '首创股份',
 '厦门钨业',
 '宏发股份',
 '国药一致',
 '首钢股份',
 '中国西电',
 '锡业股份',
 '云南铜业',
 '重庆钢铁',
 '索菲亚',
 '粤高速A',
 '万丰奥威',
 '嘉化能源',
 '佳都科技',
 '迪普科技',
 '山东出版',
 '新钢股份',
 '北部湾港',
 '山鹰纸业',
 '昆仑万维',
 '中信国安',
 '晨鸣纸业',
 '南钢股份',
 '新潮能源',
 '梅花生物',
 '柳钢股份',
 '浙江东方',
 '宝新能源',
 '兆驰股份',
 '阳泉煤业',
 '蓝帆医疗',
 '太极股份',
 '滨江集团']

# %%
SMA.stocks_select(targets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fe8fd59e936e> in <module>
# ----> 1 SMA.stocks_select(targets)
#
# NameError: name 'targets' is not defined

# %% [markdown]
# # a

# %%
SMA.stock_select('华胜天成')
# Out:
# True

# %%
SMA.sma_base('工商银行', count=3*250)
# Out:
# returns    1.420783
# strat      1.163338
# dtype: float64
# returns    0.012678
# strat      0.010208
# dtype: float64
# hold_max_drawdown: -0.3446326645042419
# strat_max_drawdown: -0.28174801269825445

# %%
SMA.stock_select('农业银行')
# Out:
#                  net
# trade_date
# 2019-06-28  0.994475
# 2019-07-01  1.000000
# 2019-07-02  1.005525
# 2019-07-03  1.011051
# 2019-07-04  1.011051
#                  net
# trade_date
# 2019-09-16  0.972375
# 2019-09-17  0.964087
# 2019-09-18  0.961325
# 2019-09-19  0.961325
# 2019-09-20  0.964088
#                  net   fast_ma   slow_ma
# trade_date
# 2019-09-16  0.972375  0.965468       NaN
# 2019-09-17  0.964087  0.966850       NaN
# 2019-09-18  0.961325  0.966850       NaN
# 2019-09-19  0.961325  0.966504       NaN
# 2019-09-20  0.964088  0.966504  0.970764
# True

# %%
sma_base('农业银行', count=365, fast_ma=8, slow_ma=60)
# Out:
# returns    1.014592
# strat      0.963700
# dtype: float64
# returns    0.009298
# strat      0.007841
# dtype: float64
# hold_max_drawdown: -0.09064076953719413
# strat_max_drawdown: -0.0883253959812983

# %%
sma('600115.SH', 10, 60)
# Out:
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# returns    0.749975
# strat      0.916800
# dtype: float64
# hold_max_drawdown: -0.4637832208594973
# strat_max_drawdown: -0.2621351631716585

# %%
可以看到，策略长时间收益不及长期持有的收益，原因：上涨时反应慢收益少，下跌时反应慢造成大幅回撤

如何改进？
1、买入时的假信号。这个有点难
2、卖出是减少回撤，这个好像有点办法。如计算短期均线回踩长期均线的次数，进行提前减仓或清仓

# %%
sma('600567.SH', 10, 60)
# Out:
#      pct_chg trade_date
# 724  -0.9404 2019-09-23
# 725   0.0000 2019-09-24
# 726  -1.2658 2019-09-25
# 727  -1.2821 2019-09-26
# 728   0.3247 2019-09-27
# returns    0.885017
# strat      2.418716
# dtype: float64
# returns    0.018985
# strat      0.018940
# dtype: float64

# %%
np.exp(data[['returns','strat']].sum())
# Out:
# returns     1.119147
# strat      59.568000
# dtype: float64

# %%
data[['returns','strat']].std()
# Out:
# returns    0.028735
# strat      0.028718
# dtype: float64

# %%
g = data[['returns','strat']]

# %%
g.var()**0.5
# Out:
# returns    0.015785
# strat      0.015774
# dtype: float64

# %%
data[['returns','strat']].var()*252**0.5
# Out:
# returns    0.003955
# strat      0.003950
# dtype: float64

# %%
data[['returns','strat']].std()*252**0.5
# Out:
# returns    0.250571
# strat      0.250407
# dtype: float64

# %%
ax=data[['returns','strat']].cumsum().apply(np.exp).plot(figsize=(10,6))
data['position'].plot(ax=ax,secondary_y='position',style='--')
ax.get_legend().set_bbox_to_anchor((0.25,0.85))

# %%
from itertools import product
sma1=range(20,61,4)
sma2=range(180,281,10)
results=pd.DataFrame()
for SMA1,SMA2 in product(sma1,sma2):
    data=pd.DataFrame(df[symbol])
    data.dropna(inplace=True)
    data['returns']=np.log(data[symbol]/data[symbol].shift(1))
    data['SMA1']=data[symbol].rolling(SMA1).mean()
    data['SMA2']=data[symbol].rolling(SMA2).mean()
    data.dropna(inplace=True)
    data['position']=np.where(data['SMA1']>data['SMA2'],1,-1)
    data['strat']=data['position'].shift(1)*data['returns']
    data.dropna(inplace=True)
    pref=np.exp(data[['returns','strat']].sum())
    results=results.append(pd.DataFrame(
                {'SMA1':SMA1,'SMA2':SMA2,'MKT':pref['returns'],
                'strat':pref['strat'],
                'OUT':pref['strat']-pref['returns']},index=[0]),ignore_index=True)

# %%
results.sort_values('OUT',ascending=False).head()
# Out:
#      SMA1  SMA2       MKT      strat        OUT
# 113    60   210  1.088796  54.853838  53.765042
# 101    56   200  1.073628  50.129940  49.056312
# 112    60   200  1.073628  48.952989  47.879361
# 4      20   220  1.125262  37.589829  36.464567
# 99     56   180  0.970930  35.879995  34.909065

# %%
import math
import numpy as np
import scipy.stats as scs
import statsmodels.api as sm

# %%
def print_stat(array):
    sta=scs.describe(array)
    print('%14s %15s'%('statistics','value'))
    print(30*'-')
    print('%14s %15.5f'%('size',round(sta[0])))
    print('%14s %15.5f'%('min',sta[1][0]))
    print('%14s %15.5f'%('max',sta[1][1]))
    print('%14s %15.5f'%('mean',sta[2]))
    print('%14s %15.5f'%('std',np.sqrt(sta[3])))
    print('%14s %15.5f'%('skew',sta[4]))
    print('%14s %15.5f'%('kurtosis',sta[5]))

# %%
print_stat(data.strat.values)
# Out:
#     statistics           value
# ------------------------------
#           size      1858.00000
#            min        -0.08330
#            max         0.13187
#           mean         0.00066
#            std         0.01582
#           skew         0.38438
#       kurtosis         5.15146

# %%
plt.figure(figsize=(10,6))
plt.hist(data.strat.values,bins=100,density=True,label='frequency',color='b')
plt.xlabel('Strat_log_return')
plt.ylabel('frequency')
x=np.linspace(plt.axis()[0],plt.axis()[1])
plt.plot(x,scs.norm.pdf(x,data.strat.mean(),data.strat.std()),
        'r',lw=2.0,label='pdf')
plt.legend()

# %%
尖峰厚尾

# %%
sm.qqplot(data.strat.values,line='s')
plt.xlabel('theoretical')
plt.ylabel('sample quantiles')
# Out:
# Text(0, 0.5, 'sample quantiles')

# %%
def normal_test(arr):
    print('Skew of dataset    %14.3f' % scs.skew(arr))
    print('Skew test Pvalue   %14.3f' % scs.skewtest(arr)[1])
    print('Kurt of dataset    %14.3f' % scs.kurtosis(arr))
    print('Kurt test Pvalue   %14.3f' % scs.kurtosistest(arr)[1])
    print('Normal test Pvalue %14.3f' % scs.normaltest(arr)[1])

# %%
normal_test(data.strat.values)
# Out:
# Skew of dataset             0.384
# Skew test Pvalue            0.000
# Kurt of dataset             5.151
# Kurt test Pvalue            0.000
# Normal test Pvalue          0.000

# %%
np.quantile(data.strat.values,0.01)
# Out:
# -0.0420593102509018

# %%
np.quantile(data.strat.mean()+data.strat.std()*np.random.standard_normal(10000),0.01)
# Out:
# -0.03529155206844548

# %% [markdown]
# # MACD
# https://www.cnblogs.com/fangbei/p/wequant-strategy-macd.html

# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-

# 策略代码总共分为三大部分，1)PARAMS变量 2)initialize函数 3)handle_data函数
# 请根据指示阅读。或者直接点击运行回测按钮，进行测试，查看策略效果。

# 策略名称：MACD指标策略
# 策略详细介绍：https://wequant.io/study/strategy.macd.html
# 关键词：指数平滑移动均线、多空头预测。
# 方法：
# 1)利用talib库计算MACD值
# 2)MACD柱>0时买入，MACD柱<0时卖出

import numpy as np
import talib

# 阅读1，首次阅读可跳过:
# PARAMS用于设定程序参数，回测的起始时间、结束时间、滑点误差、初始资金和持仓。
# 可以仿照格式修改，基本都能运行。如果想了解详情请参考新手学堂的API文档。
PARAMS = {
    "start_time": "2017-02-01 00:00:00",
    "end_time": "2017-08-01 00:00:00",
    "slippage": 0.003,  # 此处“slippage"包含佣金（千二）+交易滑点（千一）
    "account_initial": {"cash": 100000,
                      "security": 0},
}

# %%
class Data:
    def get_price(security_code, count=365, frequency='1d'):
        import sys
        sys.path.append('/Users/luoyonggui/PycharmProjects/mayiutils_n1/mayiutils/db')
        from pymongo_wrapper import PyMongoWrapper
        mongo = PyMongoWrapper()
        table = mongo.getCollection('finance', security_code)
        start_date = datetime.now() - timedelta(days=count)
        dft = mongo.findAll(table, {'trade_date': {'$gte': start_date}}, fieldlist=['trade_date', 'pct_chg', 'close'], returnFmt='df')
    
        
class User_data:
    pass
class Account:
    def __init__(self, cash, security):
        self.cash = cash
        self.security = security
class Order:
    def sell_limit(security, quantity, price):
        pass
    def buy_limit(security, quantity, price):
        
        
class Context:
    def __init__(self, user_data=User_data(), account=Account(**PARAMS['account_initial'])):
        self.user_data = user_data
        self.account = account
        import sys
        # print(sys.path)
        sys.path.append('/Users/luoyonggui/PycharmProjects/mayiutils_n1/mayiutils/config')
        from logging_utils import get_logger
        log_path = os.path.join(LOG_PATH, 'output.log')
        self.log = get_logger(__file__, file_handler=True, log_path=log_path)

# %%
context = Context()

# %%
# 阅读2，遇到不明白的变量可以跳过，需要的时候回来查阅:
# initialize函数是两大核心函数之一（另一个是handle_data），用于初始化策略变量。
# 策略变量包含：必填变量，以及非必填（用户自己方便使用）的变量
def initialize(context):
#     context = {
#         'frequency': '1d',
#         'benchmark': '000001.SH',
#         'security': '东方航空',
#         'user_data': {
#             'fast_period': 12,
#             'slow_period': 26,
#             'macd_window': 9,
#             'longest_history': 100
#         }
#     }
    # 设置回测频率, 可选："1m", "5m", "15m", "30m", "60m", "4h", "1d", "1w"
    context.frequency = "15m"
    # 设置回测基准, 比特币："huobi_cny_btc", 莱特币："huobi_cny_ltc", 以太坊："huobi_cny_eth"
    context.benchmark = "huobi_cny_btc"
    # 设置回测标的, 比特币："huobi_cny_btc", 莱特币："huobi_cny_ltc", 以太坊："huobi_cny_eth"
    context.security = "huobi_cny_btc"

    # 设置使用talib计算MACD的参数
    # 周期快速移动平均
    context.user_data.fast_period = 12
    # 周期慢速移动平均
    context.user_data.slow_period = 26
    # 周期移动平均
    context.user_data.macd_window = 9
    # 历史数据要足够长，才能够拿到收敛的MACD
    context.user_data.longest_history = 100
    print(context)
    return context

# %%
context = initialize(context)
# Out:
# <__main__.Context object at 0x1118b8a20>

# %%
context.user_data.longest_history
# Out:
# 100

# %%
context.user_data.macd_window
# Out:
# 9

# %%
# 阅读3，策略核心逻辑：
# handle_data函数定义了策略的执行逻辑，按照frequency生成的bar依次读取并执行策略逻辑，直至程序结束。
# handle_data和bar的详细说明，请参考新手学堂的解释文档。
def handle_data(context):
    # 获取历史数据, 取后longest_history根bar
    hist = context.data.get_price(context.security, count=context.user_data.longest_history, frequency=context.frequency)
    if len(hist.index) < context.user_data.longest_history:
        context.log.warn("bar的数量不足, 等待下一根bar...")
        return

    # 历史收盘价
    prices = np.array(hist["close"])
    # 初始化买入卖出信号
    long_signal_triggered = False
    short_signal_triggered = False

    try:
        # talib计算MACD，返回三个数组，分别为DIF, DEA和MACD的值
        macd_tmp = talib.MACD(prices, fastperiod=context.user_data.fast_period, slowperiod=context.user_data.slow_period, signalperiod=context.user_data.macd_window)
        # 获取MACD值
        macd_hist = macd_tmp[2]
        # 获取最新一个MACD的值
        macd = macd_hist[-1]
        context.log.info("当前MACD为: %s" % macd)
    except:
        context.log.error("计算MACD出错...")
        return
    for macd in macd_hist:
        context.log.info("当前MACD为: %s" % macd)
        # macd大于0时，产生买入信号
        if macd > 0:
            long_signal_triggered = True
        # macd小于0时，产生卖出信号
        elif macd < 0:
            short_signal_triggered = True

        # 有卖出信号，且持有仓位，则市价单全仓卖出
        if short_signal_triggered:
            context.log.info("MACD小于0，产生卖出信号")
            if context.account.security >= 0:
                # 卖出信号，且不是空仓，则市价单全仓清空
                context.log.info("正在卖出 %s" % context.security)
                context.log.info("卖出数量为 %s" % context.account.security)
                context.order.sell_limit(context.security, quantity=str(context.account.huobi_cny_btc), price=str(prices[-1]*0.98))
            else:
                context.log.info("仓位不足，无法卖出")
        # 有买入信号，且持有现金，则市价单全仓买入
        elif long_signal_triggered:
            context.log.info("MACD大于0，产生买入信号")
            if context.account.cash >= 0:
                # 买入信号，且持有现金，则市价单全仓买入
                context.log.info("正在买入 %s" % context.security)
                context.log.info("下单金额为 %s 元" % context.account.huobi_cny_cash)
                context.order.buy_limit(context.security, quantity=str(context.account.huobi_cny_cash/prices[-1]*0.98), price=str(prices[-1]*1.02))
            else:
                context.log.info("现金不足，无法下单")
        else:
            context.log.info("无交易信号，进入下一根bar")
