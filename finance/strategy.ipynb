# %% [markdown]
# # 均线策略SMA
# 本质是趋势交易
#
# 当短期均线 上穿 长期均线是买入；相反是卖出
#
# 本质：是让价格的反应变得迟钝，均线周期越长，价格的反应就越迟钝!
#
# 迟钝的好处是平抑了一些扰动，降低交易次数；缺点是：反应迟钝，往往会造成
# 1. 当短期均线刚上穿长期均线时，股票已经上涨了很多（有可能上涨趋势已经结束),
# 1. 当短期均线下穿长期均线时，股价已经下跌很多(损失了很多利润)
#
# 为了避免情况1，短期均线不能太长，这样可以对短期股票走势会灵敏一些，上涨时可以很快的上穿长期均线，下跌时也可以快速下穿
#
# 长期均线不能太短，应该在股票的整个上涨走势中保持平稳缓慢上升，否则交易频率会上升。那么怎么避免卖出时，收益出现大幅回撤呢？
#
# 有什么业务含义做解释或者支持？
#
# 股价有时候会受到意外情况，而剧烈波动，使用短期均线会平抑这种扰动。但是好像找不到其它的解释了呢。。。
#
# 所以，不能使用。。。

# %%
import sys
sys.path.append('/Users/luoyonggui/PycharmProjects/mayifactories/finance/strategy')
from sma import SMA
# %matplotlib inline

# %%
SMA.sma_base('中国石油', count=365, fast_ma=8, slow_ma=60)
# Out:
# returns    0.851991
# strat      1.004672
# dtype: float64
# returns    0.012232
# strat      0.009556
# dtype: float64
# hold_max_drawdown: -0.34092899381273
# strat_max_drawdown: -0.14080444286393523

# %%
SMA.sma_base('中国石化')
# Out:
# returns    0.879975
# strat      0.865878
# dtype: float64
# returns    0.013930
# strat      0.009489
# dtype: float64
# hold_max_drawdown: -0.2963506195428287
# strat_max_drawdown: -0.20209894324956168

# %%
SMA.stock_select('浦发银行')
# Out:
#                  net   slow_ma
# trade_date
# 2019-09-24  1.015558       NaN
# 2019-09-25  1.020744       NaN
# 2019-09-26  1.034573       NaN
# 2019-09-27  1.028523       NaN
# 2019-09-30  1.023337  0.998905
# True

# %%
SMA.sma_base('万华化学')
# Out:
# returns    1.011633
# strat      1.259781
# dtype: float64
# returns    0.027567
# strat      0.020059
# dtype: float64
# hold_max_drawdown: -0.49155782425327466
# strat_max_drawdown: -0.2523808279755062

# %%
SMA.stocks_select(SMA.get_stocks_dict_top_n(1000, '20191010'))
# Out:
# 2019-10-10 20:55:29.130863
# 股票池容量：1000
# 0, 工商银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.998199       NaN
# 2019-09-30  0.996397       NaN
# 2019-10-08  1.001803       NaN
# 2019-10-09  1.005406       NaN
# 2019-10-10  1.003604  0.995076
# 1, 建设银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.011445       NaN
# 2019-09-30  1.000000       NaN
# 2019-10-08  1.012876       NaN
# 2019-10-09  1.021461       NaN
# 2019-10-10  1.021461  1.016524
# 2, 中国平安
#                  net   slow_ma
# trade_date
# 2019-09-27  1.013396       NaN
# 2019-09-30  0.998935       NaN
# 2019-10-08  1.009952       NaN
# 2019-10-09  1.012017       NaN
# 2019-10-10  1.015690  1.004481
# 3, 贵州茅台
#                  net   slow_ma
# trade_date
# 2019-09-27  1.195648       NaN
# 2019-09-30  1.170458       NaN
# 2019-10-08  1.187863       NaN
# 2019-10-09  1.167212       NaN
# 2019-10-10  1.175548  1.078461
# 4, 农业银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.972144       NaN
# 2019-09-30  0.963787       NaN
# 2019-10-08  0.969358       NaN
# 2019-10-09  0.972144       NaN
# 2019-10-10  0.972144  0.972887
# 5, 中国石油
#                  net   slow_ma
# trade_date
# 2019-09-27  0.929105       NaN
# 2019-09-30  0.941269       NaN
# 2019-10-08  0.929104       NaN
# 2019-10-09  0.927583       NaN
# 2019-10-10  0.926063  0.946687
# 6, 中国银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.972973       NaN
# 2019-09-30  0.967568       NaN
# 2019-10-08  0.972973       NaN
# 2019-10-09  0.978379       NaN
# 2019-10-10  0.972974  0.976531
# 7, 招商银行
#                  net  slow_ma
# trade_date
# 2019-09-27  1.029227      NaN
# 2019-09-30  1.016070      NaN
# 2019-10-08  1.017825      NaN
# 2019-10-09  1.028643      NaN
# 2019-10-10  1.026596  1.03104
# 8, 中国人寿
#                  net   slow_ma
# trade_date
# 2019-09-27  0.992569       NaN
# 2019-09-30  0.972052       NaN
# 2019-10-08  0.978419       NaN
# 2019-10-09  0.981249       NaN
# 2019-10-10  0.987969  1.027707
# 9, 中国石化
#                  net   slow_ma
# trade_date
# 2019-09-27  0.981634       NaN
# 2019-09-30  0.987535       NaN
# 2019-10-08  0.983601       NaN
# 2019-10-09  0.985568       NaN
# 2019-10-10  0.983601  0.986612
# 10, 五粮液
#                  net   slow_ma
# trade_date
# 2019-09-27  1.058291       NaN
# 2019-09-30  1.026653       NaN
# 2019-10-08  1.050065       NaN
# 2019-10-09  1.042551       NaN
# 2019-10-10  1.036065  1.017797
# 11, 交通银行
#                  net  slow_ma
# trade_date
# 2019-09-27  0.956446      NaN
# 2019-09-30  0.949478      NaN
# 2019-10-08  0.956446      NaN
# 2019-10-09  0.965156      NaN
# 2019-10-10  0.963414  0.97259
# 12, 长江电力
#                  net   slow_ma
# trade_date
# 2019-09-27  1.050605       NaN
# 2019-09-30  1.052337       NaN
# 2019-10-08  1.072541       NaN
# 2019-10-09  1.066191       NaN
# 2019-10-10  1.052914  1.069746
# 13, 中国人保
#                  net   slow_ma
# trade_date
# 2019-09-27  0.976616       NaN
# 2019-09-30  0.966501       NaN
# 2019-10-08  0.973244       NaN
# 2019-10-09  0.975492       NaN
# 2019-10-10  0.979987  0.986339
# 14, 兴业银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.998305       NaN
# 2019-09-30  0.989276       NaN
# 2019-10-08  1.013542       NaN
# 2019-10-09  1.032729       NaN
# 2019-10-10  1.033858  1.020897
# 15, 中国神华
#                  net   slow_ma
# trade_date
# 2019-09-27  0.980075       NaN
# 2019-09-30  0.984794       NaN
# 2019-10-08  0.977978       NaN
# 2019-10-09  0.991088       NaN
# 2019-10-10  0.986368  0.995178
# 16, 恒瑞医药
#                  net   slow_ma
# trade_date
# 2019-09-27  1.202343       NaN
# 2019-09-30  1.196854       NaN
# 2019-10-08  1.191959       NaN
# 2019-10-09  1.167333       NaN
# 2019-10-10  1.231270  1.086021
# 17, 美的集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.952130       NaN
# 2019-09-30  0.948048       NaN
# 2019-10-08  0.976806       NaN
# 2019-10-09  0.974023       NaN
# 2019-10-10  0.968086  0.976229
# 18, 浦发银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.048459       NaN
# 2019-09-30  1.043172       NaN
# 2019-10-08  1.048459       NaN
# 2019-10-09  1.056389       NaN
# 2019-10-10  1.053745  1.020866
# 19, 格力电器
#                  net   slow_ma
# trade_date
# 2019-09-27  1.040290       NaN
# 2019-09-30  1.047603       NaN
# 2019-10-08  1.063143       NaN
# 2019-10-09  1.042483       NaN
# 2019-10-10  1.055098  1.005301
# 20, 中国太保
#                  net   slow_ma
# trade_date
# 2019-09-27  1.033488       NaN
# 2019-09-30  1.012295       NaN
# 2019-10-08  1.032326       NaN
# 2019-10-09  1.047132       NaN
# 2019-10-10  1.043358  1.086722
# 21, 平安银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.172563       NaN
# 2019-09-30  1.149702       NaN
# 2019-10-08  1.194687       NaN
# 2019-10-09  1.198374       NaN
# 2019-10-10  1.197637  1.072111
# 22, 万科A
#                  net   slow_ma
# trade_date
# 2019-09-27  0.927207       NaN
# 2019-09-30  0.923641       NaN
# 2019-10-08  0.940046       NaN
# 2019-10-09  0.955737       NaN
# 2019-10-10  0.949319  0.967181
# 23, 海天味业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.063951       NaN
# 2019-09-30  1.069889       NaN
# 2019-10-08  1.062004       NaN
# 2019-10-09  1.068137       NaN
# 2019-10-10  1.066677  1.025156
# 24, 工业富联
#                  net   slow_ma
# trade_date
# 2019-09-27  1.183826       NaN
# 2019-09-30  1.131194       NaN
# 2019-10-08  1.146905       NaN
# 2019-10-09  1.117840       NaN
# 2019-10-10  1.150047  1.097058
# 25, 中信银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.013627       NaN
# 2019-09-30  0.999451       NaN
# 2019-10-08  1.017171       NaN
# 2019-10-09  1.034892       NaN
# 2019-10-10  1.049069  1.010043
# 26, 海康威视
#                  net   slow_ma
# trade_date
# 2019-09-25  1.211874       NaN
# 2019-09-26  1.217006       NaN
# 2019-09-27  1.216640       NaN
# 2019-09-30  1.184016       NaN
# 2019-10-10  1.132696  1.129281
# 27, 上汽集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.970437       NaN
# 2019-09-30  0.973713       NaN
# 2019-10-08  0.970437       NaN
# 2019-10-09  0.959792       NaN
# 2019-10-10  0.979036  0.999569
# 28, 中信证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.008940       NaN
# 2019-09-30  0.983990       NaN
# 2019-10-08  0.977424       NaN
# 2019-10-09  0.973047       NaN
# 2019-10-10  0.980050  0.992003
# 29, 民生银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.010032       NaN
# 2019-09-30  1.006688       NaN
# 2019-10-08  1.016722       NaN
# 2019-10-09  1.026755       NaN
# 2019-10-10  1.021738  0.996766
# 30, 中国建筑
#                  net   slow_ma
# trade_date
# 2019-09-27  0.948005       NaN
# 2019-09-30  0.941072       NaN
# 2019-10-08  0.944538       NaN
# 2019-10-09  0.949738       NaN
# 2019-10-10  0.949738  0.985007
# 31, 迈瑞医疗
#                  net   slow_ma
# trade_date
# 2019-09-27  1.148735       NaN
# 2019-09-30  1.116180       NaN
# 2019-10-08  1.110310       NaN
# 2019-10-09  1.060751       NaN
# 2019-10-10  1.119628  1.038755
# 32, 光大银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.063493       NaN
# 2019-09-30  1.042330       NaN
# 2019-10-08  1.082012       NaN
# 2019-10-09  1.119050       NaN
# 2019-10-10  1.126986  1.020019
# 33, 海螺水泥
#                  net   slow_ma
# trade_date
# 2019-09-27  1.015189       NaN
# 2019-09-30  1.012740       NaN
# 2019-10-08  1.039688       NaN
# 2019-10-09  1.024255       NaN
# 2019-10-10  1.021070  0.993452
# 34, 中国广核
#                  net  slow_ma
# trade_date
# 2019-09-27  1.698797      NaN
# 2019-09-30  1.686749      NaN
# 2019-10-08  1.662652      NaN
# 2019-10-09  1.654620      NaN
# 2019-10-10  1.682732      NaN
# 35, 中国中车
#                  net   slow_ma
# trade_date
# 2019-09-27  0.953204       NaN
# 2019-09-30  0.948024       NaN
# 2019-10-08  0.944139       NaN
# 2019-10-09  0.945434       NaN
# 2019-10-10  0.946729  0.968972
# 36, 温氏股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.961488       NaN
# 2019-09-30  0.974063       NaN
# 2019-10-08  0.994760       NaN
# 2019-10-09  0.986376       NaN
# 2019-10-10  1.017815  1.043978
# 37, 中国联通
#                  net   slow_ma
# trade_date
# 2019-09-27  1.027029       NaN
# 2019-09-30  1.015204       NaN
# 2019-10-08  1.018583       NaN
# 2019-10-09  1.023650       NaN
# 2019-10-10  1.028717  1.006336
# 38, 保利地产
#                  net   slow_ma
# trade_date
# 2019-09-27  1.057948       NaN
# 2019-09-30  1.062405       NaN
# 2019-10-08  1.122583       NaN
# 2019-10-09  1.164188       NaN
# 2019-10-10  1.162703  1.050223
# 39, 中国国旅
#                  net  slow_ma
# trade_date
# 2019-09-27  1.057651      NaN
# 2019-09-30  1.058220      NaN
# 2019-10-08  1.104161      NaN
# 2019-10-09  1.060381      NaN
# 2019-10-10  1.083464   1.0342
# 40, 中信建投
#                  net   slow_ma
# trade_date
# 2019-09-27  1.092547       NaN
# 2019-09-30  1.060246       NaN
# 2019-10-08  1.089697       NaN
# 2019-10-09  1.135299       NaN
# 2019-10-10  1.144799  0.978197
# 41, 顺丰控股
#                  net   slow_ma
# trade_date
# 2019-09-27  1.166275       NaN
# 2019-09-30  1.172521       NaN
# 2019-10-08  1.135639       NaN
# 2019-10-09  1.204943       NaN
# 2019-10-10  1.224277  1.120189
# 42, 牧原股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.051815       NaN
# 2019-09-30  1.090485       NaN
# 2019-10-08  1.162410       NaN
# 2019-10-09  1.175558       NaN
# 2019-10-10  1.268520  1.135563
# 43, 伊利股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.853134       NaN
# 2019-09-30  0.860070       NaN
# 2019-10-08  0.860673       NaN
# 2019-10-09  0.850420       NaN
# 2019-10-10  0.858562  0.896656
# 44, 华泰证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.929729       NaN
# 2019-09-30  0.918185       NaN
# 2019-10-08  0.906642       NaN
# 2019-10-09  0.897503       NaN
# 2019-10-10  0.897022  0.950188
# 45, 海通证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.097184       NaN
# 2019-09-30  1.055837       NaN
# 2019-10-08  1.049931       NaN
# 2019-10-09  1.055838       NaN
# 2019-10-10  1.070604  1.038168
# 46, 三六零
#                  net  slow_ma
# trade_date
# 2019-09-27  1.159747      NaN
# 2019-09-30  1.150438      NaN
# 2019-10-08  1.132800      NaN
# 2019-10-09  1.144069      NaN
# 2019-10-10  1.191105  1.04288
# 47, 中国交建
#                  net   slow_ma
# trade_date
# 2019-09-27  0.933700       NaN
# 2019-09-30  0.930937       NaN
# 2019-10-08  0.930016       NaN
# 2019-10-09  0.931858       NaN
# 2019-10-10  0.932779  0.969199
# 48, 招商蛇口
#                  net   slow_ma
# trade_date
# 2019-09-27  0.906054       NaN
# 2019-09-30  0.905577       NaN
# 2019-10-08  0.931328       NaN
# 2019-10-09  0.942296       NaN
# 2019-10-10  0.945157  0.958653
# 49, 宁德时代
#                  net   slow_ma
# trade_date
# 2019-09-27  0.990978       NaN
# 2019-09-30  0.991533       NaN
# 2019-10-08  0.974337       NaN
# 2019-10-09  0.958250       NaN
# 2019-10-10  0.983212  1.022824
# 50, 国泰君安
#                  net   slow_ma
# trade_date
# 2019-09-27  1.018787       NaN
# 2019-09-30  0.990597       NaN
# 2019-10-08  0.981576       NaN
# 2019-10-09  0.979885       NaN
# 2019-10-10  0.986650  0.994903
# 51, 上海机场
#                  net  slow_ma
# trade_date
# 2019-09-27  0.989628      NaN
# 2019-09-30  0.987771      NaN
# 2019-10-08  0.963008      NaN
# 2019-10-09  0.967342      NaN
# 2019-10-10  0.996438  1.01697
# 52, 新华保险
#                  net   slow_ma
# trade_date
# 2019-09-27  0.952257       NaN
# 2019-09-30  0.938185       NaN
# 2019-10-08  0.947437       NaN
# 2019-10-09  0.954955       NaN
# 2019-10-10  0.956691  0.992253
# 53, 洋河股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.809687       NaN
# 2019-09-30  0.805890       NaN
# 2019-10-08  0.804805       NaN
# 2019-10-09  0.792717       NaN
# 2019-10-10  0.790005  0.860101
# 54, 宁波银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.158955       NaN
# 2019-09-30  1.132013       NaN
# 2019-10-08  1.178264       NaN
# 2019-10-09  1.209696       NaN
# 2019-10-10  1.210145  1.059751
# 55, 中国中铁
#                  net   slow_ma
# trade_date
# 2019-09-27  0.955455       NaN
# 2019-09-30  0.953865       NaN
# 2019-10-08  0.960224       NaN
# 2019-10-09  0.963404       NaN
# 2019-10-10  0.960224  0.980139
# 56, 立讯精密
#                  net   slow_ma
# trade_date
# 2019-09-27  1.403421       NaN
# 2019-09-30  1.346077       NaN
# 2019-10-08  1.317908       NaN
# 2019-10-09  1.305332       NaN
# 2019-10-10  1.360664  1.192648
# 57, 药明康德
#                  net   slow_ma
# trade_date
# 2019-09-27  1.351974       NaN
# 2019-09-30  1.346693       NaN
# 2019-10-08  1.300095       NaN
# 2019-10-09  1.296367       NaN
# 2019-10-10  1.370458  1.165238
# 58, 中兴通讯
#                  net   slow_ma
# trade_date
# 2019-09-27  1.023424       NaN
# 2019-09-30  0.986741       NaN
# 2019-10-08  0.980576       NaN
# 2019-10-09  0.991057       NaN
# 2019-10-10  1.013251  0.979334
# 59, 万华化学
#                  net   slow_ma
# trade_date
# 2019-09-27  1.065879       NaN
# 2019-09-30  1.065396       NaN
# 2019-10-08  1.072636       NaN
# 2019-10-09  1.051882       NaN
# 2019-10-10  1.067568  1.058113
# 60, 上海银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.067118       NaN
# 2019-09-30  1.063705       NaN
# 2019-10-08  1.070531       NaN
# 2019-10-09  1.087596       NaN
# 2019-10-10  1.087596  1.035834
# 61, 上港集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.907087       NaN
# 2019-09-30  0.896063       NaN
# 2019-10-08  0.897637       NaN
# 2019-10-09  0.902362       NaN
# 2019-10-10  0.911810  0.981812
# 62, 比亚迪
#                  net   slow_ma
# trade_date
# 2019-09-27  0.904483       NaN
# 2019-09-30  0.908207       NaN
# 2019-10-08  0.901504       NaN
# 2019-10-09  0.895360       NaN
# 2019-10-10  0.912303  0.960144
# 63, 宝钢股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.932285       NaN
# 2019-09-30  0.930711       NaN
# 2019-10-08  0.929136       NaN
# 2019-10-09  0.927561       NaN
# 2019-10-10  0.932285  0.955486
# 64, 京东方A
#                  net   slow_ma
# trade_date
# 2019-09-27  1.021738       NaN
# 2019-09-30  1.019020       NaN
# 2019-10-08  1.019020       NaN
# 2019-10-09  1.019020       NaN
# 2019-10-10  1.024454  1.059058
# 65, 中国铁建
#                  net   slow_ma
# trade_date
# 2019-09-27  1.013578       NaN
# 2019-09-30  1.002976       NaN
# 2019-10-08  1.021000       NaN
# 2019-10-09  1.022060       NaN
# 2019-10-10  1.023120  1.013358
# 66, 广汽集团
#                  net   slow_ma
# trade_date
# 2019-09-27  1.076997       NaN
# 2019-09-30  1.076997       NaN
# 2019-10-08  1.066464       NaN
# 2019-10-09  1.070852       NaN
# 2019-10-10  1.096306  1.002443
# 67, 泸州老窖
#                  net   slow_ma
# trade_date
# 2019-09-27  1.043588       NaN
# 2019-09-30  1.019658       NaN
# 2019-10-08  1.055912       NaN
# 2019-10-09  1.046699       NaN
# 2019-10-10  1.037127  1.023742
# 68, 中国重工
#                  net   slow_ma
# trade_date
# 2019-09-27  0.921641       NaN
# 2019-09-30  0.918307       NaN
# 2019-10-08  0.909975       NaN
# 2019-10-09  0.908307       NaN
# 2019-10-10  0.919974  0.981781
# 69, 三一重工
#                  net   slow_ma
# trade_date
# 2019-09-27  1.177459       NaN
# 2019-09-30  1.166836       NaN
# 2019-10-08  1.188898       NaN
# 2019-10-09  1.175824       NaN
# 2019-10-10  1.178275  1.138615
# 70, 申万宏源
#                  net   slow_ma
# trade_date
# 2019-09-27  0.999998       NaN
# 2019-09-30  0.993761       NaN
# 2019-10-08  0.989603       NaN
# 2019-10-09  0.993761       NaN
# 2019-10-10  0.999998  1.010671
# 71, 中国国航
#                  net   slow_ma
# trade_date
# 2019-09-27  0.904078       NaN
# 2019-09-30  0.882027       NaN
# 2019-10-08  0.872105       NaN
# 2019-10-09  0.863284       NaN
# 2019-10-10  0.900770  0.922693
# 72, 华夏银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.001341       NaN
# 2019-09-30  0.987954       NaN
# 2019-10-08  0.995986       NaN
# 2019-10-09  1.006696       NaN
# 2019-10-10  1.008035  0.993331
# 73, 北京银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.964220       NaN
# 2019-09-30  0.958853       NaN
# 2019-10-08  0.964219       NaN
# 2019-10-09  0.974953       NaN
# 2019-10-10  0.978531  0.970481
# 74, 爱尔眼科
#                  net  slow_ma
# trade_date
# 2019-09-27  1.150897      NaN
# 2019-09-30  1.161044      NaN
# 2019-10-08  1.181012      NaN
# 2019-10-09  1.159735      NaN
# 2019-10-10  1.204579  1.06588
# 75, 大秦铁路
#                  net   slow_ma
# trade_date
# 2019-09-27  0.966961       NaN
# 2019-09-30  0.964420       NaN
# 2019-10-08  0.959337       NaN
# 2019-10-09  0.965691       NaN
# 2019-10-10  0.965691  0.981787
# 76, 招商证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.029431       NaN
# 2019-09-30  0.999654       NaN
# 2019-10-08  0.992969       NaN
# 2019-10-09  0.994184       NaN
# 2019-10-10  1.013023  1.003965
# 77, 中油资本
#                  net   slow_ma
# trade_date
# 2019-09-27  1.057562       NaN
# 2019-09-30  1.062717       NaN
# 2019-10-08  1.063576       NaN
# 2019-10-09  1.068731       NaN
# 2019-10-10  1.056703  1.041854
# 78, 中国银河
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986737       NaN
# 2019-09-30  0.962864       NaN
# 2019-10-08  0.953138       NaN
# 2019-10-09  0.958443       NaN
# 2019-10-10  0.968170  0.984748
# 79, 山东黄金
#                  net   slow_ma
# trade_date
# 2019-09-27  1.228029       NaN
# 2019-09-30  1.222259       NaN
# 2019-10-08  1.215046       NaN
# 2019-10-09  1.272030       NaN
# 2019-10-10  1.268783  1.244347
# 80, 恒力石化
#                  net   slow_ma
# trade_date
# 2019-09-27  1.296172       NaN
# 2019-09-30  1.270640       NaN
# 2019-10-08  1.271491       NaN
# 2019-10-09  1.283407       NaN
# 2019-10-10  1.295322  1.153618
# 81, 广发证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.002179       NaN
# 2019-09-30  0.984762       NaN
# 2019-10-08  0.980407       NaN
# 2019-10-09  0.982585       NaN
# 2019-10-10  0.991293  0.985413
# 82, 中公教育
#                  net   slow_ma
# trade_date
# 2019-09-27  1.284278       NaN
# 2019-09-30  1.260265       NaN
# 2019-10-08  1.254069       NaN
# 2019-10-09  1.312938       NaN
# 2019-10-10  1.303643  1.149111
# 83, 东方财富
#                  net   slow_ma
# trade_date
# 2019-09-27  1.178017       NaN
# 2019-09-30  1.143962       NaN
# 2019-10-08  1.143187       NaN
# 2019-10-09  1.154798       NaN
# 2019-10-10  1.165633  1.137202
# 84, 国信证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.946071       NaN
# 2019-09-30  0.946071       NaN
# 2019-10-08  0.939908       NaN
# 2019-10-09  0.939137       NaN
# 2019-10-10  0.946841  1.004713
# 85, 隆基股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.215896       NaN
# 2019-09-30  1.204872       NaN
# 2019-10-08  1.185120       NaN
# 2019-10-09  1.208546       NaN
# 2019-10-10  1.220948  1.193801
# 86, 海尔智家
#                  net   slow_ma
# trade_date
# 2019-09-27  0.908562       NaN
# 2019-09-30  0.904425       NaN
# 2019-10-08  0.919203       NaN
# 2019-10-09  0.921567       NaN
# 2019-10-10  0.929843  0.933319
# 87, 国电南瑞
#                  net   slow_ma
# trade_date
# 2019-09-27  1.121927       NaN
# 2019-09-30  1.112678       NaN
# 2019-10-08  1.117575       NaN
# 2019-10-09  1.147500       NaN
# 2019-10-10  1.177970  1.023613
# 88, 苏宁易购
#                  net   slow_ma
# trade_date
# 2019-09-27  0.937156       NaN
# 2019-09-30  0.943532       NaN
# 2019-10-08  0.945354       NaN
# 2019-10-09  0.941710       NaN
# 2019-10-10  0.945353  0.961111
# 89, 云南白药
#                  net   slow_ma
# trade_date
# 2019-09-27  0.931420       NaN
# 2019-09-30  0.926425       NaN
# 2019-10-08  0.935440       NaN
# 2019-10-09  0.928253       NaN
# 2019-10-10  0.920335  0.936561
# 90, 鹏鼎控股
#                  net   slow_ma
# trade_date
# 2019-09-27  1.380969       NaN
# 2019-09-30  1.349026       NaN
# 2019-10-08  1.373572       NaN
# 2019-10-09  1.328851       NaN
# 2019-10-10  1.361804  1.244799
# 91, 华能国际
#                  net   slow_ma
# trade_date
# 2019-09-27  0.944001       NaN
# 2019-09-30  0.928001       NaN
# 2019-10-08  0.931201       NaN
# 2019-10-09  0.928001       NaN
# 2019-10-10  0.937601  1.023814
# 92, 潍柴动力
#                  net   slow_ma
# trade_date
# 2019-09-27  0.975292       NaN
# 2019-09-30  0.965823       NaN
# 2019-10-08  0.956354       NaN
# 2019-10-09  0.966683       NaN
# 2019-10-10  0.986482  1.000832
# 93, 汇顶科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.560418       NaN
# 2019-09-30  1.412501       NaN
# 2019-10-08  1.324306       NaN
# 2019-10-09  1.336181       NaN
# 2019-10-10  1.371459  1.265757
# 94, 中国通号
#                  net  slow_ma
# trade_date
# 2019-09-27  1.505983      NaN
# 2019-09-30  1.446153      NaN
# 2019-10-08  1.418802      NaN
# 2019-10-09  1.427349      NaN
# 2019-10-10  1.441025      NaN
# 95, 陕西煤业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.001142       NaN
# 2019-09-30  0.995441       NaN
# 2019-10-08  1.007983       NaN
# 2019-10-09  1.004562       NaN
# 2019-10-10  1.005702  1.029762
# 96, 绿地控股
#                  net   slow_ma
# trade_date
# 2019-09-27  1.077860       NaN
# 2019-09-30  1.077860       NaN
# 2019-10-08  1.082440       NaN
# 2019-10-09  1.103813       NaN
# 2019-10-10  1.100760  1.061703
# 97, 韦尔股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.887812       NaN
# 2019-09-30  1.777991       NaN
# 2019-10-08  1.750625       NaN
# 2019-10-09  1.812242       NaN
# 2019-10-10  1.835801  1.507319
# 98, 东方航空
#                  net   slow_ma
# trade_date
# 2019-09-27  0.868552       NaN
# 2019-09-30  0.861896       NaN
# 2019-10-08  0.855240       NaN
# 2019-10-09  0.855240       NaN
# 2019-10-10  0.885190  0.906738
# 99, 永辉超市
#                  net  slow_ma
# trade_date
# 2019-09-27  0.897798      NaN
# 2019-09-30  0.890783      NaN
# 2019-10-08  0.897797      NaN
# 2019-10-09  0.893790      NaN
# 2019-10-10  0.901806   0.9494
# 100, 华夏幸福
#                  net   slow_ma
# trade_date
# 2019-09-27  0.898701       NaN
# 2019-09-30  0.887837       NaN
# 2019-10-08  0.912198       NaN
# 2019-10-09  0.920428       NaN
# 2019-10-10  0.918452  0.923483
# 101, 南方航空
#                  net   slow_ma
# trade_date
# 2019-09-27  0.911370       NaN
# 2019-09-30  0.903196       NaN
# 2019-10-08  0.889573       NaN
# 2019-10-09  0.884123       NaN
# 2019-10-10  0.926354  0.940862
# 102, 中国核电
#                  net  slow_ma
# trade_date
# 2019-09-27  0.992390      NaN
# 2019-09-30  0.984942      NaN
# 2019-10-08  0.988666      NaN
# 2019-10-09  0.992390      NaN
# 2019-10-10  0.996113  1.01349
# 103, 华能水电
#                  net   slow_ma
# trade_date
# 2019-09-27  1.014321       NaN
# 2019-09-30  1.011935       NaN
# 2019-10-08  1.019094       NaN
# 2019-10-09  1.050120       NaN
# 2019-10-10  1.076373  1.086915
# 104, 双汇发展
#                  net   slow_ma
# trade_date
# 2019-09-27  0.962802       NaN
# 2019-09-30  0.988003       NaN
# 2019-10-08  0.975203       NaN
# 2019-10-09  0.960003       NaN
# 2019-10-10  0.976003  0.958441
# 105, 智飞生物
#                  net   slow_ma
# trade_date
# 2019-09-27  1.089549       NaN
# 2019-09-30  1.078412       NaN
# 2019-10-08  1.064776       NaN
# 2019-10-09  1.080913       NaN
# 2019-10-10  1.134095  1.094968
# 106, 用友网络
#                  net   slow_ma
# trade_date
# 2019-09-27  1.240591       NaN
# 2019-09-30  1.224341       NaN
# 2019-10-08  1.225530       NaN
# 2019-10-09  1.243366       NaN
# 2019-10-10  1.272300  1.216067
# 107, 新希望
#                  net   slow_ma
# trade_date
# 2019-09-27  0.846556       NaN
# 2019-09-30  0.890102       NaN
# 2019-10-08  0.933129       NaN
# 2019-10-09  0.931056       NaN
# 2019-10-10  0.977194  0.966012
# 108, 江苏银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.989725       NaN
# 2019-09-30  0.978064       NaN
# 2019-10-08  0.985353       NaN
# 2019-10-09  0.997014       NaN
# 2019-10-10  0.998471  0.991864
# 109, 韵达股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.044486       NaN
# 2019-09-30  1.077694       NaN
# 2019-10-08  1.042606       NaN
# 2019-10-09  1.074875       NaN
# 2019-10-10  1.098685  1.096705
# 110, 洛阳钼业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.950776       NaN
# 2019-09-30  0.943004       NaN
# 2019-10-08  0.935232       NaN
# 2019-10-09  0.937823       NaN
# 2019-10-10  0.935232  0.960059
# 111, 紫金矿业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.945402       NaN
# 2019-09-30  0.939655       NaN
# 2019-10-08  0.936781       NaN
# 2019-10-09  0.954023       NaN
# 2019-10-10  0.956896  1.029214
# 112, 上海电气
#                  net   slow_ma
# trade_date
# 2019-09-27  0.964299       NaN
# 2019-09-30  0.964299       NaN
# 2019-10-08  0.964299       NaN
# 2019-10-09  0.966220       NaN
# 2019-10-10  0.970061  0.989354
# 113, 分众传媒
#                  net  slow_ma
# trade_date
# 2019-09-27  1.053417      NaN
# 2019-09-30  1.035663      NaN
# 2019-10-08  1.023826      NaN
# 2019-10-09  1.011990      NaN
# 2019-10-10  1.015935  1.02288
# 114, 科大讯飞
#                  net   slow_ma
# trade_date
# 2019-09-27  0.989092       NaN
# 2019-09-30  0.965456       NaN
# 2019-10-08  0.939699       NaN
# 2019-10-09  0.956062       NaN
# 2019-10-10  1.029699  0.997006
# 115, 南京银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.085740       NaN
# 2019-09-30  1.083218       NaN
# 2019-10-08  1.107178       NaN
# 2019-10-09  1.100872       NaN
# 2019-10-10  1.095828  1.025173
# 116, 宝丰能源
#                  net   slow_ma
# trade_date
# 2019-09-27  0.878383       NaN
# 2019-09-30  0.867853       NaN
# 2019-10-08  0.860833       NaN
# 2019-10-09  0.884526       NaN
# 2019-10-10  0.881894  0.912402
# 117, 华域汽车
#                  net   slow_ma
# trade_date
# 2019-09-27  1.129139       NaN
# 2019-09-30  1.105155       NaN
# 2019-10-08  1.096690       NaN
# 2019-10-09  1.095749       NaN
# 2019-10-10  1.091516  1.091366
# 118, 东方证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.033733       NaN
# 2019-09-30  1.011907       NaN
# 2019-10-08  1.001987       NaN
# 2019-10-09  1.007939       NaN
# 2019-10-10  1.013892  1.023249
# 119, 中国电建
#                  net   slow_ma
# trade_date
# 2019-09-27  0.943323       NaN
# 2019-09-30  0.935244       NaN
# 2019-10-08  0.935244       NaN
# 2019-10-09  0.939284       NaN
# 2019-10-10  0.941304  0.971337
# 120, 领益智造
#                  net   slow_ma
# trade_date
# 2019-09-27  1.590914       NaN
# 2019-09-30  1.519485       NaN
# 2019-10-08  1.535719       NaN
# 2019-10-09  1.529226       NaN
# 2019-10-10  1.681825  1.272649
# 121, 长城汽车
#                  net   slow_ma
# trade_date
# 2019-09-27  0.844397       NaN
# 2019-09-30  0.837868       NaN
# 2019-10-08  0.841132       NaN
# 2019-10-09  0.832427       NaN
# 2019-10-10  0.845485  0.892437
# 122, 澜起科技
#                  net  slow_ma
# trade_date
# 2019-09-27  2.754035      NaN
# 2019-09-30  2.551211      NaN
# 2019-10-08  2.466534      NaN
# 2019-10-09  2.490323      NaN
# 2019-10-10  2.520162      NaN
# 123, 荣盛石化
#                  net   slow_ma
# trade_date
# 2019-09-27  0.917588       NaN
# 2019-09-30  0.930333       NaN
# 2019-10-08  0.925235       NaN
# 2019-10-09  0.932882       NaN
# 2019-10-10  0.943077  0.950992
# 124, 山西汾酒
#                  net   slow_ma
# trade_date
# 2019-09-27  1.116793       NaN
# 2019-09-30  1.114631       NaN
# 2019-10-08  1.114487       NaN
# 2019-10-09  1.114198       NaN
# 2019-10-10  1.134960  1.035018
# 125, 青岛啤酒
#                  net   slow_ma
# trade_date
# 2019-09-27  1.036886       NaN
# 2019-09-30  1.031569       NaN
# 2019-10-08  1.050073       NaN
# 2019-10-09  1.051349       NaN
# 2019-10-10  1.068790  1.029519
# 126, 长春高新
#                  net   slow_ma
# trade_date
# 2019-09-27  1.217141       NaN
# 2019-09-30  1.194485       NaN
# 2019-10-08  1.192940       NaN
# 2019-10-09  1.175222       NaN
# 2019-10-10  1.208570  1.061063
# 127, 包钢股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.906864       NaN
# 2019-09-30  0.906864       NaN
# 2019-10-08  0.913075       NaN
# 2019-10-09  0.919286       NaN
# 2019-10-10  0.919286  0.950863
# 128, 复星医药
#                  net   slow_ma
# trade_date
# 2019-09-27  0.934287       NaN
# 2019-09-30  0.936511       NaN
# 2019-10-08  0.940217       NaN
# 2019-10-09  0.926134       NaN
# 2019-10-10  0.945035  0.983543
# 129, 中煤能源
#                  net   slow_ma
# trade_date
# 2019-09-27  1.036685       NaN
# 2019-09-30  1.067048       NaN
# 2019-10-08  1.043191       NaN
# 2019-10-09  1.069217       NaN
# 2019-10-10  1.067048  1.020714
# 130, 紫光股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.184449       NaN
# 2019-09-30  1.165930       NaN
# 2019-10-08  1.153708       NaN
# 2019-10-09  1.167411       NaN
# 2019-10-10  1.181486  1.220355
# 131, 片仔癀
#                  net   slow_ma
# trade_date
# 2019-09-27  0.907883       NaN
# 2019-09-30  0.914706       NaN
# 2019-10-08  0.936433       NaN
# 2019-10-09  0.939755       NaN
# 2019-10-10  0.969563  0.915368
# 132, 新城控股
#                  net   slow_ma
# trade_date
# 2019-09-27  0.976124       NaN
# 2019-09-30  1.011406       NaN
# 2019-10-08  1.022811       NaN
# 2019-10-09  1.006417       NaN
# 2019-10-10  1.000715  0.936577
# 133, 中远海控
#                  net   slow_ma
# trade_date
# 2019-09-27  1.054853       NaN
# 2019-09-30  1.004221       NaN
# 2019-10-08  0.978904       NaN
# 2019-10-09  0.995781       NaN
# 2019-10-10  1.073841  1.002638
# 134, 国投电力
#                  net   slow_ma
# trade_date
# 2019-09-27  1.122469       NaN
# 2019-09-30  1.126219       NaN
# 2019-10-08  1.163718       NaN
# 2019-10-09  1.128719       NaN
# 2019-10-10  1.126219  1.116727
# 135, 恒生电子
#                  net   slow_ma
# trade_date
# 2019-09-27  1.145126       NaN
# 2019-09-30  1.128187       NaN
# 2019-10-08  1.117962       NaN
# 2019-10-09  1.130781       NaN
# 2019-10-10  1.153671  1.110318
# 136, 中国铝业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.938995       NaN
# 2019-09-30  0.933689       NaN
# 2019-10-08  0.936342       NaN
# 2019-10-09  0.941647       NaN
# 2019-10-10  0.944300  0.972547
# 137, 中海油服
#                  net   slow_ma
# trade_date
# 2019-09-27  1.302232       NaN
# 2019-09-30  1.299050       NaN
# 2019-10-08  1.313897       NaN
# 2019-10-09  1.288447       NaN
# 2019-10-10  1.346771  1.191749
# 138, 生益科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.865993       NaN
# 2019-09-30  1.679460       NaN
# 2019-10-08  1.678114       NaN
# 2019-10-09  1.725252       NaN
# 2019-10-10  1.777777  1.503028
# 139, 华侨城A
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986112       NaN
# 2019-09-30  0.976390       NaN
# 2019-10-08  0.997224       NaN
# 2019-10-09  1.018057       NaN
# 2019-10-10  1.009723  0.985603
# 140, 视源股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.158276       NaN
# 2019-09-30  1.163971       NaN
# 2019-10-08  1.152448       NaN
# 2019-10-09  1.152316       NaN
# 2019-10-10  1.201455  1.067209
# 141, 苏泊尔
#                  net   slow_ma
# trade_date
# 2019-09-27  1.005932       NaN
# 2019-09-30  0.989108       NaN
# 2019-10-08  1.001243       NaN
# 2019-10-09  1.001794       NaN
# 2019-10-10  0.998761  0.969108
# 142, 三安光电
#                  net   slow_ma
# trade_date
# 2019-09-27  1.339724       NaN
# 2019-09-30  1.284967       NaN
# 2019-10-08  1.269452       NaN
# 2019-10-09  1.282229       NaN
# 2019-10-10  1.317821  1.091944
# 143, 中国中冶
#                  net   slow_ma
# trade_date
# 2019-09-27  0.955632       NaN
# 2019-09-30  0.948831       NaN
# 2019-10-08  0.952231       NaN
# 2019-10-09  0.965835       NaN
# 2019-10-10  0.962434  0.974997
# 144, 歌尔股份
#                  net  slow_ma
# trade_date
# 2019-09-27  1.914646      NaN
# 2019-09-30  1.852475      NaN
# 2019-10-08  1.778713      NaN
# 2019-10-09  1.792411      NaN
# 2019-10-10  1.904107  1.40511
# 145, 金地集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.974148       NaN
# 2019-09-30  0.971624       NaN
# 2019-10-08  1.016209       NaN
# 2019-10-09  1.071731       NaN
# 2019-10-10  1.081825  1.013352
# 146, 白云山
#                  net   slow_ma
# trade_date
# 2019-09-27  0.850161       NaN
# 2019-09-30  0.852372       NaN
# 2019-10-08  0.860723       NaN
# 2019-10-09  0.859250       NaN
# 2019-10-10  0.870303  0.909905
# 147, 古井贡酒
#                  net   slow_ma
# trade_date
# 2019-09-27  0.956974       NaN
# 2019-09-30  0.938850       NaN
# 2019-10-08  0.941952       NaN
# 2019-10-09  0.927829       NaN
# 2019-10-10  0.932155  0.963236
# 148, 方正证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.016247       NaN
# 2019-09-30  1.003144       NaN
# 2019-10-08  0.995864       NaN
# 2019-10-09  1.000232       NaN
# 2019-10-10  1.003143  1.002626
# 149, 金风科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.017722       NaN
# 2019-09-30  1.006468       NaN
# 2019-10-08  1.053898       NaN
# 2019-10-09  1.057114       NaN
# 2019-10-10  1.075603  1.006444
# 150, 红塔证券
#                  net  slow_ma
# trade_date
# 2019-09-27  2.374058      NaN
# 2019-09-30  2.251887      NaN
# 2019-10-08  2.265461      NaN
# 2019-10-09  2.337858      NaN
# 2019-10-10  2.343892  2.27456
# 151, 陆家嘴
#                  net   slow_ma
# trade_date
# 2019-09-27  0.956848       NaN
# 2019-09-30  0.935616       NaN
# 2019-10-08  0.945205       NaN
# 2019-10-09  0.952739       NaN
# 2019-10-10  0.952739  0.980434
# 152, 同花顺
#                  net   slow_ma
# trade_date
# 2019-09-27  1.136222       NaN
# 2019-09-30  1.104924       NaN
# 2019-10-08  1.110939       NaN
# 2019-10-09  1.131768       NaN
# 2019-10-10  1.141235  1.072412
# 153, 福耀玻璃
#                  net   slow_ma
# trade_date
# 2019-09-27  0.952130       NaN
# 2019-09-30  0.943346       NaN
# 2019-10-08  0.949495       NaN
# 2019-10-09  0.938955       NaN
# 2019-10-10  0.943786  0.968951
# 154, 光大证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.035437       NaN
# 2019-09-30  1.004409       NaN
# 2019-10-08  0.999976       NaN
# 2019-10-09  1.009728       NaN
# 2019-10-10  1.026571  1.000325
# 155, 浙能电力
#                  net   slow_ma
# trade_date
# 2019-09-27  0.915888       NaN
# 2019-09-30  0.911215       NaN
# 2019-10-08  0.908879       NaN
# 2019-10-09  0.913551       NaN
# 2019-10-10  0.915888  0.958451
# 156, 兖州煤业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.047011       NaN
# 2019-09-30  1.043093       NaN
# 2019-10-08  1.046031       NaN
# 2019-10-09  1.054846       NaN
# 2019-10-10  1.054846  1.006284
# 157, 宁沪高速
#                  net   slow_ma
# trade_date
# 2019-09-27  0.979463       NaN
# 2019-09-30  0.985152       NaN
# 2019-10-08  0.984204       NaN
# 2019-10-09  0.981360       NaN
# 2019-10-10  0.995583  0.970217
# 158, 世纪华通
#                  net   slow_ma
# trade_date
# 2019-09-27  0.852662       NaN
# 2019-09-30  0.852662       NaN
# 2019-10-08  0.846008       NaN
# 2019-10-09  0.833650       NaN
# 2019-10-10  0.842205  0.901584
# 159, 国投资本
#                  net   slow_ma
# trade_date
# 2019-09-27  0.953895       NaN
# 2019-09-30  0.941802       NaN
# 2019-10-08  0.941045       NaN
# 2019-10-09  0.931219       NaN
# 2019-10-10  0.938021  0.997166
# 160, 海大集团
#                  net   slow_ma
# trade_date
# 2019-09-27  1.132773       NaN
# 2019-09-30  1.093639       NaN
# 2019-10-08  1.109711       NaN
# 2019-10-09  1.112506       NaN
# 2019-10-10  1.149543  1.084888
# 161, 上海医药
#                  net   slow_ma
# trade_date
# 2019-09-27  1.070019       NaN
# 2019-09-30  1.067087       NaN
# 2019-10-08  1.070018       NaN
# 2019-10-09  1.058292       NaN
# 2019-10-10  1.071190  1.067143
# 162, 泰格医药
#                  net   slow_ma
# trade_date
# 2019-09-27  1.176260       NaN
# 2019-09-30  1.174745       NaN
# 2019-10-08  1.187619       NaN
# 2019-10-09  1.186484       NaN
# 2019-10-10  1.305189  1.082999
# 163, 康泰生物
#                  net   slow_ma
# trade_date
# 2019-09-27  1.251274       NaN
# 2019-09-30  1.260442       NaN
# 2019-10-08  1.213923       NaN
# 2019-10-09  1.220205       NaN
# 2019-10-10  1.342276  1.153953
# 164, 华兰生物
#                  net   slow_ma
# trade_date
# 2019-09-27  1.066328       NaN
# 2019-09-30  1.083384       NaN
# 2019-10-08  1.096650       NaN
# 2019-10-09  1.074225       NaN
# 2019-10-10  1.146871  1.020509
# 165, 深南电路
#                  net   slow_ma
# trade_date
# 2019-09-27  1.524854       NaN
# 2019-09-30  1.475036       NaN
# 2019-10-08  1.369731       NaN
# 2019-10-09  1.428146       NaN
# 2019-10-10  1.465267  1.271026
# 166, 通威股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.969975       NaN
# 2019-09-30  0.956461       NaN
# 2019-10-08  0.955710       NaN
# 2019-10-09  0.981236       NaN
# 2019-10-10  0.972978  1.051079
# 167, 江西铜业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.005727       NaN
# 2019-09-30  1.003632       NaN
# 2019-10-08  1.002934       NaN
# 2019-10-09  0.999442       NaN
# 2019-10-10  1.006426  1.023739
# 168, 宁波港
#                  net  slow_ma
# trade_date
# 2019-09-27  0.894988      NaN
# 2019-09-30  0.890215      NaN
# 2019-10-08  0.885442      NaN
# 2019-10-09  0.887828      NaN
# 2019-10-10  0.902148  0.95183
# 169, 大唐发电
#                  net  slow_ma
# trade_date
# 2019-09-27  0.929160      NaN
# 2019-09-30  0.922278      NaN
# 2019-10-08  0.922278      NaN
# 2019-10-09  0.922278      NaN
# 2019-10-10  0.925719  0.95913
# 170, 航发动力
#                  net   slow_ma
# trade_date
# 2019-09-27  0.959462       NaN
# 2019-09-30  0.953358       NaN
# 2019-10-08  0.946384       NaN
# 2019-10-09  0.956846       NaN
# 2019-10-10  0.958589  1.003249
# 171, 上海临港
#                  net   slow_ma
# trade_date
# 2019-09-27  0.871479       NaN
# 2019-09-30  0.867835       NaN
# 2019-10-08  0.867835       NaN
# 2019-10-09  0.857899       NaN
# 2019-10-10  0.860880  0.975002
# 172, 青岛港
#                  net   slow_ma
# trade_date
# 2019-09-27  0.903905       NaN
# 2019-09-30  0.896674       NaN
# 2019-10-08  0.893058       NaN
# 2019-10-09  0.902700       NaN
# 2019-10-10  0.912342  0.938836
# 173, 大冶特钢
#                  net   slow_ma
# trade_date
# 2019-09-27  1.294214       NaN
# 2019-09-30  1.305623       NaN
# 2019-10-08  1.348819       NaN
# 2019-10-09  1.340669       NaN
# 2019-10-10  1.345559  1.166313
# 174, 大华股份
#                  net   slow_ma
# trade_date
# 2019-09-25  1.228531       NaN
# 2019-09-26  1.235629       NaN
# 2019-09-27  1.266857       NaN
# 2019-09-30  1.225693       NaN
# 2019-10-10  1.154720  1.153987
# 175, 白云机场
#                  net   slow_ma
# trade_date
# 2019-09-27  1.304443       NaN
# 2019-09-30  1.307355       NaN
# 2019-10-08  1.337054       NaN
# 2019-10-09  1.341131       NaN
# 2019-10-10  1.366171  1.107268
# 176, 招商公路
#                  net   slow_ma
# trade_date
# 2019-09-27  0.978150       NaN
# 2019-09-30  0.968307       NaN
# 2019-10-08  0.959693       NaN
# 2019-10-09  0.962154       NaN
# 2019-10-10  0.964615  0.990925
# 177, TCL集团
#                  net   slow_ma
# trade_date
# 2019-09-27  1.112804       NaN
# 2019-09-30  1.085365       NaN
# 2019-10-08  1.073170       NaN
# 2019-10-09  1.067072       NaN
# 2019-10-10  1.079267  1.047814
# 178, 芒果超媒
#                  net   slow_ma
# trade_date
# 2019-09-27  1.269577       NaN
# 2019-09-30  1.248568       NaN
# 2019-10-08  1.224451       NaN
# 2019-10-09  1.227234       NaN
# 2019-10-10  1.248570  1.154554
# 179, 新和成
#                  net   slow_ma
# trade_date
# 2019-09-27  1.083172       NaN
# 2019-09-30  1.079137       NaN
# 2019-10-08  1.083678       NaN
# 2019-10-09  1.119497       NaN
# 2019-10-10  1.122525  1.081937
# 180, 中国卫通
#                  net  slow_ma
# trade_date
# 2019-09-27  1.442726      NaN
# 2019-09-30  1.396186      NaN
# 2019-10-08  1.391413      NaN
# 2019-10-09  1.416472      NaN
# 2019-10-10  1.422438  1.40221
# 181, 中联重科
#                  net   slow_ma
# trade_date
# 2019-09-27  1.086012       NaN
# 2019-09-30  1.087920       NaN
# 2019-10-08  1.148996       NaN
# 2019-10-09  1.148996       NaN
# 2019-10-10  1.156631  1.090348
# 182, 美年健康
#                  net   slow_ma
# trade_date
# 2019-09-27  1.218272       NaN
# 2019-09-30  1.234515       NaN
# 2019-10-08  1.243652       NaN
# 2019-10-09  1.254820       NaN
# 2019-10-10  1.288323  1.201675
# 183, 乐普医疗
#                  net   slow_ma
# trade_date
# 2019-09-27  1.030205       NaN
# 2019-09-30  1.009263       NaN
# 2019-10-08  1.049940       NaN
# 2019-10-09  1.063633       NaN
# 2019-10-10  1.072091  1.038697
# 184, 长城证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.995420       NaN
# 2019-09-30  0.969224       NaN
# 2019-10-08  0.971189       NaN
# 2019-10-09  0.990180       NaN
# 2019-10-10  0.994765  1.008253
# 185, 正泰电器
#                  net   slow_ma
# trade_date
# 2019-09-27  0.945447       NaN
# 2019-09-30  0.937715       NaN
# 2019-10-08  0.940293       NaN
# 2019-10-09  0.934279       NaN
# 2019-10-10  0.940293  0.983005
# 186, 兆易创新
#                  net   slow_ma
# trade_date
# 2019-09-27  1.591957       NaN
# 2019-09-30  1.563565       NaN
# 2019-10-08  1.509467       NaN
# 2019-10-09  1.534311       NaN
# 2019-10-10  1.575718  1.285072
# 187, 国电电力
#                  net   slow_ma
# trade_date
# 2019-09-27  0.963857       NaN
# 2019-09-30  0.959841       NaN
# 2019-10-08  0.955825       NaN
# 2019-10-09  0.951809       NaN
# 2019-10-10  0.955824  0.994512
# 188, 闻泰科技
#                  net   slow_ma
# trade_date
# 2019-09-27  2.094976       NaN
# 2019-09-30  1.974584       NaN
# 2019-10-08  1.899445       NaN
# 2019-10-09  1.994417       NaN
# 2019-10-10  2.044417  1.446411
# 189, 欧派家居
#                  net   slow_ma
# trade_date
# 2019-09-27  1.023376       NaN
# 2019-09-30  1.021818       NaN
# 2019-10-08  1.000915       NaN
# 2019-10-09  1.009807       NaN
# 2019-10-10  1.012741  1.010933
# 190, 浙江龙盛
#                  net   slow_ma
# trade_date
# 2019-09-27  0.942382       NaN
# 2019-09-30  0.931124       NaN
# 2019-10-08  0.929800       NaN
# 2019-10-09  0.937085       NaN
# 2019-10-10  0.944370  0.971412
# 191, 华东医药
#                  net   slow_ma
# trade_date
# 2019-09-27  0.956779       NaN
# 2019-09-30  0.976153       NaN
# 2019-10-08  0.975408       NaN
# 2019-10-09  0.970564       NaN
# 2019-10-10  0.982114  1.038716
# 192, 蓝思科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.652429       NaN
# 2019-09-30  1.516936       NaN
# 2019-10-08  1.575847       NaN
# 2019-10-09  1.568483       NaN
# 2019-10-10  1.726067  1.293299
# 193, 上海石化
#                  net   slow_ma
# trade_date
# 2019-09-27  0.881096       NaN
# 2019-09-30  0.874802       NaN
# 2019-10-08  0.874802       NaN
# 2019-10-09  0.874802       NaN
# 2019-10-10  0.874802  0.934233
# 194, 天风证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.881818       NaN
# 2019-09-30  0.867676       NaN
# 2019-10-08  0.855555       NaN
# 2019-10-09  0.864646       NaN
# 2019-10-10  0.872727  0.930573
# 195, 深信服
#                  net   slow_ma
# trade_date
# 2019-09-27  1.129389       NaN
# 2019-09-30  1.145054       NaN
# 2019-10-08  1.114873       NaN
# 2019-10-09  1.117380       NaN
# 2019-10-10  1.159151  1.104214
# 196, 杭州银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.056319       NaN
# 2019-09-30  1.057571       NaN
# 2019-10-08  1.066332       NaN
# 2019-10-09  1.075093       NaN
# 2019-10-10  1.077595  1.032081
# 197, 宝信软件
#                  net   slow_ma
# trade_date
# 2019-09-27  1.247538       NaN
# 2019-09-30  1.259157       NaN
# 2019-10-08  1.204228       NaN
# 2019-10-09  1.231693       NaN
# 2019-10-10  1.354932  1.141174
# 198, 川投能源
#                  net  slow_ma
# trade_date
# 2019-09-27  1.091956      NaN
# 2019-09-30  1.112012      NaN
# 2019-10-08  1.114240      NaN
# 2019-10-09  1.113126      NaN
# 2019-10-10  1.108669   1.0607
# 199, 沪电股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.890120       NaN
# 2019-09-30  1.818851       NaN
# 2019-10-08  1.789155       NaN
# 2019-10-09  1.815881       NaN
# 2019-10-10  1.881954  1.541682
# 200, 华林证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.979179       NaN
# 2019-09-30  0.974892       NaN
# 2019-10-08  0.968155       NaN
# 2019-10-09  0.985301       NaN
# 2019-10-10  0.985914  1.038447
# 201, 中航飞机
#                  net   slow_ma
# trade_date
# 2019-09-27  0.999363       NaN
# 2019-09-30  0.988556       NaN
# 2019-10-08  0.973934       NaN
# 2019-10-09  0.981563       NaN
# 2019-10-10  0.984741  1.025152
# 202, 沃森生物
#                  net   slow_ma
# trade_date
# 2019-09-27  1.009928       NaN
# 2019-09-30  0.990118       NaN
# 2019-10-08  0.961138       NaN
# 2019-10-09  0.960770       NaN
# 2019-10-10  1.016165  1.005933
# 203, 石基信息
#                  net   slow_ma
# trade_date
# 2019-09-27  1.207061       NaN
# 2019-09-30  1.180431       NaN
# 2019-10-08  1.156793       NaN
# 2019-10-09  1.170258       NaN
# 2019-10-10  1.192400  1.076367
# 204, 石化油服
#                  net   slow_ma
# trade_date
# 2019-09-27  0.917354       NaN
# 2019-09-30  0.925618       NaN
# 2019-10-08  0.913222       NaN
# 2019-10-09  0.921486       NaN
# 2019-10-10  0.925618  0.953717
# 205, 中航资本
#                  net   slow_ma
# trade_date
# 2019-09-27  0.888045       NaN
# 2019-09-30  0.886147       NaN
# 2019-10-08  0.884250       NaN
# 2019-10-09  0.889943       NaN
# 2019-10-10  0.895636  0.929727
# 206, 中航沈飞
#                  net   slow_ma
# trade_date
# 2019-09-27  1.080479       NaN
# 2019-09-30  1.061643       NaN
# 2019-10-08  1.024656       NaN
# 2019-10-09  1.031505       NaN
# 2019-10-10  1.032190  1.076649
# 207, 中航光电
#                  net   slow_ma
# trade_date
# 2019-09-27  1.180815       NaN
# 2019-09-30  1.197093       NaN
# 2019-10-08  1.154070       NaN
# 2019-10-09  1.145058       NaN
# 2019-10-10  1.163081  1.140403
# 208, 兴业证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986417       NaN
# 2019-09-30  0.961680       NaN
# 2019-10-08  0.952404       NaN
# 2019-10-09  0.961680       NaN
# 2019-10-10  0.966318  0.981508
# 209, 华新水泥
#                  net   slow_ma
# trade_date
# 2019-09-27  0.971457       NaN
# 2019-09-30  0.960753       NaN
# 2019-10-08  1.018348       NaN
# 2019-10-09  1.019367       NaN
# 2019-10-10  1.014270  0.992803
# 210, 今世缘
#                  net   slow_ma
# trade_date
# 2019-09-27  1.110250       NaN
# 2019-09-30  1.086384       NaN
# 2019-10-08  1.119325       NaN
# 2019-10-09  1.099493       NaN
# 2019-10-10  1.100838  0.987176
# 211, 晨光文具
#                  net  slow_ma
# trade_date
# 2019-09-27  1.042016      NaN
# 2019-09-30  1.069867      NaN
# 2019-10-08  1.039615      NaN
# 2019-10-09  1.029771      NaN
# 2019-10-10  1.072028  0.98575
# 212, 上海莱士
#                  net   slow_ma
# trade_date
# ...
# 2019-09-30  1.006021       NaN
# 2019-10-08  1.012045       NaN
# 2019-10-09  1.037003       NaN
# 2019-10-10  1.028396  0.992181
# 935, 新华网
#                  net  slow_ma
# trade_date
# 2019-09-27  1.069879      NaN
# 2019-09-30  1.043210      NaN
# 2019-10-08  1.036412      NaN
# 2019-10-09  1.038504      NaN
# 2019-10-10  1.047916  1.03584
# 936, 中科三环
#                  net   slow_ma
# trade_date
# 2019-09-27  0.932684       NaN
# 2019-09-30  0.923904       NaN
# 2019-10-08  0.944392       NaN
# 2019-10-09  0.954148       NaN
# 2019-10-10  0.951222  0.988764
# 937, 安车检测
#                  net  slow_ma
# trade_date
# 2019-09-27  1.090267      NaN
# 2019-09-30  1.085691      NaN
# 2019-10-08  1.042430      NaN
# 2019-10-09  1.058653      NaN
# 2019-10-10  1.111898  1.03861
# 938, 红日药业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.036807       NaN
# 2019-09-30  1.024537       NaN
# 2019-10-08  1.021470       NaN
# 2019-10-09  1.027605       NaN
# 2019-10-10  1.055212  1.029446
# 939, 安洁科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.138599       NaN
# 2019-09-30  1.061848       NaN
# 2019-10-08  1.067810       NaN
# 2019-10-09  1.084948       NaN
# 2019-10-10  1.116244  1.053452
# 940, 宝钛股份
#                  net  slow_ma
# trade_date
# 2019-09-27  1.180485      NaN
# 2019-09-30  1.160623      NaN
# 2019-10-08  1.062178      NaN
# 2019-10-09  1.037135      NaN
# 2019-10-10  1.034113  1.04931
# 941, 航天彩虹
#                  net   slow_ma
# trade_date
# 2019-09-27  1.010978       NaN
# 2019-09-30  0.991764       NaN
# 2019-10-08  0.985359       NaN
# 2019-10-09  0.987189       NaN
# 2019-10-10  0.996339  1.005292
# 942, 岷江水电
#                  net   slow_ma
# trade_date
# 2019-09-27  1.380540       NaN
# 2019-09-30  1.344955       NaN
# 2019-10-08  1.456792       NaN
# 2019-10-09  1.478578       NaN
# 2019-10-10  1.481484  1.208885
# 943, 汉缆股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.975524       NaN
# 2019-09-30  0.972028       NaN
# 2019-10-08  0.975525       NaN
# 2019-10-09  0.982517       NaN
# 2019-10-10  1.080419  0.994347
# 944, 我爱我家
#                  net   slow_ma
# trade_date
# 2019-09-27  0.910790       NaN
# 2019-09-30  0.902491       NaN
# 2019-10-08  0.904566       NaN
# 2019-10-09  0.906641       NaN
# 2019-10-10  0.904566  0.958161
# 945, 上海环境
#                  net   slow_ma
# trade_date
# 2019-09-27  0.885202       NaN
# 2019-09-30  0.896519       NaN
# 2019-10-08  0.893286       NaN
# 2019-10-09  0.899753       NaN
# 2019-10-10  0.907837  0.948326
# 946, 春兴精工
#                  net   slow_ma
# trade_date
# 2019-09-27  0.904624       NaN
# 2019-09-30  0.878519       NaN
# 2019-10-08  0.882534       NaN
# 2019-10-09  0.903619       NaN
# 2019-10-10  0.912655  0.946957
# 947, 北京君正
#                  net   slow_ma
# trade_date
# 2019-09-27  1.797408       NaN
# 2019-09-30  1.731513       NaN
# 2019-10-08  1.721349       NaN
# 2019-10-09  1.752545       NaN
# 2019-10-10  1.784792  1.539585
# 948, 宏大爆破
#                  net   slow_ma
# trade_date
# 2019-09-27  1.187501       NaN
# 2019-09-30  1.148335       NaN
# 2019-10-08  1.156668       NaN
# 2019-10-09  1.158335       NaN
# 2019-10-10  1.203335  1.126473
# 949, 皖能电力
#                  net   slow_ma
# trade_date
# 2019-09-27  0.995517       NaN
# 2019-09-30  0.977579       NaN
# 2019-10-08  1.004485       NaN
# 2019-10-09  0.997759       NaN
# 2019-10-10  1.008970  1.043834
# 950, 红旗连锁
#                  net  slow_ma
# trade_date
# 2019-09-27  1.210436      NaN
# 2019-09-30  1.215330      NaN
# 2019-10-08  1.212067      NaN
# 2019-10-09  1.208804      NaN
# 2019-10-10  1.223486  1.12376
# 951, 鲁信创投
#                  net   slow_ma
# trade_date
# 2019-09-27  0.771997       NaN
# 2019-09-30  0.770824       NaN
# 2019-10-08  0.764958       NaN
# 2019-10-09  0.777277       NaN
# 2019-10-10  0.803675  0.844673
# 952, 旗滨集团
#                  net  slow_ma
# trade_date
# 2019-09-27  0.975480      NaN
# 2019-09-30  0.980930      NaN
# 2019-10-08  1.008178      NaN
# 2019-10-09  1.016352      NaN
# 2019-10-10  1.032701  0.97348
# 953, 东诚药业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.025684       NaN
# 2019-09-30  1.039383       NaN
# 2019-10-08  1.042808       NaN
# 2019-10-09  1.051369       NaN
# 2019-10-10  1.086473  1.070591
# 954, 创业环保
#                  net  slow_ma
# trade_date
# 2019-09-27  0.864075      NaN
# 2019-09-30  0.850726      NaN
# 2019-10-08  0.849512      NaN
# 2019-10-09  0.858007      NaN
# 2019-10-10  0.865289  0.91173
# 955, 兴业矿业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.075246       NaN
# 2019-09-30  1.061385       NaN
# 2019-10-08  1.059405       NaN
# 2019-10-09  1.083167       NaN
# 2019-10-10  1.093068  1.080527
# 956, 电连技术
#                  net   slow_ma
# trade_date
# 2019-09-27  1.347818       NaN
# 2019-09-30  1.292805       NaN
# 2019-10-08  1.222954       NaN
# 2019-10-09  1.238879       NaN
# 2019-10-10  1.306559  1.321707
# 957, 许继电气
#                  net   slow_ma
# trade_date
# 2019-09-27  0.954036       NaN
# 2019-09-30  0.948431       NaN
# 2019-10-08  0.985426       NaN
# 2019-10-09  1.084081       NaN
# 2019-10-10  1.126682  0.962071
# 958, 百川能源
#                  net  slow_ma
# trade_date
# 2019-09-27  0.980388      NaN
# 2019-09-30  0.983189      NaN
# 2019-10-08  0.981788      NaN
# 2019-10-09  0.977586      NaN
# 2019-10-10  0.983189  1.00553
# 959, 深康佳A
#                  net   slow_ma
# trade_date
# 2019-09-27  1.049756       NaN
# 2019-09-30  1.044781       NaN
# 2019-10-08  1.049757       NaN
# 2019-10-09  1.042294       NaN
# 2019-10-10  1.044782  1.052531
# 960, 张家港行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.992725       NaN
# 2019-09-30  0.972725       NaN
# 2019-10-08  0.985452       NaN
# 2019-10-09  1.019997       NaN
# 2019-10-10  1.016361  1.000968
# 961, 天康生物
#                  net  slow_ma
# trade_date
# 2019-09-27  1.030516      NaN
# 2019-09-30  1.046948      NaN
# 2019-10-08  1.080985      NaN
# 2019-10-09  1.110327      NaN
# 2019-10-10  1.171360  1.15446
# 962, 岱美股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.076253       NaN
# 2019-09-30  1.107189       NaN
# 2019-10-08  1.122876       NaN
# 2019-10-09  1.093682       NaN
# 2019-10-10  1.098475  1.024699
# 963, 艾迪精密
#                  net   slow_ma
# trade_date
# 2019-09-27  1.002715       NaN
# 2019-09-30  0.998054       NaN
# 2019-10-08  0.978249       NaN
# 2019-10-09  1.015918       NaN
# 2019-10-10  1.016306  0.986315
# 964, 火炬电子
#                  net  slow_ma
# trade_date
# 2019-09-27  1.045151      NaN
# 2019-09-30  1.034803      NaN
# 2019-10-08  1.040917      NaN
# 2019-10-09  1.044680      NaN
# 2019-10-10  1.047973  1.11835
# 965, 双塔食品
#                  net  slow_ma
# trade_date
# 2019-09-27  1.160360      NaN
# 2019-09-30  1.208772      NaN
# 2019-10-08  1.232977      NaN
# 2019-10-09  1.226926      NaN
# 2019-10-10  1.226926  1.16548
# 966, 中恒集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986300       NaN
# 2019-09-30  0.982876       NaN
# 2019-10-08  0.986300       NaN
# 2019-10-09  0.993149       NaN
# 2019-10-10  0.993149  1.004736
# 967, 盛达矿业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.364287       NaN
# 2019-09-30  1.408165       NaN
# 2019-10-08  1.396940       NaN
# 2019-10-09  1.507145       NaN
# 2019-10-10  1.489798  1.429561
# 968, 泛微网络
#                  net   slow_ma
# trade_date
# 2019-09-27  0.947312       NaN
# 2019-09-30  0.947610       NaN
# 2019-10-08  0.947013       NaN
# 2019-10-09  0.965819       NaN
# 2019-10-10  0.990893  1.004249
# 969, 珍宝岛
#                  net   slow_ma
# trade_date
# 2019-09-27  0.943156       NaN
# 2019-09-30  0.936751       NaN
# 2019-10-08  0.937552       NaN
# 2019-10-09  0.943157       NaN
# 2019-10-10  0.949562  0.962771
# 970, 蓝焰控股
#                  net   slow_ma
# trade_date
# 2019-09-27  0.934329       NaN
# 2019-09-30  0.922946       NaN
# 2019-10-08  0.911562       NaN
# 2019-10-09  0.916816       NaN
# 2019-10-10  0.910686  0.923411
# 971, 九洲药业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.408028       NaN
# 2019-09-30  1.387960       NaN
# 2019-10-08  1.391305       NaN
# 2019-10-09  1.395765       NaN
# 2019-10-10  1.390190  1.189538
# 972, 开山股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.021293       NaN
# 2019-09-30  1.013886       NaN
# 2019-10-08  1.049071       NaN
# 2019-10-09  1.092589       NaN
# 2019-10-10  1.083330  0.934906
# 973, 广晟有色
#                  net   slow_ma
# trade_date
# 2019-09-27  0.896928       NaN
# 2019-09-30  0.899163       NaN
# 2019-10-08  0.914805       NaN
# 2019-10-09  0.930169       NaN
# 2019-10-10  0.925978  0.975867
# 974, 商赢环球
#                  net  slow_ma
# trade_date
# 2019-09-27  1.190510      NaN
# 2019-09-30  1.309492      NaN
# 2019-10-08  1.440167      NaN
# 2019-10-09  1.475242      NaN
# 2019-10-10  1.460799  1.16246
# 975, 中国重汽
#                  net   slow_ma
# trade_date
# 2019-09-27  0.907798       NaN
# 2019-09-30  0.906560       NaN
# 2019-10-08  0.904085       NaN
# 2019-10-09  0.919556       NaN
# 2019-10-10  0.920175  0.951393
# 976, 艾德生物
#                  net   slow_ma
# trade_date
# 2019-09-27  1.256443       NaN
# 2019-09-30  1.264138       NaN
# 2019-10-08  1.236628       NaN
# 2019-10-09  1.242208       NaN
# 2019-10-10  1.303193  1.035447
# 977, 河北宣工
#                  net   slow_ma
# trade_date
# 2019-09-27  0.817935       NaN
# 2019-09-30  0.802717       NaN
# 2019-10-08  0.816304       NaN
# 2019-10-09  0.817391       NaN
# 2019-10-10  0.829348  0.844384
# 978, 平高电气
#                  net   slow_ma
# trade_date
# 2019-09-27  0.922555       NaN
# 2019-09-30  0.915994       NaN
# 2019-10-08  0.922555       NaN
# 2019-10-09  0.961925       NaN
# 2019-10-10  0.963237  0.967951
# 979, 国际医学
#                  net   slow_ma
# trade_date
# 2019-09-27  0.938104       NaN
# 2019-09-30  0.967117       NaN
# 2019-10-08  0.959381       NaN
# 2019-10-09  0.959381       NaN
# 2019-10-10  0.976788  0.963958
# 980, 无锡银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.967451       NaN
# 2019-09-30  0.947560       NaN
# 2019-10-08  0.952984       NaN
# 2019-10-09  0.976493       NaN
# 2019-10-10  0.972876  0.980712
# 981, 法拉电子
#                  net   slow_ma
# trade_date
# 2019-09-27  1.025031       NaN
# 2019-09-30  1.048423       NaN
# 2019-10-08  1.003511       NaN
# 2019-10-09  1.025499       NaN
# 2019-10-10  1.033452  0.968497
# 982, 江淮汽车
#                  net   slow_ma
# trade_date
# 2019-09-27  1.050099       NaN
# 2019-09-30  1.017343       NaN
# 2019-10-08  1.001928       NaN
# 2019-10-09  1.017343       NaN
# 2019-10-10  1.011562  0.985196
# 983, 珠江钢琴
#                  net   slow_ma
# trade_date
# 2019-09-27  1.019552       NaN
# 2019-09-30  1.018155       NaN
# 2019-10-08  1.027932       NaN
# 2019-10-09  1.029329       NaN
# 2019-10-10  1.019552  1.009752
# 984, 金正大
#                  net   slow_ma
# trade_date
# 2019-09-27  0.877910       NaN
# 2019-09-30  0.875003       NaN
# 2019-10-08  0.860468       NaN
# 2019-10-09  0.869189       NaN
# 2019-10-10  0.875003  0.934207
# 985, 华邦健康
#                  net   slow_ma
# trade_date
# 2019-09-27  1.047616       NaN
# 2019-09-30  1.045452       NaN
# 2019-10-08  1.051945       NaN
# 2019-10-09  1.069261       NaN
# 2019-10-10  1.080083  1.026477
# 986, 北信源
#                  net  slow_ma
# trade_date
# 2019-09-27  1.014377      NaN
# 2019-09-30  0.998403      NaN
# 2019-10-08  0.982428      NaN
# 2019-10-09  1.017572      NaN
# 2019-10-10  1.087859  0.94984
# 987, 思创医惠
#                  net   slow_ma
# trade_date
# 2019-09-27  1.190381       NaN
# 2019-09-30  1.180360       NaN
# 2019-10-08  1.177354       NaN
# 2019-10-09  1.171342       NaN
# 2019-10-10  1.224448  1.111523
# 988, 创力集团
#                  net   slow_ma
# trade_date
# 2019-09-27  1.353648       NaN
# 2019-09-30  1.387813       NaN
# 2019-10-08  1.387813       NaN
# 2019-10-09  1.395201       NaN
# 2019-10-10  1.427518  1.091521
# 989, 华东科技
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986366       NaN
# 2019-09-30  0.981821       NaN
# 2019-10-08  0.977275       NaN
# 2019-10-09  0.977275       NaN
# 2019-10-10  0.986366  0.997426
# 990, 天健集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.986767       NaN
# 2019-09-30  0.973534       NaN
# 2019-10-08  0.982986       NaN
# 2019-10-09  0.996219       NaN
# 2019-10-10  0.994328  1.035223
# 991, 大康农业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.920633       NaN
# 2019-09-30  0.936506       NaN
# 2019-10-08  0.947087       NaN
# 2019-10-09  0.936505       NaN
# 2019-10-10  0.947087  0.979099
# 992, 亚泰集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.943220       NaN
# 2019-09-30  0.936911       NaN
# 2019-10-08  0.946375       NaN
# 2019-10-09  0.949529       NaN
# 2019-10-10  0.952683  0.975764
# 993, 长城军工
#                  net   slow_ma
# trade_date
# 2019-09-27  0.918241       NaN
# 2019-09-30  0.912835       NaN
# 2019-10-08  0.900673       NaN
# 2019-10-09  0.906755       NaN
# 2019-10-10  0.914863  0.977577
# 994, 置信电气
#                  net   slow_ma
# trade_date
# 2019-09-27  1.132292       NaN
# 2019-09-30  1.059746       NaN
# 2019-10-08  1.009959       NaN
# 2019-10-09  1.041254       NaN
# 2019-10-10  1.028451  0.994003
# 995, 三星医疗
#                  net   slow_ma
# trade_date
# 2019-09-27  1.185443       NaN
# 2019-09-30  1.228771       NaN
# 2019-10-08  1.235704       NaN
# 2019-10-09  1.211441       NaN
# 2019-10-10  1.225306  1.067071
# 996, 鹏博士
#                  net   slow_ma
# trade_date
# 2019-09-27  0.947739       NaN
# 2019-09-30  0.940677       NaN
# 2019-10-08  0.943501       NaN
# 2019-10-09  0.942089       NaN
# 2019-10-10  0.966100  0.993785
# 997, 哈药股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.972149       NaN
# 2019-09-30  0.967086       NaN
# 2019-10-08  0.969618       NaN
# 2019-10-09  0.977213       NaN
# 2019-10-10  0.982276  0.998521
# 998, 心脉医疗
#                  net  slow_ma
# trade_date
# 2019-09-27  2.961288      NaN
# 2019-09-30  2.818092      NaN
# 2019-10-08  2.787809      NaN
# 2019-10-09  2.821984      NaN
# 2019-10-10  2.939224      NaN
# 999, 特发信息
#                  net   slow_ma
# trade_date
# 2019-09-27  1.113244       NaN
# 2019-09-30  1.102285       NaN
# 2019-10-08  1.068495       NaN
# 2019-10-09  1.088585       NaN
# 2019-10-10  1.097718  1.065084
# 2019-10-10 21:19:55.211215
# 符合条件的stock num: 129
# ['工商银行',
#  '建设银行',
#  '农业银行',
#  '中国银行',
#  '招商银行',
#  '中国石化',
#  '交通银行',
#  '中国人保',
#  '中国神华',
#  '美的集团',
#  '海康威视',
#  '国泰君安',
#  '万华化学',
#  '中国铁建',
#  '北京银行',
#  '招商证券',
#  '广发证券',
#  '海尔智家',
#  '华夏幸福',
#  '华能水电',
#  '江苏银行',
#  '韵达股份',
#  '分众传媒',
#  '华域汽车',
#  '东方证券',
#  '荣盛石化',
#  '国投电力',
#  '方正证券',
#  '上海医药',
#  '大华股份',
#  '欧派家居',
#  '广联达',
#  '美凯龙',
#  '长安汽车',
#  '巨人网络',
#  '中集集团',
#  '圆通速递',
#  '五矿资本',
#  '招商港口',
#  '北新建材',
#  '宇通客车',
#  '长沙银行',
#  '亨通光电',
#  '深天马A',
#  '浙商证券',
#  '合盛硅业',
#  '申能股份',
#  '南京证券',
#  '湖北能源',
#  '青岛银行',
#  '大连港',
#  '华西证券',
#  '南山铝业',
#  '传化智联',
#  '建发股份',
#  '桐昆股份',
#  '深圳能源',
#  '中铁工业',
#  '太钢不锈',
#  '中南传媒',
#  '第一创业',
#  '步长制药',
#  '广深铁路',
#  '中油工程',
#  '粤电力A',
#  '张裕A',
#  '首创股份',
#  '华宝股份',
#  '格林美',
#  '诚志股份',
#  '国药一致',
#  '南洋股份',
#  '秦港股份',
#  '首钢股份',
#  '中文传媒',
#  '营口港',
#  '首旅酒店',
#  '索菲亚',
#  '粤高速A',
#  '九阳股份',
#  '露天煤业',
#  '百联股份',
#  '太极实业',
#  '万丰奥威',
#  '嘉化能源',
#  '唐山港',
#  '山东出版',
#  '新钢股份',
#  '山鹰纸业',
#  '晨鸣纸业',
#  '供销大集',
#  '天地科技',
#  '梅花生物',
#  '瀚蓝环境',
#  '东华能源',
#  '以岭药业',
#  '广州酒家',
#  '兆驰股份',
#  '天津港',
#  '宇信科技',
#  '太极股份',
#  '滨江集团',
#  '润和软件',
#  '嘉凯城',
#  '中国宝安',
#  '酒钢宏兴',
#  '上海钢联',
#  '新乳业',
#  '跨境通',
#  '四川成渝',
#  '重庆百货',
#  '横店东磁',
#  '南京高科',
#  '彤程新材',
#  '金禾实业',
#  '奇正藏药',
#  '上海贝岭',
#  '数知科技',
#  '鄂尔多斯',
#  '中新药业',
#  '罗牛山',
#  '中材国际',
#  '民和股份',
#  '南京熊猫',
#  '航天彩虹',
#  '深康佳A',
#  '平高电气',
#  '无锡银行',
#  '珠江钢琴']

# %%
targets = ['工商银行',
 '建设银行',
 '农业银行',
 '中国银行',
 '招商银行',
 '中国石化',
 '交通银行',
 '中国人保',
 '中国神华',
 '美的集团',
 '海康威视',
 '国泰君安',
 '万华化学',
 '中国铁建',
 '北京银行',
 '招商证券',
 '广发证券',
 '海尔智家',
 '华夏幸福',
 '华能水电',
 '江苏银行',
 '韵达股份',
 '分众传媒',
 '华域汽车',
 '东方证券',
 '荣盛石化',
 '国投电力',
 '方正证券',
 '上海医药',
 '大华股份',
 '欧派家居',
 '广联达',
 '美凯龙',
 '长安汽车',
 '巨人网络',
 '中集集团',
 '圆通速递',
 '五矿资本',
 '招商港口',
 '北新建材',
 '宇通客车',
 '长沙银行',
 '亨通光电',
 '深天马A',
 '浙商证券',
 '合盛硅业',
 '申能股份',
 '南京证券',
 '湖北能源',
 '青岛银行',
 '大连港',
 '华西证券',
 '南山铝业',
 '传化智联',
 '建发股份',
 '桐昆股份',
 '深圳能源',
 '中铁工业',
 '太钢不锈',
 '中南传媒',
 '第一创业',
 '步长制药',
 '广深铁路',
 '中油工程',
 '粤电力A',
 '张裕A',
 '首创股份',
 '华宝股份',
 '格林美',
 '诚志股份',
 '国药一致',
 '南洋股份',
 '秦港股份',
 '首钢股份',
 '中文传媒',
 '营口港',
 '首旅酒店',
 '索菲亚',
 '粤高速A',
 '九阳股份',
 '露天煤业',
 '百联股份',
 '太极实业',
 '万丰奥威',
 '嘉化能源',
 '唐山港',
 '山东出版',
 '新钢股份',
 '山鹰纸业',
 '晨鸣纸业',
 '供销大集',
 '天地科技',
 '梅花生物',
 '瀚蓝环境',
 '东华能源',
 '以岭药业',
 '广州酒家',
 '兆驰股份',
 '天津港',
 '宇信科技',
 '太极股份',
 '滨江集团',
 '润和软件',
 '嘉凯城',
 '中国宝安',
 '酒钢宏兴',
 '上海钢联',
 '新乳业',
 '跨境通',
 '四川成渝',
 '重庆百货',
 '横店东磁',
 '南京高科',
 '彤程新材',
 '金禾实业',
 '奇正藏药',
 '上海贝岭',
 '数知科技',
 '鄂尔多斯',
 '中新药业',
 '罗牛山',
 '中材国际',
 '民和股份',
 '南京熊猫',
 '航天彩虹',
 '深康佳A',
 '平高电气',
 '无锡银行',
 '珠江钢琴']

# %%
SMA.stocks_select(targets)
# Out:
# 2019-10-10 22:00:13.650004
# 股票池容量：129
# 0, 工商银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.998199       NaN
# 2019-09-30  0.996397       NaN
# 2019-10-08  1.001803       NaN
# 2019-10-09  1.005406       NaN
# 2019-10-10  1.003604  0.995076
# 1, 建设银行
#                  net   slow_ma
# trade_date
# 2019-09-27  1.011445       NaN
# 2019-09-30  1.000000       NaN
# 2019-10-08  1.012876       NaN
# 2019-10-09  1.021461       NaN
# 2019-10-10  1.021461  1.016524
# 2, 农业银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.972144       NaN
# 2019-09-30  0.963787       NaN
# 2019-10-08  0.969358       NaN
# 2019-10-09  0.972144       NaN
# 2019-10-10  0.972144  0.972887
# 3, 中国银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.972973       NaN
# 2019-09-30  0.967568       NaN
# 2019-10-08  0.972973       NaN
# 2019-10-09  0.978379       NaN
# 2019-10-10  0.972974  0.976531
# 4, 招商银行
#                  net  slow_ma
# trade_date
# 2019-09-27  1.029227      NaN
# 2019-09-30  1.016070      NaN
# 2019-10-08  1.017825      NaN
# 2019-10-09  1.028643      NaN
# 2019-10-10  1.026596  1.03104
# 5, 中国石化
#                  net   slow_ma
# trade_date
# 2019-09-27  0.981634       NaN
# 2019-09-30  0.987535       NaN
# 2019-10-08  0.983601       NaN
# 2019-10-09  0.985568       NaN
# 2019-10-10  0.983601  0.986612
# 6, 交通银行
#                  net  slow_ma
# trade_date
# 2019-09-27  0.956446      NaN
# 2019-09-30  0.949478      NaN
# 2019-10-08  0.956446      NaN
# 2019-10-09  0.965156      NaN
# 2019-10-10  0.963414  0.97259
# 7, 中国人保
#                  net   slow_ma
# trade_date
# 2019-09-27  0.976616       NaN
# 2019-09-30  0.966501       NaN
# 2019-10-08  0.973244       NaN
# 2019-10-09  0.975492       NaN
# 2019-10-10  0.979987  0.986339
# 8, 中国神华
#                  net   slow_ma
# trade_date
# 2019-09-27  0.980075       NaN
# 2019-09-30  0.984794       NaN
# 2019-10-08  0.977978       NaN
# 2019-10-09  0.991088       NaN
# 2019-10-10  0.986368  0.995178
# 9, 美的集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.952130       NaN
# 2019-09-30  0.948048       NaN
# 2019-10-08  0.976806       NaN
# 2019-10-09  0.974023       NaN
# 2019-10-10  0.968086  0.976229
# 10, 海康威视
#                  net   slow_ma
# trade_date
# 2019-09-25  1.211874       NaN
# 2019-09-26  1.217006       NaN
# 2019-09-27  1.216640       NaN
# 2019-09-30  1.184016       NaN
# 2019-10-10  1.132696  1.129281
# 11, 国泰君安
#                  net   slow_ma
# trade_date
# 2019-09-27  1.018787       NaN
# 2019-09-30  0.990597       NaN
# 2019-10-08  0.981576       NaN
# 2019-10-09  0.979885       NaN
# 2019-10-10  0.986650  0.994903
# 12, 万华化学
#                  net   slow_ma
# trade_date
# 2019-09-27  1.065879       NaN
# 2019-09-30  1.065396       NaN
# 2019-10-08  1.072636       NaN
# 2019-10-09  1.051882       NaN
# 2019-10-10  1.067568  1.058113
# 13, 中国铁建
#                  net   slow_ma
# trade_date
# 2019-09-27  1.013578       NaN
# 2019-09-30  1.002976       NaN
# 2019-10-08  1.021000       NaN
# 2019-10-09  1.022060       NaN
# 2019-10-10  1.023120  1.013358
# 14, 北京银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.964220       NaN
# 2019-09-30  0.958853       NaN
# 2019-10-08  0.964219       NaN
# 2019-10-09  0.974953       NaN
# 2019-10-10  0.978531  0.970481
# 15, 招商证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.029431       NaN
# 2019-09-30  0.999654       NaN
# 2019-10-08  0.992969       NaN
# 2019-10-09  0.994184       NaN
# 2019-10-10  1.013023  1.003965
# 16, 广发证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.002179       NaN
# 2019-09-30  0.984762       NaN
# 2019-10-08  0.980407       NaN
# 2019-10-09  0.982585       NaN
# 2019-10-10  0.991293  0.985413
# 17, 海尔智家
#                  net   slow_ma
# trade_date
# 2019-09-27  0.908562       NaN
# 2019-09-30  0.904425       NaN
# 2019-10-08  0.919203       NaN
# 2019-10-09  0.921567       NaN
# 2019-10-10  0.929843  0.933319
# 18, 华夏幸福
#                  net   slow_ma
# trade_date
# 2019-09-27  0.898701       NaN
# 2019-09-30  0.887837       NaN
# 2019-10-08  0.912198       NaN
# 2019-10-09  0.920428       NaN
# 2019-10-10  0.918452  0.923483
# 19, 华能水电
#                  net   slow_ma
# trade_date
# 2019-09-27  1.014321       NaN
# 2019-09-30  1.011935       NaN
# 2019-10-08  1.019094       NaN
# 2019-10-09  1.050120       NaN
# 2019-10-10  1.076373  1.086915
# 20, 江苏银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.989725       NaN
# 2019-09-30  0.978064       NaN
# 2019-10-08  0.985353       NaN
# 2019-10-09  0.997014       NaN
# 2019-10-10  0.998471  0.991864
# 21, 韵达股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.044486       NaN
# 2019-09-30  1.077694       NaN
# 2019-10-08  1.042606       NaN
# 2019-10-09  1.074875       NaN
# 2019-10-10  1.098685  1.096705
# 22, 分众传媒
#                  net  slow_ma
# trade_date
# 2019-09-27  1.053417      NaN
# 2019-09-30  1.035663      NaN
# 2019-10-08  1.023826      NaN
# 2019-10-09  1.011990      NaN
# 2019-10-10  1.015935  1.02288
# 23, 华域汽车
#                  net   slow_ma
# trade_date
# 2019-09-27  1.129139       NaN
# 2019-09-30  1.105155       NaN
# 2019-10-08  1.096690       NaN
# 2019-10-09  1.095749       NaN
# 2019-10-10  1.091516  1.091366
# 24, 东方证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.033733       NaN
# 2019-09-30  1.011907       NaN
# 2019-10-08  1.001987       NaN
# 2019-10-09  1.007939       NaN
# 2019-10-10  1.013892  1.023249
# 25, 荣盛石化
#                  net   slow_ma
# trade_date
# 2019-09-27  0.917588       NaN
# 2019-09-30  0.930333       NaN
# 2019-10-08  0.925235       NaN
# 2019-10-09  0.932882       NaN
# 2019-10-10  0.943077  0.950992
# 26, 国投电力
#                  net   slow_ma
# trade_date
# 2019-09-27  1.122469       NaN
# 2019-09-30  1.126219       NaN
# 2019-10-08  1.163718       NaN
# 2019-10-09  1.128719       NaN
# 2019-10-10  1.126219  1.116727
# 27, 方正证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.016247       NaN
# 2019-09-30  1.003144       NaN
# 2019-10-08  0.995864       NaN
# 2019-10-09  1.000232       NaN
# 2019-10-10  1.003143  1.002626
# 28, 上海医药
#                  net   slow_ma
# trade_date
# 2019-09-27  1.070019       NaN
# 2019-09-30  1.067087       NaN
# 2019-10-08  1.070018       NaN
# 2019-10-09  1.058292       NaN
# 2019-10-10  1.071190  1.067143
# 29, 大华股份
#                  net   slow_ma
# trade_date
# 2019-09-25  1.228531       NaN
# 2019-09-26  1.235629       NaN
# 2019-09-27  1.266857       NaN
# 2019-09-30  1.225693       NaN
# 2019-10-10  1.154720  1.153987
# 30, 欧派家居
#                  net   slow_ma
# trade_date
# 2019-09-27  1.023376       NaN
# 2019-09-30  1.021818       NaN
# 2019-10-08  1.000915       NaN
# 2019-10-09  1.009807       NaN
# 2019-10-10  1.012741  1.010933
# 31, 广联达
#                  net  slow_ma
# trade_date
# 2019-09-27  1.081946      NaN
# 2019-09-30  1.073176      NaN
# 2019-10-08  1.053824      NaN
# 2019-10-09  1.061686      NaN
# 2019-10-10  1.075898  1.06588
# 32, 美凯龙
#                  net   slow_ma
# trade_date
# 2019-09-27  1.009700       NaN
# 2019-09-30  1.000881       NaN
# 2019-10-08  0.985890       NaN
# 2019-10-09  0.983245       NaN
# 2019-10-10  0.987654  0.979351
# 33, 长安汽车
#                  net  slow_ma
# trade_date
# 2019-09-27  1.084752      NaN
# 2019-09-30  1.087688      NaN
# 2019-10-08  1.103834      NaN
# 2019-10-09  1.130256      NaN
# 2019-10-10  1.147870  1.15525
# 34, 巨人网络
#                  net   slow_ma
# trade_date
# 2019-09-27  1.071251       NaN
# 2019-09-30  1.060589       NaN
# 2019-10-08  1.040948       NaN
# 2019-10-09  1.016818       NaN
# 2019-10-10  1.021307  1.016967
# 35, 中集集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.896427       NaN
# 2019-09-30  0.933090       NaN
# 2019-10-08  0.927591       NaN
# 2019-10-09  0.916591       NaN
# 2019-10-10  0.919341  0.920211
# 36, 圆通速递
#                  net   slow_ma
# trade_date
# 2019-09-27  0.956371       NaN
# 2019-09-30  0.965599       NaN
# 2019-10-08  0.976506       NaN
# 2019-10-09  0.998318       NaN
# 2019-10-10  0.987412  0.990643
# 37, 五矿资本
#                  net   slow_ma
# trade_date
# 2019-09-27  1.004118       NaN
# 2019-09-30  0.967970       NaN
# 2019-10-08  0.981358       NaN
# 2019-10-09  0.982697       NaN
# 2019-10-10  0.984035  0.987109
# 38, 招商港口
#                  net   slow_ma
# trade_date
# 2019-09-27  1.045809       NaN
# 2019-09-30  1.044001       NaN
# 2019-10-08  1.050029       NaN
# 2019-10-09  1.048221       NaN
# 2019-10-10  1.062085  1.065813
# 39, 北新建材
#                  net   slow_ma
# trade_date
# 2019-09-27  0.990599       NaN
# 2019-09-30  0.995577       NaN
# 2019-10-08  0.994471       NaN
# 2019-10-09  0.996683       NaN
# 2019-10-10  0.996130  0.995623
# 40, 宇通客车
#                  net  slow_ma
# trade_date
# 2019-09-27  1.039525      NaN
# 2019-09-30  1.036543      NaN
# 2019-10-08  1.021629      NaN
# 2019-10-09  1.031323      NaN
# 2019-10-10  1.024611   1.0262
# 41, 长沙银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.967887       NaN
# 2019-09-30  0.953490       NaN
# 2019-10-08  0.959027       NaN
# 2019-10-09  0.973424       NaN
# 2019-10-10  0.974532  0.975343
# 42, 亨通光电
#                  net   slow_ma
# trade_date
# 2019-09-27  0.963758       NaN
# 2019-09-30  0.955772       NaN
# 2019-10-08  0.947787       NaN
# 2019-10-09  0.950244       NaN
# 2019-10-10  0.961915  0.954893
# 43, 深天马A
#                  net   slow_ma
# trade_date
# 2019-09-27  1.003568       NaN
# 2019-09-30  0.985737       NaN
# 2019-10-08  1.003569       NaN
# 2019-10-09  1.019261       NaN
# 2019-10-10  1.022827  1.027832
# 44, 浙商证券
#                  net   slow_ma
# trade_date
# 2019-09-27  0.996645       NaN
# 2019-09-30  0.967562       NaN
# 2019-10-08  0.953021       NaN
# 2019-10-09  0.966444       NaN
# 2019-10-10  0.978748  0.969818
# 45, 合盛硅业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.987115       NaN
# 2019-09-30  0.969434       NaN
# 2019-10-08  0.951155       NaN
# 2019-10-09  0.918490       NaN
# 2019-10-10  0.922985  0.920732
# 46, 申能股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.967353       NaN
# 2019-09-30  0.953607       NaN
# 2019-10-08  0.957044       NaN
# 2019-10-09  0.974226       NaN
# 2019-10-10  0.991408  0.982759
# 47, 南京证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.042783       NaN
# 2019-09-30  0.997496       NaN
# 2019-10-08  0.986769       NaN
# 2019-10-09  0.995112       NaN
# 2019-10-10  0.983194  0.975362
# 48, 湖北能源
#                  net   slow_ma
# trade_date
# 2019-09-27  1.007301       NaN
# 2019-09-30  0.990270       NaN
# 2019-10-08  1.009735       NaN
# 2019-10-09  1.007301       NaN
# 2019-10-10  1.009734  1.006166
# 49, 青岛银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.952222       NaN
# 2019-09-30  0.932722       NaN
# 2019-10-08  0.934347       NaN
# 2019-10-09  0.957097       NaN
# 2019-10-10  0.957097  0.961095
# 50, 大连港
#                  net   slow_ma
# trade_date
# 2019-09-27  0.970779       NaN
# 2019-09-30  0.985413       NaN
# 2019-10-08  0.985413       NaN
# 2019-10-09  0.985413       NaN
# 2019-10-10  0.995170  0.986779
# 51, 华西证券
#                  net   slow_ma
# trade_date
# 2019-09-27  1.006088       NaN
# 2019-09-30  0.986991       NaN
# 2019-10-08  0.977946       NaN
# 2019-10-09  0.985986       NaN
# 2019-10-10  0.995032  0.999032
# 52, 南山铝业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.968182       NaN
# 2019-09-30  0.963636       NaN
# 2019-10-08  0.959091       NaN
# 2019-10-09  0.963636       NaN
# 2019-10-10  0.977272  0.985454
# 53, 传化智联
#                  net   slow_ma
# trade_date
# 2019-09-27  1.055707       NaN
# 2019-09-30  1.057065       NaN
# 2019-10-08  1.040761       NaN
# 2019-10-09  1.031251       NaN
# 2019-10-10  1.043479  1.037478
# 54, 建发股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.951005       NaN
# 2019-09-30  0.968822       NaN
# 2019-10-08  0.953231       NaN
# 2019-10-09  0.954345       NaN
# 2019-10-10  0.971049  0.962937
# 55, 桐昆股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.918130       NaN
# 2019-09-30  0.928363       NaN
# 2019-10-08  0.940059       NaN
# 2019-10-09  0.953947       NaN
# 2019-10-10  0.947368  0.943544
# 56, 深圳能源
#                  net   slow_ma
# trade_date
# 2019-09-27  0.978041       NaN
# 2019-09-30  0.976352       NaN
# 2019-10-08  0.988177       NaN
# 2019-10-09  0.989866       NaN
# 2019-10-10  1.000001  0.999662
# 57, 中铁工业
#                  net  slow_ma
# trade_date
# 2019-09-27  0.959493      NaN
# 2019-09-30  0.954840      NaN
# 2019-10-08  0.959493      NaN
# 2019-10-09  0.968799      NaN
# 2019-10-10  0.972521  0.97414
# 58, 太钢不锈
#                  net   slow_ma
# trade_date
# 2019-09-27  0.955112       NaN
# 2019-09-30  0.957606       NaN
# 2019-10-08  0.960099       NaN
# 2019-10-09  0.962593       NaN
# 2019-10-10  0.975061  0.983748
# 59, 中南传媒
#                  net   slow_ma
# trade_date
# 2019-09-27  0.993580       NaN
# 2019-09-30  0.971109       NaN
# 2019-10-08  0.993580       NaN
# 2019-10-09  0.980739       NaN
# 2019-10-10  0.993580  0.985995
# 60, 第一创业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.089579       NaN
# 2019-09-30  1.035833       NaN
# 2019-10-08  1.024433       NaN
# 2019-10-09  1.027691       NaN
# 2019-10-10  1.030948  1.023915
# 61, 步长制药
#                  net   slow_ma
# trade_date
# 2019-09-27  0.994847       NaN
# 2019-09-30  1.008062       NaN
# 2019-10-08  1.002248       NaN
# 2019-10-09  1.012820       NaN
# 2019-10-10  1.018635  1.016965
# 62, 广深铁路
#                  net   slow_ma
# trade_date
# 2019-09-27  0.997401       NaN
# 2019-09-30  0.997401       NaN
# 2019-10-08  0.994163       NaN
# 2019-10-09  0.994163       NaN
# 2019-10-10  1.000640  1.009088
# 63, 中油工程
#                  net   slow_ma
# trade_date
# 2019-09-27  0.935057       NaN
# 2019-09-30  0.945138       NaN
# 2019-10-08  0.937577       NaN
# 2019-10-09  0.940098       NaN
# 2019-10-10  0.942618  0.947388
# 64, 粤电力A
#                  net   slow_ma
# trade_date
# 2019-09-27  0.984998       NaN
# 2019-09-30  0.974999       NaN
# 2019-10-08  0.979998       NaN
# 2019-10-09  0.987498       NaN
# 2019-10-10  0.987498  0.979957
# 65, 张裕A
#                  net   slow_ma
# trade_date
# 2019-09-27  0.975782       NaN
# 2019-09-30  0.957618       NaN
# 2019-10-08  0.966860       NaN
# 2019-10-09  0.946465       NaN
# 2019-10-10  0.941366  0.943638
# 66, 首创股份
#                  net  slow_ma
# trade_date
# 2019-09-27  0.920545      NaN
# 2019-09-30  0.909586      NaN
# 2019-10-08  0.920545      NaN
# 2019-10-09  0.926024      NaN
# 2019-10-10  0.934243  0.94114
# 67, 华宝股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.944513       NaN
# 2019-09-30  0.944513       NaN
# 2019-10-08  0.945444       NaN
# 2019-10-09  0.966212       NaN
# 2019-10-10  0.970552  0.961604
# 68, 格林美
#                  net   slow_ma
# trade_date
# 2019-09-27  0.997793       NaN
# 2019-09-30  0.982340       NaN
# 2019-10-08  0.984547       NaN
# 2019-10-09  0.997792       NaN
# 2019-10-10  1.015452  1.009603
# 69, 诚志股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.938413       NaN
# 2019-09-30  0.930159       NaN
# 2019-10-08  0.947937       NaN
# 2019-10-09  0.960001       NaN
# 2019-10-10  0.962541  0.965228
# 70, 国药一致
#                  net   slow_ma
# trade_date
# 2019-09-27  1.009554       NaN
# 2019-09-30  1.013282       NaN
# 2019-10-08  1.022835       NaN
# 2019-10-09  1.026563       NaN
# 2019-10-10  1.027961  1.023953
# 71, 南洋股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.124916       NaN
# 2019-09-30  1.103074       NaN
# 2019-10-08  1.074405       NaN
# 2019-10-09  1.088740       NaN
# 2019-10-10  1.108535  1.116737
# 72, 秦港股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.931545       NaN
# 2019-09-30  0.922616       NaN
# 2019-10-08  0.934521       NaN
# 2019-10-09  0.943449       NaN
# 2019-10-10  0.961306  0.962796
# 73, 首钢股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.991152       NaN
# 2019-09-30  0.985252       NaN
# 2019-10-08  0.985252       NaN
# 2019-10-09  1.014751       NaN
# 2019-10-10  1.002951  1.008802
# 74, 中文传媒
#                  net   slow_ma
# trade_date
# 2019-09-27  1.079712       NaN
# 2019-09-30  1.051531       NaN
# 2019-10-08  1.028986       NaN
# 2019-10-09  1.012078       NaN
# 2019-10-10  1.013688  1.019781
# 75, 营口港
#                  net   slow_ma
# trade_date
# 2019-09-27  0.992853       NaN
# 2019-09-30  0.981353       NaN
# 2019-10-08  0.989020       NaN
# 2019-10-09  0.992853       NaN
# 2019-10-10  1.000520  1.007391
# 76, 首旅酒店
#                  net   slow_ma
# trade_date
# 2019-09-27  0.955567       NaN
# 2019-09-30  0.944318       NaN
# 2019-10-08  0.932507       NaN
# 2019-10-09  0.917321       NaN
# 2019-10-10  0.951067  0.954264
# 77, 索菲亚
#                  net   slow_ma
# trade_date
# 2019-09-27  0.939838       NaN
# 2019-09-30  0.927914       NaN
# 2019-10-08  0.948510       NaN
# 2019-10-09  0.964771       NaN
# 2019-10-10  0.968023  0.976134
# 78, 粤高速A
#                  net   slow_ma
# trade_date
# 2019-09-27  0.963569       NaN
# 2019-09-30  0.969850       NaN
# 2019-10-08  0.966081       NaN
# 2019-10-09  0.968594       NaN
# 2019-10-10  0.974876  0.968175
# 79, 九阳股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.089594       NaN
# 2019-09-30  1.089096       NaN
# 2019-10-08  1.102038       NaN
# 2019-10-09  1.076155       NaN
# 2019-10-10  1.066983  1.075149
# 80, 露天煤业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.998799       NaN
# 2019-09-30  0.984341       NaN
# 2019-10-08  0.989160       NaN
# 2019-10-09  0.995184       NaN
# 2019-10-10  1.004823  1.001248
# 81, 百联股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.987780       NaN
# 2019-09-30  0.970102       NaN
# 2019-10-08  0.973416       NaN
# 2019-10-09  0.975626       NaN
# 2019-10-10  0.982255  0.988113
# 82, 太极实业
#                  net   slow_ma
# trade_date
# 2019-09-27  1.048779       NaN
# 2019-09-30  1.008128       NaN
# 2019-10-08  0.991868       NaN
# 2019-10-09  1.009483       NaN
# 2019-10-10  1.014903  1.008287
# 83, 万丰奥威
#                  net   slow_ma
# trade_date
# 2019-09-27  0.988764       NaN
# 2019-09-30  0.990168       NaN
# 2019-10-08  1.012640       NaN
# 2019-10-09  1.004213       NaN
# 2019-10-10  0.999999  0.994849
# 84, 嘉化能源
#                  net   slow_ma
# trade_date
# 2019-09-27  0.978361       NaN
# 2019-09-30  0.954014       NaN
# 2019-10-08  0.958523       NaN
# 2019-10-09  0.959425       NaN
# 2019-10-10  0.972049  0.977518
# 85, 唐山港
#                  net   slow_ma
# trade_date
# 2019-09-27  0.922223       NaN
# 2019-09-30  0.911112       NaN
# 2019-10-08  0.918519       NaN
# 2019-10-09  0.925927       NaN
# 2019-10-10  0.944446  0.946729
# 86, 山东出版
#                  net   slow_ma
# trade_date
# 2019-09-27  0.978435       NaN
# 2019-09-30  0.963609       NaN
# 2019-10-08  0.955523       NaN
# 2019-10-09  0.968999       NaN
# 2019-10-10  0.973042  0.980052
# 87, 新钢股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.945263       NaN
# 2019-09-30  0.936842       NaN
# 2019-10-08  0.951578       NaN
# 2019-10-09  0.955789       NaN
# 2019-10-10  0.959999  0.968422
# 88, 山鹰纸业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.922387       NaN
# 2019-09-30  0.919402       NaN
# 2019-10-08  0.919402       NaN
# 2019-10-09  0.922387       NaN
# 2019-10-10  0.940297  0.946367
# 89, 晨鸣纸业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.915739       NaN
# 2019-09-30  0.911891       NaN
# 2019-10-08  0.906120       NaN
# 2019-10-09  0.919587       NaN
# 2019-10-10  0.934977  0.941148
# 90, 供销大集
#                  net   slow_ma
# trade_date
# 2019-09-27  0.995885       NaN
# 2019-09-30  1.028807       NaN
# 2019-10-08  0.954733       NaN
# 2019-10-09  0.946502       NaN
# 2019-10-10  0.954733  0.962826
# 91, 天地科技
#                  net   slow_ma
# trade_date
# 2019-09-27  0.976190       NaN
# 2019-09-30  0.976190       NaN
# 2019-10-08  0.973214       NaN
# 2019-10-09  0.973214       NaN
# 2019-10-10  0.994047  0.984425
# 92, 梅花生物
#                  net   slow_ma
# trade_date
# 2019-09-27  0.978871       NaN
# 2019-09-30  0.978871       NaN
# 2019-10-08  0.983403       NaN
# 2019-10-09  0.981138       NaN
# 2019-10-10  0.992467  0.998749
# 93, 瀚蓝环境
#                  net   slow_ma
# trade_date
# 2019-09-27  1.058138       NaN
# 2019-09-30  1.057541       NaN
# 2019-10-08  1.065299       NaN
# 2019-10-09  1.052766       NaN
# 2019-10-10  1.056943  1.047146
# 94, 东华能源
#                  net   slow_ma
# trade_date
# 2019-09-27  0.940629       NaN
# 2019-09-30  0.918510       NaN
# 2019-10-08  0.922002       NaN
# 2019-10-09  0.940628       NaN
# 2019-10-10  0.945284  0.949554
# 95, 以岭药业
#                  net  slow_ma
# trade_date
# 2019-09-27  0.938471      NaN
# 2019-09-30  0.935006      NaN
# 2019-10-08  0.935872      NaN
# 2019-10-09  0.942804      NaN
# 2019-10-10  0.951470  0.95111
# 96, 广州酒家
#                  net   slow_ma
# trade_date
# 2019-09-27  1.074193       NaN
# 2019-09-30  1.083871       NaN
# 2019-10-08  1.045806       NaN
# 2019-10-09  1.056451       NaN
# 2019-10-10  1.046451  1.046215
# 97, 兆驰股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.975608       NaN
# 2019-09-30  0.972124       NaN
# 2019-10-08  0.979093       NaN
# 2019-10-09  0.986061       NaN
# 2019-10-10  0.999998  1.003484
# 98, 天津港
#                  net   slow_ma
# trade_date
# 2019-09-27  1.006503       NaN
# 2019-09-30  1.001624       NaN
# 2019-10-08  1.008129       NaN
# 2019-10-09  1.004877       NaN
# 2019-10-10  1.017885  1.008211
# 99, 宇信科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.194145       NaN
# 2019-09-30  1.164656       NaN
# 2019-10-08  1.173464       NaN
# 2019-10-09  1.172698       NaN
# 2019-10-10  1.191847  1.185875
# 100, 太极股份
#                  net   slow_ma
# trade_date
# 2019-09-27  1.112410       NaN
# 2019-09-30  1.078104       NaN
# 2019-10-08  1.075184       NaN
# 2019-10-09  1.085768       NaN
# 2019-10-10  1.089417  1.084732
# 101, 滨江集团
#                  net   slow_ma
# trade_date
# 2019-09-27  0.914284       NaN
# 2019-09-30  0.909522       NaN
# 2019-10-08  0.919046       NaN
# 2019-10-09  0.940474       NaN
# 2019-10-10  0.940474  0.945476
# 102, 润和软件
#                  net   slow_ma
# trade_date
# 2019-09-27  1.168582       NaN
# 2019-09-30  1.154023       NaN
# 2019-10-08  1.132567       NaN
# 2019-10-09  1.159388       NaN
# 2019-10-10  1.172415  1.172937
# 103, 嘉凯城
#                  net   slow_ma
# trade_date
# 2019-09-27  0.894666       NaN
# 2019-09-30  0.880985       NaN
# 2019-10-08  0.905609       NaN
# 2019-10-09  0.928865       NaN
# 2019-10-10  0.916553  0.921159
# 104, 中国宝安
#                  net   slow_ma
# trade_date
# 2019-09-27  0.989690       NaN
# 2019-09-30  0.969896       NaN
# 2019-10-08  1.009483       NaN
# 2019-10-09  1.016081       NaN
# 2019-10-10  1.020480  1.020012
# 105, 酒钢宏兴
#                  net   slow_ma
# trade_date
# 2019-09-27  0.949749       NaN
# 2019-09-30  0.934674       NaN
# 2019-10-08  0.944724       NaN
# 2019-10-09  0.949749       NaN
# 2019-10-10  0.959799  0.963652
# 106, 上海钢联
#                  net   slow_ma
# trade_date
# 2019-09-27  1.017243       NaN
# 2019-09-30  1.015312       NaN
# 2019-10-08  0.991450       NaN
# 2019-10-09  1.005106       NaN
# 2019-10-10  1.032416  1.039792
# 107, 新乳业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.919429       NaN
# 2019-09-30  0.907437       NaN
# 2019-10-08  0.898109       NaN
# 2019-10-09  0.890781       NaN
# 2019-10-10  0.922760  0.928255
# 108, 跨境通
#                  net   slow_ma
# trade_date
# 2019-09-27  0.919984       NaN
# 2019-09-30  0.906842       NaN
# 2019-10-08  0.882946       NaN
# 2019-10-09  0.897284       NaN
# 2019-10-10  0.900868  0.896127
# 109, 四川成渝
#                  net   slow_ma
# trade_date
# 2019-09-27  0.933165       NaN
# 2019-09-30  0.930690       NaN
# 2019-10-08  0.918313       NaN
# 2019-10-09  0.923264       NaN
# 2019-10-10  0.938116  0.932878
# 110, 重庆百货
#                  net  slow_ma
# trade_date
# 2019-09-27  1.005631      NaN
# 2019-09-30  1.008798      NaN
# 2019-10-08  0.998242      NaN
# 2019-10-09  1.004927      NaN
# 2019-10-10  0.999298  0.99002
# 111, 横店东磁
#                  net   slow_ma
# trade_date
# 2019-09-27  1.011642       NaN
# 2019-09-30  0.992719       NaN
# 2019-10-08  1.008731       NaN
# 2019-10-09  1.017464       NaN
# 2019-10-10  1.018920  1.014482
# 112, 南京高科
#                  net   slow_ma
# trade_date
# 2019-09-27  0.937173       NaN
# 2019-09-30  0.930995       NaN
# 2019-10-08  0.937174       NaN
# 2019-10-09  0.952622       NaN
# 2019-10-10  0.954682  0.960502
# 113, 彤程新材
#                  net   slow_ma
# trade_date
# 2019-09-27  0.949774       NaN
# 2019-09-30  0.954747       NaN
# 2019-10-08  0.956239       NaN
# 2019-10-09  0.970163       NaN
# 2019-10-10  0.967676  0.976561
# 114, 金禾实业
#                  net  slow_ma
# trade_date
# 2019-09-27  1.041716      NaN
# 2019-09-30  1.064177      NaN
# 2019-10-08  1.056690      NaN
# 2019-10-09  1.063642      NaN
# 2019-10-10  1.069524  1.06994
# 115, 奇正藏药
#                  net   slow_ma
# trade_date
# 2019-09-27  0.937955       NaN
# 2019-09-30  0.927919       NaN
# 2019-10-08  0.953923       NaN
# 2019-10-09  0.937499       NaN
# 2019-10-10  0.953467  0.958151
# 116, 上海贝岭
#                  net   slow_ma
# trade_date
# 2019-09-27  1.009263       NaN
# 2019-09-30  0.999336       NaN
# 2019-10-08  1.003307       NaN
# 2019-10-09  1.024485       NaN
# 2019-10-10  1.031103  1.025279
# 117, 数知科技
#                  net   slow_ma
# trade_date
# 2019-09-27  1.030736       NaN
# 2019-09-30  1.013174       NaN
# 2019-10-08  0.998903       NaN
# 2019-10-09  1.003294       NaN
# 2019-10-10  1.013174  1.018734
# 118, 鄂尔多斯
#                  net   slow_ma
# trade_date
# 2019-09-27  0.998940       NaN
# 2019-09-30  1.018225       NaN
# 2019-10-08  1.009226       NaN
# 2019-10-09  1.018225       NaN
# 2019-10-10  1.022082  1.030685
# 119, 中新药业
#                  net   slow_ma
# trade_date
# 2019-09-27  0.984966       NaN
# 2019-09-30  0.993650       NaN
# 2019-10-08  1.008125       NaN
# 2019-10-09  1.004506       NaN
# 2019-10-10  1.016085  1.010255
# 120, 罗牛山
#                  net   slow_ma
# trade_date
# 2019-09-27  0.977585       NaN
# 2019-09-30  0.974383       NaN
# 2019-10-08  0.972248       NaN
# 2019-10-09  0.975450       NaN
# 2019-10-10  0.985055  0.989717
# 121, 中材国际
#                  net   slow_ma
# trade_date
# 2019-09-27  0.944270       NaN
# 2019-09-30  0.933124       NaN
# 2019-10-08  0.945863       NaN
# 2019-10-09  0.955417       NaN
# 2019-10-10  0.963378  0.971524
# 122, 民和股份
#                  net   slow_ma
# trade_date
# 2019-09-27  0.942064       NaN
# 2019-09-30  0.937442       NaN
# 2019-10-08  0.996609       NaN
# 2019-10-09  1.051463       NaN
# 2019-10-10  1.072110  1.067956
# 123, 南京熊猫
#                  net   slow_ma
# trade_date
# 2019-09-27  0.987575       NaN
# 2019-09-30  0.976898       NaN
# 2019-10-08  1.001810       NaN
# 2019-10-09  1.007149       NaN
# 2019-10-10  1.013377  1.010263
# 124, 航天彩虹
#                  net   slow_ma
# trade_date
# 2019-09-27  1.010978       NaN
# 2019-09-30  0.991764       NaN
# 2019-10-08  0.985359       NaN
# 2019-10-09  0.987189       NaN
# 2019-10-10  0.996339  1.005292
# 125, 深康佳A
#                  net   slow_ma
# trade_date
# 2019-09-27  1.049756       NaN
# 2019-09-30  1.044781       NaN
# 2019-10-08  1.049757       NaN
# 2019-10-09  1.042294       NaN
# 2019-10-10  1.044782  1.052531
# 126, 平高电气
#                  net   slow_ma
# trade_date
# 2019-09-27  0.922555       NaN
# 2019-09-30  0.915994       NaN
# 2019-10-08  0.922555       NaN
# 2019-10-09  0.961925       NaN
# 2019-10-10  0.963237  0.967951
# 127, 无锡银行
#                  net   slow_ma
# trade_date
# 2019-09-27  0.967451       NaN
# 2019-09-30  0.947560       NaN
# 2019-10-08  0.952984       NaN
# 2019-10-09  0.976493       NaN
# 2019-10-10  0.972876  0.980712
# 128, 珠江钢琴
#                  net   slow_ma
# trade_date
# 2019-09-27  1.019552       NaN
# 2019-09-30  1.018155       NaN
# 2019-10-08  1.027932       NaN
# 2019-10-09  1.029329       NaN
# 2019-10-10  1.019552  1.009752
# 2019-10-10 22:02:19.832968
# 符合条件的stock num: 59
# ['工商银行',
#  '建设银行',
#  '海康威视',
#  '万华化学',
#  '中国铁建',
#  '北京银行',
#  '招商证券',
#  '广发证券',
#  '江苏银行',
#  '韵达股份',
#  '华域汽车',
#  '国投电力',
#  '方正证券',
#  '上海医药',
#  '大华股份',
#  '欧派家居',
#  '广联达',
#  '美凯龙',
#  '巨人网络',
#  '北新建材',
#  '亨通光电',
#  '浙商证券',
#  '合盛硅业',
#  '申能股份',
#  '南京证券',
#  '湖北能源',
#  '大连港',
#  '传化智联',
#  '建发股份',
#  '桐昆股份',
#  '深圳能源',
#  '中南传媒',
#  '第一创业',
#  '步长制药',
#  '粤电力A',
#  '华宝股份',
#  '格林美',
#  '国药一致',
#  '粤高速A',
#  '露天煤业',
#  '太极实业',
#  '万丰奥威',
#  '天地科技',
#  '瀚蓝环境',
#  '以岭药业',
#  '广州酒家',
#  '天津港',
#  '宇信科技',
#  '太极股份',
#  '中国宝安',
#  '跨境通',
#  '四川成渝',
#  '重庆百货',
#  '横店东磁',
#  '上海贝岭',
#  '中新药业',
#  '民和股份',
#  '南京熊猫',
#  '珠江钢琴']

# %% [markdown]
# # a

# %%
SMA.stock_select('华胜天成')
# Out:
# True

# %%
SMA.sma_base('工商银行', count=3*250)
# Out:
# returns    1.420783
# strat      1.163338
# dtype: float64
# returns    0.012678
# strat      0.010208
# dtype: float64
# hold_max_drawdown: -0.3446326645042419
# strat_max_drawdown: -0.28174801269825445

# %%
SMA.stock_select('农业银行')
# Out:
#                  net
# trade_date
# 2019-06-28  0.994475
# 2019-07-01  1.000000
# 2019-07-02  1.005525
# 2019-07-03  1.011051
# 2019-07-04  1.011051
#                  net
# trade_date
# 2019-09-16  0.972375
# 2019-09-17  0.964087
# 2019-09-18  0.961325
# 2019-09-19  0.961325
# 2019-09-20  0.964088
#                  net   fast_ma   slow_ma
# trade_date
# 2019-09-16  0.972375  0.965468       NaN
# 2019-09-17  0.964087  0.966850       NaN
# 2019-09-18  0.961325  0.966850       NaN
# 2019-09-19  0.961325  0.966504       NaN
# 2019-09-20  0.964088  0.966504  0.970764
# True

# %%
sma_base('农业银行', count=365, fast_ma=8, slow_ma=60)
# Out:
# returns    1.014592
# strat      0.963700
# dtype: float64
# returns    0.009298
# strat      0.007841
# dtype: float64
# hold_max_drawdown: -0.09064076953719413
# strat_max_drawdown: -0.0883253959812983

# %%
sma('600115.SH', 10, 60)
# Out:
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# /Users/luoyonggui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# returns    0.749975
# strat      0.916800
# dtype: float64
# hold_max_drawdown: -0.4637832208594973
# strat_max_drawdown: -0.2621351631716585

# %%
可以看到，策略长时间收益不及长期持有的收益，原因：上涨时反应慢收益少，下跌时反应慢造成大幅回撤

如何改进？
1、买入时的假信号。这个有点难
2、卖出是减少回撤，这个好像有点办法。如计算短期均线回踩长期均线的次数，进行提前减仓或清仓

# %%
sma('600567.SH', 10, 60)
# Out:
#      pct_chg trade_date
# 724  -0.9404 2019-09-23
# 725   0.0000 2019-09-24
# 726  -1.2658 2019-09-25
# 727  -1.2821 2019-09-26
# 728   0.3247 2019-09-27
# returns    0.885017
# strat      2.418716
# dtype: float64
# returns    0.018985
# strat      0.018940
# dtype: float64

# %%
np.exp(data[['returns','strat']].sum())
# Out:
# returns     1.119147
# strat      59.568000
# dtype: float64

# %%
data[['returns','strat']].std()
# Out:
# returns    0.028735
# strat      0.028718
# dtype: float64

# %%
g = data[['returns','strat']]

# %%
g.var()**0.5
# Out:
# returns    0.015785
# strat      0.015774
# dtype: float64

# %%
data[['returns','strat']].var()*252**0.5
# Out:
# returns    0.003955
# strat      0.003950
# dtype: float64

# %%
data[['returns','strat']].std()*252**0.5
# Out:
# returns    0.250571
# strat      0.250407
# dtype: float64

# %%
ax=data[['returns','strat']].cumsum().apply(np.exp).plot(figsize=(10,6))
data['position'].plot(ax=ax,secondary_y='position',style='--')
ax.get_legend().set_bbox_to_anchor((0.25,0.85))

# %%
from itertools import product
sma1=range(20,61,4)
sma2=range(180,281,10)
results=pd.DataFrame()
for SMA1,SMA2 in product(sma1,sma2):
    data=pd.DataFrame(df[symbol])
    data.dropna(inplace=True)
    data['returns']=np.log(data[symbol]/data[symbol].shift(1))
    data['SMA1']=data[symbol].rolling(SMA1).mean()
    data['SMA2']=data[symbol].rolling(SMA2).mean()
    data.dropna(inplace=True)
    data['position']=np.where(data['SMA1']>data['SMA2'],1,-1)
    data['strat']=data['position'].shift(1)*data['returns']
    data.dropna(inplace=True)
    pref=np.exp(data[['returns','strat']].sum())
    results=results.append(pd.DataFrame(
                {'SMA1':SMA1,'SMA2':SMA2,'MKT':pref['returns'],
                'strat':pref['strat'],
                'OUT':pref['strat']-pref['returns']},index=[0]),ignore_index=True)

# %%
results.sort_values('OUT',ascending=False).head()
# Out:
#      SMA1  SMA2       MKT      strat        OUT
# 113    60   210  1.088796  54.853838  53.765042
# 101    56   200  1.073628  50.129940  49.056312
# 112    60   200  1.073628  48.952989  47.879361
# 4      20   220  1.125262  37.589829  36.464567
# 99     56   180  0.970930  35.879995  34.909065

# %%
import math
import numpy as np
import scipy.stats as scs
import statsmodels.api as sm

# %%
def print_stat(array):
    sta=scs.describe(array)
    print('%14s %15s'%('statistics','value'))
    print(30*'-')
    print('%14s %15.5f'%('size',round(sta[0])))
    print('%14s %15.5f'%('min',sta[1][0]))
    print('%14s %15.5f'%('max',sta[1][1]))
    print('%14s %15.5f'%('mean',sta[2]))
    print('%14s %15.5f'%('std',np.sqrt(sta[3])))
    print('%14s %15.5f'%('skew',sta[4]))
    print('%14s %15.5f'%('kurtosis',sta[5]))

# %%
print_stat(data.strat.values)
# Out:
#     statistics           value
# ------------------------------
#           size      1858.00000
#            min        -0.08330
#            max         0.13187
#           mean         0.00066
#            std         0.01582
#           skew         0.38438
#       kurtosis         5.15146

# %%
plt.figure(figsize=(10,6))
plt.hist(data.strat.values,bins=100,density=True,label='frequency',color='b')
plt.xlabel('Strat_log_return')
plt.ylabel('frequency')
x=np.linspace(plt.axis()[0],plt.axis()[1])
plt.plot(x,scs.norm.pdf(x,data.strat.mean(),data.strat.std()),
        'r',lw=2.0,label='pdf')
plt.legend()

# %%
尖峰厚尾

# %%
sm.qqplot(data.strat.values,line='s')
plt.xlabel('theoretical')
plt.ylabel('sample quantiles')
# Out:
# Text(0, 0.5, 'sample quantiles')

# %%
def normal_test(arr):
    print('Skew of dataset    %14.3f' % scs.skew(arr))
    print('Skew test Pvalue   %14.3f' % scs.skewtest(arr)[1])
    print('Kurt of dataset    %14.3f' % scs.kurtosis(arr))
    print('Kurt test Pvalue   %14.3f' % scs.kurtosistest(arr)[1])
    print('Normal test Pvalue %14.3f' % scs.normaltest(arr)[1])

# %%
normal_test(data.strat.values)
# Out:
# Skew of dataset             0.384
# Skew test Pvalue            0.000
# Kurt of dataset             5.151
# Kurt test Pvalue            0.000
# Normal test Pvalue          0.000

# %%
np.quantile(data.strat.values,0.01)
# Out:
# -0.0420593102509018

# %%
np.quantile(data.strat.mean()+data.strat.std()*np.random.standard_normal(10000),0.01)
# Out:
# -0.03529155206844548

# %% [markdown]
# # MACD
# https://www.cnblogs.com/fangbei/p/wequant-strategy-macd.html

# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-

# 策略代码总共分为三大部分，1)PARAMS变量 2)initialize函数 3)handle_data函数
# 请根据指示阅读。或者直接点击运行回测按钮，进行测试，查看策略效果。

# 策略名称：MACD指标策略
# 策略详细介绍：https://wequant.io/study/strategy.macd.html
# 关键词：指数平滑移动均线、多空头预测。
# 方法：
# 1)利用talib库计算MACD值
# 2)MACD柱>0时买入，MACD柱<0时卖出

import numpy as np
import talib

# 阅读1，首次阅读可跳过:
# PARAMS用于设定程序参数，回测的起始时间、结束时间、滑点误差、初始资金和持仓。
# 可以仿照格式修改，基本都能运行。如果想了解详情请参考新手学堂的API文档。
PARAMS = {
    "start_time": "2017-02-01 00:00:00",
    "end_time": "2017-08-01 00:00:00",
    "slippage": 0.003,  # 此处“slippage"包含佣金（千二）+交易滑点（千一）
    "account_initial": {"cash": 100000,
                      "security": 0},
}

# %%
class Data:
    def get_price(security_code, count=365, frequency='1d'):
        import sys
        sys.path.append('/Users/luoyonggui/PycharmProjects/mayiutils_n1/mayiutils/db')
        from pymongo_wrapper import PyMongoWrapper
        mongo = PyMongoWrapper()
        table = mongo.getCollection('finance', security_code)
        start_date = datetime.now() - timedelta(days=count)
        dft = mongo.findAll(table, {'trade_date': {'$gte': start_date}}, fieldlist=['trade_date', 'pct_chg', 'close'], returnFmt='df')
    
        
class User_data:
    pass
class Account:
    def __init__(self, cash, security):
        self.cash = cash
        self.security = security
class Order:
    def sell_limit(security, quantity, price):
        pass
    def buy_limit(security, quantity, price):
        
        
class Context:
    def __init__(self, user_data=User_data(), account=Account(**PARAMS['account_initial'])):
        self.user_data = user_data
        self.account = account
        import sys
        # print(sys.path)
        sys.path.append('/Users/luoyonggui/PycharmProjects/mayiutils_n1/mayiutils/config')
        from logging_utils import get_logger
        log_path = os.path.join(LOG_PATH, 'output.log')
        self.log = get_logger(__file__, file_handler=True, log_path=log_path)

# %%
context = Context()

# %%
# 阅读2，遇到不明白的变量可以跳过，需要的时候回来查阅:
# initialize函数是两大核心函数之一（另一个是handle_data），用于初始化策略变量。
# 策略变量包含：必填变量，以及非必填（用户自己方便使用）的变量
def initialize(context):
#     context = {
#         'frequency': '1d',
#         'benchmark': '000001.SH',
#         'security': '东方航空',
#         'user_data': {
#             'fast_period': 12,
#             'slow_period': 26,
#             'macd_window': 9,
#             'longest_history': 100
#         }
#     }
    # 设置回测频率, 可选："1m", "5m", "15m", "30m", "60m", "4h", "1d", "1w"
    context.frequency = "15m"
    # 设置回测基准, 比特币："huobi_cny_btc", 莱特币："huobi_cny_ltc", 以太坊："huobi_cny_eth"
    context.benchmark = "huobi_cny_btc"
    # 设置回测标的, 比特币："huobi_cny_btc", 莱特币："huobi_cny_ltc", 以太坊："huobi_cny_eth"
    context.security = "huobi_cny_btc"

    # 设置使用talib计算MACD的参数
    # 周期快速移动平均
    context.user_data.fast_period = 12
    # 周期慢速移动平均
    context.user_data.slow_period = 26
    # 周期移动平均
    context.user_data.macd_window = 9
    # 历史数据要足够长，才能够拿到收敛的MACD
    context.user_data.longest_history = 100
    print(context)
    return context

# %%
context = initialize(context)
# Out:
# <__main__.Context object at 0x1118b8a20>

# %%
context.user_data.longest_history
# Out:
# 100

# %%
context.user_data.macd_window
# Out:
# 9

# %%
# 阅读3，策略核心逻辑：
# handle_data函数定义了策略的执行逻辑，按照frequency生成的bar依次读取并执行策略逻辑，直至程序结束。
# handle_data和bar的详细说明，请参考新手学堂的解释文档。
def handle_data(context):
    # 获取历史数据, 取后longest_history根bar
    hist = context.data.get_price(context.security, count=context.user_data.longest_history, frequency=context.frequency)
    if len(hist.index) < context.user_data.longest_history:
        context.log.warn("bar的数量不足, 等待下一根bar...")
        return

    # 历史收盘价
    prices = np.array(hist["close"])
    # 初始化买入卖出信号
    long_signal_triggered = False
    short_signal_triggered = False

    try:
        # talib计算MACD，返回三个数组，分别为DIF, DEA和MACD的值
        macd_tmp = talib.MACD(prices, fastperiod=context.user_data.fast_period, slowperiod=context.user_data.slow_period, signalperiod=context.user_data.macd_window)
        # 获取MACD值
        macd_hist = macd_tmp[2]
        # 获取最新一个MACD的值
        macd = macd_hist[-1]
        context.log.info("当前MACD为: %s" % macd)
    except:
        context.log.error("计算MACD出错...")
        return
    for macd in macd_hist:
        context.log.info("当前MACD为: %s" % macd)
        # macd大于0时，产生买入信号
        if macd > 0:
            long_signal_triggered = True
        # macd小于0时，产生卖出信号
        elif macd < 0:
            short_signal_triggered = True

        # 有卖出信号，且持有仓位，则市价单全仓卖出
        if short_signal_triggered:
            context.log.info("MACD小于0，产生卖出信号")
            if context.account.security >= 0:
                # 卖出信号，且不是空仓，则市价单全仓清空
                context.log.info("正在卖出 %s" % context.security)
                context.log.info("卖出数量为 %s" % context.account.security)
                context.order.sell_limit(context.security, quantity=str(context.account.huobi_cny_btc), price=str(prices[-1]*0.98))
            else:
                context.log.info("仓位不足，无法卖出")
        # 有买入信号，且持有现金，则市价单全仓买入
        elif long_signal_triggered:
            context.log.info("MACD大于0，产生买入信号")
            if context.account.cash >= 0:
                # 买入信号，且持有现金，则市价单全仓买入
                context.log.info("正在买入 %s" % context.security)
                context.log.info("下单金额为 %s 元" % context.account.huobi_cny_cash)
                context.order.buy_limit(context.security, quantity=str(context.account.huobi_cny_cash/prices[-1]*0.98), price=str(prices[-1]*1.02))
            else:
                context.log.info("现金不足，无法下单")
        else:
            context.log.info("无交易信号，进入下一根bar")
